# %% [markdown]
# ### **Curating Tcel13290870**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290870_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4991 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
print(adata.X)
# Out:
#   (0, 16)	1.0
#   (0, 63)	3.0
#   (0, 123)	1.0
#   (0, 156)	1.0
#   (0, 193)	4.0
#   (0, 207)	1.0
#   (0, 234)	1.0
#   (0, 279)	1.0
#   (0, 296)	1.0
#   (0, 335)	1.0
#   (0, 357)	1.0
#   (0, 385)	1.0
#   (0, 392)	1.0
#   (0, 446)	1.0
#   (0, 447)	2.0
#   (0, 477)	1.0
#   (0, 521)	8.0
#   (0, 537)	1.0
#   (0, 547)	2.0
#   (0, 552)	1.0
#   (0, 567)	1.0
#   (0, 573)	1.0
#   (0, 574)	1.0
#   (0, 608)	1.0
#   (0, 614)	1.0
#   :	:
#   (4990, 31395)	1.0
#   (4990, 31398)	1.0
#   (4990, 31414)	1.0
#   (4990, 31415)	1.0
#   (4990, 31416)	1.0
#   (4990, 31418)	45.0
#   (4990, 31422)	1.0
#   (4990, 31433)	1.0
#   (4990, 31439)	1.0
#   (4990, 31441)	1.0
#   (4990, 31450)	60.0
#   (4990, 31474)	1.0
#   (4990, 32195)	25.0
#   (4990, 32196)	7.0
#   (4990, 32197)	669.0
#   (4990, 32198)	109.0
#   (4990, 32200)	273.0
#   (4990, 32201)	416.0
#   (4990, 32202)	4.0
#   (4990, 32204)	17.0
#   (4990, 32205)	1.0
#   (4990, 32207)	31.0
#   (4990, 32221)	2.0
#   (4990, 32231)	1.0
#   (4990, 32284)	2.0

# %%
counts = adata.X

# Create a boolean mask for non-zero elements
non_zero_mask = counts != 0

# Convert non-zero values to integers
counts[non_zero_mask] = counts[non_zero_mask].round().astype(int)

# Update the 'counts' layer
adata.X = counts

# %%
adata.X
# Out:
# <4991x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 19338455 stored elements in Compressed Sparse Row format>

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['TACTCACAACGTAGTA-1']

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
adata.var_names_make_unique()

# %%
# Check if the number of observations (cells/spots) in adata is less than 4992
if adata.obs.shape[0] < 4992:
    # Read the tissue positions from a CSV file into a DataFrame
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv')
    
    # Create a set of observation names (barcodes) currently in adata
    obs_names_in_adata = set(adata.obs_names)
    
    # Find barcodes that are in all_barcodes but not in adata.obs_names
    missing_barcodes = all_barcodes[~all_barcodes['barcode'].isin(obs_names_in_adata)]
    
    # Create an empty sparse matrix to represent the missing data for those barcodes
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    
    # Create a new AnnData object for the missing barcodes with the empty matrix and appropriate metadata
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue', 'array_row', 'array_col']])
    
    # Concatenate the original adata with the new AnnData object containing the missing barcodes
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    
    # Update the spatial coordinates in comb_adata by combining the existing spatial data with the missing barcodes' spatial data
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'], missing_barcodes[['array_col', 'array_row']].values))
    
    # Update adata to be the concatenated and updated comb_adata
    adata = comb_adata
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float64'>'
# 	with 19338455 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 16)	1.0
#   (0, 63)	3.0
#   (0, 123)	1.0
#   (0, 156)	1.0
#   (0, 193)	4.0
#   (0, 207)	1.0
#   (0, 234)	1.0
#   (0, 279)	1.0
#   (0, 296)	1.0
#   (0, 335)	1.0
#   (0, 357)	1.0
#   (0, 385)	1.0
#   (0, 392)	1.0
#   (0, 446)	1.0
#   (0, 447)	2.0
#   (0, 477)	1.0
#   (0, 521)	8.0
#   (0, 537)	1.0
#   (0, 547)	2.0
#   (0, 552)	1.0
#   (0, 567)	1.0
#   (0, 573)	1.0
#   (0, 574)	1.0
#   (0, 608)	1.0
#   (0, 614)	1.0
#   :	:
#   (4990, 31395)	1.0
#   (4990, 31398)	1.0
#   (4990, 31414)	1.0
#   (4990, 31415)	1.0
#   (4990, 31416)	1.0
#   (4990, 31418)	45.0
#   (4990, 31422)	1.0
#   (4990, 31433)	1.0
#   (4990, 31439)	1.0
#   (4990, 31441)	1.0
#   (4990, 31450)	60.0
#   (4990, 31474)	1.0
#   (4990, 32195)	25.0
#   (4990, 32196)	7.0
#   (4990, 32197)	669.0
#   (4990, 32198)	109.0
#   (4990, 32200)	273.0
#   (4990, 32201)	416.0
#   (4990, 32202)	4.0
#   (4990, 32204)	17.0
#   (4990, 32205)	1.0
#   (4990, 32207)	31.0
#   (4990, 32221)	2.0
#   (4990, 32231)	1.0
#   (4990, 32284)	2.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col
# AAACAACGAATAGTTC-1        0.0        0.0        0.0
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0
# AAACAATCTACTAGCA-1        0.0        3.0        3.0
# AAACACCAATAACTGC-1        1.0       59.0       59.0
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0
# ...                       ...        ...        ...
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0
# TTGTTTCCATACAACT-1        0.0       45.0       45.0
# TTGTTTGTATTACACG-1        1.0       73.0       73.0
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0
# 386                       0.0        6.0        2.0
#
# [4992 rows x 3 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13290870_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1        1.0  4A_Hh.only               5242
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1        1.0  4A_Hh.only               5388
# Mus_Tcel13290870_AAACATTTCCCGGATT-1        1.0  4A_Hh.only               5149
# Mus_Tcel13290870_AAACCCGAACGAAATC-1        1.0  4A_Hh.only               5588
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1        1.0  4A_Hh.only               6923
# ...                                        ...         ...                ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1        1.0  4A_Hh.only               6376
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1        1.0  4A_Hh.only               4531
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1        1.0  4A_Hh.only               4606
# Mus_Tcel13290870_TTGTTTGTATTACACG-1        1.0  4A_Hh.only               5007
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1        1.0  4A_Hh.only               4023
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                 8.564650       23498.0
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                 8.592115       36593.0
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                 8.546752       22539.0
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                 8.628555       29907.0
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                 8.842749       49507.0
# ...                                                      ...           ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                 8.760453       39167.0
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                 8.418919       18331.0
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                 8.435332       27784.0
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                 8.518792       26104.0
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                 8.300032       19799.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1           10.064713
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1           10.507640
# Mus_Tcel13290870_AAACATTTCCCGGATT-1           10.023046
# Mus_Tcel13290870_AAACCCGAACGAAATC-1           10.305882
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1           10.809890
# ...                                                 ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1           10.575615
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1            9.816403
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1           10.232251
# Mus_Tcel13290870_TTGTTTGTATTACACG-1           10.169882
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1            9.893437
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                   23.763725
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                   32.866943
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                   20.657526
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                   22.870899
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                   24.154160
# ...                                                         ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                   25.547016
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                   21.613661
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                   34.098763
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                   28.156605
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                   33.451183
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    35.807304
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    41.691032
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    30.706776
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    33.025715
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    36.305977
# ...                                                          ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    34.613323
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    32.251377
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    42.056580
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    36.760651
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    41.411182
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    48.084942
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    51.654690
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    43.076447
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    45.206806
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    49.102146
# ...                                                          ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    46.015778
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    44.874802
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    51.133747
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    47.345234
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    50.750038
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    61.354156  ...
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    66.444405  ...
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    58.440926  ...
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    60.504230  ...
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    62.522472  ...
# ...                                                          ...  ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    60.739910  ...
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    60.280399  ...
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    65.699684  ...
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    62.902237  ...
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    65.528564  ...
#
#                                        donor_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1  4A_Hh.only
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1  4A_Hh.only
# Mus_Tcel13290870_AAACATTTCCCGGATT-1  4A_Hh.only
# Mus_Tcel13290870_AAACCCGAACGAAATC-1  4A_Hh.only
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1  4A_Hh.only
# ...                                         ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1  4A_Hh.only
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1  4A_Hh.only
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1  4A_Hh.only
# Mus_Tcel13290870_TTGTTTGTATTACACG-1  4A_Hh.only
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1  4A_Hh.only
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                     MmusDv:0000061
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                     MmusDv:0000061
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                     MmusDv:0000061
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                     MmusDv:0000061
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                     MmusDv:0000061
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                     MmusDv:0000061
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1             PATO:0000461            True
# Mus_Tcel13290870_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13290870_AAACCCGAACGAAATC-1             PATO:0000461            True
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTGTATTACACG-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACCCGAACGAAATC-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTGTATTACACG-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                                       na
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                                       na
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                                       na
# ...                                                                      ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                                       na
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1              unknown               na
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1              unknown               na
# Mus_Tcel13290870_AAACATTTCCCGGATT-1              unknown               na
# Mus_Tcel13290870_AAACCCGAACGAAATC-1              unknown               na
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1              unknown               na
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1              unknown               na
# Mus_Tcel13290870_TTGTTTGTATTACACG-1              unknown               na
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
# [3176 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1        1.0  4A_Hh.only               5242
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1        1.0  4A_Hh.only               5388
# Mus_Tcel13290870_AAACATTTCCCGGATT-1        1.0  4A_Hh.only               5149
# Mus_Tcel13290870_AAACCCGAACGAAATC-1        1.0  4A_Hh.only               5588
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1        1.0  4A_Hh.only               6923
# ...                                        ...         ...                ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1        1.0  4A_Hh.only               6376
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1        1.0  4A_Hh.only               4531
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1        1.0  4A_Hh.only               4606
# Mus_Tcel13290870_TTGTTTGTATTACACG-1        1.0  4A_Hh.only               5007
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1        1.0  4A_Hh.only               4023
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                 8.564650       23498.0
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                 8.592115       36593.0
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                 8.546752       22539.0
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                 8.628555       29907.0
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                 8.842749       49507.0
# ...                                                      ...           ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                 8.760453       39167.0
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                 8.418919       18331.0
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                 8.435332       27784.0
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                 8.518792       26104.0
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                 8.300032       19799.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1           10.064713
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1           10.507640
# Mus_Tcel13290870_AAACATTTCCCGGATT-1           10.023046
# Mus_Tcel13290870_AAACCCGAACGAAATC-1           10.305882
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1           10.809890
# ...                                                 ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1           10.575615
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1            9.816403
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1           10.232251
# Mus_Tcel13290870_TTGTTTGTATTACACG-1           10.169882
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1            9.893437
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                   23.763725
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                   32.866943
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                   20.657526
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                   22.870899
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                   24.154160
# ...                                                         ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                   25.547016
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                   21.613661
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                   34.098763
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                   28.156605
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                   33.451183
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    35.807304
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    41.691032
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    30.706776
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    33.025715
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    36.305977
# ...                                                          ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    34.613323
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    32.251377
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    42.056580
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    36.760651
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    41.411182
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    48.084942
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    51.654690
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    43.076447
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    45.206806
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    49.102146
# ...                                                          ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    46.015778
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    44.874802
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    51.133747
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    47.345234
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    50.750038
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                    61.354156  ...
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                    66.444405  ...
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                    58.440926  ...
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                    60.504230  ...
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                    62.522472  ...
# ...                                                          ...  ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                    60.739910  ...
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                    60.280399  ...
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                    65.699684  ...
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                    62.902237  ...
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                    65.528564  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                      MmusDv:0000061
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                      MmusDv:0000061
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                      MmusDv:0000061
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                      MmusDv:0000061
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                      MmusDv:0000061
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                      MmusDv:0000061
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                      MmusDv:0000061
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1             PATO:0000461            True
# Mus_Tcel13290870_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13290870_AAACCCGAACGAAATC-1             PATO:0000461            True
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTGTATTACACG-1             PATO:0000461            True
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACCCGAACGAAATC-1           NCBITaxon:10090
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTGTATTACACG-1           NCBITaxon:10090
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1                                       na
# Mus_Tcel13290870_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13290870_AAACCCGAACGAAATC-1                                       na
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1                                       na
# ...                                                                      ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13290870_TTGTTTGTATTACACG-1                                       na
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1              unknown              na
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1              unknown              na
# Mus_Tcel13290870_AAACATTTCCCGGATT-1              unknown              na
# Mus_Tcel13290870_AAACCCGAACGAAATC-1              unknown              na
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1              unknown              na
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1              unknown              na
# Mus_Tcel13290870_TTGTTTGTATTACACG-1              unknown              na
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13290870_AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA
# Mus_Tcel13290870_AAACAGTGTTCCTGGG-1  AAACAGTGTTCCTGGG
# Mus_Tcel13290870_AAACATTTCCCGGATT-1  AAACATTTCCCGGATT
# Mus_Tcel13290870_AAACCCGAACGAAATC-1  AAACCCGAACGAAATC
# Mus_Tcel13290870_AAACCGGGTAGGTACC-1  AAACCGGGTAGGTACC
# ...                                               ...
# Mus_Tcel13290870_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13290870_TTGTTTCACATCCAGG-1  TTGTTTCACATCCAGG
# Mus_Tcel13290870_TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA
# Mus_Tcel13290870_TTGTTTGTATTACACG-1  TTGTTTGTATTACACG
# Mus_Tcel13290870_TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC
#
# [3176 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0009010',
#  'AAACAGTGTTCCTGGG': 'CL:0000584',
#  'AAACATTTCCCGGATT': 'CL:0009010',
#  'AAACCCGAACGAAATC': 'CL:0000584',
#  'AAACCGGGTAGGTACC': 'CL:0009010',
#  'AAACCGTTCGTCCAGG': 'CL:0000584',
#  'AAACCTAAGCAGCCGG': 'CL:0000584',
#  'AAACGAGACGGTTGAT': 'CL:0000584',
#  'AAACGGTTGCGAACTG': 'CL:0000584',
#  'AAACTAACGTGGCGAC': 'CL:0000584',
#  'AAACTGCTGGCTCCAA': 'CL:0000584',
#  'AAAGAATGTGGACTAA': 'CL:0000584',
#  'AAAGACATGAAGTTTA': 'CL:0000186',
#  'AAAGCTTGCCTACATA': 'CL:0000584',
#  'AAAGGCTACGGACCAT': 'CL:0000186',
#  'AAAGGCTCTCGCGCCG': 'CL:0000186',
#  'AAAGGGATGTAGCAAG': 'CL:0000034',
#  'AAAGGGCAGCTTGAAT': 'CL:0000584',
#  'AAAGGTAAGCTGTACC': 'CL:0009010',
#  'AAAGTAGCATTGCTCA': 'CL:0000584',
#  'AAAGTGCCATCAATTA': 'CL:0000584',
#  'AAAGTGTGATTTATCT': 'CL:0000034',
#  'AAAGTTGACTCCCGTA': 'CL:0000034',
#  'AAATAACCATACGGGA': 'CL:0000584',
#  'AAATAAGGTAGTGCCC': 'CL:0000584',
#  'AAATACCTATAAGCAT': 'CL:0000584',
#  'AAATAGCTTAGACTTT': 'CL:0000584',
#  'AAATAGGGTGCTATTG': 'CL:0000034',
#  'AAATCCGATACACGCC': 'CL:0000584',
#  'AAATCGTGTACCACAA': 'CL:0000584',
#  'AAATCTAGCCCTGCTA': 'CL:0009010',
#  'AAATGACTGATCAAAC': 'CL:0009010',
#  'AAATGCTCGTTACGTT': 'CL:0000584',
#  'AAATGGCATGTCTTGT': 'CL:0000584',
#  'AAATGGCCCGTGCCCT': 'CL:0000584',
#  'AAATGGTCAATGTGCC': 'CL:0000034',
#  'AAATGTGGGTGCTCCT': 'CL:0000584',
#  'AAATTAACGGGTAGCT': 'CL:0000034',
#  'AAATTACACGACTCTG': 'CL:0009010',
#  'AAATTACCTATCGATG': 'CL:0000584',
#  'AAATTCCAGGTCCAAA': 'CL:0000584',
#  'AAATTTACCGAAATCC': 'CL:0009010',
#  'AAATTTGCGGGTGTGG': 'CL:0000584',
#  'AACAACTGGTAGTTGC': 'CL:0000584',
#  'AACAATACATTGTCGA': 'CL:0000186',
#  'AACAATTACTCTACGC': 'CL:0009010',
#  'AACACACGCTCGCCGC': 'CL:0009010',
#  'AACACGACTGTACTGA': 'CL:0000584',
#  'AACACGAGACGCGGCC': 'CL:0000186',
#  'AACAGCTGTGTGGCAA': 'CL:0000584',
#  'AACAGGAAATCGAATA': 'CL:0009010',
#  'AACAGGATGGGCCGCG': 'CL:0000584',
#  'AACAGGTAGTATGGAT': 'CL:0000584',
#  'AACATAGCGTGTATCG': 'CL:0000584',
#  'AACATATCAACTGGTG': 'CL:0009010',
#  'AACATCGATACGTCTA': 'CL:0000584',
#  'AACATTGTGACTCGAG': 'CL:0000186',
#  'AACCAAGACTTCTCTG': 'CL:0000186',
#  'AACCAGTATCACTCTT': 'CL:0000584',
#  'AACCCAGAGACGGAGA': 'CL:0000584',
#  'AACCCATCCCATGATC': 'CL:0000584',
#  'AACCCGACAACCCGTG': 'CL:0000584',
#  'AACCCGCTGTATTCCA': 'CL:0000584',
#  'AACCCTACTGTCAATA': 'CL:0000034',
#  'AACCGAGCTTGGTCAT': 'CL:0000057',
#  'AACCGCTAAGGGATGC': 'CL:0000034',
#  'AACCTAAAGCCGTCCG': 'CL:0000844',
#  'AACCTCGCTTTAGCCC': 'CL:0000584',
#  'AACCTGTCACGGAATT': 'CL:0000584',
#  'AACCTTTAAATACGGT': 'CL:0000584',
#  'AACCTTTACGACGTCT': 'CL:0000034',
#  'AACGACCTCCTAGCCG': 'CL:0000584',
#  'AACGATAATGCCGTAG': 'CL:0000584',
#  'AACGATAGAAGGGCCG': 'CL:0000584',
#  'AACGATATGTCAACTG': 'CL:0000034',
#  'AACGCGACCTTGGGCG': 'CL:0009010',
#  'AACGCGGTCTCCAGCC': 'CL:0000034',
#  'AACGCTGTTGCTGAAA': 'CL:0000584',
#  'AACGGACGTACGTATA': 'CL:0000584',
#  'AACGGCCATCTCCGGT': 'CL:0000186',
#  'AACGTACTGTGGGTAC': 'CL:0000584',
#  'AACGTCAGACTAGTGG': 'CL:0000584',
#  'AACGTCATCCGGCTTG': 'CL:0000584',
#  'AACGTCGCTGCACTTC': 'CL:0009010',
#  'AACGTGCGAAAGTCTC': 'CL:0000584',
#  'AACTACCCGTTTGTCA': 'CL:0000584',
#  'AACTAGCGTATCGCAC': 'CL:0000584',
#  'AACTAGGCTTGGGTGT': 'CL:0000186',
#  'AACTCAAGTTAATTGC': 'CL:0009010',
#  'AACTCCAGAGCGTGTT': 'CL:0000584',
#  'AACTCCTAATCCCATG': 'CL:0000584',
#  'AACTCTCAATAGAGCG': 'CL:0000584',
#  'AACTCTCAGTGTGCTC': 'CL:0000186',
#  'AACTGAGGTCAGCGTC': 'CL:0000584',
#  'AACTGAGTTATACTGA': 'CL:0009010',
#  'AACTGATATTAGGCCT': 'CL:0009010',
#  'AACTGGGTCCCGACGT': 'CL:0000034',
#  'AACTGGGTTCGAGCCG': 'CL:0000584',
#  'AACTGGTGTGGGCCTT': 'CL:0000584',
#  'AACTTCTGCGTCTATC': 'CL:0000584',
#  'AACTTGCCCGTATGCA': 'CL:0000584',
#  'AACTTTAGCTGCTGAG': 'CL:0000584',
#  'AAGAAGGATCAGTTAG': 'CL:0000584',
#  'AAGACATACGTGGTTT': 'CL:0000584',
#  'AAGACCCAACTGAACA': 'CL:0009010',
#  'AAGACTGCAAGCTACT': 'CL:0000584',
#  'AAGAGATGAATCGGTA': 'CL:0000584',
#  'AAGAGCTCTTTATCGG': 'CL:0000584',
#  'AAGAGGATGTACGCGA': 'CL:0000584',
#  'AAGATGGCACCGGACC': 'CL:0000584',
#  'AAGATTGGCGGAACGT': 'CL:0000584',
#  'AAGCACCCTGCGTATC': 'CL:0000584',
#  'AAGCATACTCTCCTGA': 'CL:0000584',
#  'AAGCCACTTGCAGGTA': 'CL:0009010',
#  'AAGCCGAAGCGGTTTA': 'CL:0000584',
#  'AAGCCGGAGAGCAGGA': 'CL:0009010',
#  'AAGCGGCGTCATGGGT': 'CL:0000584',
#  'AAGCGTCCCTCATCGA': 'CL:0009010',
#  'AAGCTAGATCGAGTAA': 'CL:0000584',
#  'AAGCTCGTGCCAAGTC': 'CL:0000584',
#  'AAGCTCTTTCATGGTG': 'CL:0000584',
#  'AAGGAGAACTTATAAG': 'CL:0009010',
#  'AAGGAGCGGTTGGTGC': 'CL:0000034',
#  'AAGGATCGATCGCTTG': 'CL:0000584',
#  'AAGGATGAGGGACCTC': 'CL:0000186',
#  'AAGGCAGGCTGTCTCC': 'CL:0000584',
#  'AAGGCGCGTAAAGCTT': 'CL:0000584',
#  'AAGGCTGTGCTCATCG': 'CL:0000034',
#  'AAGGGACAGATTCTGT': 'CL:0000584',
#  'AAGGTATCCTAATATA': 'CL:0000034',
#  'AAGGTGATAAACCAGC': 'CL:0000057',
#  'AAGTAGAAGACCGGGT': 'CL:0009010',
#  'AAGTAGTGACGCGAGG': 'CL:0000584',
#  'AAGTCAATTGTCGTCA': 'CL:0000584',
#  'AAGTGACGACCGAATT': 'CL:0000584',
#  'AAGTGAGTCGGGTTTA': 'CL:0000584',
#  'AAGTGCCTTGACTGTA': 'CL:0000584',
#  'AAGTGCGTTAGAATCT': 'CL:0000584',
#  'AAGTGCTTCTCTATTG': 'CL:0000584',
#  'AAGTGTTTGGAGACGG': 'CL:0000034',
#  'AAGTTCACTCCAAGCT': 'CL:0000584',
#  'AAGTTCAGTCTGCGTA': 'CL:0000584',
#  'AAGTTGTGATGTTATA': 'CL:0000584',
#  'AAGTTTACTAATGGCA': 'CL:0000584',
#  'AAGTTTATGGGCCCAA': 'CL:0000584',
#  'AATAACAACGCTCGGC': 'CL:0000584',
#  'AATAACACTAGAACAA': 'CL:0000584',
#  'AATAAGTCCTCGAGAC': 'CL:0000584',
#  'AATACAATGTTTCAGG': 'CL:0000584',
#  'AATACCGGAGGGCTGT': 'CL:0000584',
#  'AATAGAATCTGTTTCA': 'CL:0000034',
#  'AATATCAAGGTCGGAT': 'CL:0000584',
#  'AATATCGAATCAATGC': 'CL:0000584',
#  'AATATCGAGGGTTCTC': 'CL:0009010',
#  'AATCAGGTTTCATTTA': 'CL:0009010',
#  'AATCATGTAAAGACTC': 'CL:0009010',
#  'AATCCAAGGGCCTGAG': 'CL:0000584',
#  'AATCCCGCTCAGAGCC': 'CL:0009010',
#  'AATCGAGGTCTCAAGG': 'CL:0000584',
#  'AATCGCCTCAGCGCCA': 'CL:0000584',
#  'AATCGCGCAGAGGACT': 'CL:0000584',
#  'AATCTAGGTTTACTTG': 'CL:0000584',
#  'AATCTATGCCGGAGCC': 'CL:0000584',
#  'AATCTGCGTTGGGACG': 'CL:0000034',
#  'AATCTGGCTTTCTAGT': 'CL:0009010',
#  'AATGACAGCAATGTCT': 'CL:0009010',
#  'AATGACGTAGGATGTC': 'CL:0000186',
#  'AATGACTGTCAGCCGG': 'CL:0000034',
#  'AATGATGATACGCTAT': 'CL:0000034',
#  'AATGATGCGACTCCTG': 'CL:0000186',
#  'AATGCAACCGGGTACC': 'CL:0000034',
#  'AATGCACCAAGCAATG': 'CL:0000584',
#  'AATGGTTCTCACAAGC': 'CL:0009010',
#  'AATGTGCCCGAGGTGT': 'CL:0000584',
#  'AATGTGCTAATCTGAG': 'CL:0000584',
#  'AATGTTAAGACCCTGA': 'CL:0000584',
#  'AATGTTGTCGTGAGAC': 'CL:0000584',
#  'AATTAAAGGTCGGCGT': 'CL:0000034',
#  'AATTAACGGATTTCCA': 'CL:0009010',
#  'AATTAGCGCTGCAGCG': 'CL:0000584',
#  'AATTATACCCAGCAAG': 'CL:0000584',
#  'AATTCATAAGGGATCT': 'CL:0000584',
#  'AATTCCAAGCATGTAC': 'CL:0000584',
#  'AATTCTAGAGTTAGGC': 'CL:0000186',
#  'AATTGAACGCTCTGGT': 'CL:0000584',
#  'AATTGTGGTTGCCAAA': 'CL:0000584',
#  'AATTTGGGACATAGTA': 'CL:0000584',
#  'AATTTGGTTCCAAAGA': 'CL:0000584',
#  'ACAAACCATGCGTCCT': 'CL:0009010',
#  'ACAAACCGACAAGGCG': 'CL:0000844',
#  'ACAAACTCCATCAGAG': 'CL:0000584',
#  'ACAAAGCATGACCTAG': 'CL:0000584',
#  'ACAAATCGCACCGAAT': 'CL:0000186',
#  'ACAAATGGTAGTGTTT': 'CL:0000034',
#  'ACAAATTCAGATCTGA': 'CL:0000584',
#  'ACAACAGCATGAGCTA': 'CL:0000034',
#  'ACAACGGTCCCTGCGA': 'CL:0000584',
#  'ACAAGCAGTGCCTAGC': 'CL:0000584',
#  'ACAAGGAAATCCGCCC': 'CL:0000584',
#  'ACAAGGACAAGAGGTT': 'CL:0000584',
#  'ACAAGGGCAGGCTCTG': 'CL:0000186',
#  'ACAATCCATTTAAACC': 'CL:0000186',
#  'ACAATCGATCTTTATA': 'CL:0000584',
#  'ACAATGAATACGGAGA': 'CL:0000584',
#  'ACAATGATTCTTCTAC': 'CL:0009010',
#  'ACAATTGTGTCTCTTT': 'CL:0000584',
#  'ACAATTTGAGCAGTGG': 'CL:0000034',
#  'ACACAAAGACGGGTGG': 'CL:0000584',
#  'ACACAAATATTCCTAG': 'CL:0009010',
#  'ACACACCAGGACCAGT': 'CL:0000057',
#  'ACACACTTTCTACACG': 'CL:0009010',
#  'ACACATGATCAAATCT': 'CL:0000584',
#  'ACACATTTCCGTAGAC': 'CL:0000584',
#  'ACACCACATAATTAGC': 'CL:0000584',
#  'ACACCCAGCATGCAGC': 'CL:0000584',
#  'ACACCCGAGAAATCCG': 'CL:0000584',
#  'ACACCGGTCTGACCGC': 'CL:0000584',
#  'ACACCTTAAGTAGGGC': 'CL:0000584',
#  'ACACCTTACTACTTGC': 'CL:0009010',
#  'ACACTGGGACAGTCGT': 'CL:0000584',
#  'ACAGAACTGAGAACAA': 'CL:0009010',
#  'ACAGCGACATTCTCAT': 'CL:0000584',
#  'ACAGGCTTGCCCGACT': 'CL:0000584',
#  'ACAGGTGGAGGTGAGG': 'CL:0000186',
#  'ACAGTATACCGTGGGA': 'CL:0000584',
#  'ACATAATAAGGCGGTG': 'CL:0000034',
#  'ACATACAATCAAGCGG': 'CL:0009010',
#  'ACATCCCGGCCATACG': 'CL:0000186',
#  'ACATCCTGGTAACTGT': 'CL:0000584',
#  'ACATCGATCGTTTACC': 'CL:0000584',
#  'ACATCGGTCAGCCGCG': 'CL:0000584',
#  'ACATCGTATGCAATGG': 'CL:0000584',
#  'ACATCGTTAACCTAGT': 'CL:0000584',
#  'ACATCTCAACGCGTAA': 'CL:0000584',
#  'ACATTAGTTTATATCC': 'CL:0000034',
#  'ACATTTGAAACCTAAC': 'CL:0009010',
#  'ACCAAACACCCAGCGA': 'CL:0000584',
#  'ACCAAACTAGAAATCC': 'CL:0009010',
#  'ACCAAGAACGCGTGTC': 'CL:0000584',
#  'ACCAAGTCATCGGCAG': 'CL:0000584',
#  'ACCAATATGCAAGTTA': 'CL:0000584',
#  'ACCACAAGTTTCTATC': 'CL:0000584',
#  'ACCACACGGTTGATGG': 'CL:0000584',
#  'ACCACCAATGTAACAA': 'CL:0000584',
#  'ACCACCCTCTCTTCTA': 'CL:0000584',
#  'ACCACGTGCAGCTATA': 'CL:0000034',
#  'ACCAGCCCGGTCTTTG': 'CL:0000584',
#  'ACCAGGAGTGTGATCT': 'CL:0000584',
#  'ACCAGTGCCCGGTCAA': 'CL:0000584',
#  'ACCAGTGCGGGAGACG': 'CL:0000584',
#  'ACCATATCCGCAATAA': 'CL:0000584',
#  'ACCATCGTATATGGTA': 'CL:0000584',
#  'ACCCAACGCCCGTGGC': 'CL:0000057',
#  'ACCCATCTTGAGGGTA': 'CL:0000584',
#  'ACCCATTTGTCCCTCT': 'CL:0000584',
#  'ACCCGATTGGTTCCGA': 'CL:0000584',
#  'ACCCGGAAACTCCCAG': 'CL:0000584',
#  'ACCCGGAGCACCACAA': 'CL:0000584',
#  'ACCCGGATGACGCATC': 'CL:0000034',
#  'ACCCGGTTACACTTCC': 'CL:0000034',
#  'ACCCTATGCCATATCG': 'CL:0000186',
#  'ACCCTCCCGTCAGGGC': 'CL:0000584',
#  'ACCCTCCCTTGCTATT': 'CL:0000034',
#  'ACCCTGGTAACGCCCT': 'CL:0000584',
#  'ACCCTTCATCTGCGAA': 'CL:0000186',
#  'ACCCTTGCCTGGGTCG': 'CL:0009010',
#  'ACCCTTTAGTTCTCCA': 'CL:0000584',
#  'ACCGAAAGGGCCCTGC': 'CL:0000584',
#  'ACCGACACATCTCCCA': 'CL:0000584',
#  'ACCGATAGGCATAACC': 'CL:0009010',
#  'ACCGATGGTAGCATCG': 'CL:0000584',
#  'ACCGCAATAACTGCCT': 'CL:0000034',
#  'ACCGCGGTGGAAGTCG': 'CL:0000584',
#  'ACCGCTAGTCATTGGT': 'CL:0000584',
#  'ACCGGGCCTTTGTTGA': 'CL:0000584',
#  'ACCGGTCAGGTACACC': 'CL:0000584',
#  'ACCGGTCTGAGTACGG': 'CL:0000584',
#  'ACCGTGACCACGTGGG': 'CL:0000584',
#  'ACCGTTCCCGCTCTGA': 'CL:0000584',
#  'ACCTAATCGACTTCCT': 'CL:0000584',
#  'ACCTACAGTATGTGGT': 'CL:0000584',
#  'ACCTCCGCCCTCGCTG': 'CL:0000584',
#  'ACCTCCGTTATTCACC': 'CL:0000186',
#  'ACCTTTCCTTTAGAAG': 'CL:0000584',
#  'ACGAAATGGGCGGCAC': 'CL:0009010',
#  'ACGACCCATGAGTTGC': 'CL:0000584',
#  'ACGACTCTAGGGCCGA': 'CL:0000584',
#  'ACGACTGGTCATACTC': 'CL:0000584',
#  'ACGAGGATACCACTCT': 'CL:0009010',
#  'ACGAGGTTTACAACGT': 'CL:0000584',
#  'ACGAGTACGGATGCCC': 'CL:0000186',
#  'ACGATCATACATAGAG': 'CL:0000034',
#  'ACGATCATCTTGTAAA': 'CL:0000034',
#  'ACGATGCATATGTTAT': 'CL:0000584',
#  'ACGCAAACTAATAGAT': 'CL:0000584',
#  'ACGCAATCACTACAGC': 'CL:0000584',
#  'ACGCATACGTTTACTA': 'CL:0000584',
#  'ACGCATTCGTGAGTAC': 'CL:0000584',
#  'ACGCCACTCGAAACAG': 'CL:0009010',
#  'ACGCCAGATGATTTCT': 'CL:0009010',
#  'ACGCCAGTGCGTTTGC': 'CL:0000584',
#  'ACGCCCAGCTGTCGAT': 'CL:0009010',
#  'ACGCCGCTAGACGACC': 'CL:0000584',
#  'ACGCGAAGTCAGACGA': 'CL:0000186',
#  'ACGCGGGCCAAGGACA': 'CL:0000584',
#  'ACGCTAGTGATACACT': 'CL:0000584',
#  'ACGCTTAGTGTCTCTC': 'CL:0000584',
#  'ACGGAACACGAGTGCC': 'CL:0000584',
#  'ACGGAATTTAGCAAAT': 'CL:0000584',
#  'ACGGACTCTCAAAGCG': 'CL:0000584',
#  'ACGGAGCGCAAATTAC': 'CL:0000584',
#  'ACGGATGGTGCGGATA': 'CL:0000584',
#  'ACGGCACTTGCTTGGG': 'CL:0000186',
#  'ACGGCCAACATGGACT': 'CL:0000186',
#  'ACGGCGACGATGGGAA': 'CL:0000186',
#  'ACGGGAGTGTCGGCCC': 'CL:0000584',
#  'ACGGGCGTATGCGACA': 'CL:0009010',
#  'ACGGTACAGTTCAATG': 'CL:0009010',
#  'ACGTACAGATTTCTCT': 'CL:0000844',
#  'ACGTAGATTGCTGATG': 'CL:0000034',
#  'ACGTATTACTCCGATC': 'CL:0000034',
#  'ACGTCCTAAACGAGAT': 'CL:0000584',
#  'ACGTGCGCCTCGTGCA': 'CL:0000584',
#  'ACGTGGTCGAATGTGC': 'CL:0000788',
#  'ACGTTAATGTCGAAGA': 'CL:0000034',
#  'ACGTTAGATTTGCCCG': 'CL:0000584',
#  'ACGTTCACTATGCCGC': 'CL:0000584',
#  'ACGTTCGCAATCAATT': 'CL:0000584',
#  'ACGTTCGTTCAGGAAA': 'CL:0000584',
#  'ACGTTGTCGTTGAAAG': 'CL:0000584',
#  'ACGTTTAGTTGTGATC': 'CL:0000186',
#  'ACTAATACGTCAGGCG': 'CL:0000584',
#  'ACTACAAAGAGAGGTG': 'CL:0000584',
#  'ACTACATCCCGACAAG': 'CL:0000584',
#  'ACTACCAGCTCTCTGG': 'CL:0000584',
#  'ACTACGCGTTAGAATT': 'CL:0000584',
#  'ACTAGTTGCGATCGTC': 'CL:0009010',
#  'ACTATATGCTGTGTTC': 'CL:0009010',
#  'ACTATCCAGGGCATGG': 'CL:0000584',
#  'ACTATTCGTCCGTGGT': 'CL:0009010',
#  'ACTATTTCCGGGCCCA': 'CL:0000584',
#  'ACTCAAGTGCAAGGCT': 'CL:0000584',
#  'ACTCAATAAAGGCACG': 'CL:0000034',
#  'ACTCAGACCTGCTTCT': 'CL:0000584',
#  'ACTCCAATATCATCAT': 'CL:0009010',
#  'ACTCCCGAATTCGTTT': 'CL:0000584',
#  'ACTCCCTAATGCTAAA': 'CL:0000034',
#  'ACTCCCTAGAATAGTA': 'CL:0000584',
#  'ACTCGCCGTTCGATAA': 'CL:0009010',
#  'ACTCGCGATCTGACGC': 'CL:0000584',
#  'ACTCGTAACCCGTCCT': 'CL:0009010',
#  'ACTCGTCAGTAATCCC': 'CL:0000584',
#  'ACTCTCTGACTTAGGT': 'CL:0000186',
#  'ACTCTGACCTAATAGA': 'CL:0000584',
#  'ACTCTTCAGCTCCCGC': 'CL:0000584',
#  'ACTCTTGTATAGTAAC': 'CL:0000584',
#  'ACTGAAACGCCGTTAG': 'CL:0009010',
#  'ACTGAATGGCGAAAGT': 'CL:0000034',
#  'ACTGATTTAGTGATTC': 'CL:0000584',
#  'ACTGCCGTCGTAACTC': 'CL:0009010',
#  'ACTGCGGACACACCGT': 'CL:0000584',
#  'ACTGGGATGCCAGTGC': 'CL:0000584',
#  'ACTGTACGATACACAT': 'CL:0000034',
#  'ACTGTAGCACTTTGGA': 'CL:0000584',
#  'ACTGTATACGCGAGCA': 'CL:0000584',
#  'ACTGTCCAGGATTATA': 'CL:0000034',
#  'ACTGTCTTCTTTAGAA': 'CL:0000584',
#  'ACTGTGCTAGTAGATC': 'CL:0000584',
#  'ACTGTTTAGTGTAGGC': 'CL:0009010',
#  'ACTTACCGGGCGCGCA': 'CL:0000584',
#  'ACTTACGCATCCACGC': 'CL:0000584',
#  'ACTTATACTTACCCGG': 'CL:0000584',
#  'ACTTATTAGGATCGGT': 'CL:0000034',
#  'ACTTATTTATGTGCCA': 'CL:0000034',
#  'ACTTCAGGCTGATCCC': 'CL:0000584',
#  'ACTTCGCCATACGCAC': 'CL:0000584',
#  'ACTTCGCTAGCGAGTG': 'CL:0000584',
#  'ACTTGACTCCCTCTTT': 'CL:0000584',
#  'ACTTGCCATATTGTAC': 'CL:0000584',
#  'ACTTGGGACCCGGTGG': 'CL:0000034',
#  'ACTTGGGCTTTCGCCA': 'CL:0009010',
#  'ACTTGTGGATGGAACG': 'CL:0009010',
#  'ACTTGTTACCGGATCA': 'CL:0000584',
#  'ACTTTACCCTCATGAA': 'CL:0000584',
#  'ACTTTCCTATAGCTTC': 'CL:0000584',
#  'ACTTTGGTCGTGCTCC': 'CL:0000584',
#  'AGAACTGTACTTTGTA': 'CL:0009010',
#  'AGAAGAGCGCCGTTCC': 'CL:0000584',
#  'AGAAGGTACACTTCAC': 'CL:0000584',
#  'AGAAGGTTGCCGAATT': 'CL:0009010',
#  'AGAAGGTTGTAGGTCG': 'CL:0000584',
#  'AGAAGTGATTCGTGAT': 'CL:0000584',
#  'AGAATGCGGGTTCGGA': 'CL:0009010',
#  'AGAATTATGGATTCGA': 'CL:0000584',
#  'AGAATTGTTTGACATA': 'CL:0000584',
#  'AGACATAGATCCTTCC': 'CL:0000584',
#  'AGACCCACCGCTGATC': 'CL:0000034',
#  'AGACCCGCCCTCCTCG': 'CL:0000034',
#  'AGACCGCTCCGCGGTT': 'CL:0000584',
#  'AGACGAAGTGCCGGTC': 'CL:0009010',
#  'AGACGCCCACTTCGCC': 'CL:0009010',
#  'AGACGGGATTGGTATA': 'CL:0000844',
#  'AGACGGGCCGATTTAA': 'CL:0000584',
#  'AGACTAGCCTTCCAGA': 'CL:0000584',
#  'AGACTGTTACCGGGTC': 'CL:0000584',
#  'AGAGAAACACCAGAAA': 'CL:0000584',
#  'AGAGAACCGTCTAGGA': 'CL:0000584',
#  'AGAGCGCTTGTAACGG': 'CL:0000584',
#  'AGAGCGGGCTAATCAT': 'CL:0000584',
#  'AGAGCGTACAAGCTCG': 'CL:0009010',
#  'AGAGGCTTCGGAAACC': 'CL:0009010',
#  'AGAGGTATCTCGGTCC': 'CL:0000584',
#  'AGAGTAAACTTCACTA': 'CL:0000186',
#  'AGAGTATAGTGTTACG': 'CL:0000584',
#  'AGAGTTAGAGACCGAT': 'CL:0000584',
#  'AGATAACTTCAGGGCC': 'CL:0000584',
#  'AGATACCAATAGAACC': 'CL:0000584',
#  'AGATACCAGCACTTCA': 'CL:0000584',
#  'AGATACCGGTGTTCAC': 'CL:0000584',
#  'AGATACTCAAGATCGA': 'CL:0000584',
#  'AGATATAATACGACTA': 'CL:0000584',
#  'AGATCGTGCATAAGAT': 'CL:0000584',
#  'AGATCTCAGGTGTGAT': 'CL:0000584',
#  'AGATGACTCGCCCACG': 'CL:0000584',
#  'AGATGAGGGTTGCGAT': 'CL:0000584',
#  'AGATTATAGGACGTTT': 'CL:0000584',
#  'AGATTCACAACCGATA': 'CL:0000584',
#  'AGCAAAGGCCGCTAGT': 'CL:0000584',
#  'AGCAACATATCTTATT': 'CL:0000844',
#  'AGCAACCGAAAGTAAT': 'CL:0000584',
#  'AGCACCAGTACTCACG': 'CL:0000584',
#  'AGCACTACCTCACCAG': 'CL:0009010',
#  'AGCACTTAAGGACGCC': 'CL:0000235',
#  'AGCAGCCAGATGAATA': 'CL:0000186',
#  'AGCAGTCGAAGCATGC': 'CL:0000584',
#  'AGCATATCAATATGCT': 'CL:0009010',
#  'AGCATCATTTCGAAAG': 'CL:0009010',
#  'AGCATCGTCGATAATT': 'CL:0000584',
#  'AGCATTACGAGGCAAG': 'CL:0009010',
#  'AGCCAAGCTTTGTGTC': 'CL:0000186',
#  'AGCCACAGGTTACCCG': 'CL:0009010',
#  'AGCCACTCCCGTGCTT': 'CL:0000034',
#  'AGCCCATACATGTAAG': 'CL:0000584',
#  'AGCCCGCAACAAGCAG': 'CL:0009010',
#  'AGCCCGCACTACAATG': 'CL:0009010',
#  'AGCCCGGTAGCCTGTA': 'CL:0000186',
#  'AGCCCTAAGCGAAGTT': 'CL:0009010',
#  'AGCCCTTCTAATCCGA': 'CL:0000584',
#  'AGCCTAATACCCACGT': 'CL:0009010',
#  'AGCCTTAAAGCGGAAG': 'CL:0000186',
#  'AGCGACAGGAACGGTC': 'CL:0000584',
#  'AGCGACCAACGATATT': 'CL:0000057',
#  'AGCGAGACGTGAAGGC': 'CL:0000584',
#  'AGCGATGCGCCTAATA': 'CL:0000584',
#  'AGCGCGGGTGCCAATG': 'CL:0000584',
#  'AGCGCTAGAGCGATGT': 'CL:0000584',
#  'AGCGCTTATGGGCAAG': 'CL:0000584',
#  'AGCGGACACTTCGTAG': 'CL:0000584',
#  'AGCGGCGGTTAGCGGT': 'CL:0009010',
#  'AGCGGTTGAGATGTAC': 'CL:0009010',
#  'AGCGGTTGCCGCTCTG': 'CL:0000584',
#  'AGCGTGGTATTCTACT': 'CL:0000584',
#  'AGCGTTCCGATTTAAA': 'CL:0000584',
#  'AGCTAACAAGCAATGT': 'CL:0000584',
#  'AGCTAAGCTCCGTCCG': 'CL:0009010',
#  'AGCTAAGTACGCAGGC': 'CL:0009010',
#  'AGCTAGAAGCAGAAGT': 'CL:0000584',
#  'AGCTATTTAATCCAAC': 'CL:0009010',
#  'AGCTCCTTCGCACATC': 'CL:0000186',
#  'AGCTCGTTGATGGAAA': 'CL:0000584',
#  'AGCTCTAGACGTTCCA': 'CL:0000186',
#  'AGCTCTTCCCAGTGCA': 'CL:0000584',
#  'AGCTCTTCGTAACCTT': 'CL:0000584',
#  'AGCTCTTTACTCAGTT': 'CL:0000584',
#  'AGCTGAAGTAAACCAA': 'CL:0000584',
#  'AGCTGTAACCTCAATC': 'CL:0000584',
#  'AGCTTATAGAGACCTG': 'CL:0000584',
#  'AGCTTCAATACTTTGA': 'CL:0000844',
#  'AGCTTCTTCTCGAGCA': 'CL:0000584',
#  'AGGAACGAACGACTTC': 'CL:0000584',
#  'AGGAAGCTGTCCGCCG': 'CL:0000584',
#  'AGGACAGTCGAATCCC': 'CL:0000034',
#  'AGGACATCGCACGTCG': 'CL:0009010',
#  'AGGACATCGGCACACT': 'CL:0000584',
#  'AGGACGACCCATTAGA': 'CL:0000584',
#  'AGGACGCTCGATGTTG': 'CL:0009010',
#  'AGGAGACATCCACAGT': 'CL:0000584',
#  'AGGAGAGTCTGGCTAC': 'CL:0000584',
#  'AGGAGGCCTTCGCGCG': 'CL:0000584',
#  'AGGATAAAGTCGGGAT': 'CL:0000186',
#  'AGGATATAGGGATTTA': 'CL:0000584',
#  'AGGATATCCGACTGCA': 'CL:0000584',
#  'AGGATCACGCGATCTG': 'CL:0000584',
#  'AGGCAGGGAGCGTACT': 'CL:0009010',
#  'AGGCATTGTCGTAGGG': 'CL:0000584',
#  'AGGCCACATTGGTTAC': 'CL:0000584',
#  'AGGCCACCCGTTATGA': 'CL:0000584',
#  'AGGCCCATTGTACAGG': 'CL:0000584',
#  'AGGCCCTAGAACGCCA': 'CL:0009010',
#  'AGGCCTATCATACCAA': 'CL:0000584',
#  'AGGCCTGAGAATCTCG': 'CL:0000584',
#  'AGGCGATAACTGGCGT': 'CL:0000584',
#  'AGGCGTCTATGGACGG': 'CL:0000584',
#  'AGGCTTAAGTTGCACA': 'CL:0000186',
#  'AGGCTTGCTAGACACC': 'CL:0009010',
#  'AGGGAAACGAGGTACT': 'CL:0000584',
#  'AGGGACAGCACGGCGG': 'CL:0009010',
#  'AGGGACCGGCTGCGTT': 'CL:0000584',
#  'AGGGAGACATACTTCG': 'CL:0000584',
#  'AGGGCAGCGGCGTGGT': 'CL:0000584',
#  'AGGGCCCTAATGTTCT': 'CL:0000584',
#  'AGGGCGTGATCGGCTA': 'CL:0000584',
#  'AGGGCTGCAGTTACAG': 'CL:0000584',
#  'AGGGTCAGAGCACTCG': 'CL:0009010',
#  'AGGGTCAGTAACCCTA': 'CL:0000584',
#  'AGGGTCGATGCGAACT': 'CL:0000034',
#  'AGGGTCTGGACGCAGT': 'CL:0000584',
#  'AGGGTGCCGTTCTTTA': 'CL:0000584',
#  'AGGGTGCTCTCGAGGG': 'CL:0000584',
#  'AGGGTTCAGACGGTCC': 'CL:0000584',
#  'AGGGTTCCCTTTGGTT': 'CL:0000034',
#  'AGGGTTTAGTTCGGGA': 'CL:0000584',
#  'AGGTAACCTCCTATTC': 'CL:0000584',
#  'AGGTAGATCGAGATAT': 'CL:0000584',
#  'AGGTATAATTGATAGT': 'CL:0000584',
#  'AGGTATGCGGACATTA': 'CL:0000584',
#  'AGGTCGCCTCCCAACA': 'CL:0000584',
#  'AGGTCGCGGAGTTACT': 'CL:0000584',
#  'AGGTGCACGTCCACAT': 'CL:0000584',
#  'AGGTGGTGACCTTCGC': 'CL:0009010',
#  'AGGTGTTGCCGACCAC': 'CL:0000584',
#  'AGGTTACACCATGCCG': 'CL:0009010',
#  'AGGTTGAGGCACGCTT': 'CL:0000584',
#  'AGGTTTCACACACCTT': 'CL:0000034',
#  'AGTAACGTTCATCCTG': 'CL:0000584',
#  'AGTAACTATAGCAGCC': 'CL:0000584',
#  'AGTAAGGGACAGAATC': 'CL:0009010',
#  'AGTAATCTAAGGGTGG': 'CL:0000584',
#  'AGTAATGTCTTGCCGC': 'CL:0000584',
#  'AGTACATCATTTATCA': 'CL:0000584',
#  'AGTACGGGCACCTGGC': 'CL:0000034',
#  'AGTACGTGGCCTGTCT': 'CL:0000584',
#  'AGTACTCTTATGCCCA': 'CL:0000584',
#  'AGTAGCGTGAACGAAC': 'CL:0000584',
#  'AGTAGCTAGACGCCGA': 'CL:0000584',
#  'AGTAGGAAGGAAGTTG': 'CL:0000584',
#  'AGTATACACAGCGACA': 'CL:0000584',
#  'AGTATGCTGGAGACCA': 'CL:0000584',
#  'AGTATTTGGCACGACC': 'CL:0000584',
#  'AGTCAAATGATGTGAT': 'CL:0000584',
#  'AGTCAACACCACCATC': 'CL:0000584',
#  'AGTCAAGATGACACTT': 'CL:0000034',
#  'AGTCACTAGCTCTCGA': 'CL:0000584',
#  'AGTCAGCCACCGCCTG': 'CL:0000584',
#  'AGTCCATTGGCTGATG': 'CL:0000584',
#  'AGTCCCGCCTTTAATT': 'CL:0000584',
#  'AGTCCCTCGCAGAAAG': 'CL:0009010',
#  'AGTCGACGGTCTCAAG': 'CL:0000584',
#  'AGTCGGCCCAAACGAC': 'CL:0000584',
#  'AGTCGGCTCAACTTTA': 'CL:0000584',
#  'AGTCGGTTGCGTGAGA': 'CL:0009010',
#  'AGTCGTATAAAGCAGA': 'CL:0000584',
#  'AGTCGTCGACCACCAA': 'CL:0000584',
#  'AGTCGTGGGCATTACG': 'CL:0000584',
#  'AGTCTAAAGTATACTC': 'CL:0000584',
#  'AGTCTCACAAGACTAC': 'CL:0000584',
#  'AGTCTGGACATCCTTG': 'CL:0000584',
#  'AGTCTTCTCCTCAAAT': 'CL:0000584',
#  'AGTGAACAAACTTCTC': 'CL:0000584',
#  'AGTGACCTACTTTACG': 'CL:0000034',
#  'AGTGAGACTTCCAGTA': 'CL:0000584',
#  'AGTGAGCCTCGCCGCC': 'CL:0000584',
#  'AGTGAGGGTTTCTGAC': 'CL:0000584',
#  'AGTGAGTCGAATTAAC': 'CL:0009010',
#  'AGTGATAACCTGCGCG': 'CL:0000584',
#  'AGTGATATGAGTAGTT': 'CL:0000584',
#  'AGTGATTCAAGCAGGA': 'CL:0000584',
#  'AGTGCACGCTTAAGAA': 'CL:0000584',
#  'AGTGCGTAGCTCGTAA': 'CL:0000584',
#  'AGTGCTAAACACAGCA': 'CL:0000584',
#  'AGTGCTTGCACGAATA': 'CL:0000584',
#  'AGTGGCCCGCAAATGG': 'CL:0009010',
#  'AGTGGCGGCAATTTGA': 'CL:0009010',
#  'AGTGGCGTCTGAAGGT': 'CL:0000584',
#  'AGTGTATTGCGCATTG': 'CL:0009010',
#  'AGTGTGGTCTATTGTG': 'CL:0000584',
#  'AGTTAAACACTTGCGA': 'CL:0009010',
#  'AGTTAAGCGGTCCCGG': 'CL:0009010',
#  'AGTTAAGTCAACCGCT': 'CL:0009010',
#  'AGTTACTCTATCGTGG': 'CL:0000034',
#  'AGTTATTGAAAGGTAA': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000160',
#  'AGTTCCTATTTATGTT': 'CL:0000584',
#  'AGTTGACGGTCCTTGC': 'CL:0000584',
#  'AGTTGCTGACTGATAT': 'CL:0000584',
#  'AGTTGGCAAGGCTAGA': 'CL:0009010',
#  'AGTTTATGTAAAGACA': 'CL:0000584',
#  'AGTTTCGCAGGTCGGA': 'CL:0009010',
#  'AGTTTGCACCTGCCTC': 'CL:0000584',
#  'AGTTTGGCACGGGTTG': 'CL:0000034',
#  'AGTTTGGCCAGACCTA': 'CL:0009010',
#  'ATAAACGGACCCGTAA': 'CL:0000034',
#  'ATAAAGGCTCGGTCGT': 'CL:0000034',
#  'ATAAAGGTCAAGTACG': 'CL:0000584',
#  'ATAAATATTAGCAGCT': 'CL:0000584',
#  'ATAACGCCGGAGGGTC': 'CL:0000584',
#  'ATAACGGAGTCCAACG': 'CL:0000584',
#  'ATAACGTTACCTCCAC': 'CL:0000584',
#  'ATAAGGTGGAGAACAT': 'CL:0000584',
#  'ATAAGTACCCGATTGT': 'CL:0000584',
#  'ATAAGTAGGATTCAGA': 'CL:0000186',
#  'ATAAGTAGGGCGACTC': 'CL:0000584',
#  'ATAAGTTACCGCGACG': 'CL:0000584',
#  'ATAATAGCTGTTGAAT': 'CL:0000034',
#  'ATAATAGTGTAGGGAC': 'CL:0009010',
#  'ATAATCTTGGAGAACC': 'CL:0000584',
#  'ATAATTAGCTAAGTAG': 'CL:0000584',
#  'ATACAGGCCCTCCAAT': 'CL:0009010',
#  'ATACCACGGGCAACTT': 'CL:0000584',
#  'ATACCAGCAAATTGCT': 'CL:0000584',
#  'ATACCAGGTGAGCGAT': 'CL:0000584',
#  'ATACCGTCATCCATAA': 'CL:0009010',
#  'ATACCTAACCAAGAAA': 'CL:0000034',
#  'ATACGAAGGCTTTCCA': 'CL:0000584',
#  'ATACGAGGTTTGTAAG': 'CL:0009010',
#  'ATACGCCGGCGAAACC': 'CL:0000034',
#  'ATACGGAACGTCGTTT': 'CL:0000584',
#  'ATACGTACTTAGCCAC': 'CL:0000584',
#  'ATACGTCCACTCCTGT': 'CL:0000584',
#  'ATACGTTATGCACGGA': 'CL:0000584',
#  'ATACTACCCGTACCAC': 'CL:0000584',
#  'ATACTGCCTTACACCG': 'CL:0000584',
#  'ATAGACAACGGGACCT': 'CL:0000584',
#  'ATAGACGAAGAGAAAG': 'CL:0000584',
#  'ATAGAGTACTGGGACA': 'CL:0000584',
#  'ATAGAGTTATCAACTT': 'CL:0000584',
#  'ATAGATTTGCAGTCGG': 'CL:0000584',
#  'ATAGCAACTAGGGAAG': 'CL:0000584',
#  'ATAGCCATAACAGTCA': 'CL:0000584',
#  'ATAGGAATCTAAGCTT': 'CL:0000584',
#  'ATAGGCGGCTATAGAA': 'CL:0000584',
#  'ATAGGCTAGCTTCGCA': 'CL:0009010',
#  'ATAGGGATATCCTTGA': 'CL:0000584',
#  'ATAGGTTGGGCAGATG': 'CL:0000584',
#  'ATAGTGAAGCGTTCTC': 'CL:0000584',
#  'ATAGTTCCACCCACTC': 'CL:0000186',
#  'ATATAAAGCGCTCGTG': 'CL:0000584',
#  'ATATAAATGTAGCTGC': 'CL:0000584',
#  'ATATACGCTCGTGACG': 'CL:0000584',
#  'ATATCAACCTACAGAG': 'CL:0000584',
#  'ATATCGGTAGGGAGAT': 'CL:0009010',
#  'ATATCGTGCCAGACCC': 'CL:0000584',
#  'ATATCGTTCCTCGAAC': 'CL:0000584',
#  'ATATCTCCCTCGTTAA': 'CL:0000584',
#  'ATATCTTAGGGCCTTC': 'CL:0000034',
#  'ATATGGGATAGCAACT': 'CL:0000584',
#  'ATATGTCTAGAGCGTG': 'CL:0009010',
#  'ATATGTCTCCCTAGCC': 'CL:0000057',
#  'ATATTCAGTTAAACCT': 'CL:0000584',
#  'ATATTCCACATAGTGA': 'CL:0000034',
#  'ATATTCCCACAGGTCA': 'CL:0000584',
#  'ATATTGCTGTCAAAGT': 'CL:0009010',
#  'ATATTGGAGAGGCCTT': 'CL:0009010',
#  'ATATTTAACCCTCAAG': 'CL:0000584',
#  'ATCAAACACTGTTCCA': 'CL:0000584',
#  'ATCAAACGAAGGTTTG': 'CL:0009010',
#  'ATCAAAGAGCCGTGGT': 'CL:0000584',
#  'ATCAATCTGGGCTGCA': 'CL:0000034',
#  'ATCACATTAGAATATC': 'CL:0000584',
#  'ATCACGTGCTAATTAA': 'CL:0000186',
#  'ATCACTTCATCCTCGC': 'CL:0000034',
#  'ATCAGACGGCACGCCG': 'CL:0009010',
#  'ATCAGCCTCATGCTGC': 'CL:0000584',
#  'ATCAGCTCGTCCACTA': 'CL:0000584',
#  'ATCAGGTCGCCATTGC': 'CL:0000584',
#  'ATCAGTAGGCAGGGAT': 'CL:0000584',
#  'ATCATAGATCGACGAG': 'CL:0000584',
#  'ATCATCCAATATTTGT': 'CL:0000584',
#  'ATCATCTGCCCAGTGT': 'CL:0000584',
#  'ATCCAACGCAGTCATA': 'CL:0000584',
#  'ATCCAATGGAGGGTCC': 'CL:0000186',
#  'ATCCACATCGACAGAA': 'CL:0000584',
#  'ATCCACGCTAAATGTT': 'CL:0000584',
#  'ATCCAGAGCAACAACC': 'CL:0000034',
#  'ATCCAGGATTCGTGAA': 'CL:0000584',
#  'ATCCCATCCACAGCGC': 'CL:0009010',
#  'ATCCGGACCAGCCTGA': 'CL:0000584',
#  'ATCCTACCTAAGCTCT': 'CL:0000034',
#  'ATCCTGAATCGCTGCG': 'CL:0009010',
#  'ATCCTGCGTGGAATGG': 'CL:0000186',
#  'ATCCTGCTGCAGATAG': 'CL:0000584',
#  'ATCCTTCTGAAAGAAC': 'CL:0009010',
#  'ATCGACCCAATACAGA': 'CL:0000584',
#  'ATCGACTCTTTCCGTT': 'CL:0000034',
#  'ATCGCACGCCGGGAGA': 'CL:0000584',
#  'ATCGCCAGTCAACATT': 'CL:0009010',
#  'ATCGCTGCGTGCAGCA': 'CL:0000584',
#  'ATCGGAGACAGACGGC': 'CL:0000034',
#  'ATCGGCAAGCAGTCCA': 'CL:0000584',
#  'ATCGTTAGCTAGCGGA': 'CL:0000584',
#  'ATCGTTCACTTTCGCC': 'CL:0000584',
#  'ATCTAATATCCTACGG': 'CL:0000186',
#  'ATCTAGCTTGTGAGGG': 'CL:0000584',
#  'ATCTCCCTGCAATCTA': 'CL:0000584',
#  'ATCTGACATGGAAGGA': 'CL:0009010',
#  'ATCTGCACCTCTGCGA': 'CL:0000584',
#  'ATCTGCTGTTATCGCC': 'CL:0000584',
#  'ATCTGGGCTGTTCTTG': 'CL:0000584',
#  'ATCTGGTTAAGACTGT': 'CL:0000584',
#  'ATCTGTAATTGTACCC': 'CL:0000584',
#  'ATCTTATCGCACACCC': 'CL:0000584',
#  'ATCTTGACCTGCAACG': 'CL:0009010',
#  'ATCTTGACTTGTCCAA': 'CL:0000186',
#  'ATCTTTCGTATAACCA': 'CL:0000584',
#  'ATGAAGCCAAGGAGCC': 'CL:0000057',
#  'ATGACGCCGGCTCTAA': 'CL:0000584',
#  'ATGACGCGTTCTATCC': 'CL:0000584',
#  'ATGACTATCAGCTGTG': 'CL:0000584',
#  'ATGACTATGCGACATT': 'CL:0000034',
#  'ATGATCGGGAATAGAC': 'CL:0000584',
#  'ATGATGCAATGGTACA': 'CL:0000584',
#  'ATGCACTACCGCATTG': 'CL:0000584',
#  'ATGCATGATCCAGGAT': 'CL:0000584',
#  'ATGCATTCCGTGATGG': 'CL:0000584',
#  'ATGCCAATCGCTCTGC': 'CL:0000584',
#  'ATGCCATTTGCGACCA': 'CL:0000584',
#  'ATGCCGGTCTTGCATA': 'CL:0000034',
#  'ATGCCGGTTGATGGGA': 'CL:0000584',
#  'ATGCGACAATTGGTCC': 'CL:0000584',
#  'ATGCGACAGTCCCATT': 'CL:0000584',
#  'ATGCGAGTCCCACCAC': 'CL:0009010',
#  'ATGCTCTGGCGCGGTA': 'CL:0000584',
#  'ATGGAACCTTTGCACA': 'CL:0000584',
#  'ATGGAGCAGGCCGTGA': 'CL:0000584',
#  'ATGGATCCGGCGTCCG': 'CL:0000584',
#  'ATGGATTGACCAAACG': 'CL:0000584',
#  'ATGGCAGCATTACGAT': 'CL:0000584',
#  'ATGGCTGGAAATGGCC': 'CL:0000584',
#  'ATGGGAACGGAAGCGG': 'CL:0000584',
#  'ATGGGACCTGCTGAAC': 'CL:0000584',
#  'ATGGGCCTCGGCCTCT': 'CL:0000057',
#  'ATGGTGCTCAAAGCCA': 'CL:0000584',
#  'ATGTAAGGCTGCTCTT': 'CL:0000584',
#  'ATGTACATGCGGTGAG': 'CL:0000584',
#  'ATGTACGATGACGTCG': 'CL:0000584',
#  'ATGTCATAATAAACGA': 'CL:0000584',
#  'ATGTCTTGTTTGACTC': 'CL:0000584',
#  'ATGTGAAAGCCTAATG': 'CL:0009010',
#  'ATGTGCATCCGACGCA': 'CL:0000034',
#  'ATGTGGACATCTTGAT': 'CL:0000584',
#  'ATGTGTAGTTTAGTCA': 'CL:0000584',
#  'ATGTTGTAGTCTGTTT': 'CL:0000584',
#  'ATTAAACATGCGGACC': 'CL:0000584',
#  'ATTAATACTACGCGGG': 'CL:0000034',
#  'ATTAATGAACCAGTCG': 'CL:0000034',
#  'ATTAATTCGGTCACTC': 'CL:0000186',
#  'ATTACATGTCAGTCTT': 'CL:0000584',
#  'ATTACGCGCTGGCAGG': 'CL:0000584',
#  'ATTACTAGCCTCTTGC': 'CL:0000584',
#  'ATTAGATTGATAGCGG': 'CL:0000584',
#  'ATTAGGCGATGCTTTC': 'CL:0000584',
#  'ATTATACTTTGCTCGT': 'CL:0009010',
#  'ATTATAGCTACTTTAC': 'CL:0000584',
#  'ATTATCGGAATGTACG': 'CL:0000584',
#  'ATTATGCCATAGGGAG': 'CL:0000584',
#  'ATTATTATGTCCGTCA': 'CL:0000584',
#  'ATTCAACCATTTAAGG': 'CL:0000584',
#  'ATTCACTGATGTTGGA': 'CL:0000034',
#  'ATTCAGGACCTATTTC': 'CL:0000584',
#  'ATTCAGGATCGCCTCT': 'CL:0000584',
#  'ATTCAGTAGCAGGGTC': 'CL:0009010',
#  'ATTCATATACTGTCCA': 'CL:0000034',
#  'ATTCCTAAGACGTGGA': 'CL:0000584',
#  'ATTCCTCCGCCAGTGC': 'CL:0000584',
#  'ATTCGACGCCGGGCCT': 'CL:0009010',
#  'ATTCGCGCCTTGAGAG': 'CL:0009010',
#  'ATTCGTGCTATCTCTT': 'CL:0000584',
#  'ATTCGTTTATCGTATT': 'CL:0009010',
#  'ATTCTGAGTATGAACT': 'CL:0000584',
#  'ATTGAAGATCTTAGTG': 'CL:0000584',
#  'ATTGACCGGCGATGAC': 'CL:0000584',
#  'ATTGATGAGTCCTAAC': 'CL:0000584',
#  'ATTGCCTTTATGTTTG': 'CL:0009010',
#  'ATTGCGATCAGTAACT': 'CL:0000584',
#  'ATTGCTGCTCCTCCAT': 'CL:0009010',
#  'ATTGGATTACAGCGTA': 'CL:0000584',
#  'ATTGGTTGTGCATTAC': 'CL:0000584',
#  'ATTGTACAACTCGGCT': 'CL:0000034',
#  'ATTGTCGCAATACCTT': 'CL:0000186',
#  'ATTGTCTGTTTCATGT': 'CL:0000584',
#  'ATTGTGACTTCGCTGC': 'CL:0009010',
#  'ATTTAACTCGTATTAC': 'CL:0000584',
#  'ATTTACAGTTTACTGG': 'CL:0000584',
#  'ATTTACTAAGTCCATT': 'CL:0000584',
#  'ATTTATACTGGTAAAG': 'CL:0009010',
#  'ATTTCATTATTTCGCG': 'CL:0000186',
#  'ATTTCCGGGTTCTGCG': 'CL:0000186',
#  'ATTTGCCTAGTTACGA': 'CL:0000584',
#  'ATTTGTCTTGGGAGCT': 'CL:0000584',
#  'ATTTGTTCCAGGGCTC': 'CL:0000584',
#  'CAAACCATAAGCGTAT': 'CL:0000584',
#  'CAAACCCTCCGGCGGG': 'CL:0000584',
#  'CAAACGAGTATCGCAG': 'CL:0000034',
#  'CAAACGGTCGCACTTT': 'CL:0000584',
#  'CAAACGTGGTCTTGCG': 'CL:0000584',
#  'CAAACTCGCGACGCCG': 'CL:0000584',
#  'CAAAGATTATTGGGCC': 'CL:0000584',
#  'CAAAGGTCATCTGAAA': 'CL:0009010',
#  'CAAATCTCTCACAAGG': 'CL:0000584',
#  'CAAATGCGGAGTGTTC': 'CL:0000584',
#  'CAAATGTCCTTCCGTG': 'CL:0000034',
#  'CAAATTGGATTATGCC': 'CL:0000584',
#  'CAAATTGTCAGCAAGC': 'CL:0000186',
#  'CAACAGAATAACGCTA': 'CL:0009010',
#  'CAACAGTGCCAAACGG': 'CL:0000584',
#  'CAACCAGTGGCCTACC': 'CL:0000584',
#  'CAACCTACCGAGCAGT': 'CL:0000584',
#  'CAACCTGAACCTGCCA': 'CL:0000584',
#  'CAACGACCCGTTTACA': 'CL:0000057',
#  'CAACGGTTCTTGATAC': 'CL:0000584',
#  'CAACTATATCGAATGC': 'CL:0000186',
#  'CAACTCCAACGTTTAG': 'CL:0009010',
#  'CAACTCCGTAACTTGC': 'CL:0000584',
#  'CAACTCCTTGATCCCG': 'CL:0000584',
#  'CAACTGCTCATCCGAT': 'CL:0000584',
#  'CAACTTGTAGTGGGCA': 'CL:0000584',
#  'CAAGATATTATAACGT': 'CL:0000034',
#  'CAAGCAACGTCGGAGT': 'CL:0000584',
#  'CAAGCACCAAATGCCT': 'CL:0000584',
#  'CAAGCGGCACATAATT': 'CL:0000584',
#  'CAAGGATCGCATGTTC': 'CL:0000034',
#  'CAAGGTCCTATAGGCT': 'CL:0009010',
#  'CAAGTAAGTGATAGAC': 'CL:0009010',
#  'CAAGTCGTTGAAATCT': 'CL:0000584',
#  'CAAGTGTGGTTGCAAA': 'CL:0000584',
#  'CAATAAACCTTGGCCC': 'CL:0000584',
#  'CAATATGTAGATTTAC': 'CL:0000584',
#  'CAATATTCTTGACCTA': 'CL:0000584',
#  'CAATCCCTATACCAGC': 'CL:0000584',
#  'CAATCCTGCCGTGGAG': 'CL:0009010',
#  'CAATGAGGTTCGACTA': 'CL:0000584',
#  'CAATGCGAGAAGTATC': 'CL:0000584',
#  'CAATGGAATCTACATA': 'CL:0000584',
#  'CAATGGATCTCTACCA': 'CL:0000186',
#  'CAATGTGCCAACCCTT': 'CL:0000584',
#  'CAATTAAGGGTGATGA': 'CL:0000584',
#  'CAATTTCGTATAAGGG': 'CL:0000584',
#  'CACAAACCGCAGAACT': 'CL:0009010',
#  'CACAAGAAAGATATTA': 'CL:0009010',
#  'CACAATGAGCTGCTAT': 'CL:0000584',
#  'CACACACGCTAACGAG': 'CL:0000584',
#  'CACACAGCTTGCGCTC': 'CL:0000584',
#  'CACACAGGGATAGATT': 'CL:0009010',
#  'CACACGCGCTGTCTTA': 'CL:0000034',
#  'CACACGTTTCAATGGG': 'CL:0000584',
#  'CACACTTGTATTGCGA': 'CL:0000584',
#  'CACAGCACCCACGGCA': 'CL:0000584',
#  'CACAGCTAGGGAGTGA': 'CL:0000584',
#  'CACAGGGCCATATAGT': 'CL:0000584',
#  'CACAGGGCCGTTGTCA': 'CL:0000584',
#  'CACAGTCCCGCTTCGC': 'CL:0000584',
#  'CACATATTAGCAGGAT': 'CL:0000584',
#  'CACATCGTGCACGCGC': 'CL:0009010',
#  'CACATCTCACCGACGA': 'CL:0000584',
#  'CACATGATTCAGCAAC': 'CL:0000034',
#  'CACATTCTTTCGATGG': 'CL:0000584',
#  'CACATTTCTTGTCAGA': 'CL:0000034',
#  'CACCATCGGAGGAGAC': 'CL:0000584',
#  'CACCCAAATCTTATGT': 'CL:0000584',
#  'CACCCACACGTCACCC': 'CL:0000584',
#  'CACCCACGAGGCAATT': 'CL:0009010',
#  'CACCCGCGTTTGACAC': 'CL:0009010',
#  'CACCCGGTTTGTGACT': 'CL:0000186',
#  'CACCCTAACAAGATCT': 'CL:0009010',
#  'CACCCTTGGTGAGACC': 'CL:0009010',
#  'CACCCTTTCCTCGCTC': 'CL:0000584',
#  'CACCGATGATGGGTAC': 'CL:0009010',
#  'CACCGGAGATATCTCC': 'CL:0000584',
#  'CACCGGGCATCACAAG': 'CL:0009010',
#  'CACCGTATCCCATCCG': 'CL:0000584',
#  'CACCGTTGCGCGATAT': 'CL:0009010',
#  'CACCTAATAGAGTCGT': 'CL:0000584',
#  'CACCTAATCAGTTTAC': 'CL:0000034',
#  'CACCTCGATGGTGGAC': 'CL:0000584',
#  'CACCTTGGCGCCTTTG': 'CL:0000584',
#  'CACGAAAGTTAGTCCC': 'CL:0000584',
#  'CACGACGTAATAGTAA': 'CL:0000584',
#  'CACGACTAAAGTTCTG': 'CL:0000584',
#  'CACGCACAGCGCAGCT': 'CL:0000034',
#  'CACGCAGCGAGGCTTT': 'CL:0000584',
#  'CACGCGGAACTGTTGC': 'CL:0000584',
#  'CACGGACGTGGATGGC': 'CL:0000584',
#  'CACGTCAATCAATGGA': 'CL:0000584',
#  'CACGTCGGCAACCTCT': 'CL:0000584',
#  'CACGTCTATGATGTGG': 'CL:0000584',
#  'CACGTTTCGTACACAC': 'CL:0000584',
#  'CACTAAAGTTGCCTAT': 'CL:0000034',
#  'CACTACTCAGTTCTGT': 'CL:0000584',
#  'CACTCAAGAGCTATGG': 'CL:0000584',
#  'CACTCAGCTCTTGAGG': 'CL:0000584',
#  'CACTCCTATGTAAGAT': 'CL:0009010',
#  'CACTCCTCTCGGTCGG': 'CL:0000186',
#  'CACTCGAGCTGAACAA': 'CL:0000584',
#  'CACTCTTCTGCTAGCC': 'CL:0009010',
#  'CACTGACGATTGTGGA': 'CL:0009010',
#  'CACTGTCCAAGTGAGA': 'CL:0000584',
#  'CACTTAATCAGACGGA': 'CL:0000584',
#  'CACTTCGCCACAGGCT': 'CL:0000584',
#  'CAGAACTTAGCCCTCT': 'CL:0000584',
#  'CAGAATATTCGTTATC': 'CL:0009010',
#  'CAGACACCGATCGCTG': 'CL:0000186',
#  'CAGACCTGTAAGTGTT': 'CL:0000034',
#  'CAGACGAACCTGATAC': 'CL:0000034',
#  'CAGAGACGGTCACCCA': 'CL:0000186',
#  'CAGAGCGATGGATGCT': 'CL:0009010',
#  'CAGATAATGGGCGGGT': 'CL:0000584',
#  'CAGATACTAACATAGT': 'CL:0000584',
#  'CAGATATGAAGATGAC': 'CL:0000584',
#  'CAGATCCTGGTTTGAA': 'CL:0000584',
#  'CAGCAGCCCGTTCCTT': 'CL:0000034',
#  'CAGCAGTCCAGACTAT': 'CL:0000584',
#  'CAGCAGTCTGTGCTGC': 'CL:0000584',
#  'CAGCCCTCACAGGCAG': 'CL:0000584',
#  'CAGCCTCCTGCAGAGG': 'CL:0000584',
#  'CAGCCTCGATAGCGGT': 'CL:0000584',
#  'CAGCCTCTCCTCAAGA': 'CL:0000584',
#  'CAGCGATTCCCTTCAA': 'CL:0000584',
#  'CAGCTCACTGAGACAT': 'CL:0000584',
#  'CAGCTCGACAAGTTAA': 'CL:0000034',
#  'CAGCTCGTGCTTGTGT': 'CL:0000584',
#  'CAGCTGGCGTAACCGT': 'CL:0009010',
#  'CAGCTTAGTAGGTAGC': 'CL:0000584',
#  'CAGGAAGACTTTATAT': 'CL:0000584',
#  'CAGGATATATCGTTGT': 'CL:0009010',
#  'CAGGCAGTCTTACCAG': 'CL:0000584',
#  'CAGGCCGTTTGGGTGT': 'CL:0009010',
#  'CAGGCGCACGGTGGTC': 'CL:0000584',
#  'CAGGCGCCATGCTAGG': 'CL:0000584',
#  'CAGTAACTATTTATTG': 'CL:0000584',
#  'CAGTAATCCCTCCCAG': 'CL:0000584',
#  'CAGTACATTCTCTAAA': 'CL:0000584',
#  'CAGTAGCCCACGCGGT': 'CL:0000584',
#  'CAGTCGAGGATGCAAT': 'CL:0000186',
#  'CAGTCTGTATACTGGG': 'CL:0000034',
#  'CAGTGAATAAATGACT': 'CL:0000584',
#  'CAGTGGTTGCACATGA': 'CL:0000584',
#  'CAGTGTCCGCAGAATG': 'CL:0000584',
#  'CAGTGTCGGCTGGCCC': 'CL:0000584',
#  'CAGTTCAAATTGACAC': 'CL:0000584',
#  'CAGTTCCGCGGGTCGA': 'CL:0000034',
#  'CAGTTCGAGGACCCGA': 'CL:0000584',
#  'CATAACGGACAGTCGT': 'CL:0000034',
#  'CATAAGAAGCTTGGCT': 'CL:0000584',
#  'CATAATGAGCGGGCGA': 'CL:0000584',
#  'CATACACGGTTCCCAC': 'CL:0000186',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACGAACTAGCTGG': 'CL:0000584',
#  'CATACGGCGTCTGGGC': 'CL:0000584',
#  'CATACTATGTAATTGT': 'CL:0000584',
#  'CATACTTAGGCAATAC': 'CL:0000584',
#  'CATACTTCTTTCTCCG': 'CL:0009010',
#  'CATAGCGTTGCCCACC': 'CL:0000584',
#  'CATAGTACATTGAGAG': 'CL:0000186',
#  'CATAGTAGCATAGTAG': 'CL:0009010',
#  'CATAGTCCACAAGAAC': 'CL:0009010',
#  'CATATACTACTGATAA': 'CL:0000584',
#  'CATATAGGTACAGTCA': 'CL:0000034',
#  'CATATGTCAGGCTACG': 'CL:0000584',
#  'CATATTATTTGCCCTA': 'CL:0000584',
#  'CATCAAACTGGCGCCC': 'CL:0000584',
#  'CATCATCTACCCGGAC': 'CL:0000584',
#  'CATCATTACCCTGAGG': 'CL:0000584',
#  'CATCCAATATAGTTTG': 'CL:0009010',
#  'CATCCTCTCAAAGATC': 'CL:0000584',
#  'CATCGCCCGCGGCCAA': 'CL:0000584',
#  'CATCGGACGGGTTAAT': 'CL:0000584',
#  'CATCTATCCCGTGTCT': 'CL:0009010',
#  'CATCTTACACCACCTC': 'CL:0000034',
#  'CATGAACCTCTTATCA': 'CL:0000584',
#  'CATGACTTCGCTGAAT': 'CL:0000584',
#  'CATGAGATGCACTCTC': 'CL:0000584',
#  'CATGAGTCCATCACGG': 'CL:0000584',
#  'CATGATACGGTGAAAC': 'CL:0009010',
#  'CATGATCGCTTTGAGA': 'CL:0000584',
#  'CATGATGCACAATTCT': 'CL:0000584',
#  'CATGATGGAAGTTAGC': 'CL:0009010',
#  'CATGCACGTGTTACTG': 'CL:0000584',
#  'CATGCGACCAGTTTAA': 'CL:0009010',
#  'CATGCGTTAGACAGAA': 'CL:0009010',
#  'CATGCGTTGAGAGGAG': 'CL:0000584',
#  'CATGCTGGCTCCAATT': 'CL:0009010',
#  'CATGGAAATGGGACCA': 'CL:0000584',
#  'CATGGATTGTCTTCCG': 'CL:0000584',
#  'CATGGCAGGAAGATCG': 'CL:0000584',
#  'CATGGGTATGCCTTAT': 'CL:0000584',
#  'CATGGGTCGGGTGTGG': 'CL:0000584',
#  'CATGGTCTAGATACCG': 'CL:0000584',
#  'CATGGTTTATTAATCA': 'CL:0000584',
#  'CATGTAAGAGACATTT': 'CL:0000584',
#  'CATGTAGGAGCGCCAA': 'CL:0000584',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0            EFO:0010961
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0            EFO:0010961
# AAACAATCTACTAGCA-1        0.0        3.0        3.0            EFO:0010961
# AAACACCAATAACTGC-1        1.0       59.0       59.0            EFO:0010961
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0            EFO:0010961
# TTGTTTCCATACAACT-1        0.0       45.0       45.0            EFO:0010961
# TTGTTTGTATTACACG-1        1.0       73.0       73.0            EFO:0010961
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0            EFO:0010961
# 386                       0.0        6.0        2.0            EFO:0010961
#
#                             barcodes cell_type_ontology_term_id
# AAACAACGAATAGTTC-1  AAACAACGAATAGTTC                        NaN
# AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA                 CL:0009010
# AAACAATCTACTAGCA-1  AAACAATCTACTAGCA                        NaN
# AAACACCAATAACTGC-1  AAACACCAATAACTGC                        NaN
# AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT                        NaN
# ...                              ...                        ...
# TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA                 CL:0000584
# TTGTTTCCATACAACT-1  TTGTTTCCATACAACT                        NaN
# TTGTTTGTATTACACG-1  TTGTTTGTATTACACG                 CL:0000584
# TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC                 CL:0000584
# 386                              NaN                        NaN
#
# [4992 rows x 6 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 1816

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_27634/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0            EFO:0010961
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0            EFO:0010961
# AAACAATCTACTAGCA-1        0.0        3.0        3.0            EFO:0010961
# AAACACCAATAACTGC-1        1.0       59.0       59.0            EFO:0010961
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0            EFO:0010961
# TTGTTTCCATACAACT-1        0.0       45.0       45.0            EFO:0010961
# TTGTTTGTATTACACG-1        1.0       73.0       73.0            EFO:0010961
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0            EFO:0010961
# 386                       0.0        6.0        2.0            EFO:0010961
#
#                             barcodes cell_type_ontology_term_id
# AAACAACGAATAGTTC-1  AAACAACGAATAGTTC                    unknown
# AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA                 CL:0009010
# AAACAATCTACTAGCA-1  AAACAATCTACTAGCA                    unknown
# AAACACCAATAACTGC-1  AAACACCAATAACTGC                    unknown
# AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT                    unknown
# ...                              ...                        ...
# TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA                 CL:0000584
# TTGTTTCCATACAACT-1  TTGTTTCCATACAACT                    unknown
# TTGTTTGTATTACACG-1  TTGTTTGTATTACACG                 CL:0000584
# TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC                 CL:0000584
# 386                              NaN                    unknown
#
# [4992 rows x 6 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0009010',
#  'CL:0000584',
#  'CL:0000186',
#  'CL:0000034',
#  'CL:0000057',
#  'CL:0000844',
#  'CL:0000788',
#  'CL:0000235',
#  'CL:0000160',
#  'CL:0002138',
#  'CL:0000775',
#  'CL:0002461']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    4A_Hh
# AAACAAGTATCTCCCA-1    4A_Hh
# AAACAATCTACTAGCA-1    4A_Hh
# AAACACCAATAACTGC-1    4A_Hh
# AAACAGAGCGACTCCT-1    4A_Hh
#                       ...
# TTGTTTCATTAGTCTA-1    4A_Hh
# TTGTTTCCATACAACT-1    4A_Hh
# TTGTTTGTATTACACG-1    4A_Hh
# TTGTTTGTGTAAATTC-1    4A_Hh
# 386                   4A_Hh
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['4A_Hh']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# 386                   MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# 386                   PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# 386                   True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# 386                   NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# 386                   na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# 386                   unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# 386                   tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# 386                   UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0            EFO:0010961
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0            EFO:0010961
# AAACAATCTACTAGCA-1        0.0        3.0        3.0            EFO:0010961
# AAACACCAATAACTGC-1        1.0       59.0       59.0            EFO:0010961
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0            EFO:0010961
# TTGTTTCCATACAACT-1        0.0       45.0       45.0            EFO:0010961
# TTGTTTGTATTACACG-1        1.0       73.0       73.0            EFO:0010961
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0            EFO:0010961
# 386                       0.0        6.0        2.0            EFO:0010961
#
#                             barcodes cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1  AAACAACGAATAGTTC                    unknown    4A_Hh
# AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA                 CL:0009010    4A_Hh
# AAACAATCTACTAGCA-1  AAACAATCTACTAGCA                    unknown    4A_Hh
# AAACACCAATAACTGC-1  AAACACCAATAACTGC                    unknown    4A_Hh
# AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT                    unknown    4A_Hh
# ...                              ...                        ...      ...
# TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA                 CL:0000584    4A_Hh
# TTGTTTCCATACAACT-1  TTGTTTCCATACAACT                    unknown    4A_Hh
# TTGTTTGTATTACACG-1  TTGTTTGTATTACACG                 CL:0000584    4A_Hh
# TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC                 CL:0000584    4A_Hh
# 386                              NaN                    unknown    4A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
# 386                                    MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
# 386                            PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
# 386                          NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
# 386                                                      na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
# 386                             unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
# 386                         UBERON:0001155
#
# [4992 rows x 16 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# {'spatial': {'spaceranger200_count_46450_Mus_Tcel13290870_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#     'software_version': 'spaceranger-2.0.0'},
#    'images': {'hires': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8),
#     'lowres': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8)},
#    'scalefactors': {'tissue_hires_scalef': 0.23148148,
#     'tissue_lowres_scalef': 0.06944445,
#     'fiducial_diameter_fullres': 59.310209638643535,
#     'spot_diameter_fullres': 36.71584406201743}}}}

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290870_mm10-2020-A/V12U21-349_C1-5x.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '4A_Hh'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# {'spatial': {'spaceranger200_count_46450_Mus_Tcel13290870_mm10-2020-A': {'images': {'hires': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8),
#     'fullres': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8)},
#    'scalefactors': {'tissue_hires_scalef': 0.23148148,
#     'spot_diameter_fullres': 36.71584406201743}},
#   'is_single': True},
#  'image_caption': 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E',
#  'default_embedding': 'spatial',
#  'title': '4A_Hh',
#  'spatial_metadata': {'chemistry_description': 'Visium V1 Slide',
#   'software_version': 'spaceranger-2.0.0'}}

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0            EFO:0010961
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0            EFO:0010961
# AAACAATCTACTAGCA-1        0.0        3.0        3.0            EFO:0010961
# AAACACCAATAACTGC-1        1.0       59.0       59.0            EFO:0010961
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0            EFO:0010961
# TTGTTTCCATACAACT-1        0.0       45.0       45.0            EFO:0010961
# TTGTTTGTATTACACG-1        1.0       73.0       73.0            EFO:0010961
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0            EFO:0010961
# 386                       0.0        6.0        2.0            EFO:0010961
#
#                             barcodes cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1  AAACAACGAATAGTTC                    unknown    4A_Hh
# AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA                 CL:0009010    4A_Hh
# AAACAATCTACTAGCA-1  AAACAATCTACTAGCA                    unknown    4A_Hh
# AAACACCAATAACTGC-1  AAACACCAATAACTGC                    unknown    4A_Hh
# AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT                    unknown    4A_Hh
# ...                              ...                        ...      ...
# TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA                 CL:0000584    4A_Hh
# TTGTTTCCATACAACT-1  TTGTTTCCATACAACT                    unknown    4A_Hh
# TTGTTTGTATTACACG-1  TTGTTTGTATTACACG                 CL:0000584    4A_Hh
# TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC                 CL:0000584    4A_Hh
# 386                              NaN                    unknown    4A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
# 386                                    MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
# 386                            PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
# 386                          NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
# 386                                                      na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
# 386                             unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
# 386                         UBERON:0001155
#
# [4992 rows x 16 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# {'spatial': {'spaceranger200_count_46450_Mus_Tcel13290870_mm10-2020-A': {'images': {'hires': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8),
#     'fullres': array([[[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            ...,
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]],
#
#            [[244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246],
#             ...,
#             [244, 243, 246],
#             [244, 243, 246],
#             [244, 243, 246]]], dtype=uint8)},
#    'scalefactors': {'tissue_hires_scalef': 0.23148148,
#     'spot_diameter_fullres': 36.71584406201743}},
#   'is_single': True},
#  'image_caption': 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E',
#  'default_embedding': 'spatial',
#  'title': '4A_Hh',
#  'spatial_metadata': {'chemistry_description': 'Visium V1 Slide',
#   'software_version': 'spaceranger-2.0.0'}}

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_27634/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
print(adata.X.dtype)
# Out:
# float64

# %%
adata.X = adata.X.astype(np.float32)

# %%
print(adata.X.dtype)
# Out:
# float32

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13290870.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col assay_ontology_term_id  \
# AAACAACGAATAGTTC-1          0          0          0            EFO:0010961
# AAACAAGTATCTCCCA-1          1         50         50            EFO:0010961
# AAACAATCTACTAGCA-1          0          3          3            EFO:0010961
# AAACACCAATAACTGC-1          1         59         59            EFO:0010961
# AAACAGAGCGACTCCT-1          1         14         14            EFO:0010961
# ...                       ...        ...        ...                    ...
# TTGTTTCATTAGTCTA-1          1         60         60            EFO:0010961
# TTGTTTCCATACAACT-1          0         45         45            EFO:0010961
# TTGTTTGTATTACACG-1          1         73         73            EFO:0010961
# TTGTTTGTGTAAATTC-1          1          7          7            EFO:0010961
# 386                         0          6          2            EFO:0010961
#
#                    cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1                    unknown    4A_Hh
# AAACAAGTATCTCCCA-1                 CL:0009010    4A_Hh
# AAACAATCTACTAGCA-1                    unknown    4A_Hh
# AAACACCAATAACTGC-1                    unknown    4A_Hh
# AAACAGAGCGACTCCT-1                    unknown    4A_Hh
# ...                                       ...      ...
# TTGTTTCATTAGTCTA-1                 CL:0000584    4A_Hh
# TTGTTTCCATACAACT-1                    unknown    4A_Hh
# TTGTTTGTATTACACG-1                 CL:0000584    4A_Hh
# TTGTTTGTGTAAATTC-1                 CL:0000584    4A_Hh
# 386                                   unknown    4A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
# 386                                    MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
# 386                            PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
# 386                          NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
# 386                                                      na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
# 386                             unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
# 386                         UBERON:0001155
#
# [4992 rows x 15 columns]

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)
# Out:
# Missing columns: []

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
# Out:
# Data Types:
# array_col    int64
# array_row    int64
# in_tissue    int64
# dtype: object
#
# Missing Values:
# array_col    0
# array_row    0
# in_tissue    0
# dtype: int64

# %% [markdown]
# ### **Curating Tcel13255055**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255055_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 21805058 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 24)	1.0
#   (0, 39)	2.0
#   (0, 63)	2.0
#   (0, 69)	1.0
#   (0, 91)	1.0
#   (0, 96)	1.0
#   (0, 123)	1.0
#   (0, 131)	1.0
#   (0, 168)	3.0
#   (0, 178)	1.0
#   (0, 193)	8.0
#   (0, 214)	1.0
#   (0, 218)	1.0
#   (0, 234)	8.0
#   (0, 257)	1.0
#   (0, 342)	1.0
#   (0, 356)	1.0
#   (0, 368)	1.0
#   (0, 388)	1.0
#   (0, 392)	1.0
#   (0, 395)	1.0
#   (0, 408)	1.0
#   (0, 413)	2.0
#   (0, 440)	1.0
#   (0, 446)	1.0
#   :	:
#   (4991, 31415)	1.0
#   (4991, 31418)	9.0
#   (4991, 31424)	1.0
#   (4991, 31433)	1.0
#   (4991, 31437)	1.0
#   (4991, 31441)	1.0
#   (4991, 31442)	1.0
#   (4991, 31450)	39.0
#   (4991, 31460)	1.0
#   (4991, 31468)	1.0
#   (4991, 32193)	5.0
#   (4991, 32195)	10.0
#   (4991, 32196)	6.0
#   (4991, 32197)	66.0
#   (4991, 32198)	34.0
#   (4991, 32200)	58.0
#   (4991, 32201)	96.0
#   (4991, 32202)	1.0
#   (4991, 32204)	5.0
#   (4991, 32205)	1.0
#   (4991, 32207)	15.0
#   (4991, 32221)	1.0
#   (4991, 32231)	1.0
#   (4991, 32234)	1.0
#   (4991, 32284)	4.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1741
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5268
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             2359
# AAACACCAATAACTGC-1        1.0       59.0       59.0             5172
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             6671
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4384
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5892
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             6852
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             3744
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             5837
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13255055_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1        1.0  2A_Hh.only               5268
# Mus_Tcel13255055_AAACACCAATAACTGC-1        1.0  2A_Hh.only               5172
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1        1.0  2A_Hh.only               6671
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1        1.0  2A_Hh.only               7129
# Mus_Tcel13255055_AAACAGGGTCTATATT-1        1.0  2A_Hh.only               6590
# ...                                        ...         ...                ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1        1.0  2A_Hh.only               4384
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1        1.0  2A_Hh.only               5892
# Mus_Tcel13255055_TTGTTTCCATACAACT-1        1.0  2A_Hh.only               6852
# Mus_Tcel13255055_TTGTTTGTATTACACG-1        1.0  2A_Hh.only               3744
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1        1.0  2A_Hh.only               5837
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                 8.569596       23904.0
# Mus_Tcel13255055_AAACACCAATAACTGC-1                 8.551208       15036.0
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                 8.805675       34366.0
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                 8.872066       34410.0
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                 8.793460       23583.0
# ...                                                      ...           ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                 8.385945       10789.0
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                 8.681520       18940.0
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                 8.832441       42064.0
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                 8.228177        9247.0
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                 8.672144       20318.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1           10.081843
# Mus_Tcel13255055_AAACACCAATAACTGC-1            9.618269
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1           10.444852
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1           10.446132
# Mus_Tcel13255055_AAACAGGGTCTATATT-1           10.068324
# ...                                                 ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1            9.286375
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1            9.849084
# Mus_Tcel13255055_TTGTTTCCATACAACT-1           10.646972
# Mus_Tcel13255055_TTGTTTGTATTACACG-1            9.132163
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1            9.919312
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                   26.577143
# Mus_Tcel13255055_AAACACCAATAACTGC-1                   19.626230
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                   23.584356
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                   21.124674
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                   16.308357
# ...                                                         ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                   16.730003
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                   17.122492
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                   26.785376
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                   19.336000
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                   15.144207
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    33.872993
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    26.330141
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    30.716406
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    29.067131
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    22.952974
# ...                                                          ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    23.996664
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    23.949314
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    34.314377
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    26.949282
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    23.166651
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    43.783466
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    35.049213
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    39.544899
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    38.950886
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    31.671120
# ...                                                          ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    33.497082
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    32.808868
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    43.146160
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    36.152267
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    33.881287
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    58.638721  ...
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    48.503590  ...
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    53.631496  ...
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    52.760826  ...
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    45.719376  ...
# ...                                                          ...  ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    48.160164  ...
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    46.626186  ...
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    57.172405  ...
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    51.400455  ...
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    49.000885  ...
#
#                                        donor_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1  2A_Hh.only
# Mus_Tcel13255055_AAACACCAATAACTGC-1  2A_Hh.only
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1  2A_Hh.only
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1  2A_Hh.only
# Mus_Tcel13255055_AAACAGGGTCTATATT-1  2A_Hh.only
# ...                                         ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1  2A_Hh.only
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1  2A_Hh.only
# Mus_Tcel13255055_TTGTTTCCATACAACT-1  2A_Hh.only
# Mus_Tcel13255055_TTGTTTGTATTACACG-1  2A_Hh.only
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1  2A_Hh.only
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                     MmusDv:0000061
# Mus_Tcel13255055_AAACACCAATAACTGC-1                     MmusDv:0000061
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                     MmusDv:0000061
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                     MmusDv:0000061
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                     MmusDv:0000061
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                     MmusDv:0000061
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                     MmusDv:0000061
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13255055_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTGTATTACACG-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTGTATTACACG-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13255055_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                                       na
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                                       na
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1              unknown               na
# Mus_Tcel13255055_AAACACCAATAACTGC-1              unknown               na
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1              unknown               na
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1              unknown               na
# Mus_Tcel13255055_AAACAGGGTCTATATT-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1              unknown               na
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1              unknown               na
# Mus_Tcel13255055_TTGTTTCCATACAACT-1              unknown               na
# Mus_Tcel13255055_TTGTTTGTATTACACG-1              unknown               na
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
# [3228 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1        1.0  2A_Hh.only               5268
# Mus_Tcel13255055_AAACACCAATAACTGC-1        1.0  2A_Hh.only               5172
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1        1.0  2A_Hh.only               6671
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1        1.0  2A_Hh.only               7129
# Mus_Tcel13255055_AAACAGGGTCTATATT-1        1.0  2A_Hh.only               6590
# ...                                        ...         ...                ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1        1.0  2A_Hh.only               4384
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1        1.0  2A_Hh.only               5892
# Mus_Tcel13255055_TTGTTTCCATACAACT-1        1.0  2A_Hh.only               6852
# Mus_Tcel13255055_TTGTTTGTATTACACG-1        1.0  2A_Hh.only               3744
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1        1.0  2A_Hh.only               5837
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                 8.569596       23904.0
# Mus_Tcel13255055_AAACACCAATAACTGC-1                 8.551208       15036.0
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                 8.805675       34366.0
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                 8.872066       34410.0
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                 8.793460       23583.0
# ...                                                      ...           ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                 8.385945       10789.0
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                 8.681520       18940.0
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                 8.832441       42064.0
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                 8.228177        9247.0
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                 8.672144       20318.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1           10.081843
# Mus_Tcel13255055_AAACACCAATAACTGC-1            9.618269
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1           10.444852
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1           10.446132
# Mus_Tcel13255055_AAACAGGGTCTATATT-1           10.068324
# ...                                                 ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1            9.286375
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1            9.849084
# Mus_Tcel13255055_TTGTTTCCATACAACT-1           10.646972
# Mus_Tcel13255055_TTGTTTGTATTACACG-1            9.132163
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1            9.919312
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                   26.577143
# Mus_Tcel13255055_AAACACCAATAACTGC-1                   19.626230
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                   23.584356
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                   21.124674
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                   16.308357
# ...                                                         ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                   16.730003
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                   17.122492
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                   26.785376
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                   19.336000
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                   15.144207
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    33.872993
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    26.330141
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    30.716406
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    29.067131
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    22.952974
# ...                                                          ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    23.996664
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    23.949314
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    34.314377
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    26.949282
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    23.166651
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    43.783466
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    35.049213
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    39.544899
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    38.950886
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    31.671120
# ...                                                          ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    33.497082
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    32.808868
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    43.146160
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    36.152267
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    33.881287
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                    58.638721  ...
# Mus_Tcel13255055_AAACACCAATAACTGC-1                    48.503590  ...
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                    53.631496  ...
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                    52.760826  ...
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                    45.719376  ...
# ...                                                          ...  ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                    48.160164  ...
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                    46.626186  ...
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                    57.172405  ...
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                    51.400455  ...
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                    49.000885  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                      MmusDv:0000061
# Mus_Tcel13255055_AAACACCAATAACTGC-1                      MmusDv:0000061
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                      MmusDv:0000061
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                      MmusDv:0000061
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                      MmusDv:0000061
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                      MmusDv:0000061
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                      MmusDv:0000061
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                      MmusDv:0000061
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13255055_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13255055_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTGTATTACACG-1             PATO:0000461            True
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13255055_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTGTATTACACG-1           NCBITaxon:10090
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13255055_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1                                       na
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13255055_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13255055_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13255055_TTGTTTGTATTACACG-1                                       na
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1              unknown              na
# Mus_Tcel13255055_AAACACCAATAACTGC-1              unknown              na
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1              unknown              na
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1              unknown              na
# Mus_Tcel13255055_AAACAGGGTCTATATT-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1              unknown              na
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1              unknown              na
# Mus_Tcel13255055_TTGTTTCCATACAACT-1              unknown              na
# Mus_Tcel13255055_TTGTTTGTATTACACG-1              unknown              na
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13255055_AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA
# Mus_Tcel13255055_AAACACCAATAACTGC-1  AAACACCAATAACTGC
# Mus_Tcel13255055_AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT
# Mus_Tcel13255055_AAACAGCTTTCAGAAG-1  AAACAGCTTTCAGAAG
# Mus_Tcel13255055_AAACAGGGTCTATATT-1  AAACAGGGTCTATATT
# ...                                               ...
# Mus_Tcel13255055_TTGTTTCACATCCAGG-1  TTGTTTCACATCCAGG
# Mus_Tcel13255055_TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA
# Mus_Tcel13255055_TTGTTTCCATACAACT-1  TTGTTTCCATACAACT
# Mus_Tcel13255055_TTGTTTGTATTACACG-1  TTGTTTGTATTACACG
# Mus_Tcel13255055_TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC
#
# [3228 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0000584',
#  'AAACACCAATAACTGC': 'CL:0000844',
#  'AAACAGAGCGACTCCT': 'CL:0000584',
#  'AAACAGCTTTCAGAAG': 'CL:0000186',
#  'AAACAGGGTCTATATT': 'CL:0000844',
#  'AAACAGTGTTCCTGGG': 'CL:0000584',
#  'AAACATTTCCCGGATT': 'CL:0000584',
#  'AAACCCGAACGAAATC': 'CL:0000584',
#  'AAACCGGAAATGTTAA': 'CL:0000584',
#  'AAACCGGGTAGGTACC': 'CL:0000584',
#  'AAACCGTTCGTCCAGG': 'CL:0000584',
#  'AAACCTAAGCAGCCGG': 'CL:0009010',
#  'AAACCTCATGAAGTTG': 'CL:0000186',
#  'AAACGAAGAACATACC': 'CL:0009010',
#  'AAACGAGACGGTTGAT': 'CL:0000844',
#  'AAACGGGCGTACGGGT': 'CL:0000584',
#  'AAACGGTTGCGAACTG': 'CL:0000844',
#  'AAACTCGGTTCGCAAT': 'CL:0000844',
#  'AAACTCGTGATATAAG': 'CL:0000584',
#  'AAACTGCTGGCTCCAA': 'CL:0000584',
#  'AAACTTGCAAACGTAT': 'CL:0000584',
#  'AAAGACTGGGCGCTTT': 'CL:0000584',
#  'AAAGCTTGCCTACATA': 'CL:0000584',
#  'AAAGGCCCTATAATAC': 'CL:0000584',
#  'AAAGGCTACGGACCAT': 'CL:0000584',
#  'AAAGGCTCTCGCGCCG': 'CL:0000844',
#  'AAAGGGATGTAGCAAG': 'CL:0000584',
#  'AAAGGGCAGCTTGAAT': 'CL:0000186',
#  'AAAGTAGCATTGCTCA': 'CL:0000034',
#  'AAAGTCACTGATGTAA': 'CL:0000584',
#  'AAAGTCGACCCTCAGT': 'CL:0000186',
#  'AAAGTGTGATTTATCT': 'CL:0000584',
#  'AAAGTTGACTCCCGTA': 'CL:0000584',
#  'AAATAACCATACGGGA': 'CL:0000584',
#  'AAATACCTATAAGCAT': 'CL:0000584',
#  'AAATAGCTTAGACTTT': 'CL:0000584',
#  'AAATCCGATACACGCC': 'CL:0000186',
#  'AAATCGCGGAAGGAGT': 'CL:0000584',
#  'AAATCGTGTACCACAA': 'CL:0000584',
#  'AAATGATTCGATCAGC': 'CL:0000584',
#  'AAATGCTCGTTACGTT': 'CL:0000584',
#  'AAATGGCATGTCTTGT': 'CL:0000584',
#  'AAATGGCCCGTGCCCT': 'CL:0000584',
#  'AAATGGTCAATGTGCC': 'CL:0000844',
#  'AAATTAATAAGCGCGA': 'CL:0000186',
#  'AAATTACACGACTCTG': 'CL:0000584',
#  'AAATTACCTATCGATG': 'CL:0000584',
#  'AAATTGATAGTCCTTT': 'CL:0000844',
#  'AAATTTACCGAAATCC': 'CL:0000584',
#  'AAATTTGCGGGTGTGG': 'CL:0000057',
#  'AACAACTGGTAGTTGC': 'CL:0009010',
#  'AACAATACATTGTCGA': 'CL:0000160',
#  'AACACACGCTCGCCGC': 'CL:0000844',
#  'AACACGACTGTACTGA': 'CL:0000844',
#  'AACACGAGACGCGGCC': 'CL:0009010',
#  'AACAGCTGTGTGGCAA': 'CL:0000186',
#  'AACAGGAAATCGAATA': 'CL:0000584',
#  'AACAGGTAGTATGGAT': 'CL:0000844',
#  'AACATAGCGTGTATCG': 'CL:0000584',
#  'AACATATCAACTGGTG': 'CL:0000584',
#  'AACATCGATACGTCTA': 'CL:0000584',
#  'AACATTGAAGTTGATC': 'CL:0000584',
#  'AACATTGTGACTCGAG': 'CL:0000584',
#  'AACCAAGACTTCTCTG': 'CL:0000186',
#  'AACCAGTATCACTCTT': 'CL:0000584',
#  'AACCATGGGATCGCTA': 'CL:0000584',
#  'AACCCAGAGACGGAGA': 'CL:0000584',
#  'AACCCATCCCATGATC': 'CL:0000186',
#  'AACCCGACAACCCGTG': 'CL:0000584',
#  'AACCCGAGCAGAATCG': 'CL:0000584',
#  'AACCCGCTGTATTCCA': 'CL:0000584',
#  'AACCCTACTGTCAATA': 'CL:0000584',
#  'AACCCTGGTGGAACCA': 'CL:0000584',
#  'AACCGAGCTTGGTCAT': 'CL:0000186',
#  'AACCGCTAAGGGATGC': 'CL:0009010',
#  'AACCGTTGTGTTTGCT': 'CL:0000584',
#  'AACCTTTAAATACGGT': 'CL:0000186',
#  'AACCTTTACGACGTCT': 'CL:0000584',
#  'AACGATATGTCAACTG': 'CL:0000186',
#  'AACGCATGATCTGGGT': 'CL:0000584',
#  'AACGCGACCTTGGGCG': 'CL:0000844',
#  'AACGCGGTCTCCAGCC': 'CL:0000186',
#  'AACGCTGTTGCTGAAA': 'CL:0009010',
#  'AACGGACGTACGTATA': 'CL:0009010',
#  'AACGGCCATCTCCGGT': 'CL:0000186',
#  'AACGTACTGTGGGTAC': 'CL:0000844',
#  'AACGTCAGACTAGTGG': 'CL:0000186',
#  'AACGTGATGAAGGACA': 'CL:0000584',
#  'AACGTGCGAAAGTCTC': 'CL:0000057',
#  'AACGTTATCAGCACCT': 'CL:0000844',
#  'AACTACCCGTTTGTCA': 'CL:0000584',
#  'AACTAGGCTTGGGTGT': 'CL:0000584',
#  'AACTCAAGTTAATTGC': 'CL:0000584',
#  'AACTCCTAATCCCATG': 'CL:0000584',
#  'AACTCGATGGCGCAGT': 'CL:0000186',
#  'AACTCTCAATAGAGCG': 'CL:0000584',
#  'AACTCTCAGTGTGCTC': 'CL:0000584',
#  'AACTGAGTTATACTGA': 'CL:0000584',
#  'AACTGATATTAGGCCT': 'CL:0009010',
#  'AACTGGGTCCCGACGT': 'CL:0000584',
#  'AACTGGTGTGGGCCTT': 'CL:0009010',
#  'AACTTCTGCGTCTATC': 'CL:0000186',
#  'AACTTGCGTTCTCGCG': 'CL:0009010',
#  'AACTTTACGGGAGCTT': 'CL:0000186',
#  'AAGAAGGATCAGTTAG': 'CL:0000584',
#  'AAGACCCAACTGAACA': 'CL:0000057',
#  'AAGACTGCAAGCTACT': 'CL:0000057',
#  'AAGAGCTCTTTATCGG': 'CL:0000057',
#  'AAGAGGATGTACGCGA': 'CL:0009010',
#  'AAGAGGCATGGATCGC': 'CL:0000186',
#  'AAGAGGCCCTTTGGAA': 'CL:0000584',
#  'AAGATGGCACCGGACC': 'CL:0000584',
#  'AAGATTGGCGGAACGT': 'CL:0000584',
#  'AAGCACCCTGCGTATC': 'CL:0000584',
#  'AAGCCGCCGTGAAATC': 'CL:0009010',
#  'AAGCGCAGGGCTTTGA': 'CL:0000186',
#  'AAGCGGCGTCATGGGT': 'CL:0000584',
#  'AAGCGTCCCTCATCGA': 'CL:0000584',
#  'AAGCTCGTGCCAAGTC': 'CL:0000584',
#  'AAGCTCTTTCATGGTG': 'CL:0000584',
#  'AAGGAGCGGTTGGTGC': 'CL:0000584',
#  'AAGGATCGATCGCTTG': 'CL:0009010',
#  'AAGGATGAGGGACCTC': 'CL:0000844',
#  'AAGGCAGGCTGTCTCC': 'CL:0000584',
#  'AAGGCGCGTAAAGCTT': 'CL:0000186',
#  'AAGGCTGTGCTCATCG': 'CL:0000584',
#  'AAGGGAACGACTGGCT': 'CL:0000186',
#  'AAGGGACAGATTCTGT': 'CL:0000584',
#  'AAGGTATCCTAATATA': 'CL:0000584',
#  'AAGGTGATAAACCAGC': 'CL:0000584',
#  'AAGTAGAAGACCGGGT': 'CL:0000584',
#  'AAGTAGTGACGCGAGG': 'CL:0000186',
#  'AAGTCAATTGTCGTCA': 'CL:0000584',
#  'AAGTCTTCTGTGGCCT': 'CL:0000186',
#  'AAGTGACGACCGAATT': 'CL:0000186',
#  'AAGTGAGTCGGGTTTA': 'CL:0000844',
#  'AAGTGCAAAGGTAGAC': 'CL:0009010',
#  'AAGTGCGTTAGAATCT': 'CL:0000186',
#  'AAGTGCTTCTCTATTG': 'CL:0000584',
#  'AAGTTCAGTCTGCGTA': 'CL:0000584',
#  'AAGTTCGGCCAACAGG': 'CL:0000057',
#  'AAGTTGTGATGTTATA': 'CL:0000584',
#  'AAGTTTACTAATGGCA': 'CL:0000584',
#  'AATAACAACGCTCGGC': 'CL:0000186',
#  'AATAACACTAGAACAA': 'CL:0000844',
#  'AATAAGTCCTCGAGAC': 'CL:0009010',
#  'AATAATCTTCGTATCG': 'CL:0000584',
#  'AATACAATGTTTCAGG': 'CL:0000186',
#  'AATACCGGAGGGCTGT': 'CL:0000186',
#  'AATACCTGATGTGAAC': 'CL:0000584',
#  'AATAGAACAGAGTGGC': 'CL:0000584',
#  'AATAGAATCTGTTTCA': 'CL:0000034',
#  'AATAGCTACCGCGTGC': 'CL:0000584',
#  'AATAGTCCGTCCCGAC': 'CL:0000584',
#  'AATAGTCGCGAGTCGG': 'CL:0000186',
#  'AATATCAAGGTCGGAT': 'CL:0000584',
#  'AATATCGAATCAATGC': 'CL:0000584',
#  'AATATCGAGGGTTCTC': 'CL:0000584',
#  'AATATTGGAGTATTGA': 'CL:0000186',
#  'AATCAGGTTTCATTTA': 'CL:0000584',
#  'AATCCAAGGGCCTGAG': 'CL:0009010',
#  'AATCGAGGTCTCAAGG': 'CL:0009010',
#  'AATCGCCTCAGCGCCA': 'CL:0000160',
#  'AATCGCGCAGAGGACT': 'CL:0000584',
#  'AATCGGGACACTACGA': 'CL:0000186',
#  'AATCTAGGTTTACTTG': 'CL:0000186',
#  'AATCTGCGTTGGGACG': 'CL:0000844',
#  'AATGACAGCAATGTCT': 'CL:0000844',
#  'AATGACGTAGGATGTC': 'CL:0000034',
#  'AATGACTGTCAGCCGG': 'CL:0000186',
#  'AATGAGTTCGCATATG': 'CL:0000186',
#  'AATGATGATACGCTAT': 'CL:0009010',
#  'AATGATGCGACTCCTG': 'CL:0000584',
#  'AATGCACCAAGCAATG': 'CL:0000584',
#  'AATGGTTCTCACAAGC': 'CL:0009010',
#  'AATGTGCCCGAGGTGT': 'CL:0000186',
#  'AATGTGCTAATCTGAG': 'CL:0000186',
#  'AATGTTAAGACCCTGA': 'CL:0000584',
#  'AATGTTGTCGTGAGAC': 'CL:0000584',
#  'AATTAAAGGTCGGCGT': 'CL:0000844',
#  'AATTAACGGATTTCCA': 'CL:0000844',
#  'AATTATACCCAGCAAG': 'CL:0000584',
#  'AATTCATAAGGGATCT': 'CL:0000584',
#  'AATTCCAAGCATGTAC': 'CL:0000584',
#  'AATTCGATTCGAGGAT': 'CL:0000584',
#  'AATTGAACGCTCTGGT': 'CL:0000844',
#  'AATTGCAGCAATCGAC': 'CL:0000584',
#  'AATTTGGGACATAGTA': 'CL:0000584',
#  'AATTTGGTTCCAAAGA': 'CL:0009010',
#  'ACAAACCATGCGTCCT': 'CL:0009010',
#  'ACAAAGAAGGTAGGCC': 'CL:0000186',
#  'ACAAAGCATGACCTAG': 'CL:0000186',
#  'ACAAATGGTAGTGTTT': 'CL:0000584',
#  'ACAACAGCATGAGCTA': 'CL:0000584',
#  'ACAACGGTCCCTGCGA': 'CL:0009010',
#  'ACAAGCAGTGCCTAGC': 'CL:0000584',
#  'ACAAGCTATATGGAAG': 'CL:0009010',
#  'ACAAGGACAAGAGGTT': 'CL:0000186',
#  'ACAAGGGCAGGCTCTG': 'CL:0000584',
#  'ACAATAGTCGTACGTT': 'CL:0009010',
#  'ACAATCCATTTAAACC': 'CL:0000186',
#  'ACAATGAATACGGAGA': 'CL:0000844',
#  'ACAATTTAGGAGGCTC': 'CL:0009010',
#  'ACAATTTGAGCAGTGG': 'CL:0000057',
#  'ACAATTTGGCCATATT': 'CL:0000584',
#  'ACACAAAGACGGGTGG': 'CL:0000584',
#  'ACACACCAGGACCAGT': 'CL:0000584',
#  'ACACACTTTCTACACG': 'CL:0000584',
#  'ACACATGATCAAATCT': 'CL:0000186',
#  'ACACCCAGCATGCAGC': 'CL:0000186',
#  'ACACCCGAGAAATCCG': 'CL:0000584',
#  'ACACCGGTCTGACCGC': 'CL:0000584',
#  'ACACCTTAAGTAGGGC': 'CL:0000186',
#  'ACACCTTACTACTTGC': 'CL:0000584',
#  'ACACGAGACTCCTTCT': 'CL:0000844',
#  'ACACGGCACTATGCAT': 'CL:0000584',
#  'ACACGGGAACTTAGGG': 'CL:0000844',
#  'ACACGTAGGCCACAAG': 'CL:0000584',
#  'ACACTCCAATGTCACT': 'CL:0000584',
#  'ACACTGGGACAGTCGT': 'CL:0000584',
#  'ACAGCATAGAGCCAGT': 'CL:0000584',
#  'ACAGCGACATTCTCAT': 'CL:0000584',
#  'ACAGGCACGGATCCTT': 'CL:0000584',
#  'ACAGGCTTGCCCGACT': 'CL:0000584',
#  'ACAGGTGGAGGTGAGG': 'CL:0000844',
#  'ACAGGTGTGTTGTTGC': 'CL:0000584',
#  'ACAGTAATACAACTTG': 'CL:0000584',
#  'ACATAATAAGGCGGTG': 'CL:0000584',
#  'ACATCAGCTGGGACGC': 'CL:0000584',
#  'ACATCCCGGCCATACG': 'CL:0000584',
#  'ACATCCTGGTAACTGT': 'CL:0000584',
#  'ACATCGATCGTTTACC': 'CL:0000034',
#  'ACATCGGTCAGCCGCG': 'CL:0000584',
#  'ACATCGTATGCAATGG': 'CL:0000584',
#  'ACATCTCAACGCGTAA': 'CL:0000584',
#  'ACATTTGAAACCTAAC': 'CL:0000584',
#  'ACCAAACACCCAGCGA': 'CL:0000584',
#  'ACCAAACTAGAAATCC': 'CL:0009010',
#  'ACCAACACCACACACT': 'CL:0000584',
#  'ACCAACCGCACTCCAC': 'CL:0000584',
#  'ACCAATATGCAAGTTA': 'CL:0000584',
#  'ACCACAACTCAGAACA': 'CL:0000584',
#  'ACCACAAGTTTCTATC': 'CL:0000844',
#  'ACCACACGGTTGATGG': 'CL:0000584',
#  'ACCACCAATGTAACAA': 'CL:0000584',
#  'ACCACCCTCTCTTCTA': 'CL:0000584',
#  'ACCAGACCATAACAAC': 'CL:0000186',
#  'ACCAGCCCGGTCTTTG': 'CL:0000584',
#  'ACCAGTGCGGGAGACG': 'CL:0000584',
#  'ACCATATCCGCAATAA': 'CL:0000186',
#  'ACCATCCGCCAACTAG': 'CL:0000584',
#  'ACCCAACGCCCGTGGC': 'CL:0000584',
#  'ACCCACCTACATGCTC': 'CL:0000186',
#  'ACCCATCTTGAGGGTA': 'CL:0000186',
#  'ACCCATTTGTCCCTCT': 'CL:0000584',
#  'ACCCGAGCGAAATTAC': 'CL:0000584',
#  'ACCCGATTGGTTCCGA': 'CL:0000584',
#  'ACCCGGAAACTCCCAG': 'CL:0000844',
#  'ACCCGGTTACACTTCC': 'CL:0000844',
#  'ACCCGTGTCATCAGTA': 'CL:0000844',
#  'ACCCTATGCCATATCG': 'CL:0000186',
#  'ACCCTCCCGTCAGGGC': 'CL:0000584',
#  'ACCCTCCCTTGCTATT': 'CL:0000584',
#  'ACCCTTCATCTGCGAA': 'CL:0000584',
#  'ACCCTTTAGTTCTCCA': 'CL:0000584',
#  'ACCGAAAGGGCCCTGC': 'CL:0000584',
#  'ACCGAAGAGTCTGGTT': 'CL:0000186',
#  'ACCGACTGAGTCCCAC': 'CL:0000584',
#  'ACCGATATTTAATCAT': 'CL:0000584',
#  'ACCGATGGTAGCATCG': 'CL:0000844',
#  'ACCGCGGTGGAAGTCG': 'CL:0000584',
#  'ACCGGGCCTTTGTTGA': 'CL:0009010',
#  'ACCGGTCAGGTACACC': 'CL:0000186',
#  'ACCGTGACCACGTGGG': 'CL:0000584',
#  'ACCGTTCCCGCTCTGA': 'CL:0000186',
#  'ACCTAAGTACCTTTCA': 'CL:0000584',
#  'ACCTACAGTATGTGGT': 'CL:0000584',
#  'ACCTACTATAAATCTA': 'CL:0000186',
#  'ACCTCCGCCCTCGCTG': 'CL:0000584',
#  'ACCTCCGTTATTCACC': 'CL:0000584',
#  'ACCTCGAACTTATGCT': 'CL:0000844',
#  'ACCTGCGTGTCATGTT': 'CL:0000584',
#  'ACGAAATGGGCGGCAC': 'CL:0000186',
#  'ACGACTCTAGGGCCGA': 'CL:0000584',
#  'ACGACTGGTCATACTC': 'CL:0000584',
#  'ACGAGAACCCATCACG': 'CL:0000584',
#  'ACGAGGATACCACTCT': 'CL:0000584',
#  'ACGAGTACGGATGCCC': 'CL:0000584',
#  'ACGATACATAGAACTA': 'CL:0000844',
#  'ACGATCATACATAGAG': 'CL:0000186',
#  'ACGATCATCTTGTAAA': 'CL:0000584',
#  'ACGATGCATATGTTAT': 'CL:0000057',
#  'ACGATGGATCCGATGC': 'CL:0000584',
#  'ACGCAAACTAATAGAT': 'CL:0000186',
#  'ACGCAATCACTACAGC': 'CL:0000584',
#  'ACGCCACTCGAAACAG': 'CL:0000584',
#  'ACGCCAGATGATTTCT': 'CL:0000186',
#  'ACGCCAGTGCGTTTGC': 'CL:0000584',
#  'ACGCCCAGCTGTCGAT': 'CL:0009010',
#  'ACGCCGCTAGACGACC': 'CL:0000584',
#  'ACGCGCTACACAGGGT': 'CL:0000584',
#  'ACGCGTTTCTTAAGAG': 'CL:0000186',
#  'ACGCTAGTGATACACT': 'CL:0000584',
#  'ACGCTGTGAGGCGTAG': 'CL:0000186',
#  'ACGCTTAGTGTCTCTC': 'CL:0000584',
#  'ACGGAACACGAGTGCC': 'CL:0000584',
#  'ACGGAATTTAGCAAAT': 'CL:0000584',
#  'ACGGACTCTCAAAGCG': 'CL:0000584',
#  'ACGGAGCGCAAATTAC': 'CL:0000584',
#  'ACGGATGGTGCGGATA': 'CL:0000844',
#  'ACGGCCAACATGGACT': 'CL:0000057',
#  'ACGGCTGGATGTAGAA': 'CL:0000186',
#  'ACGGGAGTGTCGGCCC': 'CL:0000584',
#  'ACGGTACAGTTCAATG': 'CL:0000584',
#  'ACGTACAGATTTCTCT': 'CL:0000844',
#  'ACGTACTTTGGCACGG': 'CL:0000584',
#  'ACGTAGGAGAGTCGCT': 'CL:0000584',
#  'ACGTATTACTCCGATC': 'CL:0000584',
#  'ACGTCTCGTTCCGGGA': 'CL:0000584',
#  'ACGTGACAAAGTAAGT': 'CL:0000057',
#  'ACGTGCGCCTCGTGCA': 'CL:0009010',
#  'ACGTGGTCGAATGTGC': 'CL:0000584',
#  'ACGTTAATGTCGAAGA': 'CL:0000584',
#  'ACGTTAGATTTGCCCG': 'CL:0000584',
#  'ACGTTATTGGTCACTC': 'CL:0000584',
#  'ACGTTCCGCGCTCCGT': 'CL:0000584',
#  'ACGTTCGTTCAGGAAA': 'CL:0000057',
#  'ACGTTTAGTTGTGATC': 'CL:0000584',
#  'ACTACAAAGAGAGGTG': 'CL:0000844',
#  'ACTACATCCCGACAAG': 'CL:0009010',
#  'ACTACGCGTTAGAATT': 'CL:0000844',
#  'ACTATATGCTGTGTTC': 'CL:0000584',
#  'ACTATCCAGGGCATGG': 'CL:0000584',
#  'ACTATCTGCCCGCGTA': 'CL:0000584',
#  'ACTATGTCCAGCTGCC': 'CL:0009010',
#  'ACTATTCGTCCGTGGT': 'CL:0000584',
#  'ACTATTTCCGGGCCCA': 'CL:0000186',
#  'ACTCAAGTGCAAGGCT': 'CL:0000584',
#  'ACTCAATAAAGGCACG': 'CL:0000186',
#  'ACTCAGACCTGCTTCT': 'CL:0000584',
#  'ACTCATGGCAGCCTTC': 'CL:0000584',
#  'ACTCCAATATCATCAT': 'CL:0000584',
#  'ACTCCCATTCCTAAAG': 'CL:0000584',
#  'ACTCCCGAATTCGTTT': 'CL:0000584',
#  'ACTCCCTAATGCTAAA': 'CL:0000844',
#  'ACTCCGGCCGACCACT': 'CL:0000584',
#  'ACTCGCCGTTCGATAA': 'CL:0000584',
#  'ACTCGCGATCTGACGC': 'CL:0009010',
#  'ACTCGTAACCCGTCCT': 'CL:0000584',
#  'ACTCGTCAGTAATCCC': 'CL:0000186',
#  'ACTCTCTGACTTAGGT': 'CL:0000584',
#  'ACTCTGACCTAATAGA': 'CL:0000584',
#  'ACTCTTCAGCTCCCGC': 'CL:0000584',
#  'ACTCTTGTATAGTAAC': 'CL:0000844',
#  'ACTGAAACGCCGTTAG': 'CL:0000584',
#  'ACTGAATGGCGAAAGT': 'CL:0000844',
#  'ACTGCCCGCCATTCTC': 'CL:0000584',
#  'ACTGCCGTCGTAACTC': 'CL:0000186',
#  'ACTGCGGACACACCGT': 'CL:0000584',
#  'ACTGCTCGGAAGGATG': 'CL:0000186',
#  'ACTGTACGATACACAT': 'CL:0000584',
#  'ACTGTAGCACTTTGGA': 'CL:0000186',
#  'ACTGTATACGCGAGCA': 'CL:0000584',
#  'ACTGTCCAGGATTATA': 'CL:0000844',
#  'ACTGTCTTCTTTAGAA': 'CL:0000844',
#  'ACTGTGCTAGTAGATC': 'CL:0000584',
#  'ACTTACCGGGCGCGCA': 'CL:0000584',
#  'ACTTACGCATCCACGC': 'CL:0000584',
#  'ACTTAGTACGACAAGA': 'CL:0000584',
#  'ACTTATACTTACCCGG': 'CL:0000057',
#  'ACTTATTAGGATCGGT': 'CL:0000186',
#  'ACTTATTTATGTGCCA': 'CL:0000584',
#  'ACTTCGCCATACGCAC': 'CL:0000057',
#  'ACTTCGCTAGCGAGTG': 'CL:0000584',
#  'ACTTGACTCCCTCTTT': 'CL:0000034',
#  'ACTTGGGACCCGGTGG': 'CL:0000844',
#  'ACTTGTAGTCCCTTCA': 'CL:0000186',
#  'ACTTGTGGATGGAACG': 'CL:0000584',
#  'ACTTGTTACCGGATCA': 'CL:0000844',
#  'ACTTTACCCTCATGAA': 'CL:0000584',
#  'ACTTTCCTATAGCTTC': 'CL:0000057',
#  'ACTTTGACTGCATCCT': 'CL:0000186',
#  'ACTTTGGTCGTGCTCC': 'CL:0000186',
#  'ACTTTGTCGACGCACT': 'CL:0009010',
#  'AGAAATTATGACTCGC': 'CL:0000584',
#  'AGAACCCAGCGTGACA': 'CL:0000584',
#  'AGAACGTGGTACATTC': 'CL:0000057',
#  'AGAACTGTACTTTGTA': 'CL:0000584',
#  'AGAAGAGCGCCGTTCC': 'CL:0000584',
#  'AGAAGGTACACTTCAC': 'CL:0000584',
#  'AGAAGGTTGCCGAATT': 'CL:0000584',
#  'AGAAGTGATTCGTGAT': 'CL:0000186',
#  'AGAATGCGGGTTCGGA': 'CL:0000844',
#  'AGAATTATGGATTCGA': 'CL:0000584',
#  'AGAATTGTTTGACATA': 'CL:0000584',
#  'AGACAGCTCAGAATCC': 'CL:0000844',
#  'AGACATAGATCCTTCC': 'CL:0000584',
#  'AGACCAAACCACACCT': 'CL:0000186',
#  'AGACCATGGGATACAA': 'CL:0000186',
#  'AGACCCGCCCTCCTCG': 'CL:0000584',
#  'AGACCGCTCCGCGGTT': 'CL:0000844',
#  'AGACCGGGAAACCCTG': 'CL:0000584',
#  'AGACGAAGTGCCGGTC': 'CL:0000584',
#  'AGACGACGATGCCGCT': 'CL:0000584',
#  'AGACGCCCACTTCGCC': 'CL:0000584',
#  'AGACTAGCCTTCCAGA': 'CL:0000584',
#  'AGACTGTTACCGGGTC': 'CL:0000186',
#  'AGAGAAACACCAGAAA': 'CL:0000584',
#  'AGAGAACCGTCTAGGA': 'CL:0000584',
#  'AGAGAAGGAGTACAAT': 'CL:0000584',
#  'AGAGATCTCTAAAGCG': 'CL:0000584',
#  'AGAGCGGGCTAATCAT': 'CL:0000584',
#  'AGAGCGTACAAGCTCG': 'CL:0000186',
#  'AGAGGCTTCGGAAACC': 'CL:0000584',
#  'AGAGTATAGTGTTACG': 'CL:0000584',
#  'AGATAACTTCAGGGCC': 'CL:0000584',
#  'AGATACCGGTGTTCAC': 'CL:0000584',
#  'AGATACGACTTCATAT': 'CL:0000584',
#  'AGATACTCAAGATCGA': 'CL:0000584',
#  'AGATATAATACGACTA': 'CL:0000584',
#  'AGATCGTGCATAAGAT': 'CL:0009010',
#  'AGATCTCAGGTGTGAT': 'CL:0000844',
#  'AGATGACTCGCCCACG': 'CL:0000186',
#  'AGATGAGGGTTGCGAT': 'CL:0000844',
#  'AGATGATGGAGTCTGG': 'CL:0000584',
#  'AGATGCAAGACGTGCA': 'CL:0000584',
#  'AGATGCATCCTGTGTC': 'CL:0000844',
#  'AGATTATAGGACGTTT': 'CL:0000584',
#  'AGATTCACAACCGATA': 'CL:0000584',
#  'AGCAACCGAAAGTAAT': 'CL:0000186',
#  'AGCACACGTTTAGACT': 'CL:0000584',
#  'AGCACCAGTACTCACG': 'CL:0000584',
#  'AGCACTTAAGGACGCC': 'CL:0000186',
#  'AGCAGAAGGAGAAAGA': 'CL:0000844',
#  'AGCAGCCAGATGAATA': 'CL:0000186',
#  'AGCATATCAATATGCT': 'CL:0000584',
#  'AGCATCATTTCGAAAG': 'CL:0000186',
#  'AGCATCGTCGATAATT': 'CL:0000186',
#  'AGCATTACGAGGCAAG': 'CL:0000584',
#  'AGCCAAGCTTTGTGTC': 'CL:0000584',
#  'AGCCACAGGTTACCCG': 'CL:0000584',
#  'AGCCACTCCCGTGCTT': 'CL:0000584',
#  'AGCCCATACATGTAAG': 'CL:0009010',
#  'AGCCCGCAACAAGCAG': 'CL:0000186',
#  'AGCCCGGCATTAGAGG': 'CL:0000186',
#  'AGCCCGGTAGCCTGTA': 'CL:0000584',
#  'AGCCCTAAGCGAAGTT': 'CL:0000584',
#  'AGCCCTCCCTGGTGGC': 'CL:0000584',
#  'AGCCCTGTCGCACCGT': 'CL:0009010',
#  'AGCCCTTCTAATCCGA': 'CL:0000584',
#  'AGCCCTTGGACATCCC': 'CL:0000584',
#  'AGCCGCAAATTCAAAT': 'CL:0000186',
#  'AGCCGTGGCTAAATGT': 'CL:0000584',
#  'AGCCTAATACCCACGT': 'CL:0000584',
#  'AGCCTTAAAGCGGAAG': 'CL:0009010',
#  'AGCGACAGGAACGGTC': 'CL:0000186',
#  'AGCGACATCCCATTCA': 'CL:0009010',
#  'AGCGACCAACGATATT': 'CL:0000584',
#  'AGCGAGACGTGAAGGC': 'CL:0000584',
#  'AGCGCATAATGAATCG': 'CL:0000057',
#  'AGCGCGGGTGCCAATG': 'CL:0000584',
#  'AGCGCTAGAGCGATGT': 'CL:0000584',
#  'AGCGCTTATGGGCAAG': 'CL:0000584',
#  'AGCGGACACTTCGTAG': 'CL:0000584',
#  'AGCGGGAAGGGTCCAT': 'CL:0000584',
#  'AGCGGGTCTGACACTC': 'CL:0000584',
#  'AGCGTGGTATTCTACT': 'CL:0000844',
#  'AGCTAACAAGCAATGT': 'CL:0000584',
#  'AGCTAAGTACGCAGGC': 'CL:0000584',
#  'AGCTAGAAGCAGAAGT': 'CL:0000584',
#  'AGCTATTTAATCCAAC': 'CL:0000186',
#  'AGCTCCATATATGTTC': 'CL:0000584',
#  'AGCTCCTTCGCACATC': 'CL:0000584',
#  'AGCTCTAGACGTTCCA': 'CL:0000186',
#  'AGCTCTTCCCAGTGCA': 'CL:0009010',
#  'AGCTCTTCGTAACCTT': 'CL:0000584',
#  'AGCTCTTTACTCAGTT': 'CL:0000186',
#  'AGCTGAAGTAAACCAA': 'CL:0009010',
#  'AGCTGTAACCTCAATC': 'CL:0000584',
#  'AGCTTCTTCTCGAGCA': 'CL:0000584',
#  'AGCTTGATCTTAACTT': 'CL:0000186',
#  'AGGAAGCTGTCCGCCG': 'CL:0000584',
#  'AGGACAGTCGAATCCC': 'CL:0000584',
#  'AGGACATCGCACGTCG': 'CL:0000584',
#  'AGGACGACCCATTAGA': 'CL:0000186',
#  'AGGACGCTCGATGTTG': 'CL:0000584',
#  'AGGAGACATCCACAGT': 'CL:0000584',
#  'AGGAGAGTCTGGCTAC': 'CL:0000584',
#  'AGGATATAGGGATTTA': 'CL:0000584',
#  'AGGATATCCGACTGCA': 'CL:0000584',
#  'AGGATCACGCGATCTG': 'CL:0000584',
#  'AGGATTGCTTACGACA': 'CL:0000584',
#  'AGGCACGTGACTGTCC': 'CL:0000584',
#  'AGGCAGATGCGTAAAC': 'CL:0000844',
#  'AGGCAGGGAGCGTACT': 'CL:0000057',
#  'AGGCATTGTCGTAGGG': 'CL:0000844',
#  'AGGCCACATTGGTTAC': 'CL:0000584',
#  'AGGCCACCCGTTATGA': 'CL:0000186',
#  'AGGCCCTAGAACGCCA': 'CL:0009010',
#  'AGGCCTATCATACCAA': 'CL:0000584',
#  'AGGCGGTTTGTCCCGC': 'CL:0000844',
#  'AGGCGTCTATGGACGG': 'CL:0000584',
#  'AGGCTATGGTTAGCTT': 'CL:0000186',
#  'AGGCTTCCCGAAGAAG': 'CL:0000844',
#  'AGGGAAACGAGGTACT': 'CL:0000584',
#  'AGGGACCGGCTGCGTT': 'CL:0000584',
#  'AGGGACTCTACGCGAC': 'CL:0000584',
#  'AGGGCGAGCAGCTGAT': 'CL:0000844',
#  'AGGGCGTGATCGGCTA': 'CL:0000584',
#  'AGGGTCAGAGCACTCG': 'CL:0009010',
#  'AGGGTCGATGCGAACT': 'CL:0000584',
#  'AGGGTGCCGTTCTTTA': 'CL:0000186',
#  'AGGGTGCTCTCGAGGG': 'CL:0000584',
#  'AGGGTGGATAGTGCAT': 'CL:0009010',
#  'AGGGTTCCCTTTGGTT': 'CL:0000584',
#  'AGGTAACCTCCTATTC': 'CL:0000186',
#  'AGGTACGATATTGCCA': 'CL:0000844',
#  'AGGTAGATCGAGATAT': 'CL:0000584',
#  'AGGTAGGTACAAAGCT': 'CL:0000186',
#  'AGGTATGCGGACATTA': 'CL:0000584',
#  'AGGTCAGGTGAGAGTG': 'CL:0000584',
#  'AGGTCGCGGAGTTACT': 'CL:0000584',
#  'AGGTGGTGACCTTCGC': 'CL:0000584',
#  'AGGTGTATCGCCATGA': 'CL:0000186',
#  'AGGTTACACCATGCCG': 'CL:0000584',
#  'AGGTTGAGGCACGCTT': 'CL:0000584',
#  'AGGTTTCACACACCTT': 'CL:0000584',
#  'AGTAATGTCTTGCCGC': 'CL:0000584',
#  'AGTACAGAAGCTTATA': 'CL:0009010',
#  'AGTACGGCCCGTATCG': 'CL:0000584',
#  'AGTACGGGCACCTGGC': 'CL:0000186',
#  'AGTACGTGGCCTGTCT': 'CL:0000186',
#  'AGTACTCTTATGCCCA': 'CL:0000584',
#  'AGTAGAAGGCGCCTCA': 'CL:0000844',
#  'AGTAGCGTGAACGAAC': 'CL:0000584',
#  'AGTAGGAAGGAAGTTG': 'CL:0000584',
#  'AGTAGGTAACATACAT': 'CL:0000584',
#  'AGTATAATACTAGGCA': 'CL:0000186',
#  'AGTATACACAGCGACA': 'CL:0000584',
#  'AGTATGCTGGAGACCA': 'CL:0000844',
#  'AGTATTTGGCACGACC': 'CL:0000844',
#  'AGTCAAATGATGTGAT': 'CL:0000186',
#  'AGTCAACACCACCATC': 'CL:0000844',
#  'AGTCAAGATGACACTT': 'CL:0000584',
#  'AGTCAGCCACCGCCTG': 'CL:0000584',
#  'AGTCCATTGGCTGATG': 'CL:0000584',
#  'AGTCCCGCCTTTAATT': 'CL:0000584',
#  'AGTCGACGGTCTCAAG': 'CL:0000844',
#  'AGTCGGCTCAACTTTA': 'CL:0000584',
#  'AGTCGGTTGCGTGAGA': 'CL:0000584',
#  'AGTCGTATAAAGCAGA': 'CL:0009010',
#  'AGTCGTCGACCACCAA': 'CL:0000844',
#  'AGTCGTGGGCATTACG': 'CL:0000584',
#  'AGTCTCACAAGACTAC': 'CL:0000844',
#  'AGTCTGGACATCCTTG': 'CL:0009010',
#  'AGTCTTCTCCTCAAAT': 'CL:0000186',
#  'AGTCTTTAAAGTGTCC': 'CL:0000186',
#  'AGTGAACAAACTTCTC': 'CL:0000584',
#  'AGTGACCTACTTTACG': 'CL:0000584',
#  'AGTGACTGTGACACAA': 'CL:0000186',
#  'AGTGAGACTTCCAGTA': 'CL:0000844',
#  'AGTGAGCCTCGCCGCC': 'CL:0000584',
#  'AGTGAGGGTTTCTGAC': 'CL:0000584',
#  'AGTGAGTCGAATTAAC': 'CL:0000584',
#  'AGTGATAACCTGCGCG': 'CL:0000584',
#  'AGTGATATGAGTAGTT': 'CL:0000186',
#  'AGTGATTCAAGCAGGA': 'CL:0000844',
#  'AGTGCACGCTTAAGAA': 'CL:0000584',
#  'AGTGCGTAGCTCGTAA': 'CL:0000186',
#  'AGTGCTAAACACAGCA': 'CL:0000584',
#  'AGTGCTTGCACGAATA': 'CL:0000186',
#  'AGTGGCCCGCAAATGG': 'CL:0000584',
#  'AGTGGCGGCAATTTGA': 'CL:0000844',
#  'AGTGGCTCCGTCGGCC': 'CL:0000186',
#  'AGTGGTGTTACCCGTG': 'CL:0000186',
#  'AGTGGTTGCGTATAGG': 'CL:0000584',
#  'AGTGTATTGCGCATTG': 'CL:0000584',
#  'AGTGTGGTCTATTGTG': 'CL:0000844',
#  'AGTTAAACACTTGCGA': 'CL:0000584',
#  'AGTTAAGCGGTCCCGG': 'CL:0000584',
#  'AGTTACCCTTAAGACT': 'CL:0000186',
#  'AGTTACTCTATCGTGG': 'CL:0000584',
#  'AGTTATTGAAAGGTAA': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000584',
#  'AGTTCCTATTTATGTT': 'CL:0000584',
#  'AGTTCTGCGTTGTATC': 'CL:0000584',
#  'AGTTGACATCGGCTGG': 'CL:0000584',
#  'AGTTGACGGTCCTTGC': 'CL:0000844',
#  'AGTTGCTGACTGATAT': 'CL:0009010',
#  'AGTTGGCAAGGCTAGA': 'CL:0000584',
#  'AGTTTATGTAAAGACA': 'CL:0000584',
#  'AGTTTCGCAGGTCGGA': 'CL:0000186',
#  'AGTTTGCACCTGCCTC': 'CL:0000584',
#  'AGTTTGGCACGGGTTG': 'CL:0000584',
#  'AGTTTGGCCAGACCTA': 'CL:0000844',
#  'ATAAACGGACCCGTAA': 'CL:0000584',
#  'ATAAACGTTGCACCAC': 'CL:0000584',
#  'ATAAAGGCTCGGTCGT': 'CL:0000584',
#  'ATAAAGGTCAAGTACG': 'CL:0000584',
#  'ATAAATATTAGCAGCT': 'CL:0000186',
#  'ATAACGCCGGAGGGTC': 'CL:0000844',
#  'ATAACGGAGTCCAACG': 'CL:0000186',
#  'ATAAGTAGGATTCAGA': 'CL:0000584',
#  'ATAAGTAGGGCGACTC': 'CL:0000584',
#  'ATAAGTTACCGCGACG': 'CL:0000584',
#  'ATAATACCGTTAGCCG': 'CL:0000584',
#  'ATAATAGCTGTTGAAT': 'CL:0000584',
#  'ATAATAGTGTAGGGAC': 'CL:0000584',
#  'ATAATCTTGGAGAACC': 'CL:0000584',
#  'ATAATTAGCTAAGTAG': 'CL:0000844',
#  'ATACAGGCCCTCCAAT': 'CL:0000186',
#  'ATACCACGGGCAACTT': 'CL:0000186',
#  'ATACCAGCAAATTGCT': 'CL:0000186',
#  'ATACCAGGCTAATAGA': 'CL:0000584',
#  'ATACCTAACCAAGAAA': 'CL:0000844',
#  'ATACGAAGGCTTTCCA': 'CL:0000584',
#  'ATACGCCGGCGAAACC': 'CL:0000844',
#  'ATACGGAACGTCGTTT': 'CL:0000186',
#  'ATACGGGTTTCGATTG': 'CL:0000584',
#  'ATACGGTGAAGATGCA': 'CL:0000584',
#  'ATACGTACTTAGCCAC': 'CL:0000584',
#  'ATACGTCCACTCCTGT': 'CL:0000584',
#  'ATACGTTATGCACGGA': 'CL:0000844',
#  'ATACTACCCGTACCAC': 'CL:0000584',
#  'ATACTAGCATGACCCT': 'CL:0009010',
#  'ATACTTGTTCTCGAGC': 'CL:0009010',
#  'ATAGACAACGGGACCT': 'CL:0000584',
#  'ATAGACGAAGAGAAAG': 'CL:0000844',
#  'ATAGAGTACTGGGACA': 'CL:0000584',
#  'ATAGAGTTATCAACTT': 'CL:0000584',
#  'ATAGCAACTAGGGAAG': 'CL:0009010',
#  'ATAGGCGGCTATAGAA': 'CL:0000160',
#  'ATAGGCTAGCTTCGCA': 'CL:0000584',
#  'ATAGGGATATCCTTGA': 'CL:0000584',
#  'ATAGGTTGGGCAGATG': 'CL:0000584',
#  'ATAGTCTTTGACGTGC': 'CL:0000584',
#  'ATAGTGAAGCGTTCTC': 'CL:0000186',
#  'ATATAAAGCGCTCGTG': 'CL:0000844',
#  'ATATACGCTCGTGACG': 'CL:0000584',
#  'ATATCAACCTACAGAG': 'CL:0000584',
#  'ATATCAATTCCAGCCT': 'CL:0000584',
#  'ATATCGGTAGGGAGAT': 'CL:0009010',
#  'ATATCGTGCCAGACCC': 'CL:0000584',
#  'ATATCGTTCCTCGAAC': 'CL:0000584',
#  'ATATCTCCCTCGTTAA': 'CL:0000186',
#  'ATATGGGATAGCAACT': 'CL:0000844',
#  'ATATGTCTCCCTAGCC': 'CL:0000584',
#  'ATATTCAGTTAAACCT': 'CL:0000584',
#  'ATATTGCTGTCAAAGT': 'CL:0000186',
#  'ATATTTAACCCTCAAG': 'CL:0000057',
#  'ATCAAAGAGCCGTGGT': 'CL:0000186',
#  'ATCAATGCCGTGGCTG': 'CL:0000186',
#  'ATCACATTAGAATATC': 'CL:0000844',
#  'ATCACGTGCTAATTAA': 'CL:0000057',
#  'ATCACTTCATCCTCGC': 'CL:0000584',
#  'ATCAGACGGCACGCCG': 'CL:0000584',
#  'ATCAGCCTCATGCTGC': 'CL:0000584',
#  'ATCAGCTCGTCCACTA': 'CL:0000584',
#  'ATCAGGTAGCTGACAG': 'CL:0000584',
#  'ATCAGGTCGCCATTGC': 'CL:0000844',
#  'ATCAGTAGGCAGGGAT': 'CL:0000584',
#  'ATCATAGATCGACGAG': 'CL:0000584',
#  'ATCATAGCCCTATGTA': 'CL:0000584',
#  'ATCATCCAATATTTGT': 'CL:0000844',
#  'ATCATGGACTACCGAC': 'CL:0000584',
#  'ATCCAATGGAGGGTCC': 'CL:0000584',
#  'ATCCAATGGTACCGAA': 'CL:0000186',
#  'ATCCACATCGACAGAA': 'CL:0000584',
#  'ATCCACGCTAAATGTT': 'CL:0000186',
#  'ATCCAGAGCAACAACC': 'CL:0000186',
#  'ATCCAGGATTCGTGAA': 'CL:0000186',
#  'ATCCCATCCACAGCGC': 'CL:0000186',
#  'ATCCCATTTCCGTGGG': 'CL:0000584',
#  'ATCCTGAATCGCTGCG': 'CL:0000186',
#  'ATCCTGCGTGGAATGG': 'CL:0000186',
#  'ATCCTGCTGCAGATAG': 'CL:0000584',
#  'ATCGACCCAATACAGA': 'CL:0000034',
#  'ATCGACTCTTTCCGTT': 'CL:0000584',
#  'ATCGCCAGTCAACATT': 'CL:0000584',
#  'ATCGCTGCGTGCAGCA': 'CL:0000584',
#  'ATCGCTTTACGTCTCA': 'CL:0000584',
#  'ATCGGCAAGCAGTCCA': 'CL:0009010',
#  'ATCGGTTACCTAGTAA': 'CL:0009010',
#  'ATCGTATTCCGAGAAC': 'CL:0000844',
#  'ATCGTGGAAAGTCTGG': 'CL:0000186',
#  'ATCGTTAGCTAGCGGA': 'CL:0000584',
#  'ATCGTTCACTTTCGCC': 'CL:0000584',
#  'ATCTAATATCCTACGG': 'CL:0000844',
#  'ATCTACCATCTGCTCC': 'CL:0000584',
#  'ATCTAGCTTGTGAGGG': 'CL:0000844',
#  'ATCTCCCTGCAATCTA': 'CL:0000186',
#  'ATCTCGTGAGCGAAAC': 'CL:0000584',
#  'ATCTGACATGGAAGGA': 'CL:0000844',
#  'ATCTGCACCTCTGCGA': 'CL:0000584',
#  'ATCTGCTGTTATCGCC': 'CL:0000844',
#  'ATCTGGTTAAGACTGT': 'CL:0000057',
#  'ATCTTATCGCACACCC': 'CL:0009010',
#  'ATCTTGACCTGCAACG': 'CL:0000186',
#  'ATCTTGACTTGTCCAA': 'CL:0000584',
#  'ATCTTTCGTATAACCA': 'CL:0000584',
#  'ATGAAGCCAAGGAGCC': 'CL:0009010',
#  'ATGAAGTGGACCCAGC': 'CL:0000186',
#  'ATGACGCCGGCTCTAA': 'CL:0000584',
#  'ATGACGCGTTCTATCC': 'CL:0000584',
#  'ATGACTATCAGCTGTG': 'CL:0000584',
#  'ATGACTATGCGACATT': 'CL:0000584',
#  'ATGAGGAGTGTTAATC': 'CL:0000186',
#  'ATGAGGGCAGCGGCTA': 'CL:0000844',
#  'ATGATCGGGAATAGAC': 'CL:0000584',
#  'ATGATGCAATGGTACA': 'CL:0000186',
#  'ATGCACGCGCTGTTCA': 'CL:0000186',
#  'ATGCACTACCGCATTG': 'CL:0000844',
#  'ATGCATGATCCAGGAT': 'CL:0000186',
#  'ATGCCAATCGCTCTGC': 'CL:0000584',
#  'ATGCCATTTGCGACCA': 'CL:0000584',
#  'ATGCCGGTCTTGCATA': 'CL:0000844',
#  'ATGCCGGTTGATGGGA': 'CL:0000186',
#  'ATGCGACAATTGGTCC': 'CL:0000584',
#  'ATGCTCAGTGTTGCAT': 'CL:0000186',
#  'ATGCTTAGGAGTTGAT': 'CL:0009010',
#  'ATGGAAATTTAAGGAG': 'CL:0000186',
#  'ATGGAACCTTTGCACA': 'CL:0000584',
#  'ATGGATCCGGCGTCCG': 'CL:0000186',
#  'ATGGATTGACCAAACG': 'CL:0000584',
#  'ATGGCAGCATTACGAT': 'CL:0009010',
#  'ATGGCAGCCGAGAAAC': 'CL:0000584',
#  'ATGGCGGAATAGTCGC': 'CL:0000584',
#  'ATGGCTGGAAATGGCC': 'CL:0000584',
#  'ATGGGACCTGCTGAAC': 'CL:0000584',
#  'ATGGGCCTCGGCCTCT': 'CL:0000584',
#  'ATGGGTGTATACCTCC': 'CL:0000186',
#  'ATGGTCGCGTGGTTTC': 'CL:0000844',
#  'ATGTACGATGACGTCG': 'CL:0000584',
#  'ATGTGAAAGCCTAATG': 'CL:0009010',
#  'ATGTGCATCCGACGCA': 'CL:0000584',
#  'ATGTGGACATCTTGAT': 'CL:0000584',
#  'ATGTGTAGTTTAGTCA': 'CL:0000584',
#  'ATGTTACGAGCAATAC': 'CL:0000584',
#  'ATGTTCGTCGACCCAC': 'CL:0000584',
#  'ATGTTGATTAGAGACT': 'CL:0000584',
#  'ATGTTGTAGTCTGTTT': 'CL:0000844',
#  'ATGTTTCGGCCCGGAG': 'CL:0000584',
#  'ATTAAACATGCGGACC': 'CL:0000034',
#  'ATTAATGAACCAGTCG': 'CL:0000186',
#  'ATTAATTCGGTCACTC': 'CL:0000584',
#  'ATTACAACTACCGGCC': 'CL:0000584',
#  'ATTACATGTCAGTCTT': 'CL:0000584',
#  'ATTACCACACTGCCTG': 'CL:0000584',
#  'ATTACGCGCTGGCAGG': 'CL:0000584',
#  'ATTACTAGCCTCTTGC': 'CL:0000584',
#  'ATTACTTACTGGGCAT': 'CL:0000584',
#  'ATTAGATTGATAGCGG': 'CL:0000584',
#  'ATTAGGCGATGCTTTC': 'CL:0000057',
#  'ATTATACTTTGCTCGT': 'CL:0000186',
#  'ATTATCGGAATGTACG': 'CL:0000584',
#  'ATTATCTCGACAGATC': 'CL:0000186',
#  'ATTATGCCATAGGGAG': 'CL:0000584',
#  'ATTATTATGTCCGTCA': 'CL:0009010',
#  'ATTATTCAGAGTCACT': 'CL:0000584',
#  'ATTCAACCATTTAAGG': 'CL:0000584',
#  'ATTCACTGATGTTGGA': 'CL:0000844',
#  'ATTCAGGACCTATTTC': 'CL:0009010',
#  'ATTCATATACTGTCCA': 'CL:0000844',
#  'ATTCCCACATAAACAA': 'CL:0000186',
#  'ATTCCTAAGACGTGGA': 'CL:0000584',
#  'ATTCCTCCGCCAGTGC': 'CL:0000186',
#  'ATTCGACGCCGGGCCT': 'CL:0000186',
#  'ATTCGTGCTATCTCTT': 'CL:0000584',
#  'ATTCTCGTCTCTTTAG': 'CL:0000584',
#  'ATTCTGAGTATGAACT': 'CL:0000584',
#  'ATTCTTCGTACTTATG': 'CL:0000584',
#  'ATTGAAGATCTTAGTG': 'CL:0000584',
#  'ATTGACGTAACTCGGT': 'CL:0000584',
#  'ATTGATCACCACATTT': 'CL:0000186',
#  'ATTGATGAGTCCTAAC': 'CL:0000584',
#  'ATTGCCTTTATGTTTG': 'CL:0000584',
#  'ATTGCTGCTCCTCCAT': 'CL:0000584',
#  'ATTGGGAATATCTTGG': 'CL:0000186',
#  'ATTGTACAACTCGGCT': 'CL:0000584',
#  'ATTGTCGCAATACCTT': 'CL:0000584',
#  'ATTGTCTGTTTCATGT': 'CL:0000584',
#  'ATTGTTCAACGATCCG': 'CL:0009010',
#  'ATTTAACTCGTATTAC': 'CL:0000584',
#  'ATTTACAGTTTACTGG': 'CL:0000584',
#  'ATTTATACTGGTAAAG': 'CL:0000584',
#  'ATTTCATTATTTCGCG': 'CL:0000584',
#  'ATTTCCGGGTTCTGCG': 'CL:0000584',
#  'ATTTGCGCGAGTAGCT': 'CL:0000844',
#  'ATTTGTCTTGGGAGCT': 'CL:0000584',
#  'ATTTGTTCCAGGGCTC': 'CL:0000186',
#  'CAAACCAGGTCTGCAT': 'CL:0000584',
#  'CAAACCCTCCGGCGGG': 'CL:0000584',
#  'CAAACGAGTATCGCAG': 'CL:0000057',
#  'CAAACGGTCGCACTTT': 'CL:0000584',
#  'CAAACGTGGTCTTGCG': 'CL:0000186',
#  'CAAACTACGATAGAGA': 'CL:0000584',
#  'CAAACTATTGAGCTTC': 'CL:0000584',
#  'CAAACTCGCGACGCCG': 'CL:0000584',
#  'CAAAGATTATTGGGCC': 'CL:0000844',
#  'CAAAGGTCATCTGAAA': 'CL:0000584',
#  'CAAATCTCTCACAAGG': 'CL:0000584',
#  'CAAATGTCCTTCCGTG': 'CL:0000584',
#  'CAAATTGTCAGCAAGC': 'CL:0000584',
#  'CAACACATCTCCTGCC': 'CL:0000584',
#  'CAACCAGTGGCCTACC': 'CL:0009010',
#  'CAACCTACCGAGCAGT': 'CL:0000186',
#  'CAACCTGAACCTGCCA': 'CL:0000584',
#  'CAACGACCCGTTTACA': 'CL:0000584',
#  'CAACGGTTCTTGATAC': 'CL:0000584',
#  'CAACGTGGTGGAGTCT': 'CL:0000584',
#  'CAACTATATCGAATGC': 'CL:0000584',
#  'CAACTCCAACGTTTAG': 'CL:0000584',
#  'CAACTCCTTGATCCCG': 'CL:0000584',
#  'CAACTGCTCATCCGAT': 'CL:0000844',
#  'CAACTTGTAGTGGGCA': 'CL:0000584',
#  'CAAGACTCAGAAGCGC': 'CL:0000584',
#  'CAAGAGGGCGGAGTAC': 'CL:0000584',
#  'CAAGATATTATAACGT': 'CL:0000584',
#  'CAAGCAACGTCGGAGT': 'CL:0000584',
#  'CAAGGATCGCATGTTC': 'CL:0000034',
#  'CAAGGCCAGTGGTGCA': 'CL:0000584',
#  'CAAGGTCCTATAGGCT': 'CL:0000584',
#  'CAAGTAAGTGATAGAC': 'CL:0000584',
#  'CAAGTGAACTTTGGTT': 'CL:0000844',
#  'CAAGTGTGGTTGCAAA': 'CL:0000584',
#  'CAATAAACCTTGGCCC': 'CL:0000584',
#  'CAATACGAGAGTCTGA': 'CL:0000584',
#  'CAATACGCTCTGAGGC': 'CL:0000186',
#  'CAATATTCTTGACCTA': 'CL:0000844',
#  'CAATCCCTATACCAGC': 'CL:0000584',
#  'CAATGACCCTTAATTT': 'CL:0000584',
#  'CAATGCGAGAAGTATC': 'CL:0000584',
#  'CAATGGAATCTACATA': 'CL:0000584',
#  'CAATGGATCTCTACCA': 'CL:0000844',
#  'CAATGGTCGGCCTGGG': 'CL:0009010',
#  'CAATTAAGGGTGATGA': 'CL:0000584',
#  'CAATTGGGCCGCACTC': 'CL:0000186',
#  'CAATTTCGTATAAGGG': 'CL:0000057',
#  'CACAAGCTAAGAAAGG': 'CL:0000584',
#  'CACAATGAGCTGCTAT': 'CL:0000584',
#  'CACACAGCTTGCGCTC': 'CL:0000584',
#  'CACACAGGGATAGATT': 'CL:0000186',
#  'CACACGCGCTGTCTTA': 'CL:0000584',
#  'CACACGTTTCAATGGG': 'CL:0000584',
#  'CACAGAGACGAGGACG': 'CL:0009010',
#  'CACAGCACCCACGGCA': 'CL:0000584',
#  'CACAGCTAGGGAGTGA': 'CL:0000186',
#  'CACAGGGCCGTTGTCA': 'CL:0000186',
#  'CACAGTTCGCTTCCCA': 'CL:0000584',
#  'CACATATTAGCAGGAT': 'CL:0000584',
#  'CACATCGTGCACGCGC': 'CL:0000584',
#  'CACATCTCACCGACGA': 'CL:0000584',
#  'CACATGATTCAGCAAC': 'CL:0000584',
#  'CACATTCTTTCGATGG': 'CL:0000584',
#  'CACATTTCTTGTCAGA': 'CL:0000844',
#  'CACCAATCATCCGTCT': 'CL:0000584',
#  'CACCACGCCACACAGA': 'CL:0000584',
#  'CACCAGTCAGCATGCA': 'CL:0000584',
#  'CACCATCGGAGGAGAC': 'CL:0000186',
#  'CACCCAAATCTTATGT': 'CL:0000584',
#  'CACCCACACGTCACCC': 'CL:0000584',
#  'CACCCACGAGGCAATT': 'CL:0000186',
#  'CACCCGGTTTGTGACT': 'CL:0000844',
#  'CACCCTAACAAGATCT': 'CL:0000844',
#  'CACCCTTGGTGAGACC': 'CL:0000584',
#  'CACCCTTTCCTCGCTC': 'CL:0000584',
#  'CACCGATACACCGAGC': 'CL:0000584',
#  'CACCGCCAGAAGGTTT': 'CL:0000584',
#  'CACCGCCGACCAGCGA': 'CL:0000584',
#  'CACCGCGTCCACTCTA': 'CL:0000584',
#  'CACCGGAGATATCTCC': 'CL:0000584',
#  'CACCGGGCATCACAAG': 'CL:0000584',
#  'CACCGGTAGAGACATT': 'CL:0000584',
#  'CACCGTTAGGGATCAC': 'CL:0000186',
#  'CACCGTTGCGCGATAT': 'CL:0000186',
#  'CACCTAATAGAGTCGT': 'CL:0000584',
#  'CACCTAATCAGTTTAC': 'CL:0000844',
#  'CACCTCGATGGTGGAC': 'CL:0000186',
#  'CACCTTGCGAAACTCG': 'CL:0000186',
#  'CACCTTGGCGCCTTTG': 'CL:0000584',
#  'CACGAAAGTTAGTCCC': 'CL:0000186',
#  'CACGCACAGCGCAGCT': 'CL:0000186',
#  'CACGCAGCGAGGCTTT': 'CL:0000844',
#  'CACGCGGAACTGTTGC': 'CL:0000584',
#  'CACGGCGCGCCAAAGG': 'CL:0000584',
#  'CACGGGATTGAGGGTT': 'CL:0000584',
#  'CACGTCGGCAACCTCT': 'CL:0000186',
#  'CACGTCTATGATGTGG': 'CL:0000584',
#  'CACGTTCGTGCTCTAG': 'CL:0000584',
#  'CACGTTTCGTACACAC': 'CL:0000844',
#  'CACTAAAGTTGCCTAT': 'CL:0000584',
#  'CACTACGGGAGCTGCC': 'CL:0009010',
#  'CACTACTCAGTTCTGT': 'CL:0000584',
#  'CACTCAAGAGCTATGG': 'CL:0000186',
#  'CACTCAGCTCTTGAGG': 'CL:0000844',
#  'CACTCCTATGTAAGAT': 'CL:0000584',
#  'CACTCCTCTCGGTCGG': 'CL:0000584',
#  'CACTCGGTTAGGAGGA': 'CL:0000584',
#  'CACTCTTCTGCTAGCC': 'CL:0000584',
#  'CACTGACGATTGTGGA': 'CL:0000844',
#  'CACTGTCCAAGTGAGA': 'CL:0000584',
#  'CACTTAATCAGACGGA': 'CL:0000584',
#  'CACTTCGCCACAGGCT': 'CL:0000057',
#  'CAGAACTTAGCCCTCT': 'CL:0000584',
#  'CAGAATAACACACGGA': 'CL:0000584',
#  'CAGAATATTCGTTATC': 'CL:0000584',
#  'CAGACACCGATCGCTG': 'CL:0000844',
#  'CAGACCTGTAAGTGTT': 'CL:0000584',
#  'CAGACGAACCTGATAC': 'CL:0000186',
#  'CAGAGCATGAGCTTGC': 'CL:0000584',
#  'CAGAGGCGATGCATGA': 'CL:0000057',
#  'CAGAGTGATTTAACGT': 'CL:0000584',
#  'CAGATAATGGGCGGGT': 'CL:0000584',
#  'CAGATACTAACATAGT': 'CL:0009010',
#  'CAGATATGAAGATGAC': 'CL:0000584',
#  'CAGATCATTTAAAGTC': 'CL:0000584',
#  'CAGATCCTGGTTTGAA': 'CL:0000186',
#  'CAGCAGCCCGTTCCTT': 'CL:0000057',
#  'CAGCAGTCCAGACTAT': 'CL:0000584',
#  'CAGCAGTCTGTGCTGC': 'CL:0000584',
#  'CAGCCCTCACAGGCAG': 'CL:0000186',
#  'CAGCCGGGCCCTCTAT': 'CL:0000584',
#  'CAGCCTCCTGCAGAGG': 'CL:0000186',
#  'CAGCCTCTCCTCAAGA': 'CL:0000584',
#  'CAGCGATTCCCTTCAA': 'CL:0000844',
#  'CAGCGCCAACACGATA': 'CL:0000186',
#  'CAGCTCGACAAGTTAA': 'CL:0000057',
#  'CAGCTCGTGCTTGTGT': 'CL:0000584',
#  'CAGCTCTGGGCTCACT': 'CL:0000186',
#  'CAGCTGGCGTAACCGT': 'CL:0000584',
#  'CAGGAAGACTTTATAT': 'CL:0000584',
#  'CAGGATATATCGTTGT': 'CL:0000186',
#  'CAGGCAGTCTTACCAG': 'CL:0000186',
#  'CAGGCCGTTTGGGTGT': 'CL:0000584',
#  'CAGGCGCACGGTGGTC': 'CL:0000186',
#  'CAGTAACTATTTATTG': 'CL:0000584',
#  'CAGTAATCCCTCCCAG': 'CL:0000584',
#  'CAGTACATTCTCTAAA': 'CL:0000584',
#  'CAGTACCAGTTTACGT': 'CL:0000584',
#  'CAGTAGCCCACGCGGT': 'CL:0000584',
#  'CAGTCGAGGATGCAAT': 'CL:0009010',
#  'CAGTCGGCCTAGATAT': 'CL:0000584',
#  'CAGTCTGTATACTGGG': 'CL:0000186',
#  'CAGTGAATAAATGACT': 'CL:0000584',
#  'CAGTGGTTGCACATGA': 'CL:0000584',
#  'CAGTGTCCGCAGAATG': 'CL:0000584',
#  'CAGTGTCGGCTGGCCC': 'CL:0000844',
#  'CAGTTCAAATTGACAC': 'CL:0000584',
#  'CAGTTCCGCGGGTCGA': 'CL:0000186',
#  'CAGTTCGAGGACCCGA': 'CL:0000584',
#  'CATAACGGACAGTCGT': 'CL:0000584',
#  'CATAAGAAGCTTGGCT': 'CL:0000584',
#  'CATAAGCTCTCCGTCT': 'CL:0000584',
#  'CATACACGGTTCCCAC': 'CL:0000844',
#  'CATACCCGTACCCAGT': 'CL:0000186',
#  'CATACGAACTAGCTGG': 'CL:0000186',
#  'CATACGGCGTCTGGGC': 'CL:0000584',
#  'CATACTATGTAATTGT': 'CL:0000584',
#  'CATACTTAGGCAATAC': 'CL:0000584',
#  'CATACTTCTTTCTCCG': 'CL:0000186',
#  'CATAGAGGAGATACTA': 'CL:0000584',
#  'CATAGCCGCCCGGGAT': 'CL:0000584',
#  'CATAGCGTTGCCCACC': 'CL:0000584',
#  'CATAGTACATTGAGAG': 'CL:0000584',
#  'CATAGTAGCATAGTAG': 'CL:0000584',
#  'CATAGTCCACAAGAAC': 'CL:0000160',
#  'CATATACTACTGATAA': 'CL:0000584',
#  'CATATAGGTACAGTCA': 'CL:0000584',
#  'CATATGTCAGGCTACG': 'CL:0000584',
#  'CATCATCTACCCGGAC': 'CL:0000844',
#  'CATCATTACCCTGAGG': 'CL:0009010',
#  'CATCCAATATAGTTTG': 'CL:0000584',
#  'CATCCTCTCAAAGATC': 'CL:0000584',
#  'CATCGCCCGCGGCCAA': 'CL:0000584',
#  'CATCGGACGGGTTAAT': 'CL:0000186',
#  'CATCGTCCGGTTACTA': 'CL:0000584',
#  'CATCTAGTGAAGGGAA': 'CL:0009010',
#  'CATCTATCCCGTGTCT': 'CL:0000584',
#  'CATCTGCAGGATCATT': 'CL:0000186',
#  'CATCTTACACCACCTC': 'CL:0000584',
#  'CATGAACCTCTTATCA': 'CL:0000584',
#  'CATGACTTCGCTGAAT': 'CL:0000584',
#  'CATGATACGGTGAAAC': 'CL:0009010',
#  'CATGATGCACAATTCT': 'CL:0000584',
#  'CATGATGGAAGTTAGC': 'CL:0000584',
#  'CATGCATGGAGACCCT': 'CL:0000584',
#  'CATGCCAACTCGCAAA': 'CL:0007011',
#  'CATGCGACCAGTTTAA': 'CL:0000584',
#  'CATGCGTTAGACAGAA': 'CL:0000584',
#  'CATGCTGGCTCCAATT': 'CL:0000186',
#  'CATGGATTGTCTTCCG': 'CL:0000584',
#  'CATGGCAGGAAGATCG': 'CL:0009010',
#  'CATGGGTATGCCTTAT': 'CL:0000584',
#  'CATGGGTCGGGTGTGG': 'CL:0000584',
#  'CATGGTAAGTAGCGTT': 'CL:0000584',
#  'CATGGTCTAGATACCG': 'CL:0000584',
#  'CATGGTTTATTAATCA': 'CL:0000584',
#  'CATGTAAGAGACATTT': 'CL:0000584',
#  'CATGTAGGAGCGCCAA': 'CL:0000584',
#  'CATGTGGGCTCATCAC': 'CL:0000584',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1741
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5268
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             2359
# AAACACCAATAACTGC-1        1.0       59.0       59.0             5172
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             6671
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4384
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5892
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             6852
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             3744
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             5837
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0000584
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                 CL:0000844
# AAACAGAGCGACTCCT-1                 CL:0000584
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000186
# TTGTTTCATTAGTCTA-1                 CL:0000844
# TTGTTTCCATACAACT-1                 CL:0000584
# TTGTTTGTATTACACG-1                 CL:0000584
# TTGTTTGTGTAAATTC-1                 CL:0009010
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 1764

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_1265/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1741
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5268
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             2359
# AAACACCAATAACTGC-1        1.0       59.0       59.0             5172
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             6671
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4384
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5892
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             6852
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             3744
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             5837
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0000584
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                 CL:0000844
# AAACAGAGCGACTCCT-1                 CL:0000584
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000186
# TTGTTTCATTAGTCTA-1                 CL:0000844
# TTGTTTCCATACAACT-1                 CL:0000584
# TTGTTTGTATTACACG-1                 CL:0000584
# TTGTTTGTGTAAATTC-1                 CL:0009010
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000584',
#  'CL:0000844',
#  'CL:0000186',
#  'CL:0009010',
#  'CL:0000034',
#  'CL:0000057',
#  'CL:0000160',
#  'CL:0007011',
#  'CL:0000235',
#  'CL:0002461']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    2A_Hh
# AAACAAGTATCTCCCA-1    2A_Hh
# AAACAATCTACTAGCA-1    2A_Hh
# AAACACCAATAACTGC-1    2A_Hh
# AAACAGAGCGACTCCT-1    2A_Hh
#                       ...
# TTGTTTCACATCCAGG-1    2A_Hh
# TTGTTTCATTAGTCTA-1    2A_Hh
# TTGTTTCCATACAACT-1    2A_Hh
# TTGTTTGTATTACACG-1    2A_Hh
# TTGTTTGTGTAAATTC-1    2A_Hh
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['2A_Hh']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1741
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5268
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             2359
# AAACACCAATAACTGC-1        1.0       59.0       59.0             5172
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             6671
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4384
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5892
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             6852
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             3744
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             5837
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1                    unknown    2A_Hh
# AAACAAGTATCTCCCA-1                 CL:0000584    2A_Hh
# AAACAATCTACTAGCA-1                    unknown    2A_Hh
# AAACACCAATAACTGC-1                 CL:0000844    2A_Hh
# AAACAGAGCGACTCCT-1                 CL:0000584    2A_Hh
# ...                                       ...      ...
# TTGTTTCACATCCAGG-1                 CL:0000186    2A_Hh
# TTGTTTCATTAGTCTA-1                 CL:0000844    2A_Hh
# TTGTTTCCATACAACT-1                 CL:0000584    2A_Hh
# TTGTTTGTATTACACG-1                 CL:0000584    2A_Hh
# TTGTTTGTGTAAATTC-1                 CL:0009010    2A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255055_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'lowres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'tissue_lowres_scalef': 0.019862289,
#                  'fiducial_diameter_fullres': 230.64387598645098,
#                  'spot_diameter_fullres': 142.7795422773268}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255055_mm10-2020-A/V12Y31-030_C1.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '2A_Hh'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255055_mm10-2020-A': {'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'fullres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 142.7795422773268}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '2A_Hh'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1741
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5268
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             2359
# AAACACCAATAACTGC-1        1.0       59.0       59.0             5172
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             6671
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4384
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5892
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             6852
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             3744
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             5837
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1                    unknown    2A_Hh
# AAACAAGTATCTCCCA-1                 CL:0000584    2A_Hh
# AAACAATCTACTAGCA-1                    unknown    2A_Hh
# AAACACCAATAACTGC-1                 CL:0000844    2A_Hh
# AAACAGAGCGACTCCT-1                 CL:0000584    2A_Hh
# ...                                       ...      ...
# TTGTTTCACATCCAGG-1                 CL:0000186    2A_Hh
# TTGTTTCATTAGTCTA-1                 CL:0000844    2A_Hh
# TTGTTTCCATACAACT-1                 CL:0000584    2A_Hh
# TTGTTTGTATTACACG-1                 CL:0000584    2A_Hh
# TTGTTTGTGTAAATTC-1                 CL:0009010    2A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255055_mm10-2020-A': {'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'fullres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 142.7795422773268}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '2A_Hh'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_1265/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13255055.h5ad', compression = 'gzip')

# %%
adata.obs

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())

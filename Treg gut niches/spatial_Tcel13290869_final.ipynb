# %% [markdown]
# ### **Curating Tcel13290869**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290869_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 21402311 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 63)	1.0
#   (0, 118)	1.0
#   (0, 193)	1.0
#   (0, 198)	1.0
#   (0, 234)	1.0
#   (0, 257)	1.0
#   (0, 296)	1.0
#   (0, 446)	1.0
#   (0, 504)	2.0
#   (0, 521)	2.0
#   (0, 537)	1.0
#   (0, 542)	1.0
#   (0, 580)	1.0
#   (0, 585)	1.0
#   (0, 696)	1.0
#   (0, 819)	1.0
#   (0, 934)	1.0
#   (0, 1008)	1.0
#   (0, 1065)	1.0
#   (0, 1177)	1.0
#   (0, 1217)	1.0
#   (0, 1311)	1.0
#   (0, 1322)	1.0
#   (0, 1329)	1.0
#   (0, 1425)	1.0
#   :	:
#   (4991, 30754)	1.0
#   (4991, 30853)	2.0
#   (4991, 30854)	1.0
#   (4991, 30859)	2.0
#   (4991, 30873)	1.0
#   (4991, 30875)	1.0
#   (4991, 30878)	1.0
#   (4991, 30974)	1.0
#   (4991, 30991)	1.0
#   (4991, 31032)	1.0
#   (4991, 31080)	5.0
#   (4991, 31083)	1.0
#   (4991, 31186)	1.0
#   (4991, 31191)	1.0
#   (4991, 31271)	1.0
#   (4991, 31440)	1.0
#   (4991, 31450)	10.0
#   (4991, 32196)	3.0
#   (4991, 32197)	12.0
#   (4991, 32198)	7.0
#   (4991, 32200)	14.0
#   (4991, 32201)	25.0
#   (4991, 32202)	1.0
#   (4991, 32204)	2.0
#   (4991, 32207)	2.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              502
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5479
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             1137
# AAACACCAATAACTGC-1        1.0       59.0       59.0             7597
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4820
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5928
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             5305
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             4907
# TTGTTTGTGTAAATTC-1        0.0        7.0        7.0             1382
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13290869_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACACCAATAACTGC-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGGGTCTATATT-1        1.0  3B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCCATACAACT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTGTATTACACG-1        1.0  3B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1               5479
# Mus_Tcel13290869_AAACACCAATAACTGC-1               7597
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1               7610
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1               4206
# Mus_Tcel13290869_AAACAGGGTCTATATT-1               6782
# ...                                                ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1               3728
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1               5942
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1               4820
# Mus_Tcel13290869_TTGTTTCCATACAACT-1               5305
# Mus_Tcel13290869_TTGTTTGTATTACACG-1               4907
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                 8.608860       23726.0
# Mus_Tcel13290869_AAACACCAATAACTGC-1                 8.935640       46612.0
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                 8.937350       44794.0
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                 8.344505       18791.0
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                 8.822175       33615.0
# ...                                                      ...           ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                 8.223895       14173.0
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                 8.689969       30684.0
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                 8.480737       18295.0
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                 8.576593       19741.0
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                 8.498622       21920.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1           10.074368
# Mus_Tcel13290869_AAACACCAATAACTGC-1           10.749635
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1           10.709852
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1            9.841187
# Mus_Tcel13290869_AAACAGGGTCTATATT-1           10.422757
# ...                                                 ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1            9.559165
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1           10.331530
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1            9.814438
# Mus_Tcel13290869_TTGTTTCCATACAACT-1            9.890504
# Mus_Tcel13290869_TTGTTTGTATTACACG-1            9.995200
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                   24.121218
# Mus_Tcel13290869_AAACACCAATAACTGC-1                   24.343517
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                   20.402287
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                   27.130009
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                   17.852150
# ...                                                         ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                   26.677485
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                   25.078217
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                   22.886034
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                   25.105112
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                   29.498175
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    33.553905
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    36.254612
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    30.309862
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    36.820820
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    27.434181
# ...                                                          ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    36.484867
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    34.731457
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    34.370045
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    34.537258
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    38.161495
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    44.900108
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    47.775249
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    42.871815
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    48.475334
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    39.526997
# ...                                                          ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    48.761730
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    46.597576
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    46.264008
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    44.557014
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    49.306568
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    58.893196  ...
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    60.306358  ...
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    57.295620  ...
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    64.429779  ...
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    54.431057  ...
# ...                                                          ...  ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    64.185425  ...
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    60.513622  ...
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    60.054661  ...
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    57.418571  ...
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    63.549271  ...
#
#                                              donor_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACACCAATAACTGC-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGGGTCTATATT-1  3B_Hh.anti_IL10r
# ...                                               ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCCATACAACT-1  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTGTATTACACG-1  3B_Hh.anti_IL10r
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                     MmusDv:0000061
# Mus_Tcel13290869_AAACACCAATAACTGC-1                     MmusDv:0000061
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                     MmusDv:0000061
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                     MmusDv:0000061
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                     MmusDv:0000061
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                     MmusDv:0000061
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                     MmusDv:0000061
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290869_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTGTATTACACG-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTGTATTACACG-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290869_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                                       na
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1              unknown               na
# Mus_Tcel13290869_AAACACCAATAACTGC-1              unknown               na
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1              unknown               na
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1              unknown               na
# Mus_Tcel13290869_AAACAGGGTCTATATT-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1              unknown               na
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1              unknown               na
# Mus_Tcel13290869_TTGTTTCCATACAACT-1              unknown               na
# Mus_Tcel13290869_TTGTTTGTATTACACG-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
#
# [3195 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACACCAATAACTGC-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_AAACAGGGTCTATATT-1        1.0  3B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTCCATACAACT-1        1.0  3B_Hh.anti_IL10r
# Mus_Tcel13290869_TTGTTTGTATTACACG-1        1.0  3B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1               5479
# Mus_Tcel13290869_AAACACCAATAACTGC-1               7597
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1               7610
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1               4206
# Mus_Tcel13290869_AAACAGGGTCTATATT-1               6782
# ...                                                ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1               3728
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1               5942
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1               4820
# Mus_Tcel13290869_TTGTTTCCATACAACT-1               5305
# Mus_Tcel13290869_TTGTTTGTATTACACG-1               4907
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                 8.608860       23726.0
# Mus_Tcel13290869_AAACACCAATAACTGC-1                 8.935640       46612.0
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                 8.937350       44794.0
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                 8.344505       18791.0
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                 8.822175       33615.0
# ...                                                      ...           ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                 8.223895       14173.0
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                 8.689969       30684.0
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                 8.480737       18295.0
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                 8.576593       19741.0
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                 8.498622       21920.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1           10.074368
# Mus_Tcel13290869_AAACACCAATAACTGC-1           10.749635
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1           10.709852
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1            9.841187
# Mus_Tcel13290869_AAACAGGGTCTATATT-1           10.422757
# ...                                                 ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1            9.559165
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1           10.331530
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1            9.814438
# Mus_Tcel13290869_TTGTTTCCATACAACT-1            9.890504
# Mus_Tcel13290869_TTGTTTGTATTACACG-1            9.995200
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                   24.121218
# Mus_Tcel13290869_AAACACCAATAACTGC-1                   24.343517
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                   20.402287
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                   27.130009
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                   17.852150
# ...                                                         ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                   26.677485
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                   25.078217
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                   22.886034
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                   25.105112
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                   29.498175
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    33.553905
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    36.254612
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    30.309862
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    36.820820
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    27.434181
# ...                                                          ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    36.484867
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    34.731457
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    34.370045
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    34.537258
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    38.161495
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    44.900108
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    47.775249
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    42.871815
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    48.475334
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    39.526997
# ...                                                          ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    48.761730
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    46.597576
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    46.264008
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    44.557014
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    49.306568
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                    58.893196  ...
# Mus_Tcel13290869_AAACACCAATAACTGC-1                    60.306358  ...
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                    57.295620  ...
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                    64.429779  ...
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                    54.431057  ...
# ...                                                          ...  ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                    64.185425  ...
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                    60.513622  ...
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                    60.054661  ...
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                    57.418571  ...
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                    63.549271  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                      MmusDv:0000061
# Mus_Tcel13290869_AAACACCAATAACTGC-1                      MmusDv:0000061
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                      MmusDv:0000061
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                      MmusDv:0000061
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                      MmusDv:0000061
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                      MmusDv:0000061
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                      MmusDv:0000061
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290869_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13290869_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13290869_TTGTTTGTATTACACG-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13290869_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13290869_TTGTTTGTATTACACG-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290869_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1                                       na
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13290869_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290869_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13290869_TTGTTTGTATTACACG-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1              unknown              na
# Mus_Tcel13290869_AAACACCAATAACTGC-1              unknown              na
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1              unknown              na
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1              unknown              na
# Mus_Tcel13290869_AAACAGGGTCTATATT-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1              unknown              na
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1              unknown              na
# Mus_Tcel13290869_TTGTTTCCATACAACT-1              unknown              na
# Mus_Tcel13290869_TTGTTTGTATTACACG-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13290869_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13290869_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13290869_AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA
# Mus_Tcel13290869_AAACACCAATAACTGC-1  AAACACCAATAACTGC
# Mus_Tcel13290869_AAACAGAGCGACTCCT-1  AAACAGAGCGACTCCT
# Mus_Tcel13290869_AAACAGCTTTCAGAAG-1  AAACAGCTTTCAGAAG
# Mus_Tcel13290869_AAACAGGGTCTATATT-1  AAACAGGGTCTATATT
# ...                                               ...
# Mus_Tcel13290869_TTGTTCTAGATACGCT-1  TTGTTCTAGATACGCT
# Mus_Tcel13290869_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13290869_TTGTTTCACATCCAGG-1  TTGTTTCACATCCAGG
# Mus_Tcel13290869_TTGTTTCCATACAACT-1  TTGTTTCCATACAACT
# Mus_Tcel13290869_TTGTTTGTATTACACG-1  TTGTTTGTATTACACG
#
# [3195 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0009010',
#  'AAACACCAATAACTGC': 'CL:0000034',
#  'AAACAGAGCGACTCCT': 'CL:0009010',
#  'AAACAGCTTTCAGAAG': 'CL:0000584',
#  'AAACAGGGTCTATATT': 'CL:0009010',
#  'AAACAGTGTTCCTGGG': 'CL:0000186',
#  'AAACATGGTGAGAGGA': 'CL:0000584',
#  'AAACATTTCCCGGATT': 'CL:0000584',
#  'AAACCGGAAATGTTAA': 'CL:0000584',
#  'AAACCGGGTAGGTACC': 'CL:0000066',
#  'AAACCGTTCGTCCAGG': 'CL:0009010',
#  'AAACCTAAGCAGCCGG': 'CL:0000584',
#  'AAACGAAGATGGAGTA': 'CL:0000584',
#  'AAACGCTGGGCACGAC': 'CL:0000584',
#  'AAACGGGCGTACGGGT': 'CL:0000186',
#  'AAACGGTTGCGAACTG': 'CL:0000186',
#  'AAACTCGGTTCGCAAT': 'CL:0000584',
#  'AAACTCGTGATATAAG': 'CL:0009010',
#  'AAACTGCTGGCTCCAA': 'CL:0000034',
#  'AAACTTAATTGCACGC': 'CL:0000584',
#  'AAAGAATGACCTTAGA': 'CL:0000584',
#  'AAAGACCCAAGTCGCG': 'CL:0000584',
#  'AAAGACTGGGCGCTTT': 'CL:0000584',
#  'AAAGGCCCTATAATAC': 'CL:0000034',
#  'AAAGGCTCTCGCGCCG': 'CL:0000584',
#  'AAAGGGATGTAGCAAG': 'CL:0000584',
#  'AAAGGGCAGCTTGAAT': 'CL:0009010',
#  'AAAGTCACTGATGTAA': 'CL:0009010',
#  'AAAGTCGACCCTCAGT': 'CL:0000584',
#  'AAAGTGCCATCAATTA': 'CL:0000034',
#  'AAAGTTGACTCCCGTA': 'CL:0000584',
#  'AAATAACCATACGGGA': 'CL:0009010',
#  'AAATAAGGTAGTGCCC': 'CL:0000186',
#  'AAATACCTATAAGCAT': 'CL:0000584',
#  'AAATAGCTTAGACTTT': 'CL:0000034',
#  'AAATAGGGTGCTATTG': 'CL:0000584',
#  'AAATCCGATACACGCC': 'CL:0000034',
#  'AAATCGCGGAAGGAGT': 'CL:0009010',
#  'AAATCGTGTACCACAA': 'CL:0000034',
#  'AAATCTAGCCCTGCTA': 'CL:0000584',
#  'AAATCTGCCCGCGTCC': 'CL:0000584',
#  'AAATGATTCGATCAGC': 'CL:0000584',
#  'AAATGCTCGTTACGTT': 'CL:0000584',
#  'AAATGGCATGTCTTGT': 'CL:0000584',
#  'AAATGGCCCGTGCCCT': 'CL:0000034',
#  'AAATGGTCAATGTGCC': 'CL:0000584',
#  'AAATGTATCTTATCCC': 'CL:0009010',
#  'AAATTAACGGGTAGCT': 'CL:0000584',
#  'AAATTAATAAGCGCGA': 'CL:0000584',
#  'AAATTACACGACTCTG': 'CL:0009010',
#  'AAATTACCTATCGATG': 'CL:0009010',
#  'AAATTCCAGGTCCAAA': 'CL:0000584',
#  'AAATTGATAGTCCTTT': 'CL:0000034',
#  'AAATTTGCGGGTGTGG': 'CL:0000034',
#  'AACAACTGGTAGTTGC': 'CL:0000034',
#  'AACAATACATTGTCGA': 'CL:0000584',
#  'AACAATTACTCTACGC': 'CL:0000584',
#  'AACACGAGACGCGGCC': 'CL:0000186',
#  'AACAGCTGTGTGGCAA': 'CL:0000034',
#  'AACAGGAAATCGAATA': 'CL:0000584',
#  'AACAGGATGGGCCGCG': 'CL:0000584',
#  'AACAGGTAGTATGGAT': 'CL:0000034',
#  'AACATATCAACTGGTG': 'CL:0009010',
#  'AACATTGAAGTTGATC': 'CL:0000034',
#  'AACCAAGACTTCTCTG': 'CL:0000186',
#  'AACCATAGGGTTGAAC': 'CL:0000584',
#  'AACCATGGGATCGCTA': 'CL:0000584',
#  'AACCCGACAACCCGTG': 'CL:0000034',
#  'AACCCGAGCAGAATCG': 'CL:0000034',
#  'AACCCTACTGTCAATA': 'CL:0000034',
#  'AACCGTTGTGTTTGCT': 'CL:0000584',
#  'AACCTGTCACGGAATT': 'CL:0009010',
#  'AACCTTTAAATACGGT': 'CL:0000584',
#  'AACCTTTACGACGTCT': 'CL:0000584',
#  'AACGAAAGTCGTCCCA': 'CL:0009010',
#  'AACGACCTCCTAGCCG': 'CL:0000584',
#  'AACGATAATGCCGTAG': 'CL:0000584',
#  'AACGATAGAAGGGCCG': 'CL:0009010',
#  'AACGCATGATCTGGGT': 'CL:0000584',
#  'AACGCGGTCTCCAGCC': 'CL:0000057',
#  'AACGCTGTTGCTGAAA': 'CL:0000584',
#  'AACGGCCATCTCCGGT': 'CL:0000034',
#  'AACGTACTGTGGGTAC': 'CL:0000034',
#  'AACGTCAGACTAGTGG': 'CL:0000584',
#  'AACGTCGCTGCACTTC': 'CL:0000584',
#  'AACGTGCGAAAGTCTC': 'CL:0000034',
#  'AACGTTATCAGCACCT': 'CL:0000584',
#  'AACTACCCGTTTGTCA': 'CL:0000186',
#  'AACTAGGCTTGGGTGT': 'CL:0000034',
#  'AACTCAAGTTAATTGC': 'CL:0000034',
#  'AACTCCAGAGCGTGTT': 'CL:0000186',
#  'AACTCTCAATAGAGCG': 'CL:0000584',
#  'AACTCTCAGTGTGCTC': 'CL:0000584',
#  'AACTGAGTTATACTGA': 'CL:0000584',
#  'AACTGATATTAGGCCT': 'CL:0000584',
#  'AACTGGGTCCCGACGT': 'CL:0000584',
#  'AACTTCTGCGTCTATC': 'CL:0000584',
#  'AACTTGCCCGTATGCA': 'CL:0000584',
#  'AACTTGCGTTCTCGCG': 'CL:0000584',
#  'AACTTTACGGGAGCTT': 'CL:0000584',
#  'AAGAAAGTTTGATGGG': 'CL:0000584',
#  'AAGAAGGATCAGTTAG': 'CL:0009010',
#  'AAGACCAAATAACTCA': 'CL:0009010',
#  'AAGACCCAACTGAACA': 'CL:0000186',
#  'AAGACTGCAAGCTACT': 'CL:0009010',
#  'AAGAGATGAATCGGTA': 'CL:0009010',
#  'AAGAGCTCTTTATCGG': 'CL:0000057',
#  'AAGAGGATGTACGCGA': 'CL:0000066',
#  'AAGAGGCATGGATCGC': 'CL:0000034',
#  'AAGAGGCCCTTTGGAA': 'CL:0000584',
#  'AAGATGGCACCGGACC': 'CL:0000034',
#  'AAGATTGGCGGAACGT': 'CL:0000584',
#  'AAGCCACTTGCAGGTA': 'CL:0000034',
#  'AAGCCGCCGTGAAATC': 'CL:0009010',
#  'AAGCCGGAGAGCAGGA': 'CL:0000034',
#  'AAGCGCAGGGCTTTGA': 'CL:0009010',
#  'AAGCGTCCCTCATCGA': 'CL:0000584',
#  'AAGCTAGATCGAGTAA': 'CL:0000584',
#  'AAGCTCGTGCCAAGTC': 'CL:0009010',
#  'AAGGAGCGGTTGGTGC': 'CL:0000584',
#  'AAGGATCGATCGCTTG': 'CL:0000034',
#  'AAGGATGAGGGACCTC': 'CL:0000034',
#  'AAGGCAGGCTGTCTCC': 'CL:0000584',
#  'AAGGCGCGTAAAGCTT': 'CL:0009010',
#  'AAGGCTGTGCTCATCG': 'CL:0000584',
#  'AAGGGAACGACTGGCT': 'CL:0000034',
#  'AAGGGACAGATTCTGT': 'CL:0000584',
#  'AAGGGACTATGCATTC': 'CL:0000034',
#  'AAGTAGTGACGCGAGG': 'CL:0000584',
#  'AAGTCAATTGTCGTCA': 'CL:0000186',
#  'AAGTCTTCTGTGGCCT': 'CL:0009010',
#  'AAGTGACGACCGAATT': 'CL:0000034',
#  'AAGTGAGTCGGGTTTA': 'CL:0000034',
#  'AAGTGCAAAGGTAGAC': 'CL:0000584',
#  'AAGTGCCTTGACTGTA': 'CL:0000034',
#  'AAGTGCTTCTCTATTG': 'CL:0000034',
#  'AAGTTCACTCCAAGCT': 'CL:0009010',
#  'AAGTTCAGTCTGCGTA': 'CL:0009010',
#  'AAGTTCGGCCAACAGG': 'CL:0000066',
#  'AAGTTGTGATGTTATA': 'CL:0000034',
#  'AAGTTTATGGGCCCAA': 'CL:0000584',
#  'AATAACAACGCTCGGC': 'CL:0000584',
#  'AATAACACTAGAACAA': 'CL:0000034',
#  'AATAATCTTCGTATCG': 'CL:0000584',
#  'AATACAATGTTTCAGG': 'CL:0000584',
#  'AATACCGGAGGGCTGT': 'CL:0000034',
#  'AATAGAACAGAGTGGC': 'CL:0000584',
#  'AATAGAATCTGTTTCA': 'CL:0000584',
#  'AATAGTCCGTCCCGAC': 'CL:0000584',
#  'AATAGTCGCGAGTCGG': 'CL:0000584',
#  'AATATCCTAGCAAACT': 'CL:0000584',
#  'AATATCGAATCAATGC': 'CL:0000034',
#  'AATATCGAGGGTTCTC': 'CL:0009010',
#  'AATCAGGTTTCATTTA': 'CL:0000034',
#  'AATCATGTAAAGACTC': 'CL:0000584',
#  'AATCGCCTCAGCGCCA': 'CL:0000584',
#  'AATCGTGAGCCGAGCA': 'CL:0000034',
#  'AATCTATGCCGGAGCC': 'CL:0000584',
#  'AATCTCTACTGTGGTT': 'CL:0000584',
#  'AATCTGCGTTGGGACG': 'CL:0000034',
#  'AATCTGGCTTTCTAGT': 'CL:0000034',
#  'AATGACAGCAATGTCT': 'CL:0000034',
#  'AATGACTGTCAGCCGG': 'CL:0000584',
#  'AATGAGTTCGCATATG': 'CL:0000584',
#  'AATGATGATACGCTAT': 'CL:0000057',
#  'AATGATGCGACTCCTG': 'CL:0009010',
#  'AATGCAACCGGGTACC': 'CL:0000034',
#  'AATGCACCAAGCAATG': 'CL:0000584',
#  'AATGGTCCACCGTTCA': 'CL:0000584',
#  'AATGGTTCTCACAAGC': 'CL:0000584',
#  'AATGTATGGCACTGTA': 'CL:0000584',
#  'AATGTTGTCGTGAGAC': 'CL:0000584',
#  'AATTAAAGGTCGGCGT': 'CL:0000584',
#  'AATTAACGGATTTCCA': 'CL:0000584',
#  'AATTACGAGACCCATC': 'CL:0009010',
#  'AATTAGCGCTGCAGCG': 'CL:0000584',
#  'AATTCATAAGGGATCT': 'CL:0009010',
#  'AATTCATTGTCATGCA': 'CL:0000584',
#  'AATTCCAAGCATGTAC': 'CL:0000186',
#  'AATTCGATTCGAGGAT': 'CL:0009010',
#  'AATTCTAGAGTTAGGC': 'CL:0000584',
#  'AATTGCAGCAATCGAC': 'CL:0000034',
#  'AATTGCGTGGATTACA': 'CL:0000584',
#  'AATTGTGGTTGCCAAA': 'CL:0000584',
#  'AATTTGGTTCCAAAGA': 'CL:0009010',
#  'ACAAACCATGCGTCCT': 'CL:0000034',
#  'ACAAAGAAGGTAGGCC': 'CL:0000584',
#  'ACAAAGCATGACCTAG': 'CL:0000034',
#  'ACAAATCGCACCGAAT': 'CL:0000584',
#  'ACAACAGCATGAGCTA': 'CL:0000034',
#  'ACAACGGTCCCTGCGA': 'CL:0000584',
#  'ACAAGCAGTGCCTAGC': 'CL:0000584',
#  'ACAAGCTATATGGAAG': 'CL:0000584',
#  'ACAAGGAAATCCGCCC': 'CL:0000584',
#  'ACAAGGACAAGAGGTT': 'CL:0000584',
#  'ACAAGGATGCTTTAGG': 'CL:0009010',
#  'ACAAGGGCAGGCTCTG': 'CL:0000584',
#  'ACAATCCATTTAAACC': 'CL:0000584',
#  'ACAATGAATACGGAGA': 'CL:0000034',
#  'ACAATTTAGGAGGCTC': 'CL:0000584',
#  'ACAATTTGAGCAGTGG': 'CL:0000584',
#  'ACAATTTGGCCATATT': 'CL:0000584',
#  'ACACACTTTCTACACG': 'CL:0000186',
#  'ACACATGATCAAATCT': 'CL:0000034',
#  'ACACCCAGCATGCAGC': 'CL:0000584',
#  'ACACCCGAGAAATCCG': 'CL:0000584',
#  'ACACCTTACTACTTGC': 'CL:0000186',
#  'ACACGAGACTCCTTCT': 'CL:0000584',
#  'ACACGGGAACTTAGGG': 'CL:0000584',
#  'ACACGTAGGCCACAAG': 'CL:0000584',
#  'ACACTCCAATGTCACT': 'CL:0000584',
#  'ACACTGATCAAGGTGT': 'CL:0000584',
#  'ACACTGGGACAGTCGT': 'CL:0000034',
#  'ACAGCATAGAGCCAGT': 'CL:0009010',
#  'ACAGCGACATTCTCAT': 'CL:0000034',
#  'ACAGGCACGGATCCTT': 'CL:0000034',
#  'ACAGGCTTGCCCGACT': 'CL:0009010',
#  'ACAGGTGGAGGTGAGG': 'CL:0000584',
#  'ACAGGTGTGTTGTTGC': 'CL:0000584',
#  'ACAGTAATACAACTTG': 'CL:0009010',
#  'ACATAAGTCGTGGTGA': 'CL:0009010',
#  'ACATAATAAGGCGGTG': 'CL:0000057',
#  'ACATCAGCTGGGACGC': 'CL:0009010',
#  'ACATCCCGGCCATACG': 'CL:0000584',
#  'ACATCCTGGTAACTGT': 'CL:0000584',
#  'ACATCGATCGTTTACC': 'CL:0000034',
#  'ACATCGGTCAGCCGCG': 'CL:0000034',
#  'ACATGCTTACGGCAGC': 'CL:0000186',
#  'ACATGGCGCCAAAGTA': 'CL:0000034',
#  'ACATTAGTTTATATCC': 'CL:0000584',
#  'ACATTCGCGCGGAATA': 'CL:0000034',
#  'ACCAACACCACACACT': 'CL:0009010',
#  'ACCAACCGCACTCCAC': 'CL:0000034',
#  'ACCAACGCTTATTTAT': 'CL:0000584',
#  'ACCAAGAACGCGTGTC': 'CL:0000584',
#  'ACCAAGTCATCGGCAG': 'CL:0000584',
#  'ACCAATATGCAAGTTA': 'CL:0000584',
#  'ACCACAAGTTTCTATC': 'CL:0000584',
#  'ACCACCAATGTAACAA': 'CL:0000034',
#  'ACCACGTGCAGCTATA': 'CL:0000584',
#  'ACCAGACCATAACAAC': 'CL:0009010',
#  'ACCATATCCGCAATAA': 'CL:0009010',
#  'ACCATCGTATATGGTA': 'CL:0000034',
#  'ACCCAACGCCCGTGGC': 'CL:0000584',
#  'ACCCACCTACATGCTC': 'CL:0000584',
#  'ACCCATCTTGAGGGTA': 'CL:0000584',
#  'ACCCATTTGTCCCTCT': 'CL:0000034',
#  'ACCCGATTGGTTCCGA': 'CL:0000034',
#  'ACCCGGAAACTCCCAG': 'CL:0000066',
#  'ACCCGGATGACGCATC': 'CL:0000034',
#  'ACCCGGTTACACTTCC': 'CL:0000034',
#  'ACCCGTAGCAGAGAAT': 'CL:0000584',
#  'ACCCGTAGTCTAGTTG': 'CL:0000034',
#  'ACCCGTGTCATCAGTA': 'CL:0000034',
#  'ACCCTATGCCATATCG': 'CL:0000235',
#  'ACCCTCCCGTCAGGGC': 'CL:0000034',
#  'ACCCTCCCTTGCTATT': 'CL:0000584',
#  'ACCCTTCATCTGCGAA': 'CL:0000584',
#  'ACCGAAAGGGCCCTGC': 'CL:0009010',
#  'ACCGAAGAGTCTGGTT': 'CL:0000034',
#  'ACCGACTGAGTCCCAC': 'CL:0000584',
#  'ACCGATATTTAATCAT': 'CL:0009010',
#  'ACCGATGGTAGCATCG': 'CL:0000034',
#  'ACCGCGGTGGAAGTCG': 'CL:0000584',
#  'ACCGGGCCTTTGTTGA': 'CL:0000584',
#  'ACCGGTCAGGTACACC': 'CL:0000034',
#  'ACCGTCCACTGGGCCC': 'CL:0009010',
#  'ACCGTGACCACGTGGG': 'CL:0000034',
#  'ACCTAAGTACCTTTCA': 'CL:0000034',
#  'ACCTAATCGACTTCCT': 'CL:0000034',
#  'ACCTCCGCCCTCGCTG': 'CL:0000584',
#  'ACCTCCGTTATTCACC': 'CL:0000584',
#  'ACCTCGAACTTATGCT': 'CL:0000034',
#  'ACCTGCGTGTCATGTT': 'CL:0000186',
#  'ACGACCCATGAGTTGC': 'CL:0009010',
#  'ACGACTGGTCATACTC': 'CL:0000034',
#  'ACGAGGATACCACTCT': 'CL:0000034',
#  'ACGAGGTTTACAACGT': 'CL:0000034',
#  'ACGAGTACGGATGCCC': 'CL:0009010',
#  'ACGATACCTATCCTGA': 'CL:0000584',
#  'ACGATCATACATAGAG': 'CL:0000186',
#  'ACGATCATCTTGTAAA': 'CL:0000034',
#  'ACGATGCATATGTTAT': 'CL:0000034',
#  'ACGATGGATCCGATGC': 'CL:0000584',
#  'ACGCAAACTAATAGAT': 'CL:0000034',
#  'ACGCAATCACTACAGC': 'CL:0000584',
#  'ACGCATACGTTTACTA': 'CL:0000034',
#  'ACGCATTCGTGAGTAC': 'CL:0000034',
#  'ACGCCACTCGAAACAG': 'CL:0000584',
#  'ACGCCAGATGATTTCT': 'CL:0009010',
#  'ACGCGAAGTCAGACGA': 'CL:0000034',
#  'ACGCGCTACACAGGGT': 'CL:0000034',
#  'ACGCGGGCCAAGGACA': 'CL:0000584',
#  'ACGCGTTTCTTAAGAG': 'CL:0000584',
#  'ACGCTAGTGATACACT': 'CL:0009010',
#  'ACGCTGTGAGGCGTAG': 'CL:0000584',
#  'ACGGAATTTAGCAAAT': 'CL:0000584',
#  'ACGGACGCAGCGACAA': 'CL:0000186',
#  'ACGGCACTTGCTTGGG': 'CL:0000584',
#  'ACGGCCAACATGGACT': 'CL:0000066',
#  'ACGGCTGGATGTAGAA': 'CL:0009010',
#  'ACGGGAGTGTCGGCCC': 'CL:0000584',
#  'ACGGGTTGTGACCTGT': 'CL:0000584',
#  'ACGGTACAGTTCAATG': 'CL:0000066',
#  'ACGTACAGATTTCTCT': 'CL:0000186',
#  'ACGTACTTTGGCACGG': 'CL:0000034',
#  'ACGTAGATTGCTGATG': 'CL:0000584',
#  'ACGTAGGAGAGTCGCT': 'CL:0000034',
#  'ACGTATTACTCCGATC': 'CL:0000584',
#  'ACGTCGGGCAACTCGG': 'CL:0000584',
#  'ACGTCTCGTTCCGGGA': 'CL:0000584',
#  'ACGTGACAAAGTAAGT': 'CL:0009010',
#  'ACGTGCGCCTCGTGCA': 'CL:0000057',
#  'ACGTTAATGTCGAAGA': 'CL:0000034',
#  'ACGTTAGATTTGCCCG': 'CL:0000034',
#  'ACGTTATTGGTCACTC': 'CL:0000584',
#  'ACGTTCACTATGCCGC': 'CL:0000034',
#  'ACGTTCGCAATCAATT': 'CL:0009010',
#  'ACGTTCGTTCAGGAAA': 'CL:0000186',
#  'ACGTTCTGTACAAGTC': 'CL:0000034',
#  'ACGTTGTCGTTGAAAG': 'CL:0000034',
#  'ACTACAAAGAGAGGTG': 'CL:0000066',
#  'ACTACATCCCGACAAG': 'CL:0000034',
#  'ACTACCAGCTCTCTGG': 'CL:0000584',
#  'ACTACCATCCGAGGGC': 'CL:0000034',
#  'ACTACGCGTTAGAATT': 'CL:0000034',
#  'ACTAGTTGCGATCGTC': 'CL:0000186',
#  'ACTATCCAGGGCATGG': 'CL:0000034',
#  'ACTATCTGCCCGCGTA': 'CL:0000066',
#  'ACTATGTCCAGCTGCC': 'CL:0000034',
#  'ACTATTTCCGGGCCCA': 'CL:0000034',
#  'ACTCAAGTGCAAGGCT': 'CL:0000584',
#  'ACTCAATAAAGGCACG': 'CL:0000034',
#  'ACTCAGACCTGCTTCT': 'CL:0000844',
#  'ACTCATGGCAGCCTTC': 'CL:0000584',
#  'ACTCCCATTCCTAAAG': 'CL:0000186',
#  'ACTCCCGAATTCGTTT': 'CL:0000584',
#  'ACTCCCTAGAATAGTA': 'CL:0000584',
#  'ACTCCGGCCGACCACT': 'CL:0000584',
#  'ACTCGATGTATTTCAT': 'CL:0000584',
#  'ACTCGCCGTTCGATAA': 'CL:0000584',
#  'ACTCGCGATCTGACGC': 'CL:0000034',
#  'ACTCGTAACCCGTCCT': 'CL:0000584',
#  'ACTCGTCAGTAATCCC': 'CL:0000057',
#  'ACTCTAAACCTGGGAT': 'CL:0000584',
#  'ACTCTGACCTAATAGA': 'CL:0000034',
#  'ACTCTTCAGCTCCCGC': 'CL:0000584',
#  'ACTCTTGTATAGTAAC': 'CL:0009010',
#  'ACTGAAACGCCGTTAG': 'CL:0000584',
#  'ACTGAATGGCGAAAGT': 'CL:0000584',
#  'ACTGCCCGCCATTCTC': 'CL:0009010',
#  'ACTGCCGTCGTAACTC': 'CL:0009010',
#  'ACTGCGGACACACCGT': 'CL:0009010',
#  'ACTGGGATGCCAGTGC': 'CL:0000584',
#  'ACTGTACGATACACAT': 'CL:0000034',
#  'ACTGTAGCACTTTGGA': 'CL:0000584',
#  'ACTGTCTTCTTTAGAA': 'CL:0000034',
#  'ACTGTGCTAGTAGATC': 'CL:0009010',
#  'ACTTAGTACGACAAGA': 'CL:0000584',
#  'ACTTATACTTACCCGG': 'CL:0000186',
#  'ACTTATTAGGATCGGT': 'CL:0000034',
#  'ACTTCAGGCTGATCCC': 'CL:0000584',
#  'ACTTCCAGTGGAAGCT': 'CL:0000584',
#  'ACTTCCATGCGGGACA': 'CL:0000584',
#  'ACTTCGCCATACGCAC': 'CL:0000584',
#  'ACTTGCTCTATCTACC': 'CL:0000584',
#  'ACTTGGGACCCGGTGG': 'CL:0000584',
#  'ACTTGTGGATGGAACG': 'CL:0000034',
#  'ACTTTACCCTCATGAA': 'CL:0000584',
#  'ACTTTCCTATAGCTTC': 'CL:0000034',
#  'ACTTTGACTGCATCCT': 'CL:0000584',
#  'ACTTTGGTCGTGCTCC': 'CL:0009010',
#  'ACTTTGTCGACGCACT': 'CL:0009010',
#  'AGAAATTATGACTCGC': 'CL:0000034',
#  'AGAACCCAGCGTGACA': 'CL:0000584',
#  'AGAACCCTCAATTGGG': 'CL:0009010',
#  'AGAACGTGGTACATTC': 'CL:0000584',
#  'AGAACTGTACTTTGTA': 'CL:0000066',
#  'AGAAGAGCGCCGTTCC': 'CL:0000584',
#  'AGAAGGTTGCCGAATT': 'CL:0000034',
#  'AGAAGGTTGTAGGTCG': 'CL:0000584',
#  'AGAATAAATCTTCAGG': 'CL:0000584',
#  'AGAATTATGGATTCGA': 'CL:0000584',
#  'AGAATTGTTTGACATA': 'CL:0000584',
#  'AGACAGCTCAGAATCC': 'CL:0000584',
#  'AGACAGGCATCTCAGC': 'CL:0000584',
#  'AGACCAAACCACACCT': 'CL:0009010',
#  'AGACCATGGGATACAA': 'CL:0000584',
#  'AGACCCACCGCTGATC': 'CL:0000034',
#  'AGACCCGCCCTCCTCG': 'CL:0000034',
#  'AGACCGCTCCGCGGTT': 'CL:0000034',
#  'AGACGACGATGCCGCT': 'CL:0000584',
#  'AGACTAGCCTTCCAGA': 'CL:0000584',
#  'AGAGAACCGTCTAGGA': 'CL:0000584',
#  'AGAGAAGGAGTACAAT': 'CL:0009010',
#  'AGAGCAGTTATGAGAC': 'CL:0009010',
#  'AGAGCCGCCGAGATTT': 'CL:0000584',
#  'AGAGCGGGCTAATCAT': 'CL:0000057',
#  'AGAGCGTACAAGCTCG': 'CL:0000584',
#  'AGAGGCTTCGGAAACC': 'CL:0000584',
#  'AGAGTAAACTTCACTA': 'CL:0000034',
#  'AGAGTATAGTGTTACG': 'CL:0009010',
#  'AGATAACTTCAGGGCC': 'CL:0000584',
#  'AGATACCAATAGAACC': 'CL:0000034',
#  'AGATACCGGTGTTCAC': 'CL:0000034',
#  'AGATCGTGCATAAGAT': 'CL:0000186',
#  'AGATCTCAGGTGTGAT': 'CL:0000034',
#  'AGATGATGGAGTCTGG': 'CL:0000186',
#  'AGATGCAAGACGTGCA': 'CL:0000034',
#  'AGATGCATCCTGTGTC': 'CL:0009010',
#  'AGATTATAGGACGTTT': 'CL:0000584',
#  'AGCAACCGAAAGTAAT': 'CL:0000034',
#  'AGCACACGTTTAGACT': 'CL:0000584',
#  'AGCACCAGTACTCACG': 'CL:0000034',
#  'AGCACTTAAGGACGCC': 'CL:0000584',
#  'AGCAGCCAGATGAATA': 'CL:0000584',
#  'AGCAGTCGAAGCATGC': 'CL:0000584',
#  'AGCATCGTCGATAATT': 'CL:0000584',
#  'AGCATTACGAGGCAAG': 'CL:0000034',
#  'AGCCAAGCTTTGTGTC': 'CL:0000186',
#  'AGCCACAGGTTACCCG': 'CL:0000034',
#  'AGCCATATAGTATGTG': 'CL:0000584',
#  'AGCCCATACATGTAAG': 'CL:0000034',
#  'AGCCCGCAACAAGCAG': 'CL:0009010',
#  'AGCCCGCACTACAATG': 'CL:0000034',
#  'AGCCCGGCATTAGAGG': 'CL:0000584',
#  'AGCCCGGTAGCCTGTA': 'CL:0007011',
#  'AGCCCTAAGCGAAGTT': 'CL:0000584',
#  'AGCCCTGTCGCACCGT': 'CL:0000584',
#  'AGCCCTTCTAATCCGA': 'CL:0009010',
#  'AGCCCTTGGACATCCC': 'CL:0000034',
#  'AGCCGCAAATTCAAAT': 'CL:0009010',
#  'AGCCGTGGCTAAATGT': 'CL:0000584',
#  'AGCCTAATACCCACGT': 'CL:0000034',
#  'AGCCTTAAAGCGGAAG': 'CL:0009010',
#  'AGCCTTGTCACTGATA': 'CL:0000584',
#  'AGCGACAGGAACGGTC': 'CL:0000066',
#  'AGCGACATCCCATTCA': 'CL:0000584',
#  'AGCGACCAACGATATT': 'CL:0000186',
#  'AGCGAGACGTGAAGGC': 'CL:0000186',
#  'AGCGATGCGCCTAATA': 'CL:0000584',
#  'AGCGCATAATGAATCG': 'CL:0009010',
#  'AGCGCGGGTGCCAATG': 'CL:0009010',
#  'AGCGCTAGAGCGATGT': 'CL:0009010',
#  'AGCGGACACTTCGTAG': 'CL:0009010',
#  'AGCGGGTCTGACACTC': 'CL:0000584',
#  'AGCGTGGTATTCTACT': 'CL:0000034',
#  'AGCTAACAAGCAATGT': 'CL:0000034',
#  'AGCTAAGTACGCAGGC': 'CL:0000584',
#  'AGCTAGAAGCAGAAGT': 'CL:0000186',
#  'AGCTATTTAATCCAAC': 'CL:0009010',
#  'AGCTCCATATATGTTC': 'CL:0000584',
#  'AGCTCCTTCGCACATC': 'CL:0000584',
#  'AGCTCTAGACGTTCCA': 'CL:0000584',
#  'AGCTCTTCCCAGTGCA': 'CL:0009010',
#  'AGCTCTTCGTAACCTT': 'CL:0000584',
#  'AGCTCTTTACTCAGTT': 'CL:0000034',
#  'AGCTGAAGTAAACCAA': 'CL:0000584',
#  'AGCTTCTTCTCGAGCA': 'CL:0000034',
#  'AGCTTGATCAGGGTAG': 'CL:0000584',
#  'AGCTTGATCTTAACTT': 'CL:0000186',
#  'AGGAAGCTGTCCGCCG': 'CL:0000584',
#  'AGGACATCGCACGTCG': 'CL:0009010',
#  'AGGACATCGGCACACT': 'CL:0000584',
#  'AGGACGACCCATTAGA': 'CL:0000034',
#  'AGGACGCTCGATGTTG': 'CL:0000584',
#  'AGGAGGCCTTCGCGCG': 'CL:0000584',
#  'AGGATAAAGTCGGGAT': 'CL:0000584',
#  'AGGATATCCGACTGCA': 'CL:0000584',
#  'AGGATCACGCGATCTG': 'CL:0000034',
#  'AGGCACGTGACTGTCC': 'CL:0000034',
#  'AGGCAGATGCGTAAAC': 'CL:0000186',
#  'AGGCAGGGAGCGTACT': 'CL:0000186',
#  'AGGCATTGTCGTAGGG': 'CL:0000584',
#  'AGGCCACATTGGTTAC': 'CL:0000034',
#  'AGGCCACCCGTTATGA': 'CL:0000186',
#  'AGGCCCATTGTACAGG': 'CL:0009010',
#  'AGGCCCTAGAACGCCA': 'CL:0000034',
#  'AGGCCTATCATACCAA': 'CL:0000584',
#  'AGGCCTGAGAATCTCG': 'CL:0000034',
#  'AGGCGGTTTGTCCCGC': 'CL:0000034',
#  'AGGCTATGGTTAGCTT': 'CL:0000584',
#  'AGGCTTCCCGAAGAAG': 'CL:0000584',
#  'AGGCTTGCTAGACACC': 'CL:0000584',
#  'AGGGAAACGAGGTACT': 'CL:0009010',
#  'AGGGACCGGCTGCGTT': 'CL:0000584',
#  'AGGGACTCTACGCGAC': 'CL:0000584',
#  'AGGGAGACATACTTCG': 'CL:0000186',
#  'AGGGCCCTAATGTTCT': 'CL:0000034',
#  'AGGGCGTGATCGGCTA': 'CL:0000584',
#  'AGGGCTGCAGTTACAG': 'CL:0000584',
#  'AGGGTCAGAGCACTCG': 'CL:0000584',
#  'AGGGTCGATGCGAACT': 'CL:0000034',
#  'AGGGTCTGGACGCAGT': 'CL:0000034',
#  'AGGGTGCCGTTCTTTA': 'CL:0000034',
#  'AGGGTGCTCTCGAGGG': 'CL:0000584',
#  'AGGGTTCAGACGGTCC': 'CL:0000584',
#  'AGGGTTCCCTTTGGTT': 'CL:0000584',
#  'AGGGTTTAGTTCGGGA': 'CL:0000034',
#  'AGGTACGATATTGCCA': 'CL:0009010',
#  'AGGTAGATCGAGATAT': 'CL:0000066',
#  'AGGTAGGTACAAAGCT': 'CL:0000584',
#  'AGGTATAATTGATAGT': 'CL:0009010',
#  'AGGTATGCGGACATTA': 'CL:0000186',
#  'AGGTCAGGTGAGAGTG': 'CL:0000186',
#  'AGGTCGCGGAGTTACT': 'CL:0009010',
#  'AGGTGGTGACCTTCGC': 'CL:0000186',
#  'AGGTGTTGCCGACCAC': 'CL:0000034',
#  'AGGTTCTCCTTTCCGG': 'CL:0000584',
#  'AGGTTGAGGCACGCTT': 'CL:0000057',
#  'AGGTTTCACACACCTT': 'CL:0000584',
#  'AGTAATGTCTTGCCGC': 'CL:0000584',
#  'AGTAATTTGCAAGCGT': 'CL:0009010',
#  'AGTACATCATTTATCA': 'CL:0009010',
#  'AGTACGGCCCGTATCG': 'CL:0009010',
#  'AGTACGGGCACCTGGC': 'CL:0000034',
#  'AGTACTCTTATGCCCA': 'CL:0000034',
#  'AGTAGAAGGCGCCTCA': 'CL:0000584',
#  'AGTAGGAAGGAAGTTG': 'CL:0009010',
#  'AGTATAATACTAGGCA': 'CL:0000584',
#  'AGTATGCTGGAGACCA': 'CL:0000584',
#  'AGTATTTGGCACGACC': 'CL:0000034',
#  'AGTCAAATGATGTGAT': 'CL:0000186',
#  'AGTCAACACCACCATC': 'CL:0000034',
#  'AGTCACTAGCTCTCGA': 'CL:0000584',
#  'AGTCAGCCACCGCCTG': 'CL:0000584',
#  'AGTCCATTGGCTGATG': 'CL:0000584',
#  'AGTCCCGCCTTTAATT': 'CL:0000584',
#  'AGTCGAAACGATTCAG': 'CL:0000584',
#  'AGTCGACGGTCTCAAG': 'CL:0000584',
#  'AGTCGGCCCAAACGAC': 'CL:0000584',
#  'AGTCGGCTCAACTTTA': 'CL:0000066',
#  'AGTCGGTTGCGTGAGA': 'CL:0000584',
#  'AGTCGTATAAAGCAGA': 'CL:0000584',
#  'AGTCGTCGACCACCAA': 'CL:0000034',
#  'AGTCGTGGGCATTACG': 'CL:0000034',
#  'AGTCTAAAGTATACTC': 'CL:0009010',
#  'AGTCTCACAAGACTAC': 'CL:0000034',
#  'AGTCTTCTCCTCAAAT': 'CL:0000057',
#  'AGTCTTTAAAGTGTCC': 'CL:0000034',
#  'AGTGAACAAACTTCTC': 'CL:0000034',
#  'AGTGACCTACTTTACG': 'CL:0000034',
#  'AGTGAGACTTCCAGTA': 'CL:0000186',
#  'AGTGAGCCTCGCCGCC': 'CL:0009010',
#  'AGTGAGTCGAATTAAC': 'CL:0000584',
#  'AGTGATAACCTGCGCG': 'CL:0000186',
#  'AGTGATATGAGTAGTT': 'CL:0000584',
#  'AGTGATTCAAGCAGGA': 'CL:0000034',
#  'AGTGCGTAGCTCGTAA': 'CL:0000034',
#  'AGTGCTAAACACAGCA': 'CL:0000186',
#  'AGTGGCCCGCAAATGG': 'CL:0000034',
#  'AGTGGCGGCAATTTGA': 'CL:0009010',
#  'AGTGGCGTCTGAAGGT': 'CL:0000584',
#  'AGTGGTGTTACCCGTG': 'CL:0000584',
#  'AGTGGTTGCGTATAGG': 'CL:0000584',
#  'AGTGTATTGCGCATTG': 'CL:0000584',
#  'AGTGTGGTCTATTGTG': 'CL:0000584',
#  'AGTTAAACACTTGCGA': 'CL:0000034',
#  'AGTTAAGCGGTCCCGG': 'CL:0009010',
#  'AGTTACCCTTAAGACT': 'CL:0000584',
#  'AGTTACTCTATCGTGG': 'CL:0000584',
#  'AGTTCACCGGTTGGAC': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000584',
#  'AGTTCCTATTTATGTT': 'CL:0000584',
#  'AGTTGACGGTCCTTGC': 'CL:0000584',
#  'AGTTGCGGTCCTCAAC': 'CL:0000584',
#  'AGTTGCTGACTGATAT': 'CL:0000584',
#  'AGTTGGCAAGGCTAGA': 'CL:0000584',
#  'AGTTTCGCAGGTCGGA': 'CL:0000584',
#  'AGTTTGGCACGGGTTG': 'CL:0000584',
#  'AGTTTGGCCAGACCTA': 'CL:0000186',
#  'ATAAACGGACCCGTAA': 'CL:0000584',
#  'ATAAACGTTGCACCAC': 'CL:0000584',
#  'ATAAAGGCTCGGTCGT': 'CL:0000584',
#  'ATAAATATTAGCAGCT': 'CL:0000034',
#  'ATAACGCCGGAGGGTC': 'CL:0000034',
#  'ATAACGGAGTCCAACG': 'CL:0000186',
#  'ATAAGGTGGAGAACAT': 'CL:0000584',
#  'ATAAGTAGGATTCAGA': 'CL:0009010',
#  'ATAAGTAGGGCGACTC': 'CL:0000186',
#  'ATAAGTTACCGCGACG': 'CL:0000034',
#  'ATAATACCGTTAGCCG': 'CL:0009010',
#  'ATAATAGCTGTTGAAT': 'CL:0000034',
#  'ATAATAGTGTAGGGAC': 'CL:0009010',
#  'ATAATTAGCTAAGTAG': 'CL:0000584',
#  'ATACCACGGGCAACTT': 'CL:0000584',
#  'ATACCTAACCAAGAAA': 'CL:0000584',
#  'ATACGAAGGCTTTCCA': 'CL:0000186',
#  'ATACGCCGGCGAAACC': 'CL:0000584',
#  'ATACGGAACGTCGTTT': 'CL:0000584',
#  'ATACGGTGAAGATGCA': 'CL:0009010',
#  'ATACGTACTTAGCCAC': 'CL:0000584',
#  'ATACGTCCACTCCTGT': 'CL:0000584',
#  'ATACGTTATGCACGGA': 'CL:0000584',
#  'ATACTACCCGTACCAC': 'CL:0000034',
#  'ATACTAGCATGACCCT': 'CL:0000057',
#  'ATACTGCCTTACACCG': 'CL:0000584',
#  'ATACTTGTTCTCGAGC': 'CL:0000584',
#  'ATAGACAACGGGACCT': 'CL:0000186',
#  'ATAGACGAAGAGAAAG': 'CL:0009010',
#  'ATAGAGTACTGGGACA': 'CL:0000186',
#  'ATAGAGTTATCAACTT': 'CL:0000584',
#  'ATAGCAACTAGGGAAG': 'CL:0000584',
#  'ATAGCCATAACAGTCA': 'CL:0000034',
#  'ATAGCCTCAGTACCCA': 'CL:0000584',
#  'ATAGCTGCTCTTGTTA': 'CL:0000186',
#  'ATAGGCGGCTATAGAA': 'CL:0000034',
#  'ATAGGCTAGCTTCGCA': 'CL:0009010',
#  'ATAGGGATATCCTTGA': 'CL:0009010',
#  'ATAGGTTGGGCAGATG': 'CL:0000034',
#  'ATAGTGAAGCGTTCTC': 'CL:0000584',
#  'ATAGTTCCACCCACTC': 'CL:0000034',
#  'ATATAAAGCGCTCGTG': 'CL:0000584',
#  'ATATAACACGGGCGCA': 'CL:0000034',
#  'ATATACATGTATGGTA': 'CL:0000584',
#  'ATATAGAGTATTGGTC': 'CL:0000584',
#  'ATATCAACCTACAGAG': 'CL:0000584',
#  'ATATCGGTAGGGAGAT': 'CL:0000034',
#  'ATATCGTTCCTCGAAC': 'CL:0000034',
#  'ATATCTCCCTCGTTAA': 'CL:0009010',
#  'ATATGGGATAGCAACT': 'CL:0000584',
#  'ATATGTCTCCCTAGCC': 'CL:0000584',
#  'ATATTCAGTTAAACCT': 'CL:0000034',
#  'ATATTCCACATAGTGA': 'CL:0000584',
#  'ATATTCCCACAGGTCA': 'CL:0000584',
#  'ATATTGCTGTCAAAGT': 'CL:0009010',
#  'ATATTTAACCCTCAAG': 'CL:0000584',
#  'ATCAAACACTGTTCCA': 'CL:0000034',
#  'ATCAAACGAAGGTTTG': 'CL:0000066',
#  'ATCAAGATCCCAGGAC': 'CL:0000584',
#  'ATCAATCTGGGCTGCA': 'CL:0000584',
#  'ATCAATGCCGTGGCTG': 'CL:0000034',
#  'ATCACATTAGAATATC': 'CL:0000584',
#  'ATCACGTGCTAATTAA': 'CL:0000584',
#  'ATCACTTCATCCTCGC': 'CL:0000057',
#  'ATCAGACGGCACGCCG': 'CL:0000034',
#  'ATCAGCCTCATGCTGC': 'CL:0000034',
#  'ATCAGCTCGTCCACTA': 'CL:0000034',
#  'ATCAGTAGGCAGGGAT': 'CL:0000584',
#  'ATCATAGATCGACGAG': 'CL:0000034',
#  'ATCATAGCCCTATGTA': 'CL:0000584',
#  'ATCATCCAATATTTGT': 'CL:0000584',
#  'ATCATGGACTACCGAC': 'CL:0000034',
#  'ATCATTGTACCGCATT': 'CL:0000584',
#  'ATCCAACGCAGTCATA': 'CL:0009010',
#  'ATCCAATGGAGGGTCC': 'CL:0000034',
#  'ATCCAATGGTACCGAA': 'CL:0009010',
#  'ATCCAGAGCAACAACC': 'CL:0000034',
#  'ATCCAGGATTCGTGAA': 'CL:0000034',
#  'ATCCCATCCACAGCGC': 'CL:0000034',
#  'ATCCCATTTCCGTGGG': 'CL:0009010',
#  'ATCCTACCTAAGCTCT': 'CL:0000584',
#  'ATCCTGAATCGCTGCG': 'CL:0000034',
#  'ATCCTGCGTGGAATGG': 'CL:0000584',
#  'ATCCTTCTGAAAGAAC': 'CL:0000584',
#  'ATCGACCCAATACAGA': 'CL:0009010',
#  'ATCGACTCTTTCCGTT': 'CL:0000584',
#  'ATCGCACGCCGGGAGA': 'CL:0000186',
#  'ATCGCCAGTCAACATT': 'CL:0000034',
#  'ATCGCCGTGGTTCATG': 'CL:0000584',
#  'ATCGCTGCGTGCAGCA': 'CL:0000584',
#  'ATCGCTTTACGTCTCA': 'CL:0000584',
#  'ATCGGCAAGCAGTCCA': 'CL:0000186',
#  'ATCGGTTACCTAGTAA': 'CL:0000584',
#  'ATCGTATTCCGAGAAC': 'CL:0000584',
#  'ATCGTGGAAAGTCTGG': 'CL:0000034',
#  'ATCGTTAGCTAGCGGA': 'CL:0009010',
#  'ATCTACCATCTGCTCC': 'CL:0000584',
#  'ATCTAGCTTGTGAGGG': 'CL:0000584',
#  'ATCTCCCACGGAATAT': 'CL:0000584',
#  'ATCTCCCTGCAATCTA': 'CL:0009010',
#  'ATCTCGTGAGCGAAAC': 'CL:0000584',
#  'ATCTGACATGGAAGGA': 'CL:0000034',
#  'ATCTGATAGTGTCTTA': 'CL:0000186',
#  'ATCTGCACCTCTGCGA': 'CL:0000584',
#  'ATCTGGTTAAGACTGT': 'CL:0000034',
#  'ATCTGTAATTGTACCC': 'CL:0009010',
#  'ATCTTAGGGCATTAAT': 'CL:0009010',
#  'ATCTTATCGCACACCC': 'CL:0000584',
#  'ATCTTGACCTGCAACG': 'CL:0000186',
#  'ATCTTGACTTGTCCAA': 'CL:0000057',
#  'ATCTTTCGTATAACCA': 'CL:0009010',
#  'ATGAAGCCAAGGAGCC': 'CL:0009010',
#  'ATGAAGTGGACCCAGC': 'CL:0000584',
#  'ATGACGCCGGCTCTAA': 'CL:0000584',
#  'ATGACGCGTTCTATCC': 'CL:0000034',
#  'ATGAGGAGTGTTAATC': 'CL:0009010',
#  'ATGAGGGCAGCGGCTA': 'CL:0000584',
#  'ATGATCGGGAATAGAC': 'CL:0000584',
#  'ATGATGCAATGGTACA': 'CL:0000584',
#  'ATGCACCTTCCTTAAT': 'CL:0000584',
#  'ATGCACGCGCTGTTCA': 'CL:0009010',
#  'ATGCACTACCGCATTG': 'CL:0000034',
#  'ATGCATGATCCAGGAT': 'CL:0000186',
#  'ATGCCGGTCTTGCATA': 'CL:0000584',
#  'ATGCCGGTTGATGGGA': 'CL:0000584',
#  'ATGCGACAGTCCCATT': 'CL:0009010',
#  'ATGCGAGTCCCACCAC': 'CL:0000186',
#  'ATGCTCAGTGTTGCAT': 'CL:0000584',
#  'ATGCTTAGGAGTTGAT': 'CL:0000034',
#  'ATGGAACCTTTGCACA': 'CL:0009010',
#  'ATGGAGCAGGCCGTGA': 'CL:0009010',
#  'ATGGATCCGGCGTCCG': 'CL:0000584',
#  'ATGGATTGACCAAACG': 'CL:0000034',
#  'ATGGCAGCATTACGAT': 'CL:0000034',
#  'ATGGCAGCCGAGAAAC': 'CL:0009010',
#  'ATGGCGGAATAGTCGC': 'CL:0000584',
#  'ATGGGACCTGCTGAAC': 'CL:0000186',
#  'ATGGGTGTATACCTCC': 'CL:0000584',
#  'ATGGTATTTACTGATT': 'CL:0000584',
#  'ATGTAAGGCTGCTCTT': 'CL:0009010',
#  'ATGTACATGCGGTGAG': 'CL:0000034',
#  'ATGTACGATGACGTCG': 'CL:0000584',
#  'ATGTAGCGCGCGTAGG': 'CL:0009010',
#  'ATGTCATTTCCCATTG': 'CL:0000186',
#  'ATGTCTTGTTTGACTC': 'CL:0000584',
#  'ATGTGAAAGCCTAATG': 'CL:0000034',
#  'ATGTGCATCCGACGCA': 'CL:0000584',
#  'ATGTGGACATCTTGAT': 'CL:0000584',
#  'ATGTTACGAGCAATAC': 'CL:0000584',
#  'ATGTTCGTCGACCCAC': 'CL:0000584',
#  'ATGTTGATTAGAGACT': 'CL:0000034',
#  'ATGTTTCGGCCCGGAG': 'CL:0009010',
#  'ATTAAACATGCGGACC': 'CL:0000034',
#  'ATTAATACTACGCGGG': 'CL:0000057',
#  'ATTAATGAACCAGTCG': 'CL:0000034',
#  'ATTAATTCGGTCACTC': 'CL:0000584',
#  'ATTACATGTCAGTCTT': 'CL:0000034',
#  'ATTACCACACTGCCTG': 'CL:0000584',
#  'ATTACGCGCTGGCAGG': 'CL:0000584',
#  'ATTACGGGCTACGGTT': 'CL:0000584',
#  'ATTACTAGCCTCTTGC': 'CL:0000584',
#  'ATTACTTACTGGGCAT': 'CL:0000186',
#  'ATTAGATTCCTCAGCA': 'CL:0009010',
#  'ATTAGATTGATAGCGG': 'CL:0000584',
#  'ATTAGGCGATGCTTTC': 'CL:0009010',
#  'ATTATACTTTGCTCGT': 'CL:0000584',
#  'ATTATAGCTACTTTAC': 'CL:0000034',
#  'ATTATCGGAATGTACG': 'CL:0000034',
#  'ATTATGAGACCCAATT': 'CL:0000584',
#  'ATTATTATGTCCGTCA': 'CL:0000034',
#  'ATTATTCAGAGTCACT': 'CL:0000034',
#  'ATTCAACCATTTAAGG': 'CL:0000034',
#  'ATTCAGGACCTATTTC': 'CL:0000584',
#  'ATTCATATACTGTCCA': 'CL:0000584',
#  'ATTCATCGTTGAGGCA': 'CL:0000034',
#  'ATTCCCACATAAACAA': 'CL:0000584',
#  'ATTCCTCCGCCAGTGC': 'CL:0009010',
#  'ATTCGACGCCGGGCCT': 'CL:0000034',
#  'ATTCGCGCCTTGAGAG': 'CL:0000034',
#  'ATTCGTGCTATCTCTT': 'CL:0000034',
#  'ATTCTCGTCTCTTTAG': 'CL:0000584',
#  'ATTGAAGATCTTAGTG': 'CL:0000584',
#  'ATTGATCACCACATTT': 'CL:0000034',
#  'ATTGATGAGTCCTAAC': 'CL:0000034',
#  'ATTGCCTATTAGACCG': 'CL:0000034',
#  'ATTGCCTTTATGTTTG': 'CL:0000584',
#  'ATTGCTGCTCCTCCAT': 'CL:0000034',
#  'ATTGGATTACAGCGTA': 'CL:0000034',
#  'ATTGGGAATATCTTGG': 'CL:0000584',
#  'ATTGGTAGGATCCGCT': 'CL:0000584',
#  'ATTGGTTGTGCATTAC': 'CL:0000584',
#  'ATTGTACAACTCGGCT': 'CL:0000584',
#  'ATTGTCGCAATACCTT': 'CL:0000584',
#  'ATTGTCTGTTTCATGT': 'CL:0000584',
#  'ATTGTTCAACGATCCG': 'CL:0000584',
#  'ATTTAACTCGTATTAC': 'CL:0000186',
#  'ATTTACAGTTTACTGG': 'CL:0000584',
#  'ATTTACTAAGTCCATT': 'CL:0000034',
#  'ATTTCATTATTTCGCG': 'CL:0009010',
#  'ATTTCCGGGTTCTGCG': 'CL:0000034',
#  'ATTTGCGCGAGTAGCT': 'CL:0000034',
#  'ATTTGTCTTGGGAGCT': 'CL:0000584',
#  'ATTTGTTCCAGGGCTC': 'CL:0000584',
#  'CAAACCAGGTCTGCAT': 'CL:0000584',
#  'CAAACCCTCCGGCGGG': 'CL:0009010',
#  'CAAACGAGTATCGCAG': 'CL:0000034',
#  'CAAACGGTCGCACTTT': 'CL:0000584',
#  'CAAACTACGATAGAGA': 'CL:0000186',
#  'CAAACTATTGAGCTTC': 'CL:0009010',
#  'CAAACTCGCGACGCCG': 'CL:0000034',
#  'CAAAGATTATTGGGCC': 'CL:0000186',
#  'CAAAGGTCATCTGAAA': 'CL:0000584',
#  'CAAATCTCTCACAAGG': 'CL:0000186',
#  'CAAATGTCCTTCCGTG': 'CL:0000034',
#  'CAAATTGTCAGCAAGC': 'CL:0000584',
#  'CAACCAGTGGCCTACC': 'CL:0000584',
#  'CAACCTACCGAGCAGT': 'CL:0000034',
#  'CAACGATCGATCCAAT': 'CL:0009010',
#  'CAACGCGATGAGCCAA': 'CL:0000584',
#  'CAACGGTTCTTGATAC': 'CL:0000584',
#  'CAACGTGGTGGAGTCT': 'CL:0000034',
#  'CAACTCCTTGATCCCG': 'CL:0000584',
#  'CAACTGCTCATCCGAT': 'CL:0000034',
#  'CAAGAGGGCGGAGTAC': 'CL:0000584',
#  'CAAGCAACGTCGGAGT': 'CL:0000584',
#  'CAAGCACCAAATGCCT': 'CL:0000584',
#  'CAAGGATCGCATGTTC': 'CL:0000584',
#  'CAAGGCCAGTGGTGCA': 'CL:0000584',
#  'CAAGGTCCTATAGGCT': 'CL:0000584',
#  'CAAGTAAGTGATAGAC': 'CL:0009010',
#  'CAAGTGTGGTTGCAAA': 'CL:0000584',
#  'CAATAAACCTTGGCCC': 'CL:0000034',
#  'CAATACGAGAGTCTGA': 'CL:0000584',
#  'CAATACGCTCTGAGGC': 'CL:0000584',
#  'CAATATTCTTGACCTA': 'CL:0000584',
#  'CAATCCTGCCGTGGAG': 'CL:0009010',
#  'CAATGAGGTTCGACTA': 'CL:0000584',
#  'CAATGCGAGAAGTATC': 'CL:0000584',
#  'CAATGGATCTCTACCA': 'CL:0000066',
#  'CAATGTGCCAACCCTT': 'CL:0000584',
#  'CAATTAAGGGTGATGA': 'CL:0000584',
#  'CAATTTCGTATAAGGG': 'CL:0009010',
#  'CACAAACCGCAGAACT': 'CL:0000034',
#  'CACAAGCTAAGAAAGG': 'CL:0000584',
#  'CACAATGAGCTGCTAT': 'CL:0000584',
#  'CACACACGCTAACGAG': 'CL:0000034',
#  'CACACAGCTTGCGCTC': 'CL:0000584',
#  'CACACAGGGATAGATT': 'CL:0000584',
#  'CACACGCGCTGTCTTA': 'CL:0000034',
#  'CACAGAGACGAGGACG': 'CL:0000034',
#  'CACAGCACCCACGGCA': 'CL:0009010',
#  'CACAGCTAGGGAGTGA': 'CL:0000057',
#  'CACAGGGCCATATAGT': 'CL:0000584',
#  'CACAGGGCCGTTGTCA': 'CL:0000034',
#  'CACAGTCCCGCTTCGC': 'CL:0000584',
#  'CACAGTTCGCTTCCCA': 'CL:0000034',
#  'CACATATTAGCAGGAT': 'CL:0000584',
#  'CACATCGTGCACGCGC': 'CL:0000034',
#  'CACATGATTCAGCAAC': 'CL:0009010',
#  'CACATTCTTTCGATGG': 'CL:0009010',
#  'CACATTTCTTGTCAGA': 'CL:0000584',
#  'CACCACGCCACACAGA': 'CL:0000584',
#  'CACCAGTCAGCATGCA': 'CL:0000034',
#  'CACCATCGGAGGAGAC': 'CL:0009010',
#  'CACCCAAATCTTATGT': 'CL:0000034',
#  'CACCCACACGTCACCC': 'CL:0000584',
#  'CACCCACGAGGCAATT': 'CL:0000584',
#  'CACCCGCGTTTGACAC': 'CL:0000034',
#  'CACCCGGTTTGTGACT': 'CL:0000034',
#  'CACCCTTGGTGAGACC': 'CL:0000034',
#  'CACCGATGATGGGTAC': 'CL:0000584',
#  'CACCGCCAGAAGGTTT': 'CL:0000034',
#  'CACCGGGCATCACAAG': 'CL:0000584',
#  'CACCGGTAGAGACATT': 'CL:0000584',
#  'CACCGTATCCCATCCG': 'CL:0000034',
#  'CACCGTTAGGGATCAC': 'CL:0000034',
#  'CACCTAATAGAGTCGT': 'CL:0000584',
#  'CACCTAATCAGTTTAC': 'CL:0009010',
#  'CACCTCGATGGTGGAC': 'CL:0000584',
#  'CACCTTGCGAAACTCG': 'CL:0000584',
#  'CACCTTGGCGCCTTTG': 'CL:0000034',
#  'CACGAAAGTTAGTCCC': 'CL:0000034',
#  'CACGAGCAAACCAGAC': 'CL:0000057',
#  'CACGCACAGCGCAGCT': 'CL:0000057',
#  'CACGCAGCGAGGCTTT': 'CL:0000584',
#  'CACGCGGAACTGTTGC': 'CL:0000186',
#  'CACGGGATTGAGGGTT': 'CL:0000584',
#  'CACGTCGGCAACCTCT': 'CL:0000584',
#  'CACGTTCGTGCTCTAG': 'CL:0000034',
#  'CACGTTTCGTACACAC': 'CL:0009010',
#  'CACTAAAGTTGCCTAT': 'CL:0000034',
#  'CACTACGGGAGCTGCC': 'CL:0000584',
#  'CACTCAAGAGCTATGG': 'CL:0000584',
#  'CACTCAGCTCTTGAGG': 'CL:0009010',
#  'CACTCCTATGTAAGAT': 'CL:0000034',
#  'CACTCCTCTCGGTCGG': 'CL:0000584',
#  'CACTCGAGCTGAACAA': 'CL:0000066',
#  'CACTCGGTTAGGAGGA': 'CL:0000584',
#  'CACTCTCAAGCATCGA': 'CL:0000584',
#  'CACTCTTCTGCTAGCC': 'CL:0000186',
#  'CACTGTCCAAGTGAGA': 'CL:0000584',
#  'CACTTAATCAGACGGA': 'CL:0000034',
#  'CACTTCGCCACAGGCT': 'CL:0000584',
#  'CAGAACTTAGCCCTCT': 'CL:0000584',
#  'CAGAATAACACACGGA': 'CL:0000034',
#  'CAGAATATTCGTTATC': 'CL:0000584',
#  'CAGACACCGATCGCTG': 'CL:0000584',
#  'CAGACCTGTAAGTGTT': 'CL:0000034',
#  'CAGACGAACCTGATAC': 'CL:0000034',
#  'CAGAGACGGTCACCCA': 'CL:0000034',
#  'CAGAGCATGAGCTTGC': 'CL:0000034',
#  'CAGAGCGATGGATGCT': 'CL:0000584',
#  'CAGAGGCGATGCATGA': 'CL:0000584',
#  'CAGATAATGGGCGGGT': 'CL:0000584',
#  'CAGATACTAACATAGT': 'CL:0000186',
#  'CAGATCATTTAAAGTC': 'CL:0000584',
#  'CAGATGTTTGTCCCAA': 'CL:0000584',
#  'CAGCAGCCCGTTCCTT': 'CL:0000584',
#  'CAGCAGTCCAGACTAT': 'CL:0000584',
#  'CAGCCTCGATAGCGGT': 'CL:0000034',
#  'CAGCCTCTCCTCAAGA': 'CL:0009010',
#  'CAGCGATTCCCTTCAA': 'CL:0000584',
#  'CAGCGCCAACACGATA': 'CL:0009010',
#  'CAGCTCACTGAGACAT': 'CL:0000034',
#  'CAGCTCGACAAGTTAA': 'CL:0000034',
#  'CAGCTCGTGCTTGTGT': 'CL:0000584',
#  'CAGCTCTGGGCTCACT': 'CL:0000034',
#  'CAGCTGGCGTAACCGT': 'CL:0000034',
#  'CAGCTTAGTAGGTAGC': 'CL:0000186',
#  'CAGGAAGACTTTATAT': 'CL:0009010',
#  'CAGGACAGCTGCCCTT': 'CL:0009010',
#  'CAGGATATATCGTTGT': 'CL:0000034',
#  'CAGGCAGTCTTACCAG': 'CL:0000584',
#  'CAGGCCAGTACCACCT': 'CL:0000186',
#  'CAGGCCGTTTGGGTGT': 'CL:0000186',
#  'CAGGCGCCATGCTAGG': 'CL:0000584',
#  'CAGGGAGATAGGCCAG': 'CL:0000034',
#  'CAGTAACTATTTATTG': 'CL:0000584',
#  'CAGTAAGGGACGTCTC': 'CL:0000584',
#  'CAGTAATCCCTCCCAG': 'CL:0000584',
#  'CAGTACATTCTCTAAA': 'CL:0000584',
#  'CAGTACCAGTTTACGT': 'CL:0000186',
#  'CAGTAGCCCACGCGGT': 'CL:0009010',
#  'CAGTCGAGGATGCAAT': 'CL:0009010',
#  'CAGTCGGCCTAGATAT': 'CL:0000584',
#  'CAGTCTGTATACTGGG': 'CL:0000584',
#  'CAGTGGTTGCACATGA': 'CL:0000584',
#  'CAGTGTCGGCTGGCCC': 'CL:0000584',
#  'CAGTGTTAATCTCTCA': 'CL:0000186',
#  'CAGTTCAAATTGACAC': 'CL:0000584',
#  'CAGTTCCGCGGGTCGA': 'CL:0000584',
#  'CAGTTCGAGGACCCGA': 'CL:0000034',
#  'CATAACGGACAGTCGT': 'CL:0009010',
#  'CATACAAAGCCGAACC': 'CL:0000584',
#  'CATACACGGTTCCCAC': 'CL:0000186',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACGGCGTCTGGGC': 'CL:0009010',
#  'CATACTATGTAATTGT': 'CL:0000034',
#  'CATACTTAGGCAATAC': 'CL:0000584',
#  'CATACTTCTTTCTCCG': 'CL:0009010',
#  'CATAGAGGAGATACTA': 'CL:0000584',
#  'CATAGCCGCCCGGGAT': 'CL:0000057',
#  'CATAGCGTTGCCCACC': 'CL:0000584',
#  'CATAGGGACACTTGTG': 'CL:0000034',
#  'CATAGTAGCATAGTAG': 'CL:0000584',
#  'CATAGTCAAATACATA': 'CL:0000034',
#  'CATAGTCCACAAGAAC': 'CL:0000034',
#  'CATAGTGGGCACGCCT': 'CL:0000584',
#  'CATATACTACTGATAA': 'CL:0000584',
#  'CATATAGGTACAGTCA': 'CL:0000034',
#  'CATATGTCAGGCTACG': 'CL:0000584',
#  'CATCATCTACCCGGAC': 'CL:0009010',
#  'CATCCCGAGATTCATA': 'CL:0000584',
#  'CATCCGCAGGCCCGAA': 'CL:0000584',
#  'CATCCTCTCAAAGATC': 'CL:0000584',
#  'CATCGCCCGCGGCCAA': 'CL:0009010',
#  'CATCGGACGGGTTAAT': 'CL:0000034',
#  'CATCGTCCGGTTACTA': 'CL:0009010',
#  'CATCTATCCCGTGTCT': 'CL:0000584',
#  'CATCTTACACCACCTC': 'CL:0000034',
#  'CATGACTTCGCTGAAT': 'CL:0000034',
#  'CATGATGCACAATTCT': 'CL:0000057',
#  'CATGATGGAAGTTAGC': 'CL:0000034',
#  'CATGCACATGAGAGGC': 'CL:0000057',
#  'CATGCCAACTCGCAAA': 'CL:0000186',
#  'CATGCGACCAGTTTAA': 'CL:0009010',
#  'CATGCGTTAGACAGAA': 'CL:0000584',
#  'CATGCGTTGAGAGGAG': 'CL:0000034',
#  'CATGCTGGCTCCAATT': 'CL:0000584',
#  'CATGGATTGTCTTCCG': 'CL:0000584',
#  'CATGGCAGGAAGATCG': 'CL:0000584',
#  'CATGGCTCCCTATGTC': 'CL:0000584',
#  'CATGGGTATGCCTTAT': 'CL:0000584',
#  'CATGGGTCGGGTGTGG': 'CL:0000584',
#  'CATGGTATTAGTTTGT': 'CL:0009010',
#  'CATGGTCTAGATACCG': 'CL:0000034',
#  'CATGGTTTATTAATCA': 'CL:0000584',
#  'CATGTAAGAGACATTT': 'CL:0009010',
#  'CATGTCTCATTTATGG': 'CL:0000584',
#  'CATTACATAGATTGTG': 'CL:0000584',
#  'CATTACGCAGGAAGGG': 'CL:0000034',
#  'CATTACGTCGGCCCGT': 'CL:0000584',
#  'CATTATGCTTGTTGTG': 'CL:0000186',
#  'CATTGCGAAATGGGCG': 'CL:0000584',
#  'CATTGCGGGTCAATTC': 'CL:0009010',
#  'CATTTAGCGGACCATG': 'CL:0000584',
#  'CATTTCTAGCAGACTA': 'CL:0000584',
#  'CCAAACAGAACCCTCG': 'CL:0000584',
#  'CCAAATAACAAGATTC': 'CL:0000066',
#  'CCAAATCAAAGGGCAA': 'CL:0000034',
#  'CCAACCTTATGTAACT': 'CL:0000034',
#  'CCAACGATGCACTGAT': 'CL:0000584',
#  'CCAAGAAAGTGGGCGA': 'CL:0000066',
#  'CCAAGACTTCTGCGAA': 'CL:0000584',
#  'CCAAGCGTAACTCGTA': 'CL:0000584',
#  'CCAAGGAACAGAGAGG': 'CL:0000186',
#  'CCAAGGTTGCCCTTTC': 'CL:0000584',
#  'CCAATAGATTTCATCT': 'CL:0000584',
#  'CCAATAGTGCCGTCGA': 'CL:0000034',
#  'CCAATCGGTAGATCGA': 'CL:0000584',
#  'CCAATGTCACAGCAAG': 'CL:0000034',
#  'CCAATTACGGGTCGAG': 'CL:0009010',
#  'CCAATTGAATGTTAAT': 'CL:0000584',
#  'CCACAATGTACGTCTT': 'CL:0000066',
#  'CCACACTGAGATATTA': 'CL:0000034',
#  'CCACATACTGCACCCA': 'CL:0000584',
#  'CCACCAACTTTACTGT': 'CL:0000066',
#  'CCACCCAAGGAAAGTG': 'CL:0000034',
#  'CCACCTGTATGGAATA': 'CL:0000584',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              502
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5479
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             1137
# AAACACCAATAACTGC-1        1.0       59.0       59.0             7597
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4820
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5928
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             5305
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             4907
# TTGTTTGTGTAAATTC-1        0.0        7.0        7.0             1382
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0009010
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                 CL:0000034
# AAACAGAGCGACTCCT-1                 CL:0009010
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000034
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                 CL:0000034
# TTGTTTGTATTACACG-1                 CL:0000584
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 1797

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_51818/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              502
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5479
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             1137
# AAACACCAATAACTGC-1        1.0       59.0       59.0             7597
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4820
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5928
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             5305
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             4907
# TTGTTTGTGTAAATTC-1        0.0        7.0        7.0             1382
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0009010
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                 CL:0000034
# AAACAGAGCGACTCCT-1                 CL:0009010
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000034
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                 CL:0000034
# TTGTTTGTATTACACG-1                 CL:0000584
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0009010',
#  'CL:0000034',
#  'CL:0000584',
#  'CL:0000186',
#  'CL:0000066',
#  'CL:0000057',
#  'CL:0000235',
#  'CL:0000844',
#  'CL:0007011',
#  'CL:0000775',
#  'CL:0000787',
#  'CL:0000125']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    3B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1    3B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1    3B_Hh.anti_IL10r
# AAACACCAATAACTGC-1    3B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1    3B_Hh.anti_IL10r
#                             ...
# TTGTTTCACATCCAGG-1    3B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1    3B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1    3B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1    3B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1    3B_Hh.anti_IL10r
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['3B_Hh.anti_IL10r']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              502
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5479
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             1137
# AAACACCAATAACTGC-1        1.0       59.0       59.0             7597
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4820
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5928
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             5305
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             4907
# TTGTTTGTGTAAATTC-1        0.0        7.0        7.0             1382
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  3B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                 CL:0009010  3B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                    unknown  3B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000034  3B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                 CL:0009010  3B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                 CL:0000034  3B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                    unknown  3B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000034  3B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                 CL:0000584  3B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                    unknown  3B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290869_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8),
#                  'lowres': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.2648305,
#                  'tissue_lowres_scalef': 0.079449154,
#                  'fiducial_diameter_fullres': 59.017391806234194,
#                  'spot_diameter_fullres': 36.534575880049736}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290869_mm10-2020-A/V12U21-349_B1-5x.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '3B_Hh.anti_IL10r'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290869_mm10-2020-A': {'images': {'hires': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8),
#                  'fullres': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.2648305,
#                  'spot_diameter_fullres': 36.534575880049736}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '3B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              502
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             5479
# AAACAATCTACTAGCA-1        0.0        3.0        3.0             1137
# AAACACCAATAACTGC-1        1.0       59.0       59.0             7597
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             4820
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             5928
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             5305
# TTGTTTGTATTACACG-1        1.0       73.0       73.0             4907
# TTGTTTGTGTAAATTC-1        0.0        7.0        7.0             1382
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  3B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                 CL:0009010  3B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                    unknown  3B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000034  3B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                 CL:0009010  3B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                 CL:0000034  3B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                    unknown  3B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000034  3B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                 CL:0000584  3B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                    unknown  3B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290869_mm10-2020-A': {'images': {'hires': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8),
#                  'fullres': array([[[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         ...,
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]],
#
#                         [[246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          ...,
#                          [246, 244, 246],
#                          [246, 244, 246],
#                          [246, 244, 246]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.2648305,
#                  'spot_diameter_fullres': 36.534575880049736}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '3B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_51818/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13290869.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0          0              502
# AAACAAGTATCTCCCA-1          1         50         50             5479
# AAACAATCTACTAGCA-1          0          3          3             1137
# AAACACCAATAACTGC-1          1         59         59             7597
# AAACAGAGCGACTCCT-1          1         14         14             7610
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         58             4820
# TTGTTTCATTAGTCTA-1          1         60         60             5928
# TTGTTTCCATACAACT-1          1         45         45             5305
# TTGTTTGTATTACACG-1          1         73         73             4907
# TTGTTTGTGTAAATTC-1          0          7          7             1382
#
#                    assay_ontology_term_id cell_type_ontology_term_id  \
# AAACAACGAATAGTTC-1            EFO:0010961                    unknown
# AAACAAGTATCTCCCA-1            EFO:0010961                 CL:0009010
# AAACAATCTACTAGCA-1            EFO:0010961                    unknown
# AAACACCAATAACTGC-1            EFO:0010961                 CL:0000034
# AAACAGAGCGACTCCT-1            EFO:0010961                 CL:0009010
# ...                                   ...                        ...
# TTGTTTCACATCCAGG-1            EFO:0010961                 CL:0000034
# TTGTTTCATTAGTCTA-1            EFO:0010961                    unknown
# TTGTTTCCATACAACT-1            EFO:0010961                 CL:0000034
# TTGTTTGTATTACACG-1            EFO:0010961                 CL:0000584
# TTGTTTGTGTAAATTC-1            EFO:0010961                    unknown
#
#                             donor_id development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAAGTATCTCCCA-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAATCTACTAGCA-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# AAACACCAATAACTGC-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAGAGCGACTCCT-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# ...                              ...                                ...
# TTGTTTCACATCCAGG-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCCATACAACT-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTATTACACG-1  3B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1  3B_Hh.anti_IL10r                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 16 columns]

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)
# Out:
# Missing columns: []

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
# Out:
# Data Types:
# array_col    int64
# array_row    int64
# in_tissue    int64
# dtype: object
#
# Missing Values:
# array_col    0
# array_row    0
# in_tissue    0
# dtype: int64

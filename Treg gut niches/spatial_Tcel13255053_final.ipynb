# %% [markdown]
# ### **Curating Tcel13255053**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255053_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)

# %%
all_barcodes
# Out:
#                        0          1          2          3                   4  \
# 0                barcode  in_tissue  array_row  array_col  pxl_row_in_fullres
# 1     ACGCCTGACACGCGCT-1          0          0          0                1941
# 2     TACCGATCCAACACTT-1          0          1          1                2132
# 3     ATTAAAGCGGACGAGC-1          0          0          2                1942
# 4     GATAAGGGACGATTAG-1          0          1          3                2133
# ...                  ...        ...        ...        ...                 ...
# 4988  GAACGTTTGTATCCAC-1          0         77        123               16689
# 4989  ATTGAATTCCCTGTAG-1          0         76        124               16498
# 4990  TACCTCACCAATTGTA-1          0         77        125               16689
# 4991  AGTCGAATTAGCGTAA-1          0         76        126               16498
# 4992  TTGAAGTGCATCTACA-1          0         77        127               16690
#
#                        5
# 0     pxl_col_in_fullres
# 1                   4934
# 2                   5043
# 3                   5153
# 4                   5263
# ...                  ...
# 4988               18403
# 4989               18514
# 4990               18623
# 4991               18733
# 4992               18843
#
# [4993 rows x 6 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 16634529 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 13)	1.0
#   (0, 16)	1.0
#   (0, 38)	1.0
#   (0, 40)	1.0
#   (0, 63)	12.0
#   (0, 64)	1.0
#   (0, 71)	1.0
#   (0, 101)	1.0
#   (0, 118)	2.0
#   (0, 120)	1.0
#   (0, 123)	1.0
#   (0, 131)	1.0
#   (0, 149)	3.0
#   (0, 156)	1.0
#   (0, 168)	6.0
#   (0, 179)	1.0
#   (0, 185)	7.0
#   (0, 193)	19.0
#   (0, 198)	3.0
#   (0, 205)	4.0
#   (0, 207)	1.0
#   (0, 213)	2.0
#   (0, 214)	1.0
#   (0, 218)	2.0
#   (0, 220)	1.0
#   :	:
#   (4991, 31339)	1.0
#   (4991, 31342)	1.0
#   (4991, 31378)	3.0
#   (4991, 31379)	1.0
#   (4991, 31392)	1.0
#   (4991, 31393)	1.0
#   (4991, 31395)	1.0
#   (4991, 31409)	1.0
#   (4991, 31414)	1.0
#   (4991, 31415)	1.0
#   (4991, 31418)	2.0
#   (4991, 31428)	1.0
#   (4991, 31440)	1.0
#   (4991, 31450)	12.0
#   (4991, 32193)	5.0
#   (4991, 32195)	3.0
#   (4991, 32196)	2.0
#   (4991, 32197)	13.0
#   (4991, 32198)	12.0
#   (4991, 32200)	19.0
#   (4991, 32201)	31.0
#   (4991, 32202)	2.0
#   (4991, 32204)	2.0
#   (4991, 32207)	3.0
#   (4991, 32284)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             3878
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             8180
# AAACAATCTACTAGCA-1        1.0        3.0        3.0               78
# AAACACCAATAACTGC-1        0.0       59.0       59.0              887
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        0.0       58.0       58.0             2015
# TTGTTTCATTAGTCTA-1        0.0       60.0       60.0             5414
# TTGTTTCCATACAACT-1        0.0       45.0       45.0             1477
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              273
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2107
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13255053_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1        1.0  1A_Hh.only               8180
# Mus_Tcel13255053_AAACATTTCCCGGATT-1        1.0  1A_Hh.only               6584
# Mus_Tcel13255053_AAACCCGAACGAAATC-1        1.0  1A_Hh.only               8862
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1        1.0  1A_Hh.only               8490
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1        1.0  1A_Hh.only               4576
# ...                                        ...         ...                ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1        1.0  1A_Hh.only               5914
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1        1.0  1A_Hh.only               4335
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1        1.0  1A_Hh.only               6565
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1        1.0  1A_Hh.only               5103
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1        1.0  1A_Hh.only               2107
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                 9.009570       40689.0
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                 8.792550       41999.0
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                 9.089641       97637.0
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                 9.046762       39282.0
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                 8.428799       12352.0
# ...                                                      ...           ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                 8.685246       19541.0
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                 8.374707        9995.0
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                 8.789660       46131.0
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                 8.537780       16254.0
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                 7.653495        3569.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1           10.613738
# Mus_Tcel13255053_AAACATTTCCCGGATT-1           10.645425
# Mus_Tcel13255053_AAACCCGAACGAAATC-1           11.489022
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1           10.578547
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1            9.421654
# ...                                                 ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1            9.880322
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1            9.209940
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1           10.739263
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1            9.696156
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1            8.180321
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                   15.439062
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                   26.150623
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                   24.969017
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                   14.670841
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                   17.810881
# ...                                                         ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                   16.166010
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                   16.148073
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                   28.325855
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                   18.297035
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                   16.699356
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    23.721399
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    33.836521
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    32.589081
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    21.218370
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    24.417099
# ...                                                          ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    23.883118
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    22.811405
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    35.689667
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    25.532177
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    24.964975
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    34.336060
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    43.096264
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    41.907269
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    30.247952
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    33.047279
# ...                                                          ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    33.821198
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    31.715858
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    44.373631
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    34.791435
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    34.967777
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    47.742634  ...
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    57.165646  ...
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    56.314716  ...
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    44.096531  ...
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    47.838406  ...
# ...                                                          ...  ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    48.216572  ...
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    46.393196  ...
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    58.192974  ...
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    49.433987  ...
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    53.068085  ...
#
#                                        donor_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1  1A_Hh.only
# Mus_Tcel13255053_AAACATTTCCCGGATT-1  1A_Hh.only
# Mus_Tcel13255053_AAACCCGAACGAAATC-1  1A_Hh.only
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1  1A_Hh.only
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1  1A_Hh.only
# ...                                         ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1  1A_Hh.only
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1  1A_Hh.only
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1  1A_Hh.only
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1  1A_Hh.only
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1  1A_Hh.only
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                     MmusDv:0000061
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                     MmusDv:0000061
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                     MmusDv:0000061
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                     MmusDv:0000061
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                     MmusDv:0000061
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                     MmusDv:0000061
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                     MmusDv:0000061
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13255053_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13255053_AAACCCGAACGAAATC-1             PATO:0000461            True
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1             PATO:0000461            True
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACCCGAACGAAATC-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                                       na
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                                       na
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                                       na
# ...                                                                      ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                                       na
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1              unknown               na
# Mus_Tcel13255053_AAACATTTCCCGGATT-1              unknown               na
# Mus_Tcel13255053_AAACCCGAACGAAATC-1              unknown               na
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1              unknown               na
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1              unknown               na
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1              unknown               na
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1              unknown               na
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
# [2191 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue      sample  n_genes_by_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1        1.0  1A_Hh.only               8180
# Mus_Tcel13255053_AAACATTTCCCGGATT-1        1.0  1A_Hh.only               6584
# Mus_Tcel13255053_AAACCCGAACGAAATC-1        1.0  1A_Hh.only               8862
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1        1.0  1A_Hh.only               8490
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1        1.0  1A_Hh.only               4576
# ...                                        ...         ...                ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1        1.0  1A_Hh.only               5914
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1        1.0  1A_Hh.only               4335
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1        1.0  1A_Hh.only               6565
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1        1.0  1A_Hh.only               5103
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1        1.0  1A_Hh.only               2107
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                 9.009570       40689.0
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                 8.792550       41999.0
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                 9.089641       97637.0
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                 9.046762       39282.0
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                 8.428799       12352.0
# ...                                                      ...           ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                 8.685246       19541.0
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                 8.374707        9995.0
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                 8.789660       46131.0
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                 8.537780       16254.0
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                 7.653495        3569.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1           10.613738
# Mus_Tcel13255053_AAACATTTCCCGGATT-1           10.645425
# Mus_Tcel13255053_AAACCCGAACGAAATC-1           11.489022
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1           10.578547
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1            9.421654
# ...                                                 ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1            9.880322
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1            9.209940
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1           10.739263
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1            9.696156
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1            8.180321
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                   15.439062
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                   26.150623
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                   24.969017
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                   14.670841
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                   17.810881
# ...                                                         ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                   16.166010
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                   16.148073
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                   28.325855
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                   18.297035
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                   16.699356
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    23.721399
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    33.836521
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    32.589081
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    21.218370
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    24.417099
# ...                                                          ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    23.883118
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    22.811405
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    35.689667
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    25.532177
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    24.964975
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    34.336060
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    43.096264
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    41.907269
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    30.247952
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    33.047279
# ...                                                          ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    33.821198
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    31.715858
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    44.373631
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    34.791435
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    34.967777
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                    47.742634  ...
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                    57.165646  ...
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                    56.314716  ...
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                    44.096531  ...
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                    47.838406  ...
# ...                                                          ...  ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                    48.216572  ...
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                    46.393196  ...
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                    58.192974  ...
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                    49.433987  ...
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                    53.068085  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                      MmusDv:0000061
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                      MmusDv:0000061
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                      MmusDv:0000061
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                      MmusDv:0000061
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                      MmusDv:0000061
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                      MmusDv:0000061
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                      MmusDv:0000061
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13255053_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13255053_AAACCCGAACGAAATC-1             PATO:0000461            True
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1             PATO:0000461            True
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACCCGAACGAAATC-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1           NCBITaxon:10090
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13255053_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13255053_AAACCCGAACGAAATC-1                                       na
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1                                       na
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1                                       na
# ...                                                                      ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1                                       na
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1              unknown              na
# Mus_Tcel13255053_AAACATTTCCCGGATT-1              unknown              na
# Mus_Tcel13255053_AAACCCGAACGAAATC-1              unknown              na
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1              unknown              na
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1              unknown              na
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1              unknown              na
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1              unknown              na
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1       tissue           UBERON:0001155
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13255053_AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA
# Mus_Tcel13255053_AAACATTTCCCGGATT-1  AAACATTTCCCGGATT
# Mus_Tcel13255053_AAACCCGAACGAAATC-1  AAACCCGAACGAAATC
# Mus_Tcel13255053_AAACCTCATGAAGTTG-1  AAACCTCATGAAGTTG
# Mus_Tcel13255053_AAACGAGACGGTTGAT-1  AAACGAGACGGTTGAT
# ...                                               ...
# Mus_Tcel13255053_TTGTGTATGCCACCAA-1  TTGTGTATGCCACCAA
# Mus_Tcel13255053_TTGTTCAGTGTGCTAC-1  TTGTTCAGTGTGCTAC
# Mus_Tcel13255053_TTGTTCTAGATACGCT-1  TTGTTCTAGATACGCT
# Mus_Tcel13255053_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13255053_TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC
#
# [2191 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0009010',
#  'AAACATTTCCCGGATT': 'CL:0000584',
#  'AAACCCGAACGAAATC': 'CL:0000584',
#  'AAACCTCATGAAGTTG': 'CL:0007011',
#  'AAACGAGACGGTTGAT': 'CL:0000584',
#  'AAACGGGCGTACGGGT': 'CL:0009010',
#  'AAACGGTTGCGAACTG': 'CL:0009010',
#  'AAACTCGGTTCGCAAT': 'CL:0000584',
#  'AAACTGCTGGCTCCAA': 'CL:0007011',
#  'AAACTTGCAAACGTAT': 'CL:0000186',
#  'AAAGACTGGGCGCTTT': 'CL:0009010',
#  'AAAGGCTACGGACCAT': 'CL:0000844',
#  'AAAGGGATGTAGCAAG': 'CL:0000584',
#  'AAAGGGCAGCTTGAAT': 'CL:0000186',
#  'AAAGTCGACCCTCAGT': 'CL:0000584',
#  'AAAGTGTGATTTATCT': 'CL:0000584',
#  'AAAGTTGACTCCCGTA': 'CL:0000584',
#  'AAATAACCATACGGGA': 'CL:0000584',
#  'AAATAAGGTAGTGCCC': 'CL:0000584',
#  'AAATAGGGTGCTATTG': 'CL:0000186',
#  'AAATCCGATACACGCC': 'CL:0009010',
#  'AAATCGTGTACCACAA': 'CL:0000844',
#  'AAATCTAGCCCTGCTA': 'CL:0000584',
#  'AAATGCTCGTTACGTT': 'CL:0000584',
#  'AAATGGCATGTCTTGT': 'CL:0000844',
#  'AAATGTATCTTATCCC': 'CL:0009010',
#  'AAATTAACGGGTAGCT': 'CL:0000844',
#  'AAATTACACGACTCTG': 'CL:0000584',
#  'AAATTACCTATCGATG': 'CL:0000584',
#  'AAATTCCAGGTCCAAA': 'CL:0009010',
#  'AAATTTGCGGGTGTGG': 'CL:0000584',
#  'AACAATACATTGTCGA': 'CL:0000186',
#  'AACAATTACTCTACGC': 'CL:0000844',
#  'AACACGACTGTACTGA': 'CL:0000844',
#  'AACAGGAAATCGAATA': 'CL:0000584',
#  'AACAGGTAGTATGGAT': 'CL:0000584',
#  'AACATATCAACTGGTG': 'CL:0000844',
#  'AACATTGTGACTCGAG': 'CL:0000584',
#  'AACCCTACTGTCAATA': 'CL:0000584',
#  'AACCGAGCTTGGTCAT': 'CL:0000844',
#  'AACCGCTAAGGGATGC': 'CL:0000584',
#  'AACCGTTGTGTTTGCT': 'CL:0000584',
#  'AACCTTTAAATACGGT': 'CL:0000186',
#  'AACCTTTACGACGTCT': 'CL:0000584',
#  'AACGATAATGCCGTAG': 'CL:0000584',
#  'AACGATATGTCAACTG': 'CL:0007011',
#  'AACGCGAACGGCAACA': 'CL:0000584',
#  'AACGCGGTCTCCAGCC': 'CL:0000844',
#  'AACGGACGTACGTATA': 'CL:0000057',
#  'AACGGCCATCTCCGGT': 'CL:0000034',
#  'AACGTACTGTGGGTAC': 'CL:0000844',
#  'AACGTCAGACTAGTGG': 'CL:0000034',
#  'AACGTGCGAAAGTCTC': 'CL:0000844',
#  'AACTACCCGTTTGTCA': 'CL:0000584',
#  'AACTAGGCTTGGGTGT': 'CL:0000844',
#  'AACTCAAGTTAATTGC': 'CL:0000584',
#  'AACTCCAGAGCGTGTT': 'CL:0000584',
#  'AACTCGATGGCGCAGT': 'CL:0000584',
#  'AACTCTCAATAGAGCG': 'CL:0009010',
#  'AACTGGGTCCCGACGT': 'CL:0000584',
#  'AACTGGTGTGGGCCTT': 'CL:0000844',
#  'AACTTCTGCGTCTATC': 'CL:0009010',
#  'AACTTGCCCGTATGCA': 'CL:0000844',
#  'AACTTGCGTTCTCGCG': 'CL:0000186',
#  'AAGAAGGATCAGTTAG': 'CL:0000584',
#  'AAGACCCAACTGAACA': 'CL:0000186',
#  'AAGACTGCAAGCTACT': 'CL:0000584',
#  'AAGAGATGAATCGGTA': 'CL:0000584',
#  'AAGAGCTCTTTATCGG': 'CL:0000844',
#  'AAGAGGATGTACGCGA': 'CL:0000584',
#  'AAGAGGCATGGATCGC': 'CL:0000034',
#  'AAGAGGCCCTTTGGAA': 'CL:0000584',
#  'AAGATTGGCGGAACGT': 'CL:0000844',
#  'AAGCACCCTGCGTATC': 'CL:0000584',
#  'AAGCATACTCTCCTGA': 'CL:0000034',
#  'AAGCCGAAGCGGTTTA': 'CL:0000584',
#  'AAGCGCAGGGCTTTGA': 'CL:0000584',
#  'AAGCTCGTGCCAAGTC': 'CL:0000844',
#  'AAGCTCTTTCATGGTG': 'CL:0000584',
#  'AAGGAGCGGTTGGTGC': 'CL:0000186',
#  'AAGGATCGATCGCTTG': 'CL:0000584',
#  'AAGGATGAGGGACCTC': 'CL:0000584',
#  'AAGGCAGGCTGTCTCC': 'CL:0000584',
#  'AAGGGACAGATTCTGT': 'CL:0000584',
#  'AAGGTATCCTAATATA': 'CL:0000844',
#  'AAGTAGAAGACCGGGT': 'CL:0000844',
#  'AAGTCAATTGTCGTCA': 'CL:0000186',
#  'AAGTGACGACCGAATT': 'CL:0000844',
#  'AAGTGCAAAGGTAGAC': 'CL:0000584',
#  'AAGTGTTTGGAGACGG': 'CL:0009010',
#  'AAGTTCACTCCAAGCT': 'CL:0000186',
#  'AAGTTCGGCCAACAGG': 'CL:0000186',
#  'AATAATCTTCGTATCG': 'CL:0000584',
#  'AATAGAATCTGTTTCA': 'CL:0000584',
#  'AATAGTCCGTCCCGAC': 'CL:0000186',
#  'AATAGTCGCGAGTCGG': 'CL:0000584',
#  'AATATCGAATCAATGC': 'CL:0000584',
#  'AATATCGAGGGTTCTC': 'CL:0000844',
#  'AATCATGTAAAGACTC': 'CL:0000186',
#  'AATCGCCTCAGCGCCA': 'CL:0000186',
#  'AATCGCGCAGAGGACT': 'CL:0000186',
#  'AATCGGGACACTACGA': 'CL:0009010',
#  'AATCGTGAGCCGAGCA': 'CL:0000844',
#  'AATCTGCGTTGGGACG': 'CL:0009010',
#  'AATGACTGTCAGCCGG': 'CL:0000584',
#  'AATGAGTTCGCATATG': 'CL:0009010',
#  'AATGATGATACGCTAT': 'CL:0000844',
#  'AATGATGCGACTCCTG': 'CL:0000844',
#  'AATGCAACCGGGTACC': 'CL:0000584',
#  'AATGCACCAAGCAATG': 'CL:0000584',
#  'AATGGTCCACCGTTCA': 'CL:0009010',
#  'AATGGTTCTCACAAGC': 'CL:0000186',
#  'AATTAAAGGTCGGCGT': 'CL:0000844',
#  'AATTAACGGATTTCCA': 'CL:0000186',
#  'AATTCATAAGGGATCT': 'CL:0009010',
#  'AATTCCAAGCATGTAC': 'CL:0009010',
#  'AATTCGATTCGAGGAT': 'CL:0000844',
#  'AATTTGGTTCCAAAGA': 'CL:0000584',
#  'ACAAAGCATGACCTAG': 'CL:0009010',
#  'ACAAATCGCACCGAAT': 'CL:0000844',
#  'ACAACAGCATGAGCTA': 'CL:0000844',
#  'ACAACGGTCCCTGCGA': 'CL:0000186',
#  'ACAAGGAAATCCGCCC': 'CL:0009010',
#  'ACAATAGTCGTACGTT': 'CL:0000186',
#  'ACAATTGTGTCTCTTT': 'CL:0000584',
#  'ACAATTTAGGAGGCTC': 'CL:0009010',
#  'ACAATTTGAGCAGTGG': 'CL:0000844',
#  'ACAATTTGGCCATATT': 'CL:0000584',
#  'ACACAAAGACGGGTGG': 'CL:0000844',
#  'ACACACTTTCTACACG': 'CL:0000584',
#  'ACACCACATAATTAGC': 'CL:0000584',
#  'ACACCCAGCATGCAGC': 'CL:0000844',
#  'ACACCCGAGAAATCCG': 'CL:0000584',
#  'ACACCGAGCGCTCTTT': 'CL:0000584',
#  'ACACCTTAAGTAGGGC': 'CL:0000844',
#  'ACACCTTACTACTTGC': 'CL:0000844',
#  'ACACGAGACTCCTTCT': 'CL:0000844',
#  'ACACGGGAACTTAGGG': 'CL:0000584',
#  'ACACGTAGGCCACAAG': 'CL:0000584',
#  'ACACTCCAATGTCACT': 'CL:0000186',
#  'ACAGATTAGGTTAGTG': 'CL:0000584',
#  'ACAGCATAGAGCCAGT': 'CL:0000584',
#  'ACAGGCACGGATCCTT': 'CL:0000844',
#  'ACAGGCTTGCCCGACT': 'CL:0000186',
#  'ACAGGTGGAGGTGAGG': 'CL:0000584',
#  'ACATAATAAGGCGGTG': 'CL:0000844',
#  'ACATCAGCTGGGACGC': 'CL:0000186',
#  'ACATCCTGGTAACTGT': 'CL:0009010',
#  'ACATCGATCGTTTACC': 'CL:0000584',
#  'ACATCGGTCAGCCGCG': 'CL:0000584',
#  'ACATGGCGCCAAAGTA': 'CL:0000186',
#  'ACATGGCTCAATTTAG': 'CL:0009010',
#  'ACCAAGAACGCGTGTC': 'CL:0000844',
#  'ACCAAGTCATCGGCAG': 'CL:0000584',
#  'ACCAATATGCAAGTTA': 'CL:0000584',
#  'ACCACAAGTTTCTATC': 'CL:0000584',
#  'ACCAGTGCGGGAGACG': 'CL:0000034',
#  'ACCATATCCGCAATAA': 'CL:0000844',
#  'ACCATCGTATATGGTA': 'CL:0000844',
#  'ACCCAACGCCCGTGGC': 'CL:0000584',
#  'ACCCACCTACATGCTC': 'CL:0000186',
#  'ACCCATCTTGAGGGTA': 'CL:0009010',
#  'ACCCATTTGTCCCTCT': 'CL:0000584',
#  'ACCCGAGCGAAATTAC': 'CL:0000584',
#  'ACCCGGAAACTCCCAG': 'CL:0000186',
#  'ACCCGGATGACGCATC': 'CL:0000584',
#  'ACCCGGTTACACTTCC': 'CL:0000584',
#  'ACCCGTGTCATCAGTA': 'CL:0000186',
#  'ACCCTATAGGACTGAG': 'CL:0000186',
#  'ACCCTCCCGTCAGGGC': 'CL:0009010',
#  'ACCCTCCCTTGCTATT': 'CL:0000584',
#  'ACCCTTCATCTGCGAA': 'CL:0000584',
#  'ACCGAAAGGGCCCTGC': 'CL:0000584',
#  'ACCGACACATCTCCCA': 'CL:0000584',
#  'ACCGACTGAGTCCCAC': 'CL:0000584',
#  'ACCGATATTTAATCAT': 'CL:0000584',
#  'ACCGATGGTAGCATCG': 'CL:0000584',
#  'ACCGCAATAACTGCCT': 'CL:0000584',
#  'ACCGGGCCTTTGTTGA': 'CL:0009010',
#  'ACCGTGACCACGTGGG': 'CL:0000186',
#  'ACCTACAGTATGTGGT': 'CL:0000186',
#  'ACCTCCGCCCTCGCTG': 'CL:0000584',
#  'ACGAAATGGGCGGCAC': 'CL:0000584',
#  'ACGAGAACCCATCACG': 'CL:0000584',
#  'ACGAGTACGGATGCCC': 'CL:0000186',
#  'ACGATACATAGAACTA': 'CL:0000584',
#  'ACGATCATACATAGAG': 'CL:0000584',
#  'ACGATCATCTTGTAAA': 'CL:0000844',
#  'ACGATGCATATGTTAT': 'CL:0000584',
#  'ACGATGGATCCGATGC': 'CL:0000584',
#  'ACGCATACGTTTACTA': 'CL:0000584',
#  'ACGCATTCGTGAGTAC': 'CL:0000844',
#  'ACGCCAGATGATTTCT': 'CL:0000584',
#  'ACGCCGCTAGACGACC': 'CL:0000186',
#  'ACGCGAAGTCAGACGA': 'CL:0000186',
#  'ACGCGGGCCAAGGACA': 'CL:0000844',
#  'ACGCTAGTGATACACT': 'CL:0000844',
#  'ACGCTGTGAGGCGTAG': 'CL:0000584',
#  'ACGGACTCTCAAAGCG': 'CL:0000186',
#  'ACGGATGGTGCGGATA': 'CL:0000584',
#  'ACGGCGACGATGGGAA': 'CL:0000584',
#  'ACGGGAGTGTCGGCCC': 'CL:0000844',
#  'ACGGGTCATGTGACTT': 'CL:0000584',
#  'ACGTACAGATTTCTCT': 'CL:0000584',
#  'ACGTAGATTGCTGATG': 'CL:0000844',
#  'ACGTATTACTCCGATC': 'CL:0000584',
#  'ACGTGCGCCTCGTGCA': 'CL:0000186',
#  'ACGTTAATGTCGAAGA': 'CL:0000186',
#  'ACGTTAGATTTGCCCG': 'CL:0000584',
#  'ACGTTATTGGTCACTC': 'CL:0000186',
#  'ACGTTCCGCGCTCCGT': 'CL:0009010',
#  'ACGTTCGCAATCAATT': 'CL:0009010',
#  'ACGTTCGTTCAGGAAA': 'CL:0000186',
#  'ACGTTCTGTACAAGTC': 'CL:0000584',
#  'ACGTTTAGTTGTGATC': 'CL:0000584',
#  'ACTACCAGCTCTCTGG': 'CL:0000186',
#  'ACTACGCGTTAGAATT': 'CL:0000584',
#  'ACTAGTTGCGATCGTC': 'CL:0000584',
#  'ACTATCCAGGGCATGG': 'CL:0000584',
#  'ACTATTCGTCCGTGGT': 'CL:0000584',
#  'ACTATTTCCGGGCCCA': 'CL:0000186',
#  'ACTCAATAAAGGCACG': 'CL:0000844',
#  'ACTCCCGAATTCGTTT': 'CL:0000186',
#  'ACTCCCTAATGCTAAA': 'CL:0000186',
#  'ACTCCGGCCGACCACT': 'CL:0000584',
#  'ACTCGATGTATTTCAT': 'CL:0000584',
#  'ACTCGCGATCTGACGC': 'CL:0000844',
#  'ACTCGTCAGTAATCCC': 'CL:0000844',
#  'ACTCTAAACCTGGGAT': 'CL:0009010',
#  'ACTCTGACCTAATAGA': 'CL:0000844',
#  'ACTCTTCAGCTCCCGC': 'CL:0009010',
#  'ACTCTTGTATAGTAAC': 'CL:0000844',
#  'ACTGCCGTCGTAACTC': 'CL:0000584',
#  'ACTGCGGACACACCGT': 'CL:0009010',
#  'ACTGTACGATACACAT': 'CL:0000844',
#  'ACTGTAGCACTTTGGA': 'CL:0000186',
#  'ACTGTCCAGGATTATA': 'CL:0000186',
#  'ACTGTCTTCTTTAGAA': 'CL:0000584',
#  'ACTTACGCATCCACGC': 'CL:0009010',
#  'ACTTATACTTACCCGG': 'CL:0000584',
#  'ACTTATTAGGATCGGT': 'CL:0000844',
#  'ACTTATTTATGTGCCA': 'CL:0000584',
#  'ACTTCAGGCTGATCCC': 'CL:0009010',
#  'ACTTCGCCATACGCAC': 'CL:0000844',
#  'ACTTGACTCCCTCTTT': 'CL:0000186',
#  'ACTTGGGACCCGGTGG': 'CL:0000186',
#  'ACTTGTGGATGGAACG': 'CL:0000584',
#  'ACTTTACCCTCATGAA': 'CL:0000186',
#  'ACTTTCCTATAGCTTC': 'CL:0000584',
#  'AGAAATTATGACTCGC': 'CL:0000584',
#  'AGAACGTGGTACATTC': 'CL:0000844',
#  'AGAAGGTTGCCGAATT': 'CL:0000844',
#  'AGAATAAATCTTCAGG': 'CL:0000584',
#  'AGAATTGTTTGACATA': 'CL:0000584',
#  'AGACAGCTCAGAATCC': 'CL:0000186',
#  'AGACATAGATCCTTCC': 'CL:0000584',
#  'AGACCATGGGATACAA': 'CL:0000186',
#  'AGACCCGCCCTCCTCG': 'CL:0000844',
#  'AGACCGCTCCGCGGTT': 'CL:0009010',
#  'AGACCGGGAAACCCTG': 'CL:0000584',
#  'AGACGAAGTGCCGGTC': 'CL:0000584',
#  'AGACTAGCCTTCCAGA': 'CL:0000186',
#  'AGACTGTTACCGGGTC': 'CL:0000584',
#  'AGAGAACCGTCTAGGA': 'CL:0009010',
#  'AGAGATCTCTAAAGCG': 'CL:0000584',
#  'AGAGCAGTTATGAGAC': 'CL:0000584',
#  'AGAGCGTACAAGCTCG': 'CL:0000186',
#  'AGAGCTACGAAAGCAT': 'CL:0000584',
#  'AGAGGCTTCGGAAACC': 'CL:0000584',
#  'AGAGTAAACTTCACTA': 'CL:0000584',
#  'AGATACCGGTGTTCAC': 'CL:0000584',
#  'AGATACGACTTCATAT': 'CL:0000186',
#  'AGATATAATACGACTA': 'CL:0000186',
#  'AGATCGTGCATAAGAT': 'CL:0000584',
#  'AGATCTCAGGTGTGAT': 'CL:0000844',
#  'AGATGACTCGCCCACG': 'CL:0000844',
#  'AGATTATAGGACGTTT': 'CL:0000844',
#  'AGCAAAGGCCGCTAGT': 'CL:0000584',
#  'AGCAACATATCTTATT': 'CL:0000584',
#  'AGCACCAGTACTCACG': 'CL:0000844',
#  'AGCACTACCGGCCTGT': 'CL:0000186',
#  'AGCACTACCTCACCAG': 'CL:0000186',
#  'AGCAGAAGGAGAAAGA': 'CL:0000844',
#  'AGCAGCCAGATGAATA': 'CL:0009010',
#  'AGCATCGTCGATAATT': 'CL:0000844',
#  'AGCCAAGCTTTGTGTC': 'CL:0000584',
#  'AGCCACAGGTTACCCG': 'CL:0000186',
#  'AGCCACTCCCGTGCTT': 'CL:0000584',
#  'AGCCCATACATGTAAG': 'CL:0000584',
#  'AGCCCGGTAGCCTGTA': 'CL:0000186',
#  'AGCCCTGTCGCACCGT': 'CL:0000584',
#  'AGCCTTAAAGCGGAAG': 'CL:0009010',
#  'AGCGACATCCCATTCA': 'CL:0000844',
#  'AGCGACCAACGATATT': 'CL:0000844',
#  'AGCGCATAATGAATCG': 'CL:0009010',
#  'AGCGCGGGTGCCAATG': 'CL:0009010',
#  'AGCGCTAGAGCGATGT': 'CL:0000584',
#  'AGCGGACACTTCGTAG': 'CL:0000584',
#  'AGCGGGTCTGACACTC': 'CL:0000584',
#  'AGCTATTTAATCCAAC': 'CL:0009010',
#  'AGCTCCATATATGTTC': 'CL:0000584',
#  'AGCTCCTTCGCACATC': 'CL:0000186',
#  'AGCTCTAGACGTTCCA': 'CL:0000034',
#  'AGCTCTTCCCAGTGCA': 'CL:0000584',
#  'AGCTCTTTACTCAGTT': 'CL:0000844',
#  'AGCTGAAGTAAACCAA': 'CL:0000584',
#  'AGCTTCTTCTCGAGCA': 'CL:0000584',
#  'AGCTTGATCTTAACTT': 'CL:0000584',
#  'AGGAAGCTGTCCGCCG': 'CL:0000584',
#  'AGGACATCGCACGTCG': 'CL:0000584',
#  'AGGACGACCCATTAGA': 'CL:0000584',
#  'AGGAGGCCTTCGCGCG': 'CL:0009010',
#  'AGGATAAAGTCGGGAT': 'CL:0000584',
#  'AGGATATAGGGATTTA': 'CL:0000584',
#  'AGGCAGATGCGTAAAC': 'CL:0000584',
#  'AGGCAGGGAGCGTACT': 'CL:0000584',
#  'AGGCATTGTCGTAGGG': 'CL:0000584',
#  'AGGCCCAGTGACTGGT': 'CL:0000584',
#  'AGGCCTGAGAATCTCG': 'CL:0000186',
#  'AGGCTATGGTTAGCTT': 'CL:0000844',
#  'AGGCTTCCCGAAGAAG': 'CL:0000186',
#  'AGGGCGAGCAGCTGAT': 'CL:0000186',
#  'AGGGCGTGATCGGCTA': 'CL:0000844',
#  'AGGGCTGCAGTTACAG': 'CL:0000844',
#  'AGGGTCGATGCGAACT': 'CL:0000584',
#  'AGGGTGCTCTCGAGGG': 'CL:0000584',
#  'AGGGTGGATAGTGCAT': 'CL:0000186',
#  'AGGGTTCCCTTTGGTT': 'CL:0000844',
#  'AGGGTTTAGTTCGGGA': 'CL:0000844',
#  'AGGTACGATATTGCCA': 'CL:0000584',
#  'AGGTATGCGGACATTA': 'CL:0000584',
#  'AGGTCGCGGAGTTACT': 'CL:0000186',
#  'AGGTGGTGACCTTCGC': 'CL:0000584',
#  'AGGTGTATCGCCATGA': 'CL:0000584',
#  'AGGTTACACCATGCCG': 'CL:0000584',
#  'AGGTTGAGGCACGCTT': 'CL:0000584',
#  'AGGTTTCACACACCTT': 'CL:0000844',
#  'AGTAACTATAGCAGCC': 'CL:0000584',
#  'AGTAATGTCTTGCCGC': 'CL:0000844',
#  'AGTACGGCCCGTATCG': 'CL:0009010',
#  'AGTACGGGCACCTGGC': 'CL:0000844',
#  'AGTACTCTTATGCCCA': 'CL:0000584',
#  'AGTATAATACTAGGCA': 'CL:0000844',
#  'AGTATACACAGCGACA': 'CL:0000584',
#  'AGTATTTGGCACGACC': 'CL:0009010',
#  'AGTCAACACCACCATC': 'CL:0000584',
#  'AGTCAAGATGACACTT': 'CL:0000844',
#  'AGTCACTAGCTCTCGA': 'CL:0009010',
#  'AGTCAGCCACCGCCTG': 'CL:0000186',
#  'AGTCCAGCGGGTACGT': 'CL:0007011',
#  'AGTCCATTGGCTGATG': 'CL:0000584',
#  'AGTCCCGCCTTTAATT': 'CL:0000844',
#  'AGTCGGCCCAAACGAC': 'CL:0000186',
#  'AGTCGGTTGCGTGAGA': 'CL:0000844',
#  'AGTCGTCGACCACCAA': 'CL:0000186',
#  'AGTCTAAAGTATACTC': 'CL:0000584',
#  'AGTCTGGACATCCTTG': 'CL:0000584',
#  'AGTCTTCTCCTCAAAT': 'CL:0000844',
#  'AGTCTTTAAAGTGTCC': 'CL:0000584',
#  'AGTGAACAAACTTCTC': 'CL:0000186',
#  'AGTGACCTACTTTACG': 'CL:0000844',
#  'AGTGAGACTTCCAGTA': 'CL:0000584',
#  'AGTGAGCCTCGCCGCC': 'CL:0000584',
#  'AGTGATAACCTGCGCG': 'CL:0000186',
#  'AGTGATATGAGTAGTT': 'CL:0000844',
#  'AGTGATTCAAGCAGGA': 'CL:0000584',
#  'AGTGCACGCTTAAGAA': 'CL:0000057',
#  'AGTGCGTAGCTCGTAA': 'CL:0000584',
#  'AGTGCTAAACACAGCA': 'CL:0000584',
#  'AGTGGCGGCAATTTGA': 'CL:0000186',
#  'AGTGTATTGCGCATTG': 'CL:0000844',
#  'AGTGTGCTAAGATCGC': 'CL:0000584',
#  'AGTGTGGTCTATTGTG': 'CL:0000186',
#  'AGTTAAACACTTGCGA': 'CL:0000584',
#  'AGTTAAGCGGTCCCGG': 'CL:0000584',
#  'AGTTACCCTTAAGACT': 'CL:0000584',
#  'AGTTACCGCACATGGT': 'CL:0009010',
#  'AGTTACTCTATCGTGG': 'CL:0000584',
#  'AGTTCACCGGTTGGAC': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000186',
#  'AGTTCCTATTTATGTT': 'CL:0000844',
#  'AGTTCTGCGTTGTATC': 'CL:0000186',
#  'AGTTGACATCGGCTGG': 'CL:0000584',
#  'AGTTGACGGTCCTTGC': 'CL:0000584',
#  'AGTTGCTGACTGATAT': 'CL:0000057',
#  'AGTTTCGCAGGTCGGA': 'CL:0000584',
#  'AGTTTGCACCTGCCTC': 'CL:0000584',
#  'AGTTTGGCCAGACCTA': 'CL:0000844',
#  'ATAAACGGACCCGTAA': 'CL:0000584',
#  'ATAAATATTAGCAGCT': 'CL:0000584',
#  'ATAACGCCGGAGGGTC': 'CL:0000844',
#  'ATAACGGAGTCCAACG': 'CL:0000844',
#  'ATAAGGTGGAGAACAT': 'CL:0000584',
#  'ATAAGTAGGATTCAGA': 'CL:0000584',
#  'ATAAGTTACCGCGACG': 'CL:0000584',
#  'ATAATACCGTTAGCCG': 'CL:0000186',
#  'ATAATAGCTGTTGAAT': 'CL:0000186',
#  'ATAATAGTGTAGGGAC': 'CL:0000186',
#  'ATAATTAGCTAAGTAG': 'CL:0000584',
#  'ATACAGGCCCTCCAAT': 'CL:0000186',
#  'ATACCAGGCTAATAGA': 'CL:0000584',
#  'ATACCTAACCAAGAAA': 'CL:0000186',
#  'ATACGAAGGCTTTCCA': 'CL:0000584',
#  'ATACGCCGGCGAAACC': 'CL:0000186',
#  'ATACGGGTTTCGATTG': 'CL:0000584',
#  'ATACGGTGAAGATGCA': 'CL:0000186',
#  'ATACGTACTTAGCCAC': 'CL:0000186',
#  'ATACGTCCACTCCTGT': 'CL:0000584',
#  'ATACGTTATGCACGGA': 'CL:0000584',
#  'ATACTACCCGTACCAC': 'CL:0000584',
#  'ATACTAGCATGACCCT': 'CL:0000844',
#  'ATACTCTCGCCACTCT': 'CL:0000584',
#  'ATACTGCCTTACACCG': 'CL:0000186',
#  'ATACTTGTTCTCGAGC': 'CL:0000186',
#  'ATAGACAACGGGACCT': 'CL:0000844',
#  'ATAGAGTACTGGGACA': 'CL:0000186',
#  'ATAGAGTTATCAACTT': 'CL:0009010',
#  'ATAGCAACTAGGGAAG': 'CL:0009010',
#  'ATAGCCTCAGTACCCA': 'CL:0000186',
#  'ATAGCTGCTCTTGTTA': 'CL:0000584',
#  'ATAGGCGGCTATAGAA': 'CL:0000034',
#  'ATAGGCTAGCTTCGCA': 'CL:0000186',
#  'ATAGGGATATCCTTGA': 'CL:0000844',
#  'ATAGGTTGGGCAGATG': 'CL:0000844',
#  'ATAGTGAAGCGTTCTC': 'CL:0000584',
#  'ATAGTTCCACCCACTC': 'CL:0009010',
#  'ATATAAAGCGCTCGTG': 'CL:0000584',
#  'ATATAAATGTAGCTGC': 'CL:0000844',
#  'ATATAACACGGGCGCA': 'CL:0000186',
#  'ATATCGGTAGGGAGAT': 'CL:0000584',
#  'ATATCGTTCCTCGAAC': 'CL:0000584',
#  'ATATCTCCCTCGTTAA': 'CL:0000584',
#  'ATATCTTAGGGCCTTC': 'CL:0000844',
#  'ATATGTCTCCCTAGCC': 'CL:0000584',
#  'ATATTCAGTTAAACCT': 'CL:0000584',
#  'ATATTCCACATAGTGA': 'CL:0000584',
#  'ATATTGCTGTCAAAGT': 'CL:0000186',
#  'ATATTTAACCCTCAAG': 'CL:0000844',
#  'ATCAAACACTGTTCCA': 'CL:0000844',
#  'ATCAATCTGGGCTGCA': 'CL:0000844',
#  'ATCACATTAGAATATC': 'CL:0000584',
#  'ATCACGTGCTAATTAA': 'CL:0000186',
#  'ATCACTTCATCCTCGC': 'CL:0000584',
#  'ATCAGACGGCACGCCG': 'CL:0000584',
#  'ATCAGCCTCATGCTGC': 'CL:0000186',
#  'ATCAGGTAGCTGACAG': 'CL:0009010',
#  'ATCAGTAGGCAGGGAT': 'CL:0000584',
#  'ATCATCCAATATTTGT': 'CL:0000844',
#  'ATCATGGACTACCGAC': 'CL:0000584',
#  'ATCCAATGGAGGGTCC': 'CL:0000584',
#  'ATCCACATCGACAGAA': 'CL:0000186',
#  'ATCCAGAGCAACAACC': 'CL:0000844',
#  'ATCCAGGATTCGTGAA': 'CL:0000584',
#  'ATCCTACCTAAGCTCT': 'CL:0000844',
#  'ATCCTGCGTGGAATGG': 'CL:0000844',
#  'ATCGACCCAATACAGA': 'CL:0000584',
#  'ATCGACTCTTTCCGTT': 'CL:0000584',
#  'ATCGCACGATTGTTCA': 'CL:0000844',
#  'ATCGCACGCCGGGAGA': 'CL:0000844',
#  'ATCGCTTTACGTCTCA': 'CL:0000584',
#  'ATCGGAGACAGACGGC': 'CL:0000584',
#  'ATCGGCAAGCAGTCCA': 'CL:0000584',
#  'ATCGTCCAATCGAGTC': 'CL:0000584',
#  'ATCTAATATCCTACGG': 'CL:0000186',
#  'ATCTACCATCTGCTCC': 'CL:0000584',
#  'ATCTCCCTGCAATCTA': 'CL:0000584',
#  'ATCTGACATGGAAGGA': 'CL:0000584',
#  'ATCTGATAGTGTCTTA': 'CL:0000584',
#  'ATCTGCACCTCTGCGA': 'CL:0009010',
#  'ATCTGCTGTTATCGCC': 'CL:0009010',
#  'ATCTGGGCTGTTCTTG': 'CL:0000584',
#  'ATCTGGTTAAGACTGT': 'CL:0000844',
#  'ATCTTGACCTGCAACG': 'CL:0000186',
#  'ATGAAGCCAAGGAGCC': 'CL:0000584',
#  'ATGACGCCGGCTCTAA': 'CL:0000844',
#  'ATGACTATCAGCTGTG': 'CL:0000584',
#  'ATGAGGAGTGTTAATC': 'CL:0000584',
#  'ATGATCGGGAATAGAC': 'CL:0000034',
#  'ATGATGCAATGGTACA': 'CL:0000844',
#  'ATGCACCTTCCTTAAT': 'CL:0000584',
#  'ATGCACTACCGCATTG': 'CL:0000186',
#  'ATGCATGATCCAGGAT': 'CL:0000844',
#  'ATGCCGGTCTTGCATA': 'CL:0000584',
#  'ATGCCGGTTGATGGGA': 'CL:0000584',
#  'ATGCGACAGTCCCATT': 'CL:0000584',
#  'ATGCTCAGTGTTGCAT': 'CL:0000186',
#  'ATGCTCTGGCGCGGTA': 'CL:0000186',
#  'ATGCTTAGGAGTTGAT': 'CL:0000584',
#  'ATGGAACCTTTGCACA': 'CL:0000584',
#  'ATGGAGCAGGCCGTGA': 'CL:0000584',
#  'ATGGATCCGGCGTCCG': 'CL:0000584',
#  'ATGGATTGACCAAACG': 'CL:0000584',
#  'ATGGCGGAATAGTCGC': 'CL:0009010',
#  'ATGGGACCTGCTGAAC': 'CL:0000844',
#  'ATGTAAGGCTGCTCTT': 'CL:0009010',
#  'ATGTACGATGACGTCG': 'CL:0000584',
#  'ATGTCATTTCCCATTG': 'CL:0000584',
#  'ATGTGCATCCGACGCA': 'CL:0000844',
#  'ATGTTACGAGCAATAC': 'CL:0000584',
#  'ATGTTCCTGCCCACCT': 'CL:0000584',
#  'ATGTTCGTCGACCCAC': 'CL:0009010',
#  'ATGTTGATTAGAGACT': 'CL:0000186',
#  'ATGTTGTAGTCTGTTT': 'CL:0000584',
#  'ATGTTTCGGCCCGGAG': 'CL:0009010',
#  'ATTAAACATGCGGACC': 'CL:0000844',
#  'ATTAACACCTGAGATA': 'CL:0000844',
#  'ATTAATACTACGCGGG': 'CL:0000584',
#  'ATTAATGAACCAGTCG': 'CL:0000034',
#  'ATTAATTCGGTCACTC': 'CL:0000584',
#  'ATTACATGTCAGTCTT': 'CL:0000584',
#  'ATTACCACACTGCCTG': 'CL:0000584',
#  'ATTACTAGCCTCTTGC': 'CL:0000844',
#  'ATTACTTACTGGGCAT': 'CL:0000584',
#  'ATTAGATTCCTCAGCA': 'CL:0000186',
#  'ATTAGATTGATAGCGG': 'CL:0000844',
#  'ATTAGGCGATGCTTTC': 'CL:0000584',
#  'ATTATACTTTGCTCGT': 'CL:0000584',
#  'ATTATAGCTACTTTAC': 'CL:0000844',
#  'ATTCACTGATGTTGGA': 'CL:0000186',
#  'ATTCAGGACCTATTTC': 'CL:0000584',
#  'ATTCAGTAGCAGGGTC': 'CL:0000584',
#  'ATTCATATACTGTCCA': 'CL:0000844',
#  'ATTCATCGTTGAGGCA': 'CL:0000186',
#  'ATTCCCACATAAACAA': 'CL:0000844',
#  'ATTCCTTCCAGGCGGT': 'CL:0000186',
#  'ATTCGTGCTATCTCTT': 'CL:0000844',
#  'ATTGATAGCAACGAGA': 'CL:0000186',
#  'ATTGATGAGTCCTAAC': 'CL:0000584',
#  'ATTGCGATCAGTAACT': 'CL:0009010',
#  'ATTGGATTACAGCGTA': 'CL:0000584',
#  'ATTGGTAGGATCCGCT': 'CL:0000584',
#  'ATTGTACAACTCGGCT': 'CL:0000186',
#  'ATTGTCGCAATACCTT': 'CL:0009010',
#  'ATTTACTAAGTCCATT': 'CL:0000584',
#  'ATTTCATTATTTCGCG': 'CL:0009010',
#  'ATTTGTTCCAGGGCTC': 'CL:0000844',
#  'CAAACGAGTATCGCAG': 'CL:0000584',
#  'CAAACTATTGAGCTTC': 'CL:0000584',
#  'CAAACTCGCGACGCCG': 'CL:0000584',
#  'CAAAGTCAGGTTAGCT': 'CL:0000034',
#  'CAAATGTCCTTCCGTG': 'CL:0000584',
#  'CAAATTGTCAGCAAGC': 'CL:0009010',
#  'CAACACATCTCCTGCC': 'CL:0000844',
#  'CAACCTACCGAGCAGT': 'CL:0000584',
#  'CAACGACCCGTTTACA': 'CL:0000844',
#  'CAACGGTTCTTGATAC': 'CL:0000844',
#  'CAACGTGGTGGAGTCT': 'CL:0000584',
#  'CAACTATATCGAATGC': 'CL:0000844',
#  'CAACTCCTTGATCCCG': 'CL:0000584',
#  'CAACTGCTCATCCGAT': 'CL:0000186',
#  'CAAGCACCAAATGCCT': 'CL:0000584',
#  'CAAGCGGCACATAATT': 'CL:0000844',
#  'CAAGGATCGCATGTTC': 'CL:0000844',
#  'CAAGTGTGGTTGCAAA': 'CL:0000584',
#  'CAATAAACCTTGGCCC': 'CL:0000844',
#  'CAATACGAGAGTCTGA': 'CL:0000584',
#  'CAATATTGGACTAGTG': 'CL:0000584',
#  'CAATCCTGCCGTGGAG': 'CL:0000584',
#  'CAATGCGAGAAGTATC': 'CL:0000584',
#  'CAATGGATCTCTACCA': 'CL:0000584',
#  'CAATGTGCCAACCCTT': 'CL:0000584',
#  'CAATTAAGGGTGATGA': 'CL:0000844',
#  'CAATTTCGTATAAGGG': 'CL:0000844',
#  'CACAATGAGCTGCTAT': 'CL:0000844',
#  'CACACACGCTAACGAG': 'CL:0000584',
#  'CACACAGCTTGCGCTC': 'CL:0000584',
#  'CACACAGGGATAGATT': 'CL:0000186',
#  'CACACGCGCTGTCTTA': 'CL:0000844',
#  'CACAGCACCCACGGCA': 'CL:0000844',
#  'CACAGCTAGGGAGTGA': 'CL:0000844',
#  'CACAGGGCCATATAGT': 'CL:0000584',
#  'CACAGGGCCGTTGTCA': 'CL:0000844',
#  'CACAGTTCGCTTCCCA': 'CL:0000584',
#  'CACATCGTGCACGCGC': 'CL:0000186',
#  'CACATCTCACCGACGA': 'CL:0000584',
#  'CACATGATTCAGCAAC': 'CL:0000844',
#  'CACATGTTTGGACATG': 'CL:0000584',
#  'CACATTCTTTCGATGG': 'CL:0000584',
#  'CACATTTCTTGTCAGA': 'CL:0000584',
#  'CACCATCGGAGGAGAC': 'CL:0000584',
#  'CACCCAAATCTTATGT': 'CL:0000186',
#  'CACCCACACGTCACCC': 'CL:0000844',
#  'CACCCACGAGGCAATT': 'CL:0000584',
#  'CACCGCCAGAAGGTTT': 'CL:0000844',
#  'CACCGCCGACCAGCGA': 'CL:0000844',
#  'CACCGTTGCGCGATAT': 'CL:0000844',
#  'CACCTAATCAGTTTAC': 'CL:0000844',
#  'CACCTCGATGGTGGAC': 'CL:0000844',
#  'CACCTTGCGAAACTCG': 'CL:0000584',
#  'CACCTTGGCGCCTTTG': 'CL:0000186',
#  'CACGCACAGCGCAGCT': 'CL:0000584',
#  'CACGCGGAACTGTTGC': 'CL:0000844',
#  'CACGGGATTGAGGGTT': 'CL:0000186',
#  'CACGTCGGCAACCTCT': 'CL:0000584',
#  'CACGTTCGTGCTCTAG': 'CL:0000186',
#  'CACGTTTCGTACACAC': 'CL:0009010',
#  'CACTAAAGTTGCCTAT': 'CL:0000186',
#  'CACTACGGGAGCTGCC': 'CL:0009010',
#  'CACTCAAGAGCTATGG': 'CL:0000844',
#  'CACTCAGCTCTTGAGG': 'CL:0000584',
#  'CACTCCTCTCGGTCGG': 'CL:0000584',
#  'CACTCGGTTAGGAGGA': 'CL:0009010',
#  'CACTCTTCTGCTAGCC': 'CL:0000584',
#  'CACTGACGATTGTGGA': 'CL:0000844',
#  'CACTGTCCAAGTGAGA': 'CL:0000844',
#  'CACTTCGCCACAGGCT': 'CL:0000186',
#  'CACTTCGTCTTATCTC': 'CL:0000844',
#  'CAGAACTTAGCCCTCT': 'CL:0000186',
#  'CAGAATAACACACGGA': 'CL:0000584',
#  'CAGAATATTCGTTATC': 'CL:0000844',
#  'CAGACCTGTAAGTGTT': 'CL:0000584',
#  'CAGACGAACCTGATAC': 'CL:0000584',
#  'CAGAGCATGAGCTTGC': 'CL:0000844',
#  'CAGAGTGATTTAACGT': 'CL:0000844',
#  'CAGATACTAACATAGT': 'CL:0000186',
#  'CAGCAGCCCGTTCCTT': 'CL:0000844',
#  'CAGCAGTCCAGACTAT': 'CL:0009010',
#  'CAGCAGTCTGTGCTGC': 'CL:0000186',
#  'CAGCCTCCTGCAGAGG': 'CL:0000844',
#  'CAGCTCACTGAGACAT': 'CL:0000844',
#  'CAGCTCGACAAGTTAA': 'CL:0000584',
#  'CAGGAAGACTTTATAT': 'CL:0000584',
#  'CAGGACAGCTGCCCTT': 'CL:0009010',
#  'CAGGATATATCGTTGT': 'CL:0000844',
#  'CAGGCCGTTTGGGTGT': 'CL:0000844',
#  'CAGTAATCCCTCCCAG': 'CL:0000186',
#  'CAGTAGATGATGTCCG': 'CL:0000584',
#  'CAGTAGCCCACGCGGT': 'CL:0000584',
#  'CAGTAGCGAGGTAGTA': 'CL:0000584',
#  'CAGTCGAGGATGCAAT': 'CL:0009010',
#  'CAGTCTGTATACTGGG': 'CL:0000844',
#  'CAGTGAATAAATGACT': 'CL:0000584',
#  'CAGTGGTTGCACATGA': 'CL:0000584',
#  'CAGTGTCGGCTGGCCC': 'CL:0000186',
#  'CAGTTCAAATTGACAC': 'CL:0000844',
#  'CAGTTCCGCGGGTCGA': 'CL:0000844',
#  'CATAACGGACAGTCGT': 'CL:0009010',
#  'CATAAGAAGCTTGGCT': 'CL:0000584',
#  'CATACACGGTTCCCAC': 'CL:0000186',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACGGCGTCTGGGC': 'CL:0000584',
#  'CATACTATGTAATTGT': 'CL:0000186',
#  'CATACTTAGGCAATAC': 'CL:0009010',
#  'CATAGAGGAGATACTA': 'CL:0000584',
#  'CATAGCCGCCCGGGAT': 'CL:0000186',
#  'CATAGTACATTGAGAG': 'CL:0000844',
#  'CATAGTAGCATAGTAG': 'CL:0000844',
#  'CATAGTCAAATACATA': 'CL:0000186',
#  'CATAGTCCACAAGAAC': 'CL:0000584',
#  'CATATAGGTACAGTCA': 'CL:0000844',
#  'CATCAACACCTACTAA': 'CL:0000584',
#  'CATCATCTACCCGGAC': 'CL:0000584',
#  'CATCATTACCCTGAGG': 'CL:0000844',
#  'CATCCGCAGGCCCGAA': 'CL:0009010',
#  'CATCCTCTCAAAGATC': 'CL:0000057',
#  'CATCGGACGGGTTAAT': 'CL:0000584',
#  'CATCGTCCGGTTACTA': 'CL:0000186',
#  'CATCTAGTGAAGGGAA': 'CL:0000584',
#  'CATCTGCAGGATCATT': 'CL:0000186',
#  'CATCTTACACCACCTC': 'CL:0000584',
#  'CATGATGCACAATTCT': 'CL:0000844',
#  'CATGCGACCAGTTTAA': 'CL:0009010',
#  'CATGCTGGCTCCAATT': 'CL:0000584',
#  'CATGGATTGTCTTCCG': 'CL:0009010',
#  'CATGGCAGGAAGATCG': 'CL:0000844',
#  'CATGGCTCCCTATGTC': 'CL:0000584',
#  'CATGGGTCGGGTGTGG': 'CL:0000584',
#  'CATGGTCTAGATACCG': 'CL:0000584',
#  'CATGTAAGAGACATTT': 'CL:0000844',
#  'CATGTCTCATTTATGG': 'CL:0000584',
#  'CATTACGTCGGCCCGT': 'CL:0000584',
#  'CATTATGCTTGTTGTG': 'CL:0000584',
#  'CATTCCCATTCCGTCG': 'CL:0000844',
#  'CATTCCCTAAGTACAA': 'CL:0000186',
#  'CATTGCGAAATGGGCG': 'CL:0009010',
#  'CATTGTGTGCTAGATC': 'CL:0009010',
#  'CATTTAGCGGACCATG': 'CL:0000584',
#  'CATTTGAGTGGTACGT': 'CL:0000584',
#  'CCAAACAGAACCCTCG': 'CL:0000584',
#  'CCAAAGCAGTTGGTTG': 'CL:0009010',
#  'CCAAATAACAAGATTC': 'CL:0000584',
#  'CCAAGACTTCTGCGAA': 'CL:0000844',
#  'CCAAGCGTAACTCGTA': 'CL:0000844',
#  'CCAAGTTTCTACAGAT': 'CL:0000584',
#  'CCAATCGGTAGATCGA': 'CL:0000844',
#  'CCAATGTCACAGCAAG': 'CL:0000844',
#  'CCAATTACGGGTCGAG': 'CL:0000584',
#  'CCAATTGAATGTTAAT': 'CL:0000844',
#  'CCACAATGTACGTCTT': 'CL:0000584',
#  'CCACACTGAGATATTA': 'CL:0000844',
#  'CCACAGTACCCATCCT': 'CL:0000584',
#  'CCACATACTGCACCCA': 'CL:0009010',
#  'CCACCCAAGGAAAGTG': 'CL:0000844',
#  'CCACGAATTTAACCTC': 'CL:0000584',
#  'CCACGAGAAGAGAATC': 'CL:0000584',
#  'CCACGGAGCCATAAGA': 'CL:0000844',
#  'CCACGTAAATTAGACT': 'CL:0000844',
#  'CCACTGGTGGCTGGTT': 'CL:0000844',
#  'CCACTGTTTGGATTAA': 'CL:0000584',
#  'CCAGAGACAAAGCCGG': 'CL:0000186',
#  'CCAGATAGTTGAGTGA': 'CL:0000584',
#  'CCAGCCTGGACCAATA': 'CL:0000844',
#  'CCAGCGGGATCACCAG': 'CL:0000584',
#  'CCAGCTCGAACGCATT': 'CL:0000584',
#  'CCAGCTTCCGCCCGCA': 'CL:0000584',
#  'CCAGGGACGTGGCCTC': 'CL:0000584',
#  'CCAGTAGTCTGATCCA': 'CL:0000844',
#  'CCAGTCCATTATTCGA': 'CL:0000186',
#  'CCAGTCTAGACGGCGC': 'CL:0000584',
#  'CCAGTCTTGTCATAGA': 'CL:0007011',
#  'CCATAAACAACCCGAC': 'CL:0000844',
#  'CCATACCTTTACTTGT': 'CL:0009010',
#  'CCATAGGTTGGCGTGG': 'CL:0000844',
#  'CCATAGTCAGTAACCC': 'CL:0000186',
#  'CCATATGGAAACTATA': 'CL:0000584',
#  'CCATATTGGATCATGA': 'CL:0000584',
#  'CCATCTCACCAGTGAA': 'CL:0000584',
#  'CCATCTTGTTCACAAT': 'CL:0000584',
#  'CCATGCCCTAGATTTC': 'CL:0000584',
#  'CCATGCCTGTTTAGTA': 'CL:0000186',
#  'CCATGGCCCTTGTACC': 'CL:0000186',
#  'CCATTTCTACCTATTA': 'CL:0000186',
#  'CCCAAACATGCTGCTC': 'CL:0000844',
#  'CCCAACATACGTCGCG': 'CL:0000844',
#  'CCCAACCACACTAACA': 'CL:0000844',
#  'CCCAATGAGATTTGCA': 'CL:0000186',
#  'CCCAATTTCACAACTT': 'CL:0000186',
#  'CCCAGGTCTGAAGGCT': 'CL:0000584',
#  'CCCGACCATAGTCCGC': 'CL:0000584',
#  'CCCGAGTTTCTCCGTA': 'CL:0000584',
#  'CCCGATAGCCTCGCCT': 'CL:0000584',
#  'CCCGCAGGGCCCAAAG': 'CL:0000584',
#  'CCCGCCATGCTCCCGT': 'CL:0000584',
#  'CCCGCGCAATGCACCC': 'CL:0000186',
#  'CCCGGGTCGTTCAGGG': 'CL:0000844',
#  'CCCGGTGGAAGAACCT': 'CL:0000186',
#  'CCCGTCAGCGTCTGAC': 'CL:0000584',
#  'CCCTACTTGAACAATG': 'CL:0000584',
#  'CCCTAGTGTCAGGTGT': 'CL:0000186',
#  'CCCTCAAGCTCTTAGT': 'CL:0000584',
#  'CCCTCCTCGCTCGTAT': 'CL:0000584',
#  'CCCTGACTAACAAATT': 'CL:0000584',
#  'CCCTGATGTAACTCGT': 'CL:0000186',
#  'CCCTGCCCAATCCGCT': 'CL:0000186',
#  'CCCTGTTGGCAAAGAC': 'CL:0000584',
#  'CCCTTTGACAGGTCTT': 'CL:0000186',
#  'CCGAAAGTGGTGAGCA': 'CL:0000186',
#  'CCGAAGTATATTGTTC': 'CL:0000186',
#  'CCGACAAACACATGAG': 'CL:0009010',
#  'CCGACAAAGGGAGTGC': 'CL:0000186',
#  'CCGACAATAGGCCGCC': 'CL:0009010',
#  'CCGAGAAGTCGCATAA': 'CL:0009010',
#  'CCGATCTCAACCTTAT': 'CL:0009010',
#  'CCGATTCGAGGGACCC': 'CL:0000186',
#  'CCGCACAAAGACCAAC': 'CL:0000844',
#  'CCGCACACGAACGTGT': 'CL:0000584',
#  'CCGCACGTGACCTCGG': 'CL:0000844',
#  'CCGCATGTGGTACGAT': 'CL:0000186',
#  'CCGCGGAATGCGTCAC': 'CL:0000186',
#  'CCGCGTAGGTAAGGGC': 'CL:0000844',
#  'CCGCTATCAGCACCAG': 'CL:0000584',
#  'CCGCTTACCTCACTCT': 'CL:0000186',
#  'CCGGAATGGTTTCAGT': 'CL:0000186',
#  'CCGGAGCGTACTTTCT': 'CL:0000186',
#  'CCGGCACGACCGTTTC': 'CL:0000584',
#  'CCGGGACCCGCAGAGA': 'CL:0000844',
#  'CCGGGCGGTCTCGTCA': 'CL:0000584',
#  'CCGGTAATGGCTAGTC': 'CL:0000844',
#  'CCGTAAGTTGGTCCCA': 'CL:0000844',
#  'CCGTAGGGTTGTTTAC': 'CL:0009010',
#  'CCGTGAGGCATTCATG': 'CL:0009010',
#  'CCGTGGAACGATCCAA': 'CL:0000186',
#  'CCGTGTTAAATTCCAT': 'CL:0000584',
#  'CCGTTACGTTAGAACA': 'CL:0000584',
#  'CCGTTCCGAATCTCGG': 'CL:0000584',
#  'CCTAAAGGCTGACGCT': 'CL:0000844',
#  'CCTAAATTAACGGTTC': 'CL:0000186',
#  'CCTAACCCAAACAAGT': 'CL:0000844',
#  'CCTAACTAAGGCTCTA': 'CL:0000584',
#  'CCTACGGCTCAGTCGA': 'CL:0000186',
#  'CCTACTGCTTACACTT': 'CL:0000186',
#  'CCTAGGCGTAGCGATC': 'CL:0000584',
#  'CCTAGTTAGTCGCATG': 'CL:0000584',
#  'CCTATAATGAGTGCCC': 'CL:0000584',
#  'CCTATCTATATCGGAA': 'CL:0000584',
#  'CCTATGAAGTGGTGCC': 'CL:0000584',
#  'CCTATGGGTTACCGTC': 'CL:0000584',
#  'CCTATGTCCACTCCAC': 'CL:0000584',
#  'CCTCACCAATCTTGAC': 'CL:0000186',
#  'CCTCACCTGAGGGAGC': 'CL:0000057',
#  'CCTCACCTTAGCATCG': 'CL:0000584',
#  'CCTCATGCAGCTACGA': 'CL:0000584',
#  'CCTCCCGACAATCCCT': 'CL:0000584',
#  'CCTCCTGTTGTGTCGT': 'CL:0000584',
#  'CCTCGAAGTGGACGGG': 'CL:0000584',
#  'CCTCGCCAGCAAATTA': 'CL:0000584',
#  'CCTCGCGCGATATAGG': 'CL:0000584',
#  'CCTCGCGCTGTGCGAT': 'CL:0000186',
#  'CCTCTAATCTGCCAAG': 'CL:0000844',
#  'CCTCTGGCCTAGACGG': 'CL:0009010',
#  'CCTGAATATTTACATA': 'CL:0000584',
#  'CCTGACAAACTCGCGC': 'CL:0000584',
#  'CCTGACCACCGATGGT': 'CL:0000844',
#  'CCTGCCCGTTGTCTAG': 'CL:0000584',
#  'CCTGCGATAGAACTGT': 'CL:0000584',
#  'CCTGCGTTCTACGCTT': 'CL:0009010',
#  'CCTGCTATTTGAGAAG': 'CL:0000160',
#  'CCTGGAAACGTTCTGC': 'CL:0007011',
#  'CCTGTAAGACATGATA': 'CL:0000844',
#  'CCTGTACTCACGCCCA': 'CL:0000844',
#  'CCTGTCACCCGGGCTC': 'CL:0000844',
#  'CCTGTCCCTCACGTTA': 'CL:0009010',
#  'CCTGTCGCCCGTAAAT': 'CL:0000584',
#  'CCTGTTTGAAGACACG': 'CL:0000584',
#  'CCTTCTTGATCCAGTG': 'CL:0000844',
#  'CCTTTAAGGGAGCACT': 'CL:0000584',
#  'CCTTTCAATGAAGAAA': 'CL:0000584',
#  'CGAAACATAGATGGCA': 'CL:0000584',
#  'CGAAACGCAATTCATG': 'CL:0000186',
#  'CGAACCCGCATGCGTC': 'CL:0000584',
#  'CGAACGCCCAGTGCCG': 'CL:0009010',
#  'CGAATGACGCATAATG': 'CL:0000844',
#  'CGACAATTTGATCTAA': 'CL:0000584',
#  'CGACACGCTCCGACAG': 'CL:0000584',
#  'CGACAGTTCGCGTTAT': 'CL:0000186',
#  'CGACATGCGATCTTCT': 'CL:0000844',
#  'CGACTCAGGATGTTAT': 'CL:0009010',
#  'CGAGACCCTAGAGTGT': 'CL:0000844',
#  'CGAGAGATGTGAACCT': 'CL:0000844',
#  'CGAGAGCTTTCACTAC': 'CL:0000186',
#  'CGAGATTTCGCTCGGG': 'CL:0000584',
#  'CGAGCACTTCAAGTTT': 'CL:0000186',
#  'CGAGCTGGGCTTTAGG': 'CL:0000844',
#  'CGAGGCCAGGCATTGG': 'CL:0009010',
#  'CGAGGCTAAATATGGC': 'CL:0000844',
#  'CGAGGGTATCCAGGTG': 'CL:0000584',
#  'CGAGTACTAAAGAGGA': 'CL:0000844',
#  'CGAGTTCTGTCCCACC': 'CL:0000584',
#  'CGAGTTTATCGGACTG': 'CL:0000584',
#  'CGATAATACTCAGGTT': 'CL:0000584',
#  'CGATACCTCGCGGACA': 'CL:0000844',
#  'CGATAGTCGTACTGCA': 'CL:0009010',
#  'CGATCCGACCCAGTGC': 'CL:0000844',
#  'CGATGGACCCTACGCC': 'CL:0000584',
#  'CGATTAAATATCTCCT': 'CL:0009010',
#  'CGATTCGCCTGGCTGC': 'CL:0000186',
#  'CGCAAACACGAGTTAC': 'CL:0000186',
#  'CGCAATCGATCATTAG': 'CL:0000584',
#  'CGCAATTACTTTCGGT': 'CL:0000186',
#  'CGCAATTAGGGTAATA': 'CL:0000186',
#  'CGCAATTCTACAATAA': 'CL:0000844',
#  'CGCACGTGCGCTATCA': 'CL:0000584',
#  'CGCAGAAACATTTGCG': 'CL:0009010',
#  'CGCAGGCGATCCAAAC': 'CL:0000584',
#  'CGCATGCCGAATGCGT': 'CL:0000584',
#  'CGCATGGTGCGATGCT': 'CL:0000844',
#  'CGCATTAGCTAATAGG': 'CL:0000844',
#  'CGCCAAGAAGCCGAGT': 'CL:0000584',
#  'CGCCATCCGATTATGA': 'CL:0000844',
#  'CGCCCAGCACGCCTAG': 'CL:0000584',
#  'CGCCCAGCGTTTCACG': 'CL:0000186',
#  'CGCCCGCTTCCGTACA': 'CL:0000584',
#  'CGCCCTTGAAGGCTGA': 'CL:0000186',
#  'CGCCGTCTACCCATCG': 'CL:0000584',
#  'CGCGAAGTGGCATACT': 'CL:0000584',
#  'CGCGACACTGCGCAGC': 'CL:0000186',
#  'CGCGCAAGGAACTACA': 'CL:0000584',
#  'CGCGCATGTTTGATTG': 'CL:0000186',
#  'CGCGCCCGACTTAATA': 'CL:0000584',
#  'CGCGGCAGTATTACGG': 'CL:0000844',
#  'CGCGGCTCAACTTGAA': 'CL:0009010',
#  'CGCGGGAATTAGGCAG': 'CL:0000584',
#  'CGCGTTCATGAAATAC': 'CL:0000844',
#  'CGCTACGGGACATTTA': 'CL:0000844',
#  'CGCTAGAGACCGCTGC': 'CL:0000584',
#  'CGCTATTCAATGTATG': 'CL:0000186',
#  'CGCTATTCTTAGGCTC': 'CL:0000844',
#  'CGCTCGACATAATGAT': 'CL:0000584',
#  'CGCTGGTGACTACCCT': 'CL:0000584',
#  'CGCTGTGACGCCGCAC': 'CL:0000844',
#  'CGCTGTGTGGATGTTG': 'CL:0000186',
#  'CGCTTAGTATTGATAC': 'CL:0000844',
#  'CGCTTCCACTGAAATC': 'CL:0000844',
#  'CGCTTTCTTGCATTCG': 'CL:0000584',
#  'CGGAAAGAATCAAACG': 'CL:0000584',
#  'CGGAACGTAAACATAG': 'CL:0000584',
#  'CGGAGCATGGCGATCC': 'CL:0000584',
#  'CGGATAAGCGGACATG': 'CL:0009010',
#  'CGGATCCTCAAGGACT': 'CL:0000584',
#  'CGGCAATAAGATCGCC': 'CL:0000584',
#  'CGGCACTCAAGAAAGT': 'CL:0000584',
#  'CGGCAGGGTCGGGTTG': 'CL:0000584',
#  'CGGCCACGCACAAAGT': 'CL:0000844',
#  'CGGCGCCATCAATCCC': 'CL:0000584',
#  'CGGCTCTAAAGCTGCA': 'CL:0009010',
#  'CGGCTTTGTATGATAA': 'CL:0009010',
#  'CGGGAATTTATGTAAA': 'CL:0000186',
#  'CGGGAGCTTCAGTGTA': 'CL:0009010',
#  'CGGGAGTATACCGCCG': 'CL:0000186',
#  'CGGGATCAATGTAAGA': 'CL:0000844',
#  'CGGGCAGCTAAACCGC': 'CL:0000186',
#  'CGGGCCATAGCCGCAC': 'CL:0000186',
#  'CGGGCCTTCTTTGTAA': 'CL:0000584',
#  'CGGGTGTACCCATTTA': 'CL:0000584',
#  'CGGGTTTGTTAGGGCT': 'CL:0000584',
#  'CGGTAGAGGTGCAGGT': 'CL:0000584',
#  'CGGTCAAGTGGGAACC': 'CL:0000844',
#  'CGGTCTATCAACCCGT': 'CL:0000584',
#  'CGGTGCAGATAGAACG': 'CL:0000584',
#  'CGGTGCGCGTTGGTCC': 'CL:0000186',
#  'CGGTGTACTTGATCCC': 'CL:0000186',
#  'CGGTTATCCAACAGTG': 'CL:0000584',
#  'CGGTTCAAGTAGGTGT': 'CL:0000844',
#  'CGGTTCCGGCTTCTTG': 'CL:0000584',
#  'CGGTTGACCTGGCATA': 'CL:0000844',
#  'CGTAAACGCTTGAGTG': 'CL:0000186',
#  'CGTAATAATTACGAGT': 'CL:0000584',
#  'CGTACCGAAAGTCTAG': 'CL:0000584',
#  'CGTACCTGATAGGCCT': 'CL:0000844',
#  'CGTAGAGAGTAATTAT': 'CL:0000844',
#  'CGTAGCGAATTGTCAG': 'CL:0009010',
#  'CGTAGCGCCGACGTTG': 'CL:0000844',
#  'CGTATTAAGAGATCTA': 'CL:0000186',
#  'CGTCAAGGCTATAAAT': 'CL:0009010',
#  'CGTCAATCTTTAACAT': 'CL:0009010',
#  'CGTCACGTCCATTGGT': 'CL:0000844',
#  'CGTCAGCTATTTACTC': 'CL:0000584',
#  'CGTCATACCATATCCA': 'CL:0000584',
#  'CGTCGCATGTGAGCCA': 'CL:0000186',
#  'CGTCGCGGCGGGATTT': 'CL:0000584',
#  'CGTCGTCCTTCGCGAA': 'CL:0000186',
#  'CGTCTTGAGTGTGACG': 'CL:0000844',
#  'CGTGAAGTTAATTCAC': 'CL:0000844',
#  'CGTGACATTGGGTCGT': 'CL:0000844',
#  'CGTGACCAGTCCTCTG': 'CL:0000584',
#  'CGTGCAGACTGGGACA': 'CL:0000186',
#  'CGTGCTGGCCTAGTCG': 'CL:0009010',
#  'CGTGCTTCTACCTAAA': 'CL:0000584',
#  'CGTGGAAGCCTCGTAC': 'CL:0009010',
#  'CGTGTCCCATTCGCGA': 'CL:0000186',
#  'CGTGTCTCGTTACGAC': 'CL:0000844',
#  'CGTGTGTTAAACCCTG': 'CL:0000584',
#  'CGTTAAACTAGTTAGG': 'CL:0009010',
#  'CGTTAATGTCCCGACG': 'CL:0000186',
#  'CGTTCAGACCCGCGAA': 'CL:0000844',
#  'CGTTGAATACCGCGCT': 'CL:0000584',
#  'CGTTGCCCGCGTGGGA': 'CL:0000844',
#  'CGTTGTAAACGTCAGG': 'CL:0000186',
#  'CGTTGTAAGATTGATT': 'CL:0000186',
#  'CGTTGTCGGCAATTGA': 'CL:0000844',
#  'CGTTTCACTTCGGGCG': 'CL:0000584',
#  'CGTTTCGCTCATTACA': 'CL:0000186',
#  'CTAAAGGGAAATAGGA': 'CL:0000844',
#  'CTAAATCCGGTGTACA': 'CL:0000186',
#  'CTAAATCCTATTCCGG': 'CL:0000584',
#  'CTAACGAAACTTGCTG': 'CL:0000584',
#  'CTAACTGGTCCGGTTC': 'CL:0009010',
#  'CTAATTCTCAGATATT': 'CL:0000186',
#  'CTAATTTCAACAACAC': 'CL:0000186',
#  'CTACCCTAAGGTCATA': 'CL:0009010',
#  'CTACGCACGGAGTACC': 'CL:0000844',
#  'CTACGCCATTTCCGAT': 'CL:0000584',
#  'CTACTATCTTTCAGAG': 'CL:0000584',
#  'CTACTCAAGGTATAGT': 'CL:0000186',
#  'CTACTGCCACCTGACC': 'CL:0000844',
#  'CTAGATGTGAGTGTAA': 'CL:0000186',
#  'CTAGATTTACGACGGC': 'CL:0000186',
#  'CTAGCATAGTATAATG': 'CL:0000844',
#  'CTAGCCGATGTTATGA': 'CL:0000584',
#  'CTAGGCGCCCTATCAG': 'CL:0000186',
#  'CTAGGTCTGAAGGAAT': 'CL:0000186',
#  'CTAGTATTCGGAATTA': 'CL:0000844',
#  'CTAGTCACGTCTTAAG': 'CL:0000844',
#  'CTAGTTACAACCCGGT': 'CL:0009010',
#  'CTAGTTGGGCCCGGTA': 'CL:0000844',
#  'CTATAAGAGCCAATCG': 'CL:0000186',
#  'CTATAGGCGTTGATGT': 'CL:0000186',
#  'CTATCGACGAAATACA': 'CL:0000057',
#  'CTATCGGGTCTCAACA': 'CL:0000584',
#  'CTATGCCCGAATGCAA': 'CL:0000844',
#  'CTATGGGAAGCGGAAT': 'CL:0009010',
#  'CTATGTCACTAGCCCA': 'CL:0000584',
#  'CTATTTGGTTACGGAT': 'CL:0000186',
#  'CTCACATTTACTAAAT': 'CL:0000584',
#  'CTCAGGACTCACCTGT': 'CL:0000186',
#  'CTCAGTCACGACAAAT': 'CL:0000186',
#  'CTCATGGCTCACAATC': 'CL:0000584',
#  'CTCATTTGATGGGCGG': 'CL:0000584',
#  'CTCCGCCCACATGAGG': 'CL:0000844',
#  'CTCCGGCCTAATATGC': 'CL:0000844',
#  'CTCCGGCTTGTAGACA': 'CL:0000186',
#  'CTCCTAAGTTATGTCT': 'CL:0000584',
#  'CTCGAGATCCAAAGCA': 'CL:0000584',
#  'CTCGAGGTCGAACAGT': 'CL:0000844',
#  'CTCGATATTTGCGAGC': 'CL:0000584',
#  'CTCGCACCTATATAGT': 'CL:0000844',
#  'CTCGCCGAATGTAGGG': 'CL:0009010',
#  'CTCGGTCCGTAGCCTG': 'CL:0000186',
#  'CTCTAGCCCTCGGAAA': 'CL:0009010',
#  'CTCTCACAATCGATGA': 'CL:0000844',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             3878
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             8180
# AAACAATCTACTAGCA-1        1.0        3.0        3.0               78
# AAACACCAATAACTGC-1        0.0       59.0       59.0              887
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        0.0       58.0       58.0             2015
# TTGTTTCATTAGTCTA-1        0.0       60.0       60.0             5414
# TTGTTTCCATACAACT-1        0.0       45.0       45.0             1477
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              273
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2107
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0009010
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                        NaN
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                        NaN
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                        NaN
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                 CL:0000844
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 2801

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_46863/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             3878
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             8180
# AAACAATCTACTAGCA-1        1.0        3.0        3.0               78
# AAACACCAATAACTGC-1        0.0       59.0       59.0              887
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        0.0       58.0       58.0             2015
# TTGTTTCATTAGTCTA-1        0.0       60.0       60.0             5414
# TTGTTTCCATACAACT-1        0.0       45.0       45.0             1477
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              273
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2107
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0009010
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                    unknown
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                    unknown
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                    unknown
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                 CL:0000844
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0009010',
#  'CL:0000584',
#  'CL:0007011',
#  'CL:0000186',
#  'CL:0000844',
#  'CL:0000057',
#  'CL:0000034',
#  'CL:0000160',
#  'CL:0000115']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    1A_Hh
# AAACAAGTATCTCCCA-1    1A_Hh
# AAACAATCTACTAGCA-1    1A_Hh
# AAACACCAATAACTGC-1    1A_Hh
# AAACAGAGCGACTCCT-1    1A_Hh
#                       ...
# TTGTTTCACATCCAGG-1    1A_Hh
# TTGTTTCATTAGTCTA-1    1A_Hh
# TTGTTTCCATACAACT-1    1A_Hh
# TTGTTTGTATTACACG-1    1A_Hh
# TTGTTTGTGTAAATTC-1    1A_Hh
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['1A_Hh']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             3878
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             8180
# AAACAATCTACTAGCA-1        1.0        3.0        3.0               78
# AAACACCAATAACTGC-1        0.0       59.0       59.0              887
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        0.0       58.0       58.0             2015
# TTGTTTCATTAGTCTA-1        0.0       60.0       60.0             5414
# TTGTTTCCATACAACT-1        0.0       45.0       45.0             1477
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              273
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2107
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1                    unknown    1A_Hh
# AAACAAGTATCTCCCA-1                 CL:0009010    1A_Hh
# AAACAATCTACTAGCA-1                    unknown    1A_Hh
# AAACACCAATAACTGC-1                    unknown    1A_Hh
# AAACAGAGCGACTCCT-1                    unknown    1A_Hh
# ...                                       ...      ...
# TTGTTTCACATCCAGG-1                    unknown    1A_Hh
# TTGTTTCATTAGTCTA-1                    unknown    1A_Hh
# TTGTTTCCATACAACT-1                    unknown    1A_Hh
# TTGTTTGTATTACACG-1                    unknown    1A_Hh
# TTGTTTGTGTAAATTC-1                 CL:0000844    1A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255053_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'lowres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'tissue_lowres_scalef': 0.019862289,
#                  'fiducial_diameter_fullres': 230.61471646033417,
#                  'spot_diameter_fullres': 142.76149114211162}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255053_mm10-2020-A/V12Y31-030_A1.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '1A_Hh'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255053_mm10-2020-A': {'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'fullres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 142.76149114211162}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '1A_Hh'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             3878
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             8180
# AAACAATCTACTAGCA-1        1.0        3.0        3.0               78
# AAACACCAATAACTGC-1        0.0       59.0       59.0              887
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        0.0       58.0       58.0             2015
# TTGTTTCATTAGTCTA-1        0.0       60.0       60.0             5414
# TTGTTTCCATACAACT-1        0.0       45.0       45.0             1477
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              273
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2107
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1                    unknown    1A_Hh
# AAACAAGTATCTCCCA-1                 CL:0009010    1A_Hh
# AAACAATCTACTAGCA-1                    unknown    1A_Hh
# AAACACCAATAACTGC-1                    unknown    1A_Hh
# AAACAGAGCGACTCCT-1                    unknown    1A_Hh
# ...                                       ...      ...
# TTGTTTCACATCCAGG-1                    unknown    1A_Hh
# TTGTTTCATTAGTCTA-1                    unknown    1A_Hh
# TTGTTTCCATACAACT-1                    unknown    1A_Hh
# TTGTTTGTATTACACG-1                    unknown    1A_Hh
# TTGTTTGTGTAAATTC-1                 CL:0000844    1A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255053_mm10-2020-A': {'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'fullres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 142.76149114211162}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '1A_Hh'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_46863/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13255053.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0          0             3878
# AAACAAGTATCTCCCA-1          1         50         50             8180
# AAACAATCTACTAGCA-1          1          3          3               78
# AAACACCAATAACTGC-1          0         59         59              887
# AAACAGAGCGACTCCT-1          1         14         14              175
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         58             2015
# TTGTTTCATTAGTCTA-1          0         60         60             5414
# TTGTTTCCATACAACT-1          0         45         45             1477
# TTGTTTGTATTACACG-1          0         73         73              273
# TTGTTTGTGTAAATTC-1          1          7          7             2107
#
#                    assay_ontology_term_id cell_type_ontology_term_id donor_id  \
# AAACAACGAATAGTTC-1            EFO:0010961                    unknown    1A_Hh
# AAACAAGTATCTCCCA-1            EFO:0010961                 CL:0009010    1A_Hh
# AAACAATCTACTAGCA-1            EFO:0010961                    unknown    1A_Hh
# AAACACCAATAACTGC-1            EFO:0010961                    unknown    1A_Hh
# AAACAGAGCGACTCCT-1            EFO:0010961                    unknown    1A_Hh
# ...                                   ...                        ...      ...
# TTGTTTCACATCCAGG-1            EFO:0010961                    unknown    1A_Hh
# TTGTTTCATTAGTCTA-1            EFO:0010961                    unknown    1A_Hh
# TTGTTTCCATACAACT-1            EFO:0010961                    unknown    1A_Hh
# TTGTTTGTATTACACG-1            EFO:0010961                    unknown    1A_Hh
# TTGTTTGTGTAAATTC-1            EFO:0010961                 CL:0000844    1A_Hh
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 16 columns]

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)
# Out:
# Missing columns: []

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
# Out:
# Data Types:
# array_col    int64
# array_row    int64
# in_tissue    int64
# dtype: object
#
# Missing Values:
# array_col    0
# array_row    0
# in_tissue    0
# dtype: int64

# %% [markdown]
# # **Curating `fetal-lung` dataset:**

# %% [markdown]
# ### PNS dataset

# %% [markdown]
# # <ins>STEPS:</ins>

# %% [markdown]
# ## 1. Load the dataset

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy

# %%
adata = sc.read_h5ad('/lustre/scratch117/cellgen/cellgeni/cxgportal_sets/fetal-lung/C7filtered.h5ad')

# %%
adata.var
# Out:
#                     gene_ids  n_cells  highly_variable5891STDY8062349  \
# MIR1302-2HG  ENSG00000243485        3                           False
# AL669831.5   ENSG00000237491       20                           False
# LINC00115    ENSG00000225880       29                           False
# FAM41C       ENSG00000230368        3                            True
# AL645608.7   ENSG00000272438        5                           False
# ...                      ...      ...                             ...
# AL592183.1   ENSG00000273748        7                           False
# AC007325.4   ENSG00000278817      108                            True
# AC007325.2   ENSG00000277196        7                            True
# AC004556.1   ENSG00000276345      306                           False
# AC240274.1   ENSG00000271254      130                           False
#
#              highly_variable5891STDY8062350  highly_variable5891STDY8062351  \
# MIR1302-2HG                           False                           False
# AL669831.5                            False                            True
# LINC00115                              True                            True
# FAM41C                                 True                            True
# AL645608.7                            False                           False
# ...                                     ...                             ...
# AL592183.1                            False                           False
# AC007325.4                             True                            True
# AC007325.2                             True                           False
# AC004556.1                            False                           False
# AC240274.1                            False                            True
#
#              highly_variable5891STDY8062352  highly_variable5891STDY8062353  \
# MIR1302-2HG                           False                           False
# AL669831.5                            False                            True
# LINC00115                             False                            True
# FAM41C                                 True                            True
# AL645608.7                            False                           False
# ...                                     ...                             ...
# AL592183.1                             True                           False
# AC007325.4                             True                            True
# AC007325.2                            False                           False
# AC004556.1                            False                           False
# AC240274.1                            False                           False
#
#              highly_variable5891STDY8062354  highly_variable5891STDY8062355  \
# MIR1302-2HG                           False                           False
# AL669831.5                            False                           False
# LINC00115                             False                           False
# FAM41C                                 True                            True
# AL645608.7                            False                           False
# ...                                     ...                             ...
# AL592183.1                            False                           False
# AC007325.4                            False                           False
# AC007325.2                             True                            True
# AC004556.1                            False                           False
# AC240274.1                             True                            True
#
#              highly_variable5891STDY8062356  ...  Deep_WSSS_F_LNG8713191  \
# MIR1302-2HG                           False  ...                   False
# AL669831.5                            False  ...                   False
# LINC00115                             False  ...                   False
# FAM41C                                 True  ...                   False
# AL645608.7                            False  ...                   False
# ...                                     ...  ...                     ...
# AL592183.1                            False  ...                   False
# AC007325.4                            False  ...                   False
# AC007325.2                             True  ...                   False
# AC004556.1                            False  ...                   False
# AC240274.1                            False  ...                   False
#
#              Deep_5891STDY9030806  Deep_5891STDY9030807  Deep_5891STDY9030808  \
# MIR1302-2HG                 False                 False                 False
# AL669831.5                  False                 False                 False
# LINC00115                   False                 False                 False
# FAM41C                      False                 False                 False
# AL645608.7                  False                 False                 False
# ...                           ...                   ...                   ...
# AL592183.1                  False                 False                 False
# AC007325.4                  False                 False                 False
# AC007325.2                  False                 False                  True
# AC004556.1                  False                 False                 False
# AC240274.1                  False                 False                 False
#
#              Deep_5891STDY9030809  Deep_5891STDY9030810  Deep_n     means  \
# MIR1302-2HG                 False                 False       0  0.003591
# AL669831.5                  False                 False       0  0.044867
# LINC00115                   False                 False       1  0.074161
# FAM41C                      False                 False      14  0.011604
# AL645608.7                  False                 False       0  0.010806
# ...                           ...                   ...     ...       ...
# AL592183.1                  False                 False       1  0.008129
# AC007325.4                  False                 False       5  0.169911
# AC007325.2                  False                 False       9  0.017246
# AC004556.1                  False                 False       0  0.482869
# AC240274.1                  False                 False       1  0.195335
#
#              dispersions  dispersions_norm
# MIR1302-2HG    -0.107463         -1.354816
# AL669831.5      1.259747          1.223400
# LINC00115       1.497555          1.671846
# FAM41C          1.684297          2.023994
# AL645608.7      0.726696          0.218199
# ...                  ...               ...
# AL592183.1      0.102937         -0.958054
# AC007325.4      0.488998         -0.230041
# AC007325.2      1.249787          1.204617
# AC004556.1      0.690596         -0.351638
# AC240274.1      0.525980         -0.160301
#
# [16182 rows x 66 columns]

# %%
len(adata.var.columns)
# Out:
# 66

# %%
adata.var = adata.var[['gene_ids', 'n_cells', 'Deep_n', 'means', 'dispersions', 'dispersions_norm']]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 649 × 16182
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'C7_leiden', 'C7_leiden_R', 'new_celltype'
#     var: 'gene_ids', 'n_cells', 'Deep_n', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'C7_leiden_R_colors', 'batch_colors', 'new_celltype_colors', 'old_celltype_colors', 'rank_genes_groups', 'rank_genes_groups_filtered'
#     obsm: 'X_C7filteredumap', 'X_Clusterumap', 'X_pca', 'X_umap'

# %%
def CalculateRaw(adata,scaling_factor=10000):
    #update by Polanski in Feb 2022
    #The object must contain a log-transformed matrix
    #This function returns an integer-count object
    #The normalization constant is assumed to be 10000
    #return anndata.AnnData(X=sparse.csr_matrix(np.rint(np.array(np.expm1(adata.X).todense().transpose())*(adata.obs['n_counts'].values).transpose() / scaling_factor).transpose()),\
    #              obs=adata.obs,var=adata.var,obsm=adata.obsm,varm=adata.varm)
    X = np.expm1(adata.X)
    scaling_vector = adata.obs['n_counts'].values / scaling_factor
    #.indptr[i]:.indptr[i+1] provides the .data coordinates where the i'th row of the data resides in CSR
    #which happens to be a cell, which happens to be what we have a unique entry in scaling_vector for
    for i in np.arange(X.shape[0]):
        X.data[X.indptr[i]:X.indptr[i+1]] = X.data[X.indptr[i]:X.indptr[i+1]] * scaling_vector[i]
    return sc.AnnData(X=np.rint(X),obs=adata.obs,var=adata.var,obsm=adata.obsm,varm=adata.varm)

# %%
raw = CalculateRaw(adata)

# %%
del raw.var

# %%
geno = pd.read_csv('~/genes_homo_sapiens.csv', header = None, names = ['ENSEMBLid', 'gena','no'])
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
geno
# Out:
#               ENSEMBLid                 gena no
# 0       ENSG00000223972              DDX11L1  5
# 1       ENST00000456328          DDX11L1-202  2
# 2       ENST00000450305          DDX11L1-201  2
# 3       ENSG00000227232               WASH7P  5
# 4       ENST00000488147           WASH7P-201  1
# ...                 ...                  ... ..
# 297782  ENST00000621424  ENSG110105435.4-001  4
# 297783  ENSG00000278625                   U6  1
# 297784  ENST00000616830            U6.88-201  1
# 297785  ENSG00000277374                   U1  1
# 297786  ENST00000612925            U1.29-201  1
#
# [297787 rows x 3 columns]

# %%
ens_ids = adata.var['gene_ids']

# %%
adata.var
# Out:
#                     gene_ids  n_cells  Deep_n     means  dispersions  \
# MIR1302-2HG  ENSG00000243485        3       0  0.003591    -0.107463
# AL669831.5   ENSG00000237491       20       0  0.044867     1.259747
# LINC00115    ENSG00000225880       29       1  0.074161     1.497555
# FAM41C       ENSG00000230368        3      14  0.011604     1.684297
# AL645608.7   ENSG00000272438        5       0  0.010806     0.726696
# ...                      ...      ...     ...       ...          ...
# AL592183.1   ENSG00000273748        7       1  0.008129     0.102937
# AC007325.4   ENSG00000278817      108       5  0.169911     0.488998
# AC007325.2   ENSG00000277196        7       9  0.017246     1.249787
# AC004556.1   ENSG00000276345      306       0  0.482869     0.690596
# AC240274.1   ENSG00000271254      130       1  0.195335     0.525980
#
#              dispersions_norm
# MIR1302-2HG         -1.354816
# AL669831.5           1.223400
# LINC00115            1.671846
# FAM41C               2.023994
# AL645608.7           0.218199
# ...                       ...
# AL592183.1          -0.958054
# AC007325.4          -0.230041
# AC007325.2           1.204617
# AC004556.1          -0.351638
# AC240274.1          -0.160301
#
# [16182 rows x 6 columns]

# %%
genedict = {key: 1 for key in list(geno.ENSEMBLid)}

# %%
genedict
# Out:
# {'ENSG00000223972': 1,
#  'ENST00000456328': 1,
#  'ENST00000450305': 1,
#  'ENSG00000227232': 1,
#  'ENST00000488147': 1,
#  'ENSG00000278267': 1,
#  'ENST00000619216': 1,
#  'ENSG00000243485': 1,
#  'ENST00000473358': 1,
#  'ENST00000469289': 1,
#  'ENSG00000284332': 1,
#  'ENST00000607096': 1,
#  'ENSG00000237613': 1,
#  'ENST00000417324': 1,
#  'ENST00000461467': 1,
#  'ENSG00000268020': 1,
#  'ENST00000606857': 1,
#  'ENSG00000240361': 1,
#  'ENST00000642116': 1,
#  'ENST00000492842': 1,
#  'ENSG00000186092': 1,
#  'ENST00000641515': 1,
#  'ENSG00000238009': 1,
#  'ENST00000466430': 1,
#  'ENST00000477740': 1,
#  'ENST00000471248': 1,
#  'ENST00000610542': 1,
#  'ENST00000453576': 1,
#  'ENSG00000239945': 1,
#  'ENST00000495576': 1,
#  'ENSG00000233750': 1,
#  'ENST00000442987': 1,
#  'ENSG00000268903': 1,
#  'ENST00000494149': 1,
#  'ENSG00000269981': 1,
#  'ENST00000595919': 1,
#  'ENSG00000239906': 1,
#  'ENST00000493797': 1,
#  'ENSG00000241860': 1,
#  'ENST00000484859': 1,
#  'ENST00000490997': 1,
#  'ENST00000466557': 1,
#  'ENST00000662089': 1,
#  'ENST00000491962': 1,
#  'ENST00000655252': 1,
#  'ENSG00000222623': 1,
#  'ENST00000410691': 1,
#  'ENSG00000241599': 1,
#  'ENST00000496488': 1,
#  'ENSG00000279928': 1,
#  'ENST00000624431': 1,
#  'ENSG00000279457': 1,
#  'ENST00000623083': 1,
#  'ENSG00000273874': 1,
#  'ENST00000612080': 1,
#  'ENSG00000228463': 1,
#  'ENST00000442116': 1,
#  'ENST00000448958': 1,
#  'ENST00000441866': 1,
#  'ENST00000634344': 1,
#  'ENST00000450734': 1,
#  'ENST00000424587': 1,
#  'ENSG00000286448': 1,
#  'ENST00000669836': 1,
#  'ENSG00000236679': 1,
#  'ENST00000458203': 1,
#  'ENSG00000236601': 1,
#  'ENST00000450983': 1,
#  'ENST00000412666': 1,
#  'ENST00000635159': 1,
#  'ENSG00000237094': 1,
#  'ENST00000431321': 1,
#  'ENST00000453935': 1,
#  'ENST00000440163': 1,
#  'ENST00000455207': 1,
#  'ENST00000455464': 1,
#  'ENST00000601814': 1,
#  'ENST00000445840': 1,
#  'ENST00000431812': 1,
#  'ENST00000419160': 1,
#  'ENST00000440038': 1,
#  'ENST00000642074': 1,
#  'ENST00000423728': 1,
#  'ENST00000616311': 1,
#  'ENST00000599771': 1,
#  'ENST00000641845': 1,
#  'ENST00000641916': 1,
#  'ENST00000601486': 1,
#  'ENST00000641579': 1,
#  'ENST00000616947': 1,
#  'ENST00000432964': 1,
#  'ENST00000608420': 1,
#  'ENST00000641303': 1,
#  'ENST00000641063': 1,
#  'ENST00000641049': 1,
#  'ENST00000642124': 1,
#  'ENSG00000269732': 1,
#  'ENST00000437905': 1,
#  'ENSG00000284733': 1,
#  'ENST00000426406': 1,
#  'ENSG00000233653': 1,
#  'ENST00000432723': 1,
#  'ENSG00000250575': 1,
#  'ENST00000514436': 1,
#  'ENSG00000278757': 1,
#  'ENST00000614007': 1,
#  'ENSG00000230021': 1,
#  'ENST00000634833': 1,
#  'ENST00000417636': 1,
#  'ENST00000419394': 1,
#  'ENST00000440196': 1,
#  'ENST00000641296': 1,
#  'ENST00000357876': 1,
#  'ENST00000635509': 1,
#  'ENST00000634337': 1,
#  'ENST00000648019': 1,
#  'ENST00000440200': 1,
#  'ENST00000452176': 1,
#  'ENST00000441245': 1,
#  'ENST00000414688': 1,
#  'ENST00000636676': 1,
#  'ENST00000447954': 1,
#  'ENSG00000235146': 1,
#  'ENST00000423796': 1,
#  'ENST00000450696': 1,
#  'ENSG00000225972': 1,
#  'ENST00000416931': 1,
#  'ENSG00000225630': 1,
#  'ENST00000457540': 1,
#  'ENSG00000237973': 1,
#  'ENST00000414273': 1,
#  'ENSG00000278791': 1,
#  'ENST00000621981': 1,
#  'ENSG00000229344': 1,
#  'ENST00000427426': 1,
#  'ENSG00000240409': 1,
#  'ENST00000467115': 1,
#  'ENSG00000248527': 1,
#  'ENST00000514057': 1,
#  'ENSG00000198744': 1,
#  'ENST00000416718': 1,
#  'ENSG00000268663': 1,
#  'ENST00000438434': 1,
#  'ENSG00000284662': 1,
#  'ENST00000332831': 1,
#  'ENSG00000229376': 1,
#  'ENST00000440782': 1,
#  'ENSG00000228327': 1,
#  'ENST00000506640': 1,
#  'ENST00000428504': 1,
#  'ENSG00000223181': 1,
#  'ENST00000411249': 1,
#  'ENSG00000229905': 1,
#  'ENST00000422528': 1,
#  'ENSG00000237491': 1,
#  'ENST00000655765': 1,
#  'ENST00000412115': 1,
#  'ENST00000670700': 1,
#  'ENST00000429505': 1,
#  'ENST00000657896': 1,
#  'ENST00000434264': 1,
#  'ENST00000457084': 1,
#  'ENST00000658648': 1,
#  'ENST00000656571': 1,
#  'ENST00000665867': 1,
#  'ENST00000669749': 1,
#  'ENST00000666217': 1,
#  'ENST00000665719': 1,
#  'ENST00000651411': 1,
#  'ENST00000589899': 1,
#  'ENST00000609830': 1,
#  'ENST00000443772': 1,
#  'ENST00000585826': 1,
#  'ENST00000592547': 1,
#  'ENST00000586928': 1,
#  'ENST00000585745': 1,
#  'ENST00000585768': 1,
#  'ENST00000590848': 1,
#  'ENST00000591440': 1,
#  'ENST00000587530': 1,
#  'ENST00000593022': 1,
#  'ENST00000589531': 1,
#  'ENST00000588951': 1,
#  'ENST00000586288': 1,
#  'ENST00000591702': 1,
#  'ENST00000655384': 1,
#  'ENST00000667728': 1,
#  'ENSG00000285268': 1,
#  'ENST00000644482': 1,
#  'ENSG00000230092': 1,
#  'ENST00000447500': 1,
#  'ENST00000590817': 1,
#  'ENSG00000177757': 1,
#  'ENST00000326734': 1,
#  'ENSG00000228794': 1,
#  'ENST00000624927': 1,
#  'ENST00000623808': 1,
#  'ENST00000445118': 1,
#  'ENST00000669922': 1,
#  'ENST00000670780': 1,
#  'ENST00000667414': 1,
#  'ENST00000666741': 1,
#  'ENST00000623070': 1,
#  'ENST00000659124': 1,
#  'ENST00000658846': 1,
#  'ENST00000608189': 1,
#  'ENST00000448975': 1,
#  'ENST00000449005': 1,
#  'ENST00000441765': 1,
#  'ENST00000609139': 1,
#  'ENST00000609009': 1,
#  'ENST00000657837': 1,
#  'ENST00000610067': 1,
#  'ENST00000416570': 1,
#  'ENST00000661237': 1,
#  'ENST00000668541': 1,
#  'ENST00000657175': 1,
#  'ENST00000660797': 1,
#  'ENST00000622921': 1,
#  'ENST00000670824': 1,
#  'ENST00000415295': 1,
#  'ENST00000425657': 1,
#  'ENSG00000225880': 1,
#  'ENST00000473798': 1,
#  'ENSG00000288531': 1,
#  'ENST00000671208': 1,
#  'ENST00000661463': 1,
#  'ENSG00000230368': 1,
#  'ENST00000446136': 1,
#  'ENST00000432963': 1,
#  'ENST00000427857': 1,
#  'ENSG00000234711': 1,
#  'ENST00000415481': 1,
#  'ENSG00000283040': 1,
#  'ENST00000635557': 1,
#  'ENSG00000272438': 1,
#  'ENST00000607769': 1,
#  'ENSG00000230699': 1,
#  'ENST00000448179': 1,
#  'ENSG00000241180': 1,
#  'ENST00000398216': 1,
#  'ENSG00000223764': 1,
#  'ENST00000609207': 1,
#  'ENST00000417705': 1,
#  'ENST00000432961': 1,
#  'ENSG00000187634': 1,
#  'ENST00000616016': 1,
#  'ENST00000618323': 1,
#  'ENST00000437963': 1,
#  'ENST00000342066': 1,
#  'ENST00000616125': 1,
#  'ENST00000618779': 1,
#  'ENST00000622503': 1,
#  'ENST00000618181': 1,
#  'ENST00000617307': 1,
#  'ENST00000341065': 1,
#  'ENST00000455979': 1,
#  'ENST00000478729': 1,
#  'ENST00000474461': 1,
#  'ENST00000466827': 1,
#  'ENST00000464948': 1,
#  'ENSG00000188976': 1,
#  'ENST00000327044': 1,
#  'ENST00000483767': 1,
#  'ENST00000477976': 1,
#  'ENST00000496938': 1,
#  'ENST00000487214': 1,
#  'ENST00000469563': 1,
#  'ENSG00000187961': 1,
#  'ENST00000338591': 1,
#  'ENST00000622660': 1,
#  'ENST00000463212': 1,
#  'ENST00000466300': 1,
#  'ENST00000481067': 1,
#  'ENSG00000187583': 1,
#  'ENST00000379410': 1,
#  'ENST00000379407': 1,
#  'ENST00000379409': 1,
#  'ENST00000480267': 1,
#  'ENST00000491024': 1,
#  'ENSG00000187642': 1,
#  'ENST00000341290': 1,
#  'ENST00000479361': 1,
#  'ENST00000433179': 1,
#  'ENSG00000272512': 1,
#  'ENST00000606034': 1,
#  'ENSG00000188290': 1,
#  'ENST00000428771': 1,
#  'ENST00000304952': 1,
#  'ENST00000481869': 1,
#  'ENST00000484667': 1,
#  'ENSG00000187608': 1,
#  'ENST00000624697': 1,
#  'ENST00000624652': 1,
#  'ENST00000649529': 1,
#  'ENSG00000231702': 1,
#  'ENST00000423619': 1,
#  'ENSG00000224969': 1,
#  'ENST00000458555': 1,
#  'ENSG00000188157': 1,
#  'ENST00000379370': 1,
#  'ENST00000620552': 1,
#  'ENST00000651234': 1,
#  'ENST00000652369': 1,
#  'ENST00000469403': 1,
#  'ENST00000479707': 1,
#  'ENST00000466223': 1,
#  'ENST00000478677': 1,
#  'ENST00000492947': 1,
#  'ENST00000461111': 1,
#  'ENSG00000242590': 1,
#  'ENST00000418300': 1,
#  'ENSG00000217801': 1,
#  'ENST00000394517': 1,
#  'ENST00000427998': 1,
#  'ENST00000456409': 1,
#  'ENST00000412397': 1,
#  'ENST00000433695': 1,
#  'ENST00000451054': 1,
#  'ENSG00000273443': 1,
#  'ENST00000442292': 1,
#  'ENSG00000237330': 1,
#  'ENST00000453464': 1,
#  'ENSG00000131591': 1,
#  'ENST00000379339': 1,
#  'ENST00000465822': 1,
#  'ENST00000421241': 1,
#  'ENST00000379325': 1,
#  'ENST00000487177': 1,
#  'ENST00000467751': 1,
#  'ENST00000477196': 1,
#  'ENST00000464905': 1,
#  'ENST00000379320': 1,
#  'ENST00000379319': 1,
#  'ENST00000434641': 1,
#  'ENST00000482816': 1,
#  'ENST00000462097': 1,
#  'ENST00000473600': 1,
#  'ENST00000475119': 1,
#  'ENST00000442117': 1,
#  'ENST00000427787': 1,
#  'ENST00000472741': 1,
#  'ENST00000480643': 1,
#  'ENSG00000285812': 1,
#  'ENST00000648183': 1,
#  'ENSG00000223823': 1,
#  'ENST00000416774': 1,
#  'ENSG00000207730': 1,
#  'ENST00000384997': 1,
#  'ENSG00000207607': 1,
#  'ENST00000384875': 1,
#  'ENSG00000198976': 1,
#  'ENST00000362106': 1,
#  'ENSG00000272141': 1,
#  'ENST00000606993': 1,
#  'ENSG00000205231': 1,
#  'ENST00000379317': 1,
#  'ENSG00000162571': 1,
#  'ENST00000379290': 1,
#  'ENST00000379289': 1,
#  'ENST00000506177': 1,
#  'ENST00000673999': 1,
#  'ENST00000379288': 1,
#  'ENST00000460998': 1,
#  'ENST00000514695': 1,
#  'ENST00000486379': 1,
#  'ENSG00000186891': 1,
#  'ENST00000328596': 1,
#  'ENST00000379268': 1,
#  'ENST00000486728': 1,
#  'ENST00000379265': 1,
#  'ENSG00000186827': 1,
#  'ENST00000497869': 1,
#  'ENST00000379236': 1,
#  'ENST00000453580': 1,
#  'ENSG00000078808': 1,
#  'ENST00000660930': 1,
#  'ENST00000360001': 1,
#  'ENST00000465727': 1,
#  'ENST00000263741': 1,
#  'ENST00000494748': 1,
#  'ENST00000478938': 1,
#  'ENST00000403997': 1,
#  'ENST00000459994': 1,
#  'ENSG00000176022': 1,
#  'ENST00000379198': 1,
#  'ENSG00000184163': 1,
#  'ENST00000462849': 1,
#  'ENST00000478606': 1,
#  'ENST00000330388': 1,
#  'ENST00000468365': 1,
#  'ENST00000486627': 1,
#  'ENSG00000260179': 1,
#  'ENST00000565563': 1,
#  'ENSG00000160087': 1,
#  'ENST00000450390': 1,
#  'ENST00000349431': 1,
#  'ENST00000347370': 1,
#  'ENST00000400929': 1,
#  'ENST00000464036': 1,
#  'ENST00000360466': 1,
#  'ENST00000400930': 1,
#  'ENST00000467339': 1,
#  'ENST00000473215': 1,
#  'ENST00000435198': 1,
#  'ENST00000509720': 1,
#  'ENST00000491779': 1,
#  'ENST00000466752': 1,
#  'ENST00000503294': 1,
#  'ENST00000477894': 1,
#  'ENST00000471154': 1,
#  'ENST00000422076': 1,
#  'ENST00000502382': 1,
#  'ENST00000461142': 1,
#  'ENST00000488418': 1,
#  'ENSG00000230415': 1,
#  'ENST00000434139': 1,
#  'ENST00000453732': 1,
#  'ENSG00000162572': 1,
#  'ENST00000379116': 1,
#  'ENST00000379101': 1,
#  'ENST00000338555': 1,
#  'ENST00000400928': 1,
#  'ENST00000470022': 1,
#  'ENST00000325425': 1,
#  'ENST00000467651': 1,
#  'ENST00000379099': 1,
#  'ENSG00000131584': 1,
#  'ENST00000492936': 1,
#  'ENST00000354700': 1,
#  'ENST00000467278': 1,
#  'ENST00000353662': 1,
#  'ENST00000470659': 1,
#  'ENST00000379037': 1,
#  'ENST00000476572': 1,
#  'ENST00000493992': 1,
#  'ENST00000472541': 1,
#  'ENST00000354980': 1,
#  'ENST00000478065': 1,
#  'ENST00000479108': 1,
#  'ENST00000438966': 1,
#  'ENSG00000278073': 1,
#  'ENST00000613751': 1,
#  'ENSG00000169972': 1,
#  'ENST00000379031': 1,
#  'ENST00000470520': 1,
#  'ENST00000463758': 1,
#  'ENST00000467712': 1,
#  'ENST00000493657': 1,
#  'ENSG00000127054': 1,
#  'ENST00000470030': 1,
#  'ENST00000540437': 1,
#  'ENST00000545578': 1,
#  'ENST00000620829': 1,
#  'ENST00000618806': 1,
#  'ENST00000497304': 1,
#  'ENST00000323275': 1,
#  'ENST00000435064': 1,
#  'ENST00000411962': 1,
#  'ENST00000462432': 1,
#  'ENST00000478641': 1,
#  'ENST00000421495': 1,
#  'ENST00000458452': 1,
#  'ENST00000419704': 1,
#  'ENST00000532772': 1,
#  'ENST00000450926': 1,
#  'ENST00000527098': 1,
#  'ENST00000485710': 1,
#  'ENST00000461514': 1,
#  'ENST00000525164': 1,
#  'ENST00000528879': 1,
#  'ENST00000525769': 1,
#  'ENST00000531377': 1,
#  'ENST00000527383': 1,
#  'ENST00000531292': 1,
#  'ENST00000467408': 1,
#  'ENST00000434694': 1,
#  'ENST00000531020': 1,
#  'ENST00000533916': 1,
#  'ENST00000488042': 1,
#  'ENST00000526797': 1,
#  'ENST00000526332': 1,
#  'ENST00000430786': 1,
#  'ENST00000527719': 1,
#  'ENST00000530031': 1,
#  'ENST00000526113': 1,
#  'ENST00000526904': 1,
#  'ENST00000525603': 1,
#  'ENST00000429572': 1,
#  'ENST00000498173': 1,
#  'ENST00000496353': 1,
#  'ENST00000493534': 1,
#  'ENST00000534345': 1,
#  'ENST00000532952': 1,
#  'ENST00000490853': 1,
#  'ENST00000531019': 1,
#  'ENST00000498476': 1,
#  'ENST00000470679': 1,
#  'ENST00000525285': 1,
#  'ENST00000530233': 1,
#  'ENSG00000283712': 1,
#  'ENST00000620702': 1,
#  'ENSG00000240731': 1,
#  'ENST00000444968': 1,
#  'ENSG00000224051': 1,
#  'ENST00000464957': 1,
#  'ENST00000343938': 1,
#  'ENST00000488011': 1,
#  'ENSG00000169962': 1,
#  'ENST00000339381': 1,
#  'ENSG00000107404': 1,
#  'ENST00000378891': 1,
#  'ENST00000378888': 1,
#  'ENST00000610709': 1,
#  'ENST00000632445': 1,
#  'ENST00000631679': 1,
#  'ENST00000634054': 1,
#  'ENST00000633096': 1,
#  'ENST00000472445': 1,
#  'ENSG00000284372': 1,
#  'ENST00000616525': 1,
#  'ENSG00000162576': 1,
#  'ENST00000474033': 1,
#  'ENST00000342753': 1,
#  'ENST00000309212': 1,
#  'ENST00000445648': 1,
#  'ENST00000477278': 1,
#  'ENST00000473097': 1,
#  'ENST00000478517': 1,
#  'ENST00000476718': 1,
#  'ENST00000464351': 1,
#  'ENST00000460473': 1,
#  'ENSG00000175756': 1,
#  'ENST00000338370': 1,
#  'ENST00000338338': 1,
#  'ENST00000321751': 1,
#  'ENST00000378853': 1,
#  'ENST00000489799': 1,
#  'ENST00000496905': 1,
#  'ENSG00000223663': 1,
#  'ENST00000435351': 1,
#  'ENSG00000221978': 1,
#  'ENST00000480479': 1,
#  'ENST00000400809': 1,
#  'ENST00000482621': 1,
#  'ENST00000463260': 1,
#  'ENST00000496007': 1,
#  'ENST00000482365': 1,
#  'ENST00000408952': 1,
#  'ENST00000481223': 1,
#  'ENST00000418865': 1,
#  'ENST00000505849': 1,
#  'ENST00000488340': 1,
#  'ENST00000492998': 1,
#  'ENST00000469113': 1,
#  'ENST00000480646': 1,
#  'ENST00000471930': 1,
#  'ENST00000408918': 1,
#  'ENST00000473872': 1,
#  'ENST00000425598': 1,
#  'ENST00000463895': 1,
#  'ENST00000497013': 1,
#  'ENSG00000224870': 1,
#  'ENST00000659048': 1,
#  'ENST00000448629': 1,
#  'ENST00000444362': 1,
#  'ENST00000418833': 1,
#  'ENST00000576232': 1,
#  'ENST00000570344': 1,
#  'ENST00000447725': 1,
#  'ENST00000572242': 1,
#  'ENST00000453521': 1,
#  'ENSG00000242485': 1,
#  'ENST00000344843': 1,
#  'ENST00000493287': 1,
#  'ENST00000487659': 1,
#  'ENST00000492508': 1,
#  'ENST00000482352': 1,
#  'ENST00000477686': 1,
#  'ENSG00000264293': 1,
#  'ENST00000582431': 1,
#  'ENSG00000272455': 1,
#  'ENST00000607307': 1,
#  'ENSG00000235098': 1,
#  'ENST00000537107': 1,
#  'ENST00000520296': 1,
#  'ENST00000427211': 1,
#  'ENST00000454272': 1,
#  'ENST00000442470': 1,
#  'ENSG00000225905': 1,
#  'ENST00000428932': 1,
#  'ENSG00000205116': 1,
#  'ENST00000378821': 1,
#  'ENSG00000225285': 1,
#  'ENST00000430109': 1,
#  'ENST00000434150': 1,
#  'ENST00000454562': 1,
#  'ENST00000417917': 1,
#  'ENSG00000179403': 1,
#  'ENST00000495558': 1,
#  'ENST00000338660': 1,
#  'ENST00000476993': 1,
#  'ENST00000471398': 1,
#  'ENSG00000215915': 1,
#  'ENST00000378785': 1,
#  'ENST00000475091': 1,
#  'ENST00000484537': 1,
#  'ENSG00000160072': 1,
#  'ENST00000673477': 1,
#  'ENST00000308647': 1,
#  'ENST00000472194': 1,
#  'ENST00000378736': 1,
#  'ENST00000485748': 1,
#  'ENST00000474481': 1,
#  'ENSG00000284740': 1,
#  'ENST00000641974': 1,
#  'ENST00000641679': 1,
#  'ENSG00000197785': 1,
#  'ENST00000378756': 1,
#  'ENST00000672388': 1,
#  'ENST00000378755': 1,
#  'ENST00000339113': 1,
#  'ENST00000536055': 1,
#  'ENST00000439513': 1,
#  'ENST00000429957': 1,
#  'ENST00000400830': 1,
#  'ENSG00000205090': 1,
#  'ENST00000378733': 1,
#  'ENST00000425828': 1,
#  'ENST00000624426': 1,
#  'ENSG00000160075': 1,
#  'ENST00000291386': 1,
#  'ENST00000378726': 1,
#  'ENST00000378725': 1,
#  'ENST00000359060': 1,
#  'ENSG00000215014': 1,
#  'ENST00000647566': 1,
#  'ENST00000366221': 1,
#  'ENSG00000274481': 1,
#  'ENST00000621860': 1,
#  'ENSG00000228594': 1,
#  'ENST00000422725': 1,
#  'ENSG00000286989': 1,
#  'ENST00000658591': 1,
#  'ENSG00000272106': 1,
#  'ENST00000607222': 1,
#  'ENSG00000197530': 1,
#  'ENST00000479659': 1,
#  'ENST00000489635': 1,
#  'ENST00000355826': 1,
#  'ENST00000505820': 1,
#  'ENST00000518681': 1,
#  'ENST00000520777': 1,
#  'ENST00000511502': 1,
#  'ENST00000477990': 1,
#  'ENST00000514363': 1,
#  'ENST00000487053': 1,
#  'ENST00000502470': 1,
#  'ENST00000378712': 1,
#  'ENST00000507082': 1,
#  'ENST00000463492': 1,
#  'ENST00000510793': 1,
#  'ENST00000504599': 1,
#  'ENST00000507229': 1,
#  'ENST00000503789': 1,
#  'ENST00000378708': 1,
#  'ENST00000506488': 1,
#  'ENST00000512004': 1,
#  'ENST00000508455': 1,
#  'ENST00000514234': 1,
#  'ENST00000467597': 1,
#  'ENST00000508148': 1,
#  'ENST00000486072': 1,
#  'ENST00000505370': 1,
#  'ENST00000473511': 1,
#  'ENST00000464570': 1,
#  'ENST00000483015': 1,
#  'ENST00000511910': 1,
#  'ENST00000470373': 1,
#  'ENSG00000189409': 1,
#  'ENST00000472264': 1,
#  'ENST00000356026': 1,
#  'ENST00000512731': 1,
#  'ENST00000378675': 1,
#  'ENST00000479814': 1,
#  'ENST00000435358': 1,
#  'ENST00000503792': 1,
#  'ENST00000489782': 1,
#  'ENST00000486400': 1,
#  'ENST00000490017': 1,
#  'ENSG00000248333': 1,
#  'ENST00000341832': 1,
#  'ENST00000407249': 1,
#  'ENST00000340677': 1,
#  'ENST00000611150': 1,
#  'ENST00000615951': 1,
#  'ENST00000626918': 1,
#  'ENST00000629289': 1,
#  'ENST00000629312': 1,
#  'ENST00000341028': 1,
#  'ENSG00000272004': 1,
#  'ENST00000607013': 1,
#  'ENSG00000189339': 1,
#  'ENST00000614300': 1,
#  'ENST00000617444': 1,
#  'ENST00000611123': 1,
#  'ENST00000480991': 1,
#  'ENST00000481276': 1,
#  'ENSG00000269737': 1,
#  'ENST00000596308': 1,
#  'ENST00000597891': 1,
#  'ENSG00000215914': 1,
#  'ENST00000234610': 1,
#  'ENSG00000008128': 1,
#  'ENST00000404249': 1,
#  'ENST00000356200': 1,
#  'ENST00000463652': 1,
#  'ENST00000356937': 1,
#  'ENST00000378638': 1,
#  'ENST00000509982': 1,
#  'ENST00000357760': 1,
#  'ENST00000358779': 1,
#  'ENST00000378633': 1,
#  'ENST00000460465': 1,
#  'ENST00000478901': 1,
#  'ENST00000468397': 1,
#  'ENST00000491311': 1,
#  'ENST00000495016': 1,
#  'ENST00000468800': 1,
#  'ENST00000464748': 1,
#  'ENST00000489300': 1,
#  'ENST00000492390': 1,
#  'ENST00000474916': 1,
#  'ENST00000479362': 1,
#  'ENST00000498810': 1,
#  'ENST00000487462': 1,
#  'ENST00000401096': 1,
#  'ENSG00000268575': 1,
#  'ENST00000598846': 1,
#  'ENSG00000227775': 1,
#  'ENST00000577672': 1,
#  'ENST00000417099': 1,
#  'ENST00000424604': 1,
#  'ENST00000418950': 1,
#  'ENSG00000215790': 1,
#  'ENST00000647043': 1,
#  'ENST00000475229': 1,
#  'ENST00000246421': 1,
#  'ENST00000643943': 1,
#  'ENSG00000008130': 1,
#  'ENST00000341426': 1,
#  'ENST00000341991': 1,
#  'ENST00000378625': 1,
#  'ENST00000342348': 1,
#  'ENST00000498806': 1,
#  'ENST00000469045': 1,
#  'ENST00000480499': 1,
#  'ENST00000497747': 1,
#  'ENST00000477235': 1,
#  'ENST00000489538': 1,
#  'ENST00000497615': 1,
#  'ENST00000497186': 1,
#  'ENST00000492845': 1,
#  'ENST00000492768': 1,
#  'ENST00000460602': 1,
#  'ENST00000464373': 1,
#  'ENST00000480542': 1,
#  'ENSG00000078369': 1,
#  'ENST00000610897': 1,
#  'ENST00000615252': 1,
#  'ENST00000378609': 1,
#  'ENST00000461893': 1,
#  'ENST00000471354': 1,
#  'ENST00000439272': 1,
#  'ENST00000434686': 1,
#  'ENST00000437146': 1,
#  'ENST00000607589': 1,
#  'ENST00000472614': 1,
#  'ENSG00000231050': 1,
#  'ENST00000412228': 1,
#  'ENSG00000169885': 1,
#  'ENST00000378604': 1,
#  'ENST00000307786': 1,
#  'ENST00000482402': 1,
#  'ENST00000462293': 1,
#  'ENSG00000178821': 1,
#  'ENST00000378602': 1,
#  'ENST00000310991': 1,
#  'ENST00000378598': 1,
#  'ENST00000470931': 1,
#  'ENST00000602604': 1,
#  'ENST00000416272': 1,
#  'ENSG00000142609': 1,
#  'ENST00000642590': 1,
#  'ENST00000493964': 1,
#  'ENST00000464311': 1,
#  'ENST00000682832': 1,
#  'ENST00000412120': 1,
#  'ENST00000493316': 1,
#  'ENST00000270720': 1,
#  'ENST00000468610': 1,
#  'ENST00000461752': 1,
#  'ENST00000378592': 1,
#  'ENST00000378590': 1,
#  'ENSG00000233542': 1,
#  'ENST00000443930': 1,
#  'ENST00000659674': 1,
#  'ENSG00000187730': 1,
#  'ENST00000638411': 1,
#  'ENST00000378585': 1,
#  'ENST00000639045': 1,
#  'ENST00000640067': 1,
#  'ENST00000638604': 1,
#  'ENST00000638771': 1,
#  'ENST00000639935': 1,
#  'ENST00000640949': 1,
#  'ENST00000640030': 1,
#  'ENST00000640423': 1,
#  'ENST00000639625': 1,
#  'ENST00000639777': 1,
#  'ENST00000640981': 1,
#  'ENST00000638763': 1,
#  'ENST00000639070': 1,
#  'ENST00000640892': 1,
#  'ENST00000640317': 1,
#  'ENST00000638804': 1,
#  'ENST00000640688': 1,
#  'ENSG00000226969': 1,
#  'ENST00000445600': 1,
#  'ENST00000449154': 1,
#  'ENSG00000067606': 1,
#  'ENST00000378567': 1,
#  'ENST00000468310': 1,
#  'ENST00000484419': 1,
#  'ENST00000503297': 1,
#  'ENST00000479566': 1,
#  'ENST00000466651': 1,
#  'ENST00000400921': 1,
#  'ENST00000495347': 1,
#  'ENST00000461106': 1,
#  'ENST00000461465': 1,
#  'ENST00000470596': 1,
#  'ENST00000496325': 1,
#  'ENST00000481140': 1,
#  'ENST00000482686': 1,
#  'ENST00000486681': 1,
#  'ENST00000470986': 1,
#  'ENST00000470511': 1,
#  'ENST00000471018': 1,
#  'ENST00000466352': 1,
#  'ENST00000497183': 1,
#  'ENST00000419838': 1,
#  'ENST00000479263': 1,
#  'ENST00000503672': 1,
#  'ENST00000478770': 1,
#  'ENST00000505322': 1,
#  'ENST00000472017': 1,
#  'ENSG00000271806': 1,
#  'ENST00000606533': 1,
#  'ENSG00000182873': 1,
#  'ENST00000333854': 1,
#  'ENST00000444529': 1,
#  'ENSG00000162585': 1,
#  'ENST00000400919': 1,
#  'ENST00000469733': 1,
#  'ENST00000428120': 1,
#  'ENST00000414253': 1,
#  'ENST00000400918': 1,
#  'ENST00000497675': 1,
#  'ENST00000378543': 1,
#  'ENST00000378546': 1,
#  'ENST00000401813': 1,
#  'ENST00000487186': 1,
#  'ENST00000476803': 1,
#  'ENST00000440825': 1,
#  'ENST00000420515': 1,
#  'ENST00000514625': 1,
#  'ENST00000420964': 1,
#  'ENSG00000234396': 1,
#  'ENST00000442483': 1,
#  'ENSG00000157933': 1,
#  'ENST00000378536': 1,
#  'ENST00000508416': 1,
#  'ENST00000478223': 1,
#  'ENST00000507179': 1,
#  'ENSG00000287356': 1,
#  'ENST00000659232': 1,
#  'ENST00000661319': 1,
#  'ENSG00000116151': 1,
#  'ENST00000378531': 1,
#  'ENST00000606372': 1,
#  'ENST00000378529': 1,
#  'ENST00000607342': 1,
#  'ENST00000469374': 1,
#  'ENST00000419785': 1,
#  'ENST00000449373': 1,
#  'ENST00000378525': 1,
#  'ENST00000607031': 1,
#  'ENST00000475812': 1,
#  'ENST00000494279': 1,
#  'ENSG00000272161': 1,
#  'ENST00000607720': 1,
#  'ENSG00000269896': 1,
#  'ENST00000602865': 1,
#  'ENST00000417061': 1,
#  'ENSG00000272420': 1,
#  'ENST00000607858': 1,
#  'ENSG00000157916': 1,
#  'ENST00000378513': 1,
#  'ENST00000378518': 1,
#  'ENST00000605895': 1,
#  'ENST00000306256': 1,
#  'ENST00000493207': 1,
#  'ENST00000378512': 1,
#  'ENST00000443438': 1,
#  'ENST00000488353': 1,
#  'ENST00000462129': 1,
#  'ENSG00000157911': 1,
#  'ENST00000288774': 1,
#  'ENST00000447513': 1,
#  'ENST00000650293': 1,
#  'ENST00000507596': 1,
#  'ENST00000510434': 1,
#  'ENST00000508384': 1,
#  'ENST00000515760': 1,
#  'ENST00000502666': 1,
#  'ENST00000514502': 1,
#  'ENSG00000149527': 1,
#  'ENST00000609981': 1,
#  'ENST00000449969': 1,
#  'ENST00000378486': 1,
#  'ENST00000419816': 1,
#  'ENST00000343889': 1,
#  'ENST00000278878': 1,
#  'ENST00000473964': 1,
#  'ENST00000462379': 1,
#  'ENSG00000224387': 1,
#  'ENST00000424657': 1,
#  'ENSG00000229393': 1,
#  'ENST00000442305': 1,
#  'ENSG00000157881': 1,
#  'ENST00000378466': 1,
#  'ENST00000435556': 1,
#  'ENST00000505228': 1,
#  'ENST00000502512': 1,
#  'ENST00000471361': 1,
#  'ENST00000487804': 1,
#  'ENST00000515423': 1,
#  'ENST00000468002': 1,
#  'ENST00000486396': 1,
#  'ENST00000502770': 1,
#  'ENST00000491212': 1,
#  'ENST00000514922': 1,
#  'ENSG00000197921': 1,
#  'ENST00000378453': 1,
#  'ENSG00000272449': 1,
#  'ENST00000644246': 1,
#  'ENST00000606645': 1,
#  'ENSG00000238164': 1,
#  'ENST00000449660': 1,
#  'ENST00000443892': 1,
#  'ENST00000416860': 1,
#  'ENST00000448624': 1,
#  'ENST00000432521': 1,
#  'ENST00000452793': 1,
#  'ENSG00000157873': 1,
#  'ENST00000426449': 1,
#  'ENST00000434817': 1,
#  'ENST00000435221': 1,
#  'ENST00000451778': 1,
#  'ENST00000409119': 1,
#  'ENST00000355716': 1,
#  'ENST00000475523': 1,
#  'ENST00000442392': 1,
#  'ENST00000482074': 1,
#  'ENST00000496064': 1,
#  'ENST00000463471': 1,
#  'ENST00000466750': 1,
#  'ENST00000471768': 1,
#  'ENST00000463835': 1,
#  'ENST00000482602': 1,
#  'ENST00000480305': 1,
#  'ENSG00000225931': 1,
#  'ENST00000456687': 1,
#  'ENSG00000228037': 1,
#  'ENST00000424215': 1,
#  'ENSG00000157870': 1,
#  'ENST00000493183': 1,
#  'ENST00000474659': 1,
#  'ENST00000444521': 1,
#  'ENST00000378425': 1,
#  'ENST00000419916': 1,
#  'ENST00000378424': 1,
#  'ENST00000537325': 1,
#  'ENST00000378427': 1,
#  'ENST00000464043': 1,
#  'ENST00000465233': 1,
#  'ENST00000498083': 1,
#  'ENST00000481683': 1,
#  'ENST00000484099': 1,
#  ...}

# %%
ens_ids2 = [x for x in ens_ids if (x in genedict or x.startswith('SARSCoV'))]

# %%
ens_ids2
# Out:
# ['ENSG00000243485',
#  'ENSG00000237491',
#  'ENSG00000225880',
#  'ENSG00000230368',
#  'ENSG00000272438',
#  'ENSG00000230699',
#  'ENSG00000223764',
#  'ENSG00000187634',
#  'ENSG00000188976',
#  'ENSG00000187961',
#  'ENSG00000188290',
#  'ENSG00000187608',
#  'ENSG00000188157',
#  'ENSG00000131591',
#  'ENSG00000078808',
#  'ENSG00000176022',
#  'ENSG00000160087',
#  'ENSG00000162572',
#  'ENSG00000131584',
#  'ENSG00000169972',
#  'ENSG00000127054',
#  'ENSG00000224051',
#  'ENSG00000107404',
#  'ENSG00000162576',
#  'ENSG00000175756',
#  'ENSG00000221978',
#  'ENSG00000242485',
#  'ENSG00000272455',
#  'ENSG00000235098',
#  'ENSG00000225905',
#  'ENSG00000225285',
#  'ENSG00000179403',
#  'ENSG00000160072',
#  'ENSG00000197785',
#  'ENSG00000205090',
#  'ENSG00000160075',
#  'ENSG00000215014',
#  'ENSG00000228594',
#  'ENSG00000272106',
#  'ENSG00000197530',
#  'ENSG00000189409',
#  'ENSG00000248333',
#  'ENSG00000272004',
#  'ENSG00000189339',
#  'ENSG00000008128',
#  'ENSG00000215790',
#  'ENSG00000008130',
#  'ENSG00000078369',
#  'ENSG00000178821',
#  'ENSG00000067606',
#  'ENSG00000182873',
#  'ENSG00000162585',
#  'ENSG00000157933',
#  'ENSG00000116151',
#  'ENSG00000157916',
#  'ENSG00000157911',
#  'ENSG00000157881',
#  'ENSG00000197921',
#  'ENSG00000272449',
:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adata.var['gene_symbols'] = adata.var_names

# %%
raw.var['gene_symbols'] = adata.var_names
raw.var_names = adata.var['gene_ids']

# %%
del adata.var['gene_ids']

# %%
del raw.var['gene_symbols']

# %%
adata = adata[:, ens_ids2].copy()
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
raw = raw[:, ens_ids2].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 649 × 16122
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'C7_leiden', 'C7_leiden_R', 'new_celltype'
#     var: 'n_cells', 'Deep_n', 'means', 'dispersions', 'dispersions_norm', 'gene_symbols'
#     uns: 'C7_leiden_R_colors', 'batch_colors', 'new_celltype_colors', 'old_celltype_colors', 'rank_genes_groups', 'rank_genes_groups_filtered'
#     obsm: 'X_C7filteredumap', 'X_Clusterumap', 'X_pca', 'X_umap'

# %%
raw
# Out:
# AnnData object with n_obs × n_vars = 649 × 16122
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'C7_leiden', 'C7_leiden_R', 'new_celltype'
#     obsm: 'X_C7filteredumap', 'X_Clusterumap', 'X_pca', 'X_umap'

# %%
del raw.obs
del raw.obsm

# %%
adata.var['feature_biotype'] = ["gene"] * len(adata.var)

# %%
raw.var['feature_biotype'] = ["gene"] * len(adata.var)

# %%
adata.raw = raw

# %% [markdown]
# ## 2. Pre-prepare before schema adjustments

# %%
adata.var
# Out:
#                  n_cells  Deep_n     means  dispersions  dispersions_norm  \
# gene_ids
# ENSG00000243485        3       0  0.003591    -0.107463         -1.354816
# ENSG00000237491       20       0  0.044867     1.259747          1.223400
# ENSG00000225880       29       1  0.074161     1.497555          1.671846
# ENSG00000230368        3      14  0.011604     1.684297          2.023994
# ENSG00000272438        5       0  0.010806     0.726696          0.218199
# ...                  ...     ...       ...          ...               ...
# ENSG00000273748        7       1  0.008129     0.102937         -0.958054
# ENSG00000278817      108       5  0.169911     0.488998         -0.230041
# ENSG00000277196        7       9  0.017246     1.249787          1.204617
# ENSG00000276345      306       0  0.482869     0.690596         -0.351638
# ENSG00000271254      130       1  0.195335     0.525980         -0.160301
#
#                 gene_symbols feature_biotype
# gene_ids
# ENSG00000243485  MIR1302-2HG            gene
# ENSG00000237491   AL669831.5            gene
# ENSG00000225880    LINC00115            gene
# ENSG00000230368       FAM41C            gene
# ENSG00000272438   AL645608.7            gene
# ...                      ...             ...
# ENSG00000273748   AL592183.1            gene
# ENSG00000278817   AC007325.4            gene
# ENSG00000277196   AC007325.2            gene
# ENSG00000276345   AC004556.1            gene
# ENSG00000271254   AC240274.1            gene
#
# [16122 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Apply the schema requirements:

# %% [markdown]
# # <ins>X

# %% [markdown]
# Raw and normal count matrices are in the object, no additional adjustment is needed!

# %% [markdown]
# # <ins>obs

# %%
adata.obs.columns
# Out:
# Index(['batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts',
#        'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score',
#        'G2M_score', 'C7_leiden', 'C7_leiden_R', 'new_celltype'],
#       dtype='object')

# %%
adata.obs
# Out:
#                                             batch  stage  dissection  \
# GCGCAGTGTCCAGTTA-5891STDY8062349  5891STDY8062349  18.00    Proximal
# GGATGTTTCTTTACAC-5891STDY8062353  5891STDY8062353  15.00    Proximal
# TGTCCCAGTGGAAAGA-5891STDY8062353  5891STDY8062353  15.00    Proximal
# AAACCTGCACCTCGGA-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ACATCAGAGTCGTACT-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ...                                           ...    ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# GAATGAAGTATAAACG-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
# TGGCCAGGTATAGTAG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTCCTTCATGTCTT-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTTAGGTCGGATCC-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
#
#                                  chemistry  percent_mito  n_counts  n_genes  \
# GCGCAGTGTCCAGTTA-5891STDY8062349    Normal      0.053423    5794.0     2262
# GGATGTTTCTTTACAC-5891STDY8062353    Normal      0.192780    2102.0     1378
# TGTCCCAGTGGAAAGA-5891STDY8062353    Normal      0.064559   14765.0     4308
# AAACCTGCACCTCGGA-WSSS8012016        Normal      0.009378    5176.0     1809
# ACATCAGAGTCGTACT-WSSS8012016        Normal      0.035617    8123.0     3058
# ...                                    ...           ...       ...      ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    Normal      0.051788    8221.0     3349
# GAATGAAGTATAAACG-5891STDY9030810    Normal      0.103537    3853.0     1816
# TGGCCAGGTATAGTAG-5891STDY9030810    Normal      0.060677   21703.0     5670
# TTCTCCTTCATGTCTT-5891STDY9030810    Normal      0.047309   22813.0     5970
# TTCTTAGGTCGGATCC-5891STDY9030810    Normal      0.043563    7399.0     2869
#
#                                   doublet_scores   bh_pval leiden phase  \
# GCGCAGTGTCCAGTTA-5891STDY8062349        0.140584  0.999862      7    G1
# GGATGTTTCTTTACAC-5891STDY8062353        0.160350  0.000021      7     S
# TGTCCCAGTGGAAAGA-5891STDY8062353        0.171779  0.000021      7    G1
# AAACCTGCACCTCGGA-WSSS8012016            0.163569  0.893066      7    G1
# ACATCAGAGTCGTACT-WSSS8012016            0.061184  0.921305      7    G1
# ...                                          ...       ...    ...   ...
# CTGAAGTAGTCAAGCG-5891STDY9030810        0.190647  0.796614      7    G1
# GAATGAAGTATAAACG-5891STDY9030810        0.090323  0.796614      7    G1
# TGGCCAGGTATAGTAG-5891STDY9030810        0.127860  0.796614      7    G1
# TTCTCCTTCATGTCTT-5891STDY9030810        0.258581  0.796614      7     S
# TTCTTAGGTCGGATCC-5891STDY9030810        0.206897  0.796614      7     S
#
#                                    S_score  G2M_score C7_leiden C7_leiden_R  \
# GCGCAGTGTCCAGTTA-5891STDY8062349 -0.042786  -0.117230         8           8
# GGATGTTTCTTTACAC-5891STDY8062353  0.002162  -0.161572         7           7
# TGTCCCAGTGGAAAGA-5891STDY8062353 -0.107704  -0.123366         7           7
# AAACCTGCACCTCGGA-WSSS8012016     -0.004359  -0.081952        10          10
# ACATCAGAGTCGTACT-WSSS8012016     -0.085392  -0.100867         4         4,1
# ...                                    ...        ...       ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810 -0.102093  -0.082692        11          11
# GAATGAAGTATAAACG-5891STDY9030810 -0.046438  -0.208117         6         6,0
# TGGCCAGGTATAGTAG-5891STDY9030810 -0.157894  -0.221724         6         6,0
# TTCTCCTTCATGTCTT-5891STDY9030810  0.015327  -0.130961         8           8
# TTCTTAGGTCGGATCC-5891STDY9030810  0.306583  -0.053603         8           8
#
#                                       new_celltype
# GCGCAGTGTCCAGTTA-5891STDY8062349  COL20A1+ Schwann
# GGATGTTTCTTTACAC-5891STDY8062353      Late Schwann
# TGTCCCAGTGGAAAGA-5891STDY8062353      Late Schwann
# AAACCTGCACCTCGGA-WSSS8012016         Early Schwann
# ACATCAGAGTCGTACT-WSSS8012016          PCP4+ neuron
# ...                                            ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    KCNIP4+ neuron
# GAATGAAGTATAAACG-5891STDY9030810       Mid Schwann
# TGGCCAGGTATAGTAG-5891STDY9030810       Mid Schwann
# TTCTCCTTCATGTCTT-5891STDY9030810  COL20A1+ Schwann
# TTCTTAGGTCGGATCC-5891STDY9030810  COL20A1+ Schwann
#
# [649 rows x 16 columns]

# %% [markdown]
# ## assay_ontology_term_id

# %% [markdown]
# Assay used in this study is 10x 5' v1. Publication

# %% [markdown]
# 10x 3' v2	"EFO:0009899"
# 10x 3' v3	"EFO:0009922"
# 10x 5' v1	"EFO:0011025"
# Smart-seq	"EFO:0008930"
# Smart-seq2	"EFO:0008931"

# %% [markdown]
# > Chromium Single Cell 5’ V(D)J Reagent Kits (V1.0 chemistry) were used for scRNAseq library
# construction.

# %%
adata.obs['assay_ontology_term_id'] = ['EFO:0011025'] * len(adata.obs)

# %%
adata.obs['assay_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    EFO:0011025
# GGATGTTTCTTTACAC-5891STDY8062353    EFO:0011025
# TGTCCCAGTGGAAAGA-5891STDY8062353    EFO:0011025
# AAACCTGCACCTCGGA-WSSS8012016        EFO:0011025
# ACATCAGAGTCGTACT-WSSS8012016        EFO:0011025
#                                        ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    EFO:0011025
# GAATGAAGTATAAACG-5891STDY9030810    EFO:0011025
# TGGCCAGGTATAGTAG-5891STDY9030810    EFO:0011025
# TTCTCCTTCATGTCTT-5891STDY9030810    EFO:0011025
# TTCTTAGGTCGGATCC-5891STDY9030810    EFO:0011025
# Name: assay_ontology_term_id, Length: 649, dtype: object

# %% [markdown]
# ## cell_type_ontology_term_id

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['new_celltype']

# %%
len(list(adata.obs['cell_type_ontology_term_id'].unique()))
# Out:
# 13

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['COL20A1+ Schwann',
#  'Late Schwann',
#  'Early Schwann',
#  'PCP4+ neuron',
#  'MFNG+ DBH+ neuron',
#  'Schwann precursor',
#  'TM4SF4+ CHODL+ neuron',
#  'SST+ neuron',
#  'KCNIP4+ neuron',
#  'TM4SF4+ PENK+ neuron',
#  'FGFBP2+ Neural progenitor',
#  'Mid Schwann',
#  'Proliferating Schwann']

# %%
mapping = {'COL20A1+ Schwann': 'CL:0002573',
 'Late Schwann': 'CL:0002573',
 'Early Schwann': 'CL:0002377', # immature
 'PCP4+ neuron': 'CL:0000540',
 'MFNG+ DBH+ neuron': 'CL:0000540',
 'Schwann precursor': 'CL:0002375',
 'TM4SF4+ CHODL+ neuron': 'CL:0000540',
 'SST+ neuron': 'CL:0000540',
 'KCNIP4+ neuron': 'CL:0000540',
 'TM4SF4+ PENK+ neuron': 'CL:0000540',
 'FGFBP2+ Neural progenitor': 'CL:0011020',
 'Mid Schwann': 'CL:0002573',
 'Proliferating Schwann': 'CL:0002573'}

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].map(mapping)

# %% [markdown]
# ## development_stage_ontology_term_id

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['stage']

# %%
list(adata.obs['stage'].unique())
# Out:
# [18.0, 15.0, 6.86, 5.0, 20.0, 22.0, 9.0, 11.0]

# %%
mapping = {18.0: 'HsapDv:0000055', 
           22.0: 'HsapDv:0000059', 
           15.0: 'HsapDv:0000052', 
           20.0: 'HsapDv:0000057', 
           6.86: 'HsapDv:0000026', 
           5.0: 'HsapDv:0000023', 
           9.0: 'HsapDv:0000046', 
           11.0: 'HsapDv:0000048'}

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].map(mapping)

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    HsapDv:0000055
# GGATGTTTCTTTACAC-5891STDY8062353    HsapDv:0000052
# TGTCCCAGTGGAAAGA-5891STDY8062353    HsapDv:0000052
# AAACCTGCACCTCGGA-WSSS8012016        HsapDv:0000026
# ACATCAGAGTCGTACT-WSSS8012016        HsapDv:0000026
#                                          ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    HsapDv:0000048
# GAATGAAGTATAAACG-5891STDY9030810    HsapDv:0000046
# TGGCCAGGTATAGTAG-5891STDY9030810    HsapDv:0000048
# TTCTCCTTCATGTCTT-5891STDY9030810    HsapDv:0000048
# TTCTTAGGTCGGATCC-5891STDY9030810    HsapDv:0000046
# Name: development_stage_ontology_term_id, Length: 649, dtype: object

# %%
adata.obs['development_stage_ontology_term_id'].unique()
# Out:
# array(['HsapDv:0000055', 'HsapDv:0000052', 'HsapDv:0000026',
#        'HsapDv:0000023', 'HsapDv:0000057', 'HsapDv:0000059',
#        'HsapDv:0000046', 'HsapDv:0000048'], dtype=object)

# %% [markdown]
# ## disease_ontology_term_id

# %%
adata.obs['disease_ontology_term_id'] = ['PATO:0000461'] * len(adata.obs)

# %%
adata.obs['disease_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    PATO:0000461
# GGATGTTTCTTTACAC-5891STDY8062353    PATO:0000461
# TGTCCCAGTGGAAAGA-5891STDY8062353    PATO:0000461
# AAACCTGCACCTCGGA-WSSS8012016        PATO:0000461
# ACATCAGAGTCGTACT-WSSS8012016        PATO:0000461
#                                         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    PATO:0000461
# GAATGAAGTATAAACG-5891STDY9030810    PATO:0000461
# TGGCCAGGTATAGTAG-5891STDY9030810    PATO:0000461
# TTCTCCTTCATGTCTT-5891STDY9030810    PATO:0000461
# TTCTTAGGTCGGATCC-5891STDY9030810    PATO:0000461
# Name: disease_ontology_term_id, Length: 649, dtype: object

# %%
adata.obs['disease_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    PATO:0000461
# GGATGTTTCTTTACAC-5891STDY8062353    PATO:0000461
# TGTCCCAGTGGAAAGA-5891STDY8062353    PATO:0000461
# AAACCTGCACCTCGGA-WSSS8012016        PATO:0000461
# ACATCAGAGTCGTACT-WSSS8012016        PATO:0000461
#                                         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    PATO:0000461
# GAATGAAGTATAAACG-5891STDY9030810    PATO:0000461
# TGGCCAGGTATAGTAG-5891STDY9030810    PATO:0000461
# TTCTCCTTCATGTCTT-5891STDY9030810    PATO:0000461
# TTCTTAGGTCGGATCC-5891STDY9030810    PATO:0000461
# Name: disease_ontology_term_id, Length: 649, dtype: object

# %% [markdown]
# ## ethnicity_ontology_term_id

# %%
adata.obs['ethnicity_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
adata.obs['ethnicity_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    unknown
# GGATGTTTCTTTACAC-5891STDY8062353    unknown
# TGTCCCAGTGGAAAGA-5891STDY8062353    unknown
# AAACCTGCACCTCGGA-WSSS8012016        unknown
# ACATCAGAGTCGTACT-WSSS8012016        unknown
#                                      ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    unknown
# GAATGAAGTATAAACG-5891STDY9030810    unknown
# TGGCCAGGTATAGTAG-5891STDY9030810    unknown
# TTCTCCTTCATGTCTT-5891STDY9030810    unknown
# TTCTTAGGTCGGATCC-5891STDY9030810    unknown
# Name: ethnicity_ontology_term_id, Length: 649, dtype: object

# %% [markdown]
# ## is_primary_data

# %%
allcells = pd.read_csv('/lustre/scratch117/cellgen/cellgeni/cxgportal_sets/fetal-lung/cellnames_all.csv', index_col=0)

# %%
allcells
# Out:
#                                                 batch dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349      5891STDY8062349   Proximal
# AAACCTGCACCGAATT-5891STDY8062349      5891STDY8062349   Proximal
# AAAGATGTCGTGACAT-5891STDY8062349      5891STDY8062349   Proximal
# AAAGCAACAAACGTGG-5891STDY8062349      5891STDY8062349   Proximal
# AAAGCAACATACTACG-5891STDY8062349      5891STDY8062349   Proximal
# ...                                               ...        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  WSSS_F_LNG8713184   Proximal
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# CATCGAACATTAACCG-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  WSSS_F_LNG8713188   Proximal
#
#                                         chemistry  percent_mito  n_counts  \
# AAACCTGAGACAGGCT-5891STDY8062349           Normal      0.042116    8711.0
# AAACCTGCACCGAATT-5891STDY8062349           Normal      0.042811    8228.0
# AAAGATGTCGTGACAT-5891STDY8062349           Normal      0.052119    3601.0
# AAAGCAACAAACGTGG-5891STDY8062349           Normal      0.069157    5707.0
# AAAGCAACATACTACG-5891STDY8062349           Normal      0.065710    7095.0
# ...                                           ...           ...       ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184         Normal      0.039884    9581.0
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185         Normal      0.034237    2706.0
# CATCGAACATTAACCG-WSSS_F_LNG8713185         Normal      0.040634    7625.0
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185         Normal      0.027229   13147.0
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  Trypsin+CD326      0.037289   20550.0
#
#                                     n_genes  doublet_scores   bh_pval  leiden  \
# AAACCTGAGACAGGCT-5891STDY8062349       3101        0.060127  0.826769       0
# AAACCTGCACCGAATT-5891STDY8062349       2992        0.131980  0.826769       0
# AAAGATGTCGTGACAT-5891STDY8062349       1714        0.051245  0.826769       0
# AAAGCAACAAACGTGG-5891STDY8062349       2280        0.083019  0.826769       0
# AAAGCAACATACTACG-5891STDY8062349       2639        0.070568  0.826769       0
# ...                                     ...             ...       ...     ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184     3133        0.330578  0.826283       8
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185     1305        0.394231  0.122739       8
# CATCGAACATTAACCG-WSSS_F_LNG8713185     2735        0.330578  0.122739       8
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185     3721        0.245161  0.122739       8
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188     4687        0.188732  0.815435       8
#
#                                    phase  ...  broad_celltype  \
# AAACCTGAGACAGGCT-5891STDY8062349      G1  ...      Fibroblast
# AAACCTGCACCGAATT-5891STDY8062349      G1  ...      Fibroblast
# AAAGATGTCGTGACAT-5891STDY8062349      G1  ...      Fibroblast
# AAAGCAACAAACGTGG-5891STDY8062349      G1  ...      Fibroblast
# AAAGCAACATACTACG-5891STDY8062349      G1  ...      Fibroblast
# ...                                  ...  ...             ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    G1  ...   Other myeloid
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    G1  ...   Other myeloid
# CATCGAACATTAACCG-WSSS_F_LNG8713185    G1  ...   Other myeloid
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185     S  ...   Other myeloid
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188   G2M  ...   Other myeloid
#
#                                     assay_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349               EFO:0011025
# AAACCTGCACCGAATT-5891STDY8062349               EFO:0011025
# AAAGATGTCGTGACAT-5891STDY8062349               EFO:0011025
# AAAGCAACAAACGTGG-5891STDY8062349               EFO:0011025
# AAAGCAACATACTACG-5891STDY8062349               EFO:0011025
# ...                                                    ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184             EFO:0011025
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185             EFO:0011025
# CATCGAACATTAACCG-WSSS_F_LNG8713185             EFO:0011025
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185             EFO:0011025
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188             EFO:0011025
#
#                                    cell_type_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349                   CL:4028004
# AAACCTGCACCGAATT-5891STDY8062349                   CL:4028004
# AAAGATGTCGTGACAT-5891STDY8062349                   CL:4028004
# AAAGCAACAAACGTGG-5891STDY8062349                   CL:4028004
# AAAGCAACATACTACG-5891STDY8062349                   CL:4028004
# ...                                                       ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184                 CL:0000097
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185                 CL:0000097
# CATCGAACATTAACCG-WSSS_F_LNG8713185                 CL:0000097
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185                 CL:0000097
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188                 CL:0000097
#
#                                    development_stage_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349                       HsapDv:0000055
# AAACCTGCACCGAATT-5891STDY8062349                       HsapDv:0000055
# AAAGATGTCGTGACAT-5891STDY8062349                       HsapDv:0000055
# AAAGCAACAAACGTGG-5891STDY8062349                       HsapDv:0000055
# AAAGCAACATACTACG-5891STDY8062349                       HsapDv:0000055
# ...                                                               ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184                     HsapDv:0000052
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185                     HsapDv:0000052
# CATCGAACATTAACCG-WSSS_F_LNG8713185                     HsapDv:0000052
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185                     HsapDv:0000052
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188                     HsapDv:0000052
#
#                                    disease_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349               PATO:0000461
# AAACCTGCACCGAATT-5891STDY8062349               PATO:0000461
# AAAGATGTCGTGACAT-5891STDY8062349               PATO:0000461
# AAAGCAACAAACGTGG-5891STDY8062349               PATO:0000461
# AAAGCAACATACTACG-5891STDY8062349               PATO:0000461
# ...                                                     ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184             PATO:0000461
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185             PATO:0000461
# CATCGAACATTAACCG-WSSS_F_LNG8713185             PATO:0000461
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185             PATO:0000461
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188             PATO:0000461
#
#                                    ethnicity_ontology_term_id is_primary_data  \
# AAACCTGAGACAGGCT-5891STDY8062349                      unknown            True
# AAACCTGCACCGAATT-5891STDY8062349                      unknown            True
# AAAGATGTCGTGACAT-5891STDY8062349                      unknown            True
# AAAGCAACAAACGTGG-5891STDY8062349                      unknown            True
# AAAGCAACATACTACG-5891STDY8062349                      unknown            True
# ...                                                       ...             ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184                    unknown            True
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185                    unknown            True
# CATCGAACATTAACCG-WSSS_F_LNG8713185                    unknown            True
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185                    unknown            True
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188                    unknown            True
#
#                                    organism_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349              NCBITaxon:9606
# AAACCTGCACCGAATT-5891STDY8062349              NCBITaxon:9606
# AAAGATGTCGTGACAT-5891STDY8062349              NCBITaxon:9606
# AAAGCAACAAACGTGG-5891STDY8062349              NCBITaxon:9606
# AAAGCAACATACTACG-5891STDY8062349              NCBITaxon:9606
# ...                                                      ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184            NCBITaxon:9606
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185            NCBITaxon:9606
# CATCGAACATTAACCG-WSSS_F_LNG8713185            NCBITaxon:9606
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185            NCBITaxon:9606
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188            NCBITaxon:9606
#
#                                    sex_ontology_term_id  \
# AAACCTGAGACAGGCT-5891STDY8062349           PATO:0000384
# AAACCTGCACCGAATT-5891STDY8062349           PATO:0000384
# AAAGATGTCGTGACAT-5891STDY8062349           PATO:0000384
# AAAGCAACAAACGTGG-5891STDY8062349           PATO:0000384
# AAAGCAACATACTACG-5891STDY8062349           PATO:0000384
# ...                                                 ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184         PATO:0000384
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185         PATO:0000384
# CATCGAACATTAACCG-WSSS_F_LNG8713185         PATO:0000384
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185         PATO:0000384
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188         PATO:0000384
#
#                                    tissue_ontology_term_id
# AAACCTGAGACAGGCT-5891STDY8062349            UBERON:0002048
# AAACCTGCACCGAATT-5891STDY8062349            UBERON:0002048
# AAAGATGTCGTGACAT-5891STDY8062349            UBERON:0002048
# AAAGCAACAAACGTGG-5891STDY8062349            UBERON:0002048
# AAAGCAACATACTACG-5891STDY8062349            UBERON:0002048
# ...                                                    ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184          UBERON:0002048
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185          UBERON:0002048
# CATCGAACATTAACCG-WSSS_F_LNG8713185          UBERON:0002048
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185          UBERON:0002048
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188          UBERON:0002048
#
# [71752 rows x 25 columns]

# %%
adata.obs['is_primary_data'] = [False] * len(adata.obs)

# %%
len(set(adata.obs_names).intersection(set(allcells.index)))
# Out:
# 649

# %%
adata.obs.loc[set(adata.obs_names).difference(set(allcells.index)),'is_primary_data'] = True

# %%
adata.obs['is_primary_data']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    False
# GGATGTTTCTTTACAC-5891STDY8062353    False
# TGTCCCAGTGGAAAGA-5891STDY8062353    False
# AAACCTGCACCTCGGA-WSSS8012016        False
# ACATCAGAGTCGTACT-WSSS8012016        False
#                                     ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    False
# GAATGAAGTATAAACG-5891STDY9030810    False
# TGGCCAGGTATAGTAG-5891STDY9030810    False
# TTCTCCTTCATGTCTT-5891STDY9030810    False
# TTCTTAGGTCGGATCC-5891STDY9030810    False
# Name: is_primary_data, Length: 649, dtype: bool

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %% [markdown]
# ## organism_ontology_term_id

# %%
adata.obs['organism_ontology_term_id'] = ['NCBITaxon:9606'] * len(adata.obs)

# %%
adata.obs['organism_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    NCBITaxon:9606
# GGATGTTTCTTTACAC-5891STDY8062353    NCBITaxon:9606
# TGTCCCAGTGGAAAGA-5891STDY8062353    NCBITaxon:9606
# AAACCTGCACCTCGGA-WSSS8012016        NCBITaxon:9606
# ACATCAGAGTCGTACT-WSSS8012016        NCBITaxon:9606
#                                          ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    NCBITaxon:9606
# GAATGAAGTATAAACG-5891STDY9030810    NCBITaxon:9606
# TGGCCAGGTATAGTAG-5891STDY9030810    NCBITaxon:9606
# TTCTCCTTCATGTCTT-5891STDY9030810    NCBITaxon:9606
# TTCTTAGGTCGGATCC-5891STDY9030810    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 649, dtype: object

# %%
adata.obs['organism_ontology_term_id'] = pd.Categorical(adata.obs['organism_ontology_term_id'])

# %%
adata.obs['organism_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    NCBITaxon:9606
# GGATGTTTCTTTACAC-5891STDY8062353    NCBITaxon:9606
# TGTCCCAGTGGAAAGA-5891STDY8062353    NCBITaxon:9606
# AAACCTGCACCTCGGA-WSSS8012016        NCBITaxon:9606
# ACATCAGAGTCGTACT-WSSS8012016        NCBITaxon:9606
#                                          ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    NCBITaxon:9606
# GAATGAAGTATAAACG-5891STDY9030810    NCBITaxon:9606
# TGGCCAGGTATAGTAG-5891STDY9030810    NCBITaxon:9606
# TTCTCCTTCATGTCTT-5891STDY9030810    NCBITaxon:9606
# TTCTTAGGTCGGATCC-5891STDY9030810    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 649, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %%
pd.set_option('display.max_columns', 500)

# %%
adata.obs
# Out:
#                                             batch  stage  dissection  \
# GCGCAGTGTCCAGTTA-5891STDY8062349  5891STDY8062349  18.00    Proximal
# GGATGTTTCTTTACAC-5891STDY8062353  5891STDY8062353  15.00    Proximal
# TGTCCCAGTGGAAAGA-5891STDY8062353  5891STDY8062353  15.00    Proximal
# AAACCTGCACCTCGGA-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ACATCAGAGTCGTACT-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ...                                           ...    ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# GAATGAAGTATAAACG-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
# TGGCCAGGTATAGTAG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTCCTTCATGTCTT-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTTAGGTCGGATCC-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
#
#                                  chemistry  percent_mito  n_counts  n_genes  \
# GCGCAGTGTCCAGTTA-5891STDY8062349    Normal      0.053423    5794.0     2262
# GGATGTTTCTTTACAC-5891STDY8062353    Normal      0.192780    2102.0     1378
# TGTCCCAGTGGAAAGA-5891STDY8062353    Normal      0.064559   14765.0     4308
# AAACCTGCACCTCGGA-WSSS8012016        Normal      0.009378    5176.0     1809
# ACATCAGAGTCGTACT-WSSS8012016        Normal      0.035617    8123.0     3058
# ...                                    ...           ...       ...      ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    Normal      0.051788    8221.0     3349
# GAATGAAGTATAAACG-5891STDY9030810    Normal      0.103537    3853.0     1816
# TGGCCAGGTATAGTAG-5891STDY9030810    Normal      0.060677   21703.0     5670
# TTCTCCTTCATGTCTT-5891STDY9030810    Normal      0.047309   22813.0     5970
# TTCTTAGGTCGGATCC-5891STDY9030810    Normal      0.043563    7399.0     2869
#
#                                   doublet_scores   bh_pval leiden phase  \
# GCGCAGTGTCCAGTTA-5891STDY8062349        0.140584  0.999862      7    G1
# GGATGTTTCTTTACAC-5891STDY8062353        0.160350  0.000021      7     S
# TGTCCCAGTGGAAAGA-5891STDY8062353        0.171779  0.000021      7    G1
# AAACCTGCACCTCGGA-WSSS8012016            0.163569  0.893066      7    G1
# ACATCAGAGTCGTACT-WSSS8012016            0.061184  0.921305      7    G1
# ...                                          ...       ...    ...   ...
# CTGAAGTAGTCAAGCG-5891STDY9030810        0.190647  0.796614      7    G1
# GAATGAAGTATAAACG-5891STDY9030810        0.090323  0.796614      7    G1
# TGGCCAGGTATAGTAG-5891STDY9030810        0.127860  0.796614      7    G1
# TTCTCCTTCATGTCTT-5891STDY9030810        0.258581  0.796614      7     S
# TTCTTAGGTCGGATCC-5891STDY9030810        0.206897  0.796614      7     S
#
#                                    S_score  G2M_score C7_leiden C7_leiden_R  \
# GCGCAGTGTCCAGTTA-5891STDY8062349 -0.042786  -0.117230         8           8
# GGATGTTTCTTTACAC-5891STDY8062353  0.002162  -0.161572         7           7
# TGTCCCAGTGGAAAGA-5891STDY8062353 -0.107704  -0.123366         7           7
# AAACCTGCACCTCGGA-WSSS8012016     -0.004359  -0.081952        10          10
# ACATCAGAGTCGTACT-WSSS8012016     -0.085392  -0.100867         4         4,1
# ...                                    ...        ...       ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810 -0.102093  -0.082692        11          11
# GAATGAAGTATAAACG-5891STDY9030810 -0.046438  -0.208117         6         6,0
# TGGCCAGGTATAGTAG-5891STDY9030810 -0.157894  -0.221724         6         6,0
# TTCTCCTTCATGTCTT-5891STDY9030810  0.015327  -0.130961         8           8
# TTCTTAGGTCGGATCC-5891STDY9030810  0.306583  -0.053603         8           8
#
#                                       new_celltype assay_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349  COL20A1+ Schwann            EFO:0011025
# GGATGTTTCTTTACAC-5891STDY8062353      Late Schwann            EFO:0011025
# TGTCCCAGTGGAAAGA-5891STDY8062353      Late Schwann            EFO:0011025
# AAACCTGCACCTCGGA-WSSS8012016         Early Schwann            EFO:0011025
# ACATCAGAGTCGTACT-WSSS8012016          PCP4+ neuron            EFO:0011025
# ...                                            ...                    ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    KCNIP4+ neuron            EFO:0011025
# GAATGAAGTATAAACG-5891STDY9030810       Mid Schwann            EFO:0011025
# TGGCCAGGTATAGTAG-5891STDY9030810       Mid Schwann            EFO:0011025
# TTCTCCTTCATGTCTT-5891STDY9030810  COL20A1+ Schwann            EFO:0011025
# TTCTTAGGTCGGATCC-5891STDY9030810  COL20A1+ Schwann            EFO:0011025
#
#                                  cell_type_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                 CL:0002573
# GGATGTTTCTTTACAC-5891STDY8062353                 CL:0002573
# TGTCCCAGTGGAAAGA-5891STDY8062353                 CL:0002573
# AAACCTGCACCTCGGA-WSSS8012016                     CL:0002377
# ACATCAGAGTCGTACT-WSSS8012016                     CL:0000540
# ...                                                     ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                 CL:0000540
# GAATGAAGTATAAACG-5891STDY9030810                 CL:0002573
# TGGCCAGGTATAGTAG-5891STDY9030810                 CL:0002573
# TTCTCCTTCATGTCTT-5891STDY9030810                 CL:0002573
# TTCTTAGGTCGGATCC-5891STDY9030810                 CL:0002573
#
#                                  development_stage_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                     HsapDv:0000055
# GGATGTTTCTTTACAC-5891STDY8062353                     HsapDv:0000052
# TGTCCCAGTGGAAAGA-5891STDY8062353                     HsapDv:0000052
# AAACCTGCACCTCGGA-WSSS8012016                         HsapDv:0000026
# ACATCAGAGTCGTACT-WSSS8012016                         HsapDv:0000026
# ...                                                             ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                     HsapDv:0000048
# GAATGAAGTATAAACG-5891STDY9030810                     HsapDv:0000046
# TGGCCAGGTATAGTAG-5891STDY9030810                     HsapDv:0000048
# TTCTCCTTCATGTCTT-5891STDY9030810                     HsapDv:0000048
# TTCTTAGGTCGGATCC-5891STDY9030810                     HsapDv:0000046
#
#                                  disease_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349             PATO:0000461
# GGATGTTTCTTTACAC-5891STDY8062353             PATO:0000461
# TGTCCCAGTGGAAAGA-5891STDY8062353             PATO:0000461
# AAACCTGCACCTCGGA-WSSS8012016                 PATO:0000461
# ACATCAGAGTCGTACT-WSSS8012016                 PATO:0000461
# ...                                                   ...
# CTGAAGTAGTCAAGCG-5891STDY9030810             PATO:0000461
# GAATGAAGTATAAACG-5891STDY9030810             PATO:0000461
# TGGCCAGGTATAGTAG-5891STDY9030810             PATO:0000461
# TTCTCCTTCATGTCTT-5891STDY9030810             PATO:0000461
# TTCTTAGGTCGGATCC-5891STDY9030810             PATO:0000461
#
#                                  ethnicity_ontology_term_id  is_primary_data  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                    unknown            False
# GGATGTTTCTTTACAC-5891STDY8062353                    unknown            False
# TGTCCCAGTGGAAAGA-5891STDY8062353                    unknown            False
# AAACCTGCACCTCGGA-WSSS8012016                        unknown            False
# ACATCAGAGTCGTACT-WSSS8012016                        unknown            False
# ...                                                     ...              ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                    unknown            False
# GAATGAAGTATAAACG-5891STDY9030810                    unknown            False
# TGGCCAGGTATAGTAG-5891STDY9030810                    unknown            False
# TTCTCCTTCATGTCTT-5891STDY9030810                    unknown            False
# TTCTTAGGTCGGATCC-5891STDY9030810                    unknown            False
#
#                                  organism_ontology_term_id
# GCGCAGTGTCCAGTTA-5891STDY8062349            NCBITaxon:9606
# GGATGTTTCTTTACAC-5891STDY8062353            NCBITaxon:9606
# TGTCCCAGTGGAAAGA-5891STDY8062353            NCBITaxon:9606
# AAACCTGCACCTCGGA-WSSS8012016                NCBITaxon:9606
# ACATCAGAGTCGTACT-WSSS8012016                NCBITaxon:9606
# ...                                                    ...
# CTGAAGTAGTCAAGCG-5891STDY9030810            NCBITaxon:9606
# GAATGAAGTATAAACG-5891STDY9030810            NCBITaxon:9606
# TGGCCAGGTATAGTAG-5891STDY9030810            NCBITaxon:9606
# TTCTCCTTCATGTCTT-5891STDY9030810            NCBITaxon:9606
# TTCTTAGGTCGGATCC-5891STDY9030810            NCBITaxon:9606
#
# [649 rows x 23 columns]

# %% [markdown]
# ## sex_ontology_term_id

# %% [markdown]
# **PATO_0000384 for male
# PATO_0000383 for female**

# %%
adata.obs['sex_ontology_term_id'] = ['x'] * len(adata.obs)

# %%
allcells.loc[list(set(allcells.index).intersection(set(adata.obs_names))), 'sex_ontology_term_id']
# Out:
# GTCCTCAGTGCGCTTG-WSSS8011222          PATO:0000383
# GGATTACGTTCATGGT-WSSS_F_LNG8713178    PATO:0000384
# TACGGATAGTAACCCT-WSSS8012016          PATO:0000383
# GGATGTTTCTTTACAC-5891STDY8062353      PATO:0000383
# CATGCCTTCAGCTCGG-WSSS8011222          PATO:0000383
#                                           ...
# GTTCTCGTCGTATCAG-WSSS8011222          PATO:0000383
# TGTGTTTTCAACCAAC-5891STDY9030809      PATO:0000384
# CGTAGGCGTATTCTCT-5891STDY9030808      PATO:0000383
# TAGGCATGTACCGCTG-WSSS8011222          PATO:0000383
# GACCTGGGTGTCTGAT-5891STDY9030809      PATO:0000384
# Name: sex_ontology_term_id, Length: 649, dtype: object

# %%
adata.obs.loc[list(set(adata.obs_names).difference(set(allcells.index))),'sex_ontology_term_id'] = 'unknown'

# %%
adata.obs.loc[list(set(allcells.index).intersection(set(adata.obs_names))),'sex_ontology_term_id'] = allcells.loc[list(set(allcells.index).intersection(set(adata.obs_names))), 'sex_ontology_term_id']

# %%
adata.obs['sex_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    PATO:0000384
# GGATGTTTCTTTACAC-5891STDY8062353    PATO:0000383
# TGTCCCAGTGGAAAGA-5891STDY8062353    PATO:0000383
# AAACCTGCACCTCGGA-WSSS8012016        PATO:0000383
# ACATCAGAGTCGTACT-WSSS8012016        PATO:0000383
#                                         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    PATO:0000384
# GAATGAAGTATAAACG-5891STDY9030810    PATO:0000383
# TGGCCAGGTATAGTAG-5891STDY9030810    PATO:0000384
# TTCTCCTTCATGTCTT-5891STDY9030810    PATO:0000384
# TTCTTAGGTCGGATCC-5891STDY9030810    PATO:0000383
# Name: sex_ontology_term_id, Length: 649, dtype: object

# %% [markdown]
# ## tissue_ontology_term_id

# %% [markdown]
# Lung: UBERON:0002048

# %%
adata.obs['tissue_ontology_term_id'] = ['UBERON:0002048'] * len(adata.obs)

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# GCGCAGTGTCCAGTTA-5891STDY8062349    UBERON:0002048
# GGATGTTTCTTTACAC-5891STDY8062353    UBERON:0002048
# TGTCCCAGTGGAAAGA-5891STDY8062353    UBERON:0002048
# AAACCTGCACCTCGGA-WSSS8012016        UBERON:0002048
# ACATCAGAGTCGTACT-WSSS8012016        UBERON:0002048
#                                          ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    UBERON:0002048
# GAATGAAGTATAAACG-5891STDY9030810    UBERON:0002048
# TGGCCAGGTATAGTAG-5891STDY9030810    UBERON:0002048
# TTCTCCTTCATGTCTT-5891STDY9030810    UBERON:0002048
# TTCTTAGGTCGGATCC-5891STDY9030810    UBERON:0002048
# Name: tissue_ontology_term_id, Length: 649, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # <ins>var and raw.var

# %%
adata.var
# Out:
#                  n_cells  Deep_n     means  dispersions  dispersions_norm  \
# gene_ids
# ENSG00000243485        3       0  0.003591    -0.107463         -1.354816
# ENSG00000237491       20       0  0.044867     1.259747          1.223400
# ENSG00000225880       29       1  0.074161     1.497555          1.671846
# ENSG00000230368        3      14  0.011604     1.684297          2.023994
# ENSG00000272438        5       0  0.010806     0.726696          0.218199
# ...                  ...     ...       ...          ...               ...
# ENSG00000273748        7       1  0.008129     0.102937         -0.958054
# ENSG00000278817      108       5  0.169911     0.488998         -0.230041
# ENSG00000277196        7       9  0.017246     1.249787          1.204617
# ENSG00000276345      306       0  0.482869     0.690596         -0.351638
# ENSG00000271254      130       1  0.195335     0.525980         -0.160301
#
#                 gene_symbols feature_biotype
# gene_ids
# ENSG00000243485  MIR1302-2HG            gene
# ENSG00000237491   AL669831.5            gene
# ENSG00000225880    LINC00115            gene
# ENSG00000230368       FAM41C            gene
# ENSG00000272438   AL645608.7            gene
# ...                      ...             ...
# ENSG00000273748   AL592183.1            gene
# ENSG00000278817   AC007325.4            gene
# ENSG00000277196   AC007325.2            gene
# ENSG00000276345   AC004556.1            gene
# ENSG00000271254   AC240274.1            gene
#
# [16122 rows x 7 columns]

# %% [markdown]
# ## feature_is_filtered

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var['feature_is_filtered']
# Out:
# gene_ids
# ENSG00000243485    False
# ENSG00000237491    False
# ENSG00000225880    False
# ENSG00000230368    False
# ENSG00000272438    False
#                    ...
# ENSG00000273748    False
# ENSG00000278817    False
# ENSG00000277196    False
# ENSG00000276345    False
# ENSG00000271254    False
# Name: feature_is_filtered, Length: 16122, dtype: bool

# %% [markdown]
# # <ins>obsm

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_C7filteredumap, X_Clusterumap, X_pca, X_umap

# %% [markdown]
# # <ins>uns

# %%
adata.uns['schema_version'] = '2.0.0'

# %%
adata.uns['title'] = 'PNS'

# %%
adata.uns['X_normalization'] = 'Scanpy'

# %%
adata.uns['default_embedding'] = 'X_umap'

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 4. Final adjustments

# %% [markdown]
# Final adjustments include the removal of the slots that were already re-created for the schema.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 649 × 16122
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'C7_leiden', 'C7_leiden_R', 'new_celltype', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id'
#     var: 'n_cells', 'Deep_n', 'means', 'dispersions', 'dispersions_norm', 'gene_symbols', 'feature_biotype', 'feature_is_filtered'
#     uns: 'C7_leiden_R_colors', 'batch_colors', 'new_celltype_colors', 'old_celltype_colors', 'rank_genes_groups', 'rank_genes_groups_filtered', 'schema_version', 'title', 'X_normalization', 'default_embedding'
#     obsm: 'X_C7filteredumap', 'X_Clusterumap', 'X_pca', 'X_umap'

# %%
adata.obs
# Out:
#                                             batch  stage  dissection  \
# GCGCAGTGTCCAGTTA-5891STDY8062349  5891STDY8062349  18.00    Proximal
# GGATGTTTCTTTACAC-5891STDY8062353  5891STDY8062353  15.00    Proximal
# TGTCCCAGTGGAAAGA-5891STDY8062353  5891STDY8062353  15.00    Proximal
# AAACCTGCACCTCGGA-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ACATCAGAGTCGTACT-WSSS8012016          WSSS8012016   6.86  Whole-lung
# ...                                           ...    ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# GAATGAAGTATAAACG-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
# TGGCCAGGTATAGTAG-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTCCTTCATGTCTT-5891STDY9030810  5891STDY9030810  11.00  Whole-lung
# TTCTTAGGTCGGATCC-5891STDY9030810  5891STDY9030810   9.00  Whole-lung
#
#                                  chemistry  percent_mito  n_counts  n_genes  \
# GCGCAGTGTCCAGTTA-5891STDY8062349    Normal      0.053423    5794.0     2262
# GGATGTTTCTTTACAC-5891STDY8062353    Normal      0.192780    2102.0     1378
# TGTCCCAGTGGAAAGA-5891STDY8062353    Normal      0.064559   14765.0     4308
# AAACCTGCACCTCGGA-WSSS8012016        Normal      0.009378    5176.0     1809
# ACATCAGAGTCGTACT-WSSS8012016        Normal      0.035617    8123.0     3058
# ...                                    ...           ...       ...      ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    Normal      0.051788    8221.0     3349
# GAATGAAGTATAAACG-5891STDY9030810    Normal      0.103537    3853.0     1816
# TGGCCAGGTATAGTAG-5891STDY9030810    Normal      0.060677   21703.0     5670
# TTCTCCTTCATGTCTT-5891STDY9030810    Normal      0.047309   22813.0     5970
# TTCTTAGGTCGGATCC-5891STDY9030810    Normal      0.043563    7399.0     2869
#
#                                   doublet_scores   bh_pval leiden phase  \
# GCGCAGTGTCCAGTTA-5891STDY8062349        0.140584  0.999862      7    G1
# GGATGTTTCTTTACAC-5891STDY8062353        0.160350  0.000021      7     S
# TGTCCCAGTGGAAAGA-5891STDY8062353        0.171779  0.000021      7    G1
# AAACCTGCACCTCGGA-WSSS8012016            0.163569  0.893066      7    G1
# ACATCAGAGTCGTACT-WSSS8012016            0.061184  0.921305      7    G1
# ...                                          ...       ...    ...   ...
# CTGAAGTAGTCAAGCG-5891STDY9030810        0.190647  0.796614      7    G1
# GAATGAAGTATAAACG-5891STDY9030810        0.090323  0.796614      7    G1
# TGGCCAGGTATAGTAG-5891STDY9030810        0.127860  0.796614      7    G1
# TTCTCCTTCATGTCTT-5891STDY9030810        0.258581  0.796614      7     S
# TTCTTAGGTCGGATCC-5891STDY9030810        0.206897  0.796614      7     S
#
#                                    S_score  G2M_score C7_leiden C7_leiden_R  \
# GCGCAGTGTCCAGTTA-5891STDY8062349 -0.042786  -0.117230         8           8
# GGATGTTTCTTTACAC-5891STDY8062353  0.002162  -0.161572         7           7
# TGTCCCAGTGGAAAGA-5891STDY8062353 -0.107704  -0.123366         7           7
# AAACCTGCACCTCGGA-WSSS8012016     -0.004359  -0.081952        10          10
# ACATCAGAGTCGTACT-WSSS8012016     -0.085392  -0.100867         4         4,1
# ...                                    ...        ...       ...         ...
# CTGAAGTAGTCAAGCG-5891STDY9030810 -0.102093  -0.082692        11          11
# GAATGAAGTATAAACG-5891STDY9030810 -0.046438  -0.208117         6         6,0
# TGGCCAGGTATAGTAG-5891STDY9030810 -0.157894  -0.221724         6         6,0
# TTCTCCTTCATGTCTT-5891STDY9030810  0.015327  -0.130961         8           8
# TTCTTAGGTCGGATCC-5891STDY9030810  0.306583  -0.053603         8           8
#
#                                       new_celltype assay_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349  COL20A1+ Schwann            EFO:0011025
# GGATGTTTCTTTACAC-5891STDY8062353      Late Schwann            EFO:0011025
# TGTCCCAGTGGAAAGA-5891STDY8062353      Late Schwann            EFO:0011025
# AAACCTGCACCTCGGA-WSSS8012016         Early Schwann            EFO:0011025
# ACATCAGAGTCGTACT-WSSS8012016          PCP4+ neuron            EFO:0011025
# ...                                            ...                    ...
# CTGAAGTAGTCAAGCG-5891STDY9030810    KCNIP4+ neuron            EFO:0011025
# GAATGAAGTATAAACG-5891STDY9030810       Mid Schwann            EFO:0011025
# TGGCCAGGTATAGTAG-5891STDY9030810       Mid Schwann            EFO:0011025
# TTCTCCTTCATGTCTT-5891STDY9030810  COL20A1+ Schwann            EFO:0011025
# TTCTTAGGTCGGATCC-5891STDY9030810  COL20A1+ Schwann            EFO:0011025
#
#                                  cell_type_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                 CL:0002573
# GGATGTTTCTTTACAC-5891STDY8062353                 CL:0002573
# TGTCCCAGTGGAAAGA-5891STDY8062353                 CL:0002573
# AAACCTGCACCTCGGA-WSSS8012016                     CL:0002377
# ACATCAGAGTCGTACT-WSSS8012016                     CL:0000540
# ...                                                     ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                 CL:0000540
# GAATGAAGTATAAACG-5891STDY9030810                 CL:0002573
# TGGCCAGGTATAGTAG-5891STDY9030810                 CL:0002573
# TTCTCCTTCATGTCTT-5891STDY9030810                 CL:0002573
# TTCTTAGGTCGGATCC-5891STDY9030810                 CL:0002573
#
#                                  development_stage_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                     HsapDv:0000055
# GGATGTTTCTTTACAC-5891STDY8062353                     HsapDv:0000052
# TGTCCCAGTGGAAAGA-5891STDY8062353                     HsapDv:0000052
# AAACCTGCACCTCGGA-WSSS8012016                         HsapDv:0000026
# ACATCAGAGTCGTACT-WSSS8012016                         HsapDv:0000026
# ...                                                             ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                     HsapDv:0000048
# GAATGAAGTATAAACG-5891STDY9030810                     HsapDv:0000046
# TGGCCAGGTATAGTAG-5891STDY9030810                     HsapDv:0000048
# TTCTCCTTCATGTCTT-5891STDY9030810                     HsapDv:0000048
# TTCTTAGGTCGGATCC-5891STDY9030810                     HsapDv:0000046
#
#                                  disease_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349             PATO:0000461
# GGATGTTTCTTTACAC-5891STDY8062353             PATO:0000461
# TGTCCCAGTGGAAAGA-5891STDY8062353             PATO:0000461
# AAACCTGCACCTCGGA-WSSS8012016                 PATO:0000461
# ACATCAGAGTCGTACT-WSSS8012016                 PATO:0000461
# ...                                                   ...
# CTGAAGTAGTCAAGCG-5891STDY9030810             PATO:0000461
# GAATGAAGTATAAACG-5891STDY9030810             PATO:0000461
# TGGCCAGGTATAGTAG-5891STDY9030810             PATO:0000461
# TTCTCCTTCATGTCTT-5891STDY9030810             PATO:0000461
# TTCTTAGGTCGGATCC-5891STDY9030810             PATO:0000461
#
#                                  ethnicity_ontology_term_id  is_primary_data  \
# GCGCAGTGTCCAGTTA-5891STDY8062349                    unknown            False
# GGATGTTTCTTTACAC-5891STDY8062353                    unknown            False
# TGTCCCAGTGGAAAGA-5891STDY8062353                    unknown            False
# AAACCTGCACCTCGGA-WSSS8012016                        unknown            False
# ACATCAGAGTCGTACT-WSSS8012016                        unknown            False
# ...                                                     ...              ...
# CTGAAGTAGTCAAGCG-5891STDY9030810                    unknown            False
# GAATGAAGTATAAACG-5891STDY9030810                    unknown            False
# TGGCCAGGTATAGTAG-5891STDY9030810                    unknown            False
# TTCTCCTTCATGTCTT-5891STDY9030810                    unknown            False
# TTCTTAGGTCGGATCC-5891STDY9030810                    unknown            False
#
#                                  organism_ontology_term_id  \
# GCGCAGTGTCCAGTTA-5891STDY8062349            NCBITaxon:9606
# GGATGTTTCTTTACAC-5891STDY8062353            NCBITaxon:9606
# TGTCCCAGTGGAAAGA-5891STDY8062353            NCBITaxon:9606
# AAACCTGCACCTCGGA-WSSS8012016                NCBITaxon:9606
# ACATCAGAGTCGTACT-WSSS8012016                NCBITaxon:9606
# ...                                                    ...
# CTGAAGTAGTCAAGCG-5891STDY9030810            NCBITaxon:9606
# GAATGAAGTATAAACG-5891STDY9030810            NCBITaxon:9606
# TGGCCAGGTATAGTAG-5891STDY9030810            NCBITaxon:9606
# TTCTCCTTCATGTCTT-5891STDY9030810            NCBITaxon:9606
# TTCTTAGGTCGGATCC-5891STDY9030810            NCBITaxon:9606
#
#                                  sex_ontology_term_id tissue_ontology_term_id
# GCGCAGTGTCCAGTTA-5891STDY8062349         PATO:0000384          UBERON:0002048
# GGATGTTTCTTTACAC-5891STDY8062353         PATO:0000383          UBERON:0002048
# TGTCCCAGTGGAAAGA-5891STDY8062353         PATO:0000383          UBERON:0002048
# AAACCTGCACCTCGGA-WSSS8012016             PATO:0000383          UBERON:0002048
# ACATCAGAGTCGTACT-WSSS8012016             PATO:0000383          UBERON:0002048
# ...                                               ...                     ...
# CTGAAGTAGTCAAGCG-5891STDY9030810         PATO:0000384          UBERON:0002048
# GAATGAAGTATAAACG-5891STDY9030810         PATO:0000383          UBERON:0002048
# TGGCCAGGTATAGTAG-5891STDY9030810         PATO:0000384          UBERON:0002048
# TTCTCCTTCATGTCTT-5891STDY9030810         PATO:0000384          UBERON:0002048
# TTCTTAGGTCGGATCC-5891STDY9030810         PATO:0000383          UBERON:0002048
#
# [649 rows x 25 columns]

# %%
adata.obs.dtypes
# Out:
# batch                                 category
# stage                                  float64
# dissection                            category
# chemistry                             category
# percent_mito                           float32
# n_counts                               float32
# n_genes                                  int64
# doublet_scores                         float64
# bh_pval                                float64
# leiden                                category
# phase                                 category
# S_score                                float32
# G2M_score                              float32
# C7_leiden                             category
# C7_leiden_R                           category
# new_celltype                          category
# assay_ontology_term_id                  object
# cell_type_ontology_term_id              object
# development_stage_ontology_term_id      object
# disease_ontology_term_id                object
# ethnicity_ontology_term_id              object
# is_primary_data                           bool
# organism_ontology_term_id             category
# sex_ontology_term_id                    object
# tissue_ontology_term_id                 object
# dtype: object

# %%
del adata.obs['stage']
del adata.obs['bh_pval']
del adata.obs['doublet_scores']
del adata.obs['C7_leiden']
del adata.obs['C7_leiden_R']

# %%
adata.obs.dtypes
# Out:
# batch                                 category
# dissection                            category
# chemistry                             category
# percent_mito                           float32
# n_counts                               float32
# n_genes                                  int64
# leiden                                category
# phase                                 category
# S_score                                float32
# G2M_score                              float32
# new_celltype                          category
# assay_ontology_term_id                  object
# cell_type_ontology_term_id              object
# development_stage_ontology_term_id      object
# disease_ontology_term_id                object
# ethnicity_ontology_term_id              object
# is_primary_data                           bool
# organism_ontology_term_id             category
# sex_ontology_term_id                    object
# tissue_ontology_term_id                 object
# dtype: object

# %%
adata.var.dtypes
# Out:
# n_cells                  int64
# Deep_n                   int32
# means                  float64
# dispersions            float64
# dispersions_norm       float32
# gene_symbols            object
# feature_biotype         object
# feature_is_filtered       bool
# dtype: object

# %%
# adata.obs
print('obs')
dty = pd.DataFrame(adata.obs.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.obs[c] = adata.obs[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.obs[c] = adata.obs[c].astype('int32') 
    print(f"changed {c} from int64 to int32")

# adata.var
print('var')
dty = pd.DataFrame(adata.var.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.var[c] = adata.var[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.var[c] = adata.var[c].astype('int32') 
    print(f"changed {c} from int64 to int32")
# Out:
# obs
# changed n_genes from int64 to int32
# var
# changed means from float64 to float32
# changed dispersions from float64 to float32
# changed n_cells from int64 to int32

# %%
adata.write('/lustre/scratch117/cellgen/cellgeni/cxgportal_sets/fetal-lung/final/fl_pns.h5ad', compression = 'gzip')
# Out:
# ... storing 'assay_ontology_term_id' as categorical
# ... storing 'cell_type_ontology_term_id' as categorical
# ... storing 'development_stage_ontology_term_id' as categorical
# ... storing 'disease_ontology_term_id' as categorical
# ... storing 'ethnicity_ontology_term_id' as categorical
# ... storing 'sex_ontology_term_id' as categorical
# ... storing 'tissue_ontology_term_id' as categorical
# ... storing 'feature_biotype' as categorical
# ... storing 'feature_biotype' as categorical

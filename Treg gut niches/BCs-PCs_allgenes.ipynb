# %% [markdown]
# ### **Curating BCs-PCs_allgenes**

# %% [markdown]
# Article: Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source : https://treg-gut-niches.cellgeni.sanger.ac.uk

# %% [markdown]
# ##### **Mount farm**

# %% [markdown]
# mount-farm

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import re
from collections import Counter

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
adata = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/BCs-PCs_allgenes.h5ad')

# %%
# View the AnnData object

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3912 × 19330
#     obs: 'final_annotation', 'lineage', 'location'
#     var: 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'location_colors'
#     obsm: 'X_pca', 'X_umap'

# %% [markdown]
# ##### **X - expression matrix**

# %%
# View the expression matrix of the anndata object.

# %%
adata.X
# Out:
# <3912x19330 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7916964 stored elements in Compressed Sparse Row format>

# %%
# Print the matrix to check whether they are normalized counts or raw counts. if the matrix has floating numbers,they are normalized counts.if they are integers, they are raw counts.

# %%
print(adata.X)
# Out:
#   (0, 3)	2.3085635
#   (0, 5)	0.82580304
#   (0, 15)	0.83009386
#   (0, 18)	0.8195916
#   (0, 32)	0.8286092
#   (0, 40)	3.2906787
#   (0, 44)	0.8251624
#   (0, 66)	0.8249553
#   (0, 67)	0.82418835
#   (0, 78)	0.8256777
#   (0, 86)	2.306515
#   (0, 92)	1.2756549
#   (0, 99)	1.2739407
#   (0, 103)	1.2763335
#   (0, 104)	0.8231335
#   (0, 111)	1.5784442
#   (0, 112)	0.82539594
#   (0, 115)	1.8203938
#   (0, 128)	1.2718738
#   (0, 129)	1.2749233
#   (0, 138)	0.8251257
#   (0, 140)	1.5779023
#   (0, 167)	1.2745485
#   (0, 170)	0.82341534
#   (0, 193)	0.80613863
#   :	:
#   (3911, 18952)	3.363887
#   (3911, 18959)	1.1136417
#   (3911, 18965)	1.1294258
#   (3911, 18982)	1.1367664
#   (3911, 19042)	1.1354567
#   (3911, 19057)	2.8923721
#   (3911, 19080)	1.6570591
#   (3911, 19125)	1.9989483
#   (3911, 19148)	1.1379305
#   (3911, 19173)	1.0212976
#   (3911, 19223)	1.6641432
#   (3911, 19230)	1.136623
#   (3911, 19235)	1.128641
#   (3911, 19255)	1.1370549
#   (3911, 19293)	1.1322955
#   (3911, 19294)	1.6481347
#   (3911, 19296)	2.228501
#   (3911, 19297)	2.889403
#   (3911, 19298)	1.631647
#   (3911, 19299)	2.2486973
#   (3911, 19300)	1.11075
#   (3911, 19302)	2.2345047
#   (3911, 19303)	1.1141528
#   (3911, 19306)	1.6293352
#   (3911, 19329)	1.9968642

# %%
adata.layers.keys()
# Out:
# KeysView(Layers with keys: )

# %% [markdown]
# ##### **Raw counts matrix**

# %%
araw = sc.read_h5ad('/nfs/team205/rb29/mice_gutTCRtg_project/Src/Mice-gut.TCRtg/new_analysis/h5ad_files/cellxgene/global_object_rawcounts.h5ad')

# %%
araw
# Out:
# AnnData object with n_obs × n_vars = 10831 × 19330
#     obs: 'original_annotation', 'anno', 'Dataset'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'

# %%
barcodes_of_interest = adata.obs_names

# Subset araw based on the extracted barcodes
subset_araw = araw[araw.obs_names.isin(barcodes_of_interest)]

# %%
subset_araw
# Out:
# View of AnnData object with n_obs × n_vars = 3912 × 19330
#     obs: 'original_annotation', 'anno', 'Dataset'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'

# %%
araw.layers.keys()
# Out:
# KeysView(Layers with keys: )

# %%
subset_araw.X
# Out:
# <3912x19330 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7925088 stored elements in Compressed Sparse Row format>

# %%
araw = ad.AnnData(X=subset_araw.X.copy(), obs=subset_araw.obs.copy(), var=subset_araw.var.copy())

# %%
araw
# Out:
# AnnData object with n_obs × n_vars = 3912 × 19330
#     obs: 'original_annotation', 'anno', 'Dataset'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'

# %%
print(araw.X)
# Out:
#   (0, 3)	7.0
#   (0, 5)	1.0
#   (0, 15)	1.0
#   (0, 18)	1.0
#   (0, 32)	1.0
#   (0, 40)	20.0
#   (0, 44)	1.0
#   (0, 66)	1.0
#   (0, 67)	1.0
#   (0, 78)	1.0
#   (0, 86)	7.0
#   (0, 92)	2.0
#   (0, 99)	2.0
#   (0, 103)	2.0
#   (0, 104)	1.0
#   (0, 111)	3.0
#   (0, 112)	1.0
#   (0, 115)	4.0
#   (0, 128)	2.0
#   (0, 129)	2.0
#   (0, 138)	1.0
#   (0, 140)	3.0
#   (0, 167)	2.0
#   (0, 170)	1.0
#   (0, 193)	1.0
#   :	:
#   (3911, 18952)	13.0
#   (3911, 18959)	1.0
#   (3911, 18965)	1.0
#   (3911, 18982)	1.0
#   (3911, 19042)	1.0
#   (3911, 19057)	8.0
#   (3911, 19080)	2.0
#   (3911, 19125)	3.0
#   (3911, 19148)	1.0
#   (3911, 19173)	1.0
#   (3911, 19223)	2.0
#   (3911, 19230)	1.0
#   (3911, 19235)	1.0
#   (3911, 19255)	1.0
#   (3911, 19293)	1.0
#   (3911, 19294)	2.0
#   (3911, 19296)	4.0
#   (3911, 19297)	8.0
#   (3911, 19298)	2.0
#   (3911, 19299)	4.0
#   (3911, 19300)	1.0
#   (3911, 19302)	4.0
#   (3911, 19303)	1.0
#   (3911, 19306)	2.0
#   (3911, 19329)	3.0

# %% [markdown]
# ##### **Variables(var)**

# %%
# View the var of anndata and raw object

# %%
adata.var
# Out:
#                    mt     rb  n_cells_by_counts  mean_counts  \
# Sox17           False  False                221     0.026731
# Mrpl15          False  False               3218     0.297666
# Lypla1          False  False               2460     0.188250
# Tcea1           False  False               6241     0.829154
# Rgs20           False  False                  3     0.000174
# ...               ...    ...                ...          ...
# CR974586.2      False  False                 67     0.007599
# CR974586.4      False  False                237     0.042484
# Ccl21a.1        False  False                 30     0.002436
# CAAA01147332.1  False  False               1400     0.095975
# AC149090.1      False  False               4401     0.400457
#
#                 pct_dropout_by_counts  total_counts  n_cells  highly_variable  \
# Sox17                       98.718025    460.818756      221             True
# Mrpl15                      81.333023   5131.465332     3218            False
# Lypla1                      85.730034   3245.247803     2460            False
# Tcea1                       63.797203  14293.792969     6241            False
# Rgs20                       99.982597      2.995511        3            False
# ...                               ...           ...      ...              ...
# CR974586.2                  99.611343    131.000000       67            False
# CR974586.4                  98.625214    732.385132      237             True
# Ccl21a.1                    99.825974     42.000000       30            False
# CAAA01147332.1              91.878876   1654.511108     1400            False
# AC149090.1                  74.470680   6903.481445     4401            False
#
#                    means  dispersions  dispersions_norm
# Sox17           0.131385     2.748144          2.592534
# Mrpl15          0.480022     1.226943         -0.471321
# Lypla1          0.353775     1.208837         -0.495850
# Tcea1           1.043117     1.383716         -0.455413
# Rgs20           0.000562     1.542446          0.282720
# ...                  ...          ...               ...
# CR974586.2      0.017431     1.512446          0.225248
# CR974586.4      0.101700     2.757137          2.609761
# Ccl21a.1        0.008137     1.713660          0.610724
# CAAA01147332.1  0.240455     1.431409          0.070001
# AC149090.1      0.789610     2.315884          0.485422
#
# [19330 rows x 11 columns]

# %%
araw.var
# Out:
#                           gene_ids    feature_types genome  n_cells
# Sox17           ENSMUSG00000025902  Gene Expression   mm10      221
# Mrpl15          ENSMUSG00000033845  Gene Expression   mm10     3218
# Lypla1          ENSMUSG00000025903  Gene Expression   mm10     2460
# Tcea1           ENSMUSG00000033813  Gene Expression   mm10     6241
# Rgs20           ENSMUSG00000002459  Gene Expression   mm10        3
# ...                            ...              ...    ...      ...
# CR974586.2      ENSMUSG00000095585  Gene Expression   mm10       67
# CR974586.4      ENSMUSG00000096506  Gene Expression   mm10      237
# Ccl21a-1        ENSMUSG00000095320  Gene Expression   mm10       30
# CAAA01147332.1  ENSMUSG00000095742  Gene Expression   mm10     1400
# AC149090.1      ENSMUSG00000095041  Gene Expression   mm10     4401
#
# [19330 rows x 4 columns]

# %%
old_names = ['Ptp4a1.1', 'Zc3h11a.1', 'Gm16701.1', 'Pakap.1', 'Fam220a.1',
             'Gm16499.1', 'Aldoa.1', 'Gm16364.1', 'St6galnac2.1', 'Gm41392.1',
             'Snhg4.1', 'Fam90a1b.1', 'Ccl21a.1']

new_names = ['Ptp4a1-1', 'Zc3h11a-1', 'Gm16701-1', 'Pakap-1', 'Fam220a-1',
             'Gm16499-1', 'Aldoa-1', 'Gm16364-1', 'St6galnac2-1', 'Gm41392-1',
             'Snhg4-1', 'Fam90a1b-1', 'Ccl21a-1']

# Create a dictionary for the replacements
rename_dict = dict(zip(old_names, new_names))

# Rename the values in adata.var.index
adata.var.index = adata.var.index.to_series().replace(rename_dict)

# %%
gene_name_to_id = {index: gene_id for index, gene_id in zip(araw.var.index, araw.var['gene_ids'])}

# %%
gene_name_to_id
# Out:
# {'Sox17': 'ENSMUSG00000025902',
#  'Mrpl15': 'ENSMUSG00000033845',
#  'Lypla1': 'ENSMUSG00000025903',
#  'Tcea1': 'ENSMUSG00000033813',
#  'Rgs20': 'ENSMUSG00000002459',
#  'Atp6v1h': 'ENSMUSG00000033793',
#  'Rb1cc1': 'ENSMUSG00000025907',
#  '4732440D04Rik': 'ENSMUSG00000090031',
#  'St18': 'ENSMUSG00000033740',
#  'Pcmtd1': 'ENSMUSG00000051285',
#  'Gm26901': 'ENSMUSG00000097797',
#  'Sntg1': 'ENSMUSG00000025909',
#  'Rrs1': 'ENSMUSG00000061024',
#  'Adhfe1': 'ENSMUSG00000025911',
#  '2610203C22Rik': 'ENSMUSG00000079671',
#  'Mybl1': 'ENSMUSG00000025912',
#  'Vcpip1': 'ENSMUSG00000045210',
#  '1700034P13Rik': 'ENSMUSG00000097893',
#  'Sgk3': 'ENSMUSG00000025915',
#  'Mcmdc2': 'ENSMUSG00000046101',
#  'Snhg6': 'ENSMUSG00000098234',
#  'Tcf24': 'ENSMUSG00000099032',
#  'Cops5': 'ENSMUSG00000025917',
#  'Cspp1': 'ENSMUSG00000056763',
#  'Arfgef1': 'ENSMUSG00000067851',
#  'Cpa6': 'ENSMUSG00000042501',
#  'Prex2': 'ENSMUSG00000048960',
#  'Sulf1': 'ENSMUSG00000016918',
#  'Slco5a1': 'ENSMUSG00000025938',
#  'Ncoa2': 'ENSMUSG00000005886',
#  'Gm29570': 'ENSMUSG00000101476',
#  'Tram1': 'ENSMUSG00000025935',
#  'Lactb2': 'ENSMUSG00000025937',
#  'Eya1': 'ENSMUSG00000025932',
#  'Gm9947': 'ENSMUSG00000054493',
#  'Msc': 'ENSMUSG00000025930',
#  'Trpa1': 'ENSMUSG00000032769',
#  'Terf1': 'ENSMUSG00000025925',
#  'Sbspon': 'ENSMUSG00000032719',
#  '4930444P10Rik': 'ENSMUSG00000067795',
#  'Rpl7': 'ENSMUSG00000043716',
#  'Rdh10': 'ENSMUSG00000025921',
#  'Stau2': 'ENSMUSG00000025920',
#  'Ube2w': 'ENSMUSG00000025939',
#  'Eloc': 'ENSMUSG00000079658',
#  'D030040B21Rik': 'ENSMUSG00000097744',
#  'Tmem70': 'ENSMUSG00000025940',
#  'Ly96': 'ENSMUSG00000025779',
#  'Jph1': 'ENSMUSG00000042686',
#  'Pi15': 'ENSMUSG00000067780',
#  'Gm16070': 'ENSMUSG00000085125',
#  'Crispld1': 'ENSMUSG00000025776',
#  'Il17a': 'ENSMUSG00000025929',
#  'Il17f': 'ENSMUSG00000041872',
#  'Mcm3': 'ENSMUSG00000041859',
#  '6720483E21Rik': 'ENSMUSG00000097934',
#  'Paqr8': 'ENSMUSG00000025931',
#  'Efhc1': 'ENSMUSG00000041809',
#  'Tram2': 'ENSMUSG00000041779',
#  'Tmem14a': 'ENSMUSG00000025933',
#  'Gsta3': 'ENSMUSG00000025934',
#  'Gm28836': 'ENSMUSG00000099343',
#  'Khdc1a': 'ENSMUSG00000067750',
#  'Kcnq5': 'ENSMUSG00000028033',
#  'Ogfrl1': 'ENSMUSG00000026158',
#  'B3gat2': 'ENSMUSG00000026156',
#  'Smap1': 'ENSMUSG00000026155',
#  'Sdhaf4': 'ENSMUSG00000026154',
#  'Fam135a': 'ENSMUSG00000026153',
#  'Lmbrd1': 'ENSMUSG00000073725',
#  '4931408C20Rik': 'ENSMUSG00000073722',
#  'Phf3': 'ENSMUSG00000048874',
#  'Ptp4a1': 'ENSMUSG00000026064',
#  'Ptp4a1-1': 'ENSMUSG00000117310',
#  '4931428L18Rik': 'ENSMUSG00000086727',
#  'Prim2': 'ENSMUSG00000026134',
#  'Rab23': 'ENSMUSG00000004768',
#  'Bag2': 'ENSMUSG00000042215',
#  'Zfp451': 'ENSMUSG00000042197',
#  'Bend6': 'ENSMUSG00000042182',
#  'Dst': 'ENSMUSG00000026131',
#  'Gm26788': 'ENSMUSG00000096992',
#  'Gm37233': 'ENSMUSG00000102336',
#  'Ccdc115': 'ENSMUSG00000042111',
#  'Gm28306': 'ENSMUSG00000101711',
#  'Imp4': 'ENSMUSG00000026127',
#  'Ptpn18': 'ENSMUSG00000026126',
#  'Gm28417': 'ENSMUSG00000100280',
#  '4930568A12Rik': 'ENSMUSG00000101223',
#  'Prss39': 'ENSMUSG00000026125',
#  'Arhgef4': 'ENSMUSG00000037509',
#  'Gm38336': 'ENSMUSG00000104002',
#  'Fam168b': 'ENSMUSG00000037503',
#  'Plekhb2': 'ENSMUSG00000026123',
#  'Gm37068': 'ENSMUSG00000104417',
#  '1110002O04Rik': 'ENSMUSG00000102531',
#  'Hs6st1': 'ENSMUSG00000045216',
#  'Gm33280': 'ENSMUSG00000102202',
#  'Uggt1': 'ENSMUSG00000037470',
#  'Neurl3': 'ENSMUSG00000047180',
#  'Arid5a': 'ENSMUSG00000037447',
#  'Kansl3': 'ENSMUSG00000010453',
#  'Fer1l5': 'ENSMUSG00000037432',
#  'Lman2l': 'ENSMUSG00000001143',
#  'Cnnm4': 'ENSMUSG00000037408',
#  'Cnnm3': 'ENSMUSG00000001138',
#  'Ankrd23': 'ENSMUSG00000067653',
#  'Ankrd39': 'ENSMUSG00000079610',
#  'Sema4c': 'ENSMUSG00000026121',
#  'D430040D24Rik': 'ENSMUSG00000087589',
#  'Fam178b': 'ENSMUSG00000046337',
#  'Cox5b': 'ENSMUSG00000061518',
#  'Actr1b': 'ENSMUSG00000037351',
#  '4933424G06Rik': 'ENSMUSG00000102416',
#  'Zap70': 'ENSMUSG00000026117',
#  'Tmem131': 'ENSMUSG00000026116',
#  'Gm38115': 'ENSMUSG00000102930',
#  'Vwa3b': 'ENSMUSG00000050122',
#  'Cnga3': 'ENSMUSG00000026114',
#  'Inpp4a': 'ENSMUSG00000026113',
#  'Coa5': 'ENSMUSG00000026112',
#  'Unc50': 'ENSMUSG00000026111',
#  'Mgat4a': 'ENSMUSG00000026110',
#  '2010300C02Rik': 'ENSMUSG00000026090',
#  'Tsga10': 'ENSMUSG00000060771',
#  'Gm26805': 'ENSMUSG00000097268',
#  'Lipt1': 'ENSMUSG00000037216',
#  'Mitd1': 'ENSMUSG00000026088',
#  'Mrpl30': 'ENSMUSG00000026087',
#  'Txndc9': 'ENSMUSG00000058407',
#  'Eif5b': 'ENSMUSG00000026083',
#  'Rev1': 'ENSMUSG00000026082',
#  'Gm37062': 'ENSMUSG00000103804',
#  'Gm5099': 'ENSMUSG00000102716',
#  'Aff3': 'ENSMUSG00000037138',
#  'Gm16152': 'ENSMUSG00000087131',
#  'Lonrf2': 'ENSMUSG00000048814',
#  'Chst10': 'ENSMUSG00000026080',
#  'Pdcl3': 'ENSMUSG00000026078',
#  'Npas2': 'ENSMUSG00000026077',
#  'Rpl31': 'ENSMUSG00000073702',
#  'Tbc1d8': 'ENSMUSG00000003134',
#  'Cnot11': 'ENSMUSG00000003135',
#  'Gm15832': 'ENSMUSG00000085894',
#  'Rnf149': 'ENSMUSG00000048234',
#  'Creg2': 'ENSMUSG00000050967',
#  'D930019O06Rik': 'ENSMUSG00000097083',
#  'Rfx8': 'ENSMUSG00000057173',
#  'Map4k4': 'ENSMUSG00000026074',
#  'Il1r2': 'ENSMUSG00000026073',
#  'Gm16894': 'ENSMUSG00000097899',
#  'Il1r1': 'ENSMUSG00000026072',
#  'Il1rl2': 'ENSMUSG00000070942',
#  'Il1rl1': 'ENSMUSG00000026069',
#  'Il18r1': 'ENSMUSG00000026070',
#  'Il18rap': 'ENSMUSG00000026068',
#  'Slc9a4': 'ENSMUSG00000026065',
#  'Slc9a2': 'ENSMUSG00000026062',
#  'Gm37915': 'ENSMUSG00000103270',
#  'Mfsd9': 'ENSMUSG00000041945',
#  'Mrps9': 'ENSMUSG00000060679',
#  'Gpr45': 'ENSMUSG00000041907',
#  'Tgfbrap1': 'ENSMUSG00000070939',
#  '8430432A02Rik': 'ENSMUSG00000041878',
#  'AI597479': 'ENSMUSG00000010290',
#  'Fhl2': 'ENSMUSG00000008136',
#  'Gm29040': 'ENSMUSG00000099576',
#  'Nck2': 'ENSMUSG00000066877',
#  'Ecrg4': 'ENSMUSG00000026051',
#  'Uxs1': 'ENSMUSG00000057363',
#  'Tpp2': 'ENSMUSG00000041763',
#  'Mettl21c': 'ENSMUSG00000047343',
#  'Gm8251': 'ENSMUSG00000091844',
#  'Tex30': 'ENSMUSG00000026049',
#  'Poglut2': 'ENSMUSG00000026047',
#  'Bivm': 'ENSMUSG00000041684',
#  'Ercc5': 'ENSMUSG00000026048',
#  'Gulp1': 'ENSMUSG00000056870',
#  'Col3a1': 'ENSMUSG00000026043',
#  'Col5a2': 'ENSMUSG00000026042',
#  'Wdr75': 'ENSMUSG00000025995',
#  'Slc40a1': 'ENSMUSG00000025993',
#  'Dnah7b': 'ENSMUSG00000041144',
#  'Slc39a10': 'ENSMUSG00000025986',
#  'Gm28151': 'ENSMUSG00000100213',
#  'Tmeff2': 'ENSMUSG00000026109',
#  'Cavin2': 'ENSMUSG00000045954',
#  'Nabp1': 'ENSMUSG00000026107',
#  'Gm17767': 'ENSMUSG00000099413',
#  'Myo1b': 'ENSMUSG00000018417',
#  'Gm28323': 'ENSMUSG00000100313',
#  'Stat4': 'ENSMUSG00000062939',
#  'Gm31812': 'ENSMUSG00000109599',
#  'Stat1': 'ENSMUSG00000026104',
#  'Gls': 'ENSMUSG00000026103',
#  'Nab1': 'ENSMUSG00000002881',
#  'Nemp2': 'ENSMUSG00000043015',
#  'Mfsd6': 'ENSMUSG00000041439',
#  'Gm29670': 'ENSMUSG00000100302',
#  'Inpp1': 'ENSMUSG00000026102',
#  'Hibch': 'ENSMUSG00000041426',
#  '1700019D03Rik': 'ENSMUSG00000043629',
#  'Pms1': 'ENSMUSG00000026098',
#  'Ormdl1': 'ENSMUSG00000026097',
#  'Osgepl1': 'ENSMUSG00000026096',
#  'Asnsd1': 'ENSMUSG00000026095',
#  'Dnah7a': 'ENSMUSG00000096141',
#  'Stk17b': 'ENSMUSG00000026094',
#  'Hecw2': 'ENSMUSG00000042807',
#  'Ccdc150': 'ENSMUSG00000025983',
#  'Gtf3c3': 'ENSMUSG00000041303',
#  'Pgap1': 'ENSMUSG00000073678',
#  'Ankrd44': 'ENSMUSG00000052331',
#  '4930444A19Rik': 'ENSMUSG00000101674',
#  'Sf3b1': 'ENSMUSG00000025982',
#  'Coq10b': 'ENSMUSG00000025981',
#  'Hspd1': 'ENSMUSG00000025980',
#  'Hspe1': 'ENSMUSG00000073676',
#  'Mob4': 'ENSMUSG00000025979',
#  'Rftn2': 'ENSMUSG00000025978',
#  'Gm10561': 'ENSMUSG00000097649',
#  'Mars2': 'ENSMUSG00000046994',
#  'Boll': 'ENSMUSG00000025977',
#  'Plcl1': 'ENSMUSG00000038349',
#  '1700003I22Rik': 'ENSMUSG00000100372',
#  'Satb2': 'ENSMUSG00000038331',
#  '9130024F11Rik': 'ENSMUSG00000087022',
#  '4930558J18Rik': 'ENSMUSG00000097519',
#  '1700066M21Rik': 'ENSMUSG00000038323',
#  'Tyw5': 'ENSMUSG00000048495',
#  'Maip1': 'ENSMUSG00000025971',
#  'Spats2l': 'ENSMUSG00000038305',
#  'Kctd18': 'ENSMUSG00000054770',
#  'Sgo2a': 'ENSMUSG00000026039',
#  'Aox1': 'ENSMUSG00000063558',
#  'Aox3': 'ENSMUSG00000064294',
#  'Bzw1': 'ENSMUSG00000051223',
#  'Clk1': 'ENSMUSG00000026034',
#  'Ppil3': 'ENSMUSG00000026035',
#  'Nif3l1': 'ENSMUSG00000026036',
#  'Orc2': 'ENSMUSG00000026037',
#  'Gm15834': 'ENSMUSG00000085054',
#  'Fam126b': 'ENSMUSG00000038174',
#  'Ndufb3': 'ENSMUSG00000026032',
#  'Flacc1': 'ENSMUSG00000047528',
#  'Cflar': 'ENSMUSG00000026031',
#  'Casp8': 'ENSMUSG00000026029',
#  'Trak2': 'ENSMUSG00000026028',
#  'Stradb': 'ENSMUSG00000026027',
#  'Tmem237': 'ENSMUSG00000038079',
#  'G730003C15Rik': 'ENSMUSG00000097573',
#  'Mpp4': 'ENSMUSG00000079550',
#  'Als2': 'ENSMUSG00000026024',
#  'Cdk15': 'ENSMUSG00000026023',
#  'Fzd7': 'ENSMUSG00000041075',
#  'Gm973': 'ENSMUSG00000047361',
#  'Gm28411': 'ENSMUSG00000099811',
#  'Sumo1': 'ENSMUSG00000026021',
#  'Nop58': 'ENSMUSG00000026020',
#  'Bmpr2': 'ENSMUSG00000067336',
#  'Fam117b': 'ENSMUSG00000041040',
#  'Ica1l': 'ENSMUSG00000026018',
#  'Wdr12': 'ENSMUSG00000026019',
#  'Carf': 'ENSMUSG00000026017',
#  'Nbeal1': 'ENSMUSG00000073664',
#  'Cyp20a1': 'ENSMUSG00000049439',
#  'Abi2': 'ENSMUSG00000026782',
#  'Raph1': 'ENSMUSG00000026014',
#  'Cd28': 'ENSMUSG00000026012',
#  'Gm11579': 'ENSMUSG00000086795',
#  'Ctla4': 'ENSMUSG00000026011',
#  'Icos': 'ENSMUSG00000026009',
#  'Gm11588': 'ENSMUSG00000086408',
#  'Pard3b': 'ENSMUSG00000052062',
#  'Pard3bos1': 'ENSMUSG00000085842',
#  'Gm29084': 'ENSMUSG00000100750',
#  'Nrp2': 'ENSMUSG00000025969',
#  'Ino80d': 'ENSMUSG00000040865',
#  'Ino80dos': 'ENSMUSG00000084799',
#  'Gm20342': 'ENSMUSG00000101599',
#  'Ndufs1': 'ENSMUSG00000025968',
#  'Eef1b2': 'ENSMUSG00000025967',
#  'Zdbf2': 'ENSMUSG00000027520',
#  'Adam23': 'ENSMUSG00000025964',
#  'Fastkd2': 'ENSMUSG00000025962',
#  'Klf7': 'ENSMUSG00000025959',
#  'Gm13748': 'ENSMUSG00000086836',
#  'Creb1': 'ENSMUSG00000025958',
#  'Mettl21a': 'ENSMUSG00000025956',
#  '2810408I11Rik': 'ENSMUSG00000087213',
#  'Ccnyl1': 'ENSMUSG00000070871',
#  'Fzd5': 'ENSMUSG00000045005',
#  'Plekhm3': 'ENSMUSG00000051344',
#  'Akr1cl': 'ENSMUSG00000025955',
#  'D630023F18Rik': 'ENSMUSG00000044816',
#  'Idh1': 'ENSMUSG00000025950',
#  'Pikfyve': 'ENSMUSG00000025949',
#  'Map2': 'ENSMUSG00000015222',
#  'Rpe': 'ENSMUSG00000026005',
#  'Kansl1l': 'ENSMUSG00000026004',
#  'Acadl': 'ENSMUSG00000026003',
#  'Myl1': 'ENSMUSG00000061816',
#  'Lancl1': 'ENSMUSG00000026000',
#  'Cps1': 'ENSMUSG00000025991',
#  'Ikzf2': 'ENSMUSG00000025997',
#  'Gm29112': 'ENSMUSG00000100815',
#  'Bard1': 'ENSMUSG00000026196',
#  'Atic': 'ENSMUSG00000026192',
#  'Fn1': 'ENSMUSG00000026193',
#  'Apol7d': 'ENSMUSG00000073652',
#  'Mreg': 'ENSMUSG00000039395',
#  'Pecr': 'ENSMUSG00000026189',
#  'Tmem169': 'ENSMUSG00000026188',
#  'Xrcc5': 'ENSMUSG00000026187',
#  'March4': 'ENSMUSG00000039372',
#  'Smarcal1': 'ENSMUSG00000039354',
#  'Rpl37a': 'ENSMUSG00000046330',
#  'Igfbp2': 'ENSMUSG00000039323',
#  'Igfbp5': 'ENSMUSG00000026185',
#  'Tns1': 'ENSMUSG00000055322',
#  'Rufy4': 'ENSMUSG00000061815',
#  'Cxcr2': 'ENSMUSG00000026180',
#  'Arpc2': 'ENSMUSG00000006304',
#  'Gpbar1': 'ENSMUSG00000064272',
#  'Aamp': 'ENSMUSG00000006299',
#  'Gm28364': 'ENSMUSG00000101503',
#  'Pnkd': 'ENSMUSG00000026179',
#  'Tmbim1': 'ENSMUSG00000006301',
#  'Gm29358': 'ENSMUSG00000099931',
#  'Catip': 'ENSMUSG00000073650',
#  'Slc11a1': 'ENSMUSG00000026177',
#  'Ctdsp1': 'ENSMUSG00000026176',
#  'Vil1': 'ENSMUSG00000026175',
#  'Usp37': 'ENSMUSG00000033364',
#  'Cnot9': 'ENSMUSG00000026174',
#  'Plcd4': 'ENSMUSG00000026173',
#  'Zfp142': 'ENSMUSG00000026135',
#  'Bcs1l': 'ENSMUSG00000026172',
#  'Rnf25': 'ENSMUSG00000026171',
#  'Stk36': 'ENSMUSG00000033276',
#  'Ttll4': 'ENSMUSG00000033257',
#  'Cyp27a1': 'ENSMUSG00000026170',
#  'Wnt6': 'ENSMUSG00000033227',
#  'Gm29539': 'ENSMUSG00000099472',
#  'Wnt10a': 'ENSMUSG00000026167',
#  'Ihh': 'ENSMUSG00000006538',
#  'Nhej1': 'ENSMUSG00000026162',
#  'Slc23a3': 'ENSMUSG00000026205',
#  'Cnppd1': 'ENSMUSG00000033159',
#  'Retreg2': 'ENSMUSG00000049339',
#  'Zfand2b': 'ENSMUSG00000026197',
#  'Abcb6': 'ENSMUSG00000026198',
#  'Atg9a': 'ENSMUSG00000033124',
#  'Ankzf1': 'ENSMUSG00000026199',
#  'Glb1l': 'ENSMUSG00000026200',
#  'Stk16': 'ENSMUSG00000026201',
#  'Tuba4a': 'ENSMUSG00000026202',
#  'A630095N17Rik': 'ENSMUSG00000096094',
#  'Dnajb2': 'ENSMUSG00000026203',
#  'Ptprn': 'ENSMUSG00000026204',
#  'Dnpep': 'ENSMUSG00000026209',
#  'Des': 'ENSMUSG00000026208',
#  'Speg': 'ENSMUSG00000026207',
#  'Gmppa': 'ENSMUSG00000033021',
#  'Chpf': 'ENSMUSG00000032997',
#  'Obsl1': 'ENSMUSG00000026211',
#  'Tmem198': 'ENSMUSG00000051703',
#  'Inha': 'ENSMUSG00000032968',
#  'Stk11ip': 'ENSMUSG00000026213',
#  'Slc4a3': 'ENSMUSG00000006576',
#  'Epha4': 'ENSMUSG00000026235',
#  'Sgpp2': 'ENSMUSG00000032908',
#  'Farsb': 'ENSMUSG00000026245',
#  'Mogat1': 'ENSMUSG00000012187',
#  'Acsl3': 'ENSMUSG00000032883',
#  'Utp14b': 'ENSMUSG00000079470',
#  'Kcne4': 'ENSMUSG00000047330',
#  'Ap1s3': 'ENSMUSG00000054702',
#  'Wdfy1': 'ENSMUSG00000073643',
#  'Mrpl44': 'ENSMUSG00000026248',
#  'Serpine2': 'ENSMUSG00000026249',
#  'Fam124b': 'ENSMUSG00000043230',
#  'Cul3': 'ENSMUSG00000004364',
#  'Gm29125': 'ENSMUSG00000101722',
#  '1700016L21Rik': 'ENSMUSG00000101483',
#  'Dock10': 'ENSMUSG00000038608',
#  'Irs1': 'ENSMUSG00000055980',
#  'Rhbdd1': 'ENSMUSG00000026142',
#  'Col4a4': 'ENSMUSG00000067158',
#  'Col4a3': 'ENSMUSG00000079465',
#  'C430014B12Rik': 'ENSMUSG00000097564',
#  'Mff': 'ENSMUSG00000026150',
#  'Gm28941': 'ENSMUSG00000101450',
#  'Tm4sf20': 'ENSMUSG00000026149',
#  'Gm28942': 'ENSMUSG00000100170',
#  'Agfg1': 'ENSMUSG00000026159',
#  'A030005L19Rik': 'ENSMUSG00000113880',
#  'Ccl20': 'ENSMUSG00000026166',
#  'Daw1': 'ENSMUSG00000053161',
#  'Pid1': 'ENSMUSG00000045658',
#  'Trip12': 'ENSMUSG00000026219',
#  'Fbxo36': 'ENSMUSG00000073633',
#  'Slc16a14': 'ENSMUSG00000026220',
#  'C130026I21Rik': 'ENSMUSG00000052477',
#  'A530032D15Rik': 'ENSMUSG00000089844',
#  'Gm10553': 'ENSMUSG00000073631',
#  'A530040E14Rik': 'ENSMUSG00000072109',
#  'Gm16028': 'ENSMUSG00000090252',
#  'Gm16025': 'ENSMUSG00000089652',
#  'Sp110': 'ENSMUSG00000070034',
#  'Gm16094': 'ENSMUSG00000090103',
#  'Sp140': 'ENSMUSG00000070031',
#  'Gm10552': 'ENSMUSG00000073628',
#  'Gm17017': 'ENSMUSG00000090246',
#  'Sp100': 'ENSMUSG00000026222',
#  'A630001G21Rik': 'ENSMUSG00000052760',
#  'Cab39': 'ENSMUSG00000036707',
#  'Itm2c': 'ENSMUSG00000026223',
#  '4933407L21Rik': 'ENSMUSG00000026224',
#  'Gm28884': 'ENSMUSG00000099767',
#  'Gpr55': 'ENSMUSG00000049608',
#  'Gm28100': 'ENSMUSG00000100108',
#  '2810459M11Rik': 'ENSMUSG00000026227',
#  'Psmd1': 'ENSMUSG00000026229',
#  'Htr2b': 'ENSMUSG00000026228',
#  'Armc9': 'ENSMUSG00000062590',
#  'Gm16341': 'ENSMUSG00000087538',
#  'B3gnt7': 'ENSMUSG00000079445',
#  'Gm28626': 'ENSMUSG00000099644',
#  'Ncl': 'ENSMUSG00000026234',
#  'C130036L24Rik': 'ENSMUSG00000073627',
#  'Nmur1': 'ENSMUSG00000026237',
#  'Ptma': 'ENSMUSG00000026238',
#  'Pde6d': 'ENSMUSG00000026239',
#  'Cops7b': 'ENSMUSG00000026240',
#  'Nppc': 'ENSMUSG00000026241',
#  'Dis3l2': 'ENSMUSG00000053333',
#  'Gm29055': 'ENSMUSG00000100768',
#  'Akp3': 'ENSMUSG00000036500',
#  'Gm29374': 'ENSMUSG00000099839',
#  'Ecel1': 'ENSMUSG00000026247',
#  'Chrng': 'ENSMUSG00000026253',
#  'Eif4e2': 'ENSMUSG00000026254',
#  'Efhd1': 'ENSMUSG00000026255',
#  'Gigyf2': 'ENSMUSG00000048000',
#  'Kcnj13': 'ENSMUSG00000079436',
#  'Ngef': 'ENSMUSG00000026259',
#  'Inpp5d': 'ENSMUSG00000026288',
#  'Atg16l1': 'ENSMUSG00000026289',
#  'Sag': 'ENSMUSG00000056055',
#  'Dgkd': 'ENSMUSG00000070738',
#  'Gm19582': 'ENSMUSG00000101942',
#  'Usp40': 'ENSMUSG00000005501',
#  'Gm20528': 'ENSMUSG00000092220',
#  'Ugt1a7c': 'ENSMUSG00000090124',
#  'Ugt1a6a': 'ENSMUSG00000054545',
#  'Ugt1a5': 'ENSMUSG00000089943',
#  'Dnajb3': 'ENSMUSG00000081984',
#  'Ugt1a1': 'ENSMUSG00000089960',
#  'Mroh2a': 'ENSMUSG00000079429',
#  'Hjurp': 'ENSMUSG00000044783',
#  'Glrp1': 'ENSMUSG00000062310',
#  'Gm29336': 'ENSMUSG00000100367',
#  'Arl4c': 'ENSMUSG00000049866',
#  'Sh3bp4': 'ENSMUSG00000036206',
#  'Agap1': 'ENSMUSG00000055013',
#  'Gm28499': 'ENSMUSG00000101662',
#  'Gbx2': 'ENSMUSG00000034486',
#  'D130058E05Rik': 'ENSMUSG00000092627',
#  'Iqca': 'ENSMUSG00000026301',
#  'Ackr3': 'ENSMUSG00000044337',
#  'Cops8': 'ENSMUSG00000034432',
#  'Col6a3': 'ENSMUSG00000048126',
#  'Mlph': 'ENSMUSG00000026303',
#  'Rab17': 'ENSMUSG00000026304',
#  'Lrrfip1': 'ENSMUSG00000026305',
#  'Rbm44': 'ENSMUSG00000070732',
#  'Ramp1': 'ENSMUSG00000034353',
#  'Ube2f': 'ENSMUSG00000034343',
#  'Scly': 'ENSMUSG00000026307',
#  'Klhl30': 'ENSMUSG00000026308',
#  'Erfe': 'ENSMUSG00000047443',
#  'Ilkap': 'ENSMUSG00000026309',
#  '1700020N18Rik': 'ENSMUSG00000100253',
#  'Hes6': 'ENSMUSG00000067071',
#  'Per2': 'ENSMUSG00000055866',
#  'Traf3ip1': 'ENSMUSG00000034292',
#  'Asb1': 'ENSMUSG00000026311',
#  'Twist2': 'ENSMUSG00000007805',
#  'Hdac4': 'ENSMUSG00000026313',
#  'Ndufa10': 'ENSMUSG00000026260',
#  'Cops9': 'ENSMUSG00000073616',
#  'Otos': 'ENSMUSG00000044055',
#  'Gpc1': 'ENSMUSG00000034220',
#  'Ankmy1': 'ENSMUSG00000034212',
#  'Dusp28': 'ENSMUSG00000047067',
#  '5033417F24Rik': 'ENSMUSG00000097251',
#  'Rnpepl1': 'ENSMUSG00000026269',
#  '9430060I03Rik': 'ENSMUSG00000100632',
#  'Capn10': 'ENSMUSG00000026270',
#  'Gpr35': 'ENSMUSG00000026271',
#  'Kif1a': 'ENSMUSG00000014602',
#  'Mab21l4': 'ENSMUSG00000034159',
#  'Crocc2': 'ENSMUSG00000084989',
#  'Sned1': 'ENSMUSG00000047793',
#  'Mterf4': 'ENSMUSG00000026273',
#  'Gm28535': 'ENSMUSG00000101172',
#  'Pask': 'ENSMUSG00000026274',
#  'Ppp1r7': 'ENSMUSG00000026275',
#  'Ano7': 'ENSMUSG00000034107',
#  'Hdlbp': 'ENSMUSG00000034088',
#  'Sept2': 'ENSMUSG00000026276',
#  'Farp2': 'ENSMUSG00000034066',
#  'Stk25': 'ENSMUSG00000026277',
#  'Gm28536': 'ENSMUSG00000100927',
#  'Bok': 'ENSMUSG00000026278',
#  'Thap4': 'ENSMUSG00000026279',
#  'Gm10550': 'ENSMUSG00000101952',
#  'Atg4b': 'ENSMUSG00000026280',
#  'Dtymk': 'ENSMUSG00000026281',
#  'Ing5': 'ENSMUSG00000026283',
#  'D2hgdh': 'ENSMUSG00000073609',
#  'Gal3st2': 'ENSMUSG00000094651',
#  'Gal3st2b': 'ENSMUSG00000093805',
#  'Gal3st2c': 'ENSMUSG00000073608',
#  'Pdcd1': 'ENSMUSG00000026285',
#  'Fam174a': 'ENSMUSG00000051185',
#  'St8sia4': 'ENSMUSG00000040710',
#  'Slco4c1': 'ENSMUSG00000040693',
#  'Panct2': 'ENSMUSG00000097814',
#  'Gm28901': 'ENSMUSG00000100454',
#  'D1Ertd622e': 'ENSMUSG00000044768',
#  'Ppip5k2': 'ENSMUSG00000040648',
#  'Gin1': 'ENSMUSG00000026333',
#  'Pam': 'ENSMUSG00000026335',
#  'B230216N24Rik': 'ENSMUSG00000089706',
#  '1810006J02Rik': 'ENSMUSG00000100182',
#  'Gm29461': 'ENSMUSG00000100711',
#  'Gm7967': 'ENSMUSG00000100009',
#  'Gm28187': 'ENSMUSG00000099375',
#  'Cdh20': 'ENSMUSG00000050840',
#  'Rnf152': 'ENSMUSG00000047496',
#  'Gm17634': 'ENSMUSG00000097482',
#  'Pign': 'ENSMUSG00000056536',
#  'Gm28404': 'ENSMUSG00000100672',
#  'Relch': 'ENSMUSG00000026319',
#  'Tnfrsf11a': 'ENSMUSG00000026321',
#  'Gm7160': 'ENSMUSG00000099843',
#  'Zcchc2': 'ENSMUSG00000038866',
#  'Gm20753': 'ENSMUSG00000101583',
#  'Phlpp1': 'ENSMUSG00000044340',
#  'A530053M12Rik': 'ENSMUSG00000100247',
#  'Bcl2': 'ENSMUSG00000057329',
#  'D630008O14Rik': 'ENSMUSG00000054006',
#  'Kdsr': 'ENSMUSG00000009905',
#  'Vps4b': 'ENSMUSG00000009907',
#  'Serpinb5': 'ENSMUSG00000067006',
#  'Serpinb7': 'ENSMUSG00000067001',
#  'Serpinb2': 'ENSMUSG00000062345',
#  'Serpinb8': 'ENSMUSG00000026315',
#  'Cdh19': 'ENSMUSG00000047216',
#  'Dsel': 'ENSMUSG00000038702',
#  'Cntnap5a': 'ENSMUSG00000070695',
#  'Tsn': 'ENSMUSG00000026374',
#  'Nifk': 'ENSMUSG00000026377',
#  'Clasp1': 'ENSMUSG00000064302',
#  '2900060B14Rik': 'ENSMUSG00000107722',
#  'Tfcp2l1': 'ENSMUSG00000026380',
#  'Gli2': 'ENSMUSG00000048402',
#  'Inhbb': 'ENSMUSG00000037035',
#  'Ralb': 'ENSMUSG00000004451',
#  'Gm27184': 'ENSMUSG00000098447',
#  'Tmem185b': 'ENSMUSG00000098923',
#  'Epb41l5': 'ENSMUSG00000026383',
#  'Ptpn4': 'ENSMUSG00000026384',
#  'Tmem177': 'ENSMUSG00000036975',
#  'Tmem37': 'ENSMUSG00000050777',
#  'Dbi': 'ENSMUSG00000026385',
#  '3110009E18Rik': 'ENSMUSG00000026388',
#  'Steap3': 'ENSMUSG00000026389',
#  'C1ql2': 'ENSMUSG00000036907',
#  'Marco': 'ENSMUSG00000026390',
#  'En1': 'ENSMUSG00000058665',
#  'Insig2': 'ENSMUSG00000003721',
#  'Ccdc93': 'ENSMUSG00000026339',
#  'Ddx18': 'ENSMUSG00000001674',
#  'Dpp10': 'ENSMUSG00000036815',
#  'Actr3': 'ENSMUSG00000026341',
#  'Gm28706': 'ENSMUSG00000102063',
#  'Slc35f5': 'ENSMUSG00000026342',
#  'Gpr39': 'ENSMUSG00000026343',
#  'Lypd1': 'ENSMUSG00000026344',
#  'Nckap5': 'ENSMUSG00000049690',
#  'Mgat5': 'ENSMUSG00000036155',
#  'Tmem163': 'ENSMUSG00000026347',
#  '2900009J06Rik': 'ENSMUSG00000102014',
#  'Ccnt2': 'ENSMUSG00000026349',
#  'Map3k19': 'ENSMUSG00000051590',
#  'Rab3gap1': 'ENSMUSG00000036104',
#  'Zranb3': 'ENSMUSG00000036086',
#  'Gm28800': 'ENSMUSG00000099760',
#  'R3hdm1': 'ENSMUSG00000056211',
#  'Ubxn4': 'ENSMUSG00000026353',
#  'Lct': 'ENSMUSG00000026354',
#  'Mcm6': 'ENSMUSG00000026355',
#  'Dars': 'ENSMUSG00000026356',
#  'Cxcr4': 'ENSMUSG00000045382',
#  'Gm26686': 'ENSMUSG00000097283',
#  'Gm15674': 'ENSMUSG00000087691',
#  'Gm15675': 'ENSMUSG00000086825',
#  'Cd55': 'ENSMUSG00000026399',
#  'Gm16083': 'ENSMUSG00000085526',
#  'C4bp': 'ENSMUSG00000026405',
#  'Pfkfb2': 'ENSMUSG00000026409',
#  'Yod1': 'ENSMUSG00000046404',
#  'AA986860': 'ENSMUSG00000042510',
#  'Fcamr': 'ENSMUSG00000026415',
#  'Gm15848': 'ENSMUSG00000086706',
#  'Pigr': 'ENSMUSG00000026417',
#  'Fcmr': 'ENSMUSG00000042474',
#  'Il10': 'ENSMUSG00000016529',
#  'Mapkapk2': 'ENSMUSG00000016528',
#  'Dyrk3': 'ENSMUSG00000016526',
#  'Eif2d': 'ENSMUSG00000026427',
#  'Rassf5': 'ENSMUSG00000026430',
#  'Ikbke': 'ENSMUSG00000042349',
#  'Srgap2': 'ENSMUSG00000026425',
#  'Gm29488': 'ENSMUSG00000101778',
#  'Fam72a': 'ENSMUSG00000055184',
#  'Ctse': 'ENSMUSG00000004552',
#  'Rab7b': 'ENSMUSG00000052688',
#  'Pm20d1': 'ENSMUSG00000042251',
#  'Slc41a1': 'ENSMUSG00000013275',
#  'Rab29': 'ENSMUSG00000026433',
#  'Nucks1': 'ENSMUSG00000026434',
#  'Slc45a3': 'ENSMUSG00000026435',
#  'Elk4': 'ENSMUSG00000026436',
#  'Mfsd4a': 'ENSMUSG00000059149',
#  'Cdk18': 'ENSMUSG00000026437',
#  'Klhdc8a': 'ENSMUSG00000042115',
#  'Nuak2': 'ENSMUSG00000009772',
#  'F730311O21Rik': 'ENSMUSG00000100658',
#  'Tmcc2': 'ENSMUSG00000042066',
#  'Dstyk': 'ENSMUSG00000042046',
#  '6030442K20Rik': 'ENSMUSG00000097760',
#  'Rbbp5': 'ENSMUSG00000026439',
#  'Tmem81': 'ENSMUSG00000048174',
#  'Cntn2': 'ENSMUSG00000053024',
#  'Nfasc': 'ENSMUSG00000026442',
#  'Lrrn2': 'ENSMUSG00000026443',
#  'Mdm4': 'ENSMUSG00000054387',
#  'Pik3c2b': 'ENSMUSG00000026447',
#  'Ppp1r15b': 'ENSMUSG00000046062',
#  'Plekha6': 'ENSMUSG00000041757',
#  'Ren1': 'ENSMUSG00000070645',
#  'Etnk2': 'ENSMUSG00000070644',
#  'Sox13': 'ENSMUSG00000070643',
#  'Snrpe': 'ENSMUSG00000090553',
#  'Zc3h11a': 'ENSMUSG00000102976',
#  'Zc3h11a-1': 'ENSMUSG00000116275',
#  'Gm38394': 'ENSMUSG00000094410',
#  'Lax1': 'ENSMUSG00000051998',
#  'Atp2b4': 'ENSMUSG00000026463',
#  'Optc': 'ENSMUSG00000010311',
#  'Gm15851': 'ENSMUSG00000090208',
#  'Prelp': 'ENSMUSG00000041577',
#  'Fmod': 'ENSMUSG00000041559',
#  'Btg2': 'ENSMUSG00000020423',
#  'Chit1': 'ENSMUSG00000026450',
#  'Chil1': 'ENSMUSG00000064246',
#  'Mybph': 'ENSMUSG00000042451',
#  'Adora1': 'ENSMUSG00000042429',
#  'Ppfia4': 'ENSMUSG00000026458',
#  'Tmem183a': 'ENSMUSG00000042305',
#  'Cyb5r1': 'ENSMUSG00000026456',
#  'Adipor1': 'ENSMUSG00000026457',
#  'Platr1': 'ENSMUSG00000101061',
#  'Klhl12': 'ENSMUSG00000026455',
#  'Rabif': 'ENSMUSG00000042229',
#  'Kdm5b': 'ENSMUSG00000042207',
#  'Ppp1r12b': 'ENSMUSG00000073557',
#  'Ube2t': 'ENSMUSG00000026429',
#  'Lgr6': 'ENSMUSG00000042793',
#  'Ptpn7': 'ENSMUSG00000031506',
#  'Arl8a': 'ENSMUSG00000026426',
#  'Gm15445': 'ENSMUSG00000085311',
#  'Gpr37l1': 'ENSMUSG00000026424',
#  'Gm26642': 'ENSMUSG00000097680',
#  'Elf3': 'ENSMUSG00000003051',
#  'Rnpep': 'ENSMUSG00000041926',
#  'Timm17a': 'ENSMUSG00000062580',
#  'Lmod1': 'ENSMUSG00000048096',
#  'Shisa4': 'ENSMUSG00000041889',
#  'Ipo9': 'ENSMUSG00000041879',
#  'Nav1': 'ENSMUSG00000009418',
#  'Gm4793': 'ENSMUSG00000054412',
#  'Csrp1': 'ENSMUSG00000026421',
#  'Phlda3': 'ENSMUSG00000041801',
#  'Tnni1': 'ENSMUSG00000026418',
#  'Lad1': 'ENSMUSG00000041782',
#  'Tnnt2': 'ENSMUSG00000026414',
#  'Tmem9': 'ENSMUSG00000026411',
#  'Cacna1s': 'ENSMUSG00000026407',
#  'Gm37759': 'ENSMUSG00000102717',
#  'Gm15850': 'ENSMUSG00000086264',
#  'Kif21b': 'ENSMUSG00000041642',
#  'Inava': 'ENSMUSG00000041605',
#  'A430034D21Rik': 'ENSMUSG00000103594',
#  'Gm37552': 'ENSMUSG00000102941',
#  'Gm26781': 'ENSMUSG00000097433',
#  'Gpr25': 'ENSMUSG00000052759',
#  'Camsap2': 'ENSMUSG00000041570',
#  '9230116N13Rik': 'ENSMUSG00000097403',
#  'Ddx59': 'ENSMUSG00000026404',
#  'Kif14': 'ENSMUSG00000041498',
#  'Gm33994': 'ENSMUSG00000104509',
#  'Platr23': 'ENSMUSG00000097229',
#  'Zfp281': 'ENSMUSG00000041483',
#  'Gm19705': 'ENSMUSG00000097113',
#  'Nr5a2': 'ENSMUSG00000026398',
#  'Gm4258': 'ENSMUSG00000098243',
#  'Gm26930': 'ENSMUSG00000102142',
#  'A430106G13Rik': 'ENSMUSG00000098206',
#  'Ptprc': 'ENSMUSG00000026395',
#  'Gm28556': 'ENSMUSG00000099459',
#  'Atp6v1g3': 'ENSMUSG00000026394',
#  'Nek7': 'ENSMUSG00000026393',
#  '2310009B15Rik': 'ENSMUSG00000079283',
#  'Dennd1b': 'ENSMUSG00000056268',
#  'Zbtb41': 'ENSMUSG00000033964',
#  'Aspm': 'ENSMUSG00000033952',
#  'F13b': 'ENSMUSG00000026368',
#  'Cfh': 'ENSMUSG00000026365',
#  'Kcnt2': 'ENSMUSG00000052726',
#  'Cdc73': 'ENSMUSG00000026361',
#  'B3galt2': 'ENSMUSG00000033849',
#  'Glrx2': 'ENSMUSG00000018196',
#  'Ro60': 'ENSMUSG00000018199',
#  'Uchl5': 'ENSMUSG00000018189',
#  'Gm29170': 'ENSMUSG00000100455',
#  'Rgs2': 'ENSMUSG00000026360',
#  'Rgs13': 'ENSMUSG00000051079',
#  'Rgs1': 'ENSMUSG00000026358',
#  'Rgs18': 'ENSMUSG00000026357',
#  'Brinp3': 'ENSMUSG00000035131',
#  'A230059L01Rik': 'ENSMUSG00000087627',
#  'Pla2g4a': 'ENSMUSG00000056220',
#  'Ptgs2os': 'ENSMUSG00000097028',
#  'Ptgs2': 'ENSMUSG00000032487',
#  'Ptgs2os2': 'ENSMUSG00000097754',
#  'Odr4': 'ENSMUSG00000006010',
#  'Tpr': 'ENSMUSG00000006005',
#  'Prg4': 'ENSMUSG00000006014',
#  'Hmcn1': 'ENSMUSG00000066842',
#  'Gm10138': 'ENSMUSG00000100954',
#  'Ivns1abp': 'ENSMUSG00000023150',
#  'Swt1': 'ENSMUSG00000052748',
#  'Trmt1l': 'ENSMUSG00000053286',
#  'Rnf2': 'ENSMUSG00000026484',
#  'Fam129a': 'ENSMUSG00000026483',
#  '2810414N06Rik': 'ENSMUSG00000100594',
#  'Edem3': 'ENSMUSG00000043019',
#  '1700025G04Rik': 'ENSMUSG00000032666',
#  'Tsen15': 'ENSMUSG00000014980',
#  'Colgalt2': 'ENSMUSG00000032649',
#  'Rgl1': 'ENSMUSG00000026482',
#  'Arpc5': 'ENSMUSG00000008475',
#  'Ncf2': 'ENSMUSG00000026480',
#  'Smg7': 'ENSMUSG00000042772',
#  'Gm28791': 'ENSMUSG00000100394',
#  'Nmnat2': 'ENSMUSG00000042751',
#  'Lamc2': 'ENSMUSG00000026479',
#  'Lamc1': 'ENSMUSG00000026478',
#  'E330020D12Rik': 'ENSMUSG00000073538',
#  'Shcbp1l': 'ENSMUSG00000042708',
#  'Dhx9': 'ENSMUSG00000042699',
#  'Npl': 'ENSMUSG00000042684',
#  'Rgs8': 'ENSMUSG00000042671',
#  'C230024C17Rik': 'ENSMUSG00000100334',
#  'Rgs16': 'ENSMUSG00000026475',
#  'Gm28513': 'ENSMUSG00000099568',
#  'Rnasel': 'ENSMUSG00000066800',
#  'Gm28512': 'ENSMUSG00000100183',
#  'Teddm2': 'ENSMUSG00000045968',
#  'Glul': 'ENSMUSG00000026473',
#  'Gm29291': 'ENSMUSG00000101903',
#  'A830008E24Rik': 'ENSMUSG00000100627',
#  'Cacna1e': 'ENSMUSG00000004110',
#  'Gm29282': 'ENSMUSG00000101880',
#  'Gm9530': 'ENSMUSG00000096950',
#  'Ier5': 'ENSMUSG00000056708',
#  'Mr1': 'ENSMUSG00000026471',
#  'Stx6': 'ENSMUSG00000026470',
#  'BC034090': 'ENSMUSG00000033722',
#  'Xpr1': 'ENSMUSG00000026469',
#  'Acbd6': 'ENSMUSG00000033701',
#  'Qsox1': 'ENSMUSG00000033684',
#  'Cep350': 'ENSMUSG00000033671',
#  'Tor1aip1': 'ENSMUSG00000026466',
#  'Tor1aip2': 'ENSMUSG00000050565',
#  'Tdrd5': 'ENSMUSG00000060985',
#  'Axdnd1': 'ENSMUSG00000026601',
#  'Gm2000': 'ENSMUSG00000078193',
#  'Soat1': 'ENSMUSG00000026600',
#  'Abl2': 'ENSMUSG00000026596',
#  'Tor3a': 'ENSMUSG00000060519',
#  'Fam20b': 'ENSMUSG00000033557',
#  'Ralgps2': 'ENSMUSG00000026594',
#  'Angptl1': 'ENSMUSG00000033544',
#  '4930439D14Rik': 'ENSMUSG00000101905',
#  'Gm28694': 'ENSMUSG00000101768',
#  'Rasal2': 'ENSMUSG00000070565',
#  'Cryzl2': 'ENSMUSG00000033488',
#  'Sec16b': 'ENSMUSG00000026589',
#  'Brinp2': 'ENSMUSG00000004031',
#  'Astn1': 'ENSMUSG00000026587',
#  'Gm37679': 'ENSMUSG00000103971',
#  'Pappa2': 'ENSMUSG00000073530',
#  '1600012P17Rik': 'ENSMUSG00000047661',
#  'Cop1': 'ENSMUSG00000040782',
#  'Tnr': 'ENSMUSG00000015829',
#  'Gm37294': 'ENSMUSG00000104111',
#  '4930523C07Rik': 'ENSMUSG00000090394',
#  '4930562F07Rik': 'ENSMUSG00000026729',
#  'Tnn': 'ENSMUSG00000026725',
#  'Mrps14': 'ENSMUSG00000058267',
#  'Cacybp': 'ENSMUSG00000014226',
#  'Rabgap1l': 'ENSMUSG00000026721',
#  'Gm36975': 'ENSMUSG00000104302',
#  'Gm37529': 'ENSMUSG00000103693',
#  'Gpr52': 'ENSMUSG00000118401',
#  'Gm37328': 'ENSMUSG00000103200',
#  'Gm37083': 'ENSMUSG00000102852',
#  'Rc3h1': 'ENSMUSG00000040423',
#  'Serpinc1': 'ENSMUSG00000026715',
#  'Zbtb37': 'ENSMUSG00000043467',
#  'Gas5': 'ENSMUSG00000053332',
#  'Dars2': 'ENSMUSG00000026709',
#  'Gm37634': 'ENSMUSG00000102864',
#  'Cenpl': 'ENSMUSG00000026708',
#  'Klhl20': 'ENSMUSG00000026705',
#  'Ankrd45': 'ENSMUSG00000044835',
#  'Prdx6': 'ENSMUSG00000026701',
#  'Tnfsf4': 'ENSMUSG00000026700',
#  'Tnfsf18': 'ENSMUSG00000066755',
#  'Fasl': 'ENSMUSG00000000817',
#  'Suco': 'ENSMUSG00000040297',
#  'Gm31925': 'ENSMUSG00000103158',
#  '4930558K02Rik': 'ENSMUSG00000086277',
#  'Pigc': 'ENSMUSG00000026698',
#  'Gm38304': 'ENSMUSG00000103393',
#  'Dnm3': 'ENSMUSG00000040265',
#  '2810442N19Rik': 'ENSMUSG00000090260',
#  'Dnm3os': 'ENSMUSG00000078190',
#  'Eef1aknmt': 'ENSMUSG00000026694',
#  'Vamp4': 'ENSMUSG00000026696',
#  'Myoc': 'ENSMUSG00000026697',
#  'Prrc2c': 'ENSMUSG00000040225',
#  'Fmo1': 'ENSMUSG00000040181',
#  'Fmo2': 'ENSMUSG00000040170',
#  'Prrx1': 'ENSMUSG00000026586',
#  'Gorab': 'ENSMUSG00000040124',
#  'Kifap3': 'ENSMUSG00000026585',
#  'Scyl3': 'ENSMUSG00000026584',
#  'BC055324': 'ENSMUSG00000041406',
#  'Mettl18': 'ENSMUSG00000041396',
#  'Sele': 'ENSMUSG00000026582',
#  'Sell': 'ENSMUSG00000026581',
#  'Selp': 'ENSMUSG00000026580',
#  'Gm16548': 'ENSMUSG00000086593',
#  'F5': 'ENSMUSG00000026579',
#  'Slc19a2': 'ENSMUSG00000040918',
#  'Ccdc181': 'ENSMUSG00000026578',
#  'Blzf1': 'ENSMUSG00000026577',
#  'Nme7': 'ENSMUSG00000026575',
#  'Atp1b1': 'ENSMUSG00000026576',
#  'Gm32391': 'ENSMUSG00000104011',
#  'Gm26685': 'ENSMUSG00000097281',
#  'Dpt': 'ENSMUSG00000026574',
#  'Gm32569': 'ENSMUSG00000103659',
#  'Gm20743': 'ENSMUSG00000104117',
#  'Xcl1': 'ENSMUSG00000026573',
#  'Sft2d2': 'ENSMUSG00000040848',
#  'Tiprl': 'ENSMUSG00000040843',
#  'Gm38190': 'ENSMUSG00000102302',
#  'Gpr161': 'ENSMUSG00000040836',
#  'Dcaf6': 'ENSMUSG00000026571',
#  'Gm37864': 'ENSMUSG00000102401',
#  'Mpc2': 'ENSMUSG00000026568',
#  'Mpzl1': 'ENSMUSG00000026566',
#  'Rcsd1': 'ENSMUSG00000040723',
#  'Creg1': 'ENSMUSG00000040713',
#  'Gm16565': 'ENSMUSG00000089829',
#  'Cd247': 'ENSMUSG00000005763',
#  'Gm37469': 'ENSMUSG00000102154',
#  'Pou2f1': 'ENSMUSG00000026565',
#  'Gm26665': 'ENSMUSG00000097196',
#  'Gpa33': 'ENSMUSG00000000544',
#  'Ildr2': 'ENSMUSG00000040612',
#  '5330438I03Rik': 'ENSMUSG00000091393',
#  'Gm15853': 'ENSMUSG00000103400',
#  'Tada1': 'ENSMUSG00000026563',
#  'Pogk': 'ENSMUSG00000040596',
#  'Gm16701-1': 'ENSMUSG00000097823',
#  'Fam78b': 'ENSMUSG00000060568',
#  'Uck2': 'ENSMUSG00000026558',
#  'Gm37982': 'ENSMUSG00000103139',
#  'Tmco1': 'ENSMUSG00000052428',
#  'Aldh9a1': 'ENSMUSG00000026687',
#  'Mgst3': 'ENSMUSG00000026688',
#  'Rxrg': 'ENSMUSG00000015843',
#  'Pbx1': 'ENSMUSG00000052534',
#  'Nuf2': 'ENSMUSG00000026683',
#  'Rgs5': 'ENSMUSG00000026678',
#  'Rgs4': 'ENSMUSG00000038530',
#  'Ccdc190': 'ENSMUSG00000070532',
#  'Gm15852': 'ENSMUSG00000089990',
#  'Hsd17b7': 'ENSMUSG00000026675',
#  '3110045C21Rik': 'ENSMUSG00000097503',
#  'Ddr2': 'ENSMUSG00000026674',
#  'Uap1': 'ENSMUSG00000026670',
#  'Gm37748': 'ENSMUSG00000104266',
#  'Uhmk1': 'ENSMUSG00000026667',
#  '4930500M09Rik': 'ENSMUSG00000044306',
#  'Sh2d1b2': 'ENSMUSG00000073494',
#  'Sh2d1b1': 'ENSMUSG00000102418',
#  'Gm7694': 'ENSMUSG00000102752',
#  'Nos1ap': 'ENSMUSG00000038473',
#  'Olfml2b': 'ENSMUSG00000038463',
#  'Atf6': 'ENSMUSG00000026663',
#  'Gm9929': 'ENSMUSG00000053925',
#  'Dusp12': 'ENSMUSG00000026659',
#  'Gm26620': 'ENSMUSG00000096968',
#  'Fcrlb': 'ENSMUSG00000070524',
#  'Fcrla': 'ENSMUSG00000038421',
#  'Fcgr2b': 'ENSMUSG00000026656',
#  'Gm38204': 'ENSMUSG00000103676',
#  'Gm10522': 'ENSMUSG00000104340',
#  'Fcgr4': 'ENSMUSG00000059089',
#  'Fcgr3': 'ENSMUSG00000059498',
#  'Cfap126': 'ENSMUSG00000026649',
#  'Sdhc': 'ENSMUSG00000058076',
#  'Mpz': 'ENSMUSG00000056569',
#  'Pcp4l1': 'ENSMUSG00000038370',
#  'Nr1i3': 'ENSMUSG00000005677',
#  'Tomm40l': 'ENSMUSG00000005674',
#  'Apoa2': 'ENSMUSG00000005681',
#  'Fcer1g': 'ENSMUSG00000058715',
#  'Ndufs2': 'ENSMUSG00000013593',
#  'Adamts4': 'ENSMUSG00000006403',
#  'B4galt3': 'ENSMUSG00000052423',
#  'Ppox': 'ENSMUSG00000062729',
#  'Usp21': 'ENSMUSG00000053483',
#  'Ufc1': 'ENSMUSG00000062963',
#  'Gm20045': 'ENSMUSG00000103983',
#  'Dedd': 'ENSMUSG00000013973',
#  'Nit1': 'ENSMUSG00000013997',
#  'Pfdn2': 'ENSMUSG00000006412',
#  'Klhdc9': 'ENSMUSG00000045259',
#  'Nectin4': 'ENSMUSG00000006411',
#  'Arhgap30': 'ENSMUSG00000048865',
#  'Usf1': 'ENSMUSG00000026641',
#  'Tstd1': 'ENSMUSG00000103711',
#  'F11r': 'ENSMUSG00000038235',
#  'B930036N10Rik': 'ENSMUSG00000091993',
#  'Alyref2': 'ENSMUSG00000060244',
#  'Itln1': 'ENSMUSG00000038209',
#  'Cd244a': 'ENSMUSG00000004709',
#  'Ly9': 'ENSMUSG00000004707',
#  'Slamf7': 'ENSMUSG00000038179',
#  'Gm37787': 'ENSMUSG00000103219',
#  'A630035G10Rik': 'ENSMUSG00000103083',
#  'Cd48': 'ENSMUSG00000015355',
#  'Slamf1': 'ENSMUSG00000015316',
#  'Cd84': 'ENSMUSG00000038147',
#  'Gm10521': 'ENSMUSG00000073492',
#  'Gm37065': 'ENSMUSG00000104413',
#  'Slamf6': 'ENSMUSG00000015314',
#  'Vangl2': 'ENSMUSG00000026556',
#  'Ncstn': 'ENSMUSG00000003458',
#  'Copa': 'ENSMUSG00000026553',
#  'Gm37756': 'ENSMUSG00000103380',
#  'Pex19': 'ENSMUSG00000003464',
#  'Dcaf8': 'ENSMUSG00000026554',
#  'Pea15a': 'ENSMUSG00000013698',
#  'Casq1': 'ENSMUSG00000007122',
#  'Atp1a4': 'ENSMUSG00000007107',
#  'Igsf8': 'ENSMUSG00000038034',
#  'Atp1a2': 'ENSMUSG00000007097',
#  'Kcnj10': 'ENSMUSG00000044708',
#  'Pigm': 'ENSMUSG00000050229',
#  'Slamf9': 'ENSMUSG00000026548',
#  'Igsf9': 'ENSMUSG00000037995',
#  'Tagln2': 'ENSMUSG00000026547',
#  'Cfap45': 'ENSMUSG00000026546',
#  '4933439K11Rik': 'ENSMUSG00000085184',
#  'Vsig8': 'ENSMUSG00000049598',
#  'Slamf8': 'ENSMUSG00000053318',
#  'Dusp23': 'ENSMUSG00000026544',
#  'Fcer1a': 'ENSMUSG00000005339',
#  ...}

# %%
adata.var['gene_ids'] = adata.var.index.map(gene_name_to_id)

# %%
nan_values = adata.var['gene_ids'].isna().sum()

print(f"Number of NaN values in 'gene_ids' column: {nan_values}")
# Out:
# Number of NaN values in 'gene_ids' column: 0

# %%
adata.var
# Out:
#                    mt     rb  n_cells_by_counts  mean_counts  \
# Sox17           False  False                221     0.026731
# Mrpl15          False  False               3218     0.297666
# Lypla1          False  False               2460     0.188250
# Tcea1           False  False               6241     0.829154
# Rgs20           False  False                  3     0.000174
# ...               ...    ...                ...          ...
# CR974586.2      False  False                 67     0.007599
# CR974586.4      False  False                237     0.042484
# Ccl21a-1        False  False                 30     0.002436
# CAAA01147332.1  False  False               1400     0.095975
# AC149090.1      False  False               4401     0.400457
#
#                 pct_dropout_by_counts  total_counts  n_cells  highly_variable  \
# Sox17                       98.718025    460.818756      221             True
# Mrpl15                      81.333023   5131.465332     3218            False
# Lypla1                      85.730034   3245.247803     2460            False
# Tcea1                       63.797203  14293.792969     6241            False
# Rgs20                       99.982597      2.995511        3            False
# ...                               ...           ...      ...              ...
# CR974586.2                  99.611343    131.000000       67            False
# CR974586.4                  98.625214    732.385132      237             True
# Ccl21a-1                    99.825974     42.000000       30            False
# CAAA01147332.1              91.878876   1654.511108     1400            False
# AC149090.1                  74.470680   6903.481445     4401            False
#
#                    means  dispersions  dispersions_norm            gene_ids
# Sox17           0.131385     2.748144          2.592534  ENSMUSG00000025902
# Mrpl15          0.480022     1.226943         -0.471321  ENSMUSG00000033845
# Lypla1          0.353775     1.208837         -0.495850  ENSMUSG00000025903
# Tcea1           1.043117     1.383716         -0.455413  ENSMUSG00000033813
# Rgs20           0.000562     1.542446          0.282720  ENSMUSG00000002459
# ...                  ...          ...               ...                 ...
# CR974586.2      0.017431     1.512446          0.225248  ENSMUSG00000095585
# CR974586.4      0.101700     2.757137          2.609761  ENSMUSG00000096506
# Ccl21a-1        0.008137     1.713660          0.610724  ENSMUSG00000095320
# CAAA01147332.1  0.240455     1.431409          0.070001  ENSMUSG00000095742
# AC149090.1      0.789610     2.315884          0.485422  ENSMUSG00000095041
#
# [19330 rows x 12 columns]

# %%
araw.var
# Out:
#                           gene_ids    feature_types genome  n_cells
# Sox17           ENSMUSG00000025902  Gene Expression   mm10      221
# Mrpl15          ENSMUSG00000033845  Gene Expression   mm10     3218
# Lypla1          ENSMUSG00000025903  Gene Expression   mm10     2460
# Tcea1           ENSMUSG00000033813  Gene Expression   mm10     6241
# Rgs20           ENSMUSG00000002459  Gene Expression   mm10        3
# ...                            ...              ...    ...      ...
# CR974586.2      ENSMUSG00000095585  Gene Expression   mm10       67
# CR974586.4      ENSMUSG00000096506  Gene Expression   mm10      237
# Ccl21a-1        ENSMUSG00000095320  Gene Expression   mm10       30
# CAAA01147332.1  ENSMUSG00000095742  Gene Expression   mm10     1400
# AC149090.1      ENSMUSG00000095041  Gene Expression   mm10     4401
#
# [19330 rows x 4 columns]

# %%
nan_values = adata.var['gene_ids'].isna().sum()

print(f"Number of NaN values in 'gene_ids' column: {nan_values}")
# Out:
# Number of NaN values in 'gene_ids' column: 0

# %%
nan_gene_ids_indices = adata.var.index[adata.var['gene_ids'].isna()]

print("Index values with NaN in 'gene_ids' column:")
print(nan_gene_ids_indices)
# Out:
# Index values with NaN in 'gene_ids' column:
# Index([], dtype='object')

# %%
adata.var['gene_name'] = adata.var.index
araw.var['gene_name'] = araw.var.index

# %%
adata.var.index = adata.var['gene_ids'] 
araw.var.index = araw.var['gene_ids']

# %%
# Load the approved genes file.

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
#Create a dictionary from the approved genes file

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
genedict
# Out:
# {'ERCC-00002': 1,
#  'ERCC-00003': 1,
#  'ERCC-00004': 1,
#  'ERCC-00009': 1,
#  'ERCC-00012': 1,
#  'ERCC-00013': 1,
#  'ERCC-00014': 1,
#  'ERCC-00016': 1,
#  'ERCC-00017': 1,
#  'ERCC-00019': 1,
#  'ERCC-00022': 1,
#  'ERCC-00024': 1,
#  'ERCC-00025': 1,
#  'ERCC-00028': 1,
#  'ERCC-00031': 1,
#  'ERCC-00033': 1,
#  'ERCC-00034': 1,
#  'ERCC-00035': 1,
#  'ERCC-00039': 1,
#  'ERCC-00040': 1,
#  'ERCC-00041': 1,
#  'ERCC-00042': 1,
#  'ERCC-00043': 1,
#  'ERCC-00044': 1,
#  'ERCC-00046': 1,
#  'ERCC-00048': 1,
#  'ERCC-00051': 1,
#  'ERCC-00053': 1,
#  'ERCC-00054': 1,
#  'ERCC-00057': 1,
#  'ERCC-00058': 1,
#  'ERCC-00059': 1,
#  'ERCC-00060': 1,
#  'ERCC-00061': 1,
#  'ERCC-00062': 1,
#  'ERCC-00067': 1,
#  'ERCC-00069': 1,
#  'ERCC-00071': 1,
#  'ERCC-00073': 1,
#  'ERCC-00074': 1,
#  'ERCC-00075': 1,
#  'ERCC-00076': 1,
#  'ERCC-00077': 1,
#  'ERCC-00078': 1,
#  'ERCC-00079': 1,
#  'ERCC-00081': 1,
#  'ERCC-00083': 1,
#  'ERCC-00084': 1,
#  'ERCC-00085': 1,
#  'ERCC-00086': 1,
#  'ERCC-00092': 1,
#  'ERCC-00095': 1,
#  'ERCC-00096': 1,
#  'ERCC-00097': 1,
#  'ERCC-00098': 1,
#  'ERCC-00099': 1,
#  'ERCC-00104': 1,
#  'ERCC-00108': 1,
#  'ERCC-00109': 1,
#  'ERCC-00111': 1,
#  'ERCC-00112': 1,
#  'ERCC-00113': 1,
#  'ERCC-00116': 1,
#  'ERCC-00117': 1,
#  'ERCC-00120': 1,
#  'ERCC-00123': 1,
#  'ERCC-00126': 1,
#  'ERCC-00130': 1,
#  'ERCC-00131': 1,
#  'ERCC-00134': 1,
#  'ERCC-00136': 1,
#  'ERCC-00137': 1,
#  'ERCC-00138': 1,
#  'ERCC-00142': 1,
#  'ERCC-00143': 1,
#  'ERCC-00144': 1,
#  'ERCC-00145': 1,
#  'ERCC-00147': 1,
#  'ERCC-00148': 1,
#  'ERCC-00150': 1,
#  'ERCC-00154': 1,
#  'ERCC-00156': 1,
#  'ERCC-00157': 1,
#  'ERCC-00158': 1,
#  'ERCC-00160': 1,
#  'ERCC-00162': 1,
#  'ERCC-00163': 1,
#  'ERCC-00164': 1,
#  'ERCC-00165': 1,
#  'ERCC-00168': 1,
#  'ERCC-00170': 1,
#  'ERCC-00171': 1,
#  'ENSG00000290825': 1,
#  'ENSG00000223972': 1,
#  'ENSG00000227232': 1,
#  'ENSG00000278267': 1,
#  'ENSG00000243485': 1,
#  'ENSG00000284332': 1,
#  'ENSG00000237613': 1,
#  'ENSG00000268020': 1,
#  'ENSG00000290826': 1,
#  'ENSG00000240361': 1,
#  'ENSG00000186092': 1,
#  'ENSG00000238009': 1,
#  'ENSG00000239945': 1,
#  'ENSG00000233750': 1,
#  'ENSG00000268903': 1,
#  'ENSG00000269981': 1,
#  'ENSG00000239906': 1,
#  'ENSG00000241860': 1,
#  'ENSG00000222623': 1,
#  'ENSG00000241599': 1,
#  'ENSG00000279928': 1,
#  'ENSG00000279457': 1,
#  'ENSG00000273874': 1,
#  'ENSG00000228463': 1,
#  'ENSG00000286448': 1,
#  'ENSG00000236679': 1,
#  'ENSG00000236601': 1,
#  'ENSG00000290385': 1,
#  'ENSG00000269732': 1,
#  'ENSG00000284733': 1,
#  'ENSG00000237094': 1,
#  'ENSG00000233653': 1,
#  'ENSG00000250575': 1,
#  'ENSG00000278757': 1,
#  'ENSG00000230021': 1,
#  'ENSG00000235146': 1,
#  'ENSG00000225972': 1,
#  'ENSG00000225630': 1,
#  'ENSG00000237973': 1,
#  'ENSG00000278791': 1,
#  'ENSG00000229344': 1,
#  'ENSG00000240409': 1,
#  'ENSG00000248527': 1,
#  'ENSG00000198744': 1,
#  'ENSG00000268663': 1,
#  'ENSG00000284662': 1,
#  'ENSG00000229376': 1,
#  'ENSG00000291215': 1,
#  'ENSG00000223181': 1,
#  'ENSG00000229905': 1,
#  'ENSG00000228327': 1,
#  'ENSG00000237491': 1,
#  'ENSG00000285268': 1,
#  'ENSG00000290784': 1,
#  'ENSG00000230092': 1,
#  'ENSG00000177757': 1,
#  'ENSG00000225880': 1,
#  'ENSG00000228794': 1,
#  'ENSG00000288531': 1,
#  'ENSG00000230368': 1,
#  'ENSG00000234711': 1,
#  'ENSG00000283040': 1,
#  'ENSG00000272438': 1,
#  'ENSG00000230699': 1,
#  'ENSG00000241180': 1,
#  'ENSG00000223764': 1,
#  'ENSG00000187634': 1,
#  'ENSG00000188976': 1,
#  'ENSG00000187961': 1,
#  'ENSG00000187583': 1,
#  'ENSG00000187642': 1,
#  'ENSG00000272512': 1,
#  'ENSG00000188290': 1,
#  'ENSG00000187608': 1,
#  'ENSG00000231702': 1,
#  'ENSG00000224969': 1,
#  'ENSG00000188157': 1,
#  'ENSG00000242590': 1,
#  'ENSG00000291156': 1,
#  'ENSG00000273443': 1,
#  'ENSG00000217801': 1,
#  'ENSG00000237330': 1,
#  'ENSG00000131591': 1,
#  'ENSG00000285812': 1,
#  'ENSG00000223823': 1,
#  'ENSG00000207730': 1,
#  'ENSG00000207607': 1,
#  'ENSG00000198976': 1,
#  'ENSG00000272141': 1,
#  'ENSG00000205231': 1,
#  'ENSG00000162571': 1,
#  'ENSG00000186891': 1,
#  'ENSG00000186827': 1,
#  'ENSG00000078808': 1,
#  'ENSG00000176022': 1,
#  'ENSG00000184163': 1,
#  'ENSG00000260179': 1,
#  'ENSG00000160087': 1,
#  'ENSG00000230415': 1,
#  'ENSG00000162572': 1,
#  'ENSG00000131584': 1,
#  'ENSG00000278073': 1,
#  'ENSG00000169972': 1,
#  'ENSG00000127054': 1,
#  'ENSG00000283712': 1,
#  'ENSG00000240731': 1,
#  'ENSG00000224051': 1,
#  'ENSG00000169962': 1,
#  'ENSG00000107404': 1,
#  'ENSG00000284372': 1,
#  'ENSG00000162576': 1,
#  'ENSG00000175756': 1,
#  'ENSG00000223663': 1,
#  'ENSG00000221978': 1,
#  'ENSG00000224870': 1,
#  'ENSG00000242485': 1,
#  'ENSG00000264293': 1,
#  'ENSG00000272455': 1,
#  'ENSG00000235098': 1,
#  'ENSG00000225905': 1,
#  'ENSG00000205116': 1,
#  'ENSG00000225285': 1,
#  'ENSG00000179403': 1,
#  'ENSG00000215915': 1,
#  'ENSG00000160072': 1,
#  'ENSG00000290916': 1,
#  'ENSG00000284740': 1,
#  'ENSG00000197785': 1,
#  'ENSG00000205090': 1,
#  'ENSG00000160075': 1,
#  'ENSG00000215014': 1,
#  'ENSG00000274481': 1,
#  'ENSG00000228594': 1,
#  'ENSG00000286989': 1,
#  'ENSG00000272106': 1,
#  'ENSG00000197530': 1,
#  'ENSG00000189409': 1,
#  'ENSG00000248333': 1,
#  'ENSG00000272004': 1,
#  'ENSG00000189339': 1,
#  'ENSG00000269737': 1,
#  'ENSG00000215914': 1,
#  'ENSG00000008128': 1,
#  'ENSG00000268575': 1,
#  'ENSG00000227775': 1,
#  'ENSG00000290854': 1,
#  'ENSG00000215790': 1,
#  'ENSG00000008130': 1,
#  'ENSG00000078369': 1,
#  'ENSG00000231050': 1,
#  'ENSG00000169885': 1,
#  'ENSG00000178821': 1,
#  'ENSG00000142609': 1,
#  'ENSG00000233542': 1,
#  'ENSG00000187730': 1,
#  'ENSG00000226969': 1,
#  'ENSG00000067606': 1,
#  'ENSG00000271806': 1,
#  'ENSG00000182873': 1,
#  'ENSG00000162585': 1,
#  'ENSG00000234396': 1,
#  'ENSG00000157933': 1,
#  'ENSG00000287356': 1,
#  'ENSG00000116151': 1,
#  'ENSG00000272161': 1,
#  'ENSG00000269896': 1,
#  'ENSG00000272420': 1,
#  'ENSG00000157916': 1,
#  'ENSG00000157911': 1,
#  'ENSG00000149527': 1,
#  'ENSG00000224387': 1,
#  'ENSG00000229393': 1,
#  'ENSG00000157881': 1,
#  'ENSG00000197921': 1,
#  'ENSG00000272449': 1,
#  'ENSG00000238164': 1,
#  'ENSG00000157873': 1,
#  'ENSG00000225931': 1,
#  'ENSG00000228037': 1,
#  'ENSG00000289610': 1,
#  'ENSG00000157870': 1,
#  'ENSG00000142606': 1,
#  'ENSG00000237058': 1,
#  'ENSG00000215912': 1,
#  'ENSG00000285945': 1,
#  'ENSG00000283259': 1,
#  'ENSG00000233234': 1,
#  'ENSG00000287396': 1,
#  'ENSG00000231630': 1,
#  'ENSG00000284745': 1,
#  'ENSG00000169717': 1,
#  'ENSG00000177133': 1,
#  'ENSG00000142611': 1,
#  'ENSG00000283572': 1,
#  'ENSG00000226286': 1,
#  'ENSG00000279839': 1,
#  'ENSG00000272235': 1,
#  'ENSG00000287828': 1,
#  'ENSG00000286518': 1,
#  'ENSG00000130762': 1,
#  'ENSG00000272088': 1,
#  'ENSG00000162591': 1,
#  'ENSG00000207776': 1,
#  'ENSG00000238260': 1,
#  'ENSG00000158109': 1,
#  'ENSG00000116213': 1,
#  'ENSG00000078900': 1,
#  'ENSG00000227589': 1,
#  'ENSG00000235131': 1,
#  'ENSG00000227372': 1,
#  'ENSG00000276189': 1,
#  'ENSG00000162592': 1,
#  'ENSG00000235169': 1,
#  'ENSG00000130764': 1,
#  'ENSG00000266075': 1,
#  'ENSG00000272153': 1,
#  'ENSG00000116198': 1,
#  'ENSG00000169598': 1,
#  'ENSG00000198912': 1,
#  'ENSG00000236423': 1,
#  'ENSG00000233304': 1,
#  'ENSG00000226374': 1,
#  'ENSG00000284668': 1,
#  'ENSG00000284703': 1,
#  'ENSG00000229280': 1,
#  'ENSG00000235054': 1,
#  'ENSG00000284694': 1,
#  'ENSG00000227169': 1,
#  'ENSG00000232596': 1,
#  'ENSG00000196581': 1,
#  'ENSG00000287586': 1,
#  'ENSG00000284739': 1,
#  'ENSG00000284674': 1,
#  'ENSG00000231510': 1,
#  'ENSG00000284616': 1,
#  'ENSG00000284692': 1,
#  'ENSG00000284666': 1,
#  'ENSG00000260972': 1,
#  'ENSG00000283356': 1,
#  'ENSG00000236948': 1,
#  'ENSG00000264341': 1,
#  'ENSG00000289893': 1,
#  'ENSG00000264101': 1,
#  'ENSG00000131697': 1,
#  'ENSG00000069424': 1,
#  'ENSG00000116254': 1,
#  'ENSG00000285629': 1,
#  'ENSG00000116251': 1,
#  'ENSG00000226944': 1,
#  'ENSG00000158286': 1,
#  'ENSG00000116237': 1,
#  'ENSG00000225077': 1,
#  'ENSG00000173673': 1,
#  'ENSG00000158292': 1,
#  'ENSG00000097021': 1,
#  'ENSG00000271746': 1,
#  'ENSG00000069812': 1,
#  'ENSG00000187017': 1,
#  'ENSG00000265392': 1,
#  'ENSG00000231868': 1,
#  'ENSG00000215788': 1,
#  'ENSG00000171680': 1,
#  'ENSG00000162408': 1,
#  'ENSG00000253022': 1,
#  'ENSG00000229519': 1,
#  'ENSG00000173662': 1,
#  'ENSG00000204859': 1,
#  'ENSG00000162413': 1,
#  'ENSG00000116273': 1,
#  'ENSG00000041988': 1,
#  'ENSG00000007923': 1,
#  'ENSG00000228750': 1,
#  'ENSG00000284744': 1,
#  'ENSG00000237436': 1,
#  'ENSG00000171735': 1,
#  'ENSG00000227950': 1,
#  'ENSG00000237365': 1,
#  'ENSG00000207056': 1,
#  'ENSG00000237402': 1,
#  'ENSG00000237728': 1,
#  'ENSG00000225126': 1,
#  'ENSG00000270171': 1,
#  'ENSG00000270035': 1,
#  'ENSG00000269978': 1,
#  'ENSG00000049245': 1,
#  'ENSG00000269925': 1,
#  'ENSG00000049246': 1,
#  'ENSG00000236266': 1,
#  'ENSG00000049247': 1,
#  'ENSG00000049249': 1,
#  'ENSG00000270330': 1,
#  'ENSG00000116288': 1,
#  'ENSG00000200344': 1,
#  'ENSG00000284747': 1,
#  'ENSG00000284716': 1,
#  'ENSG00000116285': 1,
#  'ENSG00000238290': 1,
#  'ENSG00000232848': 1,
#  'ENSG00000229305': 1,
#  'ENSG00000288816': 1,
#  'ENSG00000227634': 1,
#  'ENSG00000200975': 1,
#  'ENSG00000233645': 1,
#  'ENSG00000251977': 1,
#  'ENSG00000162426': 1,
#  'ENSG00000252254': 1,
#  'ENSG00000142599': 1,
#  'ENSG00000232912': 1,
#  'ENSG00000221083': 1,
#  'ENSG00000270282': 1,
#  'ENSG00000234619': 1,
#  'ENSG00000224315': 1,
#  'ENSG00000222511': 1,
#  'ENSG00000226545': 1,
#  'ENSG00000228423': 1,
#  'ENSG00000229716': 1,
#  'ENSG00000074800': 1,
#  'ENSG00000274258': 1,
#  'ENSG00000230679': 1,
#  'ENSG00000201725': 1,
#  'ENSG00000238249': 1,
#  'ENSG00000232208': 1,
#  'ENSG00000232663': 1,
#  'ENSG00000131686': 1,
#  'ENSG00000290109': 1,
#  'ENSG00000265141': 1,
#  'ENSG00000197241': 1,
#  'ENSG00000142583': 1,
#  'ENSG00000252404': 1,
#  'ENSG00000180758': 1,
#  'ENSG00000228526': 1,
#  'ENSG00000284357': 1,
#  'ENSG00000289914': 1,
#  'ENSG00000234546': 1,
#  'ENSG00000049239': 1,
#  'ENSG00000171621': 1,
#  'ENSG00000284652': 1,
#  'ENSG00000284693': 1,
#  'ENSG00000252956': 1,
#  'ENSG00000235263': 1,
#  'ENSG00000171612': 1,
#  'ENSG00000231181': 1,
#  'ENSG00000188807': 1,
#  'ENSG00000171608': 1,
#  'ENSG00000179840': 1,
#  'ENSG00000233268': 1,
#  'ENSG00000231789': 1,
#  'ENSG00000171603': 1,
#  'ENSG00000271264': 1,
#  'ENSG00000280113': 1,
#  'ENSG00000178585': 1,
#  'ENSG00000223989': 1,
#  'ENSG00000285701': 1,
#  'ENSG00000162441': 1,
#  'ENSG00000228150': 1,
#  'ENSG00000173614': 1,
#  'ENSG00000202415': 1,
#  'ENSG00000283611': 1,
#  'ENSG00000265521': 1,
#  'ENSG00000241326': 1,
#  'ENSG00000162444': 1,
#  'ENSG00000130939': 1,
#  'ENSG00000224340': 1,
#  'ENSG00000233623': 1,
#  'ENSG00000201746': 1,
#  'ENSG00000054523': 1,
#  'ENSG00000264881': 1,
#  'ENSG00000199562': 1,
#  'ENSG00000264501': 1,
#  'ENSG00000284735': 1,
#  'ENSG00000284642': 1,
#  'ENSG00000142657': 1,
#  'ENSG00000271989': 1,
#  'ENSG00000251503': 1,
#  'ENSG00000175279': 1,
#  'ENSG00000241563': 1,
#  'ENSG00000160049': 1,
#  'ENSG00000203469': 1,
#  'ENSG00000142655': 1,
#  'ENSG00000287727': 1,
#  'ENSG00000243267': 1,
#  'ENSG00000130940': 1,
#  'ENSG00000272078': 1,
#  'ENSG00000225158': 1,
#  'ENSG00000175262': 1,
#  'ENSG00000215785': 1,
#  'ENSG00000120948': 1,
#  'ENSG00000009724': 1,
#  'ENSG00000116649': 1,
#  'ENSG00000171824': 1,
#  'ENSG00000226849': 1,
#  'ENSG00000230337': 1,
#  'ENSG00000198793': 1,
#  'ENSG00000225602': 1,
#  'ENSG00000253086': 1,
#  'ENSG00000171819': 1,
#  'ENSG00000207451': 1,
#  'ENSG00000238173': 1,
#  'ENSG00000120942': 1,
#  'ENSG00000238199': 1,
#  'ENSG00000284646': 1,
#  'ENSG00000224338': 1,
#  'ENSG00000204624': 1,
#  'ENSG00000285833': 1,
#  'ENSG00000235643': 1,
#  'ENSG00000284708': 1,
#  'ENSG00000116661': 1,
#  'ENSG00000132879': 1,
#  'ENSG00000116670': 1,
#  'ENSG00000116663': 1,
#  'ENSG00000162490': 1,
#  'ENSG00000177674': 1,
#  'ENSG00000215910': 1,
#  'ENSG00000177553': 1,
#  'ENSG00000177000': 1,
#  'ENSG00000011021': 1,
#  'ENSG00000276470': 1,
#  'ENSG00000278852': 1,
#  'ENSG00000175206': 1,
#  'ENSG00000275915': 1,
#  'ENSG00000120937': 1,
#  'ENSG00000224904': 1,
#  'ENSG00000285646': 1,
#  'ENSG00000199347': 1,
#  'ENSG00000201801': 1,
#  'ENSG00000116685': 1,
#  'ENSG00000083444': 1,
#  'ENSG00000287384': 1,
#  'ENSG00000116688': 1,
#  'ENSG00000270914': 1,
#  'ENSG00000116691': 1,
#  'ENSG00000202461': 1,
#  'ENSG00000276869': 1,
#  'ENSG00000243539': 1,
#  'ENSG00000120949': 1,
#  'ENSG00000201135': 1,
#  'ENSG00000227875': 1,
#  'ENSG00000285604': 1,
#  'ENSG00000283789': 1,
#  'ENSG00000028137': 1,
#  'ENSG00000263676': 1,
#  'ENSG00000225196': 1,
#  'ENSG00000252969': 1,
#  'ENSG00000048707': 1,
#  'ENSG00000239149': 1,
#  'ENSG00000229484': 1,
#  'ENSG00000162496': 1,
#  'ENSG00000221340': 1,
#  'ENSG00000276830': 1,
#  'ENSG00000288927': 1,
#  'ENSG00000272482': 1,
#  'ENSG00000204518': 1,
#  'ENSG00000226166': 1,
#  'ENSG00000188984': 1,
#  'ENSG00000157330': 1,
#  'ENSG00000116726': 1,
#  'ENSG00000116721': 1,
#  'ENSG00000228338': 1,
#  'ENSG00000239810': 1,
#  'ENSG00000231103': 1,
#  'ENSG00000179172': 1,
#  'ENSG00000120952': 1,
#  'ENSG00000243073': 1,
#  'ENSG00000187545': 1,
#  'ENSG00000204510': 1,
#  'ENSG00000207434': 1,
#  'ENSG00000234064': 1,
#  'ENSG00000232423': 1,
#  'ENSG00000274178': 1,
#  'ENSG00000274764': 1,
#  'ENSG00000277058': 1,
#  'ENSG00000229571': 1,
#  'ENSG00000277862': 1,
#  'ENSG00000236179': 1,
#  'ENSG00000275774': 1,
#  'ENSG00000229978': 1,
#  'ENSG00000290772': 1,
#  'ENSG00000233336': 1,
#  'ENSG00000280267': 1,
#  'ENSG00000179412': 1,
#  'ENSG00000204505': 1,
#  'ENSG00000279169': 1,
#  'ENSG00000279804': 1,
#  'ENSG00000250894': 1,
#  'ENSG00000270601': 1,
#  'ENSG00000231219': 1,
#  'ENSG00000207511': 1,
#  'ENSG00000182330': 1,
#  'ENSG00000237700': 1,
#  'ENSG00000204501': 1,
#  'ENSG00000228229': 1,
#  'ENSG00000204481': 1,
#  'ENSG00000204480': 1,
#  'ENSG00000204479': 1,
#  'ENSG00000204478': 1,
#  'ENSG00000162494': 1,
#  'ENSG00000259961': 1,
#  'ENSG00000215909': 1,
#  'ENSG00000162493': 1,
#  'ENSG00000222952': 1,
#  'ENSG00000237445': 1,
#  'ENSG00000253085': 1,
#  'ENSG00000116731': 1,
#  'ENSG00000289380': 1,
#  'ENSG00000189337': 1,
#  'ENSG00000252151': 1,
#  'ENSG00000231606': 1,
#  'ENSG00000234593': 1,
#  'ENSG00000235829': 1,
#  'ENSG00000287756': 1,
#  'ENSG00000175147': 1,
#  'ENSG00000171729': 1,
#  'ENSG00000204464': 1,
#  'ENSG00000215720': 1,
#  'ENSG00000278480': 1,
#  'ENSG00000142621': 1,
#  'ENSG00000233485': 1,
#  'ENSG00000236045': 1,
#  'ENSG00000228140': 1,
#  'ENSG00000142634': 1,
#  'ENSG00000162438': 1,
#  'ENSG00000142615': 1,
#  'ENSG00000215704': 1,
#  'ENSG00000132906': 1,
#  'ENSG00000116138': 1,
#  'ENSG00000251866': 1,
#  'ENSG00000272510': 1,
#  'ENSG00000116771': 1,
#  'ENSG00000237301': 1,
#  'ENSG00000235084': 1,
#  'ENSG00000252417': 1,
#  'ENSG00000236500': 1,
#  'ENSG00000197312': 1,
#  'ENSG00000215695': 1,
#  'ENSG00000271742': 1,
#  'ENSG00000116786': 1,
#  'ENSG00000237938': 1,
#  'ENSG00000162461': 1,
#  'ENSG00000224459': 1,
#  'ENSG00000162460': 1,
#  'ENSG00000162458': 1,
#  'ENSG00000224321': 1,
#  'ENSG00000233954': 1,
#  'ENSG00000178715': 1,
#  'ENSG00000179743': 1,
#  'ENSG00000065526': 1,
#  'ENSG00000270620': 1,
#  'ENSG00000116809': 1,
#  'ENSG00000234607': 1,
#  'ENSG00000231353': 1,
#  'ENSG00000275503': 1,
#  'ENSG00000224966': 1,
#  'ENSG00000183888': 1,
#  'ENSG00000233078': 1,
#  'ENSG00000173641': 1,
#  'ENSG00000186510': 1,
#  'ENSG00000232456': 1,
#  'ENSG00000184908': 1,
#  'ENSG00000185519': 1,
#  'ENSG00000142627': 1,
#  'ENSG00000227959': 1,
#  'ENSG00000224621': 1,
#  'ENSG00000234166': 1,
#  'ENSG00000142632': 1,
#  'ENSG00000291077': 1,
#  'ENSG00000237276': 1,
#  'ENSG00000288398': 1,
#  'ENSG00000132881': 1,
#  'ENSG00000233929': 1,
#  'ENSG00000037637': 1,
#  'ENSG00000055070': 1,
#  'ENSG00000226457': 1,
#  'ENSG00000187144': 1,
#  'ENSG00000157191': 1,
#  'ENSG00000226029': 1,
#  'ENSG00000290842': 1,
#  'ENSG00000080947': 1,
#  'ENSG00000206652': 1,
#  'ENSG00000261135': 1,
#  'ENSG00000285853': 1,
#  'ENSG00000224174': 1,
#  'ENSG00000233421': 1,
#  'ENSG00000277344': 1,
#  'ENSG00000225710': 1,
#  'ENSG00000219481': 1,
#  'ENSG00000271732': 1,
#  'ENSG00000291072': 1,
#  'ENSG00000215908': 1,
#  'ENSG00000283773': 1,
#  'ENSG00000186301': 1,
#  'ENSG00000282143': 1,
#  'ENSG00000207513': 1,
#  'ENSG00000280114': 1,
#  'ENSG00000236698': 1,
#  'ENSG00000290849': 1,
#  'ENSG00000268869': 1,
#  'ENSG00000279151': 1,
#  'ENSG00000282740': 1,
#  'ENSG00000058453': 1,
#  'ENSG00000290850': 1,
#  'ENSG00000207389': 1,
#  'ENSG00000227684': 1,
#  'ENSG00000290851': 1,
#  'ENSG00000186715': 1,
#  'ENSG00000223643': 1,
#  'ENSG00000230239': 1,
#  'ENSG00000263811': 1,
#  'ENSG00000228549': 1,
#  'ENSG00000277234': 1,
#  'ENSG00000238142': 1,
#  'ENSG00000235241': 1,
#  'ENSG00000207005': 1,
#  'ENSG00000272426': 1,
#  'ENSG00000290122': 1,
#  'ENSG00000117122': 1,
#  'ENSG00000286898': 1,
#  'ENSG00000226526': 1,
#  'ENSG00000159363': 1,
#  'ENSG00000288636': 1,
#  'ENSG00000117118': 1,
#  'ENSG00000117115': 1,
#  'ENSG00000204362': 1,
#  'ENSG00000282843': 1,
#  'ENSG00000142623': 1,
#  'ENSG00000142619': 1,
#  'ENSG00000266634': 1,
#  'ENSG00000159339': 1,
#  'ENSG00000276747': 1,
#  'ENSG00000227751': 1,
#  'ENSG00000179051': 1,
#  'ENSG00000290096': 1,
#  'ENSG00000074964': 1,
#  'ENSG00000236648': 1,
#  'ENSG00000117148': 1,
#  'ENSG00000284653': 1,
#  'ENSG00000261781': 1,
#  'ENSG00000117154': 1,
#  'ENSG00000280222': 1,
#  'ENSG00000230035': 1,
#  'ENSG00000225387': 1,
#  'ENSG00000179023': 1,
#  'ENSG00000235282': 1,
#  'ENSG00000225478': 1,
#  'ENSG00000009709': 1,
#  'ENSG00000179002': 1,
#  'ENSG00000159423': 1,
#  'ENSG00000265606': 1,
#  'ENSG00000221662': 1,
#  'ENSG00000169991': 1,
#  'ENSG00000272084': 1,
#  'ENSG00000127481': 1,
#  'ENSG00000230424': 1,
#  'ENSG00000127463': 1,
#  'ENSG00000053372': 1,
#  'ENSG00000286064': 1,
#  'ENSG00000211454': 1,
#  'ENSG00000162482': 1,
#  'ENSG00000270728': 1,
#  'ENSG00000053371': 1,
#  'ENSG00000200403': 1,
#  'ENSG00000040487': 1,
#  'ENSG00000077549': 1,
#  'ENSG00000240490': 1,
#  'ENSG00000173436': 1,
#  'ENSG00000201609': 1,
#  'ENSG00000235185': 1,
#  'ENSG00000158747': 1,
#  'ENSG00000270136': 1,
#  'ENSG00000226396': 1,
#  'ENSG00000158748': 1,
#  'ENSG00000162542': 1,
#  'ENSG00000178828': 1,
#  'ENSG00000235434': 1,
#  'ENSG00000169914': 1,
#  'ENSG00000188784': 1,
#  'ENSG00000242688': 1,
#  'ENSG00000188257': 1,
#  'ENSG00000127472': 1,
#  'ENSG00000117215': 1,
#  'ENSG00000158786': 1,
#  'ENSG00000227066': 1,
#  'ENSG00000187980': 1,
#  'ENSG00000162543': 1,
#  'ENSG00000228105': 1,
#  'ENSG00000284710': 1,
#  'ENSG00000158816': 1,
#  'ENSG00000226664': 1,
#  'ENSG00000236963': 1,
#  'ENSG00000226487': 1,
#  'ENSG00000284641': 1,
#  'ENSG00000284743': 1,
#  'ENSG00000162545': 1,
#  'ENSG00000289402': 1,
#  'ENSG00000090432': 1,
#  'ENSG00000215520': 1,
#  'ENSG00000183114': 1,
#  'ENSG00000158825': 1,
#  'ENSG00000158828': 1,
#  'ENSG00000284005': 1,
#  'ENSG00000117242': 1,
#  'ENSG00000244038': 1,
#  'ENSG00000117245': 1,
#  'ENSG00000235432': 1,
#  'ENSG00000189410': 1,
#  'ENSG00000233069': 1,
#  'ENSG00000127483': 1,
#  'ENSG00000075151': 1,
#  'ENSG00000251914': 1,
#  'ENSG00000221808': 1,
#  'ENSG00000233072': 1,
#  'ENSG00000236073': 1,
#  'ENSG00000235112': 1,
#  'ENSG00000287192': 1,
#  'ENSG00000117298': 1,
#  'ENSG00000236936': 1,
#  'ENSG00000231105': 1,
#  'ENSG00000236216': 1,
#  'ENSG00000228823': 1,
#  'ENSG00000236009': 1,
#  'ENSG00000227001': 1,
#  'ENSG00000187952': 1,
#  'ENSG00000186543': 1,
#  'ENSG00000142794': 1,
#  'ENSG00000176378': 1,
#  'ENSG00000162551': 1,
#  'ENSG00000289715': 1,
#  'ENSG00000233431': 1,
#  'ENSG00000076864': 1,
#  'ENSG00000090686': 1,
#  'ENSG00000231978': 1,
#  'ENSG00000187942': 1,
#  'ENSG00000142798': 1,
#  'ENSG00000232037': 1,
#  'ENSG00000283234': 1,
#  'ENSG00000219073': 1,
#  'ENSG00000285959': 1,
#  'ENSG00000273610': 1,
#  'ENSG00000201919': 1,
#  'ENSG00000142789': 1,
#  'ENSG00000278124': 1,
#  'ENSG00000201273': 1,
#  'ENSG00000228397': 1,
#  'ENSG00000218510': 1,
#  'ENSG00000289694': 1,
#  'ENSG00000285752': 1,
#  'ENSG00000285794': 1,
#  'ENSG00000070831': 1,
#  'ENSG00000230068': 1,
#  'ENSG00000271428': 1,
#  'ENSG00000162552': 1,
#  'ENSG00000285873': 1,
#  'ENSG00000266564': 1,
#  'ENSG00000234397': 1,
#  'ENSG00000279625': 1,
#  'ENSG00000184677': 1,
#  'ENSG00000237200': 1,
#  'ENSG00000070886': 1,
#  'ENSG00000276835': 1,
#  'ENSG00000173372': 1,
#  'ENSG00000289692': 1,
#  'ENSG00000159189': 1,
#  'ENSG00000173369': 1,
#  'ENSG00000133216': 1,
#  'ENSG00000265422': 1,
#  'ENSG00000225952': 1,
#  'ENSG00000264014': 1,
#  'ENSG00000215906': 1,
#  'ENSG00000227868': 1,
#  'ENSG00000004487': 1,
#  'ENSG00000240553': 1,
#  'ENSG00000263793': 1,
#  'ENSG00000266802': 1,
#  'ENSG00000169641': 1,
#  'ENSG00000229010': 1,
#  'ENSG00000206935': 1,
#  'ENSG00000252578': 1,
#  'ENSG00000289014': 1,
#  'ENSG00000179546': 1,
#  'ENSG00000215381': 1,
#  'ENSG00000261326': 1,
#  'ENSG00000284726': 1,
#  'ENSG00000125944': 1,
#  'ENSG00000125945': 1,
#  'ENSG00000249087': 1,
#  'ENSG00000201405': 1,
#  'ENSG00000271420': 1,
#  'ENSG00000204219': 1,
#  'ENSG00000232482': 1,
#  'ENSG00000088280': 1,
#  'ENSG00000007968': 1,
#  'ENSG00000235052': 1,
#  'ENSG00000117318': 1,
#  'ENSG00000285802': 1,
#  'ENSG00000197880': 1,
#  'ENSG00000229239': 1,
#  'ENSG00000142676': 1,
#  'ENSG00000236810': 1,
#  'ENSG00000011007': 1,
#  'ENSG00000057757': 1,
#  'ENSG00000289835': 1,
#  'ENSG00000011009': 1,
#  'ENSG00000117308': 1,
#  'ENSG00000117305': 1,
#  'ENSG00000179163': 1,
#  'ENSG00000188822': 1,
#  'ENSG00000229106': 1,
#  'ENSG00000232557': 1,
#  'ENSG00000264926': 1,
#  'ENSG00000230228': 1,
#  'ENSG00000189266': 1,
#  'ENSG00000188529': 1,
#  'ENSG00000215905': 1,
#  'ENSG00000225315': 1,
#  'ENSG00000142661': 1,
#  'ENSG00000230703': 1,
#  'ENSG00000142677': 1,
#  'ENSG00000185436': 1,
#  'ENSG00000158055': 1,
#  'ENSG00000230023': 1,
#  'ENSG00000232298': 1,
#  'ENSG00000001460': 1,
#  'ENSG00000001461': 1,
#  'ENSG00000288982': 1,
#  'ENSG00000286061': 1,
#  'ENSG00000117602': 1,
#  'ENSG00000264443': 1,
#  'ENSG00000184454': 1,
#  'ENSG00000227312': 1,
#  'ENSG00000239106': 1,
#  'ENSG00000133226': 1,
#  'ENSG00000284699': 1,
#  'ENSG00000169504': 1,
#  'ENSG00000238482': 1,
#  'ENSG00000020633': 1,
#  'ENSG00000278034': 1,
#  'ENSG00000229162': 1,
#  'ENSG00000261025': 1,
#  'ENSG00000264371': 1,
#  'ENSG00000285823': 1,
#  'ENSG00000233755': 1,
#  'ENSG00000233419': 1,
#  'ENSG00000231953': 1,
#  'ENSG00000117614': 1,
#  'ENSG00000284602': 1,
#  'ENSG00000284657': 1,
#  'ENSG00000117616': 1,
#  'ENSG00000272432': 1,
#  'ENSG00000261349': 1,
#  'ENSG00000187010': 1,
#  'ENSG00000224183': 1,
#  'ENSG00000259984': 1,
#  'ENSG00000183726': 1,
#  'ENSG00000188672': 1,
#  'ENSG00000238084': 1,
#  'ENSG00000204178': 1,
#  'ENSG00000157978': 1,
#  'ENSG00000225643': 1,
#  'ENSG00000117643': 1,
#  'ENSG00000233478': 1,
#  'ENSG00000162430': 1,
#  'ENSG00000255054': 1,
#  'ENSG00000228172': 1,
#  'ENSG00000117640': 1,
#  'ENSG00000272478': 1,
#  'ENSG00000127423': 1,
#  'ENSG00000236528': 1,
#  'ENSG00000182749': 1,
#  'ENSG00000207302': 1,
#  'ENSG00000117632': 1,
#  'ENSG00000229786': 1,
#  'ENSG00000223624': 1,
#  'ENSG00000283938': 1,
#  'ENSG00000158006': 1,
#  'ENSG00000207237': 1,
#  'ENSG00000252190': 1,
#  'ENSG00000252691': 1,
#  'ENSG00000158008': 1,
#  'ENSG00000158014': 1,
#  'ENSG00000284309': 1,
#  'ENSG00000158022': 1,
#  'ENSG00000175087': 1,
#  'ENSG00000197245': 1,
#  'ENSG00000282872': 1,
#  'ENSG00000236782': 1,
#  'ENSG00000142684': 1,
#  'ENSG00000142675': 1,
#  'ENSG00000188782': 1,
#  'ENSG00000236155': 1,
#  'ENSG00000278572': 1,
#  'ENSG00000130695': 1,
#  'ENSG00000270733': 1,
#  'ENSG00000142669': 1,
#  'ENSG00000158062': 1,
#  'ENSG00000169442': 1,
#  'ENSG00000176092': 1,
#  'ENSG00000225854': 1,
#  'ENSG00000176083': 1,
#  'ENSG00000131914': 1,
#  'ENSG00000117682': 1,
#  'ENSG00000223583': 1,
#  'ENSG00000225891': 1,
#  'ENSG00000198830': 1,
#  'ENSG00000224129': 1,
#  'ENSG00000117676': 1,
#  'ENSG00000238705': 1,
#  'ENSG00000243905': 1,
#  'ENSG00000252802': 1,
#  'ENSG00000252429': 1,
#  ...}

# %%
len(genedict)
# Out:
# 119799

# %%
#Filter out the genes which are not in the approved genes file.

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]
var_to_keep_araw = [x for x in araw.var_names if (x in genedict)]

# %%
len(var_to_keep_adata)
# Out:
# 19283

# %%
len(var_to_keep_araw)
# Out:
# 19283

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000095585  False  False                 67     0.007599
# ENSMUSG00000096506  False  False                237     0.042484
# ENSMUSG00000095320  False  False                 30     0.002436
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000095585              99.611343    131.000000       67
# ENSMUSG00000096506              98.625214    732.385132      237
# ENSMUSG00000095320              99.825974     42.000000       30
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000095585            False  0.017431     1.512446          0.225248
# ENSMUSG00000096506             True  0.101700     2.757137          2.609761
# ENSMUSG00000095320            False  0.008137     1.713660          0.610724
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                               gene_ids       gene_name
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902           Sox17
# ENSMUSG00000033845  ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903  ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813  ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459  ENSMUSG00000002459           Rgs20
# ...                                ...             ...
# ENSMUSG00000095585  ENSMUSG00000095585      CR974586.2
# ENSMUSG00000096506  ENSMUSG00000096506      CR974586.4
# ENSMUSG00000095320  ENSMUSG00000095320        Ccl21a-1
# ENSMUSG00000095742  ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041  ENSMUSG00000095041      AC149090.1
#
# [19330 rows x 13 columns]

# %%
araw.var
# Out:
#                               gene_ids    feature_types genome  n_cells  \
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  ENSMUSG00000002459  Gene Expression   mm10        3
# ...                                ...              ...    ...      ...
# ENSMUSG00000095585  ENSMUSG00000095585  Gene Expression   mm10       67
# ENSMUSG00000096506  ENSMUSG00000096506  Gene Expression   mm10      237
# ENSMUSG00000095320  ENSMUSG00000095320  Gene Expression   mm10       30
# ENSMUSG00000095742  ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression   mm10     4401
#
#                          gene_name
# gene_ids
# ENSMUSG00000025902           Sox17
# ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459           Rgs20
# ...                            ...
# ENSMUSG00000095585      CR974586.2
# ENSMUSG00000096506      CR974586.4
# ENSMUSG00000095320        Ccl21a-1
# ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041      AC149090.1
#
# [19330 rows x 5 columns]

# %%
# Modify the anndata object by filtering out the filtered genes.

# %%
adata = adata[:, adata.var.index.isin(var_to_keep_adata)]
araw = araw[:, araw.var.index.isin(var_to_keep_araw)]

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                               gene_ids       gene_name
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902           Sox17
# ENSMUSG00000033845  ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903  ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813  ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459  ENSMUSG00000002459           Rgs20
# ...                                ...             ...
# ENSMUSG00000094728  ENSMUSG00000094728      AC132444.2
# ENSMUSG00000062783  ENSMUSG00000062783           Csprs
# ENSMUSG00000096808  ENSMUSG00000096808      AC132444.6
# ENSMUSG00000095742  ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041  ENSMUSG00000095041      AC149090.1
#
# [19283 rows x 13 columns]

# %%
# View var

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                               gene_ids       gene_name
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902           Sox17
# ENSMUSG00000033845  ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903  ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813  ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459  ENSMUSG00000002459           Rgs20
# ...                                ...             ...
# ENSMUSG00000094728  ENSMUSG00000094728      AC132444.2
# ENSMUSG00000062783  ENSMUSG00000062783           Csprs
# ENSMUSG00000096808  ENSMUSG00000096808      AC132444.6
# ENSMUSG00000095742  ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041  ENSMUSG00000095041      AC149090.1
#
# [19283 rows x 13 columns]

# %%
araw.var
# Out:
#                               gene_ids    feature_types genome  n_cells  \
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  ENSMUSG00000002459  Gene Expression   mm10        3
# ...                                ...              ...    ...      ...
# ENSMUSG00000094728  ENSMUSG00000094728  Gene Expression   mm10       70
# ENSMUSG00000062783  ENSMUSG00000062783  Gene Expression   mm10       91
# ENSMUSG00000096808  ENSMUSG00000096808  Gene Expression   mm10        8
# ENSMUSG00000095742  ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression   mm10     4401
#
#                          gene_name
# gene_ids
# ENSMUSG00000025902           Sox17
# ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459           Rgs20
# ...                            ...
# ENSMUSG00000094728      AC132444.2
# ENSMUSG00000062783           Csprs
# ENSMUSG00000096808      AC132444.6
# ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041      AC149090.1
#
# [19283 rows x 5 columns]

# %% [markdown]
# feature is filtered

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)
# Out:
# /tmp/ipykernel_32553/3766134281.py:1: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                               gene_ids       gene_name  feature_is_filtered
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902           Sox17                False
# ENSMUSG00000033845  ENSMUSG00000033845          Mrpl15                False
# ENSMUSG00000025903  ENSMUSG00000025903          Lypla1                False
# ENSMUSG00000033813  ENSMUSG00000033813           Tcea1                False
# ENSMUSG00000002459  ENSMUSG00000002459           Rgs20                False
# ...                                ...             ...                  ...
# ENSMUSG00000094728  ENSMUSG00000094728      AC132444.2                False
# ENSMUSG00000062783  ENSMUSG00000062783           Csprs                False
# ENSMUSG00000096808  ENSMUSG00000096808      AC132444.6                False
# ENSMUSG00000095742  ENSMUSG00000095742  CAAA01147332.1                False
# ENSMUSG00000095041  ENSMUSG00000095041      AC149090.1                False
#
# [19283 rows x 14 columns]

# %%
araw.var
# Out:
#                               gene_ids    feature_types genome  n_cells  \
# gene_ids
# ENSMUSG00000025902  ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  ENSMUSG00000002459  Gene Expression   mm10        3
# ...                                ...              ...    ...      ...
# ENSMUSG00000094728  ENSMUSG00000094728  Gene Expression   mm10       70
# ENSMUSG00000062783  ENSMUSG00000062783  Gene Expression   mm10       91
# ENSMUSG00000096808  ENSMUSG00000096808  Gene Expression   mm10        8
# ENSMUSG00000095742  ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  ENSMUSG00000095041  Gene Expression   mm10     4401
#
#                          gene_name
# gene_ids
# ENSMUSG00000025902           Sox17
# ENSMUSG00000033845          Mrpl15
# ENSMUSG00000025903          Lypla1
# ENSMUSG00000033813           Tcea1
# ENSMUSG00000002459           Rgs20
# ...                            ...
# ENSMUSG00000094728      AC132444.2
# ENSMUSG00000062783           Csprs
# ENSMUSG00000096808      AC132444.6
# ENSMUSG00000095742  CAAA01147332.1
# ENSMUSG00000095041      AC149090.1
#
# [19283 rows x 5 columns]

# %%
del adata.var['gene_ids']
del araw.var['gene_ids']
del adata.var['gene_name']
del araw.var['gene_name']

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000025902                False
# ENSMUSG00000033845                False
# ENSMUSG00000025903                False
# ENSMUSG00000033813                False
# ENSMUSG00000002459                False
# ...                                 ...
# ENSMUSG00000094728                False
# ENSMUSG00000062783                False
# ENSMUSG00000096808                False
# ENSMUSG00000095742                False
# ENSMUSG00000095041                False
#
# [19283 rows x 12 columns]

# %%
araw.var
# Out:
#                       feature_types genome  n_cells
# gene_ids
# ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  Gene Expression   mm10        3
# ...                             ...    ...      ...
# ENSMUSG00000094728  Gene Expression   mm10       70
# ENSMUSG00000062783  Gene Expression   mm10       91
# ENSMUSG00000096808  Gene Expression   mm10        8
# ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  Gene Expression   mm10     4401
#
# [19283 rows x 3 columns]

# %% [markdown]
# #### **obs (Cell metadata)**

# %%
#view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN
# ...                                ...     ...      ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP
#
# [3912 rows x 3 columns]

# %%
# view the column names in obs

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location'], dtype='object')

# %%
adata.obs
# Out:
#                       final_annotation lineage location
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN
# ...                                ...     ...      ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP
#
# [3912 rows x 3 columns]

# %%
araw.obs
# Out:
#                        original_annotation              anno   Dataset
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting_MLN  GC.BC_LZ-resting  NicheSeq
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2_MLN   PCs.CD19-IgM+.2  NicheSeq
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+_MLN     PCs.CD19+IgM+  NicheSeq
# AAACCTGGTACCGGCT-1-0      Naive.Bcells_MLN      Naive.Bcells  NicheSeq
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2_MLN        GC.BC_DZ.2  NicheSeq
# ...                                    ...               ...       ...
# TTTATGCCAATGGATA-1-3           PCs.IgA+_LP          PCs.IgA+  NicheSeq
# TTTATGCTCGTAGATC-1-3    PCs.CD19-IgM+.1_LP   PCs.CD19-IgM+.1  NicheSeq
# TTTGCGCAGGCCCTCA-1-3           PCs.IgA+_LP          PCs.IgA+  NicheSeq
# TTTGCGCAGGGTTTCT-1-3    PCs.CD19-IgM+.1_LP   PCs.CD19-IgM+.1  NicheSeq
# TTTGGTTCACGGTAAG-1-3           PCs.IgA+_LP          PCs.IgA+  NicheSeq
#
# [3912 rows x 3 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['barcodes'] = adata.obs_names

# %%
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
assay_info = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/covid_cell_atlas_ALI_organoids/10X_barcode_table_assay.csv')

# %%
mapping = dict(zip(assay_info['barcode'], assay_info['assay']))

# %%
adata.obs['assay'] = adata.obs['barcodes'].map(mapping)

# %%
list(adata.obs['assay'].unique())
# Out:
# ['3pv2_5pv1_5pv2', '3pv2_5pv1_5pv2+3pv3', '3pv2_5pv1_5pv2+multiome']

# %%
adata.obs['assay_ontology_term_id']  = 'EFO:0009900'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
# [3912 rows x 6 columns]

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
#identify the column in adata.obs related. to cell type annotation

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id'],
#       dtype='object')

# %%
list(adata.obs['final_annotation'].unique())
# Out:
# ['GC.BC_LZ-resting',
#  'PCs.CD19-IgM+.2',
#  'PCs.CD19+IgM+',
#  'Naive.Bcells',
#  'GC.BC_DZ.2',
#  'Plasmablast-IgM+_cycling',
#  'GC.BC_DZ.1',
#  'eMBCs',
#  'PCs.CD19-IgM+.1',
#  'PCs.IgA+',
#  'pre-GC.BCs',
#  'PCs_low_count',
#  'Naive.Bcells.ISGhi',
#  'GC.BC_DZ-pre-memory BC']

# %%
# create a dictionary of cell type and ontology term

# %%
mapping={'GC.BC_LZ-resting':'CL:0000844',
'Lymph.DC.Sirpa+':'CL:0000990',
'PCs.CD19-IgM+.2':'CL:0000786',
'cTregs':'CL:0000815',
'PCs.CD19+IgM+':'CL:0000786',
'Naive.Bcells':'CL:0000788',
'Naive.CD4+_MLN':'CL:0000895',
'GC.BC_DZ.2':'CL:0000844',
'Plasmablast-IgM+_cycling':'CL:0000983',
'Lymph.DC.Cd81+':'CL:0000990',
'DC.Sirpa+Cd81+':'CL:0000451',
'GC.BC_DZ.1':'CL:0009104',
'eMBCs':'CL:0000787',
'PCs.CD19-IgM+.1':'CL:0000786',
'DC1.Cd8+Xcr1+':'CL:0001000',
'Naive.CD8+_MLN':'CL:0000900',
'DC.Il1b_low.Cd103-Sirpa+':'CL:0000990',
'Fibroblast_Cxcl12+':'CL:0000057',
'PCs.IgA+':'CL:0000786',
'DC1.apopt.':'CL:0000990',
'Th17':'CL:0000899',
'DC.prolif.':'CL:0000990',
'NK-NKT-gdTCs':'CL:0000798',
'Naive.CD4+_CP':'CL:0000895',
'Mono.Sirpa+':'CL:0000576',
'Endothelial.cells':'CL:0000115',
'Neutrophils':'CL:0000775',
'Lymph.DC.Cd8+':'CL:0000990',
'pDCs':'CL:0000784',
'pre-GC.BCs':'CL:0000844',
'PCs_low_count':'CL:0000786',
'gdTCs.Th17':'CL:0000798',
'Naive.Bcells.ISGhi':'CL:0000788',
'Lymphatic_capillary':'CL:0002144',
'Naive.CD4+CD8+':'CL:0000895',
'LTi-like.ILC3s':'CL:0001071',
'Naive.CD8+_CP':'CL:0000900',
'Fibroblast_Endosialin+':'CL:0000057',
'Mono.Il1b+':'CL:0000576',
'CD4.memory':'CL:0000897',
'Lymph.DC.Il1b_high.prolif.':'CL:0000990',
'Prolif-Tregs':'CL:0000815',
'eTregs':'CL:0000815',
'Mac.Sirpa+':'CL:0000235',
'pre-DC':'CL:0000451',
'Mac.Il1b+':'CL:0000235',
'ILC3s.Rorgt+':'CL:0001071',
'ILC3s.Rorgt+.MHCIIhi':'CL:0001071',
'DC.Il1b_high.Cd103+':'CL:0002461',
'DC.Il1b_high.Cd103+Sirpa+':'CL:0002461',
'ILC2s':'CL:0001069',
'Pericytes':'CL:0000669',
'Mac.Cd206+':'CL:0000235',
'Epithelial.MHCII+':'CL:0000066',
'Mast cells':'CL:0000097',
'GC.BC_DZ-pre-memory BC':'CL:0000844',
'Lymphatic_endothelium':'CL:0002138',
'Fibroblast.Adamdec1+Pdgfra_high':'CL:0000057',
'Fibroblast_Adamdec1+Pdgfra_low':'CL:0000057',
'Fibroblast_Acta2+':'CL:0000057',
'Epithelial':'CL:0000066',
'Myofibroblast':'CL:0000186',
'Glial cells':'CL:0000125'}

# %%
# add the cell_type_ontology_term_id column

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['final_annotation'].map(mapping)

# %%
# change datatype of the column

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
# [3912 rows x 7 columns]

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
# identify the column in adata which corresponds to age

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id'],
#       dtype='object')

# %%
adata.obs['development_stage_ontology_term_id'] = 'MmusDv:0000061'

# %%
# change datatype of the column

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
# view unique values of development_stage_ontology_term_id column

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061
# ...                                                 ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061
#
# [3912 rows x 8 columns]

# %% [markdown]
# #### **donor_id**

# %%
#identify the column in adata.obs which provides donor information

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id'],
#       dtype='object')

# %%
adata.obs['donor_id'] = 'pooled'

# %%
#adata.obs['donor_id'] = ['unknown'] * len(adata.obs['names'])

# %%
# change datatype of the column

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
# view unique values of donor_id column

# %%
list(adata.obs['donor_id'].unique())
# Out:
# ['pooled']

# %%
#view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
# [3912 rows x 9 columns]

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id'],
#       dtype='object')

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
adata.obs['disease_ontology_term_id']= ['PATO:0000461'] * len(adata.obs)

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id
# AAACCTGAGCCCAATT-1-0             PATO:0000461
# AAACCTGAGGTGATTA-1-0             PATO:0000461
# AAACCTGCATGGTTGT-1-0             PATO:0000461
# AAACCTGGTACCGGCT-1-0             PATO:0000461
# AAACCTGGTCGAGATG-1-0             PATO:0000461
# ...                                       ...
# TTTATGCCAATGGATA-1-3             PATO:0000461
# TTTATGCTCGTAGATC-1-3             PATO:0000461
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461
# TTTGGTTCACGGTAAG-1-3             PATO:0000461
#
# [3912 rows x 10 columns]

# %%
# change datatype of the column

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id
# AAACCTGAGCCCAATT-1-0             PATO:0000461
# AAACCTGAGGTGATTA-1-0             PATO:0000461
# AAACCTGCATGGTTGT-1-0             PATO:0000461
# AAACCTGGTACCGGCT-1-0             PATO:0000461
# AAACCTGGTCGAGATG-1-0             PATO:0000461
# ...                                       ...
# TTTATGCCAATGGATA-1-3             PATO:0000461
# TTTATGCTCGTAGATC-1-3             PATO:0000461
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461
# TTTGGTTCACGGTAAG-1-3             PATO:0000461
#
# [3912 rows x 10 columns]

# %% [markdown]
# #### **is_primary_data**

# %%
#change data type of column

# %%
adata.obs['is_primary_data']= [True] * len(adata.obs)

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
# [3912 rows x 11 columns]

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
# assign organism id

# %%
adata.obs['organism_ontology_term_id'] = ['NCBITaxon:10090'] * len(adata.obs)

# %%
#change data type of column

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
# [3912 rows x 12 columns]

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = ['na'] * len(adata.obs)

# %%
# change data type

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
# [3912 rows x 13 columns]

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id'],
#       dtype='object')

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
# identify the column in adata.obs which corresponds to sex

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id'],
#       dtype='object')

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
# [3912 rows x 13 columns]

# %%
adata.obs['sex_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
# change data type

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id
# AAACCTGAGCCCAATT-1-0              unknown
# AAACCTGAGGTGATTA-1-0              unknown
# AAACCTGCATGGTTGT-1-0              unknown
# AAACCTGGTACCGGCT-1-0              unknown
# AAACCTGGTCGAGATG-1-0              unknown
# ...                                   ...
# TTTATGCCAATGGATA-1-3              unknown
# TTTATGCTCGTAGATC-1-3              unknown
# TTTGCGCAGGCCCTCA-1-3              unknown
# TTTGCGCAGGGTTTCT-1-3              unknown
# TTTGGTTCACGGTAAG-1-3              unknown
#
# [3912 rows x 14 columns]

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id
# AAACCTGAGCCCAATT-1-0              unknown
# AAACCTGAGGTGATTA-1-0              unknown
# AAACCTGCATGGTTGT-1-0              unknown
# AAACCTGGTACCGGCT-1-0              unknown
# AAACCTGGTCGAGATG-1-0              unknown
# ...                                   ...
# TTTATGCCAATGGATA-1-3              unknown
# TTTATGCTCGTAGATC-1-3              unknown
# TTTGCGCAGGCCCTCA-1-3              unknown
# TTTGCGCAGGGTTTCT-1-3              unknown
# TTTGGTTCACGGTAAG-1-3              unknown
#
# [3912 rows x 14 columns]

# %%
adata.obs['suspension_type'] = ['cell'] * len(adata.obs)

# %%
# change data type of column

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id suspension_type
# AAACCTGAGCCCAATT-1-0              unknown            cell
# AAACCTGAGGTGATTA-1-0              unknown            cell
# AAACCTGCATGGTTGT-1-0              unknown            cell
# AAACCTGGTACCGGCT-1-0              unknown            cell
# AAACCTGGTCGAGATG-1-0              unknown            cell
# ...                                   ...             ...
# TTTATGCCAATGGATA-1-3              unknown            cell
# TTTATGCTCGTAGATC-1-3              unknown            cell
# TTTGCGCAGGCCCTCA-1-3              unknown            cell
# TTTGCGCAGGGTTTCT-1-3              unknown            cell
# TTTGGTTCACGGTAAG-1-3              unknown            cell
#
# [3912 rows x 15 columns]

# %% [markdown]
# #### **tissue_type**

# %%
adata.obs['tissue_type'] = ['tissue'] * len(adata.obs)

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
# identify the column in adata.obs which corresponds to tissue

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type'],
#       dtype='object')

# %%
list(adata.obs['location'].unique())
# Out:
# ['MLN', 'CP', 'LA', 'LP']

# %%
mapping= {'MLN':'UBERON:0002509', 'CP':'UBERON:0001153', 'LA':'UBERON:0003454', 'LP':'UBERON:0001238'}

# %%
# add 'tissue_ontology_term_id' column

# %%
adata.obs['tissue_ontology_term_id'] =adata.obs['location'].map(mapping)

# %%
# change data type of column

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
#list the unique values in 'tissue_ontology_term_id' column

# %%
list(adata.obs['tissue_ontology_term_id'].unique())
# Out:
# ['UBERON:0002509', 'UBERON:0001153', 'UBERON:0003454', 'UBERON:0001238']

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCCCAATT-1-0              unknown            cell      tissue
# AAACCTGAGGTGATTA-1-0              unknown            cell      tissue
# AAACCTGCATGGTTGT-1-0              unknown            cell      tissue
# AAACCTGGTACCGGCT-1-0              unknown            cell      tissue
# AAACCTGGTCGAGATG-1-0              unknown            cell      tissue
# ...                                   ...             ...         ...
# TTTATGCCAATGGATA-1-3              unknown            cell      tissue
# TTTATGCTCGTAGATC-1-3              unknown            cell      tissue
# TTTGCGCAGGCCCTCA-1-3              unknown            cell      tissue
# TTTGCGCAGGGTTTCT-1-3              unknown            cell      tissue
# TTTGGTTCACGGTAAG-1-3              unknown            cell      tissue
#
#                      tissue_ontology_term_id
# AAACCTGAGCCCAATT-1-0          UBERON:0002509
# AAACCTGAGGTGATTA-1-0          UBERON:0002509
# AAACCTGCATGGTTGT-1-0          UBERON:0002509
# AAACCTGGTACCGGCT-1-0          UBERON:0002509
# AAACCTGGTCGAGATG-1-0          UBERON:0002509
# ...                                      ...
# TTTATGCCAATGGATA-1-3          UBERON:0001238
# TTTATGCTCGTAGATC-1-3          UBERON:0001238
# TTTGCGCAGGCCCTCA-1-3          UBERON:0001238
# TTTGCGCAGGGTTTCT-1-3          UBERON:0001238
# TTTGGTTCACGGTAAG-1-3          UBERON:0001238
#
# [3912 rows x 17 columns]

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
# view obsm

# %%
# check whether all columns are prefixed with X

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_pca, X_umap

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
# View

# %%
adata.uns
# Out:
# {'location_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728'], dtype=object)}

# %%
adata.uns.keys
# Out:
# <function dict.keys>

# %%
# Give a title for the dataset

# %%
adata.uns['title'] = 'BCs-PCs'

# %%
# Set the default embedding

# %%
adata.uns['default_embedding'] = 'X_umap'

# %% [markdown]
# ### **Final check**

# %%
# view anndata object

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3912 × 19283
#     obs: 'final_annotation', 'lineage', 'location', 'barcodes', 'assay', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id', 'suspension_type', 'tissue_type', 'tissue_ontology_term_id'
#     var: 'mt', 'rb', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'feature_is_filtered'
#     uns: 'location_colors', 'title', 'default_embedding'
#     obsm: 'X_pca', 'X_umap'

# %%
# view obs and var data types

# %%
adata.obs.dtypes
# Out:
# final_annotation                            category
# lineage                                     category
# location                                    category
# barcodes                                      object
# assay                                         object
# assay_ontology_term_id                      category
# cell_type_ontology_term_id                  category
# development_stage_ontology_term_id          category
# donor_id                                    category
# disease_ontology_term_id                    category
# is_primary_data                                 bool
# organism_ontology_term_id                   category
# self_reported_ethnicity_ontology_term_id    category
# sex_ontology_term_id                        category
# suspension_type                             category
# tissue_type                                 category
# tissue_ontology_term_id                     category
# dtype: object

# %%
dty = pd.DataFrame(adata.var.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.var[c] = adata.var[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.var[c] = adata.var[c].astype('int32') 
    print(f"changed {c} from int64 to int32")

# %%
dty = pd.DataFrame(adata.obs.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.obs[c] = adata.obs[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.obs[c] = adata.obs[c].astype('int32') 
    print(f"changed {c} from int64 to int32")
for c in dty[dty['dtype'] == 'object'].index.values:
    adata.obs[c] = adata.obs[c].astype('category') 
    print(f"changed {c} from object to category")
# Out:
# changed barcodes from object to category
# changed assay from object to category

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage location          barcodes  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs      MLN  AAACCTGAGCCCAATT
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs      MLN  AAACCTGAGGTGATTA
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs      MLN  AAACCTGCATGGTTGT
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs      MLN  AAACCTGGTACCGGCT
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs      MLN  AAACCTGGTCGAGATG
# ...                                ...     ...      ...               ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs       LP  TTTATGCCAATGGATA
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTATGCTCGTAGATC
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs       LP  TTTGCGCAGGCCCTCA
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs       LP  TTTGCGCAGGGTTTCT
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs       LP  TTTGGTTCACGGTAAG
#
#                                     assay assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGAGGTGATTA-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGCATGGTTGT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTACCGGCT-1-0       3pv2_5pv1_5pv2            EFO:0009900
# AAACCTGGTCGAGATG-1-0       3pv2_5pv1_5pv2            EFO:0009900
# ...                                   ...                    ...
# TTTATGCCAATGGATA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTATGCTCGTAGATC-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3       3pv2_5pv1_5pv2            EFO:0009900
# TTTGGTTCACGGTAAG-1-3  3pv2_5pv1_5pv2+3pv3            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCCCAATT-1-0              unknown            cell      tissue
# AAACCTGAGGTGATTA-1-0              unknown            cell      tissue
# AAACCTGCATGGTTGT-1-0              unknown            cell      tissue
# AAACCTGGTACCGGCT-1-0              unknown            cell      tissue
# AAACCTGGTCGAGATG-1-0              unknown            cell      tissue
# ...                                   ...             ...         ...
# TTTATGCCAATGGATA-1-3              unknown            cell      tissue
# TTTATGCTCGTAGATC-1-3              unknown            cell      tissue
# TTTGCGCAGGCCCTCA-1-3              unknown            cell      tissue
# TTTGCGCAGGGTTTCT-1-3              unknown            cell      tissue
# TTTGGTTCACGGTAAG-1-3              unknown            cell      tissue
#
#                      tissue_ontology_term_id
# AAACCTGAGCCCAATT-1-0          UBERON:0002509
# AAACCTGAGGTGATTA-1-0          UBERON:0002509
# AAACCTGCATGGTTGT-1-0          UBERON:0002509
# AAACCTGGTACCGGCT-1-0          UBERON:0002509
# AAACCTGGTCGAGATG-1-0          UBERON:0002509
# ...                                      ...
# TTTATGCCAATGGATA-1-3          UBERON:0001238
# TTTATGCTCGTAGATC-1-3          UBERON:0001238
# TTTGCGCAGGCCCTCA-1-3          UBERON:0001238
# TTTGCGCAGGGTTTCT-1-3          UBERON:0001238
# TTTGGTTCACGGTAAG-1-3          UBERON:0001238
#
# [3912 rows x 17 columns]

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'location', 'barcodes', 'assay',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
# delete unwanted columns in obs

# %%
del adata.obs['barcodes']
del adata.obs['assay']
del adata.obs['location']
del adata.uns['location_colors']

# %%
# view obs

# %%
adata.obs
# Out:
#                       final_annotation lineage assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs            EFO:0009900
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs            EFO:0009900
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs            EFO:0009900
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs            EFO:0009900
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs            EFO:0009900
# ...                                ...     ...                    ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs            EFO:0009900
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs            EFO:0009900
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCCCAATT-1-0              unknown            cell      tissue
# AAACCTGAGGTGATTA-1-0              unknown            cell      tissue
# AAACCTGCATGGTTGT-1-0              unknown            cell      tissue
# AAACCTGGTACCGGCT-1-0              unknown            cell      tissue
# AAACCTGGTCGAGATG-1-0              unknown            cell      tissue
# ...                                   ...             ...         ...
# TTTATGCCAATGGATA-1-3              unknown            cell      tissue
# TTTATGCTCGTAGATC-1-3              unknown            cell      tissue
# TTTGCGCAGGCCCTCA-1-3              unknown            cell      tissue
# TTTGCGCAGGGTTTCT-1-3              unknown            cell      tissue
# TTTGGTTCACGGTAAG-1-3              unknown            cell      tissue
#
#                      tissue_ontology_term_id
# AAACCTGAGCCCAATT-1-0          UBERON:0002509
# AAACCTGAGGTGATTA-1-0          UBERON:0002509
# AAACCTGCATGGTTGT-1-0          UBERON:0002509
# AAACCTGGTACCGGCT-1-0          UBERON:0002509
# AAACCTGGTCGAGATG-1-0          UBERON:0002509
# ...                                      ...
# TTTATGCCAATGGATA-1-3          UBERON:0001238
# TTTATGCTCGTAGATC-1-3          UBERON:0001238
# TTTGCGCAGGCCCTCA-1-3          UBERON:0001238
# TTTGCGCAGGGTTTCT-1-3          UBERON:0001238
# TTTGGTTCACGGTAAG-1-3          UBERON:0001238
#
# [3912 rows x 14 columns]

# %%
# view var

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000025902                False
# ENSMUSG00000033845                False
# ENSMUSG00000025903                False
# ENSMUSG00000033813                False
# ENSMUSG00000002459                False
# ...                                 ...
# ENSMUSG00000094728                False
# ENSMUSG00000062783                False
# ENSMUSG00000096808                False
# ENSMUSG00000095742                False
# ENSMUSG00000095041                False
#
# [19283 rows x 12 columns]

# %%
araw.var
# Out:
#                       feature_types genome  n_cells
# gene_ids
# ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  Gene Expression   mm10        3
# ...                             ...    ...      ...
# ENSMUSG00000094728  Gene Expression   mm10       70
# ENSMUSG00000062783  Gene Expression   mm10       91
# ENSMUSG00000096808  Gene Expression   mm10        8
# ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  Gene Expression   mm10     4401
#
# [19283 rows x 3 columns]

# %%
#view uns

# %%
adata.uns
# Out:
# {'title': 'BCs-PCs', 'default_embedding': 'X_umap'}

# %%
list(adata.uns.keys())
# Out:
# ['title', 'default_embedding']

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
# Remove unwanted columns in uns

# %%
#check the format of expression matrix

# %%
adata.X
# Out:
# <3912x19283 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7902226 stored elements in Compressed Sparse Row format>

# %%
araw.X
# Out:
# <3912x19283 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7910284 stored elements in Compressed Sparse Row format>

# %%
#Copy raw counts to adata.raw

# %%
adata.raw = araw

# %%
obs_dtype = adata.obs.dtypes

# %%
obs_dtype
# Out:
# final_annotation                            category
# lineage                                     category
# assay_ontology_term_id                      category
# cell_type_ontology_term_id                  category
# development_stage_ontology_term_id          category
# donor_id                                    category
# disease_ontology_term_id                    category
# is_primary_data                                 bool
# organism_ontology_term_id                   category
# self_reported_ethnicity_ontology_term_id    category
# sex_ontology_term_id                        category
# suspension_type                             category
# tissue_type                                 category
# tissue_ontology_term_id                     category
# dtype: object

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000025902                False
# ENSMUSG00000033845                False
# ENSMUSG00000025903                False
# ENSMUSG00000033813                False
# ENSMUSG00000002459                False
# ...                                 ...
# ENSMUSG00000094728                False
# ENSMUSG00000062783                False
# ENSMUSG00000096808                False
# ENSMUSG00000095742                False
# ENSMUSG00000095041                False
#
# [19283 rows x 12 columns]

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/BCs-PCs_allgenes.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                       final_annotation lineage assay_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0  GC.BC_LZ-resting   B-PCs            EFO:0009900
# AAACCTGAGGTGATTA-1-0   PCs.CD19-IgM+.2   B-PCs            EFO:0009900
# AAACCTGCATGGTTGT-1-0     PCs.CD19+IgM+   B-PCs            EFO:0009900
# AAACCTGGTACCGGCT-1-0      Naive.Bcells   B-PCs            EFO:0009900
# AAACCTGGTCGAGATG-1-0        GC.BC_DZ.2   B-PCs            EFO:0009900
# ...                                ...     ...                    ...
# TTTATGCCAATGGATA-1-3          PCs.IgA+   B-PCs            EFO:0009900
# TTTATGCTCGTAGATC-1-3   PCs.CD19-IgM+.1   B-PCs            EFO:0009900
# TTTGCGCAGGCCCTCA-1-3          PCs.IgA+   B-PCs            EFO:0009900
# TTTGCGCAGGGTTTCT-1-3   PCs.CD19-IgM+.1   B-PCs            EFO:0009900
# TTTGGTTCACGGTAAG-1-3          PCs.IgA+   B-PCs            EFO:0009900
#
#                      cell_type_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                 CL:0000844
# AAACCTGAGGTGATTA-1-0                 CL:0000786
# AAACCTGCATGGTTGT-1-0                 CL:0000786
# AAACCTGGTACCGGCT-1-0                 CL:0000788
# AAACCTGGTCGAGATG-1-0                 CL:0000844
# ...                                         ...
# TTTATGCCAATGGATA-1-3                 CL:0000786
# TTTATGCTCGTAGATC-1-3                 CL:0000786
# TTTGCGCAGGCCCTCA-1-3                 CL:0000786
# TTTGCGCAGGGTTTCT-1-3                 CL:0000786
# TTTGGTTCACGGTAAG-1-3                 CL:0000786
#
#                      development_stage_ontology_term_id donor_id  \
# AAACCTGAGCCCAATT-1-0                     MmusDv:0000061   pooled
# AAACCTGAGGTGATTA-1-0                     MmusDv:0000061   pooled
# AAACCTGCATGGTTGT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTACCGGCT-1-0                     MmusDv:0000061   pooled
# AAACCTGGTCGAGATG-1-0                     MmusDv:0000061   pooled
# ...                                                 ...      ...
# TTTATGCCAATGGATA-1-3                     MmusDv:0000061   pooled
# TTTATGCTCGTAGATC-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGCCCTCA-1-3                     MmusDv:0000061   pooled
# TTTGCGCAGGGTTTCT-1-3                     MmusDv:0000061   pooled
# TTTGGTTCACGGTAAG-1-3                     MmusDv:0000061   pooled
#
#                      disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCCCAATT-1-0             PATO:0000461             True
# AAACCTGAGGTGATTA-1-0             PATO:0000461             True
# AAACCTGCATGGTTGT-1-0             PATO:0000461             True
# AAACCTGGTACCGGCT-1-0             PATO:0000461             True
# AAACCTGGTCGAGATG-1-0             PATO:0000461             True
# ...                                       ...              ...
# TTTATGCCAATGGATA-1-3             PATO:0000461             True
# TTTATGCTCGTAGATC-1-3             PATO:0000461             True
# TTTGCGCAGGCCCTCA-1-3             PATO:0000461             True
# TTTGCGCAGGGTTTCT-1-3             PATO:0000461             True
# TTTGGTTCACGGTAAG-1-3             PATO:0000461             True
#
#                      organism_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0           NCBITaxon:10090
# AAACCTGAGGTGATTA-1-0           NCBITaxon:10090
# AAACCTGCATGGTTGT-1-0           NCBITaxon:10090
# AAACCTGGTACCGGCT-1-0           NCBITaxon:10090
# AAACCTGGTCGAGATG-1-0           NCBITaxon:10090
# ...                                        ...
# TTTATGCCAATGGATA-1-3           NCBITaxon:10090
# TTTATGCTCGTAGATC-1-3           NCBITaxon:10090
# TTTGCGCAGGCCCTCA-1-3           NCBITaxon:10090
# TTTGCGCAGGGTTTCT-1-3           NCBITaxon:10090
# TTTGGTTCACGGTAAG-1-3           NCBITaxon:10090
#
#                      self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCCCAATT-1-0                                       na
# AAACCTGAGGTGATTA-1-0                                       na
# AAACCTGCATGGTTGT-1-0                                       na
# AAACCTGGTACCGGCT-1-0                                       na
# AAACCTGGTCGAGATG-1-0                                       na
# ...                                                       ...
# TTTATGCCAATGGATA-1-3                                       na
# TTTATGCTCGTAGATC-1-3                                       na
# TTTGCGCAGGCCCTCA-1-3                                       na
# TTTGCGCAGGGTTTCT-1-3                                       na
# TTTGGTTCACGGTAAG-1-3                                       na
#
#                      sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCCCAATT-1-0              unknown            cell      tissue
# AAACCTGAGGTGATTA-1-0              unknown            cell      tissue
# AAACCTGCATGGTTGT-1-0              unknown            cell      tissue
# AAACCTGGTACCGGCT-1-0              unknown            cell      tissue
# AAACCTGGTCGAGATG-1-0              unknown            cell      tissue
# ...                                   ...             ...         ...
# TTTATGCCAATGGATA-1-3              unknown            cell      tissue
# TTTATGCTCGTAGATC-1-3              unknown            cell      tissue
# TTTGCGCAGGCCCTCA-1-3              unknown            cell      tissue
# TTTGCGCAGGGTTTCT-1-3              unknown            cell      tissue
# TTTGGTTCACGGTAAG-1-3              unknown            cell      tissue
#
#                      tissue_ontology_term_id
# AAACCTGAGCCCAATT-1-0          UBERON:0002509
# AAACCTGAGGTGATTA-1-0          UBERON:0002509
# AAACCTGCATGGTTGT-1-0          UBERON:0002509
# AAACCTGGTACCGGCT-1-0          UBERON:0002509
# AAACCTGGTCGAGATG-1-0          UBERON:0002509
# ...                                      ...
# TTTATGCCAATGGATA-1-3          UBERON:0001238
# TTTATGCTCGTAGATC-1-3          UBERON:0001238
# TTTGCGCAGGCCCTCA-1-3          UBERON:0001238
# TTTGCGCAGGGTTTCT-1-3          UBERON:0001238
# TTTGGTTCACGGTAAG-1-3          UBERON:0001238
#
# [3912 rows x 14 columns]

# %%
adata.obs.columns
# Out:
# Index(['final_annotation', 'lineage', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata.raw.var
# Out:
#                       feature_types genome  n_cells
# gene_ids
# ENSMUSG00000025902  Gene Expression   mm10      221
# ENSMUSG00000033845  Gene Expression   mm10     3218
# ENSMUSG00000025903  Gene Expression   mm10     2460
# ENSMUSG00000033813  Gene Expression   mm10     6241
# ENSMUSG00000002459  Gene Expression   mm10        3
# ...                             ...    ...      ...
# ENSMUSG00000094728  Gene Expression   mm10       70
# ENSMUSG00000062783  Gene Expression   mm10       91
# ENSMUSG00000096808  Gene Expression   mm10        8
# ENSMUSG00000095742  Gene Expression   mm10     1400
# ENSMUSG00000095041  Gene Expression   mm10     4401
#
# [19283 rows x 3 columns]

# %%
adata.var
# Out:
#                        mt     rb  n_cells_by_counts  mean_counts  \
# gene_ids
# ENSMUSG00000025902  False  False                221     0.026731
# ENSMUSG00000033845  False  False               3218     0.297666
# ENSMUSG00000025903  False  False               2460     0.188250
# ENSMUSG00000033813  False  False               6241     0.829154
# ENSMUSG00000002459  False  False                  3     0.000174
# ...                   ...    ...                ...          ...
# ENSMUSG00000094728  False  False                 70     0.004056
# ENSMUSG00000062783  False  False                 91     0.005321
# ENSMUSG00000096808  False  False                  8     0.000464
# ENSMUSG00000095742  False  False               1400     0.095975
# ENSMUSG00000095041  False  False               4401     0.400457
#
#                     pct_dropout_by_counts  total_counts  n_cells  \
# gene_ids
# ENSMUSG00000025902              98.718025    460.818756      221
# ENSMUSG00000033845              81.333023   5131.465332     3218
# ENSMUSG00000025903              85.730034   3245.247803     2460
# ENSMUSG00000033813              63.797203  14293.792969     6241
# ENSMUSG00000002459              99.982597      2.995511        3
# ...                                   ...           ...      ...
# ENSMUSG00000094728              99.593941     69.925201       70
# ENSMUSG00000062783              99.472130     91.735985       91
# ENSMUSG00000096808              99.953590      8.000000        8
# ENSMUSG00000095742              91.878876   1654.511108     1400
# ENSMUSG00000095041              74.470680   6903.481445     4401
#
#                     highly_variable     means  dispersions  dispersions_norm  \
# gene_ids
# ENSMUSG00000025902             True  0.131385     2.748144          2.592534
# ENSMUSG00000033845            False  0.480022     1.226943         -0.471321
# ENSMUSG00000025903            False  0.353775     1.208837         -0.495850
# ENSMUSG00000033813            False  1.043117     1.383716         -0.455413
# ENSMUSG00000002459            False  0.000562     1.542446          0.282720
# ...                             ...       ...          ...               ...
# ENSMUSG00000094728            False  0.006127     0.903737         -0.940885
# ENSMUSG00000062783            False  0.011063     1.130046         -0.507334
# ENSMUSG00000096808            False  0.000741     1.017444         -0.723052
# ENSMUSG00000095742            False  0.240455     1.431409          0.070001
# ENSMUSG00000095041            False  0.789610     2.315884          0.485422
#
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000025902                False
# ENSMUSG00000033845                False
# ENSMUSG00000025903                False
# ENSMUSG00000033813                False
# ENSMUSG00000002459                False
# ...                                 ...
# ENSMUSG00000094728                False
# ENSMUSG00000062783                False
# ENSMUSG00000096808                False
# ENSMUSG00000095742                False
# ENSMUSG00000095041                False
#
# [19283 rows x 12 columns]

# %%
adata.raw.X
# Out:
# <3912x19283 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7910284 stored elements in Compressed Sparse Row format>

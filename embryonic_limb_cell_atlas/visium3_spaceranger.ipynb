# %% [markdown]
# ### **Curating visium_slide3.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9383361/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 1

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 10

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2408215 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 784)	1.0
#   (0, 1533)	1.0
#   (0, 1546)	1.0
#   (0, 1600)	1.0
#   (0, 2679)	1.0
#   (0, 3689)	1.0
#   (0, 3957)	1.0
#   (0, 4999)	1.0
#   (0, 5788)	1.0
#   (0, 6427)	1.0
#   (0, 6677)	1.0
#   (0, 7946)	1.0
#   (0, 8234)	1.0
#   (0, 10898)	1.0
#   (0, 11268)	1.0
#   (0, 11636)	1.0
#   (0, 11696)	1.0
#   (0, 11907)	1.0
#   (0, 12588)	1.0
#   (0, 14102)	1.0
#   (0, 14617)	1.0
#   (0, 14818)	1.0
#   (0, 16216)	1.0
#   (0, 16671)	1.0
#   (0, 17062)	1.0
#   :	:
#   (4991, 27819)	1.0
#   (4991, 28019)	2.0
#   (4991, 28079)	1.0
#   (4991, 28330)	1.0
#   (4991, 28371)	1.0
#   (4991, 28546)	1.0
#   (4991, 28836)	1.0
#   (4991, 29709)	1.0
#   (4991, 29944)	1.0
#   (4991, 29969)	1.0
#   (4991, 30261)	1.0
#   (4991, 30367)	1.0
#   (4991, 30420)	1.0
#   (4991, 30905)	1.0
#   (4991, 30931)	1.0
#   (4991, 31093)	1.0
#   (4991, 31426)	1.0
#   (4991, 31764)	1.0
#   (4991, 32176)	1.0
#   (4991, 32824)	1.0
#   (4991, 32858)	1.0
#   (4991, 32925)	1.0
#   (4991, 33661)	1.0
#   (4991, 33662)	1.0
#   (4991, 33664)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16               42
# AAACAAGTATCTCCCA-1          0         50        102              422
# AAACAATCTACTAGCA-1          0          3         43              169
# AAACACCAATAACTGC-1          1         59         19             2631
# AAACAGAGCGACTCCT-1          1         14         94             1406
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42              139
# TTGTTTCATTAGTCTA-1          0         60         30              401
# TTGTTTCCATACAACT-1          1         45         27              781
# TTGTTTGTATTACACG-1          0         73         41               89
# TTGTTTGTGTAAATTC-1          0          7         51              116
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide3.h5ad')

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361          1           0.0        0.004771
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361          1           0.0        0.074960
# AAACAGGGTCTATATT-1_WSSS_THYst9383361          1           0.0        0.001149
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361          1           0.0        0.007740
# AAACCACTACACAGAT-1_WSSS_THYst9383361          1           0.0        3.930484
# ...                                         ...           ...             ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361          1           0.0        0.002404
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361          1           0.0        0.082030
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361          1           0.0        0.008589
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361          1           0.0        0.011993
# TTGTTTCCATACAACT-1_WSSS_THYst9383361          1           0.0        0.010601
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361        8.939075           0.018417
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361        0.013104           0.875842
# AAACAGGGTCTATATT-1_WSSS_THYst9383361        3.377904           0.000305
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361        0.001895           0.046881
# AAACCACTACACAGAT-1_WSSS_THYst9383361        0.026443           0.005691
# ...                                              ...                ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361        0.001359           0.018174
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361        0.432514           0.047619
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361        0.000885           0.065257
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361        0.001719           0.018959
# TTGTTTCCATACAACT-1_WSSS_THYst9383361        0.900175           0.034601
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361       0.043178  0.012007    6.439445
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361       0.187521  0.020274    0.010129
# AAACAGGGTCTATATT-1_WSSS_THYst9383361       0.018242  0.002670    3.370343
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361       0.035667  0.017059    0.002443
# AAACCACTACACAGAT-1_WSSS_THYst9383361       0.005660  0.009832    0.016753
# ...                                             ...       ...         ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361       0.142212  0.001466    0.001845
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361       0.216695  0.031715    0.367731
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361       0.008913  0.001003    0.000725
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361       1.410804  0.005675    0.001983
# TTGTTTCCATACAACT-1_WSSS_THYst9383361       0.042695  0.007086    0.461330
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361      0.024502          0.037832  ...
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361      0.022626          0.049650  ...
# AAACAGGGTCTATATT-1_WSSS_THYst9383361      0.003946          0.007577  ...
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361      0.005897          0.029290  ...
# AAACCACTACACAGAT-1_WSSS_THYst9383361      0.015550          0.015419  ...
# ...                                            ...               ...  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361      0.001415          0.008390  ...
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361      0.036196          0.057114  ...
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361      0.001475          0.003507  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361      0.006494          0.022389  ...
# TTGTTTCCATACAACT-1_WSSS_THYst9383361      0.003592          0.016666  ...
#
#                                        stage  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361  PCW8.1
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361  PCW8.1
# AAACAGGGTCTATATT-1_WSSS_THYst9383361  PCW8.1
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361  PCW8.1
# AAACCACTACACAGAT-1_WSSS_THYst9383361  PCW8.1
# ...                                      ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361  PCW8.1
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361  PCW8.1
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361  PCW8.1
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361  PCW8.1
# TTGTTTCCATACAACT-1_WSSS_THYst9383361  PCW8.1
#
#                                       development_stage_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACAGGGTCTATATT-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACCACTACACAGAT-1_WSSS_THYst9383361                      HsapDv:0000030
# ...                                                                  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTTCCATACAACT-1_WSSS_THYst9383361                      HsapDv:0000030
#
#                                       disease_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361              PATO:0000461
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361              PATO:0000461
# AAACAGGGTCTATATT-1_WSSS_THYst9383361              PATO:0000461
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361              PATO:0000461
# AAACCACTACACAGAT-1_WSSS_THYst9383361              PATO:0000461
# ...                                                        ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361              PATO:0000461
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361              PATO:0000461
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361              PATO:0000461
# TTGTTTCCATACAACT-1_WSSS_THYst9383361              PATO:0000461
#
#                                       is_primary_data  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361             True
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361             True
# AAACAGGGTCTATATT-1_WSSS_THYst9383361             True
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361             True
# AAACCACTACACAGAT-1_WSSS_THYst9383361             True
# ...                                               ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361             True
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361             True
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361             True
# TTGTTTCCATACAACT-1_WSSS_THYst9383361             True
#
#                                       organism_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACAGGGTCTATATT-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACCACTACACAGAT-1_WSSS_THYst9383361             NCBITaxon:9606
# ...                                                         ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTTCCATACAACT-1_WSSS_THYst9383361             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361                                   unknown
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361                                   unknown
# AAACAGGGTCTATATT-1_WSSS_THYst9383361                                   unknown
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361                                   unknown
# AAACCACTACACAGAT-1_WSSS_THYst9383361                                   unknown
# ...                                                                        ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361                                   unknown
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361                                   unknown
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361                                   unknown
# TTGTTTCCATACAACT-1_WSSS_THYst9383361                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361          PATO:0000384               na
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361          PATO:0000384               na
# AAACAGGGTCTATATT-1_WSSS_THYst9383361          PATO:0000384               na
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361          PATO:0000384               na
# AAACCACTACACAGAT-1_WSSS_THYst9383361          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTTCCATACAACT-1_WSSS_THYst9383361          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id
# AAACACCAATAACTGC-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACAGGGTCTATATT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACCACTACACAGAT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTTCCATACAACT-1_WSSS_THYst9383361       tissue           UBERON:0000978
#
# [1889 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361          1           0.0        0.004771
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361          1           0.0        0.074960
# AAACAGGGTCTATATT-1_WSSS_THYst9383361          1           0.0        0.001149
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361          1           0.0        0.007740
# AAACCACTACACAGAT-1_WSSS_THYst9383361          1           0.0        3.930484
# ...                                         ...           ...             ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361          1           0.0        0.002404
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361          1           0.0        0.082030
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361          1           0.0        0.008589
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361          1           0.0        0.011993
# TTGTTTCCATACAACT-1_WSSS_THYst9383361          1           0.0        0.010601
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361        8.939075           0.018417
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361        0.013104           0.875842
# AAACAGGGTCTATATT-1_WSSS_THYst9383361        3.377904           0.000305
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361        0.001895           0.046881
# AAACCACTACACAGAT-1_WSSS_THYst9383361        0.026443           0.005691
# ...                                              ...                ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361        0.001359           0.018174
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361        0.432514           0.047619
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361        0.000885           0.065257
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361        0.001719           0.018959
# TTGTTTCCATACAACT-1_WSSS_THYst9383361        0.900175           0.034601
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361       0.043178  0.012007    6.439445
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361       0.187521  0.020274    0.010129
# AAACAGGGTCTATATT-1_WSSS_THYst9383361       0.018242  0.002670    3.370343
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361       0.035667  0.017059    0.002443
# AAACCACTACACAGAT-1_WSSS_THYst9383361       0.005660  0.009832    0.016753
# ...                                             ...       ...         ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361       0.142212  0.001466    0.001845
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361       0.216695  0.031715    0.367731
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361       0.008913  0.001003    0.000725
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361       1.410804  0.005675    0.001983
# TTGTTTCCATACAACT-1_WSSS_THYst9383361       0.042695  0.007086    0.461330
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361      0.024502          0.037832  ...
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361      0.022626          0.049650  ...
# AAACAGGGTCTATATT-1_WSSS_THYst9383361      0.003946          0.007577  ...
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361      0.005897          0.029290  ...
# AAACCACTACACAGAT-1_WSSS_THYst9383361      0.015550          0.015419  ...
# ...                                            ...               ...  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361      0.001415          0.008390  ...
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361      0.036196          0.057114  ...
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361      0.001475          0.003507  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361      0.006494          0.022389  ...
# TTGTTTCCATACAACT-1_WSSS_THYst9383361      0.003592          0.016666  ...
#
#                                       development_stage_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACAGGGTCTATATT-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361                      HsapDv:0000030
# AAACCACTACACAGAT-1_WSSS_THYst9383361                      HsapDv:0000030
# ...                                                                  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361                      HsapDv:0000030
# TTGTTTCCATACAACT-1_WSSS_THYst9383361                      HsapDv:0000030
#
#                                       disease_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361              PATO:0000461
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361              PATO:0000461
# AAACAGGGTCTATATT-1_WSSS_THYst9383361              PATO:0000461
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361              PATO:0000461
# AAACCACTACACAGAT-1_WSSS_THYst9383361              PATO:0000461
# ...                                                        ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361              PATO:0000461
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361              PATO:0000461
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361              PATO:0000461
# TTGTTTCCATACAACT-1_WSSS_THYst9383361              PATO:0000461
#
#                                       is_primary_data  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361             True
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361             True
# AAACAGGGTCTATATT-1_WSSS_THYst9383361             True
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361             True
# AAACCACTACACAGAT-1_WSSS_THYst9383361             True
# ...                                               ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361             True
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361             True
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361             True
# TTGTTTCCATACAACT-1_WSSS_THYst9383361             True
#
#                                       organism_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACAGGGTCTATATT-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361             NCBITaxon:9606
# AAACCACTACACAGAT-1_WSSS_THYst9383361             NCBITaxon:9606
# ...                                                         ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361             NCBITaxon:9606
# TTGTTTCCATACAACT-1_WSSS_THYst9383361             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361                                   unknown
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361                                   unknown
# AAACAGGGTCTATATT-1_WSSS_THYst9383361                                   unknown
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361                                   unknown
# AAACCACTACACAGAT-1_WSSS_THYst9383361                                   unknown
# ...                                                                        ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361                                   unknown
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361                                   unknown
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361                                   unknown
# TTGTTTCCATACAACT-1_WSSS_THYst9383361                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361          PATO:0000384               na
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361          PATO:0000384               na
# AAACAGGGTCTATATT-1_WSSS_THYst9383361          PATO:0000384               na
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361          PATO:0000384               na
# AAACCACTACACAGAT-1_WSSS_THYst9383361          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361          PATO:0000384               na
# TTGTTTCCATACAACT-1_WSSS_THYst9383361          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id  \
# AAACACCAATAACTGC-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACAGGGTCTATATT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# AAACCACTACACAGAT-1_WSSS_THYst9383361       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361       tissue           UBERON:0000978
# TTGTTTCCATACAACT-1_WSSS_THYst9383361       tissue           UBERON:0000978
#
#                                               barcodes
# AAACACCAATAACTGC-1_WSSS_THYst9383361  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1_WSSS_THYst9383361  AAACAGAGCGACTCCT
# AAACAGGGTCTATATT-1_WSSS_THYst9383361  AAACAGGGTCTATATT
# AAACATGGTGAGAGGA-1_WSSS_THYst9383361  AAACATGGTGAGAGGA
# AAACCACTACACAGAT-1_WSSS_THYst9383361  AAACCACTACACAGAT
# ...                                                ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9383361  TTGTGTATGCCACCAA
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9383361  TTGTGTTTCCCGAAAG
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9383361  TTGTTCAGTGTGCTAC
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383361  TTGTTGTGTGTCAAGA
# TTGTTTCCATACAACT-1_WSSS_THYst9383361  TTGTTTCCATACAACT
#
# [1889 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACACCAATAACTGC': 'CL:0002551',
#  'AAACAGAGCGACTCCT': 'CL:0000057',
#  'AAACAGGGTCTATATT': 'CL:0002551',
#  'AAACATGGTGAGAGGA': 'CL:0000138',
#  'AAACCACTACACAGAT': 'CL:0000187',
#  'AAACCGGGTAGGTACC': 'CL:0008019',
#  'AAACCGTTCGTCCAGG': 'CL:0000138',
#  'AAACGACAGTCTTGCC': 'CL:0000187',
#  'AAACGAGACGGTTGAT': 'CL:0000388',
#  'AAACGCCCGAGATCGG': 'CL:0000187',
#  'AAACGTGTTCGCCCTA': 'CL:0000388',
#  'AAACTAACGTGGCGAC': 'CL:0000187',
#  'AAACTGCTGGCTCCAA': 'CL:0000057',
#  'AAACTTGCAAACGTAT': 'CL:0002551',
#  'AAAGACATGAAGTTTA': 'CL:0000743',
#  'AAAGGGATGTAGCAAG': 'CL:0000388',
#  'AAAGGTAAGCTGTACC': 'CL:0000187',
#  'AAAGGTCAACGACATG': 'CL:0000192',
#  'AAAGTAGCATTGCTCA': 'CL:0000138',
#  'AAAGTGTGATTTATCT': 'CL:0002551',
#  'AAAGTTGACTCCCGTA': 'CL:0002551',
#  'AAATAACCATACGGGA': 'CL:0002551',
#  'AAATACCTATAAGCAT': 'CL:0002551',
#  'AAATCACTCCTAAACG': 'CL:0000187',
#  'AAATCGTGTACCACAA': 'CL:0000138',
#  'AAATGGCCCGTGCCCT': 'CL:0002551',
#  'AAATGGTCAATGTGCC': 'CL:0002551',
#  'AAATTAACGGGTAGCT': 'CL:0000057',
#  'AAATTACACGACTCTG': 'CL:0000388',
#  'AAATTACCTATCGATG': 'CL:0002551',
#  'AAATTGATAGTCCTTT': 'CL:0002551',
#  'AAATTGGTGAGAAGCA': 'CL:0002551',
#  'AAATTTACCGAAATCC': 'CL:0000057',
#  'AAATTTGCGGGTGTGG': 'CL:0000138',
#  'AACAACTGGTAGTTGC': 'CL:0000057',
#  'AACACGAGACGCGGCC': 'CL:0000558',
#  'AACATATCAACTGGTG': 'CL:0002551',
#  'AACATCGATACGTCTA': 'CL:0002551',
#  'AACCAAGACTTCTCTG': 'CL:0002551',
#  'AACCAGTATCACTCTT': 'CL:0002551',
#  'AACCCATCCCATGATC': 'CL:0008019',
#  'AACCCGATAGGGCTTC': 'CL:0002551',
#  'AACCCTACTGTCAATA': 'CL:0002551',
#  'AACCGAGCTTGGTCAT': 'CL:0002551',
#  'AACCTAAAGCCGTCCG': 'CL:0002551',
#  'AACCTTTAAATACGGT': 'CL:0002551',
#  'AACCTTTACGACGTCT': 'CL:0002551',
#  'AACGATAATGCCGTAG': 'CL:0002551',
#  'AACGATATGTCAACTG': 'CL:0000138',
#  'AACGCGGTCTCCAGCC': 'CL:0002551',
#  'AACGGCCATCTCCGGT': 'CL:0000138',
#  'AACGTACTGTGGGTAC': 'CL:0000057',
#  'AACGTGATGAAGGACA': 'CL:0000388',
#  'AACGTGCGAAAGTCTC': 'CL:0000388',
#  'AACTCAAGTTAATTGC': 'CL:0000057',
#  'AACTCCTAATCCCATG': 'CL:0000388',
#  'AACTCTCAATAGAGCG': 'CL:0002551',
#  'AACTCTCAGTGTGCTC': 'CL:0002551',
#  'AACTGAGGTCAGCGTC': 'CL:0000187',
#  'AACTGGGTCCCGACGT': 'CL:0002551',
#  'AACTGGGTTCGAGCCG': 'CL:0000669',
#  'AACTTTCTCGATCATG': 'CL:0002551',
#  'AAGAAATCACCAGATT': 'CL:0002551',
#  'AAGACTCACGCCCACT': 'CL:0000057',
#  'AAGACTGCAAGCTACT': 'CL:0000138',
#  'AAGAGCTCTTTATCGG': 'CL:0000388',
#  'AAGAGGATGTACGCGA': 'CL:0000558',
#  'AAGAGGCATGGATCGC': 'CL:0000057',
#  'AAGATTGGCGGAACGT': 'CL:0000388',
#  'AAGCATACTCTCCTGA': 'CL:0002551',
#  'AAGCCGCTTTACCTTG': 'CL:0002551',
#  'AAGCGGAGTGCGCGCA': 'CL:0000558',
#  'AAGCGGCGTCATGGGT': 'CL:0000187',
#  'AAGCGTCCCTCATCGA': 'CL:0002551',
#  'AAGCTAGATCGAGTAA': 'CL:0002551',
#  'AAGCTCGTGCCAAGTC': 'CL:0000388',
#  'AAGGAGCGGTTGGTGC': 'CL:0002551',
#  'AAGGATGAGGGACCTC': 'CL:0000388',
#  'AAGGCTGTGCTCATCG': 'CL:0000388',
#  'AAGGGACAGATTCTGT': 'CL:0002551',
#  'AAGGTATCCTAATATA': 'CL:0002551',
#  'AAGGTGATAAACCAGC': 'CL:0002551',
#  'AAGTCTAGTAGCTGCC': 'CL:0002551',
#  'AAGTGACGACCGAATT': 'CL:0002551',
#  'AAGTGCCTTGACTGTA': 'CL:0002551',
#  'AAGTGCGTTAGAATCT': 'CL:0000138',
#  'AAGTTCGGCCAACAGG': 'CL:0000057',
#  'AATAACAACGCTCGGC': 'CL:0002551',
#  'AATAACACTAGAACAA': 'CL:0002551',
#  'AATAGAACAGAGTGGC': 'CL:0002551',
#  'AATAGCAAGCCTCCTG': 'CL:0008019',
#  'AATAGCTACCGCGTGC': 'CL:0002551',
#  'AATATCGAGGGTTCTC': 'CL:0000078',
#  'AATCGCCTCAGCGCCA': 'CL:0000057',
#  'AATCTAGGTTTACTTG': 'CL:0002551',
#  'AATCTGCGTTGGGACG': 'CL:0000388',
#  'AATCTGGCTTTCTAGT': 'CL:0002551',
#  'AATCTGGGTAGACCCT': 'CL:0000187',
#  'AATGACAGCAATGTCT': 'CL:0000138',
#  'AATGACGTAGGATGTC': 'CL:0002551',
#  'AATGACTGTCAGCCGG': 'CL:0002551',
#  'AATGATGATACGCTAT': 'CL:0000057',
#  'AATGCAACCGGGTACC': 'CL:0000187',
#  'AATGGCCGCCAATGCG': 'CL:0002551',
#  'AATGTGCCCGAGGTGT': 'CL:0002551',
#  'AATTAAAGGTCGGCGT': 'CL:0000138',
#  'AATTAGCGCTGCAGCG': 'CL:0002551',
#  'AATTCATAAGGGATCT': 'CL:0000388',
#  'AATTCTAGAGTTAGGC': 'CL:0000057',
#  'AATTGAACGCTCTGGT': 'CL:0002551',
#  'AATTTGGGACATAGTA': 'CL:0000388',
#  'ACAAACCGACAAGGCG': 'CL:0000187',
#  'ACAAATGGTAGTGTTT': 'CL:0002551',
#  'ACAAATTCAGATCTGA': 'CL:0000187',
#  'ACAACAGCATGAGCTA': 'CL:0000388',
#  'ACAAGGAAATCCGCCC': 'CL:0002551',
#  'ACAAGGCCTACCAGCC': 'CL:0000187',
#  'ACAAGGGCAGGCTCTG': 'CL:0000057',
#  'ACAATCCATTTAAACC': 'CL:0002551',
#  'ACAATGAATACGGAGA': 'CL:0002551',
#  'ACAATGATTCTTCTAC': 'CL:0000187',
#  'ACAATTTGAGCAGTGG': 'CL:0000388',
#  'ACACAAAGACGGGTGG': 'CL:0000187',
#  'ACACAAATATTCCTAG': 'CL:0002551',
#  'ACACACCAGGACCAGT': 'CL:0002551',
#  'ACACATGATCAAATCT': 'CL:0002551',
#  'ACACCCAGCATGCAGC': 'CL:0000057',
#  'ACACCCGTAAATCTGT': 'CL:0002551',
#  'ACACCTTAAGTAGGGC': 'CL:0002551',
#  'ACACGAGACTCCTTCT': 'CL:0000388',
#  'ACACGGCACTATGCAT': 'CL:0000388',
#  'ACACGGGAACTTAGGG': 'CL:0000388',
#  'ACACTGATCAAGGTGT': 'CL:0002551',
#  'ACAGAACTGAGAACAA': 'CL:0000388',
#  'ACAGCGCACCCGCAGC': 'CL:0002551',
#  'ACAGGTGGAGGTGAGG': 'CL:0000057',
#  'ACAGTAATACAACTTG': 'CL:0002551',
#  'ACAGTATACCGTGGGA': 'CL:0000388',
#  'ACAGTGCAGCGCATTT': 'CL:0000187',
#  'ACATAATAAGGCGGTG': 'CL:0002551',
#  'ACATCGATCGTTTACC': 'CL:0000388',
#  'ACATCGGTCAGCCGCG': 'CL:0000057',
#  'ACATCGTATGCAATGG': 'CL:0002551',
#  'ACATCGTTAACCTAGT': 'CL:0000187',
#  'ACATCTCAACGCGTAA': 'CL:0002551',
#  'ACATTAGTTTATATCC': 'CL:0002551',
#  'ACCAAACACCCAGCGA': 'CL:0000388',
#  'ACCAACGCTTATTTAT': 'CL:0000057',
#  'ACCACAACTCAGAACA': 'CL:0000558',
#  'ACCACAAGTTTCTATC': 'CL:0000388',
#  'ACCACCCTCTCTTCTA': 'CL:0002551',
#  'ACCACGTGCAGCTATA': 'CL:0002551',
#  'ACCAGTGCCCGGTCAA': 'CL:0000187',
#  'ACCATATCCGCAATAA': 'CL:0000138',
#  'ACCATCCGCCAACTAG': 'CL:0002551',
#  'ACCATCGTATATGGTA': 'CL:0000057',
#  'ACCCAACGCCCGTGGC': 'CL:0000388',
#  'ACCCATCTTGAGGGTA': 'CL:0002551',
#  'ACCCGGATGACGCATC': 'CL:0002551',
#  'ACCCGGTTACACTTCC': 'CL:0000138',
#  'ACCCTATGCCATATCG': 'CL:0002551',
#  'ACCCTCCCTTGCTATT': 'CL:0000646',
#  'ACCCTGGTAACGCCCT': 'CL:0002551',
#  'ACCCTTGCCTGGGTCG': 'CL:0000388',
#  'ACCCTTTAGTTCTCCA': 'CL:0002551',
#  'ACCGAAGAGTCTGGTT': 'CL:0008019',
#  'ACCGACTGAGTCCCAC': 'CL:0002551',
#  'ACCGAGTCTCCTTATT': 'CL:0000138',
#  'ACCGATGGTAGCATCG': 'CL:0002551',
#  'ACCGCAATAACTGCCT': 'CL:0000078',
#  'ACCGCGGTGGAAGTCG': 'CL:0002551',
#  'ACCGGTCAGGTACACC': 'CL:0002551',
#  'ACCGGTCTGAGTACGG': 'CL:0002551',
#  'ACCTAAGTACCTTTCA': 'CL:1001607',
#  'ACCTGCGTGTCATGTT': 'CL:0002551',
#  'ACGAGATATTTGCTTA': 'CL:0002551',
#  'ACGAGGATACCACTCT': 'CL:0002551',
#  'ACGAGGTTTACAACGT': 'CL:0008019',
#  'ACGATACATAGAACTA': 'CL:0002551',
#  'ACGATCATACATAGAG': 'CL:0002551',
#  'ACGATCATCTTGTAAA': 'CL:0002551',
#  'ACGATGCATATGTTAT': 'CL:0002551',
#  'ACGCATAAATGACATG': 'CL:0000187',
#  'ACGCATTCGTGAGTAC': 'CL:0000057',
#  'ACGCCAGATGATTTCT': 'CL:0002551',
#  'ACGCCGCTAGACGACC': 'CL:0000057',
#  'ACGCGAAGTCAGACGA': 'CL:0002551',
#  'ACGCGCTACACAGGGT': 'CL:0002551',
#  'ACGCGGGCCAAGGACA': 'CL:0000388',
#  'ACGCTAGTATCAGTGC': 'CL:0000388',
#  'ACGCTAGTGATACACT': 'CL:0002551',
#  'ACGCTTAGTGTCTCTC': 'CL:0002551',
#  'ACGGAGCGCAAATTAC': 'CL:0000078',
#  'ACGGCACTTGCTTGGG': 'CL:0002551',
#  'ACGGCGACGATGGGAA': 'CL:0002551',
#  'ACGGGAGTGTCGGCCC': 'CL:0002551',
#  'ACGTAGATTGCTGATG': 'CL:0000388',
#  'ACGTATTACTCCGATC': 'CL:0002551',
#  'ACGTGGTCGAATGTGC': 'CL:0002551',
#  'ACGTTAATGTCGAAGA': 'CL:0000057',
#  'ACGTTAGATTTGCCCG': 'CL:0002551',
#  'ACTAAGGACGCACACC': 'CL:0000558',
#  'ACTAATACGTCAGGCG': 'CL:0000187',
#  'ACTACCAGCTCTCTGG': 'CL:0002551',
#  'ACTATATGCTGTGTTC': 'CL:0000057',
#  'ACTATTCGTCCGTGGT': 'CL:0002551',
#  'ACTCAATAAAGGCACG': 'CL:0000057',
#  'ACTCCCATTCCTAAAG': 'CL:0002551',
#  'ACTCCCGAATTCGTTT': 'CL:0002551',
#  'ACTCCCGTAGACTAGG': 'CL:0002551',
#  'ACTCCCTAGAATAGTA': 'CL:0000057',
#  'ACTCGTAACCCGTCCT': 'CL:0002551',
#  'ACTCGTCAGTAATCCC': 'CL:0000057',
#  'ACTCTCTGACTTAGGT': 'CL:0000057',
#  'ACTCTCTTATACACGA': 'CL:0000388',
#  'ACTCTTGTATAGTAAC': 'CL:0000388',
#  'ACTGAATGGCGAAAGT': 'CL:0002551',
#  'ACTGATTTAGTGATTC': 'CL:0000078',
#  'ACTGCTCGGAAGGATG': 'CL:0000646',
#  'ACTGGCGAACCTGCGT': 'CL:0002551',
#  'ACTGTACGATACACAT': 'CL:0000388',
#  'ACTGTAGCACTTTGGA': 'CL:0000078',
#  'ACTGTCCAGGATTATA': 'CL:0000138',
#  'ACTGTCTTCTTTAGAA': 'CL:0002551',
#  'ACTTACCGGGCGCGCA': 'CL:0000057',
#  'ACTTATACTTACCCGG': 'CL:0002551',
#  'ACTTATTAGGATCGGT': 'CL:0000138',
#  'ACTTCCTGTCGTGCGA': 'CL:0000187',
#  'ACTTCGCCATACGCAC': 'CL:0000138',
#  'ACTTGACTCCCTCTTT': 'CL:0000057',
#  'ACTTGGGACCCGGTGG': 'CL:0000388',
#  'ACTTTACCCTCATGAA': 'CL:0002551',
#  'ACTTTCCTATAGCTTC': 'CL:0002551',
#  'AGAACGTGGTACATTC': 'CL:0000388',
#  'AGAAGAGCGCCGTTCC': 'CL:0000138',
#  'AGAAGGTACACTTCAC': 'CL:0002551',
#  'AGAAGGTTGCCGAATT': 'CL:0000388',
#  'AGAAGTGATTCGTGAT': 'CL:1001607',
#  'AGAATGCGGGTTCGGA': 'CL:0000388',
#  'AGAATTATGGATTCGA': 'CL:0002551',
#  'AGACCCACCGCTGATC': 'CL:0002551',
#  'AGACCCGCCCTCCTCG': 'CL:0000388',
#  'AGACGACGATGCCGCT': 'CL:0002551',
#  'AGACGGGATTGGTATA': 'CL:0002551',
#  'AGACGGGCCGATTTAA': 'CL:0000187',
#  'AGACTAGCCTTCCAGA': 'CL:0000388',
#  'AGAGAACCGTCTAGGA': 'CL:0000388',
#  'AGAGAAGGAGTACAAT': 'CL:0002551',
#  'AGAGCGCTTGTAACGG': 'CL:0000388',
#  'AGAGGGACAATTGTCC': 'CL:0002551',
#  'AGAGTGAACAGACACC': 'CL:0002551',
#  'AGAGTTAGAGACCGAT': 'CL:0000057',
#  'AGAGTTGCAGGCCTCC': 'CL:0002551',
#  'AGATAACTTCAGGGCC': 'CL:0000057',
#  'AGATACCAGCACTTCA': 'CL:0000388',
#  'AGATACCGGTGTTCAC': 'CL:0002551',
#  'AGATACTCAAGATCGA': 'CL:0002551',
#  'AGATCTCAGGTGTGAT': 'CL:0000138',
#  'AGATGACTCGCCCACG': 'CL:0002551',
#  'AGATGAGGGTTGCGAT': 'CL:0000057',
#  'AGATTATAGGACGTTT': 'CL:0000057',
#  'AGATTCAAGCGGGTCG': 'CL:0000187',
#  'AGATTCACAACCGATA': 'CL:0002551',
#  'AGCAACATATCTTATT': 'CL:0002551',
#  'AGCAACCGAAAGTAAT': 'CL:0000078',
#  'AGCACCAGTACTCACG': 'CL:0002551',
#  'AGCAGCCAGATGAATA': 'CL:0000138',
#  'AGCATCATTTCGAAAG': 'CL:0000138',
#  'AGCATCGTCGATAATT': 'CL:0000388',
#  'AGCCACTCCCGTGCTT': 'CL:0002551',
#  'AGCCCATACATGTAAG': 'CL:0008019',
#  'AGCCGTGGCTAAATGT': 'CL:0000138',
#  'AGCCTAATACCCACGT': 'CL:0002551',
#  'AGCGACAGGAACGGTC': 'CL:0000388',
#  'AGCGACCAACGATATT': 'CL:0000388',
#  'AGCGCGGGTGCCAATG': 'CL:0002551',
#  'AGCGCTTATGGGCAAG': 'CL:0002551',
#  'AGCGGTTGAGATGTAC': 'CL:0000235',
#  'AGCGGTTGCCGCTCTG': 'CL:0002551',
#  'AGCGTGGTATTCTACT': 'CL:0000057',
#  'AGCGTTCCGATTTAAA': 'CL:1000413',
#  'AGCTATTTAATCCAAC': 'CL:0000078',
#  'AGCTCGTTGATGGAAA': 'CL:0002551',
#  'AGCTCTAGACGTTCCA': 'CL:0000057',
#  'AGCTCTTCCCAGTGCA': 'CL:0000388',
#  'AGCTCTTTACTCAGTT': 'CL:0000138',
#  'AGCTGAAGTAAACCAA': 'CL:0002551',
#  'AGCTGCATTTGAGGTG': 'CL:0000187',
#  'AGCTGCTGTGCCGAAT': 'CL:0000187',
#  'AGCTGTAACCTCAATC': 'CL:0002551',
#  'AGCTTCAATACTTTGA': 'CL:0002551',
#  'AGCTTGATCTTAACTT': 'CL:0000078',
#  'AGGACAGTCGAATCCC': 'CL:0002551',
#  'AGGACGACCCATTAGA': 'CL:0000388',
#  'AGGATAAAGTCGGGAT': 'CL:0002551',
#  'AGGATCACGCGATCTG': 'CL:0002551',
#  'AGGCAGATGCGTAAAC': 'CL:0000388',
#  'AGGCCACCCGTTATGA': 'CL:0000138',
#  'AGGCCCTAGAACGCCA': 'CL:0000558',
#  'AGGCGGTTTGTCCCGC': 'CL:0002551',
#  'AGGCGTCTATGGACGG': 'CL:0000388',
#  'AGGCTTCCCGAAGAAG': 'CL:0000388',
#  'AGGGAAACGAGGTACT': 'CL:0002551',
#  'AGGGCAGCGGCGTGGT': 'CL:0000138',
#  'AGGGCGAGCAGCTGAT': 'CL:0000669',
#  'AGGGCTGCAGTTACAG': 'CL:0000138',
#  'AGGGTCAGTAACCCTA': 'CL:0002551',
#  'AGGGTCGATGCGAACT': 'CL:0002551',
#  'AGGGTGCTCTCGAGGG': 'CL:0002551',
#  'AGGGTGTGCTACACGC': 'CL:0000187',
#  'AGGGTTCCCTTTGGTT': 'CL:0000388',
#  'AGGGTTTAGTTCGGGA': 'CL:0000057',
#  'AGGTACGATATTGCCA': 'CL:0000078',
#  'AGGTAGGTACAAAGCT': 'CL:0000078',
#  'AGGTCAGGTGAGAGTG': 'CL:0000558',
#  'AGGTTGAGGCACGCTT': 'CL:0000057',
#  'AGGTTTCACACACCTT': 'CL:0000057',
#  'AGTAACGTTCATCCTG': 'CL:0000743',
#  'AGTACCTTCGAGTGCT': 'CL:0000187',
#  'AGTACGGGCACCTGGC': 'CL:0002551',
#  'AGTACGTGGCCTGTCT': 'CL:0000388',
#  'AGTAGCTAGACGCCGA': 'CL:0000187',
#  'AGTAGGAAGGAAGTTG': 'CL:0002551',
#  'AGTCAACACCACCATC': 'CL:0000138',
#  'AGTCCCGCCTTTAATT': 'CL:0000057',
#  'AGTCCCTCGCAGAAAG': 'CL:0002551',
#  'AGTCGACGGTCTCAAG': 'CL:0000057',
#  'AGTCGGCTCAACTTTA': 'CL:0000558',
#  'AGTCGTGGGCATTACG': 'CL:0000138',
#  'AGTCTCACAAGACTAC': 'CL:0002551',
#  'AGTCTTCTCCTCAAAT': 'CL:0002551',
#  'AGTGAACAAACTTCTC': 'CL:0000388',
#  'AGTGAAGATGGTGTCC': 'CL:0002551',
#  'AGTGACCTACTTTACG': 'CL:0000138',
#  'AGTGAGACTTCCAGTA': 'CL:0000057',
#  'AGTGAGCCTCGCCGCC': 'CL:0000388',
#  'AGTGAGGGTTTCTGAC': 'CL:1000413',
#  'AGTGATATGAGTAGTT': 'CL:0000057',
#  'AGTGATTCAAGCAGGA': 'CL:0002551',
#  'AGTGCGTAGCTCGTAA': 'CL:0000057',
#  'AGTGCTTGCACGAATA': 'CL:0002551',
#  'AGTGGCGGCAATTTGA': 'CL:0002551',
#  'AGTGTATTGCGCATTG': 'CL:0002551',
#  'AGTTAAACACTTGCGA': 'CL:0000138',
#  'AGTTAAGCGGTCCCGG': 'CL:0000388',
#  'AGTTAAGTCAACCGCT': 'CL:0000388',
#  'AGTTACTCTATCGTGG': 'CL:0000057',
#  'AGTTATTGAAAGGTAA': 'CL:0000669',
#  'AGTTCCTACAGAATTA': 'CL:0002551',
#  'AGTTCCTATTTATGTT': 'CL:0000057',
#  'AGTTTGGCCAGACCTA': 'CL:0008019',
#  'ATAAACGGACCCGTAA': 'CL:0000187',
#  'ATAAAGGCTCGGTCGT': 'CL:0002551',
#  'ATAAAGGTCAAGTACG': 'CL:0000743',
#  'ATAAATATTAGCAGCT': 'CL:0002551',
#  'ATAACGCCGGAGGGTC': 'CL:0000057',
#  'ATAACGGAGTCCAACG': 'CL:0000138',
#  'ATAACGTTACCTCCAC': 'CL:0002551',
#  'ATAAGCAAACACCGAG': 'CL:0002551',
#  'ATAAGGTGGAGAACAT': 'CL:0002551',
#  'ATAAGTACCCGATTGT': 'CL:0000388',
#  'ATAAGTTACCGCGACG': 'CL:0000138',
#  'ATAATAGCTGTTGAAT': 'CL:0002551',
#  'ATACCACGGGCAACTT': 'CL:0002551',
#  'ATACCGTCATCCATAA': 'CL:0002551',
#  'ATACGACAGATGGGTA': 'CL:0000187',
#  'ATACGCCGGCGAAACC': 'CL:0000057',
#  'ATACGGAACGTCGTTT': 'CL:0000078',
#  'ATACGGGTTTCGATTG': 'CL:0000388',
#  'ATACTAGCATGACCCT': 'CL:0002551',
#  'ATAGACAACGGGACCT': 'CL:0002551',
#  'ATAGACGAAGAGAAAG': 'CL:0002551',
#  'ATAGAGTACTGGGACA': 'CL:0002551',
#  'ATAGAGTTATCAACTT': 'CL:0002551',
#  'ATAGGAATCTAAGCTT': 'CL:0000187',
#  'ATAGGCGGCTATAGAA': 'CL:0002573',
#  'ATAGGCTAGCTTCGCA': 'CL:0002551',
#  'ATAGGGATATCCTTGA': 'CL:0002551',
#  'ATAGGTTGGGCAGATG': 'CL:0000057',
#  'ATAGTGAAGCGTTCTC': 'CL:0000388',
#  'ATAGTTCCACCCACTC': 'CL:0002551',
#  'ATATAAATGTAGCTGC': 'CL:0000078',
#  'ATATCAATTCCAGCCT': 'CL:0000646',
#  'ATATCGTGCCAGACCC': 'CL:0000558',
#  'ATATCTCCCTCGTTAA': 'CL:0000388',
#  'ATATCTTAGGGCCTTC': 'CL:0000388',
#  'ATATGTCTCCCTAGCC': 'CL:0002551',
#  'ATATGTGCACAAACCA': 'CL:0002551',
#  'ATATTCAGTTAAACCT': 'CL:0000138',
#  'ATATTCCACATAGTGA': 'CL:0002551',
#  'ATATTTAACCCTCAAG': 'CL:0002551',
#  'ATCAAACGAAGGTTTG': 'CL:0000138',
#  'ATCAATCTGGGCTGCA': 'CL:0000388',
#  'ATCACATTAGAATATC': 'CL:0002551',
#  'ATCACGTGCTAATTAA': 'CL:0000138',
#  'ATCACTTCATCCTCGC': 'CL:0002551',
#  'ATCAGACGGCACGCCG': 'CL:0000057',
#  'ATCAGCTCGTCCACTA': 'CL:0002551',
#  'ATCAGGTCGCCATTGC': 'CL:0002551',
#  'ATCAGTAGGCAGGGAT': 'CL:0000057',
#  'ATCATCCAATATTTGT': 'CL:0002551',
#  'ATCATCTGCCCAGTGT': 'CL:0002551',
#  'ATCCAATGGAGGGTCC': 'CL:0000138',
#  'ATCCACGCTAAATGTT': 'CL:0002551',
#  'ATCCACTTTCAGACTA': 'CL:0000388',
#  'ATCCAGAGCAACAACC': 'CL:0002551',
#  'ATCCAGGATTCGTGAA': 'CL:0000138',
#  'ATCCTACCTAAGCTCT': 'CL:0002551',
#  'ATCCTGAATCGCTGCG': 'CL:0000078',
#  'ATCCTGCGTGGAATGG': 'CL:0000057',
#  'ATCGACCCAATACAGA': 'CL:0000057',
#  'ATCGACTCTTTCCGTT': 'CL:0002551',
#  'ATCGCACGCCGGGAGA': 'CL:0000187',
#  'ATCGGAGACAGACGGC': 'CL:0000078',
#  'ATCGTTCACTTTCGCC': 'CL:0002551',
#  'ATCTCATAAACCTACC': 'CL:0000057',
#  'ATCTGCACCTCTGCGA': 'CL:0002551',
#  'ATCTGGTTAAGACTGT': 'CL:0000388',
#  'ATCTTGACCTGCAACG': 'CL:0000078',
#  'ATGACGCGTTCTATCC': 'CL:0000388',
#  'ATGATGCAATGGTACA': 'CL:0000388',
#  'ATGCACGCGCTGTTCA': 'CL:0000646',
#  'ATGCACTACCGCATTG': 'CL:0002551',
#  'ATGCATGATCCAGGAT': 'CL:0002551',
#  'ATGCCAATCGCTCTGC': 'CL:0002551',
#  'ATGCCATTTGCGACCA': 'CL:0002551',
#  'ATGCCGGTCTTGCATA': 'CL:0000558',
#  'ATGCCGGTTGATGGGA': 'CL:0002551',
#  'ATGCGACAATTGGTCC': 'CL:0002551',
#  'ATGCGACAGTCCCATT': 'CL:0000388',
#  'ATGGAACAGAATAAAC': 'CL:0000187',
#  'ATGGAGCAGGCCGTGA': 'CL:0000138',
#  'ATGGATCCGGCGTCCG': 'CL:0000388',
#  'ATGGATTGACCAAACG': 'CL:0002551',
#  'ATGGCTGGAAATGGCC': 'CL:0002551',
#  'ATGGGAACGGAAGCGG': 'CL:0000558',
#  'ATGGGCCTCGGCCTCT': 'CL:0002551',
#  'ATGGTCGCGTGGTTTC': 'CL:0002551',
#  'ATGGTTACGAAACATG': 'CL:0000187',
#  'ATGTGAAAGCCTAATG': 'CL:0002551',
#  'ATGTGCATCCGACGCA': 'CL:0002551',
#  'ATGTGGACATCTTGAT': 'CL:0000057',
#  'ATGTTTGTAAGATCAT': 'CL:0000187',
#  'ATTAAACATGCGGACC': 'CL:0000388',
#  'ATTAATACTACGCGGG': 'CL:0002551',
#  'ATTAATGAACCAGTCG': 'CL:0000138',
#  'ATTACAACTACCGGCC': 'CL:0002551',
#  'ATTACGACTCCACAGT': 'CL:0000388',
#  'ATTACGCGCTGGCAGG': 'CL:0008019',
#  'ATTAGGCGATGCTTTC': 'CL:0000388',
#  'ATTATACTTTGCTCGT': 'CL:0000388',
#  'ATTATGCCATAGGGAG': 'CL:0002551',
#  'ATTATGCTCAGTATTG': 'CL:0002551',
#  'ATTCAGATGAATCCCT': 'CL:0000192',
#  'ATTCAGGATCGCCTCT': 'CL:0000388',
#  'ATTCATATACTGTCCA': 'CL:0000057',
#  'ATTCCTAAGACGTGGA': 'CL:0002551',
#  'ATTCGACGCCGGGCCT': 'CL:0002551',
#  'ATTCGCAGAGGACACT': 'CL:0002551',
#  'ATTCTGAGTATGAACT': 'CL:0000388',
#  'ATTCTTCGTACTTATG': 'CL:0002551',
#  'ATTGAAGATCTTAGTG': 'CL:0000388',
#  'ATTGACCGGCGATGAC': 'CL:0002551',
#  'ATTGACGTAACTCGGT': 'CL:0002551',
#  'ATTGATGAGTCCTAAC': 'CL:0002551',
#  'ATTGCTGCTCCTCCAT': 'CL:0000057',
#  'ATTGGGAGTTCTGTAA': 'CL:0000388',
#  'ATTGTACAACTCGGCT': 'CL:0002551',
#  'ATTGTCGCAATACCTT': 'CL:0000388',
#  'ATTGTGACTTCGCTGC': 'CL:0000388',
#  'ATTTACAGTTTACTGG': 'CL:0002551',
#  'ATTTCATTATTTCGCG': 'CL:0002551',
#  'ATTTCCGGGTTCTGCG': 'CL:0002551',
#  'ATTTGCGCGAGTAGCT': 'CL:0002551',
#  'ATTTGTCTTGGGAGCT': 'CL:0000057',
#  'ATTTGTTCCAGGGCTC': 'CL:0002551',
#  'CAAACGAGTATCGCAG': 'CL:0000187',
#  'CAAACGGTCGCACTTT': 'CL:0002551',
#  'CAAACGTGGTCTTGCG': 'CL:0002551',
#  'CAAACTACGATAGAGA': 'CL:0002551',
#  'CAAACTATTGAGCTTC': 'CL:0002551',
#  'CAAAGATTATTGGGCC': 'CL:0002551',
#  'CAAAGGTTAAATTCAG': 'CL:0000187',
#  'CAAATCTCTCACAAGG': 'CL:0000138',
#  'CAAATGTCCTTCCGTG': 'CL:0000057',
#  'CAACAGAATAACGCTA': 'CL:1000413',
#  'CAACGACCCGTTTACA': 'CL:0002551',
#  'CAACTATATCGAATGC': 'CL:0002551',
#  'CAACTCCAACGTTTAG': 'CL:1000413',
#  'CAACTCCGTAACTTGC': 'CL:0002551',
#  'CAACTGAGGGTATGAC': 'CL:0002551',
#  'CAAGAAACCCTAAACT': 'CL:0002551',
#  'CAAGAGGGCGGAGTAC': 'CL:0002551',
#  'CAAGATATTATAACGT': 'CL:0000646',
#  'CAAGCAACGTCGGAGT': 'CL:0000388',
#  'CAAGCACCAAATGCCT': 'CL:0000078',
#  'CAAGCGGCACATAATT': 'CL:0000078',
#  'CAAGGATCGCATGTTC': 'CL:0000057',
#  'CAAGTGTGGTTGCAAA': 'CL:0002551',
#  'CAATAAACCTTGGCCC': 'CL:0000138',
#  'CAATATGTAGATTTAC': 'CL:0000187',
#  'CAATATTCTTGACCTA': 'CL:0002551',
#  'CAATCCATTATCCGTT': 'CL:0000388',
#  'CAATCCCTATACCAGC': 'CL:0002551',
#  'CAATGGAATCTACATA': 'CL:0002551',
#  'CAATGGATCTCTACCA': 'CL:1001607',
#  'CAATTAAGGGTGATGA': 'CL:0000057',
#  'CAATTTCGTATAAGGG': 'CL:1001607',
#  'CACAAGAAAGATATTA': 'CL:0002551',
#  'CACAATGAGCTGCTAT': 'CL:0000138',
#  'CACACGCGCTGTCTTA': 'CL:0000057',
#  'CACACGTTTCAATGGG': 'CL:0000235',
#  'CACACTTGTATTGCGA': 'CL:0002551',
#  'CACAGCACCCACGGCA': 'CL:0002551',
#  'CACAGCTAGGGAGTGA': 'CL:0002551',
#  'CACATATTAGCAGGAT': 'CL:0002551',
#  'CACATGATTCAGCAAC': 'CL:0000138',
#  'CACATTCTTTCGATGG': 'CL:0002551',
#  'CACCATGATCGCAAAG': 'CL:0002551',
#  'CACCCACGAGGCAATT': 'CL:0000388',
#  'CACCCGGTTTGTGACT': 'CL:0002551',
#  'CACCCTTGGTGAGACC': 'CL:0002551',
#  'CACCGATACACCGAGC': 'CL:0002551',
#  'CACCGCCAGAAGGTTT': 'CL:0002551',
#  'CACCGCGTCCACTCTA': 'CL:0002551',
#  'CACCGGAGATATCTCC': 'CL:0000062',
#  'CACCGTTAGGGATCAC': 'CL:0002551',
#  'CACCGTTGCGCGATAT': 'CL:1001607',
#  'CACCTAATCAGTTTAC': 'CL:0002551',
#  'CACCTCGATGGTGGAC': 'CL:0002551',
#  'CACCTCTACGAGTGTG': 'CL:0000187',
#  'CACCTTGCGAAACTCG': 'CL:0000388',
#  'CACCTTGGCGCCTTTG': 'CL:0002551',
#  'CACGACCACAGACTTT': 'CL:0000062',
#  'CACGACGTAATAGTAA': 'CL:0000187',
#  'CACGCACAGCGCAGCT': 'CL:0002551',
#  'CACGCAGCGAGGCTTT': 'CL:0002551',
#  'CACGCGGAACTGTTGC': 'CL:0002551',
#  'CACGGACGTGGATGGC': 'CL:0002551',
#  'CACGGCGCGCCAAAGG': 'CL:0002551',
#  'CACGTCGGCAACCTCT': 'CL:0008019',
#  'CACGTCTATGATGTGG': 'CL:0002551',
#  'CACGTTCGTGCTCTAG': 'CL:0000388',
#  'CACTAAAGTTGCCTAT': 'CL:0000388',
#  'CACTACTCAGTTCTGT': 'CL:1000413',
#  'CACTCAAGAGCTATGG': 'CL:0002551',
#  'CACTCCTATGTAAGAT': 'CL:0002551',
#  'CACTCCTCTCGGTCGG': 'CL:0000388',
#  'CACTCGAGCTGAACAA': 'CL:0002551',
#  'CACTTAATCAGACGGA': 'CL:0002551',
#  'CAGACACCGATCGCTG': 'CL:0000388',
#  'CAGACCTGTAAGTGTT': 'CL:0002551',
#  'CAGACGAACCTGATAC': 'CL:0000057',
#  'CAGAGACGGTCACCCA': 'CL:0002551',
#  'CAGAGCATGAGCTTGC': 'CL:0000388',
#  'CAGAGGCGATGCATGA': 'CL:0002551',
#  'CAGATACTAACATAGT': 'CL:0000388',
#  'CAGATCCTGGTTTGAA': 'CL:0002551',
#  'CAGCAGCCCGTTCCTT': 'CL:0000138',
#  'CAGCCGGGCCCTCTAT': 'CL:0000388',
#  'CAGCCTCCTGCAGAGG': 'CL:0000388',
#  'CAGCCTCTCCTCAAGA': 'CL:0002551',
#  'CAGCGATTCCCTTCAA': 'CL:0002551',
#  'CAGCTCACTGAGACAT': 'CL:0002551',
#  'CAGCTCGACAAGTTAA': 'CL:0000057',
#  'CAGCTGGCGTAACCGT': 'CL:0002551',
#  'CAGGAAGACTTTATAT': 'CL:0000388',
#  'CAGGATATATCGTTGT': 'CL:0000057',
#  'CAGGCCGTTTGGGTGT': 'CL:0000057',
#  'CAGGCGCACGGTGGTC': 'CL:0002551',
#  'CAGGCGCCATGCTAGG': 'CL:0002551',
#  'CAGGTTTAGTACTACA': 'CL:0000388',
#  'CAGTACCAGTTTACGT': 'CL:0002551',
#  'CAGTAGCCCACGCGGT': 'CL:0000388',
#  'CAGTCCAACGCCTTCT': 'CL:0002551',
#  'CAGTCGAGGATGCAAT': 'CL:0002551',
#  'CAGTCTGTATACTGGG': 'CL:0000057',
#  'CAGTGAATAAATGACT': 'CL:0000138',
#  'CAGTTCAAATTGACAC': 'CL:0000388',
#  'CATAACGGACAGTCGT': 'CL:0002551',
#  'CATACCCGTACCCAGT': 'CL:0002551',
#  'CATACGGCGTCTGGGC': 'CL:0000138',
#  'CATACTATGTAATTGT': 'CL:0000388',
#  'CATAGCGTTGCCCACC': 'CL:0002551',
#  'CATAGTACATTGAGAG': 'CL:0002551',
#  'CATAGTCCACAAGAAC': 'CL:0002551',
#  'CATATAGGTACAGTCA': 'CL:1001607',
#  'CATATGTCAGGCTACG': 'CL:0002551',
#  'CATATTATTTGCCCTA': 'CL:0002551',
#  'CATCAAACTGGCGCCC': 'CL:0002551',
#  'CATCGGACGGGTTAAT': 'CL:0000388',
#  'CATCTACCCGAGAACG': 'CL:0000187',
#  'CATCTTACACCACCTC': 'CL:0002551',
#  'CATGATGCACAATTCT': 'CL:0002551',
#  'CATGCACGTGTTACTG': 'CL:0008019',
#  'CATGCCAACTCGCAAA': 'CL:0002551',
#  'CATGCGACCAGTTTAA': 'CL:0002551',
#  'CATGGAAATGGGACCA': 'CL:0000187',
#  'CATGGGTCGGGTGTGG': 'CL:0000388',
#  'CATGGTAAGTAGCGTT': 'CL:0000057',
#  'CATGGTCTAGATACCG': 'CL:0002551',
#  'CATGTAGGAGCGCCAA': 'CL:0000187',
#  'CATTACGTCGGCCCGT': 'CL:0002551',
#  'CATTATGCTTGTTGTG': 'CL:0002551',
#  'CATTGCAAAGCATAAT': 'CL:0002551',
#  'CATTTAGCGGACCATG': 'CL:0000388',
#  'CATTTATCGTTCAAGA': 'CL:0002551',
#  'CATTTGAGTGGTACGT': 'CL:0000138',
#  'CCAAACAGAACCCTCG': 'CL:0002551',
#  'CCAACGCTTGCCAGGG': 'CL:0000187',
#  'CCAAGAAAGTGGGCGA': 'CL:0002551',
#  'CCAAGACTTCTGCGAA': 'CL:0002551',
#  'CCAAGCGTAACTCGTA': 'CL:0000388',
#  'CCAATAGTGCCGTCGA': 'CL:0000057',
#  'CCAATCGGTAGATCGA': 'CL:1000413',
#  'CCAATGTCACAGCAAG': 'CL:0000057',
#  'CCAATTACGGGTCGAG': 'CL:0002551',
#  'CCACAATGTACGTCTT': 'CL:1001607',
#  'CCACACTGAGATATTA': 'CL:0000138',
#  'CCACATGGCTCTTTAT': 'CL:0000646',
#  'CCACCAACTTTACTGT': 'CL:0002551',
#  'CCACCCAAGGAAAGTG': 'CL:0000388',
#  'CCACGAGAAGAGAATC': 'CL:0002551',
#  'CCACGGAGCCATAAGA': 'CL:0002551',
#  'CCAGAAAGCAACTCAT': 'CL:0002551',
#  'CCAGATAGTTGAGTGA': 'CL:0000138',
#  'CCAGATGTAAATGGGT': 'CL:0000138',
#  'CCAGCCTGGACCAATA': 'CL:0000138',
#  'CCAGGGACGTGGCCTC': 'CL:0000057',
#  'CCAGTAGTCTGATCCA': 'CL:0002551',
#  'CCAGTCTAGACGGCGC': 'CL:0002551',
#  'CCATAAACAACCCGAC': 'CL:0000078',
#  'CCATACCTTTACTTGT': 'CL:0002551',
#  'CCATCATAAGAACAGG': 'CL:0000187',
#  'CCATCGCAGTTAAACT': 'CL:0002551',
#  'CCATCTCACCAGTGAA': 'CL:0002551',
#  'CCATGCCTGTTTAGTA': 'CL:0000057',
#  'CCATTAGCGATAATCC': 'CL:0002551',
#  'CCATTCCCTGCCCACA': 'CL:0002551',
#  'CCCAAACATGCTGCTC': 'CL:0000388',
#  'CCCAACATACGTCGCG': 'CL:0002551',
#  'CCCAAGAATGCACGGT': 'CL:0000235',
#  'CCCAATTTCACAACTT': 'CL:0002551',
#  'CCCAGTAAACTTGGGA': 'CL:0002551',
#  'CCCAGTTAAGGCGCCG': 'CL:0000057',
#  'CCCGACCATAGTCCGC': 'CL:0002551',
#  'CCCGCAGCGCGAACTA': 'CL:0000057',
#  'CCCGCAGGGCCCAAAG': 'CL:0002551',
#  'CCCGCTAGAGGGTTAA': 'CL:0000078',
#  'CCCGGTGTATCGGAAT': 'CL:0008019',
#  'CCCGTAAGTCTAGGCC': 'CL:0002551',
#  'CCCGTAGCTGGGAAGA': 'CL:0002551',
#  'CCCGTCAGCGTCTGAC': 'CL:0002551',
#  'CCCTGAAATGAGTTGA': 'CL:0002551',
#  'CCCTGGTATGGGCGGC': 'CL:0000187',
#  'CCCTTTGACAGGTCTT': 'CL:0002551',
#  'CCGAACACTGGGCCTC': 'CL:0000138',
#  'CCGAACCTTCCCGGCC': 'CL:0002551',
#  'CCGACGGGCATGAGGT': 'CL:0002551',
#  'CCGACGTAAACACAAC': 'CL:0002551',
#  'CCGACTCGCATAGTCT': 'CL:0000388',
#  'CCGAGCTGTGCTTGTC': 'CL:0002551',
#  'CCGATCTCAACCTTAT': 'CL:0002551',
#  'CCGATCTTAAGAGGCT': 'CL:0000558',
#  'CCGATTGGTCAATGAA': 'CL:0000062',
#  'CCGCACAAAGACCAAC': 'CL:0000388',
#  'CCGCCGGAACTTCTCG': 'CL:0000556',
#  'CCGCCTGCGAATTGGT': 'CL:0002551',
#  'CCGCGGAATGCGTCAC': 'CL:0000057',
#  'CCGCTATCAGCACCAG': 'CL:0000057',
#  'CCGCTGGTGCCATTCA': 'CL:0002551',
#  'CCGCTTACCTCACTCT': 'CL:0000138',
#  'CCGGAGGTCTTATGGT': 'CL:0000388',
#  'CCGGGCGGTCTCGTCA': 'CL:0000388',
#  'CCGGGCTGCTCCATAC': 'CL:0000057',
#  'CCGGGTTCGAGGTTAC': 'CL:0002551',
#  'CCGGTTTGTAATTGTG': 'CL:0002551',
#  'CCGTAAGTTGGTCCCA': 'CL:0000388',
#  'CCGTATCTCGTCGTAG': 'CL:0002551',
#  'CCGTATTAGCGCAGTT': 'CL:0002551',
#  'CCGTGTTAAATTCCAT': 'CL:0000138',
#  'CCGTTACGTTAGAACA': 'CL:0000057',
#  'CCTAAAGGCTGACGCT': 'CL:0000388',
#  'CCTAAATTAACGGTTC': 'CL:0000057',
#  'CCTAACTAAGGCTCTA': 'CL:0002551',
#  'CCTACAAGTCCGGAAT': 'CL:0000187',
#  'CCTACATTCACAGACG': 'CL:0000138',
#  'CCTACGCGACCTTACA': 'CL:0000388',
#  'CCTACTGCGGCGGCCA': 'CL:0002551',
#  'CCTACTGCTTACACTT': 'CL:0000388',
#  'CCTAGGCGTAGCGATC': 'CL:0002551',
#  'CCTATACCGTCCTGTC': 'CL:0002551',
#  'CCTATCTATATCGGAA': 'CL:0002551',
#  'CCTATGGGTTACCGTC': 'CL:0002551',
#  'CCTCACCTGAGGGAGC': 'CL:0002551',
#  'CCTCACCTTAGCATCG': 'CL:0002551',
#  'CCTCGCCAGCAAATTA': 'CL:0002551',
#  'CCTCGCGCGATATAGG': 'CL:0000078',
#  'CCTCGCGCTGTGCGAT': 'CL:0000138',
#  'CCTCGGACCGGGATAG': 'CL:0002551',
#  'CCTCGTTACGCCTGTT': 'CL:0000187',
#  'CCTCTAATCTGCCAAG': 'CL:0002551',
#  'CCTCTATCGATTAGCA': 'CL:0000388',
#  'CCTCTGGCCTAGACGG': 'CL:0000078',
#  'CCTCTGTACTATTCTA': 'CL:0000078',
#  'CCTGAACGATATATTC': 'CL:0000388',
#  'CCTGAATATTTACATA': 'CL:0000057',
#  'CCTGACCACCGATGGT': 'CL:0000057',
#  'CCTGACGCAACCTTTA': 'CL:0000138',
#  'CCTGCTATTTGAGAAG': 'CL:0000388',
#  'CCTGGCTAGACCCGCC': 'CL:0002551',
#  'CCTGTAAGACATGATA': 'CL:0002551',
#  'CCTGTACTCACGCCCA': 'CL:0000078',
#  'CCTGTCACCCGGGCTC': 'CL:0000057',
#  'CCTGTCGCCCGTAAAT': 'CL:0000138',
#  'CCTGTGCGGATTGTAA': 'CL:0000388',
#  'CCTTCTTGATCCAGTG': 'CL:0002551',
#  'CCTTTCAATGAAGAAA': 'CL:0002551',
#  'CGAAACATAGATGGCA': 'CL:0002551',
#  'CGAAACGCAATTCATG': 'CL:0002551',
#  'CGAACATAGTCAGAAA': 'CL:0002551',
#  'CGAACCCGCATGCGTC': 'CL:0000057',
#  'CGAACGGCCGGACAAC': 'CL:0002551',
#  'CGAATTACATGGTGTT': 'CL:0000388',
#  'CGACAATTTGATCTAA': 'CL:0002551',
#  'CGACACCGCTTAAGGA': 'CL:0002551',
#  'CGACACGGATGCCCAC': 'CL:0002551',
#  'CGACAGTTCGCGTTAT': 'CL:0002551',
#  'CGACTCAGGATGTTAT': 'CL:0002551',
#  'CGACTCGGTACACGGT': 'CL:0002551',
#  'CGAGACCCTAGAGTGT': 'CL:0000388',
#  'CGAGAGATGTGAACCT': 'CL:0000388',
#  'CGAGCTGGGCTTTAGG': 'CL:0000078',
#  'CGAGGCTAAATATGGC': 'CL:0000388',
#  'CGAGGGACTGCGGTCG': 'CL:0000057',
#  'CGAGTACTAAAGAGGA': 'CL:0000138',
#  'CGAGTGAAGGTACCAG': 'CL:0002551',
#  'CGAGTTCTGTCCCACC': 'CL:0000138',
#  'CGAGTTTATCGGACTG': 'CL:0002551',
#  'CGATAACCAATTTGAG': 'CL:0002551',
#  'CGATACCTCGCGGACA': 'CL:1001607',
#  'CGATCATTAGAGGCAC': 'CL:0002551',
#  'CGATCCGACCCAGTGC': 'CL:0000138',
#  'CGATCTGTTGGAGGAC': 'CL:0002551',
#  'CGATGGACCCTACGCC': 'CL:0002551',
#  'CGATGTTGTTATCTAC': 'CL:0002551',
#  'CGCAATTAGGGTAATA': 'CL:0002551',
#  'CGCACATGTCCACTAC': 'CL:0000057',
#  'CGCACGTGCGCTATCA': 'CL:0002551',
#  'CGCATCATGGCTTCAG': 'CL:0002551',
#  'CGCATGGTGCGATGCT': 'CL:0000057',
#  'CGCATTAGCTAATAGG': 'CL:0002551',
#  'CGCCACAGGTCGCGAT': 'CL:0002551',
#  'CGCCATCCGATTATGA': 'CL:0002551',
#  'CGCCCGCTTCCGTACA': 'CL:0000388',
#  'CGCCCTTACATCCACC': 'CL:0002543',
#  'CGCCGCCCATGCCTGT': 'CL:0000057',
#  'CGCCGGTGTCGCAGTA': 'CL:0000558',
#  'CGCCTCCCTCCTCTAT': 'CL:0000057',
#  'CGCCTGGCCTACGTAA': 'CL:0000138',
#  'CGCGAGAGGGACTTGT': 'CL:0002551',
#  'CGCGAGTCTGCCGGGT': 'CL:0008019',
#  'CGCGCAAATGTCCAGA': 'CL:0000078',
#  'CGCGCATGTTTGATTG': 'CL:0002551',
#  'CGCGCCCGACTTAATA': 'CL:0002551',
#  'CGCGGCTCAACTTGAA': 'CL:0002551',
#  'CGCGGGAATTAGGCAG': 'CL:0000388',
#  'CGCGTACATTCTGGAA': 'CL:0002551',
#  'CGCGTTCATGAAATAC': 'CL:0000388',
#  'CGCTACGGGACATTTA': 'CL:0000057',
#  'CGCTAGAGACCGCTGC': 'CL:0002551',
#  'CGCTATCGTGGCTTTA': 'CL:0002551',
#  'CGCTATTCTTAGGCTC': 'CL:0000388',
#  'CGCTGTGACGCCGCAC': 'CL:0002551',
#  'CGCTTATTCCCGGTCG': 'CL:0000138',
#  'CGCTTTCTTGCATTCG': 'CL:0000388',
#  'CGGAAATTTCACATCC': 'CL:0002551',
#  'CGGAACGTAAACATAG': 'CL:0000057',
#  'CGGAGCAATTTAATCG': 'CL:0000388',
#  'CGGAGCATGGCGATCC': 'CL:0000388',
#  'CGGAGCTTATAACACC': 'CL:0000057',
#  'CGGAGTCCTAACCTGG': 'CL:0000388',
#  'CGGCAAACATCGTGCG': 'CL:0002551',
#  'CGGCACCGTTAGCGCC': 'CL:0002551',
#  'CGGCAGGGTCGGGTTG': 'CL:0002551',
#  'CGGCCACGCACAAAGT': 'CL:0000388',
#  'CGGCTCTTCGTCGAAC': 'CL:0002551',
#  'CGGCTGAAGGTTACGC': 'CL:0000187',
#  'CGGGAATTTATGTAAA': 'CL:0002551',
#  'CGGGATCAATGTAAGA': 'CL:0002551',
#  'CGGGCAGCTAAACCGC': 'CL:0002551',
#  'CGGGCCTTCTTTGTAA': 'CL:0002551',
#  'CGGGCTACTTAAATTG': 'CL:0002551',
#  'CGGGTGTACCCATTTA': 'CL:0000388',
#  'CGGGTTCGGCACGTAT': 'CL:0000187',
#  'CGGTACTAGAATCAAA': 'CL:0002551',
#  'CGGTAGAGGTGCAGGT': 'CL:0002551',
#  'CGGTATAGGTATTAGC': 'CL:0000187',
#  'CGGTCAAGTGGGAACC': 'CL:0000388',
#  'CGGTCCATGAGACTCC': 'CL:0000078',
#  'CGGTCTATCAACCCGT': 'CL:0002551',
#  'CGGTGCAGATAGAACG': 'CL:0000669',
#  'CGGTGCGCGTTGGTCC': 'CL:0000138',
#  'CGGTGGGCTCCAGCCT': 'CL:0002551',
#  'CGGTTATCCAACAGTG': 'CL:0002551',
#  'CGGTTCAAGTAGGTGT': 'CL:0002551',
#  'CGGTTGACCTGGCATA': 'CL:0000078',
#  'CGGTTGGGTTCAAGTT': 'CL:0000187',
#  'CGGTTTATGAAGGAAC': 'CL:0000187',
#  'CGTAACGGAACGATCA': 'CL:0000187',
#  'CGTACCTGATAGGCCT': 'CL:0002551',
#  'CGTATTAAGAGATCTA': 'CL:0002551',
#  'CGTATTGTTTCCTAAT': 'CL:0002551',
#  'CGTCAAATGGTCGCAG': 'CL:0002551',
#  'CGTCACGTCCATTGGT': 'CL:0000057',
#  'CGTCGGATAGTGTTGA': 'CL:0002551',
#  'CGTCGGGTCTAAGCGC': 'CL:0002551',
#  'CGTCTCTCGCCGAGGC': 'CL:0002551',
#  'CGTGAAGTTAATTCAC': 'CL:0002551',
#  'CGTGACATTGGGTCGT': 'CL:0000558',
#  'CGTGCAGACTGGGACA': 'CL:0000558',
#  'CGTGCATTGTCGACGC': 'CL:0002551',
#  'CGTGCCCTCCCGAAGA': 'CL:0002551',
#  'CGTGTCCCATTCGCGA': 'CL:0002551',
#  'CGTTAGCTCACAACTG': 'CL:0000388',
#  'CGTTCATGGTGCGCGT': 'CL:0002551',
#  'CGTTGAGCGACCGTCG': 'CL:0000057',
#  'CGTTGAGTAATTGCGT': 'CL:0000187',
#  'CGTTGTTTCAATTCCC': 'CL:0002551',
#  'CGTTTACAAGGCAGCT': 'CL:0000078',
#  'CGTTTCACTTCGGGCG': 'CL:0000057',
#  'CGTTTCGCTCATTACA': 'CL:0000388',
#  'CGTTTGTGTAGAGGGT': 'CL:0002551',
#  'CTAAAGAATGCCTACT': 'CL:0002551',
#  'CTAAAGGGAAATAGGA': 'CL:0000388',
#  'CTAAATCCTATTCCGG': 'CL:0000138',
#  'CTAACCGCGCGCCCGT': 'CL:0002551',
#  'CTAACGAAACTTGCTG': 'CL:0002551',
#  'CTAACTGGTCCGGTTC': 'CL:0000388',
#  'CTAAGGGAATGATTGG': 'CL:0002573',
#  'CTAAGTACAGGGCTAC': 'CL:0000187',
#  'CTAATTATGAAGCGTA': 'CL:0002551',
#  'CTACAAGAAATAACCC': 'CL:0000078',
#  'CTACCCTAAGGTCATA': 'CL:0002551',
#  'CTACGAACTAGGTCGA': 'CL:0002551',
#  'CTACGACTAGCTATAA': 'CL:0002551',
#  'CTACGCACGGAGTACC': 'CL:0000057',
#  'CTACGCCATTTCCGAT': 'CL:0002551',
#  'CTACTATCATAGGTTT': 'CL:0002551',
#  'CTACTATCTTTCAGAG': 'CL:0002551',
#  'CTACTGCCACCTGACC': 'CL:0002551',
#  'CTAGACATATATGTAG': 'CL:0000187',
#  'CTAGACTGCATTTCGT': 'CL:0000187',
#  'CTAGATGTGAGTGTAA': 'CL:0002551',
#  'CTAGATTTACGACGGC': 'CL:0000057',
#  'CTAGCATAGTATAATG': 'CL:0000138',
#  'CTAGCGCCAATCCTAC': 'CL:0000187',
#  'CTAGTATTCGGAATTA': 'CL:0000388',
#  'CTAGTCACGTCTTAAG': 'CL:0000388',
#  'CTAGTGAAGGACAGGA': 'CL:0002551',
#  'CTAGTTACAACCCGGT': 'CL:0002551',
#  'CTAGTTGGGCCCGGTA': 'CL:0000057',
#  'CTATAAGAGCCAATCG': 'CL:0002551',
#  'CTATCGGGTCTCAACA': 'CL:0000138',
#  'CTATGTCACTAGCCCA': 'CL:0000057',
#  'CTATGTGAGTCACGGC': 'CL:0002551',
#  'CTATTCATGTGTCCCA': 'CL:0002551',
#  'CTATTGTGTTTGGTCA': 'CL:0002551',
#  'CTATTTGGTTACGGAT': 'CL:0000388',
#  'CTCAAGACATTAGCGC': 'CL:0002551',
#  'CTCACACGCAAGCCTA': 'CL:0002551',
#  'CTCACCGATCCAAACT': 'CL:0002551',
#  'CTCACTTGGCTGGTAA': 'CL:0002551',
#  'CTCAGCAGACTGCCGA': 'CL:0000187',
#  'CTCAGTCACGACAAAT': 'CL:0002551',
#  'CTCATGGTAATTTGCG': 'CL:0000138',
#  'CTCATTTGATGGGCGG': 'CL:0002551',
#  'CTCCCTCCTTTCGATC': 'CL:0000388',
#  'CTCCGAGTAAATCCGC': 'CL:0000187',
#  'CTCCGCCCACATGAGG': 'CL:0002551',
#  'CTCCGGCCTAATATGC': 'CL:0002551',
#  'CTCGAATGGAACGTAT': 'CL:0000187',
#  'CTCGAGACATACGATA': 'CL:0008019',
#  'CTCGAGGTCGAACAGT': 'CL:0002551',
#  'CTCGCACCTATATAGT': 'CL:0000057',
#  'CTCGCATTGCATAGCC': 'CL:0002551',
#  'CTCGGTACCACTGCTC': 'CL:0000057',
#  'CTCGGTTGTCGGCCCT': 'CL:0002551',
#  'CTCGTCGAGGGCTCAT': 'CL:0002551',
#  'CTCTACACTGGCGATT': 'CL:0002551',
#  'CTCTATTTGGCTGCAG': 'CL:0000057',
#  'CTCTCACAATCGATGA': 'CL:0000388',
#  'CTCTCTAACTGCCTAG': 'CL:0002551',
#  'CTCTGGACGCCTGGTG': 'CL:0002551',
#  'CTGAAACGGCCCTCAG': 'CL:0000388',
#  'CTGAAAGAGATCCGAC': 'CL:0002551',
#  'CTGAATCCGAGACCTC': 'CL:0000138',
#  'CTGACTGCGCAGCTCG': 'CL:0002551',
#  'CTGCACAACTACATAT': 'CL:0002551',
#  'CTGCACTCCAGTACAG': 'CL:0000078',
#  'CTGCCAAGGTTGGAAG': 'CL:0000388',
#  'CTGCCATGCATCACAT': 'CL:0000138',
#  'CTGCCTAGCCACCAAG': 'CL:0002551',
#  'CTGCGGTAGTCACGTG': 'CL:0002551',
#  'CTGCGTTACGATATAA': 'CL:0000057',
#  'CTGCTGAGGCCACGAA': 'CL:0000138',
#  'CTGCTTGGCGATAGCT': 'CL:0000078',
#  'CTGGAAATGGATGCTT': 'CL:0000388',
#  'CTGGACGCAGTCCGGC': 'CL:0002551',
#  'CTGGATTTACACTTGA': 'CL:0000057',
#  'CTGGCATCCGAATGAG': 'CL:0000138',
#  'CTGGCGACATAAGTCC': 'CL:0000388',
#  'CTGGCGCACAGGTCTG': 'CL:0002551',
#  'CTGGCTGATTCATCCT': 'CL:0002551',
#  'CTGGGATAAATAATGG': 'CL:0000057',
#  'CTGGGCACTAGTCGGA': 'CL:0002543',
#  'CTGGGCCTGCTATATC': 'CL:0002551',
#  'CTGGGCTATCCTTTGG': 'CL:0000187',
#  'CTGGGTAGGCAGTTAA': 'CL:0002551',
#  'CTGGGTTGAGTTAAAG': 'CL:0002551',
#  'CTGGTAACACATAGAA': 'CL:0002551',
#  'CTGGTAACGAGCTCTT': 'CL:0002551',
#  'CTGTACTTCTTAGCAT': 'CL:0000388',
#  'CTGTAGCCATCTCACT': 'CL:0002551',
#  'CTGTCAAATGGCTCGG': 'CL:0000138',
#  'CTGTCACGCCAGGCGC': 'CL:0000187',
#  'CTGTGCAGGGTAGGTC': 'CL:0000057',
#  'CTGTTACCCAATCTAG': 'CL:0000057',
#  'CTGTTCACTGCCTGTG': 'CL:0002551',
#  'CTTACACGGTATTCCA': 'CL:0002551',
#  'CTTAGCCTTCCACATG': 'CL:0000388',
#  'CTTAGGTCCCAATCGT': 'CL:0000078',
#  'CTTAGTAGGCCTACAG': 'CL:0002551',
#  'CTTCAGTGGTCGCCTA': 'CL:0002551',
#  'CTTCATTGTCAGTGGA': 'CL:1001607',
#  'CTTCCTGCATATTTAC': 'CL:0000388',
#  'CTTCGTAGATAGGTGA': 'CL:0000138',
#  'CTTCTATGTTGAAGTA': 'CL:0002551',
#  'CTTCTATTAATGCTAG': 'CL:0000388',
#  'CTTGAGTTAGGGTAAT': 'CL:0002551',
#  'CTTGCAACCGCCTCCT': 'CL:0000138',
#  'CTTGCCCAGGCTCTAC': 'CL:0000057',
#  'CTTGTACTTGTTGACT': 'CL:0002551',
#  'CTTGTCAACATTCGAG': 'CL:0002551',
#  'CTTGTGCTCACCGATT': 'CL:0002551',
#  'CTTGTTGCTGAGTCAA': 'CL:0000057',
#  'CTTTAACTTTCAAAGG': 'CL:0002551',
#  'CTTTAATATTGGTCGA': 'CL:0002551',
#  'CTTTAGGAACACTGTT': 'CL:0002551',
#  'CTTTAGTGCTATTATT': 'CL:0000388',
#  'CTTTCTGTGCGGGCTT': 'CL:0002551',
#  'CTTTGAAACATATTCC': 'CL:0000388',
#  'CTTTGGCAGACAGAGT': 'CL:0000187',
#  'CTTTGGCTTTAGTAAA': 'CL:0002551',
#  'CTTTGTCGAATGCTCC': 'CL:0002551',
#  'GAAACAGATGACCACC': 'CL:0002551',
#  'GAAACCGAATTACCTT': 'CL:0000057',
#  'GAAACTCTAATGAAGG': 'CL:0002551',
#  'GAAATACCTGCTGGCT': 'CL:0002551',
#  'GAAATATGCTTGAATG': 'CL:0002551',
#  'GAAATCGCGCGCAACT': 'CL:0002551',
#  'GAAATGGCGGTGTTAG': 'CL:0000669',
#  'GAAATTAGCACGGATA': 'CL:0002551',
#  'GAAATTGTCTCTATAA': 'CL:0000138',
#  'GAACACACATCAACCA': 'CL:0002551',
#  'GAACATTAGTATGTTA': 'CL:0002551',
#  'GAACGACCGAATGATA': 'CL:0000078',
#  'GAACGGTGTAAAGCAG': 'CL:0000187',
#  'GAACGTCTCATGGTCG': 'CL:0000388',
#  'GAACTTAGCGCCCGGT': 'CL:0000187',
#  'GAACTTGTGCACGGGA': 'CL:0000388',
#  'GAAGCGTGAGGAATTT': 'CL:0000057',
#  'GAAGCTCGGACCCGTC': 'CL:0002551',
#  'GAAGTCAGTTGCACTA': 'CL:0000078',
#  'GAAGTCTCCCTAGCGA': 'CL:0002551',
#  'GAAGTGATTTATCGTG': 'CL:1001607',
#  'GAAGTTTCCACTCAAT': 'CL:0002551',
#  'GAATAGACGCGACCCA': 'CL:0002551',
#  'GAATAGCCCTGCGGTC': 'CL:0002551',
#  'GAATATTCGGAGTCCC': 'CL:0000057',
#  'GAATCGACATGGTCAC': 'CL:0000078',
#  'GAATCTATACTCGGAC': 'CL:0002551',
#  'GAATCTGAACATTCTC': 'CL:0000057',
#  'GAATGAAGGTCTTCAG': 'CL:0000057',
#  'GAATGTATGGCAGGTC': 'CL:0000057',
#  'GAATGTGGTCCGGATT': 'CL:0000057',
#  'GAATGTTGGGTAATCT': 'CL:0002551',
#  'GAATTATAGTGAAAGG': 'CL:0000138',
#  'GAATTATGCAACCTAC': 'CL:0002551',
#  'GAATTCACCCGGGTGT': 'CL:0000057',
#  'GACAAACATATGCAGG': 'CL:0002551',
#  'GACAACGACCATTGAA': 'CL:0000057',
#  'GACAACGCAGCTTACG': 'CL:0002551',
#  'GACACAAGGGAAGAAA': 'CL:0000388',
#  'GACACTGAGTTCAGTG': 'CL:0000057',
#  'GACAGCCAGACCTGAC': 'CL:0002551',
#  'GACATCGATTTATAAC': 'CL:0000057',
#  'GACCACACTTCCCTTT': 'CL:0000192',
#  'GACCAGAGCCCTGTAG': 'CL:0000057',
#  'GACCCAATTATGATAC': 'CL:0000138',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               42
# AAACAAGTATCTCCCA-1          0         50        102              422
# AAACAATCTACTAGCA-1          0          3         43              169
# AAACACCAATAACTGC-1          1         59         19             2631
# AAACAGAGCGACTCCT-1          1         14         94             1406
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42              139
# TTGTTTCATTAGTCTA-1          0         60         30              401
# TTGTTTCCATACAACT-1          1         45         27              781
# TTGTTTGTATTACACG-1          0         73         41               89
# TTGTTTGTGTAAATTC-1          0          7         51              116
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                        NaN
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                 CL:0002551
# AAACAGAGCGACTCCT-1                 CL:0000057
# ...                                       ...
# TTGTTTCACATCCAGG-1                        NaN
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                 CL:0000138
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 3103

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_31665/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               42
# AAACAAGTATCTCCCA-1          0         50        102              422
# AAACAATCTACTAGCA-1          0          3         43              169
# AAACACCAATAACTGC-1          1         59         19             2631
# AAACAGAGCGACTCCT-1          1         14         94             1406
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42              139
# TTGTTTCATTAGTCTA-1          0         60         30              401
# TTGTTTCCATACAACT-1          1         45         27              781
# TTGTTTGTATTACACG-1          0         73         41               89
# TTGTTTGTGTAAATTC-1          0          7         51              116
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                    unknown
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                 CL:0002551
# AAACAGAGCGACTCCT-1                 CL:0000057
# ...                                       ...
# TTGTTTCACATCCAGG-1                    unknown
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                 CL:0000138
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0002551',
#  'CL:0000057',
#  'CL:0000138',
#  'CL:0000187',
#  'CL:0008019',
#  'CL:0000388',
#  'CL:0000743',
#  'CL:0000192',
#  'CL:0000558',
#  'CL:0000669',
#  'CL:0000078',
#  'CL:0000646',
#  'CL:1001607',
#  'CL:0000235',
#  'CL:1000413',
#  'CL:0002573',
#  'CL:0000062',
#  'CL:0000556',
#  'CL:0002543']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000030']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000030
# AAACAAGTATCTCCCA-1    HsapDv:0000030
# AAACAATCTACTAGCA-1    HsapDv:0000030
# AAACACCAATAACTGC-1    HsapDv:0000030
# AAACAGAGCGACTCCT-1    HsapDv:0000030
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000030
# TTGTTTCATTAGTCTA-1    HsapDv:0000030
# TTGTTTCCATACAACT-1    HsapDv:0000030
# TTGTTTGTATTACACG-1    HsapDv:0000030
# TTGTTTGTGTAAATTC-1    HsapDv:0000030
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000030']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               42
# AAACAAGTATCTCCCA-1          0         50        102              422
# AAACAATCTACTAGCA-1          0          3         43              169
# AAACACCAATAACTGC-1          1         59         19             2631
# AAACAGAGCGACTCCT-1          1         14         94             1406
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42              139
# TTGTTTCATTAGTCTA-1          0         60         30              401
# TTGTTTCCATACAACT-1          1         45         27              781
# TTGTTTGTATTACACG-1          0         73         41               89
# TTGTTTGTGTAAATTC-1          0          7         51              116
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383361
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9383361
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383361
# AAACACCAATAACTGC-1                 CL:0002551  WSSS_THYst9383361
# AAACAGAGCGACTCCT-1                 CL:0000057  WSSS_THYst9383361
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                    unknown  WSSS_THYst9383361
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9383361
# TTGTTTCCATACAACT-1                 CL:0000138  WSSS_THYst9383361
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9383361
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383361
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383361': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         ...,
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]]], dtype=uint8),
#                  'lowres': array([[[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         ...,
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.34835,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 168.56271,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9383361.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               42
# AAACAAGTATCTCCCA-1          0         50        102              422
# AAACAATCTACTAGCA-1          0          3         43              169
# AAACACCAATAACTGC-1          1         59         19             2631
# AAACAGAGCGACTCCT-1          1         14         94             1406
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42              139
# TTGTTTCATTAGTCTA-1          0         60         30              401
# TTGTTTCCATACAACT-1          1         45         27              781
# TTGTTTGTATTACACG-1          0         73         41               89
# TTGTTTGTGTAAATTC-1          0          7         51              116
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383361
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9383361
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383361
# AAACACCAATAACTGC-1                 CL:0002551  WSSS_THYst9383361
# AAACAGAGCGACTCCT-1                 CL:0000057  WSSS_THYst9383361
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                    unknown  WSSS_THYst9383361
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9383361
# TTGTTTCCATACAACT-1                 CL:0000138  WSSS_THYst9383361
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9383361
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383361
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383361': {'images': {'hires': array([[[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         ...,
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]]], dtype=uint8),
#                  'fullres': array([[[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         ...,
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]],
#
#                         [[239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          ...,
#                          [239, 241, 243],
#                          [239, 241, 243],
#                          [239, 241, 243]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.34835,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9383361'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide3.h5ad', compression = 'gzip')

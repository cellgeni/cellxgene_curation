# %% [markdown]
# ### **Curating Tcel13290871**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290871_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 17784963 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 38)	1.0
#   (0, 52)	1.0
#   (0, 63)	3.0
#   (0, 68)	1.0
#   (0, 99)	1.0
#   (0, 175)	1.0
#   (0, 178)	1.0
#   (0, 190)	1.0
#   (0, 193)	6.0
#   (0, 206)	2.0
#   (0, 207)	1.0
#   (0, 234)	3.0
#   (0, 254)	1.0
#   (0, 296)	1.0
#   (0, 300)	1.0
#   (0, 321)	1.0
#   (0, 326)	1.0
#   (0, 327)	2.0
#   (0, 354)	2.0
#   (0, 385)	1.0
#   (0, 408)	1.0
#   (0, 446)	1.0
#   (0, 447)	5.0
#   (0, 462)	1.0
#   (0, 505)	1.0
#   :	:
#   (4991, 31013)	1.0
#   (4991, 31040)	5.0
#   (4991, 31060)	1.0
#   (4991, 31083)	1.0
#   (4991, 31181)	1.0
#   (4991, 31189)	1.0
#   (4991, 31191)	2.0
#   (4991, 31343)	1.0
#   (4991, 31378)	1.0
#   (4991, 31380)	1.0
#   (4991, 31398)	1.0
#   (4991, 31416)	1.0
#   (4991, 31418)	1.0
#   (4991, 31441)	1.0
#   (4991, 31450)	5.0
#   (4991, 31453)	1.0
#   (4991, 32195)	10.0
#   (4991, 32196)	4.0
#   (4991, 32197)	27.0
#   (4991, 32198)	30.0
#   (4991, 32200)	36.0
#   (4991, 32201)	37.0
#   (4991, 32202)	3.0
#   (4991, 32204)	3.0
#   (4991, 32207)	12.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1658
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             3242
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             1874
# AAACACCAATAACTGC-1        1.0       59.0       59.0             6215
# AAACAGAGCGACTCCT-1        0.0       14.0       14.0             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3621
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             2372
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             4983
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              464
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             1605
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13290871_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAATCTACTAGCA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACACCAATAACTGC-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGGGTCTATATT-1        1.0  4B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCCATACAACT-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1        1.0  4B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1               3242
# Mus_Tcel13290871_AAACAATCTACTAGCA-1               1874
# Mus_Tcel13290871_AAACACCAATAACTGC-1               6215
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1               5708
# Mus_Tcel13290871_AAACAGGGTCTATATT-1               3979
# ...                                                ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1               3887
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1               3621
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1               2372
# Mus_Tcel13290871_TTGTTTCCATACAACT-1               4983
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1               1605
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                 8.084254        9429.0
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                 7.536364        4068.0
# Mus_Tcel13290871_AAACACCAATAACTGC-1                 8.734882       31534.0
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                 8.649799       26939.0
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                 8.289037       11651.0
# ...                                                      ...           ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                 8.265650       13262.0
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                 8.194781       11161.0
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                 7.771910        5706.0
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                 8.513988       18200.0
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                 7.381502        3017.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1            9.151651
# Mus_Tcel13290871_AAACAATCTACTAGCA-1            8.311152
# Mus_Tcel13290871_AAACACCAATAACTGC-1           10.358853
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1           10.201367
# Mus_Tcel13290871_AAACAGGGTCTATATT-1            9.363234
# ...                                                 ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1            9.492733
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1            9.320271
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1            8.649448
# Mus_Tcel13290871_TTGTTTCCATACAACT-1            9.809232
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1            8.012350
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                   26.206385
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                   22.959686
# Mus_Tcel13290871_AAACACCAATAACTGC-1                   23.295490
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                   21.682320
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                   22.152605
# ...                                                         ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                   27.650431
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                   23.187887
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                   24.640730
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                   23.060440
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                   22.704674
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    34.552975
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    33.529991
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    33.268852
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    32.406548
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    31.602438
# ...                                                          ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    37.121098
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    34.127766
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    34.840519
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    32.736263
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    32.780907
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    44.384346
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    46.042282
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    44.960995
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    45.094471
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    42.622952
# ...                                                          ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    48.755844
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    45.847145
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    46.074306
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    43.582417
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    44.282398
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    59.815464  ...
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    63.839725  ...
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    59.364494  ...
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    60.224953  ...
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    57.145309  ...
# ...                                                          ...  ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    62.871361  ...
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    60.406773  ...
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    61.987381  ...
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    57.346153  ...
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    63.374214  ...
#
#                                              donor_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAATCTACTAGCA-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACACCAATAACTGC-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGGGTCTATATT-1  4B_Hh.anti_IL10r
# ...                                               ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCCATACAACT-1  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1  4B_Hh.anti_IL10r
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                     MmusDv:0000061
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                     MmusDv:0000061
# Mus_Tcel13290871_AAACACCAATAACTGC-1                     MmusDv:0000061
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                     MmusDv:0000061
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                     MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                     MmusDv:0000061
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAATCTACTAGCA-1             PATO:0000461            True
# Mus_Tcel13290871_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAATCTACTAGCA-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                                       na
# Mus_Tcel13290871_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1              unknown               na
# Mus_Tcel13290871_AAACAATCTACTAGCA-1              unknown               na
# Mus_Tcel13290871_AAACACCAATAACTGC-1              unknown               na
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1              unknown               na
# Mus_Tcel13290871_AAACAGGGTCTATATT-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1              unknown               na
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1              unknown               na
# Mus_Tcel13290871_TTGTTTCCATACAACT-1              unknown               na
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAATCTACTAGCA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
# [3120 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAATCTACTAGCA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACACCAATAACTGC-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_AAACAGGGTCTATATT-1        1.0  4B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTCCATACAACT-1        1.0  4B_Hh.anti_IL10r
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1        1.0  4B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1               3242
# Mus_Tcel13290871_AAACAATCTACTAGCA-1               1874
# Mus_Tcel13290871_AAACACCAATAACTGC-1               6215
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1               5708
# Mus_Tcel13290871_AAACAGGGTCTATATT-1               3979
# ...                                                ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1               3887
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1               3621
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1               2372
# Mus_Tcel13290871_TTGTTTCCATACAACT-1               4983
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1               1605
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                 8.084254        9429.0
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                 7.536364        4068.0
# Mus_Tcel13290871_AAACACCAATAACTGC-1                 8.734882       31534.0
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                 8.649799       26939.0
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                 8.289037       11651.0
# ...                                                      ...           ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                 8.265650       13262.0
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                 8.194781       11161.0
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                 7.771910        5706.0
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                 8.513988       18200.0
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                 7.381502        3017.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1            9.151651
# Mus_Tcel13290871_AAACAATCTACTAGCA-1            8.311152
# Mus_Tcel13290871_AAACACCAATAACTGC-1           10.358853
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1           10.201367
# Mus_Tcel13290871_AAACAGGGTCTATATT-1            9.363234
# ...                                                 ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1            9.492733
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1            9.320271
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1            8.649448
# Mus_Tcel13290871_TTGTTTCCATACAACT-1            9.809232
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1            8.012350
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                   26.206385
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                   22.959686
# Mus_Tcel13290871_AAACACCAATAACTGC-1                   23.295490
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                   21.682320
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                   22.152605
# ...                                                         ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                   27.650431
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                   23.187887
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                   24.640730
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                   23.060440
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                   22.704674
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    34.552975
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    33.529991
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    33.268852
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    32.406548
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    31.602438
# ...                                                          ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    37.121098
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    34.127766
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    34.840519
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    32.736263
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    32.780907
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    44.384346
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    46.042282
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    44.960995
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    45.094471
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    42.622952
# ...                                                          ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    48.755844
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    45.847145
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    46.074306
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    43.582417
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    44.282398
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                    59.815464  ...
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                    63.839725  ...
# Mus_Tcel13290871_AAACACCAATAACTGC-1                    59.364494  ...
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                    60.224953  ...
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                    57.145309  ...
# ...                                                          ...  ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                    62.871361  ...
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                    60.406773  ...
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                    61.987381  ...
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                    57.346153  ...
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                    63.374214  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                      MmusDv:0000061
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                      MmusDv:0000061
# Mus_Tcel13290871_AAACACCAATAACTGC-1                      MmusDv:0000061
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                      MmusDv:0000061
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                      MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                      MmusDv:0000061
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                      MmusDv:0000061
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAATCTACTAGCA-1             PATO:0000461            True
# Mus_Tcel13290871_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13290871_AAACAGGGTCTATATT-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAATCTACTAGCA-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13290871_AAACAGGGTCTATATT-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1                                       na
# Mus_Tcel13290871_AAACAATCTACTAGCA-1                                       na
# Mus_Tcel13290871_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13290871_AAACAGGGTCTATATT-1                                       na
# ...                                                                      ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1                                       na
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13290871_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1              unknown              na
# Mus_Tcel13290871_AAACAATCTACTAGCA-1              unknown              na
# Mus_Tcel13290871_AAACACCAATAACTGC-1              unknown              na
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1              unknown              na
# Mus_Tcel13290871_AAACAGGGTCTATATT-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1              unknown              na
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1              unknown              na
# Mus_Tcel13290871_TTGTTTCCATACAACT-1              unknown              na
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAATCTACTAGCA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13290871_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13290871_AAACAAGTATCTCCCA-1  AAACAAGTATCTCCCA
# Mus_Tcel13290871_AAACAATCTACTAGCA-1  AAACAATCTACTAGCA
# Mus_Tcel13290871_AAACACCAATAACTGC-1  AAACACCAATAACTGC
# Mus_Tcel13290871_AAACAGCTTTCAGAAG-1  AAACAGCTTTCAGAAG
# Mus_Tcel13290871_AAACAGGGTCTATATT-1  AAACAGGGTCTATATT
# ...                                               ...
# Mus_Tcel13290871_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13290871_TTGTTTCACATCCAGG-1  TTGTTTCACATCCAGG
# Mus_Tcel13290871_TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA
# Mus_Tcel13290871_TTGTTTCCATACAACT-1  TTGTTTCCATACAACT
# Mus_Tcel13290871_TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC
#
# [3120 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0000584',
#  'AAACAATCTACTAGCA': 'CL:0009010',
#  'AAACACCAATAACTGC': 'CL:0000584',
#  'AAACAGCTTTCAGAAG': 'CL:0009010',
#  'AAACAGGGTCTATATT': 'CL:0000034',
#  'AAACATTTCCCGGATT': 'CL:0000186',
#  'AAACCGGAAATGTTAA': 'CL:0009010',
#  'AAACCGGGTAGGTACC': 'CL:0000844',
#  'AAACCGTTCGTCCAGG': 'CL:0000844',
#  'AAACCTCATGAAGTTG': 'CL:0000584',
#  'AAACGAAGAACATACC': 'CL:0000584',
#  'AAACGAAGATGGAGTA': 'CL:0000584',
#  'AAACGAGACGGTTGAT': 'CL:0000186',
#  'AAACGCTGGGCACGAC': 'CL:0009010',
#  'AAACGGGCGTACGGGT': 'CL:0000186',
#  'AAACGGTTGCGAACTG': 'CL:0000186',
#  'AAACGTGTTCGCCCTA': 'CL:0000584',
#  'AAACTAACGTGGCGAC': 'CL:0000584',
#  'AAACTCGGTTCGCAAT': 'CL:0000186',
#  'AAACTCGTGATATAAG': 'CL:0000584',
#  'AAACTGCTGGCTCCAA': 'CL:0000584',
#  'AAACTTAATTGCACGC': 'CL:0000584',
#  'AAACTTGCAAACGTAT': 'CL:0000034',
#  'AAAGGCCCTATAATAC': 'CL:0000584',
#  'AAAGGCTACGGACCAT': 'CL:0000584',
#  'AAAGGCTCTCGCGCCG': 'CL:0000584',
#  'AAAGGGATGTAGCAAG': 'CL:0009010',
#  'AAAGGGCAGCTTGAAT': 'CL:0009010',
#  'AAAGTAGCATTGCTCA': 'CL:0000584',
#  'AAAGTCACTGATGTAA': 'CL:0000844',
#  'AAAGTCGACCCTCAGT': 'CL:0009010',
#  'AAAGTGCCATCAATTA': 'CL:0000584',
#  'AAAGTGTGATTTATCT': 'CL:0000584',
#  'AAAGTTGACTCCCGTA': 'CL:0000034',
#  'AAATACCTATAAGCAT': 'CL:0000584',
#  'AAATAGCTTAGACTTT': 'CL:0009010',
#  'AAATAGGGTGCTATTG': 'CL:0000034',
#  'AAATCGCGGAAGGAGT': 'CL:0009010',
#  'AAATCGTGTACCACAA': 'CL:0000186',
#  'AAATCTAGCCCTGCTA': 'CL:0000584',
#  'AAATCTGCCCGCGTCC': 'CL:0009010',
#  'AAATGGCCCGTGCCCT': 'CL:0009010',
#  'AAATGGTCAATGTGCC': 'CL:0000034',
#  'AAATTAACGGGTAGCT': 'CL:0000584',
#  'AAATTACCTATCGATG': 'CL:0000584',
#  'AAATTGATAGTCCTTT': 'CL:0000034',
#  'AAATTGGTGAGAAGCA': 'CL:0000584',
#  'AAATTTACCGAAATCC': 'CL:0000584',
#  'AAATTTGCGGGTGTGG': 'CL:0000034',
#  'AACAACTGGTAGTTGC': 'CL:0009010',
#  'AACAATACATTGTCGA': 'CL:0009010',
#  'AACAATTACTCTACGC': 'CL:0009010',
#  'AACACACGCTCGCCGC': 'CL:0000584',
#  'AACACGACTGTACTGA': 'CL:0000584',
#  'AACACGAGACGCGGCC': 'CL:0000584',
#  'AACAGCTGTGTGGCAA': 'CL:0009010',
#  'AACAGGATGGGCCGCG': 'CL:0009010',
#  'AACAGGTAGTATGGAT': 'CL:0000584',
#  'AACATATCAACTGGTG': 'CL:0000584',
#  'AACATCGATACGTCTA': 'CL:0000584',
#  'AACATTGTGACTCGAG': 'CL:0000186',
#  'AACCAAGACTTCTCTG': 'CL:0000584',
#  'AACCAGTATCACTCTT': 'CL:0009010',
#  'AACCATAGGGTTGAAC': 'CL:0009010',
#  'AACCCATCCCATGATC': 'CL:0000186',
#  'AACCCGAGCAGAATCG': 'CL:0000584',
#  'AACCCTACTGTCAATA': 'CL:0000584',
#  'AACCGAGCTTGGTCAT': 'CL:0000584',
#  'AACCGCTAAGGGATGC': 'CL:0000034',
#  'AACCTCGCTTTAGCCC': 'CL:0000186',
#  'AACCTTTAAATACGGT': 'CL:0000584',
#  'AACGAAAGTCGTCCCA': 'CL:0000186',
#  'AACGACCTCCTAGCCG': 'CL:0000584',
#  'AACGATAATGCCGTAG': 'CL:0000066',
#  'AACGATATGTCAACTG': 'CL:0000034',
#  'AACGCGACCTTGGGCG': 'CL:0000186',
#  'AACGCGGTCTCCAGCC': 'CL:0000057',
#  'AACGCTGTTGCTGAAA': 'CL:0000584',
#  'AACGGACGTACGTATA': 'CL:0000584',
#  'AACGGCCATCTCCGGT': 'CL:0000584',
#  'AACGTACTGTGGGTAC': 'CL:0009010',
#  'AACGTAGTCTACCCAT': 'CL:0000584',
#  'AACGTCGCTGCACTTC': 'CL:0000584',
#  'AACGTGATGAAGGACA': 'CL:0000584',
#  'AACGTGCGAAAGTCTC': 'CL:0000584',
#  'AACTACCCGTTTGTCA': 'CL:0000584',
#  'AACTAGGCTTGGGTGT': 'CL:0009010',
#  'AACTCAAGTTAATTGC': 'CL:0000186',
#  'AACTCCAGAGCGTGTT': 'CL:0000186',
#  'AACTCTCAATAGAGCG': 'CL:0000066',
#  'AACTCTCAGTGTGCTC': 'CL:0000584',
#  'AACTGAGGTCAGCGTC': 'CL:0000584',
#  'AACTGAGTTATACTGA': 'CL:0000584',
#  'AACTGGGTCCCGACGT': 'CL:0009010',
#  'AACTGGGTTCGAGCCG': 'CL:0000584',
#  'AACTGGTGTGGGCCTT': 'CL:0009010',
#  'AACTTGCCCGTATGCA': 'CL:0000186',
#  'AACTTGCGTTCTCGCG': 'CL:0009010',
#  'AACTTTAGCTGCTGAG': 'CL:0000584',
#  'AACTTTCTCGATCATG': 'CL:0000584',
#  'AAGAAAGTTTGATGGG': 'CL:0009010',
#  'AAGACCAAATAACTCA': 'CL:0009010',
#  'AAGACCCAACTGAACA': 'CL:0000584',
#  'AAGACTGCAAGCTACT': 'CL:0000584',
#  'AAGAGATGAATCGGTA': 'CL:0009010',
#  'AAGAGCTCTTTATCGG': 'CL:0000066',
#  'AAGAGGATGTACGCGA': 'CL:0000584',
#  'AAGAGGCATGGATCGC': 'CL:0000186',
#  'AAGAGGCCCTTTGGAA': 'CL:0000584',
#  'AAGATGGCACCGGACC': 'CL:0000584',
#  'AAGATTGGCGGAACGT': 'CL:0000584',
#  'AAGCACCCTGCGTATC': 'CL:0000584',
#  'AAGCATACTCTCCTGA': 'CL:0000186',
#  'AAGCCGAAGCGGTTTA': 'CL:0000186',
#  'AAGCCGGAGAGCAGGA': 'CL:0000584',
#  'AAGCGGCGTCATGGGT': 'CL:0000584',
#  'AAGCGTCCCTCATCGA': 'CL:0009010',
#  'AAGCTAGATCGAGTAA': 'CL:0000844',
#  'AAGCTCGTGCCAAGTC': 'CL:0000034',
#  'AAGCTCTTTCATGGTG': 'CL:0000584',
#  'AAGGAGCGGTTGGTGC': 'CL:0009010',
#  'AAGGATCGATCGCTTG': 'CL:0009010',
#  'AAGGATGAGGGACCTC': 'CL:0000584',
#  'AAGGCAGGCTGTCTCC': 'CL:0000584',
#  'AAGGCGCGTAAAGCTT': 'CL:0009010',
#  'AAGGCTGTGCTCATCG': 'CL:0000584',
#  'AAGGGAACGACTGGCT': 'CL:0000584',
#  'AAGGGACAGATTCTGT': 'CL:0000584',
#  'AAGGGACTATGCATTC': 'CL:0000584',
#  'AAGGGTTAGCCATGCG': 'CL:0000844',
#  'AAGGGTTTGATTTCAG': 'CL:0000584',
#  'AAGGTATCCTAATATA': 'CL:0000034',
#  'AAGGTGATAAACCAGC': 'CL:0009010',
#  'AAGTAGAAGACCGGGT': 'CL:0000034',
#  'AAGTAGTGACGCGAGG': 'CL:0000584',
#  'AAGTCAATTGTCGTCA': 'CL:0000584',
#  'AAGTCTTCTGTGGCCT': 'CL:0000186',
#  'AAGTGACGACCGAATT': 'CL:0000584',
#  'AAGTGAGTCGGGTTTA': 'CL:0009010',
#  'AAGTGCCTTGACTGTA': 'CL:0000034',
#  'AAGTGCGTTAGAATCT': 'CL:0000584',
#  'AAGTGTTTGGAGACGG': 'CL:0000034',
#  'AAGTTCACTCCAAGCT': 'CL:0000584',
#  'AAGTTCGGCCAACAGG': 'CL:0009010',
#  'AAGTTGTGATGTTATA': 'CL:0009010',
#  'AAGTTTACTAATGGCA': 'CL:0009010',
#  'AATAACAACGCTCGGC': 'CL:0009010',
#  'AATAACACTAGAACAA': 'CL:0000844',
#  'AATAACGTCGCGCCCA': 'CL:0009010',
#  'AATAAGTCCTCGAGAC': 'CL:0000584',
#  'AATAGAACAGAGTGGC': 'CL:0000584',
#  'AATAGAATCTGTTTCA': 'CL:0000584',
#  'AATAGCTACCGCGTGC': 'CL:0000584',
#  'AATAGTCCGTCCCGAC': 'CL:0000034',
#  'AATATCCTAGCAAACT': 'CL:0009010',
#  'AATATCGAATCAATGC': 'CL:0000186',
#  'AATATCGAGGGTTCTC': 'CL:0000584',
#  'AATATTGGAGTATTGA': 'CL:0000584',
#  'AATCATGTAAAGACTC': 'CL:0009010',
#  'AATCGCCTCAGCGCCA': 'CL:0000066',
#  'AATCGCGCAGAGGACT': 'CL:0000584',
#  'AATCGGGACACTACGA': 'CL:0000584',
#  'AATCGTGAGCCGAGCA': 'CL:0000186',
#  'AATCTAGGTTTACTTG': 'CL:0009010',
#  'AATCTATGCCGGAGCC': 'CL:0000584',
#  'AATCTCTACTGTGGTT': 'CL:0000584',
#  'AATCTGCGTTGGGACG': 'CL:0000584',
#  'AATCTGGCTTTCTAGT': 'CL:0009010',
#  'AATGACAGCAATGTCT': 'CL:0009010',
#  'AATGACGTAGGATGTC': 'CL:0000034',
#  'AATGCAACCGGGTACC': 'CL:0000034',
#  'AATGTATGGCACTGTA': 'CL:0009010',
#  'AATGTGCCCGAGGTGT': 'CL:0000186',
#  'AATGTTGTCGTGAGAC': 'CL:0009010',
#  'AATTAAAGGTCGGCGT': 'CL:0000186',
#  'AATTAACGGATTTCCA': 'CL:0000844',
#  'AATTACGAGACCCATC': 'CL:0000584',
#  'AATTACTCGTACGCTC': 'CL:0000584',
#  'AATTAGCGCTGCAGCG': 'CL:0000584',
#  'AATTCATTGTCATGCA': 'CL:0000584',
#  'AATTCCAAGCATGTAC': 'CL:0009010',
#  'AATTCGATTCGAGGAT': 'CL:0000584',
#  'AATTCTAGAGTTAGGC': 'CL:0000844',
#  'AATTGAACGCTCTGGT': 'CL:0000186',
#  'AATTGCAGCAATCGAC': 'CL:0009010',
#  'AATTGCGTGGATTACA': 'CL:0000584',
#  'AATTGTGGTTGCCAAA': 'CL:0000844',
#  'ACAAACCATGCGTCCT': 'CL:0000584',
#  'ACAAAGAAGGTAGGCC': 'CL:0009010',
#  'ACAAAGCATGACCTAG': 'CL:0000186',
#  'ACAAATCGCACCGAAT': 'CL:0000844',
#  'ACAAATGGTAGTGTTT': 'CL:0000034',
#  'ACAAATTCAGATCTGA': 'CL:0000584',
#  'ACAACAGCATGAGCTA': 'CL:0000066',
#  'ACAACGGTCCCTGCGA': 'CL:0009010',
#  'ACAAGCAGTGCCTAGC': 'CL:0009010',
#  'ACAAGGAAATCCGCCC': 'CL:0000186',
#  'ACAAGGACAAGAGGTT': 'CL:0000584',
#  'ACAAGGATGCTTTAGG': 'CL:0000186',
#  'ACAATAGTCGTACGTT': 'CL:0009010',
#  'ACAATCCATTTAAACC': 'CL:0009010',
#  'ACAATGAATACGGAGA': 'CL:0000186',
#  'ACAATTGTGTCTCTTT': 'CL:0000584',
#  'ACAATTTGAGCAGTGG': 'CL:0000584',
#  'ACAATTTGGCCATATT': 'CL:0000844',
#  'ACACAAAGACGGGTGG': 'CL:0009010',
#  'ACACACCAGGACCAGT': 'CL:0000160',
#  'ACACATGATCAAATCT': 'CL:0000186',
#  'ACACCACATAATTAGC': 'CL:0000584',
#  'ACACCCAGCATGCAGC': 'CL:0000584',
#  'ACACCGGTCTGACCGC': 'CL:0009010',
#  'ACACCTTACTACTTGC': 'CL:0009010',
#  'ACACGAGACTCCTTCT': 'CL:0000034',
#  'ACACGGGAACTTAGGG': 'CL:0009010',
#  'ACACGTAGGCCACAAG': 'CL:0000584',
#  'ACACTGATCAAGGTGT': 'CL:0000844',
#  'ACACTGGGACAGTCGT': 'CL:0000584',
#  'ACAGAACTGAGAACAA': 'CL:0000584',
#  'ACAGATTAGGTTAGTG': 'CL:0009010',
#  'ACAGCATAGAGCCAGT': 'CL:0000584',
#  'ACAGCGACATTCTCAT': 'CL:0000186',
#  'ACAGGCACGGATCCTT': 'CL:0000186',
#  'ACAGGCTTGCCCGACT': 'CL:0000066',
#  'ACAGGTGGAGGTGAGG': 'CL:0000584',
#  'ACAGGTGTGTTGTTGC': 'CL:0000186',
#  'ACAGTAATACAACTTG': 'CL:0009010',
#  'ACAGTATACCGTGGGA': 'CL:0000584',
#  'ACATAAGTCGTGGTGA': 'CL:0009010',
#  'ACATAATAAGGCGGTG': 'CL:0000584',
#  'ACATCCCGGCCATACG': 'CL:0000584',
#  'ACATCCTGGTAACTGT': 'CL:0000584',
#  'ACATCGGTCAGCCGCG': 'CL:0000584',
#  'ACATCGTATGCAATGG': 'CL:0000186',
#  'ACATCTCAACGCGTAA': 'CL:0000584',
#  'ACATGCTTACGGCAGC': 'CL:0009010',
#  'ACATGGCGCCAAAGTA': 'CL:0000584',
#  'ACATGGCTCAATTTAG': 'CL:0000844',
#  'ACATTAGTTTATATCC': 'CL:0000034',
#  'ACCAAACTAGAAATCC': 'CL:0009010',
#  'ACCAACCGCACTCCAC': 'CL:0000186',
#  'ACCAACGCTTATTTAT': 'CL:0000584',
#  'ACCAAGAACGCGTGTC': 'CL:0000584',
#  'ACCAATATGCAAGTTA': 'CL:0000844',
#  'ACCACAAGTTTCTATC': 'CL:0000584',
#  'ACCACCAATGTAACAA': 'CL:0009010',
#  'ACCACCCTCTCTTCTA': 'CL:0000584',
#  'ACCACGTGCAGCTATA': 'CL:0000186',
#  'ACCACTGTTCAAGAAG': 'CL:0000584',
#  'ACCAGACCATAACAAC': 'CL:0000057',
#  'ACCAGCCCGGTCTTTG': 'CL:0000584',
#  'ACCAGTGCGGGAGACG': 'CL:0000584',
#  'ACCATCCGCCAACTAG': 'CL:0009010',
#  'ACCATCGTATATGGTA': 'CL:0000584',
#  'ACCATTAAGGGTGTCA': 'CL:0000844',
#  'ACCCACCTACATGCTC': 'CL:0000584',
#  'ACCCATCTTGAGGGTA': 'CL:0000584',
#  'ACCCATTTGTCCCTCT': 'CL:0000186',
#  'ACCCGGAAACTCCCAG': 'CL:0000584',
#  'ACCCGGATGACGCATC': 'CL:0000584',
#  'ACCCGGTTACACTTCC': 'CL:0000034',
#  'ACCCGTAGTCTAGTTG': 'CL:0000787',
#  'ACCCGTGTCATCAGTA': 'CL:0000844',
#  'ACCCTATAGGACTGAG': 'CL:0009010',
#  'ACCCTCCCGTCAGGGC': 'CL:0000186',
#  'ACCCTCCCTTGCTATT': 'CL:0009010',
#  'ACCCTGGTAACGCCCT': 'CL:0000584',
#  'ACCGAAAGGGCCCTGC': 'CL:0000844',
#  'ACCGAAGAGTCTGGTT': 'CL:0000186',
#  'ACCGACTGAGTCCCAC': 'CL:0009010',
#  'ACCGATAGGCATAACC': 'CL:0000584',
#  'ACCGATATTTAATCAT': 'CL:0009010',
#  'ACCGATGGTAGCATCG': 'CL:0000584',
#  'ACCGCAATAACTGCCT': 'CL:0000034',
#  'ACCGCGGTGGAAGTCG': 'CL:0000584',
#  'ACCGGGCCTTTGTTGA': 'CL:0000584',
#  'ACCGGTCAGGTACACC': 'CL:0000186',
#  'ACCGTCCACTGGGCCC': 'CL:0009010',
#  'ACCGTGACCACGTGGG': 'CL:0009010',
#  'ACCGTTCCCGCTCTGA': 'CL:0000584',
#  'ACCTAAGTACCTTTCA': 'CL:0000034',
#  'ACCTAATCGACTTCCT': 'CL:0009010',
#  'ACCTACAGTATGTGGT': 'CL:0000584',
#  'ACCTACTATAAATCTA': 'CL:0000186',
#  'ACCTCCGCCCTCGCTG': 'CL:0000186',
#  'ACCTCCGTTATTCACC': 'CL:0000584',
#  'ACCTCGAACTTATGCT': 'CL:0000584',
#  'ACCTGCGTGTCATGTT': 'CL:0000186',
#  'ACGAAATGGGCGGCAC': 'CL:0009010',
#  'ACGAGATATTTGCTTA': 'CL:0000584',
#  'ACGAGGATACCACTCT': 'CL:0000186',
#  'ACGAGGTTTACAACGT': 'CL:0000186',
#  'ACGAGTACGGATGCCC': 'CL:0000584',
#  'ACGATACATAGAACTA': 'CL:0009010',
#  'ACGATCATACATAGAG': 'CL:0000034',
#  'ACGATCATCTTGTAAA': 'CL:0000584',
#  'ACGATGCATATGTTAT': 'CL:0000584',
#  'ACGCAAACTAATAGAT': 'CL:0009010',
#  'ACGCAATCACTACAGC': 'CL:0000584',
#  'ACGCATACGTTTACTA': 'CL:0000186',
#  'ACGCATTCGTGAGTAC': 'CL:0000584',
#  'ACGCCCAGCTGTCGAT': 'CL:0000584',
#  'ACGCCGCTAGACGACC': 'CL:0001071',
#  'ACGCGAAGTCAGACGA': 'CL:0000584',
#  'ACGCGCTACACAGGGT': 'CL:0000584',
#  'ACGCGGGCCAAGGACA': 'CL:0000584',
#  'ACGCTACTGAATGGGC': 'CL:0009010',
#  'ACGCTAGTGATACACT': 'CL:0000584',
#  'ACGCTGTGAGGCGTAG': 'CL:0009010',
#  'ACGCTTAGTGTCTCTC': 'CL:0000584',
#  'ACGGACGCAGCGACAA': 'CL:0009010',
#  'ACGGACTCTCAAAGCG': 'CL:0000584',
#  'ACGGAGCGCAAATTAC': 'CL:0000584',
#  'ACGGATGGTGCGGATA': 'CL:0000034',
#  'ACGGCACTTGCTTGGG': 'CL:0000034',
#  'ACGGCCAACATGGACT': 'CL:0000186',
#  'ACGGCGACGATGGGAA': 'CL:0000066',
#  'ACGGCGGGTTGCCCTG': 'CL:0000844',
#  'ACGGCTGGATGTAGAA': 'CL:0000844',
#  'ACGGGAGTGTCGGCCC': 'CL:0009010',
#  'ACGGGCGTATGCGACA': 'CL:0000584',
#  'ACGGGTTGTGACCTGT': 'CL:0009010',
#  'ACGGTACAGTTCAATG': 'CL:0009010',
#  'ACGTAGATTGCTGATG': 'CL:0000584',
#  'ACGTATTACTCCGATC': 'CL:0000584',
#  'ACGTCGGGCAACTCGG': 'CL:0009010',
#  'ACGTCTCGTTCCGGGA': 'CL:0009010',
#  'ACGTGACAAAGTAAGT': 'CL:0000186',
#  'ACGTGGTCGAATGTGC': 'CL:0009010',
#  'ACGTTAATGTCGAAGA': 'CL:0000034',
#  'ACGTTAGATTTGCCCG': 'CL:0000034',
#  'ACGTTCCGCGCTCCGT': 'CL:0009010',
#  'ACGTTCGTTCAGGAAA': 'CL:0000584',
#  'ACGTTCTGTACAAGTC': 'CL:0000186',
#  'ACGTTTCGGTGCACTT': 'CL:0009010',
#  'ACTAATACGTCAGGCG': 'CL:0000584',
#  'ACTACATCCCGACAAG': 'CL:0009010',
#  'ACTACGCGTTAGAATT': 'CL:0000844',
#  'ACTAGTTGCGATCGTC': 'CL:0000584',
#  'ACTATATGCTGTGTTC': 'CL:0000844',
#  'ACTATCCAGGGCATGG': 'CL:0009010',
#  'ACTATCGCCGGCTAAA': 'CL:0000844',
#  'ACTATCTGCCCGCGTA': 'CL:0009010',
#  'ACTATTTCCGGGCCCA': 'CL:0000584',
#  'ACTCAACGAATGTATT': 'CL:0000584',
#  'ACTCAAGTGCAAGGCT': 'CL:0000186',
#  'ACTCAATAAAGGCACG': 'CL:0000034',
#  'ACTCATGGCAGCCTTC': 'CL:0000034',
#  'ACTCCCATTCCTAAAG': 'CL:0000186',
#  'ACTCCCGAATTCGTTT': 'CL:0000584',
#  'ACTCCCGTAGACTAGG': 'CL:0000584',
#  'ACTCCCTAATGCTAAA': 'CL:0000584',
#  'ACTCCCTAGAATAGTA': 'CL:0000584',
#  'ACTCCGGCCGACCACT': 'CL:0000186',
#  'ACTCGCCGTTCGATAA': 'CL:0009010',
#  'ACTCGCGATCTGACGC': 'CL:0009010',
#  'ACTCGTAACCCGTCCT': 'CL:0009010',
#  'ACTCGTCAGTAATCCC': 'CL:0000066',
#  'ACTCTCTGACTTAGGT': 'CL:0000584',
#  'ACTCTGACCTAATAGA': 'CL:0000186',
#  'ACTCTTCAGCTCCCGC': 'CL:0009010',
#  'ACTCTTGTATAGTAAC': 'CL:0000844',
#  'ACTGAAACGCCGTTAG': 'CL:0009010',
#  'ACTGAATGGCGAAAGT': 'CL:0000034',
#  'ACTGATTTAGTGATTC': 'CL:0000584',
#  'ACTGCGGACACACCGT': 'CL:0000584',
#  'ACTGCTCGGAAGGATG': 'CL:0009010',
#  'ACTGTACGATACACAT': 'CL:0000844',
#  'ACTGTAGCACTTTGGA': 'CL:0000584',
#  'ACTGTCCAGGATTATA': 'CL:0000066',
#  'ACTGTCTTCTTTAGAA': 'CL:0000186',
#  'ACTTACGCATCCACGC': 'CL:0000584',
#  'ACTTATACTTACCCGG': 'CL:0000066',
#  'ACTTATTAGGATCGGT': 'CL:0000034',
#  'ACTTCAGGCTGATCCC': 'CL:0000034',
#  'ACTTCCAGTGGAAGCT': 'CL:0000844',
#  'ACTTCCATGCGGGACA': 'CL:0000186',
#  'ACTTCGCCATACGCAC': 'CL:0000034',
#  'ACTTGACTCCCTCTTT': 'CL:0000034',
#  'ACTTGGGACCCGGTGG': 'CL:0000584',
#  'ACTTGTAGTCCCTTCA': 'CL:0009010',
#  'ACTTGTGGATGGAACG': 'CL:0000186',
#  'ACTTTACCCTCATGAA': 'CL:0000584',
#  'ACTTTATACACCACTT': 'CL:0009010',
#  'ACTTTCCTATAGCTTC': 'CL:0000584',
#  'ACTTTGACTGCATCCT': 'CL:0000186',
#  'ACTTTGGTCGTGCTCC': 'CL:0009010',
#  'ACTTTGTCGACGCACT': 'CL:0000844',
#  'AGAACACGGCGATGGT': 'CL:0009010',
#  'AGAACCCAGCGTGACA': 'CL:0009010',
#  'AGAACCCTCAATTGGG': 'CL:0000584',
#  'AGAACGTGGTACATTC': 'CL:0009010',
#  'AGAAGAGCGCCGTTCC': 'CL:0000584',
#  'AGAAGGTACACTTCAC': 'CL:0009010',
#  'AGAAGGTTGCCGAATT': 'CL:0000584',
#  'AGAAGGTTGTAGGTCG': 'CL:0000186',
#  'AGAAGTGATTCGTGAT': 'CL:0000034',
#  'AGAATAAATCTTCAGG': 'CL:0000584',
#  'AGAATGCGGGTTCGGA': 'CL:0000584',
#  'AGAATTATGGATTCGA': 'CL:0000584',
#  'AGACAGGCATCTCAGC': 'CL:0009010',
#  'AGACATAGATCCTTCC': 'CL:0009010',
#  'AGACCAAACCACACCT': 'CL:0000186',
#  'AGACCATGGGATACAA': 'CL:0009010',
#  'AGACCCACCGCTGATC': 'CL:0000584',
#  'AGACCCGCCCTCCTCG': 'CL:0009010',
#  'AGACCGCTCCGCGGTT': 'CL:0000584',
#  'AGACCGGGAAACCCTG': 'CL:0000584',
#  'AGACGAAGTGCCGGTC': 'CL:0000186',
#  'AGACGACGATGCCGCT': 'CL:0000186',
#  'AGACGCCCACTTCGCC': 'CL:0000584',
#  'AGACGGGCCGATTTAA': 'CL:0000584',
#  'AGACTAGCCTTCCAGA': 'CL:0009010',
#  'AGACTGTTACCGGGTC': 'CL:0000186',
#  'AGAGAACCGTCTAGGA': 'CL:0000584',
#  'AGAGAAGGAGTACAAT': 'CL:0000584',
#  'AGAGATCTCTAAAGCG': 'CL:0000584',
#  'AGAGCCGCCGAGATTT': 'CL:0000584',
#  'AGAGCGTACAAGCTCG': 'CL:0009010',
#  'AGAGCTACGAAAGCAT': 'CL:0000584',
#  'AGAGGCTTCGGAAACC': 'CL:0000584',
#  'AGAGTAAACTTCACTA': 'CL:0000584',
#  'AGAGTATAGTGTTACG': 'CL:0000584',
#  'AGAGTCTTAATGAAAG': 'CL:0000584',
#  'AGAGTTAGAGACCGAT': 'CL:0009010',
#  'AGATAACTTCAGGGCC': 'CL:0000186',
#  'AGATACCAATAGAACC': 'CL:0009010',
#  'AGATACCAGCACTTCA': 'CL:0000584',
#  'AGATACTCAAGATCGA': 'CL:0000034',
#  'AGATATAATACGACTA': 'CL:0009010',
#  'AGATCTCAGGTGTGAT': 'CL:0009010',
#  'AGATCTGGAGAGGATA': 'CL:0009010',
#  'AGATGACTCGCCCACG': 'CL:0000584',
#  'AGATGATGGAGTCTGG': 'CL:0000844',
#  'AGATGCAAGACGTGCA': 'CL:0009010',
#  'AGATGCATCCTGTGTC': 'CL:0000186',
#  'AGATGCTATAACGAGC': 'CL:0000844',
#  'AGATTATAGGACGTTT': 'CL:0000034',
#  'AGATTCACAACCGATA': 'CL:0009010',
#  'AGCAAAGGCCGCTAGT': 'CL:0000584',
#  'AGCAACATATCTTATT': 'CL:0000584',
#  'AGCAACCGAAAGTAAT': 'CL:0009010',
#  'AGCACCAGTACTCACG': 'CL:0009010',
#  'AGCACTACCGGCCTGT': 'CL:0009010',
#  'AGCACTACCTCACCAG': 'CL:0000066',
#  'AGCACTTAAGGACGCC': 'CL:0009010',
#  'AGCAGAAGGAGAAAGA': 'CL:0009010',
#  'AGCAGCCAGATGAATA': 'CL:0000034',
#  'AGCATATCAATATGCT': 'CL:0000584',
#  'AGCATCATTTCGAAAG': 'CL:0000584',
#  'AGCATCGTCGATAATT': 'CL:0009010',
#  'AGCATTACGAGGCAAG': 'CL:0000034',
#  'AGCCAAGCTTTGTGTC': 'CL:0000584',
#  'AGCCACTCCCGTGCTT': 'CL:0000584',
#  'AGCCCATACATGTAAG': 'CL:0000584',
#  'AGCCCGCAACAAGCAG': 'CL:0000584',
#  'AGCCCGCACTACAATG': 'CL:0000034',
#  'AGCCCGGTAGCCTGTA': 'CL:0009010',
#  'AGCCCTGTCGCACCGT': 'CL:0009010',
#  'AGCCCTTGGACATCCC': 'CL:0000844',
#  'AGCCGTGGCTAAATGT': 'CL:0000584',
#  'AGCCTAATACCCACGT': 'CL:0009010',
#  'AGCCTTGTCACTGATA': 'CL:0009010',
#  'AGCGACAGGAACGGTC': 'CL:0009010',
#  'AGCGACATCCCATTCA': 'CL:0000584',
#  'AGCGACCAACGATATT': 'CL:0009010',
#  'AGCGAGACGTGAAGGC': 'CL:0000584',
#  'AGCGATGCGCCTAATA': 'CL:0009010',
#  'AGCGCATAATGAATCG': 'CL:0009010',
#  'AGCGCTAGAGCGATGT': 'CL:0009010',
#  'AGCGCTTATGGGCAAG': 'CL:0009010',
#  'AGCGGCGGTTAGCGGT': 'CL:0009010',
#  'AGCGGGTCTGACACTC': 'CL:0009010',
#  'AGCGGTTGCCGCTCTG': 'CL:0000584',
#  'AGCGTCTGAACCCGCA': 'CL:0000584',
#  'AGCGTGGTATTCTACT': 'CL:0000584',
#  'AGCTAACAAGCAATGT': 'CL:0000584',
#  'AGCTCCATATATGTTC': 'CL:0000584',
#  'AGCTCCTTCGCACATC': 'CL:0000584',
#  'AGCTCTAGACGTTCCA': 'CL:0000034',
#  'AGCTCTTCGTAACCTT': 'CL:0009010',
#  'AGCTCTTTACTCAGTT': 'CL:0000034',
#  'AGCTGTAACCTCAATC': 'CL:0000034',
#  'AGCTTATAGAGACCTG': 'CL:0009010',
#  'AGCTTCTTCTCGAGCA': 'CL:0000186',
#  'AGCTTGATCAGGGTAG': 'CL:0000584',
#  'AGCTTGATCTTAACTT': 'CL:0000584',
#  'AGGAACGAACGACTTC': 'CL:0000584',
#  'AGGACAGTCGAATCCC': 'CL:0000034',
#  'AGGACATCGGCACACT': 'CL:0000584',
#  'AGGACGACCCATTAGA': 'CL:0000584',
#  'AGGACTTATAGGAGAA': 'CL:0009010',
#  'AGGAGACATCCACAGT': 'CL:0000584',
#  'AGGAGAGTCTGGCTAC': 'CL:0000584',
#  'AGGAGCGTTTATTATC': 'CL:0000584',
#  'AGGAGGCCTTCGCGCG': 'CL:0000584',
#  'AGGATAAAGTCGGGAT': 'CL:0000584',
#  'AGGATATAGGGATTTA': 'CL:0000034',
#  'AGGATATCCGACTGCA': 'CL:0009010',
#  'AGGATCACGCGATCTG': 'CL:0009010',
#  'AGGATTGCTTACGACA': 'CL:0009010',
#  'AGGCAGATGCGTAAAC': 'CL:0000584',
#  'AGGCAGGGAGCGTACT': 'CL:0000066',
#  'AGGCATTGTCGTAGGG': 'CL:0000584',
#  'AGGCCACATTGGTTAC': 'CL:0009010',
#  'AGGCCACCCGTTATGA': 'CL:0000584',
#  'AGGCCCAGTGACTGGT': 'CL:0000584',
#  'AGGCCCTAGAACGCCA': 'CL:0000186',
#  'AGGCCTGAGAATCTCG': 'CL:0000186',
#  'AGGCGATAACTGGCGT': 'CL:0000584',
#  'AGGCGGTTTGTCCCGC': 'CL:0000186',
#  'AGGCGTCTATGGACGG': 'CL:0000584',
#  'AGGCTATGGTTAGCTT': 'CL:0000186',
#  'AGGCTTCCCGAAGAAG': 'CL:0000584',
#  'AGGGACAGCACGGCGG': 'CL:0009010',
#  'AGGGACCGGCTGCGTT': 'CL:0000584',
#  'AGGGACTCTACGCGAC': 'CL:0000186',
#  'AGGGCCCTAATGTTCT': 'CL:0000584',
#  'AGGGCGAGCAGCTGAT': 'CL:0000584',
#  'AGGGCGTGATCGGCTA': 'CL:0000584',
#  'AGGGCTGCAGTTACAG': 'CL:0000057',
#  'AGGGTCAGTAACCCTA': 'CL:0000584',
#  'AGGGTCGATGCGAACT': 'CL:0000844',
#  'AGGGTCTGGACGCAGT': 'CL:0000584',
#  'AGGGTGCTCTCGAGGG': 'CL:0000066',
#  'AGGGTTCCCTTTGGTT': 'CL:0000066',
#  'AGGGTTTAGTTCGGGA': 'CL:0000584',
#  'AGGTAGGTACAAAGCT': 'CL:0000186',
#  'AGGTATAATTGATAGT': 'CL:0000584',
#  'AGGTATGCGGACATTA': 'CL:0009010',
#  'AGGTCAGGTGAGAGTG': 'CL:0000844',
#  'AGGTCGCCACTTCGGT': 'CL:0000584',
#  'AGGTCGCCTCCCAACA': 'CL:0000584',
#  'AGGTCGCGGAGTTACT': 'CL:0000584',
#  'AGGTGCACGTCCACAT': 'CL:0000034',
#  'AGGTGGTGACCTTCGC': 'CL:0009010',
#  'AGGTGTATCGCCATGA': 'CL:0009010',
#  'AGGTTCTCCTTTCCGG': 'CL:0009010',
#  'AGGTTGAGGCACGCTT': 'CL:0009010',
#  'AGTAACGTTCATCCTG': 'CL:0000584',
#  'AGTACATCATTTATCA': 'CL:0000584',
#  'AGTACGGGCACCTGGC': 'CL:0009010',
#  'AGTACGTGGCCTGTCT': 'CL:0000584',
#  'AGTACTCTTATGCCCA': 'CL:0000584',
#  'AGTAGCGTGAACGAAC': 'CL:0009010',
#  'AGTATAATACTAGGCA': 'CL:0009010',
#  'AGTATACACAGCGACA': 'CL:0000186',
#  'AGTATGCTGGAGACCA': 'CL:0009010',
#  'AGTATTTGGCACGACC': 'CL:0000584',
#  'AGTCAACACCACCATC': 'CL:0000034',
#  'AGTCAAGATGACACTT': 'CL:0000066',
#  'AGTCACTAGCTCTCGA': 'CL:0000584',
#  'AGTCACTCCGCCTCAT': 'CL:0000584',
#  'AGTCCATTGGCTGATG': 'CL:0000584',
#  'AGTCCCTCGCAGAAAG': 'CL:0000584',
#  'AGTCGAAACGATTCAG': 'CL:0009010',
#  'AGTCGACGGTCTCAAG': 'CL:0000584',
#  'AGTCGGCCCAAACGAC': 'CL:0009010',
#  'AGTCGGCTCAACTTTA': 'CL:0000584',
#  'AGTCGGTTGCGTGAGA': 'CL:0009010',
#  'AGTCGTCGACCACCAA': 'CL:0009010',
#  'AGTCGTGGGCATTACG': 'CL:0000584',
#  'AGTCTCACAAGACTAC': 'CL:0000844',
#  'AGTCTTCTCCTCAAAT': 'CL:0000034',
#  'AGTCTTTAAAGTGTCC': 'CL:0009010',
#  'AGTGAACAAACTTCTC': 'CL:0000584',
#  'AGTGACCTACTTTACG': 'CL:0000844',
#  'AGTGAGACTTCCAGTA': 'CL:0000584',
#  'AGTGAGCCTCGCCGCC': 'CL:0000584',
#  'AGTGAGGGTTTCTGAC': 'CL:0000584',
#  'AGTGAGTCGAATTAAC': 'CL:0000186',
#  'AGTGATAACCTGCGCG': 'CL:0009010',
#  'AGTGATATGAGTAGTT': 'CL:0000584',
#  'AGTGATTCAAGCAGGA': 'CL:0000584',
#  'AGTGCACGCTTAAGAA': 'CL:0000584',
#  'AGTGCGTAGCTCGTAA': 'CL:0000584',
#  'AGTGCTAAACACAGCA': 'CL:0009010',
#  'AGTGCTTGCACGAATA': 'CL:0000584',
#  'AGTGGCGTCTGAAGGT': 'CL:0000186',
#  'AGTGGCTCCGTCGGCC': 'CL:0009010',
#  'AGTGGTGTTACCCGTG': 'CL:0009010',
#  'AGTGTGCTAAGATCGC': 'CL:0000584',
#  'AGTTAAACACTTGCGA': 'CL:0000034',
#  'AGTTATTCAGACTGTG': 'CL:0000584',
#  'AGTTATTGAAAGGTAA': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000584',
#  'AGTTCCTATTTATGTT': 'CL:0000034',
#  'AGTTCTGCGTTGTATC': 'CL:0000844',
#  'AGTTGACGGTCCTTGC': 'CL:0000034',
#  'AGTTGGCAAGGCTAGA': 'CL:0000186',
#  'AGTTTGCACCTGCCTC': 'CL:0000584',
#  'AGTTTGGCACGGGTTG': 'CL:0000584',
#  'AGTTTGGCCAGACCTA': 'CL:0000186',
#  'ATAAACCATTGGACGG': 'CL:0000584',
#  'ATAAACGGACCCGTAA': 'CL:0000584',
#  'ATAAACGTTGCACCAC': 'CL:0000584',
#  'ATAAAGGCTCGGTCGT': 'CL:0000034',
#  'ATAAAGGTCAAGTACG': 'CL:0000584',
#  'ATAAATATTAGCAGCT': 'CL:0000584',
#  'ATAACGCCGGAGGGTC': 'CL:0000584',
#  'ATAACGGAGTCCAACG': 'CL:0000584',
#  'ATAACGTTACCTCCAC': 'CL:0000584',
#  'ATAAGGTGGAGAACAT': 'CL:0000584',
#  'ATAAGTACCCGATTGT': 'CL:0000584',
#  'ATAAGTAGGATTCAGA': 'CL:0000584',
#  'ATAAGTAGGGCGACTC': 'CL:0009010',
#  'ATAAGTTACCGCGACG': 'CL:0000066',
#  'ATAATAGCTGTTGAAT': 'CL:0000034',
#  'ATAATCTTGGAGAACC': 'CL:0009010',
#  'ATAATTAGCTAAGTAG': 'CL:0009010',
#  'ATACAGGCCCTCCAAT': 'CL:0000584',
#  'ATACCACGGGCAACTT': 'CL:0000584',
#  'ATACCAGCAAATTGCT': 'CL:0000584',
#  'ATACCAGGCTAATAGA': 'CL:0000844',
#  'ATACCCTCCCGGCCAA': 'CL:0009010',
#  'ATACCGTCATCCATAA': 'CL:0000584',
#  'ATACCTAACCAAGAAA': 'CL:0000066',
#  'ATACGAAGGCTTTCCA': 'CL:0009010',
#  'ATACGCCGGCGAAACC': 'CL:0000584',
#  'ATACGGAACGTCGTTT': 'CL:0000584',
#  'ATACGGGTTTCGATTG': 'CL:0009010',
#  'ATACGTACTTAGCCAC': 'CL:0000066',
#  'ATACGTCCACTCCTGT': 'CL:0000034',
#  'ATACGTTATGCACGGA': 'CL:0000584',
#  'ATACTACCCGTACCAC': 'CL:0009010',
#  'ATACTAGCATGACCCT': 'CL:0000584',
#  'ATACTGCCTTACACCG': 'CL:0000584',
#  'ATAGACAACGGGACCT': 'CL:0000584',
#  'ATAGACGAAGAGAAAG': 'CL:0009010',
#  'ATAGAGTACTGGGACA': 'CL:0009010',
#  'ATAGAGTTATCAACTT': 'CL:0000584',
#  'ATAGCAACTAGGGAAG': 'CL:0000186',
#  'ATAGCCATAACAGTCA': 'CL:0000787',
#  'ATAGGAATCTAAGCTT': 'CL:0009010',
#  'ATAGGCGGCTATAGAA': 'CL:0000584',
#  'ATAGGCTAGCTTCGCA': 'CL:0000584',
#  'ATAGGGATATCCTTGA': 'CL:0000844',
#  'ATAGGTTGGGCAGATG': 'CL:0000584',
#  'ATAGTGAAGCGTTCTC': 'CL:0000034',
#  'ATAGTTCCACCCACTC': 'CL:0000584',
#  'ATATAAAGCGCTCGTG': 'CL:0000034',
#  'ATATAAATGTAGCTGC': 'CL:0000844',
#  'ATATAACACGGGCGCA': 'CL:0000186',
#  'ATATACATGTATGGTA': 'CL:0000844',
#  'ATATACGCTCGTGACG': 'CL:0009010',
#  'ATATAGAGTATTGGTC': 'CL:0000584',
#  'ATATCAACCTACAGAG': 'CL:0009010',
#  'ATATCAATTCCAGCCT': 'CL:0009010',
#  'ATATCGGTAGGGAGAT': 'CL:0009010',
#  'ATATCGTGCCAGACCC': 'CL:0000584',
#  'ATATCGTTCCTCGAAC': 'CL:0009010',
#  'ATATCTTAGGGCCTTC': 'CL:0000584',
#  'ATATGTCTCCCTAGCC': 'CL:0000584',
#  'ATATTCAGTTAAACCT': 'CL:0000584',
#  'ATATTCCACATAGTGA': 'CL:0000066',
#  'ATATTCCCACAGGTCA': 'CL:0000584',
#  'ATATTGGAGAGGCCTT': 'CL:0000584',
#  'ATATTTAACCCTCAAG': 'CL:0000034',
#  'ATCAAACACTGTTCCA': 'CL:0000186',
#  'ATCAAACGAAGGTTTG': 'CL:0000034',
#  'ATCAATCTGGGCTGCA': 'CL:0000844',
#  'ATCAATGCCGTGGCTG': 'CL:0000584',
#  'ATCACGTGCTAATTAA': 'CL:0009010',
#  'ATCACTTCATCCTCGC': 'CL:0000584',
#  'ATCAGACGGCACGCCG': 'CL:0000584',
#  'ATCAGCCTCATGCTGC': 'CL:0000584',
#  'ATCAGCTCGTCCACTA': 'CL:0009010',
#  'ATCAGGTCGCCATTGC': 'CL:0000584',
#  'ATCAGTAGGCAGGGAT': 'CL:0009010',
#  'ATCATAGCCCTATGTA': 'CL:0009010',
#  'ATCATCCAATATTTGT': 'CL:0000844',
#  'ATCATGGACTACCGAC': 'CL:0009010',
#  'ATCATTGTACCGCATT': 'CL:0000844',
#  'ATCCAACGCAGTCATA': 'CL:0000584',
#  'ATCCAATGGAGGGTCC': 'CL:0000844',
#  'ATCCACATCGACAGAA': 'CL:0000584',
#  'ATCCACGCTAAATGTT': 'CL:0000584',
#  'ATCCAGAGCAACAACC': 'CL:0000034',
#  'ATCCAGGATTCGTGAA': 'CL:0000186',
#  'ATCCCATCCACAGCGC': 'CL:0000584',
#  'ATCCTACCTAAGCTCT': 'CL:0000034',
#  'ATCCTGAATCGCTGCG': 'CL:0000584',
#  'ATCCTGCGTGGAATGG': 'CL:0000034',
#  'ATCCTGCTGCAGATAG': 'CL:0009010',
#  'ATCCTTCTGAAAGAAC': 'CL:0000584',
#  'ATCGACCCAATACAGA': 'CL:0000066',
#  'ATCGACTCTTTCCGTT': 'CL:0000034',
#  'ATCGCACGATTGTTCA': 'CL:0000584',
#  'ATCGCACGCCGGGAGA': 'CL:0009010',
#  'ATCGCCAGTCAACATT': 'CL:0000584',
#  'ATCGCCGTGGTTCATG': 'CL:0000844',
#  'ATCGCTGCGTGCAGCA': 'CL:0000584',
#  'ATCGCTTTACGTCTCA': 'CL:0009010',
#  'ATCGGAGACAGACGGC': 'CL:0000034',
#  'ATCGTCCAATCGAGTC': 'CL:0000584',
#  'ATCGTTAGCTAGCGGA': 'CL:0000186',
#  'ATCGTTCACTTTCGCC': 'CL:0000584',
#  'ATCTAATATCCTACGG': 'CL:0000584',
#  'ATCTACCATCTGCTCC': 'CL:0000034',
#  'ATCTAGCTTGTGAGGG': 'CL:0000186',
#  'ATCTCCCACGGAATAT': 'CL:0000584',
#  'ATCTCGTGAGCGAAAC': 'CL:0000584',
#  'ATCTGCACCTCTGCGA': 'CL:0000584',
#  'ATCTGCTGTTATCGCC': 'CL:0000186',
#  'ATCTGGGCTGTTCTTG': 'CL:0000584',
#  'ATCTGGTTAAGACTGT': 'CL:0000584',
#  'ATCTTATCGCACACCC': 'CL:0009010',
#  'ATCTTGACTTGTCCAA': 'CL:0000584',
#  'ATCTTTCGTATAACCA': 'CL:0000584',
#  'ATGAAGCCAAGGAGCC': 'CL:0009010',
#  'ATGACGCGTTCTATCC': 'CL:0000844',
#  'ATGACTATCAGCTGTG': 'CL:0009010',
#  'ATGACTATGCGACATT': 'CL:0000584',
#  'ATGAGGAGTGTTAATC': 'CL:0009010',
#  'ATGAGGGCAGCGGCTA': 'CL:0009010',
#  'ATGATCGGGAATAGAC': 'CL:0000584',
#  'ATGATGCAATGGTACA': 'CL:0000034',
#  'ATGCACGCGCTGTTCA': 'CL:0009010',
#  'ATGCACTACCGCATTG': 'CL:0009010',
#  'ATGCATGATCCAGGAT': 'CL:0000034',
#  'ATGCCAATCGCTCTGC': 'CL:0000775',
#  'ATGCCATTTGCGACCA': 'CL:0000584',
#  'ATGCCGGTCTTGCATA': 'CL:0000034',
#  'ATGCGACAATTGGTCC': 'CL:0000584',
#  'ATGCGACAGTCCCATT': 'CL:0000844',
#  'ATGCGAGTCCCACCAC': 'CL:0009010',
#  'ATGCTCAGTGTTGCAT': 'CL:0009010',
#  'ATGCTCTGGCGCGGTA': 'CL:0000584',
#  'ATGCTTAGGAGTTGAT': 'CL:0000584',
#  'ATGGAAATTTAAGGAG': 'CL:0000186',
#  'ATGGAACCTTTGCACA': 'CL:0000584',
#  'ATGGAGCAGGCCGTGA': 'CL:0000584',
#  'ATGGATTGACCAAACG': 'CL:0000844',
#  'ATGGCAGCATTACGAT': 'CL:0009010',
#  'ATGGCCCGAAAGGTTA': 'CL:0000584',
#  'ATGGCGGAATAGTCGC': 'CL:0009010',
#  'ATGGCTGGAAATGGCC': 'CL:0000584',
#  'ATGGGAACGGAAGCGG': 'CL:0009010',
#  'ATGGGCCTCGGCCTCT': 'CL:0000034',
#  'ATGGTCGCGTGGTTTC': 'CL:0000034',
#  'ATGTAAGGCTGCTCTT': 'CL:0000584',
#  'ATGTACATGCGGTGAG': 'CL:0009010',
#  'ATGTACGATGACGTCG': 'CL:0009010',
#  'ATGTAGCGCGCGTAGG': 'CL:0000584',
#  'ATGTGAAAGCCTAATG': 'CL:0000584',
#  'ATGTGCATCCGACGCA': 'CL:0000034',
#  'ATGTGGACATCTTGAT': 'CL:0000584',
#  'ATGTGTAGTTTAGTCA': 'CL:0009010',
#  'ATGTTGATTAGAGACT': 'CL:0000186',
#  'ATGTTGTAGTCTGTTT': 'CL:0000186',
#  'ATTAAACATGCGGACC': 'CL:0000034',
#  'ATTAATACTACGCGGG': 'CL:0009010',
#  'ATTAATGAACCAGTCG': 'CL:0000584',
#  'ATTACATGTCAGTCTT': 'CL:0000186',
#  'ATTACCACACTGCCTG': 'CL:0000584',
#  'ATTACGACTCCACAGT': 'CL:0000584',
#  'ATTACGCGCTGGCAGG': 'CL:0000186',
#  'ATTACGGGCTACGGTT': 'CL:0009010',
#  'ATTACTAGCCTCTTGC': 'CL:0000584',
#  'ATTAGATTCCTCAGCA': 'CL:0000584',
#  'ATTAGATTGATAGCGG': 'CL:0000034',
#  'ATTAGGCGATGCTTTC': 'CL:0000034',
#  'ATTATCTCGACAGATC': 'CL:0000584',
#  'ATTATGAGACCCAATT': 'CL:0009010',
#  'ATTATGCCATAGGGAG': 'CL:0000584',
#  'ATTATTATGTCCGTCA': 'CL:0000584',
#  'ATTATTCAGAGTCACT': 'CL:0000186',
#  'ATTCAACCATTTAAGG': 'CL:0000186',
#  'ATTCACTGATGTTGGA': 'CL:0000844',
#  'ATTCATATACTGTCCA': 'CL:0000584',
#  'ATTCATCGTTGAGGCA': 'CL:0000186',
#  'ATTCCCGAAGGTACAG': 'CL:0000844',
#  'ATTCCTAAGACGTGGA': 'CL:0000584',
#  'ATTCGACGCCGGGCCT': 'CL:0000584',
#  'ATTCGCGCCTTGAGAG': 'CL:0009010',
#  'ATTCGTCCCGAGGTTA': 'CL:0000584',
#  'ATTCGTGCTATCTCTT': 'CL:0009010',
#  'ATTCGTTTATCGTATT': 'CL:0000584',
#  'ATTCTTCGTACTTATG': 'CL:0009010',
#  'ATTGAAGATCTTAGTG': 'CL:0000186',
#  'ATTGAATTCCCTGTAG': 'CL:0000584',
#  'ATTGACCGGCGATGAC': 'CL:0000584',
#  'ATTGATAGCAACGAGA': 'CL:0009010',
#  'ATTGATCACCACATTT': 'CL:0000186',
#  'ATTGATGAGTCCTAAC': 'CL:0000584',
#  'ATTGCGATCAGTAACT': 'CL:0000584',
#  'ATTGCTGCTCCTCCAT': 'CL:0000584',
#  'ATTGGATTACAGCGTA': 'CL:0000584',
#  'ATTGTACAACTCGGCT': 'CL:0009010',
#  'ATTGTGACTTCGCTGC': 'CL:0000584',
#  'ATTGTTCAACGATCCG': 'CL:0009010',
#  'ATTTACAGTTTACTGG': 'CL:0009010',
#  'ATTTACTAAGTCCATT': 'CL:0000584',
#  'ATTTCCGGGTTCTGCG': 'CL:0000584',
#  'ATTTGCGCGAGTAGCT': 'CL:0000584',
#  'ATTTGTCTTGGGAGCT': 'CL:0000034',
#  'ATTTGTTCCAGGGCTC': 'CL:0000584',
#  'CAAACGAGTATCGCAG': 'CL:0000584',
#  'CAAACGGTCGCACTTT': 'CL:0000584',
#  'CAAACGTGGTCTTGCG': 'CL:0000584',
#  'CAAACTCGCGACGCCG': 'CL:0009010',
#  'CAAAGATTATTGGGCC': 'CL:0000034',
#  'CAAAGGTCATCTGAAA': 'CL:0009010',
#  'CAAAGTCAGGTTAGCT': 'CL:0000584',
#  'CAAATCTCTCACAAGG': 'CL:0000186',
#  'CAAATGTCCTTCCGTG': 'CL:0000844',
#  'CAAATTGGATTATGCC': 'CL:0000584',
#  'CAACACATCTCCTGCC': 'CL:0009010',
#  'CAACATGGCCTGATAA': 'CL:0009010',
#  'CAACCAGTGGCCTACC': 'CL:0000584',
#  'CAACCGCACCTAGACA': 'CL:0000844',
#  'CAACCTACCGAGCAGT': 'CL:0009010',
#  'CAACGACCCGTTTACA': 'CL:0000584',
#  'CAACGAGCTTATTATG': 'CL:0000186',
#  'CAACTCCAACGTTTAG': 'CL:0000584',
#  'CAACTCCGTAACTTGC': 'CL:0000584',
#  'CAACTCCTTGATCCCG': 'CL:0000584',
#  'CAACTGCTCATCCGAT': 'CL:0000186',
#  'CAAGAGGGCGGAGTAC': 'CL:0000034',
#  'CAAGATATTATAACGT': 'CL:0000034',
#  'CAAGCAACGTCGGAGT': 'CL:0000584',
#  'CAAGCGGCACATAATT': 'CL:0000034',
#  'CAAGGATCGCATGTTC': 'CL:0009010',
#  'CAAGGCCAGTGGTGCA': 'CL:0000186',
#  'CAAGGTCCTATAGGCT': 'CL:0000584',
#  'CAAGTGTGGTTGCAAA': 'CL:0000066',
#  'CAATAAACCTTGGCCC': 'CL:0000066',
#  'CAATACGAGAGTCTGA': 'CL:0009010',
#  'CAATACGCTCTGAGGC': 'CL:0000584',
#  'CAATATGTAGATTTAC': 'CL:0009010',
#  'CAATATTCTTGACCTA': 'CL:0000844',
#  'CAATATTGGACTAGTG': 'CL:0000584',
#  'CAATGAGGTTCGACTA': 'CL:0009010',
#  'CAATGCGAGAAGTATC': 'CL:0000584',
#  'CAATGGAATCTACATA': 'CL:0009010',
#  'CAATGGATCTCTACCA': 'CL:0000584',
#  'CAATGGTCGGCCTGGG': 'CL:0009010',
#  'CAATTAAGGGTGATGA': 'CL:0000186',
#  'CAATTGGGCCGCACTC': 'CL:0000844',
#  'CAATTTCGTATAAGGG': 'CL:0000584',
#  'CAATTTGACCGGGAAG': 'CL:0000584',
#  'CACAAACCGCAGAACT': 'CL:0000034',
#  'CACAAGAAAGATATTA': 'CL:0000584',
#  'CACAAGCTAAGAAAGG': 'CL:0009010',
#  'CACAATGAGCTGCTAT': 'CL:0000844',
#  'CACACACGCTAACGAG': 'CL:0000186',
#  'CACACAGCTTGCGCTC': 'CL:0000584',
#  'CACACAGGGATAGATT': 'CL:0009010',
#  'CACACGCGCTGTCTTA': 'CL:0000584',
#  'CACACGTTTCAATGGG': 'CL:0000584',
#  'CACACTTGTATTGCGA': 'CL:0000584',
#  'CACAGAGACGAGGACG': 'CL:0009010',
#  'CACAGCACCCACGGCA': 'CL:0000584',
#  'CACAGCTAGGGAGTGA': 'CL:0000584',
#  'CACAGGGCCATATAGT': 'CL:0000186',
#  'CACAGGGCCGTTGTCA': 'CL:0000584',
#  'CACAGTCCCGCTTCGC': 'CL:0000057',
#  'CACATATTAGCAGGAT': 'CL:0000584',
#  'CACATCGTGCACGCGC': 'CL:0000584',
#  'CACATCTCACCGACGA': 'CL:0000034',
#  'CACATGTTTGGACATG': 'CL:0000584',
#  'CACATTTCTTGTCAGA': 'CL:0009010',
#  'CACCAATCATCCGTCT': 'CL:0009010',
#  'CACCACGCCACACAGA': 'CL:0009010',
#  'CACCAGTCAGCATGCA': 'CL:0000584',
#  'CACCATGATCGCAAAG': 'CL:0000844',
#  'CACCCAAATCTTATGT': 'CL:0009010',
#  'CACCCACACGTCACCC': 'CL:0000584',
#  'CACCCGCGTTTGACAC': 'CL:0000787',
#  'CACCCGGTTTGTGACT': 'CL:0000584',
#  'CACCCTAACAAGATCT': 'CL:0000066',
#  'CACCCTTGGTGAGACC': 'CL:0000057',
#  'CACCGATGATGGGTAC': 'CL:0000584',
#  'CACCGCCAGAAGGTTT': 'CL:0000775',
#  'CACCGGAGATATCTCC': 'CL:0009010',
#  'CACCGGTAGAGACATT': 'CL:0009010',
#  'CACCGTATCCCATCCG': 'CL:0000584',
#  'CACCGTTAGGGATCAC': 'CL:0000584',
#  'CACCGTTGCGCGATAT': 'CL:0000186',
#  'CACCTAATCAGTTTAC': 'CL:0009010',
#  'CACCTTGCGAAACTCG': 'CL:0009010',
#  'CACCTTGGCGCCTTTG': 'CL:0000584',
#  'CACGAAAGTTAGTCCC': 'CL:0009010',
#  'CACGACGTAATAGTAA': 'CL:0000584',
#  'CACGCACAGCGCAGCT': 'CL:0000584',
#  'CACGCAGCGAGGCTTT': 'CL:0000584',
#  'CACGCGGAACTGTTGC': 'CL:0000844',
#  'CACGGACGTGGATGGC': 'CL:0000584',
#  'CACGTCAATCAATGGA': 'CL:0000584',
#  'CACGTCGGCAACCTCT': 'CL:0000034',
#  'CACGTCGGGTTCTAGA': 'CL:0000844',
#  'CACGTCTATGATGTGG': 'CL:0000584',
#  'CACGTTCGTGCTCTAG': 'CL:0000186',
#  'CACGTTTCGTACACAC': 'CL:0000584',
#  'CACTAAAGTTGCCTAT': 'CL:0000034',
#  'CACTACGGGAGCTGCC': 'CL:0000584',
#  'CACTCAAGAGCTATGG': 'CL:0000034',
#  'CACTCCTATGTAAGAT': 'CL:0000584',
#  'CACTCGAGCTGAACAA': 'CL:0000034',
#  'CACTCGGTTAGGAGGA': 'CL:0009010',
#  'CACTCTTCTGCTAGCC': 'CL:0000186',
#  'CACTGACGATTGTGGA': 'CL:0000186',
#  'CACTGTCCAAGTGAGA': 'CL:0000584',
#  'CACTTAATCAGACGGA': 'CL:0009010',
#  'CACTTCGCCACAGGCT': 'CL:0009010',
#  'CACTTCGTCTTATCTC': 'CL:0009010',
#  'CAGAACTTAGCCCTCT': 'CL:0000066',
#  'CAGAATAACACACGGA': 'CL:0000584',
#  'CAGAATATTCGTTATC': 'CL:0009010',
#  'CAGACACCGATCGCTG': 'CL:0000584',
#  'CAGACCTGTAAGTGTT': 'CL:0000584',
#  'CAGACGAACCTGATAC': 'CL:0000584',
#  'CAGAGACGGTCACCCA': 'CL:0000186',
#  'CAGAGCATGAGCTTGC': 'CL:0000034',
#  'CAGAGCGATGGATGCT': 'CL:0009010',
#  'CAGAGGCGATGCATGA': 'CL:0000584',
#  'CAGATAATGGGCGGGT': 'CL:0000186',
#  'CAGATACTAACATAGT': 'CL:0009010',
#  'CAGATATGAAGATGAC': 'CL:0009010',
#  'CAGATCATTTAAAGTC': 'CL:0000584',
#  'CAGATCCTGGTTTGAA': 'CL:0009010',
#  'CAGATGTTTGTCCCAA': 'CL:0009010',
#  'CAGCAGCCCGTTCCTT': 'CL:0000034',
#  'CAGCAGTCCAGACTAT': 'CL:0000584',
#  'CAGCAGTCTGTGCTGC': 'CL:0000584',
#  'CAGCCCTCACAGGCAG': 'CL:0000584',
#  'CAGCCTCCTGCAGAGG': 'CL:0009010',
#  'CAGCGATTCCCTTCAA': 'CL:0000034',
#  'CAGCTCACTGAGACAT': 'CL:0009010',
#  'CAGCTCGACAAGTTAA': 'CL:0000584',
#  'CAGCTGGCGTAACCGT': 'CL:0009010',
#  'CAGCTTAGTAGGTAGC': 'CL:0009010',
#  'CAGGACAGCTGCCCTT': 'CL:0009010',
#  'CAGGATATATCGTTGT': 'CL:0000844',
#  'CAGGCCGTTTGGGTGT': 'CL:0000186',
#  'CAGGCGCACGGTGGTC': 'CL:0000584',
#  'CAGGCGCCATGCTAGG': 'CL:0000034',
#  'CAGTAAGGGACGTCTC': 'CL:0009010',
#  'CAGTAATCCCTCCCAG': 'CL:0000186',
#  'CAGTACCAGTTTACGT': 'CL:0000186',
#  'CAGTAGCCCACGCGGT': 'CL:0000584',
#  'CAGTAGCGAGGTAGTA': 'CL:0009010',
#  'CAGTCGGCCTAGATAT': 'CL:0000186',
#  'CAGTGAATAAATGACT': 'CL:0000584',
#  'CAGTGTCGGCTGGCCC': 'CL:0000186',
#  'CAGTTCAAATTGACAC': 'CL:0000584',
#  'CAGTTCCGCGGGTCGA': 'CL:0000584',
#  'CATAACGGACAGTCGT': 'CL:0000844',
#  'CATAAGAAGCTTGGCT': 'CL:0000034',
#  'CATAAGCTCTCCGTCT': 'CL:0000584',
#  'CATAATGAGCGGGCGA': 'CL:0009010',
#  'CATACACAAAGTCAGC': 'CL:0000844',
#  'CATACACGGTTCCCAC': 'CL:0000584',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACTATGTAATTGT': 'CL:0009010',
#  'CATACTTAGGCAATAC': 'CL:0000584',
#  'CATAGAGGAGATACTA': 'CL:0000584',
#  'CATAGCGTTGCCCACC': 'CL:0000034',
#  'CATAGTAGCATAGTAG': 'CL:0000584',
#  'CATAGTCAAATACATA': 'CL:0007011',
#  'CATAGTCCACAAGAAC': 'CL:0009010',
#  'CATAGTGGGCACGCCT': 'CL:0009010',
#  'CATATAGGTACAGTCA': 'CL:0000066',
#  'CATATGTCAGGCTACG': 'CL:0000034',
#  'CATCAAACTGGCGCCC': 'CL:0000584',
#  'CATCATTACCCTGAGG': 'CL:0000584',
#  'CATCCAATATAGTTTG': 'CL:0009010',
#  'CATCCCGAGATTCATA': 'CL:0000034',
#  'CATCCTCTCAAAGATC': 'CL:0000584',
#  'CATCGGACGGGTTAAT': 'CL:0000584',
#  'CATCTAGTGAAGGGAA': 'CL:0009010',
#  'CATCTTACACCACCTC': 'CL:0000066',
#  'CATGAACCTCTTATCA': 'CL:0000584',
#  'CATGACTTCGCTGAAT': 'CL:0000584',
#  'CATGAGATGCACTCTC': 'CL:0000584',
#  'CATGATCGCTTTGAGA': 'CL:0000584',
#  'CATGATGCACAATTCT': 'CL:0000584',
#  'CATGATGGAAGTTAGC': 'CL:0000186',
#  'CATGCCAACTCGCAAA': 'CL:0000584',
#  'CATGCGACCAGTTTAA': 'CL:0000584',
#  'CATGGAAATGGGACCA': 'CL:0000844',
#  'CATGGATTGTCTTCCG': 'CL:0000584',
#  'CATGGCAGGAAGATCG': 'CL:0000584',
#  'CATGGGTATGCCTTAT': 'CL:0000034',
#  'CATGGTAAGTAGCGTT': 'CL:0000066',
#  'CATGGTCTAGATACCG': 'CL:0009010',
#  'CATGGTTTATTAATCA': 'CL:0000186',
#  'CATGTAAGAGACATTT': 'CL:0000584',
#  'CATGTAGGAGCGCCAA': 'CL:0000584',
#  'CATGTCTCATTTATGG': 'CL:0000584',
#  'CATTACATAGATTGTG': 'CL:0009010',
#  'CATTACGTCGGCCCGT': 'CL:0009010',
#  'CATTATGCTTGTTGTG': 'CL:0009010',
#  'CATTCACTGACAGCTA': 'CL:0000584',
#  'CATTCCCATTCCGTCG': 'CL:0000584',
#  'CATTCCCTAAGTACAA': 'CL:0000844',
#  'CATTCGTCGTAGCGGT': 'CL:0000584',
#  'CATTGCGAAATGGGCG': 'CL:0000584',
#  'CATTGCGGGTCAATTC': 'CL:0009010',
#  'CATTGTGTGCTAGATC': 'CL:0000584',
#  'CATTTAGCGGACCATG': 'CL:0000584',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1658
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             3242
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             1874
# AAACACCAATAACTGC-1        1.0       59.0       59.0             6215
# AAACAGAGCGACTCCT-1        0.0       14.0       14.0             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3621
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             2372
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             4983
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              464
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             1605
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0000584
# AAACAATCTACTAGCA-1                 CL:0009010
# AAACACCAATAACTGC-1                 CL:0000584
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000034
# TTGTTTCATTAGTCTA-1                 CL:0000584
# TTGTTTCCATACAACT-1                 CL:0000034
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                 CL:0009010
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 1872

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_11286/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1658
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             3242
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             1874
# AAACACCAATAACTGC-1        1.0       59.0       59.0             6215
# AAACAGAGCGACTCCT-1        0.0       14.0       14.0             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3621
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             2372
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             4983
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              464
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             1605
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0000584
# AAACAATCTACTAGCA-1                 CL:0009010
# AAACACCAATAACTGC-1                 CL:0000584
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000034
# TTGTTTCATTAGTCTA-1                 CL:0000584
# TTGTTTCCATACAACT-1                 CL:0000034
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                 CL:0009010
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000584',
#  'CL:0009010',
#  'CL:0000034',
#  'CL:0000186',
#  'CL:0000844',
#  'CL:0000066',
#  'CL:0000057',
#  'CL:0000160',
#  'CL:0000787',
#  'CL:0001071',
#  'CL:0000775',
#  'CL:0007011']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    4B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1    4B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1    4B_Hh.anti_IL10r
# AAACACCAATAACTGC-1    4B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1    4B_Hh.anti_IL10r
#                             ...
# TTGTTTCACATCCAGG-1    4B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1    4B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1    4B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1    4B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1    4B_Hh.anti_IL10r
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['4B_Hh.anti_IL10r']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1658
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             3242
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             1874
# AAACACCAATAACTGC-1        1.0       59.0       59.0             6215
# AAACAGAGCGACTCCT-1        0.0       14.0       14.0             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3621
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             2372
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             4983
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              464
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             1605
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  4B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                 CL:0000584  4B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                 CL:0009010  4B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000584  4B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  4B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                 CL:0000034  4B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                 CL:0000584  4B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000034  4B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                    unknown  4B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                 CL:0009010  4B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290871_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8),
#                  'lowres': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.23148148,
#                  'tissue_lowres_scalef': 0.06944445,
#                  'fiducial_diameter_fullres': 59.38215437800279,
#                  'spot_diameter_fullres': 36.760381281620774}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46450_Mus_Tcel13290871_mm10-2020-A/V12U21-349_D1-5x.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '4B_Hh.anti_IL10r'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290871_mm10-2020-A': {'images': {'hires': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8),
#                  'fullres': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.23148148,
#                  'spot_diameter_fullres': 36.760381281620774}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '4B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             1658
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             3242
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             1874
# AAACACCAATAACTGC-1        1.0       59.0       59.0             6215
# AAACAGAGCGACTCCT-1        0.0       14.0       14.0             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3621
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0             2372
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             4983
# TTGTTTGTATTACACG-1        0.0       73.0       73.0              464
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             1605
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  4B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                 CL:0000584  4B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                 CL:0009010  4B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000584  4B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  4B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                 CL:0000034  4B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                 CL:0000584  4B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000034  4B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                    unknown  4B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                 CL:0009010  4B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46450_Mus_Tcel13290871_mm10-2020-A': {'images': {'hires': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8),
#                  'fullres': array([[[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         ...,
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]],
#
#                         [[244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          ...,
#                          [244, 243, 245],
#                          [244, 243, 245],
#                          [244, 243, 245]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.23148148,
#                  'spot_diameter_fullres': 36.760381281620774}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '4B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_11286/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13290871.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0          0             1658
# AAACAAGTATCTCCCA-1          1         50         50             3242
# AAACAATCTACTAGCA-1          1          3          3             1874
# AAACACCAATAACTGC-1          1         59         59             6215
# AAACAGAGCGACTCCT-1          0         14         14             2455
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         58             3621
# TTGTTTCATTAGTCTA-1          1         60         60             2372
# TTGTTTCCATACAACT-1          1         45         45             4983
# TTGTTTGTATTACACG-1          0         73         73              464
# TTGTTTGTGTAAATTC-1          1          7          7             1605
#
#                    assay_ontology_term_id cell_type_ontology_term_id  \
# AAACAACGAATAGTTC-1            EFO:0010961                    unknown
# AAACAAGTATCTCCCA-1            EFO:0010961                 CL:0000584
# AAACAATCTACTAGCA-1            EFO:0010961                 CL:0009010
# AAACACCAATAACTGC-1            EFO:0010961                 CL:0000584
# AAACAGAGCGACTCCT-1            EFO:0010961                    unknown
# ...                                   ...                        ...
# TTGTTTCACATCCAGG-1            EFO:0010961                 CL:0000034
# TTGTTTCATTAGTCTA-1            EFO:0010961                 CL:0000584
# TTGTTTCCATACAACT-1            EFO:0010961                 CL:0000034
# TTGTTTGTATTACACG-1            EFO:0010961                    unknown
# TTGTTTGTGTAAATTC-1            EFO:0010961                 CL:0009010
#
#                             donor_id development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAAGTATCTCCCA-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAATCTACTAGCA-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# AAACACCAATAACTGC-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAGAGCGACTCCT-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# ...                              ...                                ...
# TTGTTTCACATCCAGG-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCCATACAACT-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTATTACACG-1  4B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1  4B_Hh.anti_IL10r                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 16 columns]

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)
# Out:
# Missing columns: []

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
# Out:
# Data Types:
# array_col    int64
# array_row    int64
# in_tissue    int64
# dtype: object
#
# Missing Values:
# array_col    0
# array_row    0
# in_tissue    0
# dtype: int64

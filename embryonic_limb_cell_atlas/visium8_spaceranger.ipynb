# %% [markdown]
# ### **Curating visium_slide8.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9699526/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['TCGTGTACTATGGATG-1']

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 9

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 6888080 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 153)	1.0
#   (0, 156)	1.0
#   (0, 484)	1.0
#   (0, 566)	1.0
#   (0, 854)	1.0
#   (0, 895)	2.0
#   (0, 1005)	1.0
#   (0, 1205)	1.0
#   (0, 1337)	1.0
#   (0, 1579)	1.0
#   (0, 1600)	1.0
#   (0, 1844)	1.0
#   (0, 1933)	2.0
#   (0, 2021)	1.0
#   (0, 2054)	1.0
#   (0, 2116)	1.0
#   (0, 2159)	1.0
#   (0, 2219)	1.0
#   (0, 2360)	1.0
#   (0, 2632)	1.0
#   (0, 2872)	1.0
#   (0, 2930)	1.0
#   (0, 3189)	1.0
#   (0, 3274)	1.0
#   (0, 3581)	1.0
#   :	:
#   (4991, 33283)	1.0
#   (4991, 33306)	1.0
#   (4991, 33310)	1.0
#   (4991, 33397)	1.0
#   (4991, 33407)	1.0
#   (4991, 33410)	2.0
#   (4991, 33433)	1.0
#   (4991, 33451)	3.0
#   (4991, 33476)	1.0
#   (4991, 33480)	2.0
#   (4991, 33488)	1.0
#   (4991, 33550)	1.0
#   (4991, 33606)	1.0
#   (4991, 33635)	3.0
#   (4991, 33652)	4.0
#   (4991, 33654)	11.0
#   (4991, 33655)	8.0
#   (4991, 33657)	2.0
#   (4991, 33658)	24.0
#   (4991, 33659)	5.0
#   (4991, 33660)	1.0
#   (4991, 33661)	9.0
#   (4991, 33662)	1.0
#   (4991, 33664)	3.0
#   (4991, 33681)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16              193
# AAACAAGTATCTCCCA-1          1         50        102             4955
# AAACAATCTACTAGCA-1          0          3         43             1169
# AAACACCAATAACTGC-1          0         59         19             1584
# AAACAGAGCGACTCCT-1          0         14         94             2738
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4580
# TTGTTTCATTAGTCTA-1          1         60         30             3769
# TTGTTTCCATACAACT-1          0         45         27               34
# TTGTTTGTATTACACG-1          0         73         41              226
# TTGTTTGTGTAAATTC-1          0          7         51             1432
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide8.h5ad')

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526          1           0.0        0.000866
# AAACCCGAACGAAATC-1_WSSS_THYst9699526          1           0.0        0.000207
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526          1           0.0        0.000012
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526          1           0.0        0.000215
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526          1           0.0        0.000713
# ...                                         ...           ...             ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526          1           0.0        0.002358
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526          1           0.0        0.000079
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526          1           0.0        0.080316
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526          1           0.0        0.000257
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526          1           0.0        0.000769
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526        0.019908           0.001418
# AAACCCGAACGAAATC-1_WSSS_THYst9699526        0.014505           0.048599
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526        0.157955           0.000010
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526        0.004625           0.000629
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526        0.002586           0.370054
# ...                                              ...                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526        0.007996           0.000956
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526        0.004456           0.005957
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526        0.001436           0.000292
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526        0.005990           0.003806
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526        0.002707           0.000067
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526       0.000436  0.043950    0.004265
# AAACCCGAACGAAATC-1_WSSS_THYst9699526       0.000136  0.012693    0.004948
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526       0.000016  0.002740    0.004801
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526       0.000786  0.006138    0.001585
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526       0.001322  0.004396    0.001427
# ...                                             ...       ...         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526       0.002608  0.028079    0.004072
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526       0.000060  0.009731    0.001707
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526       0.003009  0.000110    0.000474
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526       0.000267  0.011469    0.002487
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526       0.007203  0.015976    0.002115
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526      0.000923          0.002500  ...
# AAACCCGAACGAAATC-1_WSSS_THYst9699526      0.000735          0.002374  ...
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526      0.000114          0.000287  ...
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526      0.000487          0.004890  ...
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526      0.000527          0.004237  ...
# ...                                            ...               ...  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526      0.001833          0.014517  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526      0.000429          0.001036  ...
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526      0.000242          0.001154  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526      0.000553          0.001571  ...
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526      0.001279          0.026913  ...
#
#                                        stage  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526  PCW5.6
# AAACCCGAACGAAATC-1_WSSS_THYst9699526  PCW5.6
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526  PCW5.6
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526  PCW5.6
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526  PCW5.6
# ...                                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526  PCW5.6
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526  PCW5.6
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526  PCW5.6
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526  PCW5.6
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526  PCW5.6
#
#                                       development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526                      HsapDv:0000023
# AAACCCGAACGAAATC-1_WSSS_THYst9699526                      HsapDv:0000023
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526                      HsapDv:0000023
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526                      HsapDv:0000023
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526                      HsapDv:0000023
# ...                                                                  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526                      HsapDv:0000023
#
#                                       disease_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526              PATO:0000461
# AAACCCGAACGAAATC-1_WSSS_THYst9699526              PATO:0000461
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526              PATO:0000461
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526              PATO:0000461
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526              PATO:0000461
# ...                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526              PATO:0000461
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526              PATO:0000461
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526              PATO:0000461
#
#                                       is_primary_data  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526             True
# AAACCCGAACGAAATC-1_WSSS_THYst9699526             True
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526             True
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526             True
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526             True
# ...                                               ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526             True
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526             True
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526             True
#
#                                       organism_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526             NCBITaxon:9606
# AAACCCGAACGAAATC-1_WSSS_THYst9699526             NCBITaxon:9606
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526             NCBITaxon:9606
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526             NCBITaxon:9606
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526             NCBITaxon:9606
# ...                                                         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526                                   unknown
# AAACCCGAACGAAATC-1_WSSS_THYst9699526                                   unknown
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526                                   unknown
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526                                   unknown
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526                                   unknown
# ...                                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526                                   unknown
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526                                   unknown
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526          PATO:0000384               na
# AAACCCGAACGAAATC-1_WSSS_THYst9699526          PATO:0000384               na
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526          PATO:0000384               na
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526          PATO:0000384               na
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAACCCGAACGAAATC-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526       tissue           UBERON:0000978
#
# [1279 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526          1           0.0        0.000866
# AAACCCGAACGAAATC-1_WSSS_THYst9699526          1           0.0        0.000207
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526          1           0.0        0.000012
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526          1           0.0        0.000215
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526          1           0.0        0.000713
# ...                                         ...           ...             ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526          1           0.0        0.002358
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526          1           0.0        0.000079
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526          1           0.0        0.080316
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526          1           0.0        0.000257
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526          1           0.0        0.000769
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526        0.019908           0.001418
# AAACCCGAACGAAATC-1_WSSS_THYst9699526        0.014505           0.048599
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526        0.157955           0.000010
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526        0.004625           0.000629
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526        0.002586           0.370054
# ...                                              ...                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526        0.007996           0.000956
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526        0.004456           0.005957
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526        0.001436           0.000292
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526        0.005990           0.003806
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526        0.002707           0.000067
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526       0.000436  0.043950    0.004265
# AAACCCGAACGAAATC-1_WSSS_THYst9699526       0.000136  0.012693    0.004948
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526       0.000016  0.002740    0.004801
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526       0.000786  0.006138    0.001585
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526       0.001322  0.004396    0.001427
# ...                                             ...       ...         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526       0.002608  0.028079    0.004072
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526       0.000060  0.009731    0.001707
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526       0.003009  0.000110    0.000474
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526       0.000267  0.011469    0.002487
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526       0.007203  0.015976    0.002115
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526      0.000923          0.002500  ...
# AAACCCGAACGAAATC-1_WSSS_THYst9699526      0.000735          0.002374  ...
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526      0.000114          0.000287  ...
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526      0.000487          0.004890  ...
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526      0.000527          0.004237  ...
# ...                                            ...               ...  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526      0.001833          0.014517  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526      0.000429          0.001036  ...
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526      0.000242          0.001154  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526      0.000553          0.001571  ...
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526      0.001279          0.026913  ...
#
#                                       development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526                      HsapDv:0000023
# AAACCCGAACGAAATC-1_WSSS_THYst9699526                      HsapDv:0000023
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526                      HsapDv:0000023
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526                      HsapDv:0000023
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526                      HsapDv:0000023
# ...                                                                  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526                      HsapDv:0000023
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526                      HsapDv:0000023
#
#                                       disease_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526              PATO:0000461
# AAACCCGAACGAAATC-1_WSSS_THYst9699526              PATO:0000461
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526              PATO:0000461
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526              PATO:0000461
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526              PATO:0000461
# ...                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526              PATO:0000461
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526              PATO:0000461
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526              PATO:0000461
#
#                                       is_primary_data  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526             True
# AAACCCGAACGAAATC-1_WSSS_THYst9699526             True
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526             True
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526             True
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526             True
# ...                                               ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526             True
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526             True
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526             True
#
#                                       organism_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526             NCBITaxon:9606
# AAACCCGAACGAAATC-1_WSSS_THYst9699526             NCBITaxon:9606
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526             NCBITaxon:9606
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526             NCBITaxon:9606
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526             NCBITaxon:9606
# ...                                                         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526             NCBITaxon:9606
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526                                   unknown
# AAACCCGAACGAAATC-1_WSSS_THYst9699526                                   unknown
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526                                   unknown
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526                                   unknown
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526                                   unknown
# ...                                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526                                   unknown
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526                                   unknown
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526          PATO:0000384               na
# AAACCCGAACGAAATC-1_WSSS_THYst9699526          PATO:0000384               na
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526          PATO:0000384               na
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526          PATO:0000384               na
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526          PATO:0000384               na
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAACCCGAACGAAATC-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526       tissue           UBERON:0000978
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526       tissue           UBERON:0000978
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526       tissue           UBERON:0000978
#
#                                               barcodes
# AAACAAGTATCTCCCA-1_WSSS_THYst9699526  AAACAAGTATCTCCCA
# AAACCCGAACGAAATC-1_WSSS_THYst9699526  AAACCCGAACGAAATC
# AAACGGTTGCGAACTG-1_WSSS_THYst9699526  AAACGGTTGCGAACTG
# AAAGGCCCTATAATAC-1_WSSS_THYst9699526  AAAGGCCCTATAATAC
# AAAGGCTACGGACCAT-1_WSSS_THYst9699526  AAAGGCTACGGACCAT
# ...                                                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699526  TTGTGGCCCTGACAGT
# TTGTGTATGCCACCAA-1_WSSS_THYst9699526  TTGTGTATGCCACCAA
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699526  TTGTTAGCAAATTCGA
# TTGTTTCACATCCAGG-1_WSSS_THYst9699526  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1_WSSS_THYst9699526  TTGTTTCATTAGTCTA
#
# [1279 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0008019',
#  'AAACCCGAACGAAATC': 'CL:0008019',
#  'AAACGGTTGCGAACTG': 'CL:0000515',
#  'AAAGGCCCTATAATAC': 'CL:0008019',
#  'AAAGGCTACGGACCAT': 'CL:0000138',
#  'AAAGGCTCTCGCGCCG': 'CL:0008019',
#  'AAAGGGCAGCTTGAAT': 'CL:0008019',
#  'AAAGTGCCATCAATTA': 'CL:0008019',
#  'AAAGTGTGATTTATCT': 'CL:0008019',
#  'AAAGTTGACTCCCGTA': 'CL:0008019',
#  'AAATAACCATACGGGA': 'CL:0008019',
#  'AAATAGCTTAGACTTT': 'CL:0008019',
#  'AAATCTAGCCCTGCTA': 'CL:0008019',
#  'AAATGCTCGTTACGTT': 'CL:0002551',
#  'AAATGGCATGTCTTGT': 'CL:0000138',
#  'AAATTACACGACTCTG': 'CL:0008019',
#  'AAATTGATAGTCCTTT': 'CL:0000515',
#  'AACAACTGGTAGTTGC': 'CL:0000515',
#  'AACAATACATTGTCGA': 'CL:0000138',
#  'AACAATTACTCTACGC': 'CL:0000138',
#  'AACACGACTGTACTGA': 'CL:0008019',
#  'AACAGCTGTGTGGCAA': 'CL:0008019',
#  'AACAGGAAATCGAATA': 'CL:0000138',
#  'AACAGGATGGGCCGCG': 'CL:0008019',
#  'AACAGGTAGTATGGAT': 'CL:0000138',
#  'AACATTGAAGTTGATC': 'CL:0008019',
#  'AACATTGTGACTCGAG': 'CL:0008019',
#  'AACCATGGGATCGCTA': 'CL:0002551',
#  'AACCCAGAGACGGAGA': 'CL:0008019',
#  'AACCCGACAACCCGTG': 'CL:0008019',
#  'AACCCGAGCAGAATCG': 'CL:0000138',
#  'AACCCTACTGTCAATA': 'CL:0008019',
#  'AACCCTGGTGGAACCA': 'CL:0008019',
#  'AACCGTTGTGTTTGCT': 'CL:0000138',
#  'AACCTTTACGACGTCT': 'CL:0008019',
#  'AACGATAGAAGGGCCG': 'CL:0000138',
#  'AACGATATGTCAACTG': 'CL:0000646',
#  'AACGCGACCTTGGGCG': 'CL:0008019',
#  'AACGTCAGACTAGTGG': 'CL:0000187',
#  'AACGTGATGAAGGACA': 'CL:0008019',
#  'AACTACCCGTTTGTCA': 'CL:0000138',
#  'AACTAGGCTTGGGTGT': 'CL:0008019',
#  'AACTCCTAATCCCATG': 'CL:0008019',
#  'AACTGATATTAGGCCT': 'CL:0000138',
#  'AACTGGGTCCCGACGT': 'CL:0008019',
#  'AACTTCTGCGTCTATC': 'CL:0002551',
#  'AACTTGCCCGTATGCA': 'CL:0000515',
#  'AAGACCCAACTGAACA': 'CL:0000138',
#  'AAGAGATGAATCGGTA': 'CL:0000062',
#  'AAGAGGCCCTTTGGAA': 'CL:0008019',
#  'AAGATGGCACCGGACC': 'CL:0008019',
#  'AAGCCGAAGCGGTTTA': 'CL:0000138',
#  'AAGCCGCCGTGAAATC': 'CL:0008019',
#  'AAGCGTCCCTCATCGA': 'CL:0008019',
#  'AAGGAGCGGTTGGTGC': 'CL:0002551',
#  'AAGGATCGATCGCTTG': 'CL:0008019',
#  'AAGGCAGGCTGTCTCC': 'CL:0008019',
#  'AAGGCGCGTAAAGCTT': 'CL:0000515',
#  'AAGGCTGTGCTCATCG': 'CL:0000515',
#  'AAGGGAACGACTGGCT': 'CL:0008019',
#  'AAGGGACTATGCATTC': 'CL:0000138',
#  'AAGTAGAAGACCGGGT': 'CL:0008019',
#  'AAGTCAATTGTCGTCA': 'CL:0008019',
#  'AAGTGAGTCGGGTTTA': 'CL:0000515',
#  'AAGTGCCTTGACTGTA': 'CL:0008019',
#  'AATAAGTCCTCGAGAC': 'CL:0008019',
#  'AATACAATGTTTCAGG': 'CL:0008019',
#  'AATACCGGAGGGCTGT': 'CL:0008019',
#  'AATAGTCCGTCCCGAC': 'CL:0000515',
#  'AATATCGAATCAATGC': 'CL:0000138',
#  'AATCCAAGGGCCTGAG': 'CL:0008019',
#  'AATCGCGCAGAGGACT': 'CL:0008019',
#  'AATGACTGTCAGCCGG': 'CL:0008019',
#  'AATGGTTCTCACAAGC': 'CL:0000187',
#  'AATGTGCTAATCTGAG': 'CL:0008019',
#  'AATTAACGGATTTCCA': 'CL:0008019',
#  'AATTCCAAGCATGTAC': 'CL:0000515',
#  'AATTTGGGACATAGTA': 'CL:0008019',
#  'AATTTGGTTCCAAAGA': 'CL:0000138',
#  'ACAACGGTCCCTGCGA': 'CL:0000187',
#  'ACAAGCAGTGCCTAGC': 'CL:0000138',
#  'ACAAGGACAAGAGGTT': 'CL:0000187',
#  'ACAATGAATACGGAGA': 'CL:0000515',
#  'ACACACTTTCTACACG': 'CL:0000138',
#  'ACACATGATCAAATCT': 'CL:0008019',
#  'ACACCCAGCATGCAGC': 'CL:0002551',
#  'ACACCCGAGAAATCCG': 'CL:0000187',
#  'ACACCGGTCTGACCGC': 'CL:0008019',
#  'ACACCTTAAGTAGGGC': 'CL:0000187',
#  'ACACCTTACTACTTGC': 'CL:0000515',
#  'ACACGGCACTATGCAT': 'CL:0008019',
#  'ACACGTAGGCCACAAG': 'CL:0008019',
#  'ACACTGGGACAGTCGT': 'CL:0000138',
#  'ACAGCGCACCCGCAGC': 'CL:0008019',
#  'ACATCCCGGCCATACG': 'CL:0008019',
#  'ACATCCTGGTAACTGT': 'CL:0008019',
#  'ACATCGTTAACCTAGT': 'CL:0000138',
#  'ACATGGCGCCAAAGTA': 'CL:0000515',
#  'ACCAACGCTTATTTAT': 'CL:0008019',
#  'ACCAAGAACGCGTGTC': 'CL:0008019',
#  'ACCACAACTCAGAACA': 'CL:0008019',
#  'ACCACCAATGTAACAA': 'CL:0008019',
#  'ACCAGCCCGGTCTTTG': 'CL:0008019',
#  'ACCCACCTACATGCTC': 'CL:0008019',
#  'ACCCGAGCGAAATTAC': 'CL:0000138',
#  'ACCCGGAAACTCCCAG': 'CL:0008019',
#  'ACCCGGATGACGCATC': 'CL:0008019',
#  'ACCCGTGTCATCAGTA': 'CL:0000138',
#  'ACCCTATGCCATATCG': 'CL:0008019',
#  'ACCCTTCATCTGCGAA': 'CL:0000138',
#  'ACCCTTTAGTTCTCCA': 'CL:0008019',
#  'ACCGACACATCTCCCA': 'CL:0000515',
#  'ACCGATAGGCATAACC': 'CL:0008019',
#  'ACCGATATTTAATCAT': 'CL:0008019',
#  'ACCGCGGTGGAAGTCG': 'CL:0008019',
#  'ACCGGGCCTTTGTTGA': 'CL:0008019',
#  'ACCGTGACCACGTGGG': 'CL:0000138',
#  'ACCTAATCGACTTCCT': 'CL:0008019',
#  'ACCTACAGTATGTGGT': 'CL:0008019',
#  'ACCTCCGCCCTCGCTG': 'CL:0000515',
#  'ACGAAATGGGCGGCAC': 'CL:0000138',
#  'ACGACTGGTCATACTC': 'CL:0000138',
#  'ACGAGATATTTGCTTA': 'CL:0008019',
#  'ACGATACATAGAACTA': 'CL:0008019',
#  'ACGATCATCTTGTAAA': 'CL:0008019',
#  'ACGATGGATCCGATGC': 'CL:0000138',
#  'ACGCAAACTAATAGAT': 'CL:0008019',
#  'ACGCATACGTTTACTA': 'CL:0000515',
#  'ACGCCAGATGATTTCT': 'CL:0000138',
#  'ACGGAATTTAGCAAAT': 'CL:0002551',
#  'ACGGCCAACATGGACT': 'CL:0008019',
#  'ACGTACAGATTTCTCT': 'CL:0000138',
#  'ACGTATTACTCCGATC': 'CL:0008019',
#  'ACGTGCGCCTCGTGCA': 'CL:0000138',
#  'ACGTTCGTTCAGGAAA': 'CL:0000138',
#  'ACGTTTAGTTGTGATC': 'CL:0000138',
#  'ACTACCAGCTCTCTGG': 'CL:0000187',
#  'ACTACGCGTTAGAATT': 'CL:0000138',
#  'ACTAGTTGCGATCGTC': 'CL:0008019',
#  'ACTATCCAGGGCATGG': 'CL:0008019',
#  'ACTATGTCCAGCTGCC': 'CL:0008019',
#  'ACTATTCGTCCGTGGT': 'CL:0000138',
#  'ACTATTTCCGGGCCCA': 'CL:0008019',
#  'ACTCCAATATCATCAT': 'CL:0000138',
#  'ACTCTCTTATACACGA': 'CL:0008019',
#  'ACTGCCCGCCATTCTC': 'CL:0008019',
#  'ACTGCCGTCGTAACTC': 'CL:0000138',
#  'ACTGTAGCACTTTGGA': 'CL:0000187',
#  'ACTGTATACGCGAGCA': 'CL:0002551',
#  'ACTGTGCTAGTAGATC': 'CL:0002551',
#  'ACTTAGTACGACAAGA': 'CL:0002551',
#  'ACTTATTAGGATCGGT': 'CL:0000187',
#  'ACTTGTGGATGGAACG': 'CL:0008019',
#  'ACTTTGGTCGTGCTCC': 'CL:0008019',
#  'ACTTTGTCGACGCACT': 'CL:0000138',
#  'AGAAATTATGACTCGC': 'CL:0000138',
#  'AGAATTGTTTGACATA': 'CL:0002551',
#  'AGACAGGCATCTCAGC': 'CL:0008019',
#  'AGACCATGGGATACAA': 'CL:0000187',
#  'AGACCGCTCCGCGGTT': 'CL:0000138',
#  'AGACGACGATGCCGCT': 'CL:0000515',
#  'AGACGCCCACTTCGCC': 'CL:0008019',
#  'AGACTAGCCTTCCAGA': 'CL:0002551',
#  'AGACTGTTACCGGGTC': 'CL:0000138',
#  'AGAGAAACACCAGAAA': 'CL:0008019',
#  'AGAGAAGGAGTACAAT': 'CL:0008019',
#  'AGAGCCGCCGAGATTT': 'CL:0000138',
#  'AGAGCGGGCTAATCAT': 'CL:0000138',
#  'AGAGCGTACAAGCTCG': 'CL:0008019',
#  'AGAGGCTTCGGAAACC': 'CL:0008019',
#  'AGAGTAAACTTCACTA': 'CL:0008019',
#  'AGATAACTTCAGGGCC': 'CL:0008019',
#  'AGATACGACTTCATAT': 'CL:0008019',
#  'AGATGACTCGCCCACG': 'CL:0008019',
#  'AGATGCAAGACGTGCA': 'CL:0008019',
#  'AGCAACCGAAAGTAAT': 'CL:0008019',
#  'AGCACACGTTTAGACT': 'CL:0008019',
#  'AGCACTTAAGGACGCC': 'CL:0008019',
#  'AGCAGCCAGATGAATA': 'CL:0008019',
#  'AGCATCGTCGATAATT': 'CL:0000187',
#  'AGCCAAGCTTTGTGTC': 'CL:0008019',
#  'AGCCACTCCCGTGCTT': 'CL:0008019',
#  'AGCCCGGCATTAGAGG': 'CL:0000138',
#  'AGCCCGGTAGCCTGTA': 'CL:0000138',
#  'AGCCCTAAGCGAAGTT': 'CL:0000138',
#  'AGCCCTCCCTGGTGGC': 'CL:0008019',
#  'AGCCCTTGGACATCCC': 'CL:0000138',
#  'AGCCTTAAAGCGGAAG': 'CL:0008019',
#  'AGCGACATCCCATTCA': 'CL:0008019',
#  'AGCGCATAATGAATCG': 'CL:0008019',
#  'AGCGGACACTTCGTAG': 'CL:0008019',
#  'AGCGGGAAGGGTCCAT': 'CL:0002551',
#  'AGCTAACAAGCAATGT': 'CL:0000138',
#  'AGCTATTTAATCCAAC': 'CL:0000138',
#  'AGCTCCATATATGTTC': 'CL:0008019',
#  'AGCTCTTCCCAGTGCA': 'CL:0008019',
#  'AGCTCTTCGTAACCTT': 'CL:0008019',
#  'AGCTGAAGTAAACCAA': 'CL:0008019',
#  'AGCTGTAACCTCAATC': 'CL:0000515',
#  'AGGAACGAACGACTTC': 'CL:0008019',
#  'AGGAAGCTGTCCGCCG': 'CL:0008019',
#  'AGGACATCGCACGTCG': 'CL:0008019',
#  'AGGATATAGGGATTTA': 'CL:0008019',
#  'AGGCACGTGACTGTCC': 'CL:0000138',
#  'AGGCAGGGAGCGTACT': 'CL:0008019',
#  'AGGCCACCCGTTATGA': 'CL:0000515',
#  'AGGCCCATTGTACAGG': 'CL:0000138',
#  'AGGCGATAACTGGCGT': 'CL:0008019',
#  'AGGCTATGGTTAGCTT': 'CL:0008019',
#  'AGGCTTGCTAGACACC': 'CL:0000138',
#  'AGGGAAACGAGGTACT': 'CL:0008019',
#  'AGGGACCGGCTGCGTT': 'CL:0000515',
#  'AGGGACTCTACGCGAC': 'CL:0008019',
#  'AGGGCAGCGGCGTGGT': 'CL:0000138',
#  'AGGGCCCTAATGTTCT': 'CL:0000515',
#  'AGGGCGTGATCGGCTA': 'CL:0008019',
#  'AGGGTCGATGCGAACT': 'CL:0008019',
#  'AGGGTGCCGTTCTTTA': 'CL:0000138',
#  'AGGTAACCTCCTATTC': 'CL:0008019',
#  'AGGTACGATATTGCCA': 'CL:0000138',
#  'AGGTAGATCGAGATAT': 'CL:0000138',
#  'AGGTATAATTGATAGT': 'CL:0000515',
#  'AGGTCGCCTCCCAACA': 'CL:0008019',
#  'AGGTGGTGACCTTCGC': 'CL:0008019',
#  'AGGTTACACCATGCCG': 'CL:0008019',
#  'AGTAATGTCTTGCCGC': 'CL:0008019',
#  'AGTAGGTAACATACAT': 'CL:0000138',
#  'AGTATAATACTAGGCA': 'CL:0000187',
#  'AGTATACACAGCGACA': 'CL:0008019',
#  'AGTATGCTGGAGACCA': 'CL:0008019',
#  'AGTATTTGGCACGACC': 'CL:0000138',
#  'AGTCAAATGATGTGAT': 'CL:0008019',
#  'AGTCACTAGCTCTCGA': 'CL:0000515',
#  'AGTCAGCCACCGCCTG': 'CL:0002551',
#  'AGTCCATTGGCTGATG': 'CL:0008019',
#  'AGTCGGCCCAAACGAC': 'CL:0000187',
#  'AGTCGGTTGCGTGAGA': 'CL:0008019',
#  'AGTCTCACAAGACTAC': 'CL:0000515',
#  'AGTCTGGACATCCTTG': 'CL:0002551',
#  'AGTGAACAAACTTCTC': 'CL:0008019',
#  'AGTGACTGTGACACAA': 'CL:0008019',
#  'AGTGAGGGTTTCTGAC': 'CL:0008019',
#  'AGTGTGGTCTATTGTG': 'CL:0008019',
#  'AGTTAAGCGGTCCCGG': 'CL:0008019',
#  'AGTTACCGCACATGGT': 'CL:0000138',
#  'AGTTACTCTATCGTGG': 'CL:0000138',
#  'AGTTGACGGTCCTTGC': 'CL:0000515',
#  'AGTTTCGCAGGTCGGA': 'CL:0000138',
#  'AGTTTGGCACGGGTTG': 'CL:0008019',
#  'ATAAGTAGGGCGACTC': 'CL:0000515',
#  'ATAATAGTGTAGGGAC': 'CL:0002551',
#  'ATAATTAGCTAAGTAG': 'CL:0000515',
#  'ATACCTAACCAAGAAA': 'CL:0008019',
#  'ATACGGAACGTCGTTT': 'CL:0008019',
#  'ATACGGGTTTCGATTG': 'CL:0008019',
#  'ATACGTTATGCACGGA': 'CL:0000515',
#  'ATAGACGAAGAGAAAG': 'CL:0002551',
#  'ATAGAGTACTGGGACA': 'CL:0002551',
#  'ATAGTCTTTGACGTGC': 'CL:0008019',
#  'ATAGTTCCACCCACTC': 'CL:0008019',
#  'ATATAAAGCGCTCGTG': 'CL:0000515',
#  'ATATCAACCTACAGAG': 'CL:0008019',
#  'ATATCGGTAGGGAGAT': 'CL:0008019',
#  'ATATCTCCCTCGTTAA': 'CL:0000138',
#  'ATATTCCCACAGGTCA': 'CL:0008019',
#  'ATATTGCTGTCAAAGT': 'CL:0000187',
#  'ATATTGGAGAGGCCTT': 'CL:0008019',
#  'ATCAAACACTGTTCCA': 'CL:0008019',
#  'ATCACATTAGAATATC': 'CL:0008019',
#  'ATCCAACGCAGTCATA': 'CL:0000515',
#  'ATCCCATCCACAGCGC': 'CL:0008019',
#  'ATCGCCAGTCAACATT': 'CL:0008019',
#  'ATCGTGGAAAGTCTGG': 'CL:0000138',
#  'ATCGTTAGCTAGCGGA': 'CL:0000515',
#  'ATCTCCCTGCAATCTA': 'CL:0000138',
#  'ATCTCGTGAGCGAAAC': 'CL:0000138',
#  'ATCTGACATGGAAGGA': 'CL:0000138',
#  'ATCTGCTGTTATCGCC': 'CL:0000515',
#  'ATCTGTAATTGTACCC': 'CL:0000138',
#  'ATCTTGACCTGCAACG': 'CL:0002551',
#  'ATGAAGCCAAGGAGCC': 'CL:0000187',
#  'ATGACGCCGGCTCTAA': 'CL:0008019',
#  'ATGACGCGTTCTATCC': 'CL:0000515',
#  'ATGACTATCAGCTGTG': 'CL:0000138',
#  'ATGAGGAGTGTTAATC': 'CL:0000515',
#  'ATGATCGGGAATAGAC': 'CL:0008019',
#  'ATGCACTACCGCATTG': 'CL:0002551',
#  'ATGCCGGTTGATGGGA': 'CL:0008019',
#  'ATGCGAGTCCCACCAC': 'CL:0008019',
#  'ATGCTCAGTGTTGCAT': 'CL:0002551',
#  'ATGCTTAGGAGTTGAT': 'CL:0000138',
#  'ATGGATCCGGCGTCCG': 'CL:0008019',
#  'ATGGGACCTGCTGAAC': 'CL:0000138',
#  'ATGGGTGTATACCTCC': 'CL:0000138',
#  'ATGTTACGAGCAATAC': 'CL:0002551',
#  'ATGTTGTAGTCTGTTT': 'CL:0008019',
#  'ATTAATGAACCAGTCG': 'CL:0000646',
#  'ATTAATTCGGTCACTC': 'CL:0000138',
#  'ATTACAACTACCGGCC': 'CL:0000138',
#  'ATTACATGTCAGTCTT': 'CL:0008019',
#  'ATTACCACACTGCCTG': 'CL:0008019',
#  'ATTACTAGCCTCTTGC': 'CL:0000138',
#  'ATTAGATTGATAGCGG': 'CL:0008019',
#  'ATTATACTTTGCTCGT': 'CL:0008019',
#  'ATTATGCCATAGGGAG': 'CL:0000187',
#  'ATTATTATGTCCGTCA': 'CL:0000192',
#  'ATTCAACCATTTAAGG': 'CL:0000515',
#  'ATTCAGTAGCAGGGTC': 'CL:0000138',
#  'ATTCCCACATAAACAA': 'CL:0000138',
#  'ATTCCTCCGCCAGTGC': 'CL:0000515',
#  'ATTCGTGCTATCTCTT': 'CL:0000138',
#  'ATTCTCGTCTCTTTAG': 'CL:0000646',
#  'ATTCTTCGTACTTATG': 'CL:0008019',
#  'ATTGACGTAACTCGGT': 'CL:0000138',
#  'ATTGCCTATTAGACCG': 'CL:0008019',
#  'ATTGGATTACAGCGTA': 'CL:0008019',
#  'ATTGGGAATATCTTGG': 'CL:0002551',
#  'ATTGTACAACTCGGCT': 'CL:0000515',
#  'ATTGTCGCAATACCTT': 'CL:0000138',
#  'ATTTAACTCGTATTAC': 'CL:0000138',
#  'ATTTACAGTTTACTGG': 'CL:0008019',
#  'ATTTCATTATTTCGCG': 'CL:0000138',
#  'ATTTCCGGGTTCTGCG': 'CL:0000515',
#  'ATTTGCGCGAGTAGCT': 'CL:0000515',
#  'ATTTGTTCCAGGGCTC': 'CL:0008019',
#  'CAAACGGTCGCACTTT': 'CL:0008019',
#  'CAAACTACGATAGAGA': 'CL:0000138',
#  'CAAACTATTGAGCTTC': 'CL:0000138',
#  'CAAATTGTCAGCAAGC': 'CL:0000138',
#  'CAACGACCCGTTTACA': 'CL:0008019',
#  'CAACGGTTCTTGATAC': 'CL:0000187',
#  'CAACGTGGTGGAGTCT': 'CL:0000138',
#  'CAACTATATCGAATGC': 'CL:0000138',
#  'CAACTCCTTGATCCCG': 'CL:0000138',
#  'CAACTGCTCATCCGAT': 'CL:0000138',
#  'CAAGCACCAAATGCCT': 'CL:0000138',
#  'CAATCCCTATACCAGC': 'CL:0008019',
#  'CAATGTGCCAACCCTT': 'CL:0000515',
#  'CACACACGCTAACGAG': 'CL:0000515',
#  'CACACAGCTTGCGCTC': 'CL:0000138',
#  'CACACAGGGATAGATT': 'CL:0008019',
#  'CACAGAGACGAGGACG': 'CL:0008019',
#  'CACAGCTAGGGAGTGA': 'CL:0008019',
#  'CACAGGGCCATATAGT': 'CL:0008019',
#  'CACAGGGCCGTTGTCA': 'CL:0008019',
#  'CACAGTCCCGCTTCGC': 'CL:0008019',
#  'CACAGTTCGCTTCCCA': 'CL:0000138',
#  'CACATCGTGCACGCGC': 'CL:0008019',
#  'CACATTCTTTCGATGG': 'CL:0008019',
#  'CACATTTCTTGTCAGA': 'CL:0000138',
#  'CACCAGTCAGCATGCA': 'CL:0008019',
#  'CACCATCGGAGGAGAC': 'CL:0008019',
#  'CACCCAAATCTTATGT': 'CL:0000515',
#  'CACCCACACGTCACCC': 'CL:0000138',
#  'CACCCACGAGGCAATT': 'CL:0008019',
#  'CACCGATACACCGAGC': 'CL:0008019',
#  'CACCGCCGACCAGCGA': 'CL:0008019',
#  'CACCGTATCCCATCCG': 'CL:0008019',
#  'CACCTAATAGAGTCGT': 'CL:0002551',
#  'CACCTAATCAGTTTAC': 'CL:0008019',
#  'CACCTCGATGGTGGAC': 'CL:0000138',
#  'CACCTTGGCGCCTTTG': 'CL:0000515',
#  'CACGCAGCGAGGCTTT': 'CL:0008019',
#  'CACGCGGAACTGTTGC': 'CL:0008019',
#  'CACTACTCAGTTCTGT': 'CL:0008019',
#  'CACTCAGCTCTTGAGG': 'CL:0000138',
#  'CACTCCTATGTAAGAT': 'CL:0008019',
#  'CACTCCTCTCGGTCGG': 'CL:0000138',
#  'CACTCTTCTGCTAGCC': 'CL:0008019',
#  'CACTGACGATTGTGGA': 'CL:0008019',
#  'CACTGTCCAAGTGAGA': 'CL:0000138',
#  'CACTTCGCCACAGGCT': 'CL:0000515',
#  'CAGAATAACACACGGA': 'CL:0000138',
#  'CAGACACCGATCGCTG': 'CL:0008019',
#  'CAGAGGCGATGCATGA': 'CL:0008019',
#  'CAGAGTGATTTAACGT': 'CL:0008019',
#  'CAGATACTAACATAGT': 'CL:0002551',
#  'CAGCCGGGCCCTCTAT': 'CL:0008019',
#  'CAGCTCGTGCTTGTGT': 'CL:0008019',
#  'CAGCTTAGTAGGTAGC': 'CL:0008019',
#  'CAGGAAGACTTTATAT': 'CL:0008019',
#  'CAGTAATCCCTCCCAG': 'CL:0008019',
#  'CAGTGTCCGCAGAATG': 'CL:0008019',
#  'CAGTTCCGCGGGTCGA': 'CL:0008019',
#  'CATACAAAGCCGAACC': 'CL:0002551',
#  'CATACACGGTTCCCAC': 'CL:0008019',
#  'CATACGAACTAGCTGG': 'CL:0008019',
#  'CATACTTAGGCAATAC': 'CL:0000515',
#  'CATAGCCGCCCGGGAT': 'CL:0000138',
#  'CATAGTACATTGAGAG': 'CL:0000138',
#  'CATAGTAGCATAGTAG': 'CL:0000138',
#  'CATATTATTTGCCCTA': 'CL:0008019',
#  'CATCATCTACCCGGAC': 'CL:0000138',
#  'CATCCAATATAGTTTG': 'CL:0008019',
#  'CATCGCCCGCGGCCAA': 'CL:0008019',
#  'CATCTTACACCACCTC': 'CL:0008019',
#  'CATGAACCGACATTTG': 'CL:0002551',
#  'CATGACTTCGCTGAAT': 'CL:0008019',
#  'CATGCATGGAGACCCT': 'CL:0008019',
#  'CATGCGTTAGACAGAA': 'CL:0000138',
#  'CATGCTGGCTCCAATT': 'CL:0000138',
#  'CATGGATTGTCTTCCG': 'CL:0000515',
#  'CATGGCAGGAAGATCG': 'CL:0008019',
#  'CATGGGTCGGGTGTGG': 'CL:0008019',
#  'CATTACGTCGGCCCGT': 'CL:0000138',
#  'CATTATCCCATTAACG': 'CL:0008019',
#  'CATTCGTCGTAGCGGT': 'CL:0008019',
#  'CATTTCTAGCAGACTA': 'CL:0002551',
#  'CCAAACAGAACCCTCG': 'CL:0008019',
#  'CCAACCTTATGTAACT': 'CL:0008019',
#  'CCAACGATGCACTGAT': 'CL:0008019',
#  'CCAAGAAAGTGGGCGA': 'CL:0008019',
#  'CCAAGACTTCTGCGAA': 'CL:0008019',
#  'CCAAGGAACAGAGAGG': 'CL:0000138',
#  'CCAATCGGTAGATCGA': 'CL:0008019',
#  'CCAATTGAATGTTAAT': 'CL:0008019',
#  'CCACATACTGCACCCA': 'CL:0000138',
#  'CCACGAATTTAACCTC': 'CL:0008019',
#  'CCACGAGAAGAGAATC': 'CL:0000138',
#  'CCACGGTGCCCGGTAG': 'CL:0000515',
#  'CCAGAGACAAAGCCGG': 'CL:0008019',
#  'CCAGCTCGAACGCATT': 'CL:0000515',
#  'CCAGCTTCCGCCCGCA': 'CL:0008019',
#  'CCAGGCTGGCGTCTGA': 'CL:0008019',
#  'CCAGTCTTGTCATAGA': 'CL:0008019',
#  'CCATAAACAACCCGAC': 'CL:0000138',
#  'CCATAGGTTGGCGTGG': 'CL:0000138',
#  'CCATATGGAAACTATA': 'CL:0008019',
#  'CCATCCATACCAAGTC': 'CL:0008019',
#  'CCATCTCACCAGTGAA': 'CL:0008019',
#  'CCATGCCCTAGATTTC': 'CL:0000515',
#  'CCATGCTCTGCAGGAA': 'CL:0008019',
#  'CCATGGCCCTTGTACC': 'CL:0000138',
#  'CCATGTTCATCTATAT': 'CL:0008019',
#  'CCCAACCACACTAACA': 'CL:0008019',
#  'CCCAATGAGATTTGCA': 'CL:0000138',
#  'CCCAGGTCTGAAGGCT': 'CL:0000138',
#  'CCCATATAGGTCGATT': 'CL:0008019',
#  'CCCGACCATAGTCCGC': 'CL:0008019',
#  'CCCGAGTTTCTCCGTA': 'CL:0000138',
#  'CCCGCAGGGCCCAAAG': 'CL:0008019',
#  'CCCGCCATGCTCCCGT': 'CL:0000058',
#  'CCCGCGCAATGCACCC': 'CL:0002551',
#  'CCCGGGTCGTTCAGGG': 'CL:0008019',
#  'CCCGGTGGAAGAACCT': 'CL:0000138',
#  'CCCGTAGCTGGGAAGA': 'CL:0008019',
#  'CCCGTCAGCGTCTGAC': 'CL:0002551',
#  'CCCGTTTCGCAGATGT': 'CL:0008019',
#  'CCCTATGTAGAGCAGA': 'CL:0000138',
#  'CCCTCATTCTGGAATT': 'CL:0008019',
#  'CCCTCCTCGCTCGTAT': 'CL:0008019',
#  'CCCTGAAATGAGTTGA': 'CL:0008019',
#  'CCCTGGTATGGGCGGC': 'CL:0008019',
#  'CCGAAAGTGGTGAGCA': 'CL:0002551',
#  'CCGAAGTATATTGTTC': 'CL:0008019',
#  'CCGACAATAGGCCGCC': 'CL:0008019',
#  'CCGACGGGCATGAGGT': 'CL:0008019',
#  'CCGAGAAGTCGCATAA': 'CL:0000138',
#  'CCGATCTCAACCTTAT': 'CL:0008019',
#  'CCGCACGTGACCTCGG': 'CL:0000062',
#  'CCGCATGTGGTACGAT': 'CL:0000515',
#  'CCGCCGGTCAACACAC': 'CL:0000138',
#  'CCGCCGTTGAGGATAA': 'CL:0008019',
#  'CCGCGGGTACGAAGAA': 'CL:0008019',
#  'CCGCGTAGGTAAGGGC': 'CL:0008019',
#  'CCGCTGGTGCCATTCA': 'CL:0008019',
#  'CCGGAATGGTTTCAGT': 'CL:0000515',
#  'CCGGAGCGTACTTTCT': 'CL:0000138',
#  'CCGGCACGACCGTTTC': 'CL:0000515',
#  'CCGGCGCATATTGGAT': 'CL:0000138',
#  'CCGGGACCCGCAGAGA': 'CL:0008019',
#  'CCGGTAATGGCTAGTC': 'CL:0008019',
#  'CCGGTTTGTAATTGTG': 'CL:0008019',
#  'CCGTACCCAAGCGCCA': 'CL:0002551',
#  'CCGTATCTCGTCGTAG': 'CL:0000515',
#  'CCGTGCCCATGACGGC': 'CL:0002551',
#  'CCGTTACGTTAGAACA': 'CL:0008019',
#  'CCTAAAGGCTGACGCT': 'CL:0008019',
#  'CCTAAATTGTATCCTA': 'CL:0000138',
#  'CCTACGGCTCAGTCGA': 'CL:0000187',
#  'CCTACTGCTTACACTT': 'CL:0002551',
#  'CCTAGTTAGTCGCATG': 'CL:0000138',
#  'CCTATACCGTCCTGTC': 'CL:0008019',
#  'CCTATATTTGTCCTGG': 'CL:0008019',
#  'CCTATCTATATCGGAA': 'CL:0008019',
#  'CCTATGAAGTGGTGCC': 'CL:0000515',
#  'CCTATGGCTCCTAGTG': 'CL:0000138',
#  'CCTCACCAATCTTGAC': 'CL:0000187',
#  'CCTCACGTCAGCTAAT': 'CL:0008019',
#  'CCTCCCGACAATCCCT': 'CL:0008019',
#  'CCTCGAAGTGGACGGG': 'CL:0000138',
#  'CCTCGCCAGCAAATTA': 'CL:0000138',
#  'CCTCGCGCTGTGCGAT': 'CL:0008019',
#  'CCTCTACAAGGATTGG': 'CL:0008019',
#  'CCTCTGGCCTAGACGG': 'CL:0000138',
#  'CCTGCTATTTGAGAAG': 'CL:0002551',
#  'CCTGGAAACGTTCTGC': 'CL:0008019',
#  'CCTGGCTAGACCCGCC': 'CL:0008019',
#  'CCTGGTCGAATGTGGG': 'CL:0000515',
#  'CCTGTCCCTCACGTTA': 'CL:0000515',
#  'CCTTCAGTTAAAGTGA': 'CL:0000138',
#  'CCTTCTTGATCCAGTG': 'CL:0008019',
#  'CCTTGACCACTTTATT': 'CL:0008019',
#  'CCTTTAAGGGAGCACT': 'CL:0008019',
#  'CGAAACATAGATGGCA': 'CL:0000138',
#  'CGAACGCCCAGTGCCG': 'CL:0000138',
#  'CGAATCTGCTCGACGC': 'CL:0000138',
#  'CGAATGACGCATAATG': 'CL:0008019',
#  'CGACAATTTGATCTAA': 'CL:0008019',
#  'CGACATGCGATCTTCT': 'CL:0008019',
#  'CGAGAGGGTAGCCGCG': 'CL:0008019',
#  'CGAGATTTCGCTCGGG': 'CL:0008019',
#  'CGAGCACTTCAAGTTT': 'CL:0008019',
#  'CGAGCGTTGATCAGCC': 'CL:0002551',
#  'CGAGCTGGGCTTTAGG': 'CL:0000138',
#  'CGAGGGTATCCAGGTG': 'CL:0000515',
#  'CGAGTGCTATAGTTCG': 'CL:0002551',
#  'CGATAATACTCAGGTT': 'CL:0008019',
#  'CGATCCTCGCAACATA': 'CL:0008019',
#  'CGATTAAATATCTCCT': 'CL:0008019',
#  'CGCAAACACGAGTTAC': 'CL:0000187',
#  'CGCAATTACTTTCGGT': 'CL:0000515',
#  'CGCAATTAGGGTAATA': 'CL:0002551',
#  'CGCAATTCTACAATAA': 'CL:0008019',
#  'CGCACGTCTGTTTATG': 'CL:0008019',
#  'CGCACGTGCGCTATCA': 'CL:0008019',
#  'CGCAGGCGATCCAAAC': 'CL:0008019',
#  'CGCATCATGGCTTCAG': 'CL:0008019',
#  'CGCCCAGCACGCCTAG': 'CL:0000138',
#  'CGCCCGCTTCCGTACA': 'CL:0008019',
#  'CGCCCTTGAAGGCTGA': 'CL:0000138',
#  'CGCCTTTAGCATGCTC': 'CL:0008019',
#  'CGCGCAAATGTCCAGA': 'CL:0008019',
#  'CGCGCCCGACTTAATA': 'CL:0008019',
#  'CGCGGCTCAACTTGAA': 'CL:0008019',
#  'CGCTAGAGACCGCTGC': 'CL:0008019',
#  'CGCTATACCGCCCACT': 'CL:0002551',
#  'CGCTATTCAATGTATG': 'CL:0000187',
#  'CGCTCGACATAATGAT': 'CL:0008019',
#  'CGCTGTGACGCCGCAC': 'CL:0002551',
#  'CGCTGTGTGGATGTTG': 'CL:0008019',
#  'CGCTTAGTATTGATAC': 'CL:0008019',
#  'CGCTTCCACTGAAATC': 'CL:0000138',
#  'CGCTTTCATACCGGTG': 'CL:0000138',
#  'CGGAAAGAATCAAACG': 'CL:0008019',
#  'CGGAGCAATTTAATCG': 'CL:0008019',
#  'CGGAGCTTATAACACC': 'CL:0008019',
#  'CGGAGTTTGAGAGACA': 'CL:0000515',
#  'CGGATAAGCGGACATG': 'CL:0002551',
#  'CGGCAATAAGATCGCC': 'CL:0008019',
#  'CGGCACCGTTAGCGCC': 'CL:0000138',
#  'CGGCCAGAGCGACCAT': 'CL:0008019',
#  'CGGCCCAGGTATATCC': 'CL:0000138',
#  'CGGCTCTTCGTCGAAC': 'CL:0008019',
#  'CGGGAATATAGTATAC': 'CL:0008019',
#  'CGGGAGTATACCGCCG': 'CL:0002551',
#  'CGGGTTTGTTAGGGCT': 'CL:0000138',
#  'CGGTCCGTCGCAAGCC': 'CL:0008019',
#  'CGGTCTATCAACCCGT': 'CL:0008019',
#  'CGGTGTACTTGATCCC': 'CL:0000187',
#  'CGGTTGAGTATCCTTC': 'CL:0008019',
#  'CGTAGCGAATTGTCAG': 'CL:0000138',
#  'CGTCAGTGCGCACAAG': 'CL:0000646',
#  'CGTCATACCATATCCA': 'CL:0002551',
#  'CGTCGCTTGGTTATAC': 'CL:0000138',
#  'CGTCTGGAAGGGCCCG': 'CL:0008019',
#  'CGTGACATTGGGTCGT': 'CL:0000138',
#  'CGTGACCAGTCCTCTG': 'CL:0000515',
#  'CGTGCTTCTACCTAAA': 'CL:0000138',
#  'CGTGGAAGCCTCGTAC': 'CL:0008019',
#  'CGTGGCCGAATATCTA': 'CL:0008019',
#  'CGTGGTACCCAAAGGC': 'CL:0008019',
#  'CGTGTCCCATTCGCGA': 'CL:0000187',
#  'CGTGTCTCGTTACGAC': 'CL:0000138',
#  'CGTTAAACTAGTTAGG': 'CL:0000138',
#  'CGTTAGCTCACAACTG': 'CL:0008019',
#  'CGTTCAGACCCGCGAA': 'CL:0000515',
#  'CGTTGCCCGCGTGGGA': 'CL:0008019',
#  'CGTTGTAAACGTCAGG': 'CL:0002551',
#  'CGTTTAAGCGGAGCAC': 'CL:0000138',
#  'CGTTTCGCTCATTACA': 'CL:0000138',
#  'CGTTTGTGTAGAGGGT': 'CL:0008019',
#  'CTAAATCCGGTGTACA': 'CL:0000138',
#  'CTAATTCGCACGCGCT': 'CL:0000187',
#  'CTAATTTCAACAACAC': 'CL:0008019',
#  'CTACAAGAAATAACCC': 'CL:0008019',
#  'CTACACTCGCAGATGG': 'CL:0000515',
#  'CTACGAACTAGGTCGA': 'CL:0008019',
#  'CTACGCCATTTCCGAT': 'CL:0000138',
#  'CTACTATCATAGGTTT': 'CL:0008019',
#  'CTACTCAAGGTATAGT': 'CL:0000138',
#  'CTACTCTAGGCCCGGC': 'CL:0000138',
#  'CTAGCCACAGGCGAGC': 'CL:0000138',
#  'CTAGGTCTGAAGGAAT': 'CL:0008019',
#  'CTAGTATTCGGAATTA': 'CL:0008019',
#  'CTATAGGCGTTGATGT': 'CL:0000138',
#  'CTATCGCGTAGAGAAC': 'CL:0000138',
#  'CTATGCCCGAATGCAA': 'CL:0008019',
#  'CTATGGGAAGCGGAAT': 'CL:0002355',
#  'CTATGTCTATTGAAAC': 'CL:0008019',
#  'CTCAAACCACTGCCCG': 'CL:0000138',
#  'CTCAGGACTCACCTGT': 'CL:0002551',
#  'CTCATGGCTCACAATC': 'CL:0008019',
#  'CTCCCAATGAGTCGCG': 'CL:0000138',
#  'CTCCGGCCTAATATGC': 'CL:0008019',
#  'CTCCTCCAGCTCACAC': 'CL:0008019',
#  'CTCCTGTTCAAGGCAG': 'CL:0000138',
#  'CTCGCCGAATGTAGGG': 'CL:0008019',
#  'CTCGGGTTCTCTGGCC': 'CL:0000138',
#  'CTCGGTCCGTAGCCTG': 'CL:0000138',
#  'CTCTCTAACTGCCTAG': 'CL:0000515',
#  'CTCTGCGAAGCAAGCA': 'CL:0002551',
#  'CTCTGTTTGAGGATTC': 'CL:0000138',
#  'CTCTTCTATTGACTGG': 'CL:0008019',
#  'CTCTTCTGGAAGTTAG': 'CL:0000138',
#  'CTCTTGTCCCGCTTGG': 'CL:0008019',
#  'CTGAAAGAGATCCGAC': 'CL:0008019',
#  'CTGACATAGAAATAGA': 'CL:0008019',
#  'CTGAGAAAGTTCGGCG': 'CL:0000138',
#  'CTGAGCAAGTAACAAG': 'CL:0000646',
#  'CTGCAAGCACGTTCCG': 'CL:0008019',
#  'CTGCACCTGGAACCGC': 'CL:0000138',
#  'CTGCCAAGGTTGGAAG': 'CL:0008019',
#  'CTGCCTAGCCACCAAG': 'CL:0008019',
#  'CTGCCTTTAATACCTT': 'CL:0000138',
#  'CTGCGTTACGATATAA': 'CL:0008019',
#  'CTGCTGTCTAACGAGC': 'CL:0008019',
#  'CTGGCGACATAAGTCC': 'CL:0008019',
#  'CTGGCGGGAATAAGTA': 'CL:0002551',
#  'CTGGCTGATTCATCCT': 'CL:0008019',
#  'CTGGCTGGTTGTCAGT': 'CL:0000515',
#  'CTGGGATACGCTACCC': 'CL:0008019',
#  'CTGGTAAAGTGTGGGC': 'CL:0008019',
#  'CTGGTCCTAACTTGGC': 'CL:0000646',
#  'CTGGTGAATGGGCCTA': 'CL:0008019',
#  'CTGTAGCCATCTCACT': 'CL:0008019',
#  'CTGTATGGTGTAGAAA': 'CL:0000187',
#  'CTGTTCACTGCCTGTG': 'CL:0008019',
#  'CTGTTCATCTCACGGG': 'CL:0008019',
#  'CTGTTGTTCAGTCGTA': 'CL:0008019',
#  'CTTAACTTCGAAGTAC': 'CL:0000138',
#  'CTTACACGGTATTCCA': 'CL:0008019',
#  'CTTACACTGGGAAATA': 'CL:0008019',
#  'CTTAGCCTTCCACATG': 'CL:0008019',
#  'CTTAGTTGAGGAATCG': 'CL:0008019',
#  'CTTCATAGCTCAAGAA': 'CL:0000187',
#  'CTTCCGCTCCGTGAAG': 'CL:0008019',
#  'CTTCGGCCAATTGTTT': 'CL:0000138',
#  'CTTCTGGGCGTACCTA': 'CL:0008019',
#  'CTTCTTACGTCGTATA': 'CL:0008019',
#  'CTTGGCCAAGCTGGGA': 'CL:0008019',
#  'CTTGTACTTGTTGACT': 'CL:0000187',
#  'CTTGTTTATGTAGCCA': 'CL:0002551',
#  'CTTTGGGATTGTTGCA': 'CL:0000138',
#  'GAAACAGCCATGCAGT': 'CL:0000138',
#  'GAAACATAGGAAACAG': 'CL:0008019',
#  'GAAACCTATACAAATG': 'CL:0008019',
#  'GAAACTCGTGCGATGC': 'CL:0000138',
#  'GAAACTCTAATGAAGG': 'CL:0000138',
#  'GAAAGAACAGCGTTAT': 'CL:0008019',
#  'GAAAGCAGTGCACTTT': 'CL:0008019',
#  'GAAAGTGACTAACTGC': 'CL:0000187',
#  'GAAATACTAAACGTTT': 'CL:0002551',
#  'GAAATCGCGCGCAACT': 'CL:0000138',
#  'GAAATTCACATCGCTG': 'CL:0008019',
#  'GAACACACATCAACCA': 'CL:0008019',
#  'GAACCCTCTGTGTTCT': 'CL:0000515',
#  'GAACGACCGAATGATA': 'CL:0000138',
#  'GAACGCGGGTCACACG': 'CL:0000138',
#  'GAAGAAACGATATTGT': 'CL:0000138',
#  'GAAGAACGGTGCAGGT': 'CL:0008019',
#  'GAAGCCTGCACATTCC': 'CL:0008019',
#  'GAAGCTTGCTGACCGC': 'CL:0008019',
#  'GAAGGAGTCGAGTGCG': 'CL:0000515',
#  'GAAGTGCTGGATAGCT': 'CL:0008019',
#  'GAATAGCATTTAGGGT': 'CL:0008019',
#  'GAATAGTGCTCGATTA': 'CL:0008019',
#  'GAATATTCGGAGTCCC': 'CL:0008019',
#  'GAATCGACATGGTCAC': 'CL:0000187',
#  'GAATCGCCGGACACGG': 'CL:0002551',
#  'GAATGCCGAAATGACC': 'CL:0008019',
#  'GAATGTATGGCAGGTC': 'CL:0008019',
#  'GAATTTCTCGCTGCAG': 'CL:0008019',
#  'GACAAACATATGCAGG': 'CL:0008019',
#  'GACAACGCAGCTTACG': 'CL:0000187',
#  'GACAAGAGATGAGATT': 'CL:0000138',
#  'GACACGAGTTAGAGGA': 'CL:0002551',
#  'GACACTGGAACCCGAT': 'CL:0008019',
#  'GACATCGATTTATAAC': 'CL:0000646',
#  'GACCAGAGCCCTGTAG': 'CL:0002551',
#  'GACCGACGTGAAAGCA': 'CL:0008019',
#  'GACCGTCAGGTCGTGA': 'CL:0008019',
#  'GACGAGGCTAATAAAC': 'CL:0000515',
#  'GACGCCGTAAAGGCTA': 'CL:0008019',
#  'GACGGGTTGGCCCGTA': 'CL:0008019',
#  'GACGTGTAGGGATTAT': 'CL:0000187',
#  'GACTAAGATCATGCAC': 'CL:0002551',
#  'GACTAAGTAGGCTCAC': 'CL:0000515',
#  'GACTACAATTGCTCGT': 'CL:0008019',
#  'GACTCACCCACGTGAG': 'CL:0008019',
#  'GACTGCTGGTGAGAAA': 'CL:0008019',
#  'GAGACTTCGCGACCGA': 'CL:0008019',
#  'GAGATCTGCTTGGCAT': 'CL:0000138',
#  'GAGCATCAACAACTTG': 'CL:0000138',
#  'GAGCATCATCCCTGGG': 'CL:0002551',
#  'GAGCGAGGGAGTACCG': 'CL:0000138',
#  'GAGCGCAAATACTCCG': 'CL:0008019',
#  'GAGCGCTGTTAGGTAA': 'CL:0000138',
#  'GAGCTCTCGGACCTAA': 'CL:0000187',
#  'GAGGAATGGAGAGGTT': 'CL:0000187',
#  'GAGGATAAACAGTGCT': 'CL:0008019',
#  'GAGGGAGTCAGATCGC': 'CL:0008019',
#  'GAGGGTAGTAACAAAG': 'CL:0000138',
#  'GAGGTACATCCATCTT': 'CL:0000138',
#  'GAGGTCCCAAAGATCT': 'CL:0002551',
#  'GAGTAAACCGGAAAGT': 'CL:0000138',
#  'GAGTACGGGTATACAA': 'CL:0008019',
#  'GAGTAGATACTAGTTG': 'CL:0000515',
#  'GAGTATCAAAGTTACA': 'CL:0008019',
#  'GAGTCAGACCAGAATC': 'CL:0008019',
#  'GATAAATCGGTGGATG': 'CL:0000138',
#  'GATATCTCATGCAATA': 'CL:0000138',
#  'GATATGCGGTAGCCAA': 'CL:0000646',
#  'GATATTTCCTACATGG': 'CL:0008019',
#  'GATCAACATAAAGGGA': 'CL:0000138',
#  'GATCCTCTTGCGCTTA': 'CL:0008019',
#  'GATCGACACTATCTGA': 'CL:0002551',
#  'GATCGCTATATCTCAG': 'CL:0000138',
#  'GATCGGCGATAAGTCG': 'CL:0002551',
#  'GATCTCGACGCTGTGG': 'CL:0000138',
#  'GATCTGCTATCTAAGG': 'CL:0008019',
#  'GATGACAAGTAGGGCA': 'CL:0000515',
#  'GATGCCAGCAGAAGGC': 'CL:0008019',
#  'GATGCTACAAGCGCCT': 'CL:0000138',
#  'GATGGCGCACACATTA': 'CL:0002551',
#  'GATGGTGCCCTAGGCA': 'CL:0008019',
#  'GATGTCGGTCAACTGC': 'CL:0000138',
#  'GATGTTTGTGCGAGAT': 'CL:0008019',
#  'GATTCCGCGTTTCCGT': 'CL:0000138',
#  'GATTCCTATACGGCGC': 'CL:0000138',
#  'GATTGCTCCAGTTGCA': 'CL:0000138',
#  'GCAAACCTTGGCCATA': 'CL:0000515',
#  'GCAAACGTCGCCAGGT': 'CL:0008019',
#  'GCAAAGGGCGTTAGCC': 'CL:0008019',
#  'GCAACAGCAGTATGCG': 'CL:0008019',
#  'GCAACCACCAGACCGG': 'CL:0008019',
#  'GCAACGGCTAGTTATG': 'CL:0008019',
#  'GCAAGTGCACAGAGAA': 'CL:0000187',
#  'GCAAGTGTAAAGCATG': 'CL:0008019',
#  'GCACAAACCCTAGATG': 'CL:0008019',
#  'GCACAAACGAGGCGTG': 'CL:0000138',
#  'GCACAAGTGTCGGAAG': 'CL:0000138',
#  'GCACGCCTACTTAGAT': 'CL:0008019',
#  'GCACTAGTCGCGCTAT': 'CL:0008019',
#  'GCAGAAGGTAATCTCC': 'CL:0008019',
#  'GCAGACCCAGCACGTA': 'CL:0008019',
#  'GCAGTGCGGGCGGATG': 'CL:0008019',
#  'GCAGTTCGATCCGAGC': 'CL:0000138',
#  'GCATCCCTAACTTTGA': 'CL:0000138',
#  'GCATCGGCCGTGTAGG': 'CL:0008019',
#  'GCCACTCCTTACGGTA': 'CL:0000138',
#  'GCCAGGCGTTCGCATG': 'CL:0008019',
#  'GCCCACCAAGGCTGTC': 'CL:0002551',
#  'GCCCAGTTGGTATGCC': 'CL:0000187',
#  'GCCCGCGCGTTTGACA': 'CL:0000058',
#  'GCCGACCCACGACTGC': 'CL:0000138',
#  'GCCGTGGAAGAAATGT': 'CL:0008019',
#  'GCCTAGCGATCTGACC': 'CL:0000058',
#  'GCCTATCAGGTAAGAT': 'CL:0008019',
#  'GCCTATTCCGATATAG': 'CL:0000187',
#  'GCCTCATCTGGAAATA': 'CL:0008019',
#  'GCCTTCAGCCCTACCG': 'CL:0000138',
#  'GCGAAACGATCGGGAG': 'CL:0008019',
#  'GCGACATGTAAACATC': 'CL:0008019',
#  'GCGACCCAACCATCTG': 'CL:0008019',
#  'GCGAGCGCATGCTCCC': 'CL:0008019',
#  'GCGATTCTGGAAGCAG': 'CL:0000138',
#  'GCGCAAATATATTCAA': 'CL:0008019',
#  'GCGCAAGAGCGCGCTG': 'CL:0000515',
#  'GCGCCTCCCACTCCGA': 'CL:0000138',
#  'GCGCTGATCCAGACTC': 'CL:0008019',
#  'GCGGAGAAACTTCGCA': 'CL:0000515',
#  'GCGGCAAAGTATTGCC': 'CL:0008019',
#  'GCGGGAACCAGGCCCT': 'CL:0008019',
#  'GCGGGCGAGCCTTACC': 'CL:0008019',
#  'GCGGTCCCTAGACGCA': 'CL:0008019',
#  'GCGTCCCTAAGACATA': 'CL:0000138',
#  'GCGTCGAAATGTCGGT': 'CL:0000138',
#  'GCGTCGCCAGGGTGAT': 'CL:0000515',
#  'GCTAAACCTGAGGTGA': 'CL:0008019',
#  'GCTAATACCGAATGCC': 'CL:0008019',
#  'GCTACAATCGAGGATA': 'CL:0008019',
#  'GCTAGACCGTCTACTG': 'CL:0000138',
#  'GCTAGAGTAGAGATGT': 'CL:0008019',
#  'GCTAGCGATAGGTCTT': 'CL:0008019',
#  'GCTAGTTTCATTGAGG': 'CL:0000187',
#  'GCTATCGCGGCGCAAC': 'CL:0002551',
#  'GCTCAATCCGTTTATT': 'CL:0000515',
#  'GCTCAATGTAATACCG': 'CL:0008019',
#  'GCTCATTACTGCATGT': 'CL:0008019',
#  'GCTCCCAGTCGGTCCA': 'CL:0000138',
#  'GCTCCGCTCGCTTCAG': 'CL:0000515',
#  'GCTCCTGACATACTGG': 'CL:0000515',
#  'GCTCGCTCATGTCCAA': 'CL:0008019',
#  'GCTCGGAATTTAAAGC': 'CL:0000646',
#  'GCTCTATGTTACGTGC': 'CL:0002573',
#  'GCTCTTTCCGCTAGTG': 'CL:0008019',
#  'GCTGAATCTTCCAATC': 'CL:0008019',
#  'GCTGCTAAGTAGTCGA': 'CL:0008019',
#  'GCTGGCATATTCACCT': 'CL:0008019',
#  'GCTGTTGCTACCGAAC': 'CL:0000515',
#  'GCTTACGTAGTTAGTA': 'CL:0000515',
#  'GCTTGATGATAATCAG': 'CL:0000187',
#  'GGAAACTAAATGGGCC': 'CL:0008019',
#  'GGAACCTTGACTCTGC': 'CL:0008019',
#  'GGAACTTTGGCGATTA': 'CL:0008019',
#  'GGAAGCTCGCTTACAG': 'CL:0000138',
#  'GGACACAAGTTTACAC': 'CL:1000413',
#  'GGACCTCTAGGCCGCC': 'CL:0008019',
#  'GGACTCACAAATTAGG': 'CL:0008019',
#  'GGACTCGTGAGTGGTC': 'CL:0000138',
#  'GGACTCTTCCGGTTGA': 'CL:0008019',
#  'GGAGAAGTCATTGGCA': 'CL:0000187',
#  'GGAGGATTGAAAGGAG': 'CL:0000138',
#  'GGAGGCCGAAGTCGTC': 'CL:0008019',
#  'GGAGTGCCGCCCTGGA': 'CL:0000138',
#  'GGATCTTACTGCCCTT': 'CL:0000138',
#  'GGATGAAGATCGCTGA': 'CL:0008019',
#  'GGATTCAGTACGGTGG': 'CL:0000187',
#  'GGATTCCGCTATACCC': 'CL:0008019',
#  'GGCAAAGGCGCCAATA': 'CL:0000515',
#  'GGCAAGCCCATAGTGG': 'CL:0008019',
#  'GGCACTCCACTGGGCA': 'CL:0000138',
#  'GGCAGCAAACCTATGC': 'CL:0008019',
#  'GGCATATCGGTTCTGC': 'CL:0008019',
#  'GGCCGAGACTCTGGTG': 'CL:0000138',
#  'GGCCGTTTGGGTTTCA': 'CL:0008019',
#  'GGCCTGCTTCTCCCGA': 'CL:0000138',
#  'GGCGCTCCTCATCAAT': 'CL:0000646',
#  'GGCGTCCTATCCGCTG': 'CL:0008019',
#  'GGCTACTATACACTCC': 'CL:0008019',
#  'GGCTCCTCCACCTGTT': 'CL:0008019',
#  'GGCTCGTGCCACCAGC': 'CL:0000187',
#  'GGCTTTCAATAAGGGT': 'CL:0008019',
#  'GGGAACGGTTTCAGAT': 'CL:0000138',
#  'GGGACAGAGTTACTCC': 'CL:0008019',
#  'GGGACCCGTATATCTT': 'CL:0008019',
#  'GGGAGGATGCCCGAAA': 'CL:0008019',
#  'GGGCAGAGCAATCGTT': 'CL:0008019',
#  'GGGCGGTCCTATTGTC': 'CL:0002551',
#  'GGGCGTCCACTGGCTC': 'CL:0008019',
#  'GGGCGTTTACATTCAT': 'CL:0008019',
#  'GGGCTATGATCGATGG': 'CL:0008019',
#  'GGGTATGTATGCACTT': 'CL:0008019',
#  'GGGTCAGGAGCTAGAT': 'CL:0008019',
#  'GGGTGGTCCAGCCTGT': 'CL:0008019',
#  'GGGTGTTTCAGCTATG': 'CL:0000138',
#  'GGGTTAACATTTGAGT': 'CL:0008019',
#  'GGGTTCAGACGAACAA': 'CL:0002551',
#  'GGGTTTAGGATAGGAT': 'CL:0000138',
#  'GGTAAATGTGCGTTAC': 'CL:0008019',
#  'GGTAACTATGTATCTG': 'CL:0002551',
#  'GGTAGACCGTTGGGCG': 'CL:0008019',
#  'GGTCAAGACTACTTCG': 'CL:0008019',
#  'GGTCGGTAATTAGACA': 'CL:0002551',
#  'GGTCGGTCGTCCACAG': 'CL:0008019',
#  'GGTCTCTGAATGGACT': 'CL:0008019',
#  'GGTGAGATGCAGATAA': 'CL:0000187',
#  'GGTGCATAAATGATTA': 'CL:0008019',
#  'GGTGCGGATAAGTGGC': 'CL:0008019',
#  'GGTGCTGATCACAAAG': 'CL:0000138',
#  'GGTTAGGCTTGGAGAA': 'CL:0000187',
#  'GGTTAGTTACGGCGCC': 'CL:0000138',
#  'GGTTCTACTCGTCTGA': 'CL:0008019',
#  'GGTTTAATTACCATCG': 'CL:0000138',
#  'GGTTTAGCCTTTCTTG': 'CL:0008019',
#  'GGTTTGAGTGCTGGAA': 'CL:0002551',
#  'GTAACATCTAAGATAA': 'CL:0000138',
#  'GTAACTGCCCAAGGAG': 'CL:0008019',
#  'GTAAGGATTTGTCGGA': 'CL:0000138',
#  'GTAAGTAGGGTATACC': 'CL:0000187',
#  'GTACGAGATTGCGACA': 'CL:0008019',
#  'GTACTGAGGTCGTAAC': 'CL:0000646',
#  'GTACTGCATGAAGCGT': 'CL:0002551',
#  'GTACTTGGGCACTTCT': 'CL:0000187',
#  'GTAGAAACGGGTGGAG': 'CL:0000138',
#  'GTAGACGTCGTTACAT': 'CL:0000138',
#  'GTAGAGGGAGACAAGT': 'CL:0000515',
#  'GTAGCTCCGGGAGGCT': 'CL:0000138',
#  'GTAGGTGATCCGTGTA': 'CL:0008019',
#  'GTAGTTCGAAGGCGAA': 'CL:0000138',
#  'GTATAGGACTCAGTAG': 'CL:0008019',
#  'GTATCAAACGTTAGCT': 'CL:0000515',
#  'GTATCAGCTTGGGTTC': 'CL:0000187',
#  'GTATCTCAGTCTTGAC': 'CL:0008019',
#  'GTATTAAGGCGTCTAA': 'CL:0002551',
#  'GTATTTAATGGCATAA': 'CL:0008019',
#  'GTCAAAGTTTACATAG': 'CL:0000646',
#  'GTCACAAAGTTTCCAA': 'CL:0000138',
#  'GTCACTCTCCAAATCT': 'CL:0000187',
#  'GTCAGAATAGTCTATG': 'CL:0002355',
#  'GTCAGTTGTGCTCGTT': 'CL:0000138',
#  'GTCCAATATTTAGCCT': 'CL:0008019',
#  'GTCCACGTCGCATTCG': 'CL:0008019',
#  'GTCCATTACTGCTACG': 'CL:0000138',
#  'GTCCTTCTAGTGGGTT': 'CL:0008019',
#  'GTCGATAGGTGACTTT': 'CL:0008019',
#  'GTCGCCGTTGTGTGTT': 'CL:0008019',
#  'GTCGGATGTAGCGCGC': 'CL:0000138',
#  'GTCGGGAAGCAGAAAC': 'CL:0008019',
#  'GTCGTCAATTATAAGG': 'CL:0002551',
#  'GTCTCAAGGCCCGGCT': 'CL:0000515',
#  'GTCTCCTGCCAGTATG': 'CL:0008019',
#  'GTCTCGATCTGCTTTC': 'CL:0008019',
#  'GTCTTAGTACAGCCGG': 'CL:0000138',
#  'GTCTTGAGGAGCAGTG': 'CL:0008019',
#  'GTCTTGTAGCTATTCA': 'CL:0008019',
#  'GTGAAACGTGCTCCAC': 'CL:0002551',
#  'GTGAGGAGCGGTTGAG': 'CL:0008019',
#  'GTGATCAAGCGTGCAC': 'CL:0000138',
#  'GTGATCACTAACGCCT': 'CL:0000646',
#  'GTGCAACAAATGTGGC': 'CL:0000138',
#  'GTGCACCAGCTTCAAC': 'CL:0008019',
#  'GTGCACGAAAGTGACT': 'CL:0000138',
#  'GTGCAGCGTAGAGTAG': 'CL:0008019',
#  'GTGCGACAGGGAGTGT': 'CL:0008019',
#  'GTGCGGGTCTCCAAAT': 'CL:0000515',
#  'GTGCTTACATCAGCGC': 'CL:0008019',
#  'GTGGAACCTACATGCG': 'CL:0000138',
#  'GTGGACGCATTTGTCC': 'CL:0008019',
#  'GTGGACGTGCTGAGAC': 'CL:0008019',
#  'GTGGAGCGTTTACCGA': 'CL:0008019',
#  'GTGGAGTCGGCGGTTG': 'CL:0000646',
#  'GTGGGCTTAGACACAC': 'CL:0000515',
#  'GTGGTATAGTCTGCCG': 'CL:0008019',
#  'GTTAACTATGTTGTCA': 'CL:0008019',
#  'GTTAGAGTGTGCCGCT': 'CL:0000138',
#  'GTTATAATACGGTGAA': 'CL:0008019',
#  'GTTATTAACGTGGGAG': 'CL:0008019',
#  'GTTCCAGTCTGACCAT': 'CL:0000138',
#  'GTTCCCGTAAACATAT': 'CL:0000138',
#  'GTTCGACAATTGTATA': 'CL:0008019',
#  'GTTCGCTGAGACGTCT': 'CL:0008019',
#  'GTTCTTCCCTCGATGT': 'CL:0000138',
#  'GTTGCACGGAGTTTCG': 'CL:0002551',
#  'GTTGCAGTCGACAACA': 'CL:0008019',
#  'GTTGCGGACGGTCAGG': 'CL:0008019',
#  'GTTGGATTTGCGTTGG': 'CL:0000187',
#  'GTTGGTCATGCTATCC': 'CL:0008019',
#  'GTTGTCGTGTTAGTTG': 'CL:0008019',
#  'GTTTCCTGGAGGGTGA': 'CL:0002551',
#  'GTTTGGTAGGGTCAAC': 'CL:0008019',
#  'GTTTGGTGATCGGTGC': 'CL:0008019',
#  'TAAACCCAGGAGGGCA': 'CL:0008019',
#  'TAAAGACAACCCTTTA': 'CL:0008019',
#  'TAAAGCGGTATTTCCA': 'CL:0008019',
#  'TAAATGAATCCGTTTC': 'CL:0000187',
#  'TAACAAAGGGAGAAGC': 'CL:0000187',
#  'TAACAGCGTTTGTGCT': 'CL:0000138',
#  'TAACGCTTTGAGAGCG': 'CL:0008019',
#  'TAACTATCGAAGGTCC': 'CL:0008019',
#  'TAACTCCATGGAGGCT': 'CL:0002551',
#  'TAAGCGCGAATCAAAT': 'CL:0000138',
#  'TAAGGAACTTGTGGGA': 'CL:0000138',
#  'TAAGGCATAACATCAA': 'CL:0008019',
#  'TAAGGCTGAATCCCTC': 'CL:0008019',
#  'TAAGTCGCCGAGTATC': 'CL:0000515',
#  'TAATAAACAAGGAGAT': 'CL:0008019',
#  'TAATACACAGTAGTAT': 'CL:0008019',
#  'TAATAGGTCACCAGAA': 'CL:0008019',
#  'TAATATTGAAATTCGC': 'CL:0008019',
#  'TAATGAAAGACCCTTG': 'CL:0002551',
#  'TAATTACGTCAGTAGA': 'CL:0008019',
#  'TAATTAGGACATCCGT': 'CL:0000138',
#  'TACAAGTCTCGTGCAT': 'CL:0000138',
#  'TACCAAATAGCCCAGA': 'CL:0008019',
#  'TACCAGCTAGGTTTAA': 'CL:0000138',
#  'TACCAGGAATCCCGTC': 'CL:0008019',
#  'TACCGTAGGTTAACTA': 'CL:0000138',
#  'TACCTACTCCCAGTAT': 'CL:0008019',
#  'TACCTCACGCTTGTAC': 'CL:0000187',
#  'TACCTCAGTTGTCTGT': 'CL:0008019',
#  'TACCTCCACACCAATG': 'CL:0008019',
#  'TACCTGCTGCACTGTG': 'CL:0000138',
#  'TACGCCGAGGGTACCC': 'CL:0008019',
#  'TACGCCTCCATTCCGA': 'CL:0008019',
#  'TACGCTCGGTATTGGA': 'CL:0008019',
#  'TACGCTGCTGTGTTAA': 'CL:0008019',
#  'TACGGGATGCTAGCAG': 'CL:0008019',
#  'TACGTACTAGTGCTGA': 'CL:0000138',
#  'TACGTGCACTATGCTG': 'CL:0000187',
#  'TACTATGGTTCCTCAG': 'CL:0008019',
#  'TACTCCTCTAGTTGAC': 'CL:0000138',
#  'TACTCTCCGAACAAAT': 'CL:0008019',
#  'TACTCTTACTTTACTG': 'CL:0000138',
#  'TACTCTTTCGTCTTCA': 'CL:0008019',
#  'TACTGAACAGATTTAG': 'CL:0008019',
#  'TACTGTTTCTCTGGTA': 'CL:0008019',
#  'TAGAATTAAGGGCAAC': 'CL:0000138',
#  'TAGACTACCTAGCGTT': 'CL:0008019',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              193
# AAACAAGTATCTCCCA-1          1         50        102             4955
# AAACAATCTACTAGCA-1          0          3         43             1169
# AAACACCAATAACTGC-1          0         59         19             1584
# AAACAGAGCGACTCCT-1          0         14         94             2738
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4580
# TTGTTTCATTAGTCTA-1          1         60         30             3769
# TTGTTTCCATACAACT-1          0         45         27               34
# TTGTTTGTATTACACG-1          0         73         41              226
# TTGTTTGTGTAAATTC-1          0          7         51             1432
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0008019
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                        NaN
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0008019
# TTGTTTCATTAGTCTA-1                 CL:0000138
# TTGTTTCCATACAACT-1                        NaN
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 3713

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_32113/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              193
# AAACAAGTATCTCCCA-1          1         50        102             4955
# AAACAATCTACTAGCA-1          0          3         43             1169
# AAACACCAATAACTGC-1          0         59         19             1584
# AAACAGAGCGACTCCT-1          0         14         94             2738
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4580
# TTGTTTCATTAGTCTA-1          1         60         30             3769
# TTGTTTCCATACAACT-1          0         45         27               34
# TTGTTTGTATTACACG-1          0         73         41              226
# TTGTTTGTGTAAATTC-1          0          7         51             1432
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0008019
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                    unknown
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0008019
# TTGTTTCATTAGTCTA-1                 CL:0000138
# TTGTTTCCATACAACT-1                    unknown
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0008019',
#  'CL:0000515',
#  'CL:0000138',
#  'CL:0002551',
#  'CL:0000646',
#  'CL:0000187',
#  'CL:0000062',
#  'CL:0000192',
#  'CL:0000058',
#  'CL:0002355',
#  'CL:0002573',
#  'CL:1000413',
#  'CL:0000388']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000023']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000023
# AAACAAGTATCTCCCA-1    HsapDv:0000023
# AAACAATCTACTAGCA-1    HsapDv:0000023
# AAACACCAATAACTGC-1    HsapDv:0000023
# AAACAGAGCGACTCCT-1    HsapDv:0000023
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000023
# TTGTTTCATTAGTCTA-1    HsapDv:0000023
# TTGTTTCCATACAACT-1    HsapDv:0000023
# TTGTTTGTATTACACG-1    HsapDv:0000023
# TTGTTTGTGTAAATTC-1    HsapDv:0000023
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000023']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              193
# AAACAAGTATCTCCCA-1          1         50        102             4955
# AAACAATCTACTAGCA-1          0          3         43             1169
# AAACACCAATAACTGC-1          0         59         19             1584
# AAACAGAGCGACTCCT-1          0         14         94             2738
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4580
# TTGTTTCATTAGTCTA-1          1         60         30             3769
# TTGTTTCCATACAACT-1          0         45         27               34
# TTGTTTGTATTACACG-1          0         73         41              226
# TTGTTTGTGTAAATTC-1          0          7         51             1432
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699526
# AAACAAGTATCTCCCA-1                 CL:0008019  WSSS_THYst9699526
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699526
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699526
# AAACAGAGCGACTCCT-1                    unknown  WSSS_THYst9699526
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0008019  WSSS_THYst9699526
# TTGTTTCATTAGTCTA-1                 CL:0000138  WSSS_THYst9699526
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699526
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9699526
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699526
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000023
# AAACAAGTATCTCCCA-1                     HsapDv:0000023
# AAACAATCTACTAGCA-1                     HsapDv:0000023
# AAACACCAATAACTGC-1                     HsapDv:0000023
# AAACAGAGCGACTCCT-1                     HsapDv:0000023
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000023
# TTGTTTCATTAGTCTA-1                     HsapDv:0000023
# TTGTTTCCATACAACT-1                     HsapDv:0000023
# TTGTTTGTATTACACG-1                     HsapDv:0000023
# TTGTTTGTGTAAATTC-1                     HsapDv:0000023
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699526': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8),
#                  'lowres': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.6275457172014,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 169.01372769701763,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9699526.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)
adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              193
# AAACAAGTATCTCCCA-1          1         50        102             4955
# AAACAATCTACTAGCA-1          0          3         43             1169
# AAACACCAATAACTGC-1          0         59         19             1584
# AAACAGAGCGACTCCT-1          0         14         94             2738
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4580
# TTGTTTCATTAGTCTA-1          1         60         30             3769
# TTGTTTCCATACAACT-1          0         45         27               34
# TTGTTTGTATTACACG-1          0         73         41              226
# TTGTTTGTGTAAATTC-1          0          7         51             1432
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699526
# AAACAAGTATCTCCCA-1                 CL:0008019  WSSS_THYst9699526
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699526
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699526
# AAACAGAGCGACTCCT-1                    unknown  WSSS_THYst9699526
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0008019  WSSS_THYst9699526
# TTGTTTCATTAGTCTA-1                 CL:0000138  WSSS_THYst9699526
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699526
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9699526
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699526
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000023
# AAACAAGTATCTCCCA-1                     HsapDv:0000023
# AAACAATCTACTAGCA-1                     HsapDv:0000023
# AAACACCAATAACTGC-1                     HsapDv:0000023
# AAACAGAGCGACTCCT-1                     HsapDv:0000023
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000023
# TTGTTTCATTAGTCTA-1                     HsapDv:0000023
# TTGTTTCCATACAACT-1                     HsapDv:0000023
# TTGTTTGTATTACACG-1                     HsapDv:0000023
# TTGTTTGTGTAAATTC-1                     HsapDv:0000023
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699526': {'images': {'hires': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8),
#                  'fullres': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.6275457172014,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9699526'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide8.h5ad', compression = 'gzip')

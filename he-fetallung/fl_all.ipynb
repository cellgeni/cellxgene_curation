# %% [markdown]
# # **Curating `fetal-lung` datasets:**

# %% [markdown]
# ### Full dataset

# %% [markdown]
# # <ins>STEPS:</ins>

# %% [markdown]
# ## 1. Load the dataset

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy

# %%
adata = sc.read_h5ad('/lustre/scratch117/cellgen/team205/ph12/201002_NewLung_DaweiRNA/220511Assembled10DomainsFiltered.h5ad')

# %%
adata.var_names.sort_values()
# Out:
# Index(['A1BG', 'A1BG-AS1', 'A1CF', 'A2M', 'A2M-AS1', 'A2ML1', 'A2ML1-AS1',
#        'A3GALT2', 'A4GALT', 'AAAS',
#        ...
#        'ZW10', 'ZWILCH', 'ZWINT', 'ZXDA', 'ZXDB', 'ZXDC', 'ZYG11A', 'ZYG11B',
#        'ZYX', 'ZZEF1'],
#       dtype='object', length=26568)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26568
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
# ...

# %%
adata.obs_names
# Out:
# Index(['AAACCTGAGACAGGCT-5891STDY8062349', 'AAACCTGCACCGAATT-5891STDY8062349',
#        'AAAGATGTCGTGACAT-5891STDY8062349', 'AAAGCAACAAACGTGG-5891STDY8062349',
#        'AAAGCAACATACTACG-5891STDY8062349', 'AAAGCAATCGAATCCA-5891STDY8062349',
#        'AAAGTAGGTAAAGGAG-5891STDY8062349', 'AAAGTAGGTACCGGCT-5891STDY8062349',
#        'AAATGCCAGCTGTTCA-5891STDY8062349', 'AACACGTAGTGGACGT-5891STDY8062349',
#        ...
#        'GAGTCCGGTCTGCAAT-WSSS_F_LNG8713178',
#        'TTAACTCTCTATCCCG-WSSS_F_LNG8713178',
#        'CGCTATCGTCTGGTCG-WSSS_F_LNG8713179',
#        'GGGCATCTCAGCAACT-WSSS_F_LNG8713179',
#        'CTCATTACAATCAGAA-WSSS_F_LNG8713184',
#        'GTCACGGAGCCCTAAT-WSSS_F_LNG8713184',
#        'ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185',
#        'CATCGAACATTAACCG-WSSS_F_LNG8713185',
#        'CTCAGAAGTACTCTCC-WSSS_F_LNG8713185',
#        'TACGGGCTCACCTTAT-WSSS_F_LNG8713188'],
#       dtype='object', length=71752)

# %%
adata.obs
# Out:
#                                                 batch  stage dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAACCTGCACCGAATT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGATGTCGTGACAT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACAAACGTGG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACATACTACG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# ...                                               ...    ...        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  WSSS_F_LNG8713184   15.0   Proximal
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CATCGAACATTAACCG-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  WSSS_F_LNG8713188   15.0   Proximal
#
#                                         chemistry  percent_mito  n_counts  \
# ...

# %%
#adata.obs.to_csv('/lustre/scratch117/cellgen/cellgeni/cxgportal_sets/fetal-lung/cellnames_all.csv')

# %%
len(adata.var.columns)
# Out:
# 717

# %%
adata.var = adata.var[['gene_ids', 'n_cells']]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26568
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
#     var: 'gene_ids', 'n_cells'
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'dissection_colors', 'new_celltype_colors', 'phase_colors', 'rank_genes_groups_global'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
def CalculateRaw(adata,scaling_factor=10000):
    #update by Polanski in Feb 2022
    #The object must contain a log-transformed matrix
    #This function returns an integer-count object
    #The normalization constant is assumed to be 10000
    #return anndata.AnnData(X=sparse.csr_matrix(np.rint(np.array(np.expm1(adata.X).todense().transpose())*(adata.obs['n_counts'].values).transpose() / scaling_factor).transpose()),\
    #              obs=adata.obs,var=adata.var,obsm=adata.obsm,varm=adata.varm)
    X = np.expm1(adata.X)
    scaling_vector = adata.obs['n_counts'].values / scaling_factor
    #.indptr[i]:.indptr[i+1] provides the .data coordinates where the i'th row of the data resides in CSR
    #which happens to be a cell, which happens to be what we have a unique entry in scaling_vector for
    for i in np.arange(X.shape[0]):
        X.data[X.indptr[i]:X.indptr[i+1]] = X.data[X.indptr[i]:X.indptr[i+1]] * scaling_vector[i]
    return sc.AnnData(X=np.rint(X),obs=adata.obs,var=adata.var,obsm=adata.obsm,varm=adata.varm)

# %%
raw = CalculateRaw(adata)

# %%
del raw.var

# %%
geno = pd.read_csv('~/genes_homo_sapiens.csv', header = None, names = ['ENSEMBLid', 'gena','no'])
# Out:
# /opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
geno
# Out:
#               ENSEMBLid                 gena no
# 0       ENSG00000223972              DDX11L1  5
# 1       ENST00000456328          DDX11L1-202  2
# 2       ENST00000450305          DDX11L1-201  2
# 3       ENSG00000227232               WASH7P  5
# 4       ENST00000488147           WASH7P-201  1
# ...                 ...                  ... ..
# 297782  ENST00000621424  ENSG110105435.4-001  4
# 297783  ENSG00000278625                   U6  1
# 297784  ENST00000616830            U6.88-201  1
# 297785  ENSG00000277374                   U1  1
# 297786  ENST00000612925            U1.29-201  1
#
# [297787 rows x 3 columns]

# %%
ens_ids = adata.var['gene_ids']

# %%
adata.var
# Out:
#                     gene_ids  n_cells
# MIR1302-2HG  ENSG00000243485      105
# FAM138A      ENSG00000237613       17
# AL627309.1   ENSG00000238009      148
# AL627309.3   ENSG00000239945       11
# AL627309.2   ENSG00000239906       10
# ...                      ...      ...
# AC004556.1   ENSG00000276345    26486
# AC233755.2   ENSG00000277856       90
# AC233755.1   ENSG00000275063      153
# AC240274.1   ENSG00000271254    13664
# AC213203.1   ENSG00000277475       18
#
# [26568 rows x 2 columns]

# %%
genedict = {key: 1 for key in list(geno.ENSEMBLid)}

# %%
genedict
# Out:
# {'ENSG00000223972': 1,
#  'ENST00000456328': 1,
#  'ENST00000450305': 1,
#  'ENSG00000227232': 1,
#  'ENST00000488147': 1,
#  'ENSG00000278267': 1,
#  'ENST00000619216': 1,
#  'ENSG00000243485': 1,
#  'ENST00000473358': 1,
#  'ENST00000469289': 1,
#  'ENSG00000284332': 1,
#  'ENST00000607096': 1,
#  'ENSG00000237613': 1,
#  'ENST00000417324': 1,
#  'ENST00000461467': 1,
#  'ENSG00000268020': 1,
#  'ENST00000606857': 1,
#  'ENSG00000240361': 1,
#  'ENST00000642116': 1,
#  'ENST00000492842': 1,
#  'ENSG00000186092': 1,
#  'ENST00000641515': 1,
#  'ENSG00000238009': 1,
#  'ENST00000466430': 1,
#  'ENST00000477740': 1,
#  'ENST00000471248': 1,
#  'ENST00000610542': 1,
#  'ENST00000453576': 1,
#  'ENSG00000239945': 1,
#  'ENST00000495576': 1,
#  'ENSG00000233750': 1,
#  'ENST00000442987': 1,
#  'ENSG00000268903': 1,
#  'ENST00000494149': 1,
#  'ENSG00000269981': 1,
#  'ENST00000595919': 1,
#  'ENSG00000239906': 1,
#  'ENST00000493797': 1,
#  'ENSG00000241860': 1,
#  'ENST00000484859': 1,
# ...

# %%
ens_ids2 = [x for x in ens_ids if (x in genedict or x.startswith('SARSCoV'))]

# %%
ens_ids2
# Out:
# ['ENSG00000243485',
#  'ENSG00000237613',
#  'ENSG00000238009',
#  'ENSG00000239945',
#  'ENSG00000239906',
#  'ENSG00000236601',
#  'ENSG00000235146',
#  'ENSG00000237491',
#  'ENSG00000177757',
#  'ENSG00000225880',
#  'ENSG00000230368',
#  'ENSG00000272438',
#  'ENSG00000230699',
#  'ENSG00000241180',
#  'ENSG00000223764',
#  'ENSG00000187634',
#  'ENSG00000188976',
#  'ENSG00000187961',
#  'ENSG00000187583',
#  'ENSG00000187642',
#  'ENSG00000272512',
#  'ENSG00000188290',
#  'ENSG00000187608',
#  'ENSG00000224969',
#  'ENSG00000188157',
#  'ENSG00000273443',
#  'ENSG00000237330',
#  'ENSG00000131591',
#  'ENSG00000223823',
#  'ENSG00000272141',
#  'ENSG00000205231',
#  'ENSG00000162571',
#  'ENSG00000186891',
#  'ENSG00000186827',
#  'ENSG00000078808',
#  'ENSG00000176022',
#  'ENSG00000184163',
#  'ENSG00000260179',
#  'ENSG00000160087',
#  'ENSG00000230415',
#  'ENSG00000162572',
#  'ENSG00000131584',
#  'ENSG00000169972',
#  'ENSG00000127054',
#  'ENSG00000224051',
# ...

# %%
len(ens_ids2)
# Out:
# 26354

# %%
adata.var['gene_symbols'] = adata.var_names
adata.var_names = adata.var['gene_ids']

# %%
raw.var['gene_symbols'] = adata.var_names
raw.var_names = adata.var['gene_ids']

# %%
del adata.var['gene_ids']
del raw.var['gene_symbols']

# %%
adata.var
# Out:
#                  n_cells gene_symbols
# gene_ids
# ENSG00000243485      105  MIR1302-2HG
# ENSG00000237613       17      FAM138A
# ENSG00000238009      148   AL627309.1
# ENSG00000239945       11   AL627309.3
# ENSG00000239906       10   AL627309.2
# ...                  ...          ...
# ENSG00000276345    26486   AC004556.1
# ENSG00000277856       90   AC233755.2
# ENSG00000275063      153   AC233755.1
# ENSG00000271254    13664   AC240274.1
# ENSG00000277475       18   AC213203.1
#
# [26568 rows x 2 columns]

# %%
adata = adata[:, ens_ids2].copy()
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2487: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)

# %%
raw = raw[:, ens_ids2].copy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
#     var: 'n_cells', 'gene_symbols'
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'phase_colors', 'rank_genes_groups_global'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
raw
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
del raw.obs
del raw.obsm

# %%
adata.var['feature_biotype'] = ["gene"] * len(adata.var)

# %%
raw.var['feature_biotype'] = ["gene"] * len(raw.var)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype'
#     var: 'n_cells', 'gene_symbols', 'feature_biotype'
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'phase_colors', 'rank_genes_groups_global'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
raw
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     var: 'feature_biotype'

# %%
adata.raw = raw

# %% [markdown]
# ## 2. Pre-prepare before schema adjustments

# %%
adata.var
# Out:
#                  n_cells gene_symbols feature_biotype
# gene_ids
# ENSG00000243485      105  MIR1302-2HG            gene
# ENSG00000237613       17      FAM138A            gene
# ENSG00000238009      148   AL627309.1            gene
# ENSG00000239945       11   AL627309.3            gene
# ENSG00000239906       10   AL627309.2            gene
# ...                  ...          ...             ...
# ENSG00000276345    26486   AC004556.1            gene
# ENSG00000277856       90   AC233755.2            gene
# ENSG00000275063      153   AC233755.1            gene
# ENSG00000271254    13664   AC240274.1            gene
# ENSG00000277475       18   AC213203.1            gene
#
# [26354 rows x 3 columns]

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Apply the schema requirements:

# %% [markdown]
# # <ins>X

# %% [markdown]
# Raw and normal count matrices are in the object, no additional adjustment is needed!

# %% [markdown]
# # <ins>obs

# %%
adata.obs.columns
# Out:
# Index(['batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts',
#        'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score',
#        'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender',
#        'new_celltype-code', 'status_summary', 'productive_summary',
#        'isotype_summary', 'receptor_type', 'receptor_subtype',
#        'broad_celltype'],
#       dtype='object')

# %%
adata.obs
# Out:
#                                                 batch  stage dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAACCTGCACCGAATT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGATGTCGTGACAT-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACAAACGTGG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# AAAGCAACATACTACG-5891STDY8062349      5891STDY8062349   18.0   Proximal
# ...                                               ...    ...        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  WSSS_F_LNG8713184   15.0   Proximal
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CATCGAACATTAACCG-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  WSSS_F_LNG8713185   15.0     Distal
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  WSSS_F_LNG8713188   15.0   Proximal
#
#                                         chemistry  percent_mito  n_counts  \
# ...

# %% [markdown]
# ## assay_ontology_term_id

# %% [markdown]
# Assay used in this study is 10x 5' v1. Publication

# %% [markdown]
# 10x 3' v2	"EFO:0009899"
# 10x 3' v3	"EFO:0009922"
# 10x 5' v1	"EFO:0011025"
# Smart-seq	"EFO:0008930"
# Smart-seq2	"EFO:0008931"

# %% [markdown]
# > Chromium Single Cell 5’ V(D)J Reagent Kits (V1.0 chemistry) were used for scRNAseq library
# construction.

# %%
adata.obs['assay_ontology_term_id'] = ['EFO:0011025'] * len(adata.obs)

# %%
adata.obs['assay_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      EFO:0011025
# AAACCTGCACCGAATT-5891STDY8062349      EFO:0011025
# AAAGATGTCGTGACAT-5891STDY8062349      EFO:0011025
# AAAGCAACAAACGTGG-5891STDY8062349      EFO:0011025
# AAAGCAACATACTACG-5891STDY8062349      EFO:0011025
#                                          ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    EFO:0011025
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    EFO:0011025
# CATCGAACATTAACCG-WSSS_F_LNG8713185    EFO:0011025
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    EFO:0011025
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    EFO:0011025
# Name: assay_ontology_term_id, Length: 71752, dtype: object

# %% [markdown]
# ## cell_type_ontology_term_id

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['new_celltype']

# %%
len(list(adata.obs['cell_type_ontology_term_id'].unique()))
# Out:
# 144

# %%
mapping = {'Alveolar fibro': 'CL:0002241', # not supported alveolar type 1 fibroblast cell yet
 'Interm fibro': 'CL:0002553', # not intermediate
 'Mid fibro': 'CL:0002553', # not mid
 'Pericyte': 'CL:0000669',
 'Adventitial fibro': 'CL:0002553', 
 'Vascular SMC 1': 'CL:0000359',
 'Myofibro 3': 'CL:0000186',
 'Vascular SMC 2': 'CL:0000359',
 'Airway fibro': 'CL:2000093',
 'Late mesothelial': 'CL:0000077',
 'Myofibro 2': 'CL:0000186',
 'Myofibro 1': 'CL:0000186',
 'Early fibro': 'CL:0002553', # not early
 'Mid mesothelial': 'CL:0000077',
 'Late airway SMC': 'CL:0019019',
 'MYL4+ SMC': 'CL:0000192',
 'Early mesothelial': 'CL:0000077',
 'Resting chondrocyte': 'CL:0000138',
 'Interm chondrocyte': 'CL:0000138',
 'Mesenchymal 3': 'CL:0008019',
 'Mesenchymal 2': 'CL:0008019',
 'Mesenchymal 1': 'CL:0008019',
 'ACTC+ SMC': 'CL:0000192',
 'Early airway SMC 1': 'CL:0019019',
 'ASPN+ chondrocyte': 'CL:0000138',
 'Early airway SMC 2': 'CL:0019019',
 'Late tip': 'CL:0000082',
 'Club': 'CL:0000158',
 'Late airway progenitor': 'CL:0002368', # closest = respiratory epithelial?
 'Squamous': 'CL:0000076', 
 'AT1': 'CL:0002062',
 'AT2': 'CL:0002063',
 'Proximal secretory 2': 'CL:1000272', # because it was collected from lung?
 'Proximal secretory 3': 'CL:1000272', # because it was collected from lung?
 'Proximal secretory 1': 'CL:1000272', # because it was collected from lung?
 'GHRL+ neuroendocrine': 'CL:1000223',
 'Pulmonary neuroendocrine': 'CL:1000223',
 'SMG': 'CL:0000082',
 'Late stalk': 'CL:0000082',
 'Early tip': 'CL:0000082', # not early
 'Early airway progenitor': 'CL:0002368', # closest = respiratory epithelial?
 'Early stalk': 'CL:0000082',
 'Interm neuroendocrine': 'CL:1000223', # because it is collected from lung
 'Pulmonary NE precursor': 'CL:1000223', # closest = NE cell?
 'Mid airway progenitor': 'CL:0002368', # closest = respiratory epithelial?
 'Mid tip': 'CL:0000082',
 'Proximal basal': 'CL:0000646',
 'Proximal secretory progenitors': 'CL:1000272', # because it was collected from lung?
 'Late basal': 'CL:0000646',
 'Mid basal': 'CL:0000646',
 'GHRL+ NE precursor': 'CL:1000223', # closest = NE cell?
 'Mid stalk': 'CL:0000082',
 'SMG basal': 'CL:0000646',
 'MUC5AC+ ASCL1+ progenitor': 'CL:0000082', # only progenitor?
 'SPP1+ MΦ': 'CL:0000235',
 'Cycling DC': 'CL:0000451',
 'S100A12-lo cla. mono.': 'CL:0000860', # not s100a12lo
 'Non-cla. mono.': 'CL:0000875',
 'DC2': 'CL:0000451', # dendritic cell?
 'S100A12-hi cla. mono.': 'CL:0000860', # not s100a12hi
 'Promonocyte-like': 'CL:0000559', # promonocyte?
 'CX3CR1+ MΦ': 'CL:0000235', # not cx3cr1+
 'DC1': 'CL:0000451',
 'HSC': 'CL:0000037',
 'DC3': 'CL:0001056',
 'Neutrophil': 'CL:0000775',
 'CXCL9+ MΦ': 'CL:0000235', # not cxcl9+
 'Megakaryocyte': 'CL:0000556',
 'Promyelocyte-like': 'CL:0000836',
 'pDC': 'CL:0000784',
 'Eosinophil': 'CL:0000771',
 'aDC 2': 'CL:0000451', # not activated
 'pre-pDC/DC5': 'CL:0000451', # dendritic
 'Basophil': 'CL:0000767',
 'MEP': 'CL:0000050',
 'Platelet': 'CL:0000233',
 'aDC 1': 'CL:0000451', # not activated
 'HSC/ELP': 'CL:0000936',
 'GMP': 'CL:0000557',
 'Myelocyte-like': 'CL:0002092', # myelocyto
 'APOE+ MΦ2': 'CL:0000235', # not apoe and 2
 'CMP': 'CL:0000049',
 'APOE+ MΦ1': 'CL:0000235', # not apoe and 1
 'Definitive erythrocyte': 'CL:0002357',
 'Late cap': 'CL:0002144', # not late
 'Intermediate lymphatic endo': 'CL:0002138', # not intermediate
 'Venous endo': 'CL:0002543',
 'GRIA2+ arterial endo': 'CL:1000413', 
 'Definitive reticulocyte': 'CL:0000558', # not definitive
 'Lymphatic endo': 'CL:0002138',
 'Mid cap': 'CL:0002144',
 'Definitive erythroblast': 'CL:0000765', # not definitive
 'Cycling definitive erythroblast': 'CL:0000765', # not definitive & cycling
 'Arterial endo': 'CL:0002144', # no support for alveolar capillary type 2 endothelial cell yet
 'SCG3+ lymphatic endothelial': 'CL:0002138',
 'Aerocyte': 'CL:0002144', # no support for alveolar capillary type 2 endothelial cell yet
 'OMD+ endo': 'CL:0000115',
 'Primitive erythrocyte': 'CL:0002355',
 'HMOX1+ primitive erythroblast': 'CL:0002355',
 'Early cap': 'CL:0002144',
 'CD4 T': 'CL:0000624',
 'CD16+ NK': 'CL:0000939',
 'CD56bright NK': 'CL:0000938',
 'Intermediate NK': 'CL:0000623', # not intermediate
 'Th17': 'CL:0000899',
 'Treg': 'CL:0000815',
 'CD8 T': 'CL:0000625',
 'Cycling T': 'CL:0000084',
 'NKT2': 'CL:0000814',
 'NKT1': 'CL:0000814',
 'ILC3': 'CL:0001071',
 'Cycling NK': 'CL:0000623', # not cycling
 'ILC2': 'CL:0001069',
 'Activated NK': 'CL:0000623', # not activated
 'ILCP': 'CL:0001074',
 'Tαβ_Entry': 'CL:0000893',
 'κ small pre-B': 'CL:0000954',
 'Large pre-B': 'CL:0000957',
 'CD5- Mature B': 'CL:0000821',
 'Immature B': 'CL:0000816',
 'Pro-B': 'CL:0000826',
 'λ small pre-B': 'CL:0000956', # lambda
 'Late pro-B': 'CL:0002048',
 'Late pre-B': 'CL:0000817', # not late but there are pre-b-I and pre-b-II
 'Pro-B/Pre-B transition': 'CL:0000817', # no term for transition
 'CD5+ CCL22- mature B': 'CL:0000820', # cd5+ but no ccl22-
 'CD5+ CCL22+ mature B': 'CL:0000820', # cd5+ but no ccl22+
 'Ciliated': 'CL:1000271',
 'MUC16+ ciliated': 'CL:1000271', # not muc16
 'Deuterosomal': 'CL:1000271',
 'COL20A1+ Schwann': 'CL:0002573',
 'Late Schwann': 'CL:0002573',
 'Early Schwann': 'CL:0002377', # immature
 'PCP4+ neuron': 'CL:0000540',
 'MFNG+ DBH+ neuron': 'CL:0000540',
 'Schwann precursor': 'CL:0002375',
 'TM4SF4+ CHODL+ neuron': 'CL:0000540',
 'SST+ neuron': 'CL:0000540',
 'KCNIP4+ neuron': 'CL:0000540',
 'TM4SF4+ PENK+ neuron': 'CL:0000540',
 'FGFBP2+ Neural progenitor': 'CL:0011020',
 'Mid Schwann': 'CL:0002573',
 'Proliferating Schwann': 'CL:0002573',
 'Mast': 'CL:0000097'}

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].map(mapping)

# %% [markdown]
# ## development_stage_ontology_term_id

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['stage']

# %%
list(adata.obs['stage'].unique())
# Out:
# [18.0, 22.0, 15.0, 20.0, 6.86, 5.0, 9.0, 11.0]

# %%
mapping = {18.0: 'HsapDv:0000055', 
           22.0: 'HsapDv:0000059', 
           15.0: 'HsapDv:0000052', 
           20.0: 'HsapDv:0000057', 
           6.86: 'HsapDv:0000026', 
           5.0: 'HsapDv:0000023', 
           9.0: 'HsapDv:0000046', 
           11.0: 'HsapDv:0000048'}

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].map(mapping)

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      HsapDv:0000055
# AAACCTGCACCGAATT-5891STDY8062349      HsapDv:0000055
# AAAGATGTCGTGACAT-5891STDY8062349      HsapDv:0000055
# AAAGCAACAAACGTGG-5891STDY8062349      HsapDv:0000055
# AAAGCAACATACTACG-5891STDY8062349      HsapDv:0000055
#                                            ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    HsapDv:0000052
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    HsapDv:0000052
# CATCGAACATTAACCG-WSSS_F_LNG8713185    HsapDv:0000052
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    HsapDv:0000052
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    HsapDv:0000052
# Name: development_stage_ontology_term_id, Length: 71752, dtype: object

# %% [markdown]
# ## disease_ontology_term_id

# %%
adata.obs['disease_ontology_term_id'] = ['PATO:0000461'] * len(adata.obs)

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      PATO:0000461
# AAACCTGCACCGAATT-5891STDY8062349      PATO:0000461
# AAAGATGTCGTGACAT-5891STDY8062349      PATO:0000461
# AAAGCAACAAACGTGG-5891STDY8062349      PATO:0000461
# AAAGCAACATACTACG-5891STDY8062349      PATO:0000461
#                                           ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    PATO:0000461
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    PATO:0000461
# CATCGAACATTAACCG-WSSS_F_LNG8713185    PATO:0000461
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    PATO:0000461
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    PATO:0000461
# Name: disease_ontology_term_id, Length: 71752, dtype: object

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      PATO:0000461
# AAACCTGCACCGAATT-5891STDY8062349      PATO:0000461
# AAAGATGTCGTGACAT-5891STDY8062349      PATO:0000461
# AAAGCAACAAACGTGG-5891STDY8062349      PATO:0000461
# AAAGCAACATACTACG-5891STDY8062349      PATO:0000461
#                                           ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    PATO:0000461
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    PATO:0000461
# CATCGAACATTAACCG-WSSS_F_LNG8713185    PATO:0000461
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    PATO:0000461
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    PATO:0000461
# Name: disease_ontology_term_id, Length: 71752, dtype: object

# %% [markdown]
# ## ethnicity_ontology_term_id

# %%
adata.obs['ethnicity_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
adata.obs['ethnicity_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      unknown
# AAACCTGCACCGAATT-5891STDY8062349      unknown
# AAAGATGTCGTGACAT-5891STDY8062349      unknown
# AAAGCAACAAACGTGG-5891STDY8062349      unknown
# AAAGCAACATACTACG-5891STDY8062349      unknown
#                                        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    unknown
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    unknown
# CATCGAACATTAACCG-WSSS_F_LNG8713185    unknown
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    unknown
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    unknown
# Name: ethnicity_ontology_term_id, Length: 71752, dtype: object

# %% [markdown]
# ## is_primary_data

# %%
adata.obs['is_primary_data'] = [True] * len(adata.obs)

# %%
adata.obs['is_primary_data']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      True
# AAACCTGCACCGAATT-5891STDY8062349      True
# AAAGATGTCGTGACAT-5891STDY8062349      True
# AAAGCAACAAACGTGG-5891STDY8062349      True
# AAAGCAACATACTACG-5891STDY8062349      True
#                                       ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    True
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    True
# CATCGAACATTAACCG-WSSS_F_LNG8713185    True
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    True
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    True
# Name: is_primary_data, Length: 71752, dtype: bool

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %% [markdown]
# ## organism_ontology_term_id

# %%
adata.obs['organism_ontology_term_id'] = ['NCBITaxon:9606'] * len(adata.obs)

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      NCBITaxon:9606
# AAACCTGCACCGAATT-5891STDY8062349      NCBITaxon:9606
# AAAGATGTCGTGACAT-5891STDY8062349      NCBITaxon:9606
# AAAGCAACAAACGTGG-5891STDY8062349      NCBITaxon:9606
# AAAGCAACATACTACG-5891STDY8062349      NCBITaxon:9606
#                                            ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    NCBITaxon:9606
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    NCBITaxon:9606
# CATCGAACATTAACCG-WSSS_F_LNG8713185    NCBITaxon:9606
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    NCBITaxon:9606
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 71752, dtype: object

# %%
adata.obs['organism_ontology_term_id'] = pd.Categorical(adata.obs['organism_ontology_term_id'])

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      NCBITaxon:9606
# AAACCTGCACCGAATT-5891STDY8062349      NCBITaxon:9606
# AAAGATGTCGTGACAT-5891STDY8062349      NCBITaxon:9606
# AAAGCAACAAACGTGG-5891STDY8062349      NCBITaxon:9606
# AAAGCAACATACTACG-5891STDY8062349      NCBITaxon:9606
#                                            ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    NCBITaxon:9606
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    NCBITaxon:9606
# CATCGAACATTAACCG-WSSS_F_LNG8713185    NCBITaxon:9606
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    NCBITaxon:9606
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 71752, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# ## sex_ontology_term_id

# %% [markdown]
# **PATO_0000384 for male
# PATO_0000383 for female**

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['gender']

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      M
# AAACCTGCACCGAATT-5891STDY8062349      M
# AAAGATGTCGTGACAT-5891STDY8062349      M
# AAAGCAACAAACGTGG-5891STDY8062349      M
# AAAGCAACATACTACG-5891STDY8062349      M
#                                      ..
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    M
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    M
# CATCGAACATTAACCG-WSSS_F_LNG8713185    M
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    M
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    M
# Name: sex_ontology_term_id, Length: 71752, dtype: category
# Categories (2, object): ['F', 'M']

# %%
mapping = {'M': 'PATO:0000384',
           'F': 'PATO:0000383'}

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].map(mapping)

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      PATO:0000384
# AAACCTGCACCGAATT-5891STDY8062349      PATO:0000384
# AAAGATGTCGTGACAT-5891STDY8062349      PATO:0000384
# AAAGCAACAAACGTGG-5891STDY8062349      PATO:0000384
# AAAGCAACATACTACG-5891STDY8062349      PATO:0000384
#                                           ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    PATO:0000384
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    PATO:0000384
# CATCGAACATTAACCG-WSSS_F_LNG8713185    PATO:0000384
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    PATO:0000384
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    PATO:0000384
# Name: sex_ontology_term_id, Length: 71752, dtype: category
# Categories (2, object): ['PATO:0000383', 'PATO:0000384']

# %% [markdown]
# ## tissue_ontology_term_id

# %% [markdown]
# Lung: UBERON:0002048

# %%
adata.obs['tissue_ontology_term_id'] = ['UBERON:0002048'] * len(adata.obs)

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACCTGAGACAGGCT-5891STDY8062349      UBERON:0002048
# AAACCTGCACCGAATT-5891STDY8062349      UBERON:0002048
# AAAGATGTCGTGACAT-5891STDY8062349      UBERON:0002048
# AAAGCAACAAACGTGG-5891STDY8062349      UBERON:0002048
# AAAGCAACATACTACG-5891STDY8062349      UBERON:0002048
#                                            ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184    UBERON:0002048
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185    UBERON:0002048
# CATCGAACATTAACCG-WSSS_F_LNG8713185    UBERON:0002048
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185    UBERON:0002048
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188    UBERON:0002048
# Name: tissue_ontology_term_id, Length: 71752, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # <ins>var and raw.var

# %%
adata.var
# Out:
#                  n_cells gene_symbols feature_biotype
# gene_ids
# ENSG00000243485      105  MIR1302-2HG            gene
# ENSG00000237613       17      FAM138A            gene
# ENSG00000238009      148   AL627309.1            gene
# ENSG00000239945       11   AL627309.3            gene
# ENSG00000239906       10   AL627309.2            gene
# ...                  ...          ...             ...
# ENSG00000276345    26486   AC004556.1            gene
# ENSG00000277856       90   AC233755.2            gene
# ENSG00000275063      153   AC233755.1            gene
# ENSG00000271254    13664   AC240274.1            gene
# ENSG00000277475       18   AC213203.1            gene
#
# [26354 rows x 3 columns]

# %% [markdown]
# ## feature_is_filtered

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var['feature_is_filtered']
# Out:
# gene_ids
# ENSG00000243485    False
# ENSG00000237613    False
# ENSG00000238009    False
# ENSG00000239945    False
# ENSG00000239906    False
#                    ...
# ENSG00000276345    False
# ENSG00000277856    False
# ENSG00000275063    False
# ENSG00000271254    False
# ENSG00000277475    False
# Name: feature_is_filtered, Length: 26354, dtype: bool

# %% [markdown]
# # <ins>obsm

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_pca, X_umap, X_umap_original

# %% [markdown]
# # <ins>uns

# %%
adata.uns['schema_version'] = '2.0.0'

# %%
adata.uns['title'] = 'All cells'

# %%
adata.uns['X_normalization'] = 'Scanpy'

# %%
adata.uns['default_embedding'] = 'X_umap'

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 4. Final adjustments

# %% [markdown]
# Final adjustments include the removal of the slots that were already re-created for the schema.

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     obs: 'batch', 'stage', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'gender', 'new_celltype-code', 'status_summary', 'productive_summary', 'isotype_summary', 'receptor_type', 'receptor_subtype', 'broad_celltype', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id'
#     var: 'n_cells', 'gene_symbols', 'feature_biotype', 'feature_is_filtered'
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'phase_colors', 'rank_genes_groups_global', 'schema_version', 'title', 'X_normalization', 'default_embedding'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
pd.set_option('display.max_columns', 500)

# %%
del adata.obs['stage']
del adata.obs['gender']
del adata.obs['new_celltype-code']
del adata.obs['status_summary']
del adata.obs['productive_summary']
del adata.obs['isotype_summary']
del adata.obs['receptor_type']
del adata.obs['receptor_subtype']

# %%
adata.obs
# Out:
#                                                 batch dissection  \
# AAACCTGAGACAGGCT-5891STDY8062349      5891STDY8062349   Proximal
# AAACCTGCACCGAATT-5891STDY8062349      5891STDY8062349   Proximal
# AAAGATGTCGTGACAT-5891STDY8062349      5891STDY8062349   Proximal
# AAAGCAACAAACGTGG-5891STDY8062349      5891STDY8062349   Proximal
# AAAGCAACATACTACG-5891STDY8062349      5891STDY8062349   Proximal
# ...                                               ...        ...
# GTCACGGAGCCCTAAT-WSSS_F_LNG8713184  WSSS_F_LNG8713184   Proximal
# ACGGGCTGTTCAGCGC-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# CATCGAACATTAACCG-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# CTCAGAAGTACTCTCC-WSSS_F_LNG8713185  WSSS_F_LNG8713185     Distal
# TACGGGCTCACCTTAT-WSSS_F_LNG8713188  WSSS_F_LNG8713188   Proximal
#
#                                         chemistry  percent_mito  n_counts  \
# AAACCTGAGACAGGCT-5891STDY8062349           Normal      0.042116    8711.0
# ...

# %%
adata.obs.dtypes
# Out:
# batch                                 category
# dissection                            category
# chemistry                             category
# percent_mito                           float32
# n_counts                               float32
# n_genes                                  int64
# doublet_scores                         float64
# bh_pval                                float64
# leiden                                category
# phase                                 category
# S_score                                float32
# G2M_score                              float32
# new_celltype                          category
# big_cluster                           category
# donor                                 category
# broad_celltype                        category
# assay_ontology_term_id                  object
# cell_type_ontology_term_id              object
# development_stage_ontology_term_id      object
# disease_ontology_term_id                object
# ...

# %%
adata.X
# Out:
# <71752x26354 sparse matrix of type '<class 'numpy.float32'>'
# 	with 197645587 stored elements in Compressed Sparse Row format>

# %%
adata.var
# Out:
#                  n_cells gene_symbols feature_biotype  feature_is_filtered
# gene_ids
# ENSG00000243485      105  MIR1302-2HG            gene                False
# ENSG00000237613       17      FAM138A            gene                False
# ENSG00000238009      148   AL627309.1            gene                False
# ENSG00000239945       11   AL627309.3            gene                False
# ENSG00000239906       10   AL627309.2            gene                False
# ...                  ...          ...             ...                  ...
# ENSG00000276345    26486   AC004556.1            gene                False
# ENSG00000277856       90   AC233755.2            gene                False
# ENSG00000275063      153   AC233755.1            gene                False
# ENSG00000271254    13664   AC240274.1            gene                False
# ENSG00000277475       18   AC213203.1            gene                False
#
# [26354 rows x 4 columns]

# %%
# adata.obs
print('obs')
dty = pd.DataFrame(adata.obs.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.obs[c] = adata.obs[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.obs[c] = adata.obs[c].astype('int32') 
    print(f"changed {c} from int64 to int32")

# adata.var
print('var')
dty = pd.DataFrame(adata.var.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.var[c] = adata.var[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.var[c] = adata.var[c].astype('int32') 
    print(f"changed {c} from int64 to int32")
# Out:
# obs
# changed doublet_scores from float64 to float32
# changed bh_pval from float64 to float32
# changed n_genes from int64 to int32
# var
# changed n_cells from int64 to int32

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 71752 × 26354
#     obs: 'batch', 'dissection', 'chemistry', 'percent_mito', 'n_counts', 'n_genes', 'doublet_scores', 'bh_pval', 'leiden', 'phase', 'S_score', 'G2M_score', 'new_celltype', 'big_cluster', 'donor', 'broad_celltype', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'ethnicity_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id'
#     var: 'n_cells', 'gene_symbols', 'feature_biotype', 'feature_is_filtered'
#     uns: 'batch_colors', 'big_cluster_colors', 'broad_celltype_colors', 'chemistry_colors', 'phase_colors', 'rank_genes_groups_global', 'schema_version', 'title', 'X_normalization', 'default_embedding'
#     obsm: 'X_pca', 'X_umap', 'X_umap_original'

# %%
adata.write('/lustre/scratch117/cellgen/cellgeni/cxgportal_sets/fetal-lung/final/fetal-lung_all.h5ad', compression = 'gzip')
# Out:
# ... storing 'assay_ontology_term_id' as categorical
# ... storing 'cell_type_ontology_term_id' as categorical
# ... storing 'development_stage_ontology_term_id' as categorical
# ... storing 'disease_ontology_term_id' as categorical
# ... storing 'ethnicity_ontology_term_id' as categorical
# ... storing 'tissue_ontology_term_id' as categorical
# ... storing 'feature_biotype' as categorical
# ... storing 'feature_biotype' as categorical

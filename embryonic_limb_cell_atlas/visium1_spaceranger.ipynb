# %% [markdown]
# ### **Curating visium_slide1.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9383359/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are zero values in 'non_zero_counts' for observations in tissue.
# 1

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['AGAAGAGCGCCGTTCC-1']

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 1

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
adata.obs.loc['AGAAGAGCGCCGTTCC-1', 'in_tissue'] = 0

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 4318183 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 2007)	1.0
#   (0, 3179)	1.0
#   (0, 4566)	1.0
#   (0, 4854)	1.0
#   (0, 5607)	1.0
#   (0, 5887)	1.0
#   (0, 5981)	1.0
#   (0, 6538)	1.0
#   (0, 7149)	1.0
#   (0, 8234)	2.0
#   (0, 10219)	1.0
#   (0, 10728)	1.0
#   (0, 11106)	1.0
#   (0, 12451)	1.0
#   (0, 12686)	1.0
#   (0, 13069)	1.0
#   (0, 14691)	1.0
#   (0, 15808)	1.0
#   (0, 17064)	1.0
#   (0, 17383)	1.0
#   (0, 18012)	1.0
#   (0, 19064)	1.0
#   (0, 20586)	1.0
#   (0, 21010)	1.0
#   (0, 21035)	1.0
#   :	:
#   (4991, 31307)	1.0
#   (4991, 31365)	2.0
#   (4991, 31415)	1.0
#   (4991, 31453)	4.0
#   (4991, 31578)	1.0
#   (4991, 31592)	1.0
#   (4991, 31704)	3.0
#   (4991, 31742)	1.0
#   (4991, 31763)	5.0
#   (4991, 31764)	1.0
#   (4991, 32042)	1.0
#   (4991, 32061)	1.0
#   (4991, 32176)	2.0
#   (4991, 32191)	1.0
#   (4991, 32426)	1.0
#   (4991, 32586)	1.0
#   (4991, 32858)	2.0
#   (4991, 32919)	1.0
#   (4991, 33654)	1.0
#   (4991, 33655)	1.0
#   (4991, 33657)	1.0
#   (4991, 33658)	5.0
#   (4991, 33661)	2.0
#   (4991, 33662)	2.0
#   (4991, 33679)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16               41
# AAACAAGTATCTCCCA-1          1         50        102             1105
# AAACAATCTACTAGCA-1          0          3         43              334
# AAACACCAATAACTGC-1          1         59         19             3162
# AAACAGAGCGACTCCT-1          1         14         94             1286
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             2123
# TTGTTTCATTAGTCTA-1          1         60         30             2722
# TTGTTTCCATACAACT-1          1         45         27             2631
# TTGTTTGTATTACACG-1          1         73         41             1320
# TTGTTTGTGTAAATTC-1          0          7         51              313
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide1.h5ad')

# %%
adata1.obs
# Out:
#                   in_tissue  percent_mito  C2L: ADH+Fibro  C2L: AER-Basal  \
# AAACAAGTATCTCCCA          1           0.0        0.218709        0.003093
# AAACACCAATAACTGC          1           0.0        0.857344        0.019242
# AAACAGAGCGACTCCT          1           0.0        0.077512        0.003977
# AAACAGCTTTCAGAAG          1           0.0        0.047421        0.001802
# AAACAGGGTCTATATT          1           0.0        0.156441        0.004607
# ...                     ...           ...             ...             ...
# TTGTTGTGTGTCAAGA          1           0.0        0.869076        0.008095
# TTGTTTCACATCCAGG          1           0.0        0.553794        0.006463
# TTGTTTCATTAGTCTA          1           0.0        4.490823        0.015687
# TTGTTTCCATACAACT          1           0.0        0.261132        0.163042
# TTGTTTGTATTACACG          1           0.0        0.963678        0.009193
#
#                   C2L: ArterialEndo  C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA           0.157978       1.506415  0.005698    0.002507
# AAACACCAATAACTGC           2.307425       0.540210  0.052692    0.008612
# AAACAGAGCGACTCCT           0.787285       0.080841  0.010598    0.003859
# AAACAGCTTTCAGAAG           0.018676       0.032928  0.003423    0.004115
# AAACAGGGTCTATATT           0.125245       0.058255  0.007052    0.003260
# ...                             ...            ...       ...         ...
# TTGTTGTGTGTCAAGA           0.002399       0.384012  0.003149    0.002732
# TTGTTTCACATCCAGG           0.030894       0.954969  0.013003    0.005249
# TTGTTTCATTAGTCTA           0.004751       0.004275  0.003180    0.005122
# TTGTTTCCATACAACT           1.967347       0.147499  0.025797    0.191725
# TTGTTTGTATTACACG           0.037980       0.044012  0.007266    0.005793
#
#                   C2L: CMP/GMP  C2L: ChondroProg  ...   stage  \
# AAACAAGTATCTCCCA      0.006099          0.015340  ...  PCW8.1
# AAACACCAATAACTGC      0.063932          0.044397  ...  PCW8.1
# AAACAGAGCGACTCCT      0.010398          0.016880  ...  PCW8.1
# AAACAGCTTTCAGAAG      0.002407          0.008195  ...  PCW8.1
# AAACAGGGTCTATATT      0.009093          0.017319  ...  PCW8.1
# ...                        ...               ...  ...     ...
# TTGTTGTGTGTCAAGA      0.005718          0.008886  ...  PCW8.1
# TTGTTTCACATCCAGG      0.022047          0.042170  ...  PCW8.1
# TTGTTTCATTAGTCTA      0.010324          0.008621  ...  PCW8.1
# TTGTTTCCATACAACT      0.023357          0.039810  ...  PCW8.1
# TTGTTTGTATTACACG      0.012767          0.015933  ...  PCW8.1
#
#                   development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA                      HsapDv:0000030
# AAACACCAATAACTGC                      HsapDv:0000030
# AAACAGAGCGACTCCT                      HsapDv:0000030
# AAACAGCTTTCAGAAG                      HsapDv:0000030
# AAACAGGGTCTATATT                      HsapDv:0000030
# ...                                              ...
# TTGTTGTGTGTCAAGA                      HsapDv:0000030
# TTGTTTCACATCCAGG                      HsapDv:0000030
# TTGTTTCATTAGTCTA                      HsapDv:0000030
# TTGTTTCCATACAACT                      HsapDv:0000030
# TTGTTTGTATTACACG                      HsapDv:0000030
#
#                   disease_ontology_term_id  is_primary_data  \
# AAACAAGTATCTCCCA              PATO:0000461             True
# AAACACCAATAACTGC              PATO:0000461             True
# AAACAGAGCGACTCCT              PATO:0000461             True
# AAACAGCTTTCAGAAG              PATO:0000461             True
# AAACAGGGTCTATATT              PATO:0000461             True
# ...                                    ...              ...
# TTGTTGTGTGTCAAGA              PATO:0000461             True
# TTGTTTCACATCCAGG              PATO:0000461             True
# TTGTTTCATTAGTCTA              PATO:0000461             True
# TTGTTTCCATACAACT              PATO:0000461             True
# TTGTTTGTATTACACG              PATO:0000461             True
#
#                   organism_ontology_term_id  \
# AAACAAGTATCTCCCA             NCBITaxon:9606
# AAACACCAATAACTGC             NCBITaxon:9606
# AAACAGAGCGACTCCT             NCBITaxon:9606
# AAACAGCTTTCAGAAG             NCBITaxon:9606
# AAACAGGGTCTATATT             NCBITaxon:9606
# ...                                     ...
# TTGTTGTGTGTCAAGA             NCBITaxon:9606
# TTGTTTCACATCCAGG             NCBITaxon:9606
# TTGTTTCATTAGTCTA             NCBITaxon:9606
# TTGTTTCCATACAACT             NCBITaxon:9606
# TTGTTTGTATTACACG             NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA                                   unknown
# AAACACCAATAACTGC                                   unknown
# AAACAGAGCGACTCCT                                   unknown
# AAACAGCTTTCAGAAG                                   unknown
# AAACAGGGTCTATATT                                   unknown
# ...                                                    ...
# TTGTTGTGTGTCAAGA                                   unknown
# TTGTTTCACATCCAGG                                   unknown
# TTGTTTCATTAGTCTA                                   unknown
# TTGTTTCCATACAACT                                   unknown
# TTGTTTGTATTACACG                                   unknown
#
#                   sex_ontology_term_id  suspension_type  tissue_type  \
# AAACAAGTATCTCCCA          PATO:0000384               na       tissue
# AAACACCAATAACTGC          PATO:0000384               na       tissue
# AAACAGAGCGACTCCT          PATO:0000384               na       tissue
# AAACAGCTTTCAGAAG          PATO:0000384               na       tissue
# AAACAGGGTCTATATT          PATO:0000384               na       tissue
# ...                                ...              ...          ...
# TTGTTGTGTGTCAAGA          PATO:0000384               na       tissue
# TTGTTTCACATCCAGG          PATO:0000384               na       tissue
# TTGTTTCATTAGTCTA          PATO:0000384               na       tissue
# TTGTTTCCATACAACT          PATO:0000384               na       tissue
# TTGTTTGTATTACACG          PATO:0000384               na       tissue
#
#                   tissue_ontology_term_id
# AAACAAGTATCTCCCA           UBERON:0000978
# AAACACCAATAACTGC           UBERON:0000978
# AAACAGAGCGACTCCT           UBERON:0000978
# AAACAGCTTTCAGAAG           UBERON:0000978
# AAACAGGGTCTATATT           UBERON:0000978
# ...                                   ...
# TTGTTGTGTGTCAAGA           UBERON:0000978
# TTGTTTCACATCCAGG           UBERON:0000978
# TTGTTTCATTAGTCTA           UBERON:0000978
# TTGTTTCCATACAACT           UBERON:0000978
# TTGTTTGTATTACACG           UBERON:0000978
#
# [2540 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                   in_tissue  percent_mito  C2L: ADH+Fibro  C2L: AER-Basal  \
# AAACAAGTATCTCCCA          1           0.0        0.218709        0.003093
# AAACACCAATAACTGC          1           0.0        0.857344        0.019242
# AAACAGAGCGACTCCT          1           0.0        0.077512        0.003977
# AAACAGCTTTCAGAAG          1           0.0        0.047421        0.001802
# AAACAGGGTCTATATT          1           0.0        0.156441        0.004607
# ...                     ...           ...             ...             ...
# TTGTTGTGTGTCAAGA          1           0.0        0.869076        0.008095
# TTGTTTCACATCCAGG          1           0.0        0.553794        0.006463
# TTGTTTCATTAGTCTA          1           0.0        4.490823        0.015687
# TTGTTTCCATACAACT          1           0.0        0.261132        0.163042
# TTGTTTGTATTACACG          1           0.0        0.963678        0.009193
#
#                   C2L: ArterialEndo  C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA           0.157978       1.506415  0.005698    0.002507
# AAACACCAATAACTGC           2.307425       0.540210  0.052692    0.008612
# AAACAGAGCGACTCCT           0.787285       0.080841  0.010598    0.003859
# AAACAGCTTTCAGAAG           0.018676       0.032928  0.003423    0.004115
# AAACAGGGTCTATATT           0.125245       0.058255  0.007052    0.003260
# ...                             ...            ...       ...         ...
# TTGTTGTGTGTCAAGA           0.002399       0.384012  0.003149    0.002732
# TTGTTTCACATCCAGG           0.030894       0.954969  0.013003    0.005249
# TTGTTTCATTAGTCTA           0.004751       0.004275  0.003180    0.005122
# TTGTTTCCATACAACT           1.967347       0.147499  0.025797    0.191725
# TTGTTTGTATTACACG           0.037980       0.044012  0.007266    0.005793
#
#                   C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAAGTATCTCCCA      0.006099          0.015340  ...
# AAACACCAATAACTGC      0.063932          0.044397  ...
# AAACAGAGCGACTCCT      0.010398          0.016880  ...
# AAACAGCTTTCAGAAG      0.002407          0.008195  ...
# AAACAGGGTCTATATT      0.009093          0.017319  ...
# ...                        ...               ...  ...
# TTGTTGTGTGTCAAGA      0.005718          0.008886  ...
# TTGTTTCACATCCAGG      0.022047          0.042170  ...
# TTGTTTCATTAGTCTA      0.010324          0.008621  ...
# TTGTTTCCATACAACT      0.023357          0.039810  ...
# TTGTTTGTATTACACG      0.012767          0.015933  ...
#
#                   development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA                      HsapDv:0000030
# AAACACCAATAACTGC                      HsapDv:0000030
# AAACAGAGCGACTCCT                      HsapDv:0000030
# AAACAGCTTTCAGAAG                      HsapDv:0000030
# AAACAGGGTCTATATT                      HsapDv:0000030
# ...                                              ...
# TTGTTGTGTGTCAAGA                      HsapDv:0000030
# TTGTTTCACATCCAGG                      HsapDv:0000030
# TTGTTTCATTAGTCTA                      HsapDv:0000030
# TTGTTTCCATACAACT                      HsapDv:0000030
# TTGTTTGTATTACACG                      HsapDv:0000030
#
#                   disease_ontology_term_id  is_primary_data  \
# AAACAAGTATCTCCCA              PATO:0000461             True
# AAACACCAATAACTGC              PATO:0000461             True
# AAACAGAGCGACTCCT              PATO:0000461             True
# AAACAGCTTTCAGAAG              PATO:0000461             True
# AAACAGGGTCTATATT              PATO:0000461             True
# ...                                    ...              ...
# TTGTTGTGTGTCAAGA              PATO:0000461             True
# TTGTTTCACATCCAGG              PATO:0000461             True
# TTGTTTCATTAGTCTA              PATO:0000461             True
# TTGTTTCCATACAACT              PATO:0000461             True
# TTGTTTGTATTACACG              PATO:0000461             True
#
#                   organism_ontology_term_id  \
# AAACAAGTATCTCCCA             NCBITaxon:9606
# AAACACCAATAACTGC             NCBITaxon:9606
# AAACAGAGCGACTCCT             NCBITaxon:9606
# AAACAGCTTTCAGAAG             NCBITaxon:9606
# AAACAGGGTCTATATT             NCBITaxon:9606
# ...                                     ...
# TTGTTGTGTGTCAAGA             NCBITaxon:9606
# TTGTTTCACATCCAGG             NCBITaxon:9606
# TTGTTTCATTAGTCTA             NCBITaxon:9606
# TTGTTTCCATACAACT             NCBITaxon:9606
# TTGTTTGTATTACACG             NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA                                   unknown
# AAACACCAATAACTGC                                   unknown
# AAACAGAGCGACTCCT                                   unknown
# AAACAGCTTTCAGAAG                                   unknown
# AAACAGGGTCTATATT                                   unknown
# ...                                                    ...
# TTGTTGTGTGTCAAGA                                   unknown
# TTGTTTCACATCCAGG                                   unknown
# TTGTTTCATTAGTCTA                                   unknown
# TTGTTTCCATACAACT                                   unknown
# TTGTTTGTATTACACG                                   unknown
#
#                   sex_ontology_term_id  suspension_type  tissue_type  \
# AAACAAGTATCTCCCA          PATO:0000384               na       tissue
# AAACACCAATAACTGC          PATO:0000384               na       tissue
# AAACAGAGCGACTCCT          PATO:0000384               na       tissue
# AAACAGCTTTCAGAAG          PATO:0000384               na       tissue
# AAACAGGGTCTATATT          PATO:0000384               na       tissue
# ...                                ...              ...          ...
# TTGTTGTGTGTCAAGA          PATO:0000384               na       tissue
# TTGTTTCACATCCAGG          PATO:0000384               na       tissue
# TTGTTTCATTAGTCTA          PATO:0000384               na       tissue
# TTGTTTCCATACAACT          PATO:0000384               na       tissue
# TTGTTTGTATTACACG          PATO:0000384               na       tissue
#
#                   tissue_ontology_term_id          barcodes
# AAACAAGTATCTCCCA           UBERON:0000978  AAACAAGTATCTCCCA
# AAACACCAATAACTGC           UBERON:0000978  AAACACCAATAACTGC
# AAACAGAGCGACTCCT           UBERON:0000978  AAACAGAGCGACTCCT
# AAACAGCTTTCAGAAG           UBERON:0000978  AAACAGCTTTCAGAAG
# AAACAGGGTCTATATT           UBERON:0000978  AAACAGGGTCTATATT
# ...                                   ...               ...
# TTGTTGTGTGTCAAGA           UBERON:0000978  TTGTTGTGTGTCAAGA
# TTGTTTCACATCCAGG           UBERON:0000978  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA           UBERON:0000978  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT           UBERON:0000978  TTGTTTCCATACAACT
# TTGTTTGTATTACACG           UBERON:0000978  TTGTTTGTATTACACG
#
# [2540 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0000388',
#  'AAACACCAATAACTGC': 'CL:0000192',
#  'AAACAGAGCGACTCCT': 'CL:0002551',
#  'AAACAGCTTTCAGAAG': 'CL:0002551',
#  'AAACAGGGTCTATATT': 'CL:0002551',
#  'AAACAGTGTTCCTGGG': 'CL:0000187',
#  'AAACATGGTGAGAGGA': 'CL:0000388',
#  'AAACATTTCCCGGATT': 'CL:0002551',
#  'AAACCGTTCGTCCAGG': 'CL:0000187',
#  'AAACCTAAGCAGCCGG': 'CL:0002551',
#  'AAACGAAGATGGAGTA': 'CL:0000057',
#  'AAACGAGACGGTTGAT': 'CL:0000388',
#  'AAACGGTTGCGAACTG': 'CL:0002551',
#  'AAACTCGGTTCGCAAT': 'CL:0002551',
#  'AAACTGCTGGCTCCAA': 'CL:0000187',
#  'AAACTTAATTGCACGC': 'CL:0000187',
#  'AAACTTGCAAACGTAT': 'CL:0000669',
#  'AAAGAATGACCTTAGA': 'CL:0000388',
#  'AAAGGCCCTATAATAC': 'CL:0000187',
#  'AAAGGCTACGGACCAT': 'CL:0000187',
#  'AAAGGCTCTCGCGCCG': 'CL:0000187',
#  'AAAGGGATGTAGCAAG': 'CL:0000187',
#  'AAAGTAGCATTGCTCA': 'CL:0000187',
#  'AAAGTGTGATTTATCT': 'CL:0000388',
#  'AAAGTTGACTCCCGTA': 'CL:0000388',
#  'AAATAACCATACGGGA': 'CL:0000743',
#  'AAATACCTATAAGCAT': 'CL:0000187',
#  'AAATAGGGTGCTATTG': 'CL:0000187',
#  'AAATCCGATACACGCC': 'CL:0002551',
#  'AAATCGCGGAAGGAGT': 'CL:0000057',
#  'AAATCGTGTACCACAA': 'CL:0000057',
#  'AAATCTGCCCGCGTCC': 'CL:0000187',
#  'AAATGGCATGTCTTGT': 'CL:0000187',
#  'AAATGGCCCGTGCCCT': 'CL:0000057',
#  'AAATTAACGGGTAGCT': 'CL:0002551',
#  'AAATTACACGACTCTG': 'CL:0000187',
#  'AAATTACCTATCGATG': 'CL:0000388',
#  'AAATTGATAGTCCTTT': 'CL:0000187',
#  'AAATTTACCGAAATCC': 'CL:0002551',
#  'AAATTTGCGGGTGTGG': 'CL:0000187',
#  'AACAATACATTGTCGA': 'CL:0000187',
#  'AACACACGCTCGCCGC': 'CL:0000388',
#  'AACACGACTGTACTGA': 'CL:0000078',
#  'AACACGAGACGCGGCC': 'CL:0002551',
#  'AACAGCTGTGTGGCAA': 'CL:0000187',
#  'AACAGGAAATCGAATA': 'CL:0000187',
#  'AACATATCAACTGGTG': 'CL:0002551',
#  'AACATTGAAGTTGATC': 'CL:0002320',
#  'AACATTGTGACTCGAG': 'CL:0000187',
#  'AACCAGTATCACTCTT': 'CL:0002551',
#  'AACCATAGGGTTGAAC': 'CL:0000187',
#  'AACCCATCCCATGATC': 'CL:0002573',
#  'AACCCGACAACCCGTG': 'CL:0000187',
#  'AACCCGCTGTATTCCA': 'CL:0000187',
#  'AACCCTACTGTCAATA': 'CL:0000388',
#  'AACCCTGGTGGAACCA': 'CL:0000057',
#  'AACCGAGCTTGGTCAT': 'CL:0000187',
#  'AACCGCTAAGGGATGC': 'CL:0000057',
#  'AACCGTTGTGTTTGCT': 'CL:0000057',
#  'AACCTAAAGCCGTCCG': 'CL:0000057',
#  'AACCTCGCTTTAGCCC': 'CL:0000388',
#  'AACCTTTAAATACGGT': 'CL:0000388',
#  'AACCTTTACGACGTCT': 'CL:0002551',
#  'AACGAAAGTCGTCCCA': 'CL:0000057',
#  'AACGATAATGCCGTAG': 'CL:0000187',
#  'AACGATATGTCAACTG': 'CL:0000187',
#  'AACGCGACCTTGGGCG': 'CL:0000187',
#  'AACGCGGTCTCCAGCC': 'CL:0000187',
#  'AACGCTGTTGCTGAAA': 'CL:0000388',
#  'AACGGACGTACGTATA': 'CL:0000388',
#  'AACGGCCATCTCCGGT': 'CL:0000187',
#  'AACGTACTGTGGGTAC': 'CL:0000187',
#  'AACGTCATCCGGCTTG': 'CL:0002551',
#  'AACGTGATGAAGGACA': 'CL:0000388',
#  'AACGTGCGAAAGTCTC': 'CL:0000192',
#  'AACTAGGCTTGGGTGT': 'CL:0000057',
#  'AACTCCAGAGCGTGTT': 'CL:0002551',
#  'AACTCCTAATCCCATG': 'CL:0002551',
#  'AACTCTCAATAGAGCG': 'CL:0002551',
#  'AACTCTCAGTGTGCTC': 'CL:0000187',
#  'AACTGATATTAGGCCT': 'CL:0000187',
#  'AACTGGGTCCCGACGT': 'CL:0002320',
#  'AACTGGGTTCGAGCCG': 'CL:0000078',
#  'AAGAAAGTTTGATGGG': 'CL:0000187',
#  'AAGACCAAATAACTCA': 'CL:0000388',
#  'AAGACCCAACTGAACA': 'CL:0000057',
#  'AAGACTGCAAGCTACT': 'CL:0000187',
#  'AAGAGCTCTTTATCGG': 'CL:0000057',
#  'AAGAGGCATGGATCGC': 'CL:0000388',
#  'AAGATGGCACCGGACC': 'CL:0000187',
#  'AAGATTGGCGGAACGT': 'CL:0000187',
#  'AAGCACCCTGCGTATC': 'CL:0000388',
#  'AAGCATACTCTCCTGA': 'CL:0000057',
#  'AAGCCACTTGCAGGTA': 'CL:0000187',
#  'AAGCCGCCGTGAAATC': 'CL:0000187',
#  'AAGCGCAGGGCTTTGA': 'CL:0002551',
#  'AAGCGTCCCTCATCGA': 'CL:0000187',
#  'AAGCTAGATCGAGTAA': 'CL:0000187',
#  'AAGCTATGGATTGACC': 'CL:0000187',
#  'AAGCTCGTGCCAAGTC': 'CL:0000388',
#  'AAGCTCTTTCATGGTG': 'CL:0002551',
#  'AAGGATGAGGGACCTC': 'CL:0002551',
#  'AAGGGAACGACTGGCT': 'CL:1001609',
#  'AAGGGACAGATTCTGT': 'CL:0000187',
#  'AAGGGACTATGCATTC': 'CL:0000187',
#  'AAGGGTTTGATTTCAG': 'CL:0000057',
#  'AAGGTATCCTAATATA': 'CL:0000388',
#  'AAGGTGATAAACCAGC': 'CL:0000138',
#  'AAGTCAATTGTCGTCA': 'CL:0000187',
#  'AAGTGAGTCGGGTTTA': 'CL:0000187',
#  'AAGTGCCTTGACTGTA': 'CL:0000388',
#  'AAGTGCGTTAGAATCT': 'CL:0000187',
#  'AAGTGCTTCTCTATTG': 'CL:0000187',
#  'AAGTGTTTGGAGACGG': 'CL:0000388',
#  'AAGTTCACTCCAAGCT': 'CL:0000138',
#  'AAGTTCGGCCAACAGG': 'CL:0000057',
#  'AATAACACTAGAACAA': 'CL:0000187',
#  'AATAAGTCCTCGAGAC': 'CL:0000057',
#  'AATACCGGAGGGCTGT': 'CL:0000187',
#  'AATAGAACAGAGTGGC': 'CL:0000187',
#  'AATAGAATCTGTTTCA': 'CL:0000388',
#  'AATAGGCACGACCCTT': 'CL:0000187',
#  'AATAGTCCGTCCCGAC': 'CL:0000388',
#  'AATATCCTAGCAAACT': 'CL:0000057',
#  'AATATCGAGGGTTCTC': 'CL:0002551',
#  'AATCAGGTTTCATTTA': 'CL:0000187',
#  'AATCATGTAAAGACTC': 'CL:0002551',
#  'AATCCCGCTCAGAGCC': 'CL:0000187',
#  'AATCGCCTCAGCGCCA': 'CL:0000388',
#  'AATCTAGGTTTACTTG': 'CL:0000187',
#  'AATCTGCGTTGGGACG': 'CL:0000057',
#  'AATCTGGCTTTCTAGT': 'CL:0000187',
#  'AATGACAGCAATGTCT': 'CL:0000187',
#  'AATGACGTAGGATGTC': 'CL:0000187',
#  'AATGATGATACGCTAT': 'CL:0000388',
#  'AATGATGCGACTCCTG': 'CL:0002551',
#  'AATGCAACCGGGTACC': 'CL:0002551',
#  'AATGCACCAAGCAATG': 'CL:0002551',
#  'AATGTATGGCACTGTA': 'CL:0000187',
#  'AATGTGCCCGAGGTGT': 'CL:0000187',
#  'AATGTGCTAATCTGAG': 'CL:0002320',
#  'AATTAAAGGTCGGCGT': 'CL:0002551',
#  'AATTAACGGATTTCCA': 'CL:0000388',
#  'AATTACGAGACCCATC': 'CL:0000057',
#  'AATTAGCGCTGCAGCG': 'CL:0000057',
#  'AATTCATAAGGGATCT': 'CL:0000187',
#  'AATTCATTGTCATGCA': 'CL:0000187',
#  'AATTCCAAGCATGTAC': 'CL:0000187',
#  'AATTCGATTCGAGGAT': 'CL:0000057',
#  'AATTCTAGAGTTAGGC': 'CL:0000187',
#  'AATTGAACGCTCTGGT': 'CL:0000187',
#  'AATTGCGTGGATTACA': 'CL:0000187',
#  'AATTTGGGACATAGTA': 'CL:0002551',
#  'AATTTGGTTCCAAAGA': 'CL:0002551',
#  'ACAAACCATGCGTCCT': 'CL:0000187',
#  'ACAAACCGACAAGGCG': 'CL:0000388',
#  'ACAAACTCCATCAGAG': 'CL:0000187',
#  'ACAAAGAAGGTAGGCC': 'CL:0000057',
#  'ACAAATCGCACCGAAT': 'CL:0000187',
#  'ACAAATGGTAGTGTTT': 'CL:0000187',
#  'ACAACAGCATGAGCTA': 'CL:0000187',
#  'ACAAGGAAATCCGCCC': 'CL:0000388',
#  'ACAAGGATGCTTTAGG': 'CL:0002551',
#  'ACAAGGGCAGGCTCTG': 'CL:0000138',
#  'ACAAGTAATTGTAAGG': 'CL:0002551',
#  'ACAATCGATCTTTATA': 'CL:0000078',
#  'ACAATGAATACGGAGA': 'CL:0000187',
#  'ACAATTGTGTCTCTTT': 'CL:0000388',
#  'ACAATTTGAGCAGTGG': 'CL:0000388',
#  'ACACAAAGACGGGTGG': 'CL:0000232',
#  'ACACACCAGGACCAGT': 'CL:0000138',
#  'ACACACTTTCTACACG': 'CL:0000187',
#  'ACACATGATCAAATCT': 'CL:0000187',
#  'ACACCGGTCTGACCGC': 'CL:0000187',
#  'ACACGAGACTCCTTCT': 'CL:0000187',
#  'ACACGGCACTATGCAT': 'CL:0000057',
#  'ACACGGGAACTTAGGG': 'CL:0000187',
#  'ACACTGATCAAGGTGT': 'CL:0000187',
#  'ACAGAACTGAGAACAA': 'CL:0000187',
#  'ACAGCGCACCCGCAGC': 'CL:0002551',
#  'ACAGGCTTGCCCGACT': 'CL:1001607',
#  'ACAGGTGGAGGTGAGG': 'CL:0000187',
#  'ACAGTAATACAACTTG': 'CL:0000057',
#  'ACATAAGTCGTGGTGA': 'CL:0000388',
#  'ACATAATAAGGCGGTG': 'CL:0000187',
#  'ACATCCCGGCCATACG': 'CL:0000187',
#  'ACATCGATCGTTTACC': 'CL:0000187',
#  'ACATCGCAATATTCGG': 'CL:0002551',
#  'ACATCGTATGCAATGG': 'CL:0000187',
#  'ACATCGTTAACCTAGT': 'CL:0000057',
#  'ACATCTCAACGCGTAA': 'CL:0000057',
#  'ACATGCTTACGGCAGC': 'CL:0000187',
#  'ACATTAGTTTATATCC': 'CL:0000057',
#  'ACATTCGCGCGGAATA': 'CL:0000187',
#  'ACCAACGCTTATTTAT': 'CL:0000187',
#  'ACCAATATGCAAGTTA': 'CL:0000057',
#  'ACCACAACTCAGAACA': 'CL:0000057',
#  'ACCACAAGTTTCTATC': 'CL:0000187',
#  'ACCACGTGCAGCTATA': 'CL:1001607',
#  'ACCAGCCCGGTCTTTG': 'CL:0000057',
#  'ACCAGTGCGGGAGACG': 'CL:0000388',
#  'ACCATATCCGCAATAA': 'CL:0000138',
#  'ACCATCCGCCAACTAG': 'CL:0002551',
#  'ACCATCGTATATGGTA': 'CL:0002551',
#  'ACCCAACGCCCGTGGC': 'CL:0000057',
#  'ACCCGAGCGAAATTAC': 'CL:0000187',
#  'ACCCGATTGGTTCCGA': 'CL:0000187',
#  'ACCCGGAAACTCCCAG': 'CL:0000138',
#  'ACCCGGATGACGCATC': 'CL:0002551',
#  'ACCCGGTTACACTTCC': 'CL:0000187',
#  'ACCCGTAGCAGAGAAT': 'CL:0000187',
#  'ACCCGTGTCATCAGTA': 'CL:0000388',
#  'ACCCTATGCCATATCG': 'CL:0000187',
#  'ACCCTCCCTTGCTATT': 'CL:1001607',
#  'ACCCTTCATCTGCGAA': 'CL:0000187',
#  'ACCCTTTAGTTCTCCA': 'CL:0000187',
#  'ACCGAAGAGTCTGGTT': 'CL:0000057',
#  'ACCGACACATCTCCCA': 'CL:0000187',
#  'ACCGACTGAGTCCCAC': 'CL:0000187',
#  'ACCGATGGTAGCATCG': 'CL:0000187',
#  'ACCGCAATAACTGCCT': 'CL:0000388',
#  'ACCGCTAGTCATTGGT': 'CL:0000187',
#  'ACCGGGCCTTTGTTGA': 'CL:0000388',
#  'ACCGGTCAGGTACACC': 'CL:0000388',
#  'ACCGTCCACTGGGCCC': 'CL:0000388',
#  'ACCGTGACCACGTGGG': 'CL:0000187',
#  'ACCTAAGTACCTTTCA': 'CL:1001609',
#  'ACCTACTATAAATCTA': 'CL:0000187',
#  'ACCTCGAACTTATGCT': 'CL:0000187',
#  'ACCTGCGTGTCATGTT': 'CL:0000057',
#  'ACCTTTCCTTTAGAAG': 'CL:0002551',
#  'ACGACTGGTCATACTC': 'CL:0000187',
#  'ACGAGATATTTGCTTA': 'CL:0000388',
#  'ACGAGGATACCACTCT': 'CL:0000187',
#  'ACGAGGTTTACAACGT': 'CL:0000057',
#  'ACGAGTACGGATGCCC': 'CL:0002551',
#  'ACGATACATAGAACTA': 'CL:0000388',
#  'ACGATCATACATAGAG': 'CL:0000187',
#  'ACGATCATCTTGTAAA': 'CL:0002551',
#  'ACGATGGATCCGATGC': 'CL:0000057',
#  'ACGCAAACTAATAGAT': 'CL:0000187',
#  'ACGCATTCGTGAGTAC': 'CL:0002551',
#  'ACGCCAGATGATTTCT': 'CL:0000187',
#  'ACGCCCAGCTGTCGAT': 'CL:0000057',
#  'ACGCCGCTAGACGACC': 'CL:0000187',
#  'ACGCGAAGTCAGACGA': 'CL:0000057',
#  'ACGCGGGCCAAGGACA': 'CL:0002573',
#  'ACGCTAGTGATACACT': 'CL:0002551',
#  'ACGCTTAGTGTCTCTC': 'CL:0000187',
#  'ACGGACGCAGCGACAA': 'CL:0000187',
#  'ACGGACTCTCAAAGCG': 'CL:0000388',
#  'ACGGATGGTGCGGATA': 'CL:0000187',
#  'ACGGCACTTGCTTGGG': 'CL:0000057',
#  'ACGGCCAACATGGACT': 'CL:0000187',
#  'ACGGCGACGATGGGAA': 'CL:0000388',
#  'ACGGCTGGATGTAGAA': 'CL:0000187',
#  'ACGGGAGTGTCGGCCC': 'CL:0002551',
#  'ACGGGTTGTGACCTGT': 'CL:0000187',
#  'ACGGTCACCGAGAACA': 'CL:0000187',
#  'ACGTACAGATTTCTCT': 'CL:0002551',
#  'ACGTACTTTGGCACGG': 'CL:0000187',
#  'ACGTAGATTGCTGATG': 'CL:0000187',
#  'ACGTATTACTCCGATC': 'CL:0000388',
#  'ACGTCCTAAACGAGAT': 'CL:0002551',
#  'ACGTCGGGCAACTCGG': 'CL:0000187',
#  'ACGTCTCGTTCCGGGA': 'CL:0002551',
#  'ACGTGACAAAGTAAGT': 'CL:0000187',
#  'ACGTGCGCCTCGTGCA': 'CL:0000388',
#  'ACGTGGTCGAATGTGC': 'CL:0000187',
#  'ACGTTAATGTCGAAGA': 'CL:0000187',
#  'ACGTTCACTATGCCGC': 'CL:0000187',
#  'ACGTTCGTTCAGGAAA': 'CL:0000187',
#  'ACGTTGTCGTTGAAAG': 'CL:0000187',
#  'ACGTTTAGTTGTGATC': 'CL:0000187',
#  'ACTACAAAGAGAGGTG': 'CL:0000187',
#  'ACTACATCCCGACAAG': 'CL:0000187',
#  'ACTACCATCCGAGGGC': 'CL:0000187',
#  'ACTACGCGTTAGAATT': 'CL:0000057',
#  'ACTAGTTGCGATCGTC': 'CL:0002551',
#  'ACTATGTCCAGCTGCC': 'CL:0000187',
#  'ACTATTCGTCCGTGGT': 'CL:0000187',
#  'ACTATTTCCGGGCCCA': 'CL:0000187',
#  'ACTCAAGTGCAAGGCT': 'CL:0000388',
#  'ACTCAATAAAGGCACG': 'CL:0000187',
#  'ACTCATGGCAGCCTTC': 'CL:0000187',
#  'ACTCCAATATCATCAT': 'CL:0000187',
#  'ACTCCCATTCCTAAAG': 'CL:0000057',
#  'ACTCCCGAATTCGTTT': 'CL:0002551',
#  'ACTCCCTAATGCTAAA': 'CL:0000187',
#  'ACTCCCTAGAATAGTA': 'CL:0000187',
#  'ACTCGTAACCCGTCCT': 'CL:0000187',
#  'ACTCGTCAGTAATCCC': 'CL:0000187',
#  'ACTCTCTGACTTAGGT': 'CL:0000138',
#  'ACTCTCTTATACACGA': 'CL:0002551',
#  'ACTCTTGTATAGTAAC': 'CL:0000187',
#  'ACTGAAACGCCGTTAG': 'CL:0000388',
#  'ACTGAATGGCGAAAGT': 'CL:1001607',
#  'ACTGATTTAGTGATTC': 'CL:0000187',
#  'ACTGCCCGCCATTCTC': 'CL:0000187',
#  'ACTGCCGTCGTAACTC': 'CL:0000187',
#  'ACTGCTCGGAAGGATG': 'CL:0000187',
#  'ACTGGGATGCCAGTGC': 'CL:0002551',
#  'ACTGTACGATACACAT': 'CL:0000187',
#  'ACTGTCCAGGATTATA': 'CL:0000187',
#  'ACTGTCTTCTTTAGAA': 'CL:0000187',
#  'ACTTACCGGGCGCGCA': 'CL:0002551',
#  'ACTTACGCATCCACGC': 'CL:0000388',
#  'ACTTATACTTACCCGG': 'CL:0000187',
#  'ACTTATTAGGATCGGT': 'CL:0002551',
#  'ACTTATTTATGTGCCA': 'CL:0000388',
#  'ACTTCAGGCTGATCCC': 'CL:0000187',
#  'ACTTCCAGTGGAAGCT': 'CL:0000057',
#  'ACTTCCATGCGGGACA': 'CL:0000388',
#  'ACTTCGCCATACGCAC': 'CL:0000187',
#  'ACTTGACTCCCTCTTT': 'CL:0000187',
#  'ACTTGCTCTATCTACC': 'CL:0000187',
#  'ACTTGTAGTCCCTTCA': 'CL:0002551',
#  'ACTTGTTACCGGATCA': 'CL:0000187',
#  'ACTTTACCCTCATGAA': 'CL:0002551',
#  'ACTTTATACACCACTT': 'CL:0000187',
#  'ACTTTCCTATAGCTTC': 'CL:0000388',
#  'ACTTTGGTCGTGCTCC': 'CL:0000187',
#  'AGAACACGGCGATGGT': 'CL:0000187',
#  'AGAACCCTCAATTGGG': 'CL:0000388',
#  'AGAACGTGGTACATTC': 'CL:0002573',
#  'AGAAGGTACACTTCAC': 'CL:0000187',
#  'AGAAGGTTGCCGAATT': 'CL:0002551',
#  'AGAAGGTTGTAGGTCG': 'CL:0002551',
#  'AGAAGTGATTCGTGAT': 'CL:0000187',
#  'AGAATTATGGATTCGA': 'CL:0002551',
#  'AGACCAAACCACACCT': 'CL:0000187',
#  'AGACCCACCGCTGATC': 'CL:0000187',
#  'AGACCCGCCCTCCTCG': 'CL:0002551',
#  'AGACGAAGTGCCGGTC': 'CL:0000388',
#  'AGACGACGATGCCGCT': 'CL:0000187',
#  'AGACGGGATTGGTATA': 'CL:0000187',
#  'AGACTGTTACCGGGTC': 'CL:0000187',
#  'AGAGAAACACCAGAAA': 'CL:0000187',
#  'AGAGAACCGTCTAGGA': 'CL:0000187',
#  'AGAGAAGGAGTACAAT': 'CL:0000187',
#  'AGAGCGGGCTAATCAT': 'CL:0000187',
#  'AGAGGCTTCGGAAACC': 'CL:0002551',
#  'AGATAATCACACCTAT': 'CL:0000187',
#  'AGATACTCAAGATCGA': 'CL:0000187',
#  'AGATATAATACGACTA': 'CL:0002551',
#  'AGATCGTGCATAAGAT': 'CL:0002551',
#  'AGATCTCAGGTGTGAT': 'CL:0000669',
#  'AGATCTGGAGAGGATA': 'CL:0000187',
#  'AGATGACTCGCCCACG': 'CL:0000078',
#  'AGATGATGGAGTCTGG': 'CL:0002551',
#  'AGATGCAAGACGTGCA': 'CL:0000187',
#  'AGATGCATCCTGTGTC': 'CL:0000057',
#  'AGATTATAGGACGTTT': 'CL:0000646',
#  'AGATTCACAACCGATA': 'CL:0000187',
#  'AGCAAAGGCCGCTAGT': 'CL:0000057',
#  'AGCAACATATCTTATT': 'CL:0000138',
#  'AGCAACCGAAAGTAAT': 'CL:0000187',
#  'AGCACACGTTTAGACT': 'CL:0000187',
#  'AGCACCAGTACTCACG': 'CL:0000187',
#  'AGCACTACCTCACCAG': 'CL:0000388',
#  'AGCAGAAGGAGAAAGA': 'CL:0002551',
#  'AGCAGCCAGATGAATA': 'CL:0000057',
#  'AGCATATCAATATGCT': 'CL:0000388',
#  'AGCATCATTTCGAAAG': 'CL:0000187',
#  'AGCCAAGCTTTGTGTC': 'CL:0000388',
#  'AGCCACAGGTTACCCG': 'CL:0002551',
#  'AGCCACTCCCGTGCTT': 'CL:0000388',
#  'AGCCCGCAACAAGCAG': 'CL:0000187',
#  'AGCCCGGCATTAGAGG': 'CL:0000187',
#  'AGCCCGGTAGCCTGTA': 'CL:0000187',
#  'AGCCCTAAGCGAAGTT': 'CL:0000187',
#  'AGCCCTCCCTGGTGGC': 'CL:0000187',
#  'AGCCGTGGCTAAATGT': 'CL:0000187',
#  'AGCCTAATACCCACGT': 'CL:0000187',
#  'AGCCTTGTCACTGATA': 'CL:0000187',
#  'AGCGACAGGAACGGTC': 'CL:0000057',
#  'AGCGACATCCCATTCA': 'CL:0000187',
#  'AGCGACCAACGATATT': 'CL:0002551',
#  'AGCGACTTTGAAGACA': 'CL:0000187',
#  'AGCGAGACGTGAAGGC': 'CL:0000187',
#  'AGCGCATAATGAATCG': 'CL:0000057',
#  'AGCGCGGGTGCCAATG': 'CL:0000187',
#  'AGCGGACACTTCGTAG': 'CL:0000187',
#  'AGCGGCGGTTAGCGGT': 'CL:0000187',
#  'AGCGGGTCTGACACTC': 'CL:0002551',
#  'AGCGGTTGAGATGTAC': 'CL:0002551',
#  'AGCGTGGTATTCTACT': 'CL:0000057',
#  'AGCTAACAAGCAATGT': 'CL:0000187',
#  'AGCTAAGCTCCGTCCG': 'CL:0000187',
#  'AGCTAAGTACGCAGGC': 'CL:0002551',
#  'AGCTAGAAGCAGAAGT': 'CL:0002551',
#  'AGCTATTTAATCCAAC': 'CL:0000187',
#  'AGCTCCTTCGCACATC': 'CL:1001607',
#  'AGCTCTAGACGTTCCA': 'CL:0000187',
#  'AGCTCTTCCCAGTGCA': 'CL:0000235',
#  'AGCTCTTCGTAACCTT': 'CL:0002551',
#  'AGCTCTTTACTCAGTT': 'CL:0002551',
#  'AGCTGAAGTAAACCAA': 'CL:1000413',
#  'AGCTGTAACCTCAATC': 'CL:0000187',
#  'AGCTTCAATACTTTGA': 'CL:0000187',
#  'AGCTTGATCAGGGTAG': 'CL:0000187',
#  'AGGAAGCTGTCCGCCG': 'CL:0000187',
#  'AGGACAGTCGAATCCC': 'CL:0000187',
#  'AGGACGACCCATTAGA': 'CL:0002551',
#  'AGGACGCTCGATGTTG': 'CL:0002551',
#  'AGGAGGCCTTCGCGCG': 'CL:0002551',
#  'AGGATAAAGTCGGGAT': 'CL:0000057',
#  'AGGATATAGGGATTTA': 'CL:0000388',
#  'AGGATCACGCGATCTG': 'CL:0000187',
#  'AGGCAGATGCGTAAAC': 'CL:0000187',
#  'AGGCAGGGAGCGTACT': 'CL:1000413',
#  'AGGCATTGTCGTAGGG': 'CL:0002551',
#  'AGGCCCTAGAACGCCA': 'CL:0002551',
#  'AGGCCTATCATACCAA': 'CL:0000187',
#  'AGGCCTGAGAATCTCG': 'CL:0000558',
#  'AGGCGGTTTGTCCCGC': 'CL:0000057',
#  'AGGCTTCCCGAAGAAG': 'CL:0000187',
#  'AGGGAAACGAGGTACT': 'CL:0000187',
#  'AGGGACTCTACGCGAC': 'CL:0000187',
#  'AGGGCAGCGGCGTGGT': 'CL:0000057',
#  'AGGGCGAGCAGCTGAT': 'CL:0002551',
#  'AGGGCTGCAGTTACAG': 'CL:0000187',
#  'AGGGTCAGAGCACTCG': 'CL:0000187',
#  'AGGGTCGATGCGAACT': 'CL:0000057',
#  'AGGGTGCCGTTCTTTA': 'CL:0000187',
#  'AGGGTGCTCTCGAGGG': 'CL:0000187',
#  'AGGGTTCAGACGGTCC': 'CL:0002543',
#  'AGGGTTCCCTTTGGTT': 'CL:0000187',
#  'AGGGTTTAGTTCGGGA': 'CL:0000669',
#  'AGGTACGATATTGCCA': 'CL:0000187',
#  'AGGTAGATCGAGATAT': 'CL:0000187',
#  'AGGTCAGGTGAGAGTG': 'CL:0000057',
#  'AGGTCGCGGAGTTACT': 'CL:0002551',
#  'AGGTGGTGACCTTCGC': 'CL:0000388',
#  'AGGTTCTCCTTTCCGG': 'CL:0000187',
#  'AGGTTGAGGCACGCTT': 'CL:0000187',
#  'AGGTTTCACACACCTT': 'CL:0000187',
#  'AGTAACGTTCATCCTG': 'CL:0002551',
#  'AGTAATGTCTTGCCGC': 'CL:0002551',
#  'AGTAATTTGCAAGCGT': 'CL:0000187',
#  'AGTACGGGCACCTGGC': 'CL:0000187',
#  'AGTACGTGGCCTGTCT': 'CL:0002551',
#  'AGTACTCTTATGCCCA': 'CL:0000388',
#  'AGTAGAAGGCGCCTCA': 'CL:0002551',
#  'AGTAGCGTGAACGAAC': 'CL:0000388',
#  'AGTAGGAAGGAAGTTG': 'CL:0002551',
#  'AGTATACACAGCGACA': 'CL:0000187',
#  'AGTATGCTGGAGACCA': 'CL:0000187',
#  'AGTATTTGGCACGACC': 'CL:0000057',
#  'AGTCAAATGATGTGAT': 'CL:0000187',
#  'AGTCAACACCACCATC': 'CL:0002551',
#  'AGTCAAGATGACACTT': 'CL:0000057',
#  'AGTCCCGCCTTTAATT': 'CL:0000388',
#  'AGTCGAAACGATTCAG': 'CL:0000187',
#  'AGTCGACGGTCTCAAG': 'CL:0000187',
#  'AGTCGGCTCAACTTTA': 'CL:0000187',
#  'AGTCGTATAAAGCAGA': 'CL:0002551',
#  'AGTCGTCGACCACCAA': 'CL:0000388',
#  'AGTCGTGGGCATTACG': 'CL:0000187',
#  'AGTCTCACAAGACTAC': 'CL:0000187',
#  'AGTCTTCTCCTCAAAT': 'CL:0000187',
#  'AGTCTTTAAAGTGTCC': 'CL:0002551',
#  'AGTGAACAAACTTCTC': 'CL:0002551',
#  'AGTGACCTACTTTACG': 'CL:0002551',
#  'AGTGACTGTGACACAA': 'CL:0000187',
#  'AGTGAGACTTCCAGTA': 'CL:0000388',
#  'AGTGAGCCTCGCCGCC': 'CL:0002551',
#  'AGTGAGGGTTTCTGAC': 'CL:0000388',
#  'AGTGATAACCTGCGCG': 'CL:0000388',
#  'AGTGATATGAGTAGTT': 'CL:0000057',
#  'AGTGATTCAAGCAGGA': 'CL:0000187',
#  'AGTGCACGCTTAAGAA': 'CL:0000388',
#  'AGTGCGTAGCTCGTAA': 'CL:0000187',
#  'AGTGCTAAACACAGCA': 'CL:0002551',
#  'AGTGCTTGCACGAATA': 'CL:0000187',
#  'AGTGGCGGCAATTTGA': 'CL:0000388',
#  'AGTGGCGTCTGAAGGT': 'CL:0000057',
#  'AGTGGCTCCGTCGGCC': 'CL:0002551',
#  'AGTGGTGTTACCCGTG': 'CL:0002543',
#  'AGTGTATTGCGCATTG': 'CL:0002551',
#  'AGTTAAACACTTGCGA': 'CL:0002551',
#  'AGTTAAGCGGTCCCGG': 'CL:0002551',
#  'AGTTAAGTCAACCGCT': 'CL:0000187',
#  'AGTTACTCTATCGTGG': 'CL:1000413',
#  'AGTTATTGAAAGGTAA': 'CL:0000388',
#  'AGTTCCTATTTATGTT': 'CL:0000187',
#  'AGTTGACGGTCCTTGC': 'CL:0000057',
#  'AGTTGCGGTCCTCAAC': 'CL:0000187',
#  'AGTTTCGCAGGTCGGA': 'CL:0002551',
#  'AGTTTGCACCTGCCTC': 'CL:0000388',
#  'AGTTTGGCACGGGTTG': 'CL:0000388',
#  'AGTTTGGCCAGACCTA': 'CL:0000187',
#  'ATAAACGGACCCGTAA': 'CL:0000057',
#  'ATAAAGGTCAAGTACG': 'CL:0002551',
#  'ATAACGCCGGAGGGTC': 'CL:0000388',
#  'ATAACGGAGTCCAACG': 'CL:0000187',
#  'ATAAGGTGGAGAACAT': 'CL:0000138',
#  'ATAAGTAGGATTCAGA': 'CL:0002551',
#  'ATAAGTTACCGCGACG': 'CL:0002551',
#  'ATAATAGCTGTTGAAT': 'CL:0000187',
#  'ATAATCTTGGAGAACC': 'CL:0000388',
#  'ATAATTAGCTAAGTAG': 'CL:0000388',
#  'ATACAGCGTCCACTGA': 'CL:0000187',
#  'ATACAGGCCCTCCAAT': 'CL:0000187',
#  'ATACCCTCCCGGCCAA': 'CL:0000187',
#  'ATACCTAACCAAGAAA': 'CL:0000388',
#  'ATACGAGGTTTGTAAG': 'CL:0000187',
#  'ATACGCCGGCGAAACC': 'CL:0000057',
#  'ATACGGAACGTCGTTT': 'CL:0000187',
#  'ATACGGGTTTCGATTG': 'CL:0000062',
#  'ATACGTACTTAGCCAC': 'CL:0002551',
#  'ATACGTCCACTCCTGT': 'CL:0000388',
#  'ATACGTTATGCACGGA': 'CL:0000388',
#  'ATACTAGCATGACCCT': 'CL:0002551',
#  'ATACTGCCTTACACCG': 'CL:0000138',
#  'ATAGACAACGGGACCT': 'CL:0000187',
#  'ATAGAGTTATCAACTT': 'CL:0000187',
#  'ATAGATTTGCAGTCGG': 'CL:0002551',
#  'ATAGGCGGCTATAGAA': 'CL:0002551',
#  'ATAGGCTAGCTTCGCA': 'CL:0002551',
#  'ATAGGGATATCCTTGA': 'CL:0000187',
#  'ATAGGTTGGGCAGATG': 'CL:0000187',
#  'ATAGTCTTTGACGTGC': 'CL:0002551',
#  'ATAGTGAAGCGTTCTC': 'CL:0002551',
#  'ATAGTTCCACCCACTC': 'CL:0002551',
#  'ATATAAAGCGCTCGTG': 'CL:0000388',
#  'ATATAAATGTAGCTGC': 'CL:0000187',
#  'ATATACATGTATGGTA': 'CL:0000187',
#  'ATATAGAGTATTGGTC': 'CL:0000057',
#  'ATATCAATTCCAGCCT': 'CL:0000057',
#  'ATATCGTGCCAGACCC': 'CL:0000187',
#  'ATATCGTTCCTCGAAC': 'CL:0002551',
#  'ATATCTCCCTCGTTAA': 'CL:0000138',
#  'ATATCTTAGGGCCTTC': 'CL:0000057',
#  'ATATGGGATAGCAACT': 'CL:0002551',
#  'ATATGTCTCCCTAGCC': 'CL:0002551',
#  'ATATTCAGTTAAACCT': 'CL:0002551',
#  'ATATTCCACATAGTGA': 'CL:0000187',
#  'ATATTCCCACAGGTCA': 'CL:0002551',
#  'ATATTTAACCCTCAAG': 'CL:0000187',
#  'ATCAAACGAAGGTTTG': 'CL:0000187',
#  'ATCAAGATCCCAGGAC': 'CL:0002551',
#  'ATCAATCTGGGCTGCA': 'CL:0000187',
#  'ATCAATGCCGTGGCTG': 'CL:0000187',
#  'ATCACATTAGAATATC': 'CL:0000062',
#  'ATCACGTGCTAATTAA': 'CL:0000057',
#  'ATCACTTCATCCTCGC': 'CL:0000187',
#  'ATCAGAAGCTGGTTGC': 'CL:0002551',
#  'ATCAGACGGCACGCCG': 'CL:0002551',
#  'ATCAGCCTCATGCTGC': 'CL:0000388',
#  'ATCAGCTCGTCCACTA': 'CL:0000057',
#  'ATCAGTAGGCAGGGAT': 'CL:0000187',
#  'ATCATAGATCGACGAG': 'CL:0000187',
#  'ATCATCCAATATTTGT': 'CL:0002551',
#  'ATCATCTGCCCAGTGT': 'CL:0000388',
#  'ATCATTGTACCGCATT': 'CL:0000388',
#  'ATCCACATCGACAGAA': 'CL:0000388',
#  'ATCCACGCTAAATGTT': 'CL:0000187',
#  'ATCCAGAGCAACAACC': 'CL:0000187',
#  'ATCCAGGATTCGTGAA': 'CL:0000078',
#  'ATCCCATCCACAGCGC': 'CL:0000187',
#  'ATCCCATTTCCGTGGG': 'CL:0002551',
#  'ATCCTACCTAAGCTCT': 'CL:0002551',
#  'ATCCTGCGTGGAATGG': 'CL:0000057',
#  'ATCGACCCAATACAGA': 'CL:0000187',
#  'ATCGACTCTTTCCGTT': 'CL:0000057',
#  'ATCGCACGCCGGGAGA': 'CL:0000187',
#  'ATCGCCAGTCAACATT': 'CL:0002551',
#  'ATCGGAGACAGACGGC': 'CL:0000187',
#  'ATCGGCAAGCAGTCCA': 'CL:0000057',
#  'ATCGTGGAAAGTCTGG': 'CL:0000187',
#  'ATCGTTCACTTTCGCC': 'CL:0002551',
#  'ATCTAATATCCTACGG': 'CL:0000388',
#  'ATCTAGCTTGTGAGGG': 'CL:0002551',
#  'ATCTCCCTGCAATCTA': 'CL:0000187',
#  'ATCTGACATGGAAGGA': 'CL:0000187',
#  'ATCTGCACCTCTGCGA': 'CL:0002551',
#  'ATCTGCTGTTATCGCC': 'CL:0000187',
#  'ATCTGGGCTGTTCTTG': 'CL:0000187',
#  'ATCTGGTTAAGACTGT': 'CL:0000187',
#  'ATCTGTAATTGTACCC': 'CL:0000078',
#  'ATCTTAGGGCATTAAT': 'CL:0000187',
#  'ATGACGCCGGCTCTAA': 'CL:0002551',
#  'ATGACGCGTTCTATCC': 'CL:0000187',
#  'ATGACTATCAGCTGTG': 'CL:0000187',
#  'ATGACTATGCGACATT': 'CL:0000388',
#  'ATGATGCAATGGTACA': 'CL:0002551',
#  'ATGCACGCGCTGTTCA': 'CL:0000187',
#  'ATGCATGATCCAGGAT': 'CL:0000187',
#  'ATGCCATTTGCGACCA': 'CL:0000138',
#  'ATGCCGGTCTTGCATA': 'CL:0000232',
#  'ATGCCGGTTGATGGGA': 'CL:0000235',
#  'ATGCGACAGTCCCATT': 'CL:0000187',
#  'ATGCTCTGGCGCGGTA': 'CL:0000057',
#  'ATGGAAATTTAAGGAG': 'CL:0000187',
#  'ATGGACTGCTTAGTTG': 'CL:0000187',
#  'ATGGAGCAGGCCGTGA': 'CL:0000187',
#  'ATGGATCCGGCGTCCG': 'CL:0000057',
#  'ATGGATTGACCAAACG': 'CL:0000187',
#  'ATGGCAGCATTACGAT': 'CL:0000187',
#  'ATGGGAACGGAAGCGG': 'CL:0002551',
#  'ATGGGACCTGCTGAAC': 'CL:0000187',
#  'ATGGGCCTCGGCCTCT': 'CL:0000138',
#  'ATGGGTGTATACCTCC': 'CL:0000187',
#  'ATGGTATTGGGAACCG': 'CL:0002551',
#  'ATGGTATTTACTGATT': 'CL:0000187',
#  'ATGGTCGCGTGGTTTC': 'CL:0000187',
#  'ATGTACGATGACGTCG': 'CL:0002551',
#  'ATGTCTTGTTTGACTC': 'CL:0000187',
#  'ATGTGAAAGCCTAATG': 'CL:0000057',
#  'ATGTGCATCCGACGCA': 'CL:0000187',
#  'ATGTGGACATCTTGAT': 'CL:0000057',
#  'ATGTTGTAGTCTGTTT': 'CL:0000187',
#  'ATTAAACATGCGGACC': 'CL:0000235',
#  'ATTAATACTACGCGGG': 'CL:0000187',
#  'ATTAATGAACCAGTCG': 'CL:0000187',
#  'ATTAATTCGGTCACTC': 'CL:0000187',
#  'ATTACAACTACCGGCC': 'CL:0000187',
#  'ATTACGGGCTACGGTT': 'CL:0000187',
#  'ATTACTTACTGGGCAT': 'CL:0002551',
#  'ATTAGATTCCTCAGCA': 'CL:0002551',
#  'ATTAGGCGATGCTTTC': 'CL:0000187',
#  'ATTATACTTTGCTCGT': 'CL:0000187',
#  'ATTATCGGAATGTACG': 'CL:0002551',
#  'ATTATGAGACCCAATT': 'CL:0000187',
#  'ATTATTATGTCCGTCA': 'CL:0000187',
#  'ATTCACTGATGTTGGA': 'CL:0000187',
#  'ATTCAGGACCTATTTC': 'CL:0002551',
#  'ATTCAGGATCGCCTCT': 'CL:0002551',
#  'ATTCATATACTGTCCA': 'CL:0002573',
#  'ATTCATCGTTGAGGCA': 'CL:0002551',
#  'ATTCCCGAAGGTACAG': 'CL:0000057',
#  'ATTCTGAGTATGAACT': 'CL:0000388',
#  'ATTCTTCGTACTTATG': 'CL:0002551',
#  'ATTGACGTAACTCGGT': 'CL:0000057',
#  'ATTGATCACCACATTT': 'CL:0000187',
#  'ATTGATGAGTCCTAAC': 'CL:0002551',
#  'ATTGCCTATTAGACCG': 'CL:0002320',
#  'ATTGCCTTTATGTTTG': 'CL:0002551',
#  'ATTGCGATCAGTAACT': 'CL:0002551',
#  'ATTGTACAACTCGGCT': 'CL:0002551',
#  'ATTGTCGCAATACCTT': 'CL:0000388',
#  'ATTGTCTGTTTCATGT': 'CL:0002551',
#  'ATTTCATTATTTCGCG': 'CL:0000057',
#  'ATTTCCGGGTTCTGCG': 'CL:0000187',
#  'ATTTGCCTAGTTACGA': 'CL:0002551',
#  'ATTTGCGCGAGTAGCT': 'CL:0000057',
#  'ATTTGGAGATTGCGGT': 'CL:0000057',
#  'ATTTGTCTTGGGAGCT': 'CL:0000187',
#  'ATTTGTTCCAGGGCTC': 'CL:0000192',
#  'CAAACGAGTATCGCAG': 'CL:0002551',
#  'CAAACGTGGTCTTGCG': 'CL:0000187',
#  'CAAACTACGATAGAGA': 'CL:0000057',
#  'CAAACTATTGAGCTTC': 'CL:0000187',
#  'CAAAGATTATTGGGCC': 'CL:0000187',
#  'CAAATGCGGAGTGTTC': 'CL:0000078',
#  'CAAATGTCCTTCCGTG': 'CL:0002551',
#  'CAAATTGTCAGCAAGC': 'CL:0000187',
#  'CAACAGTGCCAAACGG': 'CL:0000388',
#  'CAACGACCCGTTTACA': 'CL:0002551',
#  'CAACGAGCTTATTATG': 'CL:0000187',
#  'CAACGCGATGAGCCAA': 'CL:0000187',
#  'CAACTATATCGAATGC': 'CL:0000388',
#  'CAACTCCAACGTTTAG': 'CL:0002551',
#  'CAACTGCTCATCCGAT': 'CL:0000388',
#  'CAAGAGGGCGGAGTAC': 'CL:0000388',
#  'CAAGATATTATAACGT': 'CL:0000187',
#  'CAAGCACCAAATGCCT': 'CL:0000187',
#  'CAAGCGGCACATAATT': 'CL:0000057',
#  'CAAGGATCGCATGTTC': 'CL:0000187',
#  'CAAGTAAGTGATAGAC': 'CL:0002551',
#  'CAAGTCGTTGAAATCT': 'CL:0000187',
#  'CAAGTGTGGTTGCAAA': 'CL:0000388',
#  'CAATAAACCTTGGCCC': 'CL:0000187',
#  'CAATACGCTCTGAGGC': 'CL:0002551',
#  'CAATATTCTTGACCTA': 'CL:0000187',
#  'CAATCCCTATACCAGC': 'CL:0002551',
#  'CAATGACCCTTAATTT': 'CL:0000187',
#  'CAATGCGAGAAGTATC': 'CL:0000187',
#  'CAATGGAATCTACATA': 'CL:0002551',
#  'CAATGGATCTCTACCA': 'CL:0000388',
#  'CAATTAAGGGTGATGA': 'CL:0000187',
#  'CAATTGGGCCGCACTC': 'CL:0000057',
#  'CAATTTCGTATAAGGG': 'CL:0000187',
#  'CACAAGCTAAGAAAGG': 'CL:0000187',
#  'CACAATGAGCTGCTAT': 'CL:0002551',
#  'CACACGCGCTGTCTTA': 'CL:0000187',
#  'CACACGTTTCAATGGG': 'CL:0002551',
#  'CACAGAGACGAGGACG': 'CL:0000187',
#  'CACAGCACCCACGGCA': 'CL:0000187',
#  'CACAGCTAGGGAGTGA': 'CL:0002551',
#  'CACAGGGCCGTTGTCA': 'CL:0000187',
#  'CACATATTAGCAGGAT': 'CL:0000388',
#  'CACATCGTGCACGCGC': 'CL:0000187',
#  'CACATCTCACCGACGA': 'CL:0000388',
#  'CACATGATTCAGCAAC': 'CL:0000187',
#  'CACATTCTTTCGATGG': 'CL:1000413',
#  'CACCAATCATCCGTCT': 'CL:0000187',
#  'CACCACGCCACACAGA': 'CL:0002551',
#  'CACCAGTCAGCATGCA': 'CL:0000187',
#  'CACCATCGGAGGAGAC': 'CL:0002551',
#  'CACCCAAATCTTATGT': 'CL:0002551',
#  'CACCCACGAGGCAATT': 'CL:0000388',
#  'CACCCGGTTTGTGACT': 'CL:0000187',
#  'CACCCTAACAAGATCT': 'CL:0000187',
#  'CACCCTTGGTGAGACC': 'CL:0000187',
#  'CACCGATACACCGAGC': 'CL:0000187',
#  'CACCGCCAGAAGGTTT': 'CL:0002551',
#  'CACCGCCGACCAGCGA': 'CL:0002551',
#  'CACCGGTAGAGACATT': 'CL:0000187',
#  'CACCGTTAGGGATCAC': 'CL:0000187',
#  'CACCGTTGCGCGATAT': 'CL:0000057',
#  'CACCTAATCAGTTTAC': 'CL:0000192',
#  'CACCTCGATGGTGGAC': 'CL:0000187',
#  'CACCTTGCGAAACTCG': 'CL:0000192',
#  'CACCTTGGCGCCTTTG': 'CL:0002551',
#  'CACGAGCAAACCAGAC': 'CL:0000187',
#  'CACGCACAGCGCAGCT': 'CL:0000187',
#  'CACGTCGGCAACCTCT': 'CL:0000187',
#  'CACGTTCGTGCTCTAG': 'CL:0000388',
#  'CACGTTTCGTACACAC': 'CL:0000388',
#  'CACTAAAGTTGCCTAT': 'CL:0002551',
#  'CACTACTCAGTTCTGT': 'CL:0000388',
#  'CACTCAAGAGCTATGG': 'CL:0000187',
#  'CACTCAGCTCTTGAGG': 'CL:0000187',
#  'CACTCCTATGTAAGAT': 'CL:0000187',
#  'CACTCCTCTCGGTCGG': 'CL:1000413',
#  'CACTCGAGCTGAACAA': 'CL:1001607',
#  'CACTCTCAAGCATCGA': 'CL:0000187',
#  'CACTGACGATTGTGGA': 'CL:0000388',
#  'CAGAACTTAGCCCTCT': 'CL:0000187',
#  'CAGACACCGATCGCTG': 'CL:0000187',
#  'CAGACCTGTAAGTGTT': 'CL:0002551',
#  'CAGACGAACCTGATAC': 'CL:0000187',
#  'CAGAGACGGTCACCCA': 'CL:0000187',
#  'CAGAGCATGAGCTTGC': 'CL:0000187',
#  'CAGAGGCGATGCATGA': 'CL:0000187',
#  'CAGAGTGATTTAACGT': 'CL:0002551',
#  'CAGATATGAAGATGAC': 'CL:1000413',
#  'CAGATCCTGGTTTGAA': 'CL:0000057',
#  'CAGATGTTTGTCCCAA': 'CL:0000187',
#  'CAGCAGCCCGTTCCTT': 'CL:0000187',
#  'CAGCAGTCCAGACTAT': 'CL:0000388',
#  'CAGCAGTCTGTGCTGC': 'CL:0000388',
#  'CAGCCGGGCCCTCTAT': 'CL:0002551',
#  'CAGCCTCCTGCAGAGG': 'CL:0000187',
#  'CAGCCTCTCCTCAAGA': 'CL:0002551',
#  'CAGCGATTCCCTTCAA': 'CL:0000187',
#  'CAGCTCACTGAGACAT': 'CL:0002551',
#  'CAGCTCGACAAGTTAA': 'CL:0000388',
#  'CAGCTCTGGGCTCACT': 'CL:0000187',
#  'CAGCTGGCGTAACCGT': 'CL:0000187',
#  'CAGGAAGACTTTATAT': 'CL:0000388',
#  'CAGGATATATCGTTGT': 'CL:0000057',
#  'CAGGCAGTCTTACCAG': 'CL:0002551',
#  'CAGGCCAGTACCACCT': 'CL:0000187',
#  'CAGGCCGTTTGGGTGT': 'CL:0002551',
#  'CAGGCGCACGGTGGTC': 'CL:0000187',
#  'CAGGCGCCATGCTAGG': 'CL:0000388',
#  'CAGGGAGATAGGCCAG': 'CL:0000187',
#  'CAGTAAGGGACGTCTC': 'CL:0000388',
#  'CAGTACCAGTTTACGT': 'CL:0000187',
#  'CAGTAGCCCACGCGGT': 'CL:0000187',
#  'CAGTCGAGGATGCAAT': 'CL:0000388',
#  'CAGTCGGCCTAGATAT': 'CL:0002551',
#  'CAGTCTGTATACTGGG': 'CL:0000187',
#  'CAGTGAATAAATGACT': 'CL:0000669',
#  'CAGTGTCGGCTGGCCC': 'CL:0000388',
#  'CAGTGTTAATCTCTCA': 'CL:0000187',
#  'CAGTTCGAGGACCCGA': 'CL:0000187',
#  'CATAACGGACAGTCGT': 'CL:0000388',
#  'CATAAGAAGCTTGGCT': 'CL:0000388',
#  'CATAAGCTCTCCGTCT': 'CL:0002551',
#  'CATACACAAAGTCAGC': 'CL:0002573',
#  'CATACACGGTTCCCAC': 'CL:0000187',
#  'CATACGAACTAGCTGG': 'CL:0000187',
#  'CATACGGCGTCTGGGC': 'CL:0000187',
#  'CATACTATGTAATTGT': 'CL:0002551',
#  'CATACTTCTTTCTCCG': 'CL:0000187',
#  'CATAGCGTTGCCCACC': 'CL:0000187',
#  'CATAGGGACACTTGTG': 'CL:0000187',
#  'CATAGTACATTGAGAG': 'CL:0000187',
#  'CATAGTCCACAAGAAC': 'CL:0002573',
#  'CATATAGGTACAGTCA': 'CL:0002551',
#  'CATATGTCAGGCTACG': 'CL:0000187',
#  'CATATTATTTGCCCTA': 'CL:0000187',
#  'CATCATCTACCCGGAC': 'CL:0000057',
#  'CATCATTACCCTGAGG': 'CL:0000388',
#  'CATCCAATATAGTTTG': 'CL:0000187',
#  'CATCCTCTCAAAGATC': 'CL:0000388',
#  'CATCGGACGGGTTAAT': 'CL:0002551',
#  'CATCTATCCCGTGTCT': 'CL:0002551',
#  'CATCTTACACCACCTC': 'CL:0000388',
#  'CATGAACCTCTTATCA': 'CL:0002551',
#  'CATGACTTCGCTGAAT': 'CL:0002551',
#  'CATGAGATGCACTCTC': 'CL:0000138',
#  'CATGAGTCCATCACGG': 'CL:0000187',
#  'CATGATGCACAATTCT': 'CL:0000187',
#  'CATGATGGAAGTTAGC': 'CL:0002551',
#  'CATGCACATGAGAGGC': 'CL:0000187',
#  'CATGCATGGAGACCCT': 'CL:0000057',
#  'CATGCGACCAGTTTAA': 'CL:0002551',
#  'CATGCGTTAGACAGAA': 'CL:0000388',
#  'CATGCGTTGAGAGGAG': 'CL:0002551',
#  'CATGCTGGCTCCAATT': 'CL:0002551',
#  'CATGGCAGGAAGATCG': 'CL:0002551',
#  'CATGGGTATGCCTTAT': 'CL:0000388',
#  'CATGGGTCGGGTGTGG': 'CL:0000235',
#  'CATGGTAAGTAGCGTT': 'CL:0000057',
#  'CATGGTATTAGTTTGT': 'CL:0000057',
#  'CATGGTCTAGATACCG': 'CL:0000187',
#  'CATGTAAGAGACATTT': 'CL:0000388',
#  'CATGTCTCATTTATGG': 'CL:1001607',
#  'CATTACGTCGGCCCGT': 'CL:0000187',
#  'CATTATAACAGGGTCC': 'CL:0002551',
#  'CATTATCCCATTAACG': 'CL:0000187',
#  'CATTATGCTTGTTGTG': 'CL:0002551',
#  'CATTCACTGACAGCTA': 'CL:0002551',
#  'CATTGCAAAGCATAAT': 'CL:0000388',
#  'CATTTAGCGGACCATG': 'CL:0000187',
#  'CATTTATCGTTCAAGA': 'CL:0000187',
#  'CATTTGAGTGGTACGT': 'CL:0000187',
#  'CCAAATCAAAGGGCAA': 'CL:0000187',
#  'CCAACCTTATGTAACT': 'CL:0000187',
#  'CCAAGAAAGTGGGCGA': 'CL:0000187',
#  'CCAAGACTTCTGCGAA': 'CL:0002551',
#  'CCAAGCGTAACTCGTA': 'CL:0000187',
#  'CCAATCGGTAGATCGA': 'CL:0000187',
#  'CCAATGTCACAGCAAG': 'CL:0000078',
#  'CCAATTACGGGTCGAG': 'CL:0000388',
#  'CCACAATGTACGTCTT': 'CL:0002551',
#  'CCACACTGAGATATTA': 'CL:0002551',
#  'CCACAGTACCCATCCT': 'CL:0000388',
#  'CCACATGGCTCTTTAT': 'CL:0000057',
#  'CCACCAACTTTACTGT': 'CL:0000187',
#  'CCACCCAAGGAAAGTG': 'CL:0000187',
#  'CCACGAGAAGAGAATC': 'CL:0000187',
#  'CCACGGAGCCATAAGA': 'CL:0000057',
#  'CCACGGCAGGTGTAGG': 'CL:0000187',
#  'CCAGAAAGCAACTCAT': 'CL:0000187',
#  'CCAGATAGTTGAGTGA': 'CL:0002551',
#  'CCAGCCTGGACCAATA': 'CL:0000187',
#  'CCAGCTCGAACGCATT': 'CL:0000388',
#  'CCAGGCGAGATGGTCT': 'CL:0000187',
#  'CCAGGGACGTGGCCTC': 'CL:0000078',
#  'CCAGTAGTCTGATCCA': 'CL:0000388',
#  'CCAGTCAAATCTCTTA': 'CL:0002551',
#  'CCAGTCTAGACGGCGC': 'CL:0000388',
#  'CCAGTCTTGTCATAGA': 'CL:0000388',
#  'CCAGTGTACAGACCGA': 'CL:0000187',
#  'CCATAAACAACCCGAC': 'CL:0000187',
#  'CCATAACCTGTGCAGT': 'CL:0000187',
#  'CCATACCTTTACTTGT': 'CL:0002551',
#  'CCATAGAGGCTGCCAG': 'CL:0000057',
#  'CCATAGGTTGGCGTGG': 'CL:0000057',
#  'CCATCGCAGTTAAACT': 'CL:0000057',
#  'CCATCTCACCAGTGAA': 'CL:0002551',
#  'CCATGCCTGTTTAGTA': 'CL:0000078',
#  'CCATGGCAAACGCTCA': 'CL:0000187',
#  'CCATGTTCATCTATAT': 'CL:0000187',
#  'CCATTTCTACCTATTA': 'CL:0002551',
#  'CCCAAACATGCTGCTC': 'CL:0000187',
#  'CCCAACATACGTCGCG': 'CL:0002551',
#  'CCCAAGAATGCACGGT': 'CL:0002551',
#  'CCCAATGAGATTTGCA': 'CL:0000187',
#  'CCCACTCCACGGTATC': 'CL:0000187',
#  'CCCAGATTCCCGTGAC': 'CL:0000187',
#  'CCCAGTAAACTTGGGA': 'CL:0000187',
#  'CCCAGTTAAGGCGCCG': 'CL:0000187',
#  'CCCGAAGTTTCGCGAA': 'CL:0002551',
#  'CCCGACCATAGTCCGC': 'CL:0000187',
#  'CCCGCAAATAATCATC': 'CL:0002551',
#  'CCCGCAGCGCGAACTA': 'CL:0000187',
#  'CCCGCAGGGCCCAAAG': 'CL:0000388',
#  'CCCGCTAGAGGGTTAA': 'CL:0000388',
#  'CCCGGGTCGTTCAGGG': 'CL:0000187',
#  'CCCGGTGTATCGGAAT': 'CL:0000187',
#  'CCCGTAGCTGGGAAGA': 'CL:0000187',
#  'CCCGTCAGCGTCTGAC': 'CL:0002551',
#  'CCCGTGAGGGCGGTGA': 'CL:0002551',
#  'CCCTAGCTCTAAGGTC': 'CL:0000187',
#  'CCCTAGGCAACAAGAG': 'CL:0000057',
#  'CCCTATGTAGAGCAGA': 'CL:0000187',
#  'CCCTCAGATCGAGAAC': 'CL:0000187',
#  'CCCTCATCACAGAGTA': 'CL:0000187',
#  'CCCTCGATAATACACA': 'CL:0000187',
#  'CCCTGGCTGTTCCTTC': 'CL:0000057',
#  'CCCTGGTATGGGCGGC': 'CL:0002551',
#  'CCCTTTGACAGGTCTT': 'CL:0000187',
#  'CCGAAACACGACCTCT': 'CL:0000187',
#  'CCGAACACTGGGCCTC': 'CL:0002551',
#  'CCGAACCTTCCCGGCC': 'CL:0000057',
#  'CCGAAGCATTGACCAA': 'CL:0000388',
#  'CCGACGGGCATGAGGT': 'CL:0000057',
#  'CCGACTCGCATAGTCT': 'CL:0000388',
#  'CCGATCTCAACCTTAT': 'CL:0002551',
#  'CCGCACAAAGACCAAC': 'CL:0000187',
#  'CCGCATGTGGTACGAT': 'CL:0000388',
#  'CCGCCGGAACTTCTCG': 'CL:1000413',
#  'CCGCCTGCGAATTGGT': 'CL:0000078',
#  'CCGCCTTGCGATGTCG': 'CL:0002551',
#  'CCGCGCAAGATACCCA': 'CL:0000388',
#  'CCGCGGAATGCGTCAC': 'CL:0000187',
#  'CCGCTATCAGCACCAG': 'CL:0000187',
#  'CCGCTCCGGATAAGCT': 'CL:0000187',
#  'CCGCTGGTGCCATTCA': 'CL:0000057',
#  'CCGCTTACCTCACTCT': 'CL:0000187',
#  'CCGGAGCGTACTTTCT': 'CL:0000388',
#  'CCGGCCGCGAGCATAT': 'CL:0000057',
#  'CCGGCGCATATTGGAT': 'CL:0002551',
#  'CCGGCGTGAGACTCTG': 'CL:0000057',
#  'CCGGGCGGTCTCGTCA': 'CL:0000057',
#  'CCGGGCTAAGAATTTC': 'CL:0000187',
#  'CCGGGCTGCTCCATAC': 'CL:0000187',
#  'CCGGTTTGTAATTGTG': 'CL:0000187',
#  'CCGTAAGTTGGTCCCA': 'CL:0000057',
#  'CCGTATCTCGTCGTAG': 'CL:0000187',
#  'CCGTCAACCTCTGGCG': 'CL:0002320',
#  'CCGTGGAACGATCCAA': 'CL:0002551',
#  'CCGTGTTAAATTCCAT': 'CL:0000187',
#  'CCGTTACGTTAGAACA': 'CL:0002551',
#  'CCGTTTCCTTTCCGTG': 'CL:0000187',
#  'CCTAAAGGCTGACGCT': 'CL:0002543',
#  'CCTAAATTAACGGTTC': 'CL:0000187',
#  'CCTAACCCAAACAAGT': 'CL:0000388',
#  'CCTAACTAAGGCTCTA': 'CL:0002551',
#  'CCTACATTCACAGACG': 'CL:0000187',
#  'CCTAGGCGTAGCGATC': 'CL:0000187',
#  'CCTAGGTAAAGGTAGC': 'CL:0000187',
#  'CCTAGTTAGTCGCATG': 'CL:0000187',
#  'CCTATAATGAGTGCCC': 'CL:0000388',
#  'CCTATACCGTCCTGTC': 'CL:0000187',
#  'CCTATATCGTGTCACG': 'CL:0000388',
#  'CCTATATTTGTCCTGG': 'CL:0000187',
#  'CCTATCTATATCGGAA': 'CL:0000187',
#  'CCTATGGCTCCTAGTG': 'CL:0000187',
#  'CCTATGGGTTACCGTC': 'CL:0000187',
#  'CCTATTATTCCGGCCG': 'CL:0000057',
#  'CCTCAACGATCGCTGT': 'CL:0000187',
#  'CCTCACCTGAGGGAGC': 'CL:0000235',
#  'CCTCACCTTAGCATCG': 'CL:0002551',
#  'CCTCCTAGCTAGAGTC': 'CL:0000187',
#  'CCTCCTGTTGTGTCGT': 'CL:0000388',
#  'CCTCGAAGTGGACGGG': 'CL:0000187',
#  'CCTCGACCCACTGCCT': 'CL:0000057',
#  'CCTCGCCAGCAAATTA': 'CL:0000187',
#  'CCTCGCGCGATATAGG': 'CL:0000057',
#  'CCTCGCGCTGTGCGAT': 'CL:0000388',
#  'CCTCGGACCGGGATAG': 'CL:0000187',
#  'CCTCGGTTTCCTTGCC': 'CL:0000187',
#  'CCTCTAATCTGCCAAG': 'CL:0000187',
#  'CCTCTACAAGGATTGG': 'CL:0000187',
#  'CCTCTATCGATTAGCA': 'CL:0000187',
#  'CCTCTGGCCTAGACGG': 'CL:0000187',
#  'CCTCTGTACTATTCTA': 'CL:0000057',
#  'CCTGAACGATATATTC': 'CL:0000187',
#  'CCTGAATATTTACATA': 'CL:0000187',
#  'CCTGACCACCGATGGT': 'CL:0000187',
#  'CCTGACGCAACCTTTA': 'CL:0002551',
#  'CCTGAGAATAAATGCA': 'CL:0000187',
#  'CCTGGTCGAATGTGGG': 'CL:0000388',
#  'CCTGTCACCCGGGCTC': 'CL:0000187',
#  'CCTGTCGCCCGTAAAT': 'CL:0000187',
#  'CCTGTCGTGTATGAAG': 'CL:0000187',
#  'CCTGTTCAACCTCGGG': 'CL:0002551',
#  'CCTGTTTGAAGACACG': 'CL:0002551',
#  'CCTTCAGTTAAAGTGA': 'CL:0000187',
#  'CCTTCCGCAACGCTGC': 'CL:0000187',
#  'CCTTCGTATAGAATCC': 'CL:0002551',
#  'CCTTCTCAGCGTTCCT': 'CL:0002551',
#  'CCTTCTTGATCCAGTG': 'CL:0000187',
#  'CCTTGTGAACGTGGTT': 'CL:0000187',
#  'CCTTTAAGGGAGCACT': 'CL:0000057',
#  'CCTTTCAATGAAGAAA': 'CL:0002551',
#  'CCTTTGAATTATGGCT': 'CL:0000057',
#  'CGAAACATAGATGGCA': 'CL:0000057',
#  'CGAACAGTATGGGCGT': 'CL:0002551',
#  'CGAACCCGCATGCGTC': 'CL:0000187',
#  'CGAACCTCTTTCCTAG': 'CL:0000187',
#  'CGAACGCCCAGTGCCG': 'CL:0000187',
#  'CGAACGGCCGGACAAC': 'CL:0000057',
#  'CGAAGCCACAGCATGG': 'CL:0000187',
#  'CGAAGGGTTTCAGATT': 'CL:0000187',
#  'CGAATCTGCTCGACGC': 'CL:0000187',
#  'CGAATGAAGTCATTGC': 'CL:0000187',
#  'CGAATGACGCATAATG': 'CL:0000187',
#  'CGAATGGTAGGTCGTC': 'CL:0000187',
#  'CGACAATTTGATCTAA': 'CL:0000388',
#  'CGACACGCTCCGACAG': 'CL:0000388',
#  'CGACCCTTAACGCCGG': 'CL:0000187',
#  'CGACCGTTGGTATTCG': 'CL:0000187',
#  'CGACCTACTAGACAAT': 'CL:0000057',
#  'CGACGCATCCGTACCT': 'CL:0000187',
#  'CGACTCAGGATGTTAT': 'CL:0000388',
#  'CGACTTGCCGGGAAAT': 'CL:0000187',
#  'CGAGACCCTAGAGTGT': 'CL:0000187',
#  'CGAGAGATGTGAACCT': 'CL:0002573',
#  'CGAGAGCGCGTAGATA': 'CL:0002551',
#  'CGAGAGCTTTCACTAC': 'CL:0002551',
#  'CGAGCTGGGCTTTAGG': 'CL:0000187',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               41
# AAACAAGTATCTCCCA-1          1         50        102             1105
# AAACAATCTACTAGCA-1          0          3         43              334
# AAACACCAATAACTGC-1          1         59         19             3162
# AAACAGAGCGACTCCT-1          1         14         94             1286
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             2123
# TTGTTTCATTAGTCTA-1          1         60         30             2722
# TTGTTTCCATACAACT-1          1         45         27             2631
# TTGTTTGTATTACACG-1          1         73         41             1320
# TTGTTTGTGTAAATTC-1          0          7         51              313
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0000388
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                 CL:0000192
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000388
# TTGTTTCATTAGTCTA-1                 CL:0000187
# TTGTTTCCATACAACT-1                 CL:0002551
# TTGTTTGTATTACACG-1                 CL:0000187
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 2452

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_31460/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               41
# AAACAAGTATCTCCCA-1          1         50        102             1105
# AAACAATCTACTAGCA-1          0          3         43              334
# AAACACCAATAACTGC-1          1         59         19             3162
# AAACAGAGCGACTCCT-1          1         14         94             1286
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             2123
# TTGTTTCATTAGTCTA-1          1         60         30             2722
# TTGTTTCCATACAACT-1          1         45         27             2631
# TTGTTTGTATTACACG-1          1         73         41             1320
# TTGTTTGTGTAAATTC-1          0          7         51              313
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0000388
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                 CL:0000192
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0000388
# TTGTTTCATTAGTCTA-1                 CL:0000187
# TTGTTTCCATACAACT-1                 CL:0002551
# TTGTTTGTATTACACG-1                 CL:0000187
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000388',
#  'CL:0000192',
#  'CL:0002551',
#  'CL:0000187',
#  'CL:0000057',
#  'CL:0000669',
#  'CL:0000743',
#  'CL:0000078',
#  'CL:0002320',
#  'CL:0002573',
#  'CL:1001609',
#  'CL:0000138',
#  'CL:0000232',
#  'CL:1001607',
#  'CL:0000646',
#  'CL:0000235',
#  'CL:1000413',
#  'CL:0000558',
#  'CL:0002543',
#  'CL:0000062',
#  'CL:0002355']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    WSSS_THYst9383359
# AAACAAGTATCTCCCA-1    WSSS_THYst9383359
# AAACAATCTACTAGCA-1    WSSS_THYst9383359
# AAACACCAATAACTGC-1    WSSS_THYst9383359
# AAACAGAGCGACTCCT-1    WSSS_THYst9383359
#                             ...
# TTGTTTCACATCCAGG-1    WSSS_THYst9383359
# TTGTTTCATTAGTCTA-1    WSSS_THYst9383359
# TTGTTTCCATACAACT-1    WSSS_THYst9383359
# TTGTTTGTATTACACG-1    WSSS_THYst9383359
# TTGTTTGTGTAAATTC-1    WSSS_THYst9383359
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['WSSS_THYst9383359']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000030']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000030
# AAACAAGTATCTCCCA-1    HsapDv:0000030
# AAACAATCTACTAGCA-1    HsapDv:0000030
# AAACACCAATAACTGC-1    HsapDv:0000030
# AAACAGAGCGACTCCT-1    HsapDv:0000030
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000030
# TTGTTTCATTAGTCTA-1    HsapDv:0000030
# TTGTTTCCATACAACT-1    HsapDv:0000030
# TTGTTTGTATTACACG-1    HsapDv:0000030
# TTGTTTGTGTAAATTC-1    HsapDv:0000030
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000030']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0002103
# AAACAAGTATCTCCCA-1    UBERON:0002103
# AAACAATCTACTAGCA-1    UBERON:0002103
# AAACACCAATAACTGC-1    UBERON:0002103
# AAACAGAGCGACTCCT-1    UBERON:0002103
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0002103
# TTGTTTCATTAGTCTA-1    UBERON:0002103
# TTGTTTCCATACAACT-1    UBERON:0002103
# TTGTTTGTATTACACG-1    UBERON:0002103
# TTGTTTGTGTAAATTC-1    UBERON:0002103
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0002103']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               41
# AAACAAGTATCTCCCA-1          1         50        102             1105
# AAACAATCTACTAGCA-1          0          3         43              334
# AAACACCAATAACTGC-1          1         59         19             3162
# AAACAGAGCGACTCCT-1          1         14         94             1286
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             2123
# TTGTTTCATTAGTCTA-1          1         60         30             2722
# TTGTTTCCATACAACT-1          1         45         27             2631
# TTGTTTGTATTACACG-1          1         73         41             1320
# TTGTTTGTGTAAATTC-1          0          7         51              313
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383359
# AAACAAGTATCTCCCA-1                 CL:0000388  WSSS_THYst9383359
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383359
# AAACACCAATAACTGC-1                 CL:0000192  WSSS_THYst9383359
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9383359
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0000388  WSSS_THYst9383359
# TTGTTTCATTAGTCTA-1                 CL:0000187  WSSS_THYst9383359
# TTGTTTCCATACAACT-1                 CL:0002551  WSSS_THYst9383359
# TTGTTTGTATTACACG-1                 CL:0000187  WSSS_THYst9383359
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383359
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383359': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8),
#                  'lowres': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.01525999999998,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 168.02466,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9383359.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
adata.uns['title']
# Out:
# 'WSSS_THYst9383359'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383359': {'images': {'hires': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8),
#                  'fullres': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.01525999999998,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9383359'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               41
# AAACAAGTATCTCCCA-1          1         50        102             1105
# AAACAATCTACTAGCA-1          0          3         43              334
# AAACACCAATAACTGC-1          1         59         19             3162
# AAACAGAGCGACTCCT-1          1         14         94             1286
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             2123
# TTGTTTCATTAGTCTA-1          1         60         30             2722
# TTGTTTCCATACAACT-1          1         45         27             2631
# TTGTTTGTATTACACG-1          1         73         41             1320
# TTGTTTGTGTAAATTC-1          0          7         51              313
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383359
# AAACAAGTATCTCCCA-1                 CL:0000388  WSSS_THYst9383359
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383359
# AAACACCAATAACTGC-1                 CL:0000192  WSSS_THYst9383359
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9383359
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0000388  WSSS_THYst9383359
# TTGTTTCATTAGTCTA-1                 CL:0000187  WSSS_THYst9383359
# TTGTTTCCATACAACT-1                 CL:0002551  WSSS_THYst9383359
# TTGTTTGTATTACACG-1                 CL:0000187  WSSS_THYst9383359
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383359
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial, X_spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383359': {'images': {'hires': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8),
#                  'fullres': array([[[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         ...,
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]],
#
#                         [[239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          ...,
#                          [239, 243, 242],
#                          [239, 243, 242],
#                          [239, 243, 242]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.01525999999998,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9383359'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide1.h5ad', compression = 'gzip')

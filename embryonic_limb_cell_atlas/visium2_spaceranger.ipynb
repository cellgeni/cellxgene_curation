# %% [markdown]
# ### **Curating visium_slide2.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9383360/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 1

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 30

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 4541563 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 238)	1.0
#   (0, 372)	1.0
#   (0, 1933)	1.0
#   (0, 2049)	1.0
#   (0, 3683)	1.0
#   (0, 4204)	3.0
#   (0, 4688)	1.0
#   (0, 4848)	1.0
#   (0, 4853)	1.0
#   (0, 4884)	1.0
#   (0, 5533)	1.0
#   (0, 5929)	1.0
#   (0, 5966)	1.0
#   (0, 5984)	1.0
#   (0, 6239)	1.0
#   (0, 7477)	2.0
#   (0, 9818)	1.0
#   (0, 10736)	1.0
#   (0, 10764)	1.0
#   (0, 10780)	1.0
#   (0, 11106)	1.0
#   (0, 11444)	1.0
#   (0, 11571)	1.0
#   (0, 12538)	1.0
#   (0, 13503)	1.0
#   :	:
#   (4991, 31383)	1.0
#   (4991, 31453)	1.0
#   (4991, 31516)	1.0
#   (4991, 31567)	1.0
#   (4991, 31704)	1.0
#   (4991, 31763)	2.0
#   (4991, 31775)	1.0
#   (4991, 31978)	1.0
#   (4991, 32042)	3.0
#   (4991, 32169)	1.0
#   (4991, 32176)	1.0
#   (4991, 32244)	1.0
#   (4991, 32346)	1.0
#   (4991, 32395)	1.0
#   (4991, 32578)	1.0
#   (4991, 32586)	1.0
#   (4991, 32589)	1.0
#   (4991, 32824)	1.0
#   (4991, 32919)	2.0
#   (4991, 33027)	1.0
#   (4991, 33041)	1.0
#   (4991, 33405)	1.0
#   (4991, 33601)	1.0
#   (4991, 33657)	1.0
#   (4991, 33664)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16               71
# AAACAAGTATCTCCCA-1          1         50        102             2350
# AAACAATCTACTAGCA-1          0          3         43              228
# AAACACCAATAACTGC-1          1         59         19             1017
# AAACAGAGCGACTCCT-1          0         14         94              144
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42              725
# TTGTTTCATTAGTCTA-1          1         60         30             1182
# TTGTTTCCATACAACT-1          1         45         27             2710
# TTGTTTGTATTACACG-1          0         73         41              100
# TTGTTTGTGTAAATTC-1          0          7         51              234
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide2.h5ad')

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360          1           0.0        6.548307
# AAACACCAATAACTGC-1_WSSS_THYst9383360          1           0.0        0.119246
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360          1           0.0        0.402854
# AAACAGGGTCTATATT-1_WSSS_THYst9383360          1           0.0        0.070164
# AAACATTTCCCGGATT-1_WSSS_THYst9383360          1           0.0        0.162862
# ...                                         ...           ...             ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360          1           0.0        0.024860
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360          1           0.0        0.617047
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360          1           0.0        0.018615
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360          1           0.0        0.044075
# TTGTTTCCATACAACT-1_WSSS_THYst9383360          1           0.0        0.010216
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360        0.005808           0.138850
# AAACACCAATAACTGC-1_WSSS_THYst9383360        0.005342           0.031597
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360        0.009738           1.943078
# AAACAGGGTCTATATT-1_WSSS_THYst9383360        0.008997           0.284592
# AAACATTTCCCGGATT-1_WSSS_THYst9383360        0.009000           0.231454
# ...                                              ...                ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360        0.002435           0.106524
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360        0.001439           0.002415
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360        0.001640           0.130623
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360        0.003774           0.203104
# TTGTTTCCATACAACT-1_WSSS_THYst9383360        0.001886           0.010634
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360       0.034429  0.005005    0.002333
# AAACACCAATAACTGC-1_WSSS_THYst9383360       0.104752  0.010040    0.004520
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360       0.188333  0.034766    0.004882
# AAACAGGGTCTATATT-1_WSSS_THYst9383360       0.138955  0.013428    0.009297
# AAACATTTCCCGGATT-1_WSSS_THYst9383360       0.064118  0.007672    0.006763
# ...                                             ...       ...         ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360       6.962591  0.011452    0.004669
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360       0.008679  0.001534    0.001256
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360       0.049475  0.004636    0.002057
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360       0.080793  0.008770    0.003824
# TTGTTTCCATACAACT-1_WSSS_THYst9383360       4.129546  0.016808    0.001528
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360      0.009136          0.007212  ...
# AAACACCAATAACTGC-1_WSSS_THYst9383360      0.011682          0.055065  ...
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360      0.072537          0.047057  ...
# AAACAGGGTCTATATT-1_WSSS_THYst9383360      0.025078          0.039985  ...
# AAACATTTCCCGGATT-1_WSSS_THYst9383360      0.011847          0.014587  ...
# ...                                            ...               ...  ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360      0.010737          0.044842  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360      0.003565          0.005324  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360      0.004665          0.011369  ...
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360      0.008986          0.018817  ...
# TTGTTTCCATACAACT-1_WSSS_THYst9383360      0.009474          1.900827  ...
#
#                                        stage  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360  PCW8.1
# AAACACCAATAACTGC-1_WSSS_THYst9383360  PCW8.1
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360  PCW8.1
# AAACAGGGTCTATATT-1_WSSS_THYst9383360  PCW8.1
# AAACATTTCCCGGATT-1_WSSS_THYst9383360  PCW8.1
# ...                                      ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360  PCW8.1
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360  PCW8.1
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360  PCW8.1
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360  PCW8.1
# TTGTTTCCATACAACT-1_WSSS_THYst9383360  PCW8.1
#
#                                       development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACACCAATAACTGC-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACAGGGTCTATATT-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACATTTCCCGGATT-1_WSSS_THYst9383360                      HsapDv:0000030
# ...                                                                  ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCCATACAACT-1_WSSS_THYst9383360                      HsapDv:0000030
#
#                                       disease_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360              PATO:0000461
# AAACACCAATAACTGC-1_WSSS_THYst9383360              PATO:0000461
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360              PATO:0000461
# AAACAGGGTCTATATT-1_WSSS_THYst9383360              PATO:0000461
# AAACATTTCCCGGATT-1_WSSS_THYst9383360              PATO:0000461
# ...                                                        ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCCATACAACT-1_WSSS_THYst9383360              PATO:0000461
#
#                                       is_primary_data  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360             True
# AAACACCAATAACTGC-1_WSSS_THYst9383360             True
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360             True
# AAACAGGGTCTATATT-1_WSSS_THYst9383360             True
# AAACATTTCCCGGATT-1_WSSS_THYst9383360             True
# ...                                               ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360             True
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360             True
# TTGTTTCCATACAACT-1_WSSS_THYst9383360             True
#
#                                       organism_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACACCAATAACTGC-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACAGGGTCTATATT-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACATTTCCCGGATT-1_WSSS_THYst9383360             NCBITaxon:9606
# ...                                                         ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCCATACAACT-1_WSSS_THYst9383360             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360                                   unknown
# AAACACCAATAACTGC-1_WSSS_THYst9383360                                   unknown
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360                                   unknown
# AAACAGGGTCTATATT-1_WSSS_THYst9383360                                   unknown
# AAACATTTCCCGGATT-1_WSSS_THYst9383360                                   unknown
# ...                                                                        ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360                                   unknown
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360                                   unknown
# TTGTTTCCATACAACT-1_WSSS_THYst9383360                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360          PATO:0000384               na
# AAACACCAATAACTGC-1_WSSS_THYst9383360          PATO:0000384               na
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360          PATO:0000384               na
# AAACAGGGTCTATATT-1_WSSS_THYst9383360          PATO:0000384               na
# AAACATTTCCCGGATT-1_WSSS_THYst9383360          PATO:0000384               na
# ...                                                    ...              ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCCATACAACT-1_WSSS_THYst9383360          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACACCAATAACTGC-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACAGGGTCTATATT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACATTTCCCGGATT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCCATACAACT-1_WSSS_THYst9383360       tissue           UBERON:0000978
#
# [2796 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360          1           0.0        6.548307
# AAACACCAATAACTGC-1_WSSS_THYst9383360          1           0.0        0.119246
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360          1           0.0        0.402854
# AAACAGGGTCTATATT-1_WSSS_THYst9383360          1           0.0        0.070164
# AAACATTTCCCGGATT-1_WSSS_THYst9383360          1           0.0        0.162862
# ...                                         ...           ...             ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360          1           0.0        0.024860
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360          1           0.0        0.617047
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360          1           0.0        0.018615
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360          1           0.0        0.044075
# TTGTTTCCATACAACT-1_WSSS_THYst9383360          1           0.0        0.010216
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360        0.005808           0.138850
# AAACACCAATAACTGC-1_WSSS_THYst9383360        0.005342           0.031597
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360        0.009738           1.943078
# AAACAGGGTCTATATT-1_WSSS_THYst9383360        0.008997           0.284592
# AAACATTTCCCGGATT-1_WSSS_THYst9383360        0.009000           0.231454
# ...                                              ...                ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360        0.002435           0.106524
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360        0.001439           0.002415
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360        0.001640           0.130623
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360        0.003774           0.203104
# TTGTTTCCATACAACT-1_WSSS_THYst9383360        0.001886           0.010634
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360       0.034429  0.005005    0.002333
# AAACACCAATAACTGC-1_WSSS_THYst9383360       0.104752  0.010040    0.004520
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360       0.188333  0.034766    0.004882
# AAACAGGGTCTATATT-1_WSSS_THYst9383360       0.138955  0.013428    0.009297
# AAACATTTCCCGGATT-1_WSSS_THYst9383360       0.064118  0.007672    0.006763
# ...                                             ...       ...         ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360       6.962591  0.011452    0.004669
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360       0.008679  0.001534    0.001256
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360       0.049475  0.004636    0.002057
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360       0.080793  0.008770    0.003824
# TTGTTTCCATACAACT-1_WSSS_THYst9383360       4.129546  0.016808    0.001528
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360      0.009136          0.007212  ...
# AAACACCAATAACTGC-1_WSSS_THYst9383360      0.011682          0.055065  ...
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360      0.072537          0.047057  ...
# AAACAGGGTCTATATT-1_WSSS_THYst9383360      0.025078          0.039985  ...
# AAACATTTCCCGGATT-1_WSSS_THYst9383360      0.011847          0.014587  ...
# ...                                            ...               ...  ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360      0.010737          0.044842  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360      0.003565          0.005324  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360      0.004665          0.011369  ...
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360      0.008986          0.018817  ...
# TTGTTTCCATACAACT-1_WSSS_THYst9383360      0.009474          1.900827  ...
#
#                                       development_stage_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACACCAATAACTGC-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACAGGGTCTATATT-1_WSSS_THYst9383360                      HsapDv:0000030
# AAACATTTCCCGGATT-1_WSSS_THYst9383360                      HsapDv:0000030
# ...                                                                  ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360                      HsapDv:0000030
# TTGTTTCCATACAACT-1_WSSS_THYst9383360                      HsapDv:0000030
#
#                                       disease_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360              PATO:0000461
# AAACACCAATAACTGC-1_WSSS_THYst9383360              PATO:0000461
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360              PATO:0000461
# AAACAGGGTCTATATT-1_WSSS_THYst9383360              PATO:0000461
# AAACATTTCCCGGATT-1_WSSS_THYst9383360              PATO:0000461
# ...                                                        ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360              PATO:0000461
# TTGTTTCCATACAACT-1_WSSS_THYst9383360              PATO:0000461
#
#                                       is_primary_data  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360             True
# AAACACCAATAACTGC-1_WSSS_THYst9383360             True
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360             True
# AAACAGGGTCTATATT-1_WSSS_THYst9383360             True
# AAACATTTCCCGGATT-1_WSSS_THYst9383360             True
# ...                                               ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360             True
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360             True
# TTGTTTCCATACAACT-1_WSSS_THYst9383360             True
#
#                                       organism_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACACCAATAACTGC-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACAGGGTCTATATT-1_WSSS_THYst9383360             NCBITaxon:9606
# AAACATTTCCCGGATT-1_WSSS_THYst9383360             NCBITaxon:9606
# ...                                                         ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360             NCBITaxon:9606
# TTGTTTCCATACAACT-1_WSSS_THYst9383360             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360                                   unknown
# AAACACCAATAACTGC-1_WSSS_THYst9383360                                   unknown
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360                                   unknown
# AAACAGGGTCTATATT-1_WSSS_THYst9383360                                   unknown
# AAACATTTCCCGGATT-1_WSSS_THYst9383360                                   unknown
# ...                                                                        ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360                                   unknown
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360                                   unknown
# TTGTTTCCATACAACT-1_WSSS_THYst9383360                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360          PATO:0000384               na
# AAACACCAATAACTGC-1_WSSS_THYst9383360          PATO:0000384               na
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360          PATO:0000384               na
# AAACAGGGTCTATATT-1_WSSS_THYst9383360          PATO:0000384               na
# AAACATTTCCCGGATT-1_WSSS_THYst9383360          PATO:0000384               na
# ...                                                    ...              ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360          PATO:0000384               na
# TTGTTTCCATACAACT-1_WSSS_THYst9383360          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id  \
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACACCAATAACTGC-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACAGGGTCTATATT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# AAACATTTCCCGGATT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360       tissue           UBERON:0000978
# TTGTTTCCATACAACT-1_WSSS_THYst9383360       tissue           UBERON:0000978
#
#                                               barcodes
# AAACAAGTATCTCCCA-1_WSSS_THYst9383360  AAACAAGTATCTCCCA
# AAACACCAATAACTGC-1_WSSS_THYst9383360  AAACACCAATAACTGC
# AAACAGCTTTCAGAAG-1_WSSS_THYst9383360  AAACAGCTTTCAGAAG
# AAACAGGGTCTATATT-1_WSSS_THYst9383360  AAACAGGGTCTATATT
# AAACATTTCCCGGATT-1_WSSS_THYst9383360  AAACATTTCCCGGATT
# ...                                                ...
# TTGTTCTAGATACGCT-1_WSSS_THYst9383360  TTGTTCTAGATACGCT
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9383360  TTGTTGTGTGTCAAGA
# TTGTTTCACATCCAGG-1_WSSS_THYst9383360  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1_WSSS_THYst9383360  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1_WSSS_THYst9383360  TTGTTTCCATACAACT
#
# [2796 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAAGTATCTCCCA': 'CL:0000187',
#  'AAACACCAATAACTGC': 'CL:0002551',
#  'AAACAGCTTTCAGAAG': 'CL:0000057',
#  'AAACAGGGTCTATATT': 'CL:0000057',
#  'AAACATTTCCCGGATT': 'CL:0002551',
#  'AAACCCGAACGAAATC': 'CL:0000187',
#  'AAACCGGAAATGTTAA': 'CL:0000187',
#  'AAACCGGGTAGGTACC': 'CL:0000057',
#  'AAACCGTTCGTCCAGG': 'CL:0000057',
#  'AAACCTAAGCAGCCGG': 'CL:0002551',
#  'AAACCTCATGAAGTTG': 'CL:0000558',
#  'AAACGAAGATGGAGTA': 'CL:0000057',
#  'AAACGAGACGGTTGAT': 'CL:0000187',
#  'AAACGGGCGTACGGGT': 'CL:0000187',
#  'AAACTGCTGGCTCCAA': 'CL:0000388',
#  'AAACTTGCAAACGTAT': 'CL:0000057',
#  'AAAGACCCAAGTCGCG': 'CL:0000646',
#  'AAAGACTGGGCGCTTT': 'CL:0000187',
#  'AAAGGCCCTATAATAC': 'CL:0002551',
#  'AAAGGCTCTCGCGCCG': 'CL:0000187',
#  'AAAGGGATGTAGCAAG': 'CL:0002551',
#  'AAAGGGCAGCTTGAAT': 'CL:0000057',
#  'AAAGTAGCATTGCTCA': 'CL:0000187',
#  'AAAGTCGACCCTCAGT': 'CL:0000057',
#  'AAAGTGTGATTTATCT': 'CL:0000187',
#  'AAAGTTGACTCCCGTA': 'CL:0000057',
#  'AAATAAGGTAGTGCCC': 'CL:0002551',
#  'AAATACCTATAAGCAT': 'CL:0000388',
#  'AAATAGCTTAGACTTT': 'CL:0000187',
#  'AAATAGGGTGCTATTG': 'CL:0000187',
#  'AAATCCGATACACGCC': 'CL:0002551',
#  'AAATCGCGGAAGGAGT': 'CL:0000057',
#  'AAATCGTGTACCACAA': 'CL:0000187',
#  'AAATCTAGCCCTGCTA': 'CL:0000187',
#  'AAATGCTCGTTACGTT': 'CL:0000057',
#  'AAATGGCCCGTGCCCT': 'CL:0000057',
#  'AAATGGTCAATGTGCC': 'CL:0002573',
#  'AAATGTATCTTATCCC': 'CL:0000057',
#  'AAATTAACGGGTAGCT': 'CL:0000187',
#  'AAATTAATAAGCGCGA': 'CL:0000057',
#  'AAATTACCTATCGATG': 'CL:0002551',
#  'AAATTCCAGGTCCAAA': 'CL:0000057',
#  'AAATTGATAGTCCTTT': 'CL:0000187',
#  'AAATTTGCGGGTGTGG': 'CL:0000138',
#  'AACAACTGGTAGTTGC': 'CL:0000057',
#  'AACAATACATTGTCGA': 'CL:0002551',
#  'AACAATTACTCTACGC': 'CL:0000057',
#  'AACACACGCTCGCCGC': 'CL:0000187',
#  'AACACGAGACGCGGCC': 'CL:0000057',
#  'AACAGCTGTGTGGCAA': 'CL:0002551',
#  'AACAGGATGGGCCGCG': 'CL:0000057',
#  'AACAGGTAGTATGGAT': 'CL:0000187',
#  'AACCAAGACTTCTCTG': 'CL:0000057',
#  'AACCATGGGATCGCTA': 'CL:0000057',
#  'AACCCAGAGACGGAGA': 'CL:0000057',
#  'AACCCATCCCATGATC': 'CL:0000057',
#  'AACCCGAGCAGAATCG': 'CL:0000187',
#  'AACCCTACTGTCAATA': 'CL:0000187',
#  'AACCGAGCTTGGTCAT': 'CL:0002551',
#  'AACCGCTAAGGGATGC': 'CL:0000057',
#  'AACCTCGCTTTAGCCC': 'CL:0002551',
#  'AACCTGTCACGGAATT': 'CL:0002551',
#  'AACCTTTAAATACGGT': 'CL:0000187',
#  'AACGAAAGTCGTCCCA': 'CL:0000057',
#  'AACGATAATGCCGTAG': 'CL:0000187',
#  'AACGATAGAAGGGCCG': 'CL:0000078',
#  'AACGCGGTCTCCAGCC': 'CL:0002551',
#  'AACGCTGTTGCTGAAA': 'CL:0000187',
#  'AACGGACGTACGTATA': 'CL:0000187',
#  'AACGGCCATCTCCGGT': 'CL:0000138',
#  'AACGTACTGTGGGTAC': 'CL:0002551',
#  'AACGTCAGACTAGTGG': 'CL:0000057',
#  'AACGTGCGAAAGTCTC': 'CL:0000187',
#  'AACGTTATCAGCACCT': 'CL:0000057',
#  'AACGTTCTACCATTGT': 'CL:0000388',
#  'AACTACCCGTTTGTCA': 'CL:0000057',
#  'AACTAGGCTTGGGTGT': 'CL:0000388',
#  'AACTCAAGTTAATTGC': 'CL:0002573',
#  'AACTCCAGAGCGTGTT': 'CL:0000187',
#  'AACTCTCAATAGAGCG': 'CL:0000187',
#  'AACTCTCAGTGTGCTC': 'CL:0000057',
#  'AACTGAGTTATACTGA': 'CL:0000057',
#  'AACTGGGTCCCGACGT': 'CL:0002551',
#  'AACTTCTGCGTCTATC': 'CL:0000057',
#  'AACTTGCCCGTATGCA': 'CL:0000057',
#  'AACTTGCGTTCTCGCG': 'CL:0000057',
#  'AACTTTACGGGAGCTT': 'CL:0000138',
#  'AAGAAGGATCAGTTAG': 'CL:0000187',
#  'AAGACCCAACTGAACA': 'CL:0002551',
#  'AAGACTGCAAGCTACT': 'CL:0000187',
#  'AAGAGATGAATCGGTA': 'CL:0000057',
#  'AAGAGCTCTTTATCGG': 'CL:0000187',
#  'AAGAGGATGTACGCGA': 'CL:0002573',
#  'AAGAGGCATGGATCGC': 'CL:0000187',
#  'AAGAGGCCCTTTGGAA': 'CL:0002551',
#  'AAGATGGCACCGGACC': 'CL:0002551',
#  'AAGCACCCTGCGTATC': 'CL:0000187',
#  'AAGCATACTCTCCTGA': 'CL:0000187',
#  'AAGCCGAAGCGGTTTA': 'CL:0000187',
#  'AAGCCGCCGTGAAATC': 'CL:0002551',
#  'AAGCGTCCCTCATCGA': 'CL:0000057',
#  'AAGCTAGATCGAGTAA': 'CL:0000187',
#  'AAGCTCGTGCCAAGTC': 'CL:0000187',
#  'AAGCTCTTTCATGGTG': 'CL:0000187',
#  'AAGGAGCGGTTGGTGC': 'CL:0000187',
#  'AAGGATCGATCGCTTG': 'CL:0000187',
#  'AAGGCAGGCTGTCTCC': 'CL:0000187',
#  'AAGGCGCGTAAAGCTT': 'CL:0002551',
#  'AAGGCTGTGCTCATCG': 'CL:0000057',
#  'AAGGGAACGACTGGCT': 'CL:0002551',
#  'AAGGGACTATGCATTC': 'CL:0002551',
#  'AAGGGTTAGCCATGCG': 'CL:0000388',
#  'AAGGGTTTGATTTCAG': 'CL:0002551',
#  'AAGGTGATAAACCAGC': 'CL:0000187',
#  'AAGTAGAAGACCGGGT': 'CL:0002551',
#  'AAGTAGTGACGCGAGG': 'CL:0000057',
#  'AAGTCAATTGTCGTCA': 'CL:0000187',
#  'AAGTCTTCTGTGGCCT': 'CL:0000057',
#  'AAGTGACGACCGAATT': 'CL:0000057',
#  'AAGTGCAAAGGTAGAC': 'CL:0000057',
#  'AAGTGCCTTGACTGTA': 'CL:0000187',
#  'AAGTGCGTTAGAATCT': 'CL:0000057',
#  'AAGTGTTTGGAGACGG': 'CL:0000187',
#  'AAGTTCACTCCAAGCT': 'CL:0000187',
#  'AAGTTCGGCCAACAGG': 'CL:0000138',
#  'AATAACAACGCTCGGC': 'CL:0002551',
#  'AATAACACTAGAACAA': 'CL:0000388',
#  'AATAACGTCGCGCCCA': 'CL:0002551',
#  'AATAATCTTCGTATCG': 'CL:0000187',
#  'AATACAATGTTTCAGG': 'CL:0000388',
#  'AATAGAACAGAGTGGC': 'CL:0000388',
#  'AATAGAATCTGTTTCA': 'CL:0000187',
#  'AATAGTCCGTCCCGAC': 'CL:0000057',
#  'AATAGTCGCGAGTCGG': 'CL:0000057',
#  'AATATCCTAGCAAACT': 'CL:0000057',
#  'AATATCGAATCAATGC': 'CL:0000187',
#  'AATATTGGAGTATTGA': 'CL:0000057',
#  'AATCATGTAAAGACTC': 'CL:0000187',
#  'AATCCAAGGGCCTGAG': 'CL:0002551',
#  'AATCGCCTCAGCGCCA': 'CL:0000057',
#  'AATCGCGCAGAGGACT': 'CL:0000187',
#  'AATCTAGGTTTACTTG': 'CL:0000057',
#  'AATCTCTACTGTGGTT': 'CL:0000057',
#  'AATCTGCGTTGGGACG': 'CL:0000057',
#  'AATCTGGCTTTCTAGT': 'CL:0000057',
#  'AATGACAGCAATGTCT': 'CL:0000057',
#  'AATGACGTAGGATGTC': 'CL:0000057',
#  'AATGACTGTCAGCCGG': 'CL:0002551',
#  'AATGAGTTCGCATATG': 'CL:0000057',
#  'AATGCAACCGGGTACC': 'CL:0002551',
#  'AATGGTCCACCGTTCA': 'CL:0000187',
#  'AATGGTTCTCACAAGC': 'CL:0002551',
#  'AATGTGCCCGAGGTGT': 'CL:0000187',
#  'AATGTGCTAATCTGAG': 'CL:0000187',
#  'AATTAAAGGTCGGCGT': 'CL:0000388',
#  'AATTAACGGATTTCCA': 'CL:0000057',
#  'AATTACGAGACCCATC': 'CL:0002551',
#  'AATTAGCGCTGCAGCG': 'CL:0000187',
#  'AATTCTAGAGTTAGGC': 'CL:0000388',
#  'AATTGAACGCTCTGGT': 'CL:0002320',
#  'ACAAACCATGCGTCCT': 'CL:0002551',
#  'ACAAAGAAGGTAGGCC': 'CL:0000057',
#  'ACAAAGCATGACCTAG': 'CL:0002551',
#  'ACAAATCGCACCGAAT': 'CL:0000057',
#  'ACAAATGGTAGTGTTT': 'CL:0000187',
#  'ACAACAGCATGAGCTA': 'CL:0000187',
#  'ACAACGGTCCCTGCGA': 'CL:0000057',
#  'ACAAGCAGTGCCTAGC': 'CL:0000057',
#  'ACAAGCTATATGGAAG': 'CL:0000057',
#  'ACAAGGAAATCCGCCC': 'CL:0000388',
#  'ACAAGGACAAGAGGTT': 'CL:0000057',
#  'ACAAGGATGCTTTAGG': 'CL:0000057',
#  'ACAAGGGCAGGCTCTG': 'CL:0000057',
#  'ACAATAGTCGTACGTT': 'CL:1000413',
#  'ACAATCCATTTAAACC': 'CL:0000057',
#  'ACAATGAATACGGAGA': 'CL:0002551',
#  'ACAATTGTGTCTCTTT': 'CL:0000187',
#  'ACAATTTAGGAGGCTC': 'CL:0002551',
#  'ACAATTTGGCCATATT': 'CL:0000187',
#  'ACACAAAGACGGGTGG': 'CL:0002551',
#  'ACACACCAGGACCAGT': 'CL:0000187',
#  'ACACATGATCAAATCT': 'CL:0002551',
#  'ACACCACATAATTAGC': 'CL:0002551',
#  'ACACCCAGCATGCAGC': 'CL:0000057',
#  'ACACCCGAGAAATCCG': 'CL:0000057',
#  'ACACCGAGCGCTCTTT': 'CL:0002551',
#  'ACACCGGTCTGACCGC': 'CL:0000388',
#  'ACACCTTAAGTAGGGC': 'CL:0000235',
#  'ACACCTTACTACTTGC': 'CL:0000187',
#  'ACACGAGACTCCTTCT': 'CL:0000187',
#  'ACACGGGAACTTAGGG': 'CL:0002551',
#  'ACACGTAGGCCACAAG': 'CL:0000187',
#  'ACACTCCAATGTCACT': 'CL:0002551',
#  'ACACTGATCAAGGTGT': 'CL:1000413',
#  'ACACTGGGACAGTCGT': 'CL:0002551',
#  'ACAGAACTGAGAACAA': 'CL:0000187',
#  'ACAGCGACATTCTCAT': 'CL:0000187',
#  'ACAGGCTTGCCCGACT': 'CL:0000187',
#  'ACAGGTGGAGGTGAGG': 'CL:0000388',
#  'ACAGGTGTGTTGTTGC': 'CL:0002551',
#  'ACAGTAATACAACTTG': 'CL:0000057',
#  'ACATAAGTCGTGGTGA': 'CL:0000057',
#  'ACATAATAAGGCGGTG': 'CL:0000646',
#  'ACATCAGCTGGGACGC': 'CL:0000057',
#  'ACATCCCGGCCATACG': 'CL:0000187',
#  'ACATCCTGGTAACTGT': 'CL:0000057',
#  'ACATCGATCGTTTACC': 'CL:0000388',
#  'ACATCGGTCAGCCGCG': 'CL:0000057',
#  'ACATCGTATGCAATGG': 'CL:0008019',
#  'ACATGGCGCCAAAGTA': 'CL:0000187',
#  'ACATTAGTTTATATCC': 'CL:0000187',
#  'ACCAACGCTTATTTAT': 'CL:0000057',
#  'ACCAAGAACGCGTGTC': 'CL:0002551',
#  'ACCAATATGCAAGTTA': 'CL:0000187',
#  'ACCACAAGTTTCTATC': 'CL:0000187',
#  'ACCACCAATGTAACAA': 'CL:0000187',
#  'ACCACGTGCAGCTATA': 'CL:0000388',
#  'ACCACTGTTCAAGAAG': 'CL:0000138',
#  'ACCAGACCATAACAAC': 'CL:0000057',
#  'ACCAGTGCGGGAGACG': 'CL:0000187',
#  'ACCATATCCGCAATAA': 'CL:0000057',
#  'ACCATCCGCCAACTAG': 'CL:0000192',
#  'ACCATCGTATATGGTA': 'CL:0000187',
#  'ACCATTAAGGGTGTCA': 'CL:0000187',
#  'ACCCAACGCCCGTGGC': 'CL:0002551',
#  'ACCCACCTACATGCTC': 'CL:0000187',
#  'ACCCATCTTGAGGGTA': 'CL:0002573',
#  'ACCCATTTGTCCCTCT': 'CL:0002551',
#  'ACCCGAGCGAAATTAC': 'CL:0002551',
#  'ACCCGGAAACTCCCAG': 'CL:0000388',
#  'ACCCGGATGACGCATC': 'CL:0000187',
#  'ACCCGGTTACACTTCC': 'CL:0002551',
#  'ACCCGTGTCATCAGTA': 'CL:0002551',
#  'ACCCTATAGGACTGAG': 'CL:0000057',
#  'ACCCTATGCCATATCG': 'CL:0000057',
#  'ACCCTCCCTTGCTATT': 'CL:0000187',
#  'ACCGAAGAGTCTGGTT': 'CL:0000057',
#  'ACCGACACATCTCCCA': 'CL:0002551',
#  'ACCGACTGAGTCCCAC': 'CL:0000057',
#  'ACCGATATTTAATCAT': 'CL:0000187',
#  'ACCGATGGTAGCATCG': 'CL:0000057',
#  'ACCGCAATAACTGCCT': 'CL:0000187',
#  'ACCGCGGTGGAAGTCG': 'CL:0000187',
#  'ACCGGGCCTTTGTTGA': 'CL:0000187',
#  'ACCGGTCAGGTACACC': 'CL:0002551',
#  'ACCGTGACCACGTGGG': 'CL:0002551',
#  'ACCTAAGTACCTTTCA': 'CL:0000388',
#  'ACCTAATCGACTTCCT': 'CL:0000057',
#  'ACCTACAGTATGTGGT': 'CL:0000187',
#  'ACCTCCGCCCTCGCTG': 'CL:0000187',
#  'ACCTCCGTTATTCACC': 'CL:0002551',
#  'ACCTGCGTGTCATGTT': 'CL:0000057',
#  'ACGAAATGGGCGGCAC': 'CL:0000057',
#  'ACGACTGGTCATACTC': 'CL:0000646',
#  'ACGAGGATACCACTCT': 'CL:0000057',
#  'ACGAGGTTTACAACGT': 'CL:0000057',
#  'ACGATACCTATCCTGA': 'CL:0000388',
#  'ACGATCATACATAGAG': 'CL:0002551',
#  'ACGATCATCTTGTAAA': 'CL:0000187',
#  'ACGATGCATATGTTAT': 'CL:0002573',
#  'ACGCATACGTTTACTA': 'CL:0000187',
#  'ACGCATTCGTGAGTAC': 'CL:0000187',
#  'ACGCCGCTAGACGACC': 'CL:0000057',
#  'ACGCGAAGTCAGACGA': 'CL:0000057',
#  'ACGCGCTACACAGGGT': 'CL:0000057',
#  'ACGCGGGCCAAGGACA': 'CL:0000187',
#  'ACGCGTTTCTTAAGAG': 'CL:0000057',
#  'ACGCTACTGAATGGGC': 'CL:0002551',
#  'ACGCTGTGAGGCGTAG': 'CL:0000558',
#  'ACGGAATTTAGCAAAT': 'CL:0000187',
#  'ACGGACTCTCAAAGCG': 'CL:0002551',
#  'ACGGATGGTGCGGATA': 'CL:0000187',
#  'ACGGCACTTGCTTGGG': 'CL:0000187',
#  'ACGGCCAACATGGACT': 'CL:0000187',
#  'ACGGCGACGATGGGAA': 'CL:0000057',
#  'ACGGCTGGATGTAGAA': 'CL:0002551',
#  'ACGGGAGTGTCGGCCC': 'CL:0000388',
#  'ACGGGTCATGTGACTT': 'CL:0000540',
#  'ACGTAGATTGCTGATG': 'CL:0000187',
#  'ACGTATTACTCCGATC': 'CL:0000187',
#  'ACGTCTCGTTCCGGGA': 'CL:1000413',
#  'ACGTGACAAAGTAAGT': 'CL:0000057',
#  'ACGTGCGCCTCGTGCA': 'CL:0002551',
#  'ACGTTAATGTCGAAGA': 'CL:0000057',
#  'ACGTTAGATTTGCCCG': 'CL:0000057',
#  'ACGTTATTGGTCACTC': 'CL:0000057',
#  'ACGTTCGCAATCAATT': 'CL:0002551',
#  'ACGTTCGTTCAGGAAA': 'CL:0002551',
#  'ACGTTTCGGTGCACTT': 'CL:0000388',
#  'ACTACATCCCGACAAG': 'CL:0002551',
#  'ACTACCAGCTCTCTGG': 'CL:0000057',
#  'ACTACGCGTTAGAATT': 'CL:0002551',
#  'ACTAGTTGCGATCGTC': 'CL:0000187',
#  'ACTATCCAGGGCATGG': 'CL:0000187',
#  'ACTATCGCCGGCTAAA': 'CL:0000138',
#  'ACTATCTGCCCGCGTA': 'CL:0000187',
#  'ACTATGTCCAGCTGCC': 'CL:0002551',
#  'ACTATTTCCGGGCCCA': 'CL:0002551',
#  'ACTCAAGTGCAAGGCT': 'CL:0000187',
#  'ACTCAATAAAGGCACG': 'CL:0002551',
#  'ACTCCAATATCATCAT': 'CL:0002551',
#  'ACTCCCATTCCTAAAG': 'CL:0000057',
#  'ACTCCCTAATGCTAAA': 'CL:0000187',
#  'ACTCCCTAGAATAGTA': 'CL:0000388',
#  'ACTCGATGTATTTCAT': 'CL:0000057',
#  'ACTCGCGATCTGACGC': 'CL:0000187',
#  'ACTCGTAACCCGTCCT': 'CL:0000187',
#  'ACTCGTCAGTAATCCC': 'CL:0000187',
#  'ACTCTAAACCTGGGAT': 'CL:0000057',
#  'ACTCTCTGACTTAGGT': 'CL:0000057',
#  'ACTCTTCAGCTCCCGC': 'CL:0002551',
#  'ACTCTTGTATAGTAAC': 'CL:0000187',
#  'ACTGAAACGCCGTTAG': 'CL:0000187',
#  'ACTGAATGGCGAAAGT': 'CL:1000413',
#  'ACTGCGGACACACCGT': 'CL:1000413',
#  'ACTGCTCGGAAGGATG': 'CL:0000558',
#  'ACTGTACGATACACAT': 'CL:0000057',
#  'ACTGTAGCACTTTGGA': 'CL:0000057',
#  'ACTGTCCAGGATTATA': 'CL:0002573',
#  'ACTGTCTTCTTTAGAA': 'CL:0000057',
#  'ACTGTGCTAGTAGATC': 'CL:0000057',
#  'ACTTACGCATCCACGC': 'CL:0000187',
#  'ACTTAGTACGACAAGA': 'CL:0000057',
#  'ACTTATACTTACCCGG': 'CL:0000187',
#  'ACTTATTAGGATCGGT': 'CL:0000057',
#  'ACTTATTTATGTGCCA': 'CL:1000413',
#  'ACTTCAGGCTGATCCC': 'CL:0000187',
#  'ACTTCCAGTGGAAGCT': 'CL:0002551',
#  'ACTTCCATGCGGGACA': 'CL:0000187',
#  'ACTTCGCCATACGCAC': 'CL:0002551',
#  'ACTTCGCTAGCGAGTG': 'CL:0000187',
#  'ACTTGACTCCCTCTTT': 'CL:0000057',
#  'ACTTGGGACCCGGTGG': 'CL:0000187',
#  'ACTTGTAGTCCCTTCA': 'CL:0000669',
#  'ACTTGTGGATGGAACG': 'CL:0000187',
#  'ACTTTCCTATAGCTTC': 'CL:0000057',
#  'ACTTTGACTGCATCCT': 'CL:0000057',
#  'ACTTTGGTCGTGCTCC': 'CL:0002551',
#  'ACTTTGTCGACGCACT': 'CL:0000187',
#  'AGAAATTATGACTCGC': 'CL:0000187',
#  'AGAACCCAGCGTGACA': 'CL:0000187',
#  'AGAACCCTCAATTGGG': 'CL:0000057',
#  'AGAACGTGGTACATTC': 'CL:0002551',
#  'AGAAGAGCGCCGTTCC': 'CL:0000187',
#  'AGAAGGTACACTTCAC': 'CL:0000057',
#  'AGAAGGTTGCCGAATT': 'CL:0000187',
#  'AGAAGTGATTCGTGAT': 'CL:0000388',
#  'AGAATAAATCTTCAGG': 'CL:0000057',
#  'AGAATTATGGATTCGA': 'CL:0002551',
#  'AGAATTGTTTGACATA': 'CL:0002551',
#  'AGACAGCTCAGAATCC': 'CL:0000057',
#  'AGACAGGCATCTCAGC': 'CL:0000187',
#  'AGACCAAACCACACCT': 'CL:0000057',
#  'AGACCATGGGATACAA': 'CL:0000187',
#  'AGACCCACCGCTGATC': 'CL:0000388',
#  'AGACCCGCCCTCCTCG': 'CL:0000187',
#  'AGACCGCTCCGCGGTT': 'CL:0000187',
#  'AGACCGGGAAACCCTG': 'CL:0000057',
#  'AGACGAAGTGCCGGTC': 'CL:0000187',
#  'AGACGACGATGCCGCT': 'CL:0000057',
#  'AGACTAGCCTTCCAGA': 'CL:0000187',
#  'AGAGAAGGAGTACAAT': 'CL:0002551',
#  'AGAGATCTCTAAAGCG': 'CL:0000057',
#  'AGAGCAGTTATGAGAC': 'CL:0000187',
#  'AGAGCCGCCGAGATTT': 'CL:0000187',
#  'AGAGCGTACAAGCTCG': 'CL:0000057',
#  'AGAGGCTTCGGAAACC': 'CL:0000187',
#  'AGAGTAAACTTCACTA': 'CL:0000187',
#  'AGAGTCTTAATGAAAG': 'CL:0000388',
#  'AGATAACTTCAGGGCC': 'CL:0000057',
#  'AGATACCGGTGTTCAC': 'CL:0000057',
#  'AGATACGACTTCATAT': 'CL:0002551',
#  'AGATACTCAAGATCGA': 'CL:0002543',
#  'AGATCTCAGGTGTGAT': 'CL:0000057',
#  'AGATGACTCGCCCACG': 'CL:0002551',
#  'AGATGCAAGACGTGCA': 'CL:0000057',
#  'AGATGCATCCTGTGTC': 'CL:0000057',
#  'AGATTATAGGACGTTT': 'CL:0002573',
#  'AGATTCACAACCGATA': 'CL:0000057',
#  'AGCAAAGGCCGCTAGT': 'CL:0002551',
#  'AGCAACATATCTTATT': 'CL:0000187',
#  'AGCAACCGAAAGTAAT': 'CL:0000057',
#  'AGCACCAGTACTCACG': 'CL:0002551',
#  'AGCACTACCGGCCTGT': 'CL:0000192',
#  'AGCACTACCTCACCAG': 'CL:0000187',
#  'AGCACTTAAGGACGCC': 'CL:0000057',
#  'AGCAGCCAGATGAATA': 'CL:0000187',
#  'AGCATATCAATATGCT': 'CL:0000187',
#  'AGCATCATTTCGAAAG': 'CL:0000057',
#  'AGCATCGTCGATAATT': 'CL:0002551',
#  'AGCCACAGGTTACCCG': 'CL:0002551',
#  'AGCCCATACATGTAAG': 'CL:0000057',
#  'AGCCCGGCATTAGAGG': 'CL:0002551',
#  'AGCCCTGTCGCACCGT': 'CL:0000187',
#  'AGCCCTTGGACATCCC': 'CL:0002551',
#  'AGCCGCAAATTCAAAT': 'CL:0000057',
#  'AGCCGCTTGATTAGCG': 'CL:0000138',
#  'AGCCGTGGCTAAATGT': 'CL:0000187',
#  'AGCCTAATACCCACGT': 'CL:0000057',
#  'AGCCTTAAAGCGGAAG': 'CL:0002551',
#  'AGCGACAGGAACGGTC': 'CL:0000388',
#  'AGCGACATCCCATTCA': 'CL:0000078',
#  'AGCGACCAACGATATT': 'CL:0000057',
#  'AGCGCATAATGAATCG': 'CL:0002551',
#  'AGCGCTAGAGCGATGT': 'CL:0000187',
#  'AGCGGACACTTCGTAG': 'CL:0002551',
#  'AGCGGCGGTTAGCGGT': 'CL:0000057',
#  'AGCGGGAAGGGTCCAT': 'CL:0002551',
#  'AGCGTGGTATTCTACT': 'CL:0000388',
#  'AGCTAACAAGCAATGT': 'CL:0002551',
#  'AGCTAAGTACGCAGGC': 'CL:0002551',
#  'AGCTCCATATATGTTC': 'CL:0000187',
#  'AGCTCCTTCGCACATC': 'CL:0000187',
#  'AGCTCTAGACGTTCCA': 'CL:0000187',
#  'AGCTCTTCGTAACCTT': 'CL:0000187',
#  'AGCTCTTTACTCAGTT': 'CL:0000138',
#  'AGCTGTAACCTCAATC': 'CL:0000187',
#  'AGCTTGATCTTAACTT': 'CL:0000057',
#  'AGGAAGCTGTCCGCCG': 'CL:0002551',
#  'AGGACAGTCGAATCCC': 'CL:0000057',
#  'AGGACATCGCACGTCG': 'CL:0000057',
#  'AGGACGACCCATTAGA': 'CL:0000187',
#  'AGGACTTATAGGAGAA': 'CL:0000187',
#  'AGGAGCGTTTATTATC': 'CL:0002551',
#  'AGGAGGCCTTCGCGCG': 'CL:0000187',
#  'AGGATAAAGTCGGGAT': 'CL:0000187',
#  'AGGATATAGGGATTTA': 'CL:0000057',
#  'AGGATCACGCGATCTG': 'CL:0000057',
#  'AGGCACGTGACTGTCC': 'CL:0000187',
#  'AGGCAGGGAGCGTACT': 'CL:0002551',
#  'AGGCATTGTCGTAGGG': 'CL:0000187',
#  'AGGCCACATTGGTTAC': 'CL:0000057',
#  'AGGCCACCCGTTATGA': 'CL:0000057',
#  'AGGCCCATTGTACAGG': 'CL:0002551',
#  'AGGCCCTAGAACGCCA': 'CL:0000388',
#  'AGGCCTGAGAATCTCG': 'CL:0002551',
#  'AGGCGATAACTGGCGT': 'CL:0000187',
#  'AGGCGGTTTGTCCCGC': 'CL:0002551',
#  'AGGCTATGGTTAGCTT': 'CL:0000057',
#  'AGGCTTCCCGAAGAAG': 'CL:0000138',
#  'AGGCTTGCTAGACACC': 'CL:0000057',
#  'AGGGACCGGCTGCGTT': 'CL:0000187',
#  'AGGGACTCTACGCGAC': 'CL:0000187',
#  'AGGGCGAGCAGCTGAT': 'CL:0000057',
#  'AGGGCGTGATCGGCTA': 'CL:0002551',
#  'AGGGCTGCAGTTACAG': 'CL:0000187',
#  'AGGGTCGATGCGAACT': 'CL:0000187',
#  'AGGGTGCCGTTCTTTA': 'CL:0002551',
#  'AGGGTGCTCTCGAGGG': 'CL:0002543',
#  'AGGGTGGATAGTGCAT': 'CL:0000057',
#  'AGGGTTCCCTTTGGTT': 'CL:0002551',
#  'AGGGTTTAGTTCGGGA': 'CL:0000187',
#  'AGGTAACCTCCTATTC': 'CL:0002551',
#  'AGGTAGATCGAGATAT': 'CL:0002551',
#  'AGGTAGGTACAAAGCT': 'CL:0000057',
#  'AGGTATAATTGATAGT': 'CL:0000669',
#  'AGGTATGCGGACATTA': 'CL:0000057',
#  'AGGTCAGGTGAGAGTG': 'CL:0000057',
#  'AGGTGTATCGCCATGA': 'CL:0002573',
#  'AGGTTACACCATGCCG': 'CL:0000187',
#  'AGGTTGAGGCACGCTT': 'CL:0000187',
#  'AGGTTTCACACACCTT': 'CL:0000057',
#  'AGTAATGTCTTGCCGC': 'CL:0002551',
#  'AGTACGGCCCGTATCG': 'CL:0000057',
#  'AGTACTCTTATGCCCA': 'CL:0000187',
#  'AGTAGGTAACATACAT': 'CL:0000078',
#  'AGTATAATACTAGGCA': 'CL:0000057',
#  'AGTATGCTGGAGACCA': 'CL:0002551',
#  'AGTATTTGGCACGACC': 'CL:0000057',
#  'AGTCAACACCACCATC': 'CL:0000187',
#  'AGTCAAGATGACACTT': 'CL:0000187',
#  'AGTCACTAGCTCTCGA': 'CL:0000187',
#  'AGTCAGCCACCGCCTG': 'CL:0000187',
#  'AGTCCATTGGCTGATG': 'CL:0000057',
#  'AGTCGAATTAGCGTAA': 'CL:0000388',
#  'AGTCGACGGTCTCAAG': 'CL:0000187',
#  'AGTCGGCCCAAACGAC': 'CL:0002551',
#  'AGTCGGCTCAACTTTA': 'CL:0000057',
#  'AGTCGGTTGCGTGAGA': 'CL:0000187',
#  'AGTCGTCGACCACCAA': 'CL:0000187',
#  'AGTCGTGGGCATTACG': 'CL:1000413',
#  'AGTCTCACAAGACTAC': 'CL:0000187',
#  'AGTCTGGACATCCTTG': 'CL:0002551',
#  'AGTCTTCTCCTCAAAT': 'CL:0002551',
#  'AGTGAACAAACTTCTC': 'CL:0000187',
#  'AGTGACCTACTTTACG': 'CL:0000057',
#  'AGTGACTGTGACACAA': 'CL:0002551',
#  'AGTGAGACTTCCAGTA': 'CL:0000187',
#  'AGTGATAACCTGCGCG': 'CL:0000187',
#  'AGTGATATGAGTAGTT': 'CL:0000057',
#  'AGTGATTCAAGCAGGA': 'CL:0000057',
#  'AGTGCACGCTTAAGAA': 'CL:0000187',
#  'AGTGCGTAGCTCGTAA': 'CL:0000138',
#  'AGTGCTAAACACAGCA': 'CL:0002551',
#  'AGTGCTTGCACGAATA': 'CL:0000187',
#  'AGTGGCGTCTGAAGGT': 'CL:0002551',
#  'AGTGGCTCCGTCGGCC': 'CL:0000057',
#  'AGTGGTGTTACCCGTG': 'CL:0000057',
#  'AGTGGTTGCGTATAGG': 'CL:0000057',
#  'AGTGTGCTAAGATCGC': 'CL:0002551',
#  'AGTGTGGTCTATTGTG': 'CL:0002551',
#  'AGTTAAACACTTGCGA': 'CL:0000388',
#  'AGTTAAGTCAACCGCT': 'CL:0000187',
#  'AGTTACCCTTAAGACT': 'CL:0000057',
#  'AGTTACCGCACATGGT': 'CL:0000187',
#  'AGTTCACCGGTTGGAC': 'CL:0000057',
#  'AGTTCCTACAGAATTA': 'CL:0000187',
#  'AGTTCCTATTTATGTT': 'CL:0000388',
#  'AGTTCTGCGTTGTATC': 'CL:0000057',
#  'AGTTGCTGACTGATAT': 'CL:0000057',
#  'AGTTTGCACCTGCCTC': 'CL:0002551',
#  'AGTTTGGCACGGGTTG': 'CL:0000187',
#  'AGTTTGGCCAGACCTA': 'CL:0000138',
#  'ATAAACGGACCCGTAA': 'CL:0000388',
#  'ATAAACGTTGCACCAC': 'CL:0000187',
#  'ATAAAGGCTCGGTCGT': 'CL:0000669',
#  'ATAAATATTAGCAGCT': 'CL:0000057',
#  'ATAACGCCGGAGGGTC': 'CL:0000187',
#  'ATAACGGAGTCCAACG': 'CL:0002551',
#  'ATAAGGTGGAGAACAT': 'CL:0000187',
#  'ATAAGTAGGGCGACTC': 'CL:0000187',
#  'ATAAGTTACCGCGACG': 'CL:0002551',
#  'ATAATACCGTTAGCCG': 'CL:0000057',
#  'ATAATAGCTGTTGAAT': 'CL:0000388',
#  'ATAATAGTGTAGGGAC': 'CL:0000187',
#  'ATAATCTTGGAGAACC': 'CL:0002551',
#  'ATACAGGCCCTCCAAT': 'CL:0000187',
#  'ATACCACGGGCAACTT': 'CL:0000057',
#  'ATACCTAACCAAGAAA': 'CL:0000057',
#  'ATACGAAGGCTTTCCA': 'CL:0000057',
#  'ATACGCCGGCGAAACC': 'CL:0002573',
#  'ATACGGAACGTCGTTT': 'CL:0000057',
#  'ATACGGTGAAGATGCA': 'CL:0000057',
#  'ATACGTACTTAGCCAC': 'CL:0000187',
#  'ATACGTCCACTCCTGT': 'CL:0000187',
#  'ATACTACCCGTACCAC': 'CL:0002551',
#  'ATACTAGCATGACCCT': 'CL:0002551',
#  'ATACTGCCTTACACCG': 'CL:0000187',
#  'ATACTTGTTCTCGAGC': 'CL:0000057',
#  'ATAGACAACGGGACCT': 'CL:0002551',
#  'ATAGACGAAGAGAAAG': 'CL:0000057',
#  'ATAGAGTACTGGGACA': 'CL:0000187',
#  'ATAGAGTTATCAACTT': 'CL:0000558',
#  'ATAGCAACTAGGGAAG': 'CL:0002551',
#  'ATAGCCTCAGTACCCA': 'CL:0002551',
#  'ATAGCTGCTCTTGTTA': 'CL:0000540',
#  'ATAGGCGGCTATAGAA': 'CL:0000138',
#  'ATAGGGATATCCTTGA': 'CL:0002551',
#  'ATAGGTTGGGCAGATG': 'CL:0002551',
#  'ATAGTGAAGCGTTCTC': 'CL:0000388',
#  'ATAGTTCCACCCACTC': 'CL:0000187',
#  'ATATAAAGCGCTCGTG': 'CL:0000057',
#  'ATATAAATGTAGCTGC': 'CL:0000187',
#  'ATATACATGTATGGTA': 'CL:0000057',
#  'ATATCAACCTACAGAG': 'CL:0000187',
#  'ATATCAATTCCAGCCT': 'CL:0000057',
#  'ATATCGGTAGGGAGAT': 'CL:0000187',
#  'ATATCGTTCCTCGAAC': 'CL:0000187',
#  'ATATCTTAGGGCCTTC': 'CL:0000187',
#  'ATATGTCTCCCTAGCC': 'CL:0000187',
#  'ATATTATCCCGTATTT': 'CL:0000138',
#  'ATATTCAGTTAAACCT': 'CL:0000138',
#  'ATATTCCACATAGTGA': 'CL:0000187',
#  'ATATTGCTGTCAAAGT': 'CL:0002551',
#  'ATATTTAACCCTCAAG': 'CL:0000187',
#  'ATCAAACACTGTTCCA': 'CL:0000187',
#  'ATCAAACGAAGGTTTG': 'CL:0000388',
#  'ATCAATCTGGGCTGCA': 'CL:0000187',
#  'ATCAATGCCGTGGCTG': 'CL:0002551',
#  'ATCACGTGCTAATTAA': 'CL:0000187',
#  'ATCACTTCATCCTCGC': 'CL:1000413',
#  'ATCAGACGGCACGCCG': 'CL:0002551',
#  'ATCAGCCTCATGCTGC': 'CL:0000187',
#  'ATCAGCTCGTCCACTA': 'CL:0000057',
#  'ATCAGGTAGCTGACAG': 'CL:0002551',
#  'ATCATCCAATATTTGT': 'CL:0000057',
#  'ATCATGGACTACCGAC': 'CL:0000187',
#  'ATCCAACGCAGTCATA': 'CL:0000057',
#  'ATCCAATGGAGGGTCC': 'CL:0000388',
#  'ATCCAATGGTACCGAA': 'CL:0000057',
#  'ATCCACATCGACAGAA': 'CL:0002551',
#  'ATCCAGAGCAACAACC': 'CL:0000057',
#  'ATCCAGGATTCGTGAA': 'CL:0000388',
#  'ATCCCATCCACAGCGC': 'CL:0002551',
#  'ATCCTACCTAAGCTCT': 'CL:0000057',
#  'ATCCTGAATCGCTGCG': 'CL:0002573',
#  'ATCCTTCTGAAAGAAC': 'CL:0000057',
#  'ATCGACCCAATACAGA': 'CL:0000388',
#  'ATCGACTCTTTCCGTT': 'CL:0002551',
#  'ATCGCACGCCGGGAGA': 'CL:0000057',
#  'ATCGCCAGTCAACATT': 'CL:0000187',
#  'ATCGCCGTGGTTCATG': 'CL:0000388',
#  'ATCGCTTTACGTCTCA': 'CL:0002551',
#  'ATCGGAGACAGACGGC': 'CL:0000187',
#  'ATCGGTTACCTAGTAA': 'CL:0000057',
#  'ATCGTATTCCGAGAAC': 'CL:0000057',
#  'ATCGTGGAAAGTCTGG': 'CL:0002551',
#  'ATCGTTAGCTAGCGGA': 'CL:0002551',
#  'ATCTAATATCCTACGG': 'CL:0000187',
#  'ATCTCCCACGGAATAT': 'CL:0000558',
#  'ATCTCGTGAGCGAAAC': 'CL:0000187',
#  'ATCTGACATGGAAGGA': 'CL:0002551',
#  'ATCTGATAGTGTCTTA': 'CL:0002551',
#  'ATCTGGGCTGTTCTTG': 'CL:0000057',
#  'ATCTGTAATTGTACCC': 'CL:0002551',
#  'ATCTTGACCTGCAACG': 'CL:0000187',
#  'ATGAAGCCAAGGAGCC': 'CL:0002551',
#  'ATGAAGTGGACCCAGC': 'CL:0002551',
#  'ATGACGCCGGCTCTAA': 'CL:0000078',
#  'ATGACGCGTTCTATCC': 'CL:0000187',
#  'ATGACTATGCGACATT': 'CL:0000187',
#  'ATGAGGAGTGTTAATC': 'CL:0000057',
#  'ATGAGGGCAGCGGCTA': 'CL:0000187',
#  'ATGATCGGGAATAGAC': 'CL:0002551',
#  'ATGATGCAATGGTACA': 'CL:0000187',
#  'ATGCACCTTCCTTAAT': 'CL:0002551',
#  'ATGCACGCGCTGTTCA': 'CL:0002551',
#  'ATGCACTACCGCATTG': 'CL:0000187',
#  'ATGCATGATCCAGGAT': 'CL:0002551',
#  'ATGCCATTTGCGACCA': 'CL:0000057',
#  'ATGCCGGTCTTGCATA': 'CL:0000187',
#  'ATGCGAGTCCCACCAC': 'CL:1001609',
#  'ATGCTCAGTGTTGCAT': 'CL:0000057',
#  'ATGCTCTGGCGCGGTA': 'CL:0000187',
#  'ATGCTTAGGAGTTGAT': 'CL:0000187',
#  'ATGGAAATTTAAGGAG': 'CL:0000057',
#  'ATGGAACCTTTGCACA': 'CL:0000057',
#  'ATGGAGCAGGCCGTGA': 'CL:0000187',
#  'ATGGATTGACCAAACG': 'CL:0002551',
#  'ATGGCAGCATTACGAT': 'CL:0002551',
#  'ATGGCAGCCGAGAAAC': 'CL:0000057',
#  'ATGGCCCGAAAGGTTA': 'CL:0000388',
#  'ATGGCGGAATAGTCGC': 'CL:0002551',
#  'ATGGGACCTGCTGAAC': 'CL:0002551',
#  'ATGGGCCTCGGCCTCT': 'CL:0000187',
#  'ATGGGTGTATACCTCC': 'CL:0002551',
#  'ATGGTCGCGTGGTTTC': 'CL:0000187',
#  'ATGTAAGGCTGCTCTT': 'CL:0002551',
#  'ATGTCATTTCCCATTG': 'CL:0000138',
#  'ATGTGAAAGCCTAATG': 'CL:0000057',
#  'ATGTGCATCCGACGCA': 'CL:0002551',
#  'ATGTGGACATCTTGAT': 'CL:0000388',
#  'ATGTTACGAGCAATAC': 'CL:0000187',
#  'ATGTTCCTGCCCACCT': 'CL:0000388',
#  'ATGTTCGTCGACCCAC': 'CL:0000192',
#  'ATGTTTCGGCCCGGAG': 'CL:0000138',
#  'ATTAAACATGCGGACC': 'CL:0000388',
#  'ATTAACACCTGAGATA': 'CL:0000388',
#  'ATTAATACTACGCGGG': 'CL:0002551',
#  'ATTACATGTCAGTCTT': 'CL:0000187',
#  'ATTACCACACTGCCTG': 'CL:0000057',
#  'ATTACGCGCTGGCAGG': 'CL:0002573',
#  'ATTACTAGCCTCTTGC': 'CL:0002551',
#  'ATTAGATTGATAGCGG': 'CL:0002551',
#  'ATTAGGCGATGCTTTC': 'CL:0000187',
#  'ATTATAGCTACTTTAC': 'CL:0002551',
#  'ATTATGCCATAGGGAG': 'CL:0002551',
#  'ATTATTATGTCCGTCA': 'CL:0002551',
#  'ATTCAACCATTTAAGG': 'CL:0000187',
#  'ATTCACTGATGTTGGA': 'CL:0000187',
#  'ATTCAGTAGCAGGGTC': 'CL:0000187',
#  'ATTCATATACTGTCCA': 'CL:0002551',
#  'ATTCATCGTTGAGGCA': 'CL:0002551',
#  'ATTCCCACATAAACAA': 'CL:0000187',
#  'ATTCCCGAAGGTACAG': 'CL:0002551',
#  'ATTCCTCCGCCAGTGC': 'CL:0000057',
#  'ATTCGACGCCGGGCCT': 'CL:0000057',
#  'ATTCGTCCCGAGGTTA': 'CL:0000388',
#  'ATTCGTGCTATCTCTT': 'CL:0000187',
#  'ATTGAAGATCTTAGTG': 'CL:0000057',
#  'ATTGAATTCCCTGTAG': 'CL:0000388',
#  'ATTGATCACCACATTT': 'CL:0000057',
#  'ATTGATGAGTCCTAAC': 'CL:0002551',
#  'ATTGCCTTTATGTTTG': 'CL:0000187',
#  'ATTGCGATCAGTAACT': 'CL:0000187',
#  'ATTGCTGCTCCTCCAT': 'CL:0002573',
#  'ATTGGATTACAGCGTA': 'CL:0000187',
#  'ATTGGTAGGATCCGCT': 'CL:0000138',
#  'ATTGTACAACTCGGCT': 'CL:0000057',
#  'ATTGTTCAACGATCCG': 'CL:0000388',
#  'ATTTAACTCGTATTAC': 'CL:0000078',
#  'ATTTACAGTTTACTGG': 'CL:0000388',
#  'ATTTCCGGGTTCTGCG': 'CL:0000187',
#  'ATTTGCGCGAGTAGCT': 'CL:0000187',
#  'ATTTGGAGATTGCGGT': 'CL:0000057',
#  'ATTTGTCTTGGGAGCT': 'CL:0000187',
#  'CAAACCAGGTCTGCAT': 'CL:0000057',
#  'CAAACGAGTATCGCAG': 'CL:0002551',
#  'CAAACGGTCGCACTTT': 'CL:0000388',
#  'CAAACTCGCGACGCCG': 'CL:0000187',
#  'CAAAGATTATTGGGCC': 'CL:0000187',
#  'CAAAGGTCATCTGAAA': 'CL:0000057',
#  'CAAATCTCTCACAAGG': 'CL:0000057',
#  'CAAATGTCCTTCCGTG': 'CL:0000057',
#  'CAACACATCTCCTGCC': 'CL:0002551',
#  'CAACCGCACCTAGACA': 'CL:0000138',
#  'CAACCTACCGAGCAGT': 'CL:0002551',
#  'CAACGACCCGTTTACA': 'CL:0002551',
#  'CAACGATCGATCCAAT': 'CL:0000138',
#  'CAACGGTTCTTGATAC': 'CL:0002551',
#  'CAACGTGGTGGAGTCT': 'CL:0000187',
#  'CAACTCCTTGATCCCG': 'CL:0002551',
#  'CAACTGCTCATCCGAT': 'CL:0000057',
#  'CAAGACTCAGAAGCGC': 'CL:0002551',
#  'CAAGAGGGCGGAGTAC': 'CL:0000388',
#  'CAAGATATTATAACGT': 'CL:0000187',
#  'CAAGCAACGTCGGAGT': 'CL:0000057',
#  'CAAGCGGCACATAATT': 'CL:0000187',
#  'CAAGGATCGCATGTTC': 'CL:0000057',
#  'CAAGGTCCTATAGGCT': 'CL:0002551',
#  'CAAGTGTGGTTGCAAA': 'CL:0000187',
#  'CAATAAACCTTGGCCC': 'CL:0002551',
#  'CAATACGAGAGTCTGA': 'CL:0000187',
#  'CAATACGCTCTGAGGC': 'CL:0000057',
#  'CAATATTCTTGACCTA': 'CL:0000187',
#  'CAATCCTGCCGTGGAG': 'CL:0000192',
#  'CAATGAGGTTCGACTA': 'CL:0000388',
#  'CAATGCGAGAAGTATC': 'CL:0000187',
#  'CAATGTGCCAACCCTT': 'CL:0000187',
#  'CAATTAAGGGTGATGA': 'CL:0000057',
#  'CAATTGGGCCGCACTC': 'CL:0000057',
#  'CAATTTCGTATAAGGG': 'CL:0002573',
#  'CACAATGAGCTGCTAT': 'CL:0000388',
#  'CACACACGCTAACGAG': 'CL:0000187',
#  'CACACAGCTTGCGCTC': 'CL:0000057',
#  'CACACAGGGATAGATT': 'CL:0000187',
#  'CACACGCGCTGTCTTA': 'CL:0000057',
#  'CACAGAGACGAGGACG': 'CL:0002551',
#  'CACAGCACCCACGGCA': 'CL:0000057',
#  'CACAGCTAGGGAGTGA': 'CL:0002551',
#  'CACAGGGCCATATAGT': 'CL:0000187',
#  'CACAGGGCCGTTGTCA': 'CL:0002551',
#  'CACAGTCCCGCTTCGC': 'CL:0002551',
#  'CACAGTTCGCTTCCCA': 'CL:0000187',
#  'CACATATTAGCAGGAT': 'CL:0000388',
#  'CACATCGTGCACGCGC': 'CL:0002551',
#  'CACATCTCACCGACGA': 'CL:0000187',
#  'CACATGATTCAGCAAC': 'CL:0002573',
#  'CACATTTCTTGTCAGA': 'CL:0000187',
#  'CACCAATCATCCGTCT': 'CL:0000057',
#  'CACCACGCCACACAGA': 'CL:0000057',
#  'CACCAGTCAGCATGCA': 'CL:0002551',
#  'CACCCAAATCTTATGT': 'CL:0002551',
#  'CACCCACACGTCACCC': 'CL:0002551',
#  'CACCCGCGTTTGACAC': 'CL:0002551',
#  'CACCCGGTTTGTGACT': 'CL:0000057',
#  'CACCCTAACAAGATCT': 'CL:0000187',
#  'CACCCTTGGTGAGACC': 'CL:0000057',
#  'CACCGCCAGAAGGTTT': 'CL:0000187',
#  'CACCGTATCCCATCCG': 'CL:0000187',
#  'CACCGTTAGGGATCAC': 'CL:0000057',
#  'CACCGTTGCGCGATAT': 'CL:0000388',
#  'CACCTAATAGAGTCGT': 'CL:0002551',
#  'CACCTTGGCGCCTTTG': 'CL:0000187',
#  'CACGAAAGTTAGTCCC': 'CL:0000057',
#  'CACGCACAGCGCAGCT': 'CL:0002551',
#  'CACGCAGCGAGGCTTT': 'CL:0000057',
#  'CACGCGGAACTGTTGC': 'CL:0000057',
#  'CACGGGATTGAGGGTT': 'CL:0000057',
#  'CACGTCGGCAACCTCT': 'CL:0000138',
#  'CACGTCGGGTTCTAGA': 'CL:0002551',
#  'CACGTTCGTGCTCTAG': 'CL:0000187',
#  'CACGTTTCGTACACAC': 'CL:0000187',
#  'CACTAAAGTTGCCTAT': 'CL:0000057',
#  'CACTACGGGAGCTGCC': 'CL:0002551',
#  'CACTCAAGAGCTATGG': 'CL:0000388',
#  'CACTCCTATGTAAGAT': 'CL:0000057',
#  'CACTCGAGCTGAACAA': 'CL:0000388',
#  'CACTCGGTTAGGAGGA': 'CL:0000057',
#  'CACTCTTCTGCTAGCC': 'CL:0000187',
#  'CACTGTCCAAGTGAGA': 'CL:0002551',
#  'CACTTAATCAGACGGA': 'CL:1000413',
#  'CACTTCGCCACAGGCT': 'CL:0000057',
#  'CACTTCGTCTTATCTC': 'CL:0002551',
#  'CAGAACTTAGCCCTCT': 'CL:0000187',
#  'CAGAATAACACACGGA': 'CL:0000187',
#  'CAGAATATTCGTTATC': 'CL:0000388',
#  'CAGACACCGATCGCTG': 'CL:0000057',
#  'CAGACCTGTAAGTGTT': 'CL:0002551',
#  'CAGACGAACCTGATAC': 'CL:0000388',
#  'CAGAGACGGTCACCCA': 'CL:0000187',
#  'CAGAGCATGAGCTTGC': 'CL:0002551',
#  'CAGAGGCGATGCATGA': 'CL:0000057',
#  'CAGATACTAACATAGT': 'CL:0000187',
#  'CAGATCCTGGTTTGAA': 'CL:0000057',
#  'CAGATGTTTGTCCCAA': 'CL:0000057',
#  'CAGCAGCCCGTTCCTT': 'CL:0002551',
#  'CAGCAGTCCAGACTAT': 'CL:0000187',
#  'CAGCAGTCTGTGCTGC': 'CL:0002551',
#  'CAGCGATTCCCTTCAA': 'CL:0002551',
#  'CAGCGCCAACACGATA': 'CL:0000057',
#  'CAGCTCACTGAGACAT': 'CL:0000057',
#  'CAGCTCGACAAGTTAA': 'CL:0002551',
#  'CAGCTCGTGCTTGTGT': 'CL:0000187',
#  'CAGCTGGCGTAACCGT': 'CL:0000187',
#  'CAGCTTAGTAGGTAGC': 'CL:0000057',
#  'CAGGACAGCTGCCCTT': 'CL:0002551',
#  'CAGGATATATCGTTGT': 'CL:0000388',
#  'CAGGCAGTCTTACCAG': 'CL:0002551',
#  'CAGGCCGTTTGGGTGT': 'CL:0000057',
#  'CAGGCGCACGGTGGTC': 'CL:0000187',
#  'CAGGCGCCATGCTAGG': 'CL:0000388',
#  'CAGTAATCCCTCCCAG': 'CL:0000057',
#  'CAGTACCAGTTTACGT': 'CL:0000057',
#  'CAGTAGATGATGTCCG': 'CL:0000138',
#  'CAGTCGGCCTAGATAT': 'CL:0000192',
#  'CAGTCTGTATACTGGG': 'CL:0000192',
#  'CAGTGGTTGCACATGA': 'CL:0000057',
#  'CAGTGTCCGCAGAATG': 'CL:0000057',
#  'CAGTGTCGGCTGGCCC': 'CL:0000187',
#  'CAGTTCAAATTGACAC': 'CL:0000187',
#  'CAGTTCCGCGGGTCGA': 'CL:0000187',
#  'CATAACGGACAGTCGT': 'CL:0000187',
#  'CATAAGAAGCTTGGCT': 'CL:0000187',
#  'CATAAGCTCTCCGTCT': 'CL:0000669',
#  'CATACAAAGCCGAACC': 'CL:0000057',
#  'CATACACAAAGTCAGC': 'CL:0000057',
#  'CATACCCGTACCCAGT': 'CL:0000057',
#  'CATACGAACTAGCTGG': 'CL:0002551',
#  'CATACGGCGTCTGGGC': 'CL:0000057',
#  'CATACTATGTAATTGT': 'CL:0002573',
#  'CATACTTAGGCAATAC': 'CL:0000187',
#  'CATAGCCGCCCGGGAT': 'CL:0000187',
#  'CATAGCGTTGCCCACC': 'CL:0000057',
#  'CATAGTAGCATAGTAG': 'CL:0002551',
#  'CATAGTCCACAAGAAC': 'CL:0000138',
#  'CATATAGGTACAGTCA': 'CL:0000057',
#  'CATATGTCAGGCTACG': 'CL:0000187',
#  'CATCAACACCTACTAA': 'CL:0000187',
#  'CATCATTACCCTGAGG': 'CL:0000187',
#  'CATCCAATATAGTTTG': 'CL:0002551',
#  'CATCCGCAGGCCCGAA': 'CL:0000057',
#  'CATCCTCTCAAAGATC': 'CL:0000187',
#  'CATCGCCCGCGGCCAA': 'CL:0002551',
#  'CATCGGACGGGTTAAT': 'CL:0000388',
#  'CATCGTCCGGTTACTA': 'CL:0000057',
#  'CATCTAGTGAAGGGAA': 'CL:0000187',
#  'CATCTGCAGGATCATT': 'CL:0000057',
#  'CATCTTACACCACCTC': 'CL:0002543',
#  'CATGAACCGACATTTG': 'CL:0002551',
#  'CATGACTTCGCTGAAT': 'CL:0000187',
#  'CATGAGATGCACTCTC': 'CL:0000187',
#  'CATGATGCACAATTCT': 'CL:0000057',
#  'CATGATGGAAGTTAGC': 'CL:0000187',
#  'CATGCCAACTCGCAAA': 'CL:0002543',
#  'CATGGATTGTCTTCCG': 'CL:0000187',
#  'CATGGCAGGAAGATCG': 'CL:0002551',
#  'CATGGCTCCCTATGTC': 'CL:0000138',
#  'CATGGGTATGCCTTAT': 'CL:0000187',
#  'CATGGTAAGTAGCGTT': 'CL:0000388',
#  'CATGGTATTAGTTTGT': 'CL:0002551',
#  'CATGGTCTAGATACCG': 'CL:0002551',
#  'CATGTAAGAGACATTT': 'CL:0000187',
#  'CATGTCTCATTTATGG': 'CL:0000187',
#  'CATTACATAGATTGTG': 'CL:0002551',
#  'CATTACGTCGGCCCGT': 'CL:0002551',
#  'CATTATGCTTGTTGTG': 'CL:0000187',
#  'CATTCCCATTCCGTCG': 'CL:0002551',
#  'CATTGCGAAATGGGCG': 'CL:0000057',
#  'CATTGTGTGCTAGATC': 'CL:0000057',
#  'CATTTCTAGCAGACTA': 'CL:0000187',
#  'CATTTGAGTGGTACGT': 'CL:0000388',
#  'CCAAACAGAACCCTCG': 'CL:0000057',
#  'CCAAATAACAAGATTC': 'CL:0000187',
#  'CCAACGATGCACTGAT': 'CL:0000057',
#  'CCAACTTGATAGATCC': 'CL:0000388',
#  'CCAAGAAAGTGGGCGA': 'CL:0000388',
#  'CCAAGACTTCTGCGAA': 'CL:0000646',
#  'CCAAGCGTAACTCGTA': 'CL:0000187',
#  'CCAAGGAACAGAGAGG': 'CL:0002551',
#  'CCAAGTTTCTACAGAT': 'CL:0000540',
#  'CCAATAGATTTCATCT': 'CL:0000057',
#  'CCAATAGTGCCGTCGA': 'CL:0000057',
#  'CCAATGTCACAGCAAG': 'CL:0002573',
#  'CCAATTGAATGTTAAT': 'CL:0002551',
#  'CCACACTGAGATATTA': 'CL:0000057',
#  'CCACAGTACCCATCCT': 'CL:0000187',
#  'CCACATACTGCACCCA': 'CL:0000187',
#  'CCACATGGCTCTTTAT': 'CL:0000057',
#  'CCACCAACTTTACTGT': 'CL:0000388',
#  'CCACCCAAGGAAAGTG': 'CL:0000187',
#  'CCACGAATTTAACCTC': 'CL:0000057',
#  'CCACGGAGCCATAAGA': 'CL:0000388',
#  'CCACGGTGCCCGGTAG': 'CL:0000558',
#  'CCACGTAAATTAGACT': 'CL:0000187',
#  'CCACTATCCGGGTCAC': 'CL:0002551',
#  'CCACTGGTGGCTGGTT': 'CL:0000235',
#  'CCACTGTTTGGATTAA': 'CL:0000187',
#  'CCAGAAAGCAACTCAT': 'CL:0000388',
#  'CCAGAGACAAAGCCGG': 'CL:0000057',
#  'CCAGCCTGGACCAATA': 'CL:0002573',
#  'CCAGCGGGATCACCAG': 'CL:0000187',
#  'CCAGCTCGAACGCATT': 'CL:0000057',
#  'CCAGCTGATGGTACTT': 'CL:0002573',
#  'CCAGCTTCCGCCCGCA': 'CL:0000187',
#  'CCAGGCTGGCGTCTGA': 'CL:0000057',
#  'CCAGGGACGTGGCCTC': 'CL:0000187',
#  'CCAGTCAAATCTCTTA': 'CL:0000057',
#  'CCAGTCTTGTCATAGA': 'CL:0002551',
#  'CCATAACCTGTGCAGT': 'CL:0000187',
#  'CCATACTCGCCTCTCC': 'CL:0000388',
#  'CCATAGAGGCTGCCAG': 'CL:0002551',
#  'CCATAGGTTGGCGTGG': 'CL:0002551',
#  'CCATAGTCAGTAACCC': 'CL:0000057',
#  'CCATATGGAAACTATA': 'CL:0000187',
#  'CCATCCATACCAAGTC': 'CL:0000057',
#  'CCATCGCAGTTAAACT': 'CL:0000187',
#  'CCATCTCACCAGTGAA': 'CL:0000187',
#  'CCATGCCCTAGATTTC': 'CL:0000187',
#  'CCATGCCTGTTTAGTA': 'CL:0000057',
#  'CCATGCTCTGCAGGAA': 'CL:0002551',
#  'CCATGGCCCTTGTACC': 'CL:0000057',
#  'CCATTAGCGATAATCC': 'CL:0000057',
#  'CCATTCCCTGCCCACA': 'CL:0000057',
#  'CCATTTCTACCTATTA': 'CL:0000187',
#  'CCCAAACATGCTGCTC': 'CL:0000057',
#  'CCCAACATACGTCGCG': 'CL:0000388',
#  'CCCAATGAGATTTGCA': 'CL:0000235',
#  'CCCAATTTCACAACTT': 'CL:0002573',
#  'CCCACTCCACGGTATC': 'CL:0000057',
#  'CCCAGGTCTGAAGGCT': 'CL:0000187',
#  'CCCAGTAAACTTGGGA': 'CL:0000057',
#  'CCCAGTTAAGGCGCCG': 'CL:0000057',
#  'CCCGAAGTTTCGCGAA': 'CL:0000057',
#  'CCCGAGTTTCTCCGTA': 'CL:0000187',
#  'CCCGATAGCCTCGCCT': 'CL:0000057',
#  'CCCGCAGCGCGAACTA': 'CL:0000388',
#  'CCCGCCATGCTCCCGT': 'CL:0002551',
#  'CCCGCGCAATGCACCC': 'CL:0000057',
#  'CCCGGCTAGGTGAGAA': 'CL:0000138',
#  'CCCGGTGGAAGAACCT': 'CL:0000187',
#  'CCCGGTGTATCGGAAT': 'CL:0000057',
#  'CCCGTAAGTCTAGGCC': 'CL:0002573',
#  'CCCGTAGCTGGGAAGA': 'CL:0002551',
#  'CCCGTCAGCGTCTGAC': 'CL:0002551',
#  'CCCGTGAGGGCGGTGA': 'CL:0000057',
#  'CCCGTTTCGCAGATGT': 'CL:0000187',
#  'CCCTAGGCAACAAGAG': 'CL:0000057',
#  'CCCTATGTAGAGCAGA': 'CL:0002551',
#  'CCCTCAAGCTCTTAGT': 'CL:1001607',
#  'CCCTCATTCTGGAATT': 'CL:0002551',
#  'CCCTCCTCGCTCGTAT': 'CL:0000187',
#  'CCCTGAAATGAGTTGA': 'CL:0000057',
#  'CCCTGACTAACAAATT': 'CL:0000057',
#  'CCCTGATGTAACTCGT': 'CL:0000057',
#  'CCCTGCCCAATCCGCT': 'CL:0000669',
#  'CCCTGCGCTACGCATA': 'CL:0000057',
#  'CCCTGGCTGTTCCTTC': 'CL:0000057',
#  'CCCTTTGACAGGTCTT': 'CL:0000187',
#  'CCGAAAGTGGTGAGCA': 'CL:0000057',
#  'CCGAACACTGGGCCTC': 'CL:0000669',
#  'CCGAACCTTCCCGGCC': 'CL:0000388',
#  'CCGAAGCATTGACCAA': 'CL:0002551',
#  'CCGAAGTATATTGTTC': 'CL:0000057',
#  'CCGACAAACACATGAG': 'CL:0000057',
#  'CCGACAAAGGGAGTGC': 'CL:0000057',
#  'CCGACAATAGGCCGCC': 'CL:0000187',
#  'CCGACGGGCATGAGGT': 'CL:0000187',
#  'CCGAGAAGTCGCATAA': 'CL:0000187',
#  'CCGATATGACGTAAGG': 'CL:0000057',
#  'CCGATCTCAACCTTAT': 'CL:0000187',
#  'CCGATTCGAGGGACCC': 'CL:0000057',
#  'CCGCACAAAGACCAAC': 'CL:0000187',
#  'CCGCACACGAACGTGT': 'CL:0000187',
#  'CCGCACGTGACCTCGG': 'CL:0000187',
#  'CCGCATGTGGTACGAT': 'CL:0000187',
#  'CCGCCGGAACTTCTCG': 'CL:0000558',
#  'CCGCCGTTGAGGATAA': 'CL:0000187',
#  'CCGCCTTGCGATGTCG': 'CL:0000057',
#  'CCGCGATTTGGTAGGT': 'CL:0000057',
#  'CCGCGGAATGCGTCAC': 'CL:0002551',
#  'CCGCGGGTACGAAGAA': 'CL:0000057',
#  'CCGCGTAGGTAAGGGC': 'CL:0000187',
#  'CCGCTATCAGCACCAG': 'CL:0000388',
#  'CCGCTTACCTCACTCT': 'CL:0000138',
#  'CCGGAAGTTATCAGTC': 'CL:0000388',
#  'CCGGAATGGTTTCAGT': 'CL:0002551',
#  'CCGGAGCGTACTTTCT': 'CL:0002551',
#  'CCGGCACGACCGTTTC': 'CL:0002543',
#  'CCGGCCGCGAGCATAT': 'CL:0002551',
#  'CCGGCGTGAGACTCTG': 'CL:0000057',
#  'CCGGGACCCGCAGAGA': 'CL:0002551',
#  'CCGGGCGGTCTCGTCA': 'CL:0000187',
#  'CCGGGCTGCTCCATAC': 'CL:0000187',
#  'CCGGGTTCGAGGTTAC': 'CL:0002573',
#  'CCGGTAATGGCTAGTC': 'CL:0000187',
#  'CCGGTTTGTAATTGTG': 'CL:0000057',
#  'CCGTAAGTTGGTCCCA': 'CL:0000187',
#  'CCGTACCCAAGCGCCA': 'CL:0000057',
#  'CCGTAGGAAATCCCTG': 'CL:0000057',
#  'CCGTAGGGTTGTTTAC': 'CL:0000669',
#  'CCGTATCTCGTCGTAG': 'CL:0000187',
#  'CCGTGAGGCATTCATG': 'CL:0000187',
#  'CCGTGTTAAATTCCAT': 'CL:0002551',
#  'CCGTTCCGAATCTCGG': 'CL:0000057',
#  'CCTAAATTAACGGTTC': 'CL:0000057',
#  'CCTAAATTGTATCCTA': 'CL:0000187',
#  'CCTAACCCAAACAAGT': 'CL:0000187',
#  'CCTACATTCACAGACG': 'CL:0000388',
#  'CCTACGGCTCAGTCGA': 'CL:0000057',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               71
# AAACAAGTATCTCCCA-1          1         50        102             2350
# AAACAATCTACTAGCA-1          0          3         43              228
# AAACACCAATAACTGC-1          1         59         19             1017
# AAACAGAGCGACTCCT-1          0         14         94              144
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42              725
# TTGTTTCATTAGTCTA-1          1         60         30             1182
# TTGTTTCCATACAACT-1          1         45         27             2710
# TTGTTTGTATTACACG-1          0         73         41              100
# TTGTTTGTGTAAATTC-1          0          7         51              234
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                 CL:0000187
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                 CL:0002551
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0002551
# TTGTTTCATTAGTCTA-1                 CL:0002551
# TTGTTTCCATACAACT-1                 CL:0000388
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 2196

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_31528/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               71
# AAACAAGTATCTCCCA-1          1         50        102             2350
# AAACAATCTACTAGCA-1          0          3         43              228
# AAACACCAATAACTGC-1          1         59         19             1017
# AAACAGAGCGACTCCT-1          0         14         94              144
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42              725
# TTGTTTCATTAGTCTA-1          1         60         30             1182
# TTGTTTCCATACAACT-1          1         45         27             2710
# TTGTTTGTATTACACG-1          0         73         41              100
# TTGTTTGTGTAAATTC-1          0          7         51              234
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                 CL:0000187
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                 CL:0002551
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0002551
# TTGTTTCATTAGTCTA-1                 CL:0002551
# TTGTTTCCATACAACT-1                 CL:0000388
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000187',
#  'CL:0002551',
#  'CL:0000057',
#  'CL:0000558',
#  'CL:0000388',
#  'CL:0000646',
#  'CL:0002573',
#  'CL:0000138',
#  'CL:0000078',
#  'CL:0002320',
#  'CL:1000413',
#  'CL:0000235',
#  'CL:0008019',
#  'CL:0000192',
#  'CL:0000540',
#  'CL:0000669',
#  'CL:0002543',
#  'CL:1001609',
#  'CL:1001607',
#  'CL:0000232',
#  'CL:0000556',
#  'CL:0000743',
#  'CL:0002138']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000030']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000030
# AAACAAGTATCTCCCA-1    HsapDv:0000030
# AAACAATCTACTAGCA-1    HsapDv:0000030
# AAACACCAATAACTGC-1    HsapDv:0000030
# AAACAGAGCGACTCCT-1    HsapDv:0000030
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000030
# TTGTTTCATTAGTCTA-1    HsapDv:0000030
# TTGTTTCCATACAACT-1    HsapDv:0000030
# TTGTTTGTATTACACG-1    HsapDv:0000030
# TTGTTTGTGTAAATTC-1    HsapDv:0000030
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000030']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               71
# AAACAAGTATCTCCCA-1          1         50        102             2350
# AAACAATCTACTAGCA-1          0          3         43              228
# AAACACCAATAACTGC-1          1         59         19             1017
# AAACAGAGCGACTCCT-1          0         14         94              144
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42              725
# TTGTTTCATTAGTCTA-1          1         60         30             1182
# TTGTTTCCATACAACT-1          1         45         27             2710
# TTGTTTGTATTACACG-1          0         73         41              100
# TTGTTTGTGTAAATTC-1          0          7         51              234
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383360
# AAACAAGTATCTCCCA-1                 CL:0000187  WSSS_THYst9383360
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383360
# AAACACCAATAACTGC-1                 CL:0002551  WSSS_THYst9383360
# AAACAGAGCGACTCCT-1                    unknown  WSSS_THYst9383360
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0002551  WSSS_THYst9383360
# TTGTTTCATTAGTCTA-1                 CL:0002551  WSSS_THYst9383360
# TTGTTTCCATACAACT-1                 CL:0000388  WSSS_THYst9383360
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9383360
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383360
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383360': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         ...,
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]]], dtype=uint8),
#                  'lowres': array([[[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         ...,
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.47474183626618,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 168.7668906585838,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9383360.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='cell_type_ontology_term_id'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='cell_type_ontology_term_id',
        img_res_key='fullres',
        scale_factor=1.0
        )
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:483: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = color_source_vector.map(color_map)
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/squidpy/pl/_spatial_utils.py:483: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = color_source_vector.map(color_map)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16               71
# AAACAAGTATCTCCCA-1          1         50        102             2350
# AAACAATCTACTAGCA-1          0          3         43              228
# AAACACCAATAACTGC-1          1         59         19             1017
# AAACAGAGCGACTCCT-1          0         14         94              144
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42              725
# TTGTTTCATTAGTCTA-1          1         60         30             1182
# TTGTTTCCATACAACT-1          1         45         27             2710
# TTGTTTGTATTACACG-1          0         73         41              100
# TTGTTTGTGTAAATTC-1          0          7         51              234
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9383360
# AAACAAGTATCTCCCA-1                 CL:0000187  WSSS_THYst9383360
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9383360
# AAACACCAATAACTGC-1                 CL:0002551  WSSS_THYst9383360
# AAACAGAGCGACTCCT-1                    unknown  WSSS_THYst9383360
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0002551  WSSS_THYst9383360
# TTGTTTCATTAGTCTA-1                 CL:0002551  WSSS_THYst9383360
# TTGTTTCCATACAACT-1                 CL:0000388  WSSS_THYst9383360
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9383360
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9383360
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000030
# AAACAAGTATCTCCCA-1                     HsapDv:0000030
# AAACAATCTACTAGCA-1                     HsapDv:0000030
# AAACACCAATAACTGC-1                     HsapDv:0000030
# AAACAGAGCGACTCCT-1                     HsapDv:0000030
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000030
# TTGTTTCATTAGTCTA-1                     HsapDv:0000030
# TTGTTTCCATACAACT-1                     HsapDv:0000030
# TTGTTTGTATTACACG-1                     HsapDv:0000030
# TTGTTTGTGTAAATTC-1                     HsapDv:0000030
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9383360': {'images': {'hires': array([[[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         ...,
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]]], dtype=uint8),
#                  'fullres': array([[[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         ...,
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]],
#
#                         [[239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          ...,
#                          [239, 242, 244],
#                          [239, 242, 244],
#                          [239, 242, 244]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.47474183626618,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9383360'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'}),
#              ('cell_type_ontology_term_id_colors',
#               ['#023fa5',
#                '#7d87b9',
#                '#bec1d4',
#                '#d6bcc0',
#                '#bb7784',
#                '#8e063b',
#                '#4a6fe3',
#                '#8595e1',
#                '#b5bbe3',
#                '#e6afb9',
#                '#e07b91',
#                '#d33f6a',
#                '#11c638',
#                '#8dd593',
#                '#c6dec7',
#                '#ead3c6',
#                '#f0b98d',
#                '#ef9708',
#                '#0fcfc0',
#                '#9cded6',
#                '#d5eae7',
#                '#f3e1eb',
#                '#f6c4e1',
#                '#f79cd4'])])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide2.h5ad', compression = 'gzip')

# %% [markdown]
# ### **Curating 240314KT_AT2_organoid_filtered.h5ad**

# %% [markdown]
# Article: Early human lung immune cell development and its role in epithelial cell fate

# %% [markdown]
# DOI: 10.1126/sciimmunol.adf99

# %% [markdown]
# Data Source : https://fetal-lung-immune.cellgeni.sanger.ac.uk

# %% [markdown]
# ##### **Mount farm**

# %% [markdown]
# mount-farm

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import re
from collections import Counter

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
adata = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/lung_organoid_2024/Data/240314KT_AT2_organoid_filtered.h5ad')

# %%
# View the AnnData object

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 9619 × 21868
#     obs: 'Souporcell4_status', 'Souporcell4_assignment', 'percent_mito', 'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score', 'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variablefirst', 'highly_variable_n'
#     uns: 'Souporcell4_assignment_colors', 'batch_colors', 'celltype_colors', 'leiden', 'leiden_R_colors', 'log1p', 'majority_voting_colors', 'neighbors', 'pca', 'predicted_labels_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ##### **X - expression matrix**

# %%
# View the expression matrix of the anndata object.

# %%
adata.X
# Out:
# <9619x21868 sparse matrix of type '<class 'numpy.float32'>'
# 	with 37008792 stored elements in Compressed Sparse Row format>

# %%
# Print the matrix to check whether they are normalized counts or raw counts. if the matrix has floating numbers,they are normalized counts.if they are integers, they are raw counts.

# %%
print(adata.X)
# Out:
#   (0, 30)	0.619026
#   (0, 39)	0.619026
#   (0, 45)	0.9985108
#   (0, 48)	0.619026
#   (0, 50)	0.619026
#   (0, 51)	0.619026
#   (0, 59)	1.2729452
#   (0, 64)	0.619026
#   (0, 78)	0.619026
#   (0, 87)	0.619026
#   (0, 104)	0.619026
#   (0, 105)	0.619026
#   (0, 108)	0.619026
#   (0, 119)	2.745411
#   (0, 122)	0.619026
#   (0, 126)	0.619026
#   (0, 145)	0.9985108
#   (0, 152)	1.2729452
#   (0, 155)	0.9985108
#   (0, 195)	0.619026
#   (0, 204)	0.619026
#   (0, 215)	0.619026
#   (0, 223)	0.619026
#   (0, 224)	1.2729452
#   (0, 244)	0.619026
#   :	:
#   (9618, 21725)	0.5632831
#   (9618, 21735)	0.32078904
#   (9618, 21744)	0.32078904
#   (9618, 21751)	0.32078904
#   (9618, 21760)	0.32078904
#   (9618, 21761)	0.92142123
#   (9618, 21763)	0.5632831
#   (9618, 21773)	0.32078904
#   (9618, 21788)	1.482498
#   (9618, 21793)	0.32078904
#   (9618, 21795)	0.32078904
#   (9618, 21796)	0.32078904
#   (9618, 21801)	4.7566504
#   (9618, 21806)	0.32078904
#   (9618, 21807)	0.5632831
#   (9618, 21808)	0.32078904
#   (9618, 21810)	0.32078904
#   (9618, 21813)	0.32078904
#   (9618, 21815)	0.75830007
#   (9618, 21816)	0.32078904
#   (9618, 21818)	0.32078904
#   (9618, 21822)	0.32078904
#   (9618, 21825)	0.32078904
#   (9618, 21835)	0.75830007
#   (9618, 21867)	0.5632831

# %%
adata.layers.keys()
# Out:
# KeysView(Layers with keys: )

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score phase leiden          predicted_labels  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028    G1      4  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267    G1      7  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150    G1      0                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696    G1      0                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853    G1      7                  Late tip
# ...                    ...        ...   ...    ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153   G2M      5                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186    G1      6                  Late tip
# TTTGTCATCGCCTGAG  0.478485   0.114177     S      5                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052     S      3                  Late tip
# TTTGTCATCTCGTATT -0.011147  -0.161577    G1      8                  Late tip
#
#                  over_clustering           majority_voting  conf_score  \
# AAACCTGAGCAGCGTA              19  Pulmonary neuroendocrine    0.670715
# AAACCTGAGTACGTAA              46  Pulmonary neuroendocrine    0.755056
# AAACCTGCACCATGTA              53                  Late tip    0.979895
# AAACCTGCACCTATCC              83                  Late tip    0.642230
# AAACCTGCACTTAACG              20                  Late tip    0.863851
# ...                          ...                       ...         ...
# TTTGTCATCCACGAAT              36                  Late tip    0.235389
# TTTGTCATCGAGAGCA              85                 Mid fibro    0.735850
# TTTGTCATCGCCTGAG              31                  Late tip    0.998556
# TTTGTCATCTATCGCC              18                 Mid fibro    0.996191
# TTTGTCATCTCGTATT              89                 Mid fibro    0.999624
#
#                  leiden_R                      celltype      donor
# AAACCTGAGCAGCGTA        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG        7    Differentiating basal-like  HDBR16392
# ...                   ...                           ...        ...
# TTTGTCATCCACGAAT        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT      8,0                      AT2-like  HDBR15934
#
# [9619 rows x 19 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor'],
#       dtype='object')

# %% [markdown]
# ##### **Raw counts matrix**

# %%
araw = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/lung_organoid_2024/Data/Lim_scRNA-seq_raw.h5ad')

# %%
araw.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet                    1/0      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts
# AAACCTGAGCAGCGTA   11970.0
# AAACCTGAGTACGTAA   23360.0
# AAACCTGCACCATGTA   16619.0
# AAACCTGCACCTATCC   12119.0
# AAACCTGCACTTAACG   13986.0
# ...                    ...
# TTTGTCATCCACGAAT    2777.0
# TTTGTCATCGAGAGCA   16124.0
# TTTGTCATCGCCTGAG   15508.0
# TTTGTCATCTATCGCC   50036.0
# TTTGTCATCTCGTATT   26487.0
#
# [11147 rows x 4 columns]

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score phase leiden          predicted_labels  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028    G1      4  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267    G1      7  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150    G1      0                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696    G1      0                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853    G1      7                  Late tip
# ...                    ...        ...   ...    ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153   G2M      5                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186    G1      6                  Late tip
# TTTGTCATCGCCTGAG  0.478485   0.114177     S      5                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052     S      3                  Late tip
# TTTGTCATCTCGTATT -0.011147  -0.161577    G1      8                  Late tip
#
#                  over_clustering           majority_voting  conf_score  \
# AAACCTGAGCAGCGTA              19  Pulmonary neuroendocrine    0.670715
# AAACCTGAGTACGTAA              46  Pulmonary neuroendocrine    0.755056
# AAACCTGCACCATGTA              53                  Late tip    0.979895
# AAACCTGCACCTATCC              83                  Late tip    0.642230
# AAACCTGCACTTAACG              20                  Late tip    0.863851
# ...                          ...                       ...         ...
# TTTGTCATCCACGAAT              36                  Late tip    0.235389
# TTTGTCATCGAGAGCA              85                 Mid fibro    0.735850
# TTTGTCATCGCCTGAG              31                  Late tip    0.998556
# TTTGTCATCTATCGCC              18                 Mid fibro    0.996191
# TTTGTCATCTCGTATT              89                 Mid fibro    0.999624
#
#                  leiden_R                      celltype      donor
# AAACCTGAGCAGCGTA        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG        7    Differentiating basal-like  HDBR16392
# ...                   ...                           ...        ...
# TTTGTCATCCACGAAT        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT      8,0                      AT2-like  HDBR15934
#
# [9619 rows x 19 columns]

# %%
common_barcodes =  set(adata.obs_names) & set(araw.obs_names)

# %%
araw_filtered = araw[araw.obs_names.isin(common_barcodes)].copy()

# %%
araw=araw_filtered

# %%
araw
# Out:
# AnnData object with n_obs × n_vars = 9619 × 36601
#     obs: 'Souporcell4_status', 'Souporcell4_assignment', 'percent_mito', 'n_counts'
#     var: 'gene_ids', 'feature_types'

# %%
print(araw.X)
# Out:
#   (0, 44)	1.0
#   (0, 53)	1.0
#   (0, 59)	2.0
#   (0, 62)	1.0
#   (0, 64)	1.0
#   (0, 65)	1.0
#   (0, 73)	3.0
#   (0, 78)	1.0
#   (0, 94)	1.0
#   (0, 104)	1.0
#   (0, 136)	1.0
#   (0, 137)	1.0
#   (0, 142)	1.0
#   (0, 170)	17.0
#   (0, 173)	1.0
#   (0, 177)	1.0
#   (0, 208)	2.0
#   (0, 216)	3.0
#   (0, 219)	2.0
#   (0, 264)	1.0
#   (0, 280)	1.0
#   (0, 293)	1.0
#   (0, 338)	1.0
#   (0, 339)	3.0
#   (0, 370)	1.0
#   :	:
#   (9618, 36386)	1.0
#   (9618, 36389)	1.0
#   (9618, 36390)	1.0
#   (9618, 36401)	305.0
#   (9618, 36406)	1.0
#   (9618, 36407)	2.0
#   (9618, 36408)	1.0
#   (9618, 36410)	1.0
#   (9618, 36413)	1.0
#   (9618, 36415)	3.0
#   (9618, 36416)	1.0
#   (9618, 36423)	1.0
#   (9618, 36429)	1.0
#   (9618, 36432)	1.0
#   (9618, 36450)	3.0
#   (9618, 36559)	2.0
#   (9618, 36561)	14.0
#   (9618, 36562)	12.0
#   (9618, 36563)	1.0
#   (9618, 36564)	3.0
#   (9618, 36565)	6.0
#   (9618, 36566)	2.0
#   (9618, 36568)	3.0
#   (9618, 36571)	3.0
#   (9618, 36600)	2.0

# %% [markdown]
# ##### **Variables(var)**

# %%
# View the var of anndata and raw object

# %%
adata.var
# Out:
#                     gene_ids    feature_types  n_cells  highly_variablefirst  \
# MIR1302-2HG  ENSG00000243485  Gene Expression        9                 False
# AL627309.1   ENSG00000238009  Gene Expression       18                 False
# AL627309.5   ENSG00000241860  Gene Expression      141                  True
# AP006222.2   ENSG00000286448  Gene Expression        7                 False
# LINC01409    ENSG00000237491  Gene Expression     1097                 False
# ...                      ...              ...      ...                   ...
# AL354822.1   ENSG00000278384  Gene Expression      318                 False
# AL592183.1   ENSG00000273748  Gene Expression      182                 False
# AC240274.1   ENSG00000271254  Gene Expression      607                 False
# AC007325.4   ENSG00000278817  Gene Expression      224                 False
# AC007325.2   ENSG00000277196  Gene Expression     3214                 False
#
#              highly_variable_n
# MIR1302-2HG                  0
# AL627309.1                   0
# AL627309.5                   1
# AP006222.2                   0
# LINC01409                    0
# ...                        ...
# AL354822.1                   0
# AL592183.1                   0
# AC240274.1                   0
# AC007325.4                   0
# AC007325.2                   0
#
# [21868 rows x 5 columns]

# %%
araw.var
# Out:
#                     gene_ids    feature_types
# MIR1302-2HG  ENSG00000243485  Gene Expression
# FAM138A      ENSG00000237613  Gene Expression
# OR4F5        ENSG00000186092  Gene Expression
# AL627309.1   ENSG00000238009  Gene Expression
# AL627309.3   ENSG00000239945  Gene Expression
# ...                      ...              ...
# AC141272.1   ENSG00000277836  Gene Expression
# AC023491.2   ENSG00000278633  Gene Expression
# AC007325.1   ENSG00000276017  Gene Expression
# AC007325.4   ENSG00000278817  Gene Expression
# AC007325.2   ENSG00000277196  Gene Expression
#
# [36601 rows x 2 columns]

# %%
adata.var_names = adata.var['gene_ids']
araw.var_names = araw.var['gene_ids']

# %%
# Load the approved genes file.

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
#Create a dictionary from the approved genes file

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
genedict
# Out:
# {'ERCC-00002': 1,
#  'ERCC-00003': 1,
#  'ERCC-00004': 1,
#  'ERCC-00009': 1,
#  'ERCC-00012': 1,
#  'ERCC-00013': 1,
#  'ERCC-00014': 1,
#  'ERCC-00016': 1,
#  'ERCC-00017': 1,
#  'ERCC-00019': 1,
#  'ERCC-00022': 1,
#  'ERCC-00024': 1,
#  'ERCC-00025': 1,
#  'ERCC-00028': 1,
#  'ERCC-00031': 1,
#  'ERCC-00033': 1,
#  'ERCC-00034': 1,
#  'ERCC-00035': 1,
#  'ERCC-00039': 1,
#  'ERCC-00040': 1,
#  'ERCC-00041': 1,
#  'ERCC-00042': 1,
#  'ERCC-00043': 1,
#  'ERCC-00044': 1,
#  'ERCC-00046': 1,
#  'ERCC-00048': 1,
#  'ERCC-00051': 1,
#  'ERCC-00053': 1,
#  'ERCC-00054': 1,
#  'ERCC-00057': 1,
#  'ERCC-00058': 1,
#  'ERCC-00059': 1,
#  'ERCC-00060': 1,
#  'ERCC-00061': 1,
#  'ERCC-00062': 1,
#  'ERCC-00067': 1,
#  'ERCC-00069': 1,
#  'ERCC-00071': 1,
#  'ERCC-00073': 1,
#  'ERCC-00074': 1,
#  'ERCC-00075': 1,
#  'ERCC-00076': 1,
#  'ERCC-00077': 1,
#  'ERCC-00078': 1,
#  'ERCC-00079': 1,
#  'ERCC-00081': 1,
#  'ERCC-00083': 1,
#  'ERCC-00084': 1,
#  'ERCC-00085': 1,
#  'ERCC-00086': 1,
#  'ERCC-00092': 1,
#  'ERCC-00095': 1,
#  'ERCC-00096': 1,
#  'ERCC-00097': 1,
#  'ERCC-00098': 1,
#  'ERCC-00099': 1,
#  'ERCC-00104': 1,
#  'ERCC-00108': 1,
#  'ERCC-00109': 1,
#  'ERCC-00111': 1,
#  'ERCC-00112': 1,
#  'ERCC-00113': 1,
#  'ERCC-00116': 1,
#  'ERCC-00117': 1,
#  'ERCC-00120': 1,
#  'ERCC-00123': 1,
#  'ERCC-00126': 1,
#  'ERCC-00130': 1,
#  'ERCC-00131': 1,
#  'ERCC-00134': 1,
#  'ERCC-00136': 1,
#  'ERCC-00137': 1,
#  'ERCC-00138': 1,
#  'ERCC-00142': 1,
#  'ERCC-00143': 1,
#  'ERCC-00144': 1,
#  'ERCC-00145': 1,
#  'ERCC-00147': 1,
#  'ERCC-00148': 1,
#  'ERCC-00150': 1,
#  'ERCC-00154': 1,
#  'ERCC-00156': 1,
#  'ERCC-00157': 1,
#  'ERCC-00158': 1,
#  'ERCC-00160': 1,
#  'ERCC-00162': 1,
#  'ERCC-00163': 1,
#  'ERCC-00164': 1,
#  'ERCC-00165': 1,
#  'ERCC-00168': 1,
#  'ERCC-00170': 1,
#  'ERCC-00171': 1,
#  'ENSG00000290825': 1,
#  'ENSG00000223972': 1,
#  'ENSG00000227232': 1,
#  'ENSG00000278267': 1,
#  'ENSG00000243485': 1,
#  'ENSG00000284332': 1,
#  'ENSG00000237613': 1,
#  'ENSG00000268020': 1,
#  'ENSG00000290826': 1,
#  'ENSG00000240361': 1,
#  'ENSG00000186092': 1,
#  'ENSG00000238009': 1,
#  'ENSG00000239945': 1,
#  'ENSG00000233750': 1,
#  'ENSG00000268903': 1,
#  'ENSG00000269981': 1,
#  'ENSG00000239906': 1,
#  'ENSG00000241860': 1,
#  'ENSG00000222623': 1,
#  'ENSG00000241599': 1,
#  'ENSG00000279928': 1,
#  'ENSG00000279457': 1,
#  'ENSG00000273874': 1,
#  'ENSG00000228463': 1,
#  'ENSG00000286448': 1,
#  'ENSG00000236679': 1,
#  'ENSG00000236601': 1,
#  'ENSG00000290385': 1,
#  'ENSG00000269732': 1,
#  'ENSG00000284733': 1,
#  'ENSG00000237094': 1,
#  'ENSG00000233653': 1,
#  'ENSG00000250575': 1,
#  'ENSG00000278757': 1,
#  'ENSG00000230021': 1,
#  'ENSG00000235146': 1,
#  'ENSG00000225972': 1,
#  'ENSG00000225630': 1,
#  'ENSG00000237973': 1,
#  'ENSG00000278791': 1,
#  'ENSG00000229344': 1,
#  'ENSG00000240409': 1,
#  'ENSG00000248527': 1,
#  'ENSG00000198744': 1,
#  'ENSG00000268663': 1,
#  'ENSG00000284662': 1,
#  'ENSG00000229376': 1,
#  'ENSG00000291215': 1,
#  'ENSG00000223181': 1,
#  'ENSG00000229905': 1,
#  'ENSG00000228327': 1,
#  'ENSG00000237491': 1,
#  'ENSG00000285268': 1,
#  'ENSG00000290784': 1,
#  'ENSG00000230092': 1,
#  'ENSG00000177757': 1,
#  'ENSG00000225880': 1,
#  'ENSG00000228794': 1,
#  'ENSG00000288531': 1,
#  'ENSG00000230368': 1,
#  'ENSG00000234711': 1,
#  'ENSG00000283040': 1,
#  'ENSG00000272438': 1,
#  'ENSG00000230699': 1,
#  'ENSG00000241180': 1,
#  'ENSG00000223764': 1,
#  'ENSG00000187634': 1,
#  'ENSG00000188976': 1,
#  'ENSG00000187961': 1,
#  'ENSG00000187583': 1,
#  'ENSG00000187642': 1,
#  'ENSG00000272512': 1,
#  'ENSG00000188290': 1,
#  'ENSG00000187608': 1,
#  'ENSG00000231702': 1,
#  'ENSG00000224969': 1,
#  'ENSG00000188157': 1,
#  'ENSG00000242590': 1,
#  'ENSG00000291156': 1,
#  'ENSG00000273443': 1,
#  'ENSG00000217801': 1,
#  'ENSG00000237330': 1,
#  'ENSG00000131591': 1,
#  'ENSG00000285812': 1,
#  'ENSG00000223823': 1,
#  'ENSG00000207730': 1,
#  'ENSG00000207607': 1,
#  'ENSG00000198976': 1,
#  'ENSG00000272141': 1,
#  'ENSG00000205231': 1,
#  'ENSG00000162571': 1,
#  'ENSG00000186891': 1,
#  'ENSG00000186827': 1,
#  'ENSG00000078808': 1,
#  'ENSG00000176022': 1,
#  'ENSG00000184163': 1,
#  'ENSG00000260179': 1,
#  'ENSG00000160087': 1,
#  'ENSG00000230415': 1,
#  'ENSG00000162572': 1,
#  'ENSG00000131584': 1,
#  'ENSG00000278073': 1,
#  'ENSG00000169972': 1,
#  'ENSG00000127054': 1,
#  'ENSG00000283712': 1,
#  'ENSG00000240731': 1,
#  'ENSG00000224051': 1,
#  'ENSG00000169962': 1,
#  'ENSG00000107404': 1,
#  'ENSG00000284372': 1,
#  'ENSG00000162576': 1,
#  'ENSG00000175756': 1,
#  'ENSG00000223663': 1,
#  'ENSG00000221978': 1,
#  'ENSG00000224870': 1,
#  'ENSG00000242485': 1,
#  'ENSG00000264293': 1,
#  'ENSG00000272455': 1,
#  'ENSG00000235098': 1,
#  'ENSG00000225905': 1,
#  'ENSG00000205116': 1,
#  'ENSG00000225285': 1,
#  'ENSG00000179403': 1,
#  'ENSG00000215915': 1,
#  'ENSG00000160072': 1,
#  'ENSG00000290916': 1,
#  'ENSG00000284740': 1,
#  'ENSG00000197785': 1,
#  'ENSG00000205090': 1,
#  'ENSG00000160075': 1,
#  'ENSG00000215014': 1,
#  'ENSG00000274481': 1,
#  'ENSG00000228594': 1,
#  'ENSG00000286989': 1,
#  'ENSG00000272106': 1,
#  'ENSG00000197530': 1,
#  'ENSG00000189409': 1,
#  'ENSG00000248333': 1,
#  'ENSG00000272004': 1,
#  'ENSG00000189339': 1,
#  'ENSG00000269737': 1,
#  'ENSG00000215914': 1,
#  'ENSG00000008128': 1,
#  'ENSG00000268575': 1,
#  'ENSG00000227775': 1,
#  'ENSG00000290854': 1,
#  'ENSG00000215790': 1,
#  'ENSG00000008130': 1,
#  'ENSG00000078369': 1,
#  'ENSG00000231050': 1,
#  'ENSG00000169885': 1,
#  'ENSG00000178821': 1,
#  'ENSG00000142609': 1,
#  'ENSG00000233542': 1,
#  'ENSG00000187730': 1,
#  'ENSG00000226969': 1,
#  'ENSG00000067606': 1,
#  'ENSG00000271806': 1,
#  'ENSG00000182873': 1,
#  'ENSG00000162585': 1,
#  'ENSG00000234396': 1,
#  'ENSG00000157933': 1,
#  'ENSG00000287356': 1,
#  'ENSG00000116151': 1,
#  'ENSG00000272161': 1,
#  'ENSG00000269896': 1,
#  'ENSG00000272420': 1,
#  'ENSG00000157916': 1,
#  'ENSG00000157911': 1,
#  'ENSG00000149527': 1,
#  'ENSG00000224387': 1,
#  'ENSG00000229393': 1,
#  'ENSG00000157881': 1,
#  'ENSG00000197921': 1,
#  'ENSG00000272449': 1,
#  'ENSG00000238164': 1,
#  'ENSG00000157873': 1,
#  'ENSG00000225931': 1,
#  'ENSG00000228037': 1,
#  'ENSG00000289610': 1,
#  'ENSG00000157870': 1,
#  'ENSG00000142606': 1,
#  'ENSG00000237058': 1,
#  'ENSG00000215912': 1,
#  'ENSG00000285945': 1,
#  'ENSG00000283259': 1,
#  'ENSG00000233234': 1,
#  'ENSG00000287396': 1,
#  'ENSG00000231630': 1,
#  'ENSG00000284745': 1,
#  'ENSG00000169717': 1,
#  'ENSG00000177133': 1,
#  'ENSG00000142611': 1,
#  'ENSG00000283572': 1,
#  'ENSG00000226286': 1,
#  'ENSG00000279839': 1,
#  'ENSG00000272235': 1,
#  'ENSG00000287828': 1,
#  'ENSG00000286518': 1,
#  'ENSG00000130762': 1,
#  'ENSG00000272088': 1,
#  'ENSG00000162591': 1,
#  'ENSG00000207776': 1,
#  'ENSG00000238260': 1,
#  'ENSG00000158109': 1,
#  'ENSG00000116213': 1,
#  'ENSG00000078900': 1,
#  'ENSG00000227589': 1,
#  'ENSG00000235131': 1,
#  'ENSG00000227372': 1,
#  'ENSG00000276189': 1,
#  'ENSG00000162592': 1,
#  'ENSG00000235169': 1,
#  'ENSG00000130764': 1,
#  'ENSG00000266075': 1,
#  'ENSG00000272153': 1,
#  'ENSG00000116198': 1,
#  'ENSG00000169598': 1,
#  'ENSG00000198912': 1,
#  'ENSG00000236423': 1,
#  'ENSG00000233304': 1,
#  'ENSG00000226374': 1,
#  'ENSG00000284668': 1,
#  'ENSG00000284703': 1,
#  'ENSG00000229280': 1,
#  'ENSG00000235054': 1,
#  'ENSG00000284694': 1,
#  'ENSG00000227169': 1,
#  'ENSG00000232596': 1,
#  'ENSG00000196581': 1,
#  'ENSG00000287586': 1,
#  'ENSG00000284739': 1,
#  'ENSG00000284674': 1,
#  'ENSG00000231510': 1,
#  'ENSG00000284616': 1,
#  'ENSG00000284692': 1,
#  'ENSG00000284666': 1,
#  'ENSG00000260972': 1,
#  'ENSG00000283356': 1,
#  'ENSG00000236948': 1,
#  'ENSG00000264341': 1,
#  'ENSG00000289893': 1,
#  'ENSG00000264101': 1,
#  'ENSG00000131697': 1,
#  'ENSG00000069424': 1,
#  'ENSG00000116254': 1,
#  'ENSG00000285629': 1,
#  'ENSG00000116251': 1,
#  'ENSG00000226944': 1,
#  'ENSG00000158286': 1,
#  'ENSG00000116237': 1,
#  'ENSG00000225077': 1,
#  'ENSG00000173673': 1,
#  'ENSG00000158292': 1,
#  'ENSG00000097021': 1,
#  'ENSG00000271746': 1,
#  'ENSG00000069812': 1,
#  'ENSG00000187017': 1,
#  'ENSG00000265392': 1,
#  'ENSG00000231868': 1,
#  'ENSG00000215788': 1,
#  'ENSG00000171680': 1,
#  'ENSG00000162408': 1,
#  'ENSG00000253022': 1,
#  'ENSG00000229519': 1,
#  'ENSG00000173662': 1,
#  'ENSG00000204859': 1,
#  'ENSG00000162413': 1,
#  'ENSG00000116273': 1,
#  'ENSG00000041988': 1,
#  'ENSG00000007923': 1,
#  'ENSG00000228750': 1,
#  'ENSG00000284744': 1,
#  'ENSG00000237436': 1,
#  'ENSG00000171735': 1,
#  'ENSG00000227950': 1,
#  'ENSG00000237365': 1,
#  'ENSG00000207056': 1,
#  'ENSG00000237402': 1,
#  'ENSG00000237728': 1,
#  'ENSG00000225126': 1,
#  'ENSG00000270171': 1,
#  'ENSG00000270035': 1,
#  'ENSG00000269978': 1,
#  'ENSG00000049245': 1,
#  'ENSG00000269925': 1,
#  'ENSG00000049246': 1,
#  'ENSG00000236266': 1,
#  'ENSG00000049247': 1,
#  'ENSG00000049249': 1,
#  'ENSG00000270330': 1,
#  'ENSG00000116288': 1,
#  'ENSG00000200344': 1,
#  'ENSG00000284747': 1,
#  'ENSG00000284716': 1,
#  'ENSG00000116285': 1,
#  'ENSG00000238290': 1,
#  'ENSG00000232848': 1,
#  'ENSG00000229305': 1,
#  'ENSG00000288816': 1,
#  'ENSG00000227634': 1,
#  'ENSG00000200975': 1,
#  'ENSG00000233645': 1,
#  'ENSG00000251977': 1,
#  'ENSG00000162426': 1,
#  'ENSG00000252254': 1,
#  'ENSG00000142599': 1,
#  'ENSG00000232912': 1,
#  'ENSG00000221083': 1,
#  'ENSG00000270282': 1,
#  'ENSG00000234619': 1,
#  'ENSG00000224315': 1,
#  'ENSG00000222511': 1,
#  'ENSG00000226545': 1,
#  'ENSG00000228423': 1,
#  'ENSG00000229716': 1,
#  'ENSG00000074800': 1,
#  'ENSG00000274258': 1,
#  'ENSG00000230679': 1,
#  'ENSG00000201725': 1,
#  'ENSG00000238249': 1,
#  'ENSG00000232208': 1,
#  'ENSG00000232663': 1,
#  'ENSG00000131686': 1,
#  'ENSG00000290109': 1,
#  'ENSG00000265141': 1,
#  'ENSG00000197241': 1,
#  'ENSG00000142583': 1,
#  'ENSG00000252404': 1,
#  'ENSG00000180758': 1,
#  'ENSG00000228526': 1,
#  'ENSG00000284357': 1,
#  'ENSG00000289914': 1,
#  'ENSG00000234546': 1,
#  'ENSG00000049239': 1,
#  'ENSG00000171621': 1,
#  'ENSG00000284652': 1,
#  'ENSG00000284693': 1,
#  'ENSG00000252956': 1,
#  'ENSG00000235263': 1,
#  'ENSG00000171612': 1,
#  'ENSG00000231181': 1,
#  'ENSG00000188807': 1,
#  'ENSG00000171608': 1,
#  'ENSG00000179840': 1,
#  'ENSG00000233268': 1,
#  'ENSG00000231789': 1,
#  'ENSG00000171603': 1,
#  'ENSG00000271264': 1,
#  'ENSG00000280113': 1,
#  'ENSG00000178585': 1,
#  'ENSG00000223989': 1,
#  'ENSG00000285701': 1,
#  'ENSG00000162441': 1,
#  'ENSG00000228150': 1,
#  'ENSG00000173614': 1,
#  'ENSG00000202415': 1,
#  'ENSG00000283611': 1,
#  'ENSG00000265521': 1,
#  'ENSG00000241326': 1,
#  'ENSG00000162444': 1,
#  'ENSG00000130939': 1,
#  'ENSG00000224340': 1,
#  'ENSG00000233623': 1,
#  'ENSG00000201746': 1,
#  'ENSG00000054523': 1,
#  'ENSG00000264881': 1,
#  'ENSG00000199562': 1,
#  'ENSG00000264501': 1,
#  'ENSG00000284735': 1,
#  'ENSG00000284642': 1,
#  'ENSG00000142657': 1,
#  'ENSG00000271989': 1,
#  'ENSG00000251503': 1,
#  'ENSG00000175279': 1,
#  'ENSG00000241563': 1,
#  'ENSG00000160049': 1,
#  'ENSG00000203469': 1,
#  'ENSG00000142655': 1,
#  'ENSG00000287727': 1,
#  'ENSG00000243267': 1,
#  'ENSG00000130940': 1,
#  'ENSG00000272078': 1,
#  'ENSG00000225158': 1,
#  'ENSG00000175262': 1,
#  'ENSG00000215785': 1,
#  'ENSG00000120948': 1,
#  'ENSG00000009724': 1,
#  'ENSG00000116649': 1,
#  'ENSG00000171824': 1,
#  'ENSG00000226849': 1,
#  'ENSG00000230337': 1,
#  'ENSG00000198793': 1,
#  'ENSG00000225602': 1,
#  'ENSG00000253086': 1,
#  'ENSG00000171819': 1,
#  'ENSG00000207451': 1,
#  'ENSG00000238173': 1,
#  'ENSG00000120942': 1,
#  'ENSG00000238199': 1,
#  'ENSG00000284646': 1,
#  'ENSG00000224338': 1,
#  'ENSG00000204624': 1,
#  'ENSG00000285833': 1,
#  'ENSG00000235643': 1,
#  'ENSG00000284708': 1,
#  'ENSG00000116661': 1,
#  'ENSG00000132879': 1,
#  'ENSG00000116670': 1,
#  'ENSG00000116663': 1,
#  'ENSG00000162490': 1,
#  'ENSG00000177674': 1,
#  'ENSG00000215910': 1,
#  'ENSG00000177553': 1,
#  'ENSG00000177000': 1,
#  'ENSG00000011021': 1,
#  'ENSG00000276470': 1,
#  'ENSG00000278852': 1,
#  'ENSG00000175206': 1,
#  'ENSG00000275915': 1,
#  'ENSG00000120937': 1,
#  'ENSG00000224904': 1,
#  'ENSG00000285646': 1,
#  'ENSG00000199347': 1,
#  'ENSG00000201801': 1,
#  'ENSG00000116685': 1,
#  'ENSG00000083444': 1,
#  'ENSG00000287384': 1,
#  'ENSG00000116688': 1,
#  'ENSG00000270914': 1,
#  'ENSG00000116691': 1,
#  'ENSG00000202461': 1,
#  'ENSG00000276869': 1,
#  'ENSG00000243539': 1,
#  'ENSG00000120949': 1,
#  'ENSG00000201135': 1,
#  'ENSG00000227875': 1,
#  'ENSG00000285604': 1,
#  'ENSG00000283789': 1,
#  'ENSG00000028137': 1,
#  'ENSG00000263676': 1,
#  'ENSG00000225196': 1,
#  'ENSG00000252969': 1,
#  'ENSG00000048707': 1,
#  'ENSG00000239149': 1,
#  'ENSG00000229484': 1,
#  'ENSG00000162496': 1,
#  'ENSG00000221340': 1,
#  'ENSG00000276830': 1,
#  'ENSG00000288927': 1,
#  'ENSG00000272482': 1,
#  'ENSG00000204518': 1,
#  'ENSG00000226166': 1,
#  'ENSG00000188984': 1,
#  'ENSG00000157330': 1,
#  'ENSG00000116726': 1,
#  'ENSG00000116721': 1,
#  'ENSG00000228338': 1,
#  'ENSG00000239810': 1,
#  'ENSG00000231103': 1,
#  'ENSG00000179172': 1,
#  'ENSG00000120952': 1,
#  'ENSG00000243073': 1,
#  'ENSG00000187545': 1,
#  'ENSG00000204510': 1,
#  'ENSG00000207434': 1,
#  'ENSG00000234064': 1,
#  'ENSG00000232423': 1,
#  'ENSG00000274178': 1,
#  'ENSG00000274764': 1,
#  'ENSG00000277058': 1,
#  'ENSG00000229571': 1,
#  'ENSG00000277862': 1,
#  'ENSG00000236179': 1,
#  'ENSG00000275774': 1,
#  'ENSG00000229978': 1,
#  'ENSG00000290772': 1,
#  'ENSG00000233336': 1,
#  'ENSG00000280267': 1,
#  'ENSG00000179412': 1,
#  'ENSG00000204505': 1,
#  'ENSG00000279169': 1,
#  'ENSG00000279804': 1,
#  'ENSG00000250894': 1,
#  'ENSG00000270601': 1,
#  'ENSG00000231219': 1,
#  'ENSG00000207511': 1,
#  'ENSG00000182330': 1,
#  'ENSG00000237700': 1,
#  'ENSG00000204501': 1,
#  'ENSG00000228229': 1,
#  'ENSG00000204481': 1,
#  'ENSG00000204480': 1,
#  'ENSG00000204479': 1,
#  'ENSG00000204478': 1,
#  'ENSG00000162494': 1,
#  'ENSG00000259961': 1,
#  'ENSG00000215909': 1,
#  'ENSG00000162493': 1,
#  'ENSG00000222952': 1,
#  'ENSG00000237445': 1,
#  'ENSG00000253085': 1,
#  'ENSG00000116731': 1,
#  'ENSG00000289380': 1,
#  'ENSG00000189337': 1,
#  'ENSG00000252151': 1,
#  'ENSG00000231606': 1,
#  'ENSG00000234593': 1,
#  'ENSG00000235829': 1,
#  'ENSG00000287756': 1,
#  'ENSG00000175147': 1,
#  'ENSG00000171729': 1,
#  'ENSG00000204464': 1,
#  'ENSG00000215720': 1,
#  'ENSG00000278480': 1,
#  'ENSG00000142621': 1,
#  'ENSG00000233485': 1,
#  'ENSG00000236045': 1,
#  'ENSG00000228140': 1,
#  'ENSG00000142634': 1,
#  'ENSG00000162438': 1,
#  'ENSG00000142615': 1,
#  'ENSG00000215704': 1,
#  'ENSG00000132906': 1,
#  'ENSG00000116138': 1,
#  'ENSG00000251866': 1,
#  'ENSG00000272510': 1,
#  'ENSG00000116771': 1,
#  'ENSG00000237301': 1,
#  'ENSG00000235084': 1,
#  'ENSG00000252417': 1,
#  'ENSG00000236500': 1,
#  'ENSG00000197312': 1,
#  'ENSG00000215695': 1,
#  'ENSG00000271742': 1,
#  'ENSG00000116786': 1,
#  'ENSG00000237938': 1,
#  'ENSG00000162461': 1,
#  'ENSG00000224459': 1,
#  'ENSG00000162460': 1,
#  'ENSG00000162458': 1,
#  'ENSG00000224321': 1,
#  'ENSG00000233954': 1,
#  'ENSG00000178715': 1,
#  'ENSG00000179743': 1,
#  'ENSG00000065526': 1,
#  'ENSG00000270620': 1,
#  'ENSG00000116809': 1,
#  'ENSG00000234607': 1,
#  'ENSG00000231353': 1,
#  'ENSG00000275503': 1,
#  'ENSG00000224966': 1,
#  'ENSG00000183888': 1,
#  'ENSG00000233078': 1,
#  'ENSG00000173641': 1,
#  'ENSG00000186510': 1,
#  'ENSG00000232456': 1,
#  'ENSG00000184908': 1,
#  'ENSG00000185519': 1,
#  'ENSG00000142627': 1,
#  'ENSG00000227959': 1,
#  'ENSG00000224621': 1,
#  'ENSG00000234166': 1,
#  'ENSG00000142632': 1,
#  'ENSG00000291077': 1,
#  'ENSG00000237276': 1,
#  'ENSG00000288398': 1,
#  'ENSG00000132881': 1,
#  'ENSG00000233929': 1,
#  'ENSG00000037637': 1,
#  'ENSG00000055070': 1,
#  'ENSG00000226457': 1,
#  'ENSG00000187144': 1,
#  'ENSG00000157191': 1,
#  'ENSG00000226029': 1,
#  'ENSG00000290842': 1,
#  'ENSG00000080947': 1,
#  'ENSG00000206652': 1,
#  'ENSG00000261135': 1,
#  'ENSG00000285853': 1,
#  'ENSG00000224174': 1,
#  'ENSG00000233421': 1,
#  'ENSG00000277344': 1,
#  'ENSG00000225710': 1,
#  'ENSG00000219481': 1,
#  'ENSG00000271732': 1,
#  'ENSG00000291072': 1,
#  'ENSG00000215908': 1,
#  'ENSG00000283773': 1,
#  'ENSG00000186301': 1,
#  'ENSG00000282143': 1,
#  'ENSG00000207513': 1,
#  'ENSG00000280114': 1,
#  'ENSG00000236698': 1,
#  'ENSG00000290849': 1,
#  'ENSG00000268869': 1,
#  'ENSG00000279151': 1,
#  'ENSG00000282740': 1,
#  'ENSG00000058453': 1,
#  'ENSG00000290850': 1,
#  'ENSG00000207389': 1,
#  'ENSG00000227684': 1,
#  'ENSG00000290851': 1,
#  'ENSG00000186715': 1,
#  'ENSG00000223643': 1,
#  'ENSG00000230239': 1,
#  'ENSG00000263811': 1,
#  'ENSG00000228549': 1,
#  'ENSG00000277234': 1,
#  'ENSG00000238142': 1,
#  'ENSG00000235241': 1,
#  'ENSG00000207005': 1,
#  'ENSG00000272426': 1,
#  'ENSG00000290122': 1,
#  'ENSG00000117122': 1,
#  'ENSG00000286898': 1,
#  'ENSG00000226526': 1,
#  'ENSG00000159363': 1,
#  'ENSG00000288636': 1,
#  'ENSG00000117118': 1,
#  'ENSG00000117115': 1,
#  'ENSG00000204362': 1,
#  'ENSG00000282843': 1,
#  'ENSG00000142623': 1,
#  'ENSG00000142619': 1,
#  'ENSG00000266634': 1,
#  'ENSG00000159339': 1,
#  'ENSG00000276747': 1,
#  'ENSG00000227751': 1,
#  'ENSG00000179051': 1,
#  'ENSG00000290096': 1,
#  'ENSG00000074964': 1,
#  'ENSG00000236648': 1,
#  'ENSG00000117148': 1,
#  'ENSG00000284653': 1,
#  'ENSG00000261781': 1,
#  'ENSG00000117154': 1,
#  'ENSG00000280222': 1,
#  'ENSG00000230035': 1,
#  'ENSG00000225387': 1,
#  'ENSG00000179023': 1,
#  'ENSG00000235282': 1,
#  'ENSG00000225478': 1,
#  'ENSG00000009709': 1,
#  'ENSG00000179002': 1,
#  'ENSG00000159423': 1,
#  'ENSG00000265606': 1,
#  'ENSG00000221662': 1,
#  'ENSG00000169991': 1,
#  'ENSG00000272084': 1,
#  'ENSG00000127481': 1,
#  'ENSG00000230424': 1,
#  'ENSG00000127463': 1,
#  'ENSG00000053372': 1,
#  'ENSG00000286064': 1,
#  'ENSG00000211454': 1,
#  'ENSG00000162482': 1,
#  'ENSG00000270728': 1,
#  'ENSG00000053371': 1,
#  'ENSG00000200403': 1,
#  'ENSG00000040487': 1,
#  'ENSG00000077549': 1,
#  'ENSG00000240490': 1,
#  'ENSG00000173436': 1,
#  'ENSG00000201609': 1,
#  'ENSG00000235185': 1,
#  'ENSG00000158747': 1,
#  'ENSG00000270136': 1,
#  'ENSG00000226396': 1,
#  'ENSG00000158748': 1,
#  'ENSG00000162542': 1,
#  'ENSG00000178828': 1,
#  'ENSG00000235434': 1,
#  'ENSG00000169914': 1,
#  'ENSG00000188784': 1,
#  'ENSG00000242688': 1,
#  'ENSG00000188257': 1,
#  'ENSG00000127472': 1,
#  'ENSG00000117215': 1,
#  'ENSG00000158786': 1,
#  'ENSG00000227066': 1,
#  'ENSG00000187980': 1,
#  'ENSG00000162543': 1,
#  'ENSG00000228105': 1,
#  'ENSG00000284710': 1,
#  'ENSG00000158816': 1,
#  'ENSG00000226664': 1,
#  'ENSG00000236963': 1,
#  'ENSG00000226487': 1,
#  'ENSG00000284641': 1,
#  'ENSG00000284743': 1,
#  'ENSG00000162545': 1,
#  'ENSG00000289402': 1,
#  'ENSG00000090432': 1,
#  'ENSG00000215520': 1,
#  'ENSG00000183114': 1,
#  'ENSG00000158825': 1,
#  'ENSG00000158828': 1,
#  'ENSG00000284005': 1,
#  'ENSG00000117242': 1,
#  'ENSG00000244038': 1,
#  'ENSG00000117245': 1,
#  'ENSG00000235432': 1,
#  'ENSG00000189410': 1,
#  'ENSG00000233069': 1,
#  'ENSG00000127483': 1,
#  'ENSG00000075151': 1,
#  'ENSG00000251914': 1,
#  'ENSG00000221808': 1,
#  'ENSG00000233072': 1,
#  'ENSG00000236073': 1,
#  'ENSG00000235112': 1,
#  'ENSG00000287192': 1,
#  'ENSG00000117298': 1,
#  'ENSG00000236936': 1,
#  'ENSG00000231105': 1,
#  'ENSG00000236216': 1,
#  'ENSG00000228823': 1,
#  'ENSG00000236009': 1,
#  'ENSG00000227001': 1,
#  'ENSG00000187952': 1,
#  'ENSG00000186543': 1,
#  'ENSG00000142794': 1,
#  'ENSG00000176378': 1,
#  'ENSG00000162551': 1,
#  'ENSG00000289715': 1,
#  'ENSG00000233431': 1,
#  'ENSG00000076864': 1,
#  'ENSG00000090686': 1,
#  'ENSG00000231978': 1,
#  'ENSG00000187942': 1,
#  'ENSG00000142798': 1,
#  'ENSG00000232037': 1,
#  'ENSG00000283234': 1,
#  'ENSG00000219073': 1,
#  'ENSG00000285959': 1,
#  'ENSG00000273610': 1,
#  'ENSG00000201919': 1,
#  'ENSG00000142789': 1,
#  'ENSG00000278124': 1,
#  'ENSG00000201273': 1,
#  'ENSG00000228397': 1,
#  'ENSG00000218510': 1,
#  'ENSG00000289694': 1,
#  'ENSG00000285752': 1,
#  'ENSG00000285794': 1,
#  'ENSG00000070831': 1,
#  'ENSG00000230068': 1,
#  'ENSG00000271428': 1,
#  'ENSG00000162552': 1,
#  'ENSG00000285873': 1,
#  'ENSG00000266564': 1,
#  'ENSG00000234397': 1,
#  'ENSG00000279625': 1,
#  'ENSG00000184677': 1,
#  'ENSG00000237200': 1,
#  'ENSG00000070886': 1,
#  'ENSG00000276835': 1,
#  'ENSG00000173372': 1,
#  'ENSG00000289692': 1,
#  'ENSG00000159189': 1,
#  'ENSG00000173369': 1,
#  'ENSG00000133216': 1,
#  'ENSG00000265422': 1,
#  'ENSG00000225952': 1,
#  'ENSG00000264014': 1,
#  'ENSG00000215906': 1,
#  'ENSG00000227868': 1,
#  'ENSG00000004487': 1,
#  'ENSG00000240553': 1,
#  'ENSG00000263793': 1,
#  'ENSG00000266802': 1,
#  'ENSG00000169641': 1,
#  'ENSG00000229010': 1,
#  'ENSG00000206935': 1,
#  'ENSG00000252578': 1,
#  'ENSG00000289014': 1,
#  'ENSG00000179546': 1,
#  'ENSG00000215381': 1,
#  'ENSG00000261326': 1,
#  'ENSG00000284726': 1,
#  'ENSG00000125944': 1,
#  'ENSG00000125945': 1,
#  'ENSG00000249087': 1,
#  'ENSG00000201405': 1,
#  'ENSG00000271420': 1,
#  'ENSG00000204219': 1,
#  'ENSG00000232482': 1,
#  'ENSG00000088280': 1,
#  'ENSG00000007968': 1,
#  'ENSG00000235052': 1,
#  'ENSG00000117318': 1,
#  'ENSG00000285802': 1,
#  'ENSG00000197880': 1,
#  'ENSG00000229239': 1,
#  'ENSG00000142676': 1,
#  'ENSG00000236810': 1,
#  'ENSG00000011007': 1,
#  'ENSG00000057757': 1,
#  'ENSG00000289835': 1,
#  'ENSG00000011009': 1,
#  'ENSG00000117308': 1,
#  'ENSG00000117305': 1,
#  'ENSG00000179163': 1,
#  'ENSG00000188822': 1,
#  'ENSG00000229106': 1,
#  'ENSG00000232557': 1,
#  'ENSG00000264926': 1,
#  'ENSG00000230228': 1,
#  'ENSG00000189266': 1,
#  'ENSG00000188529': 1,
#  'ENSG00000215905': 1,
#  'ENSG00000225315': 1,
#  'ENSG00000142661': 1,
#  'ENSG00000230703': 1,
#  'ENSG00000142677': 1,
#  'ENSG00000185436': 1,
#  'ENSG00000158055': 1,
#  'ENSG00000230023': 1,
#  'ENSG00000232298': 1,
#  'ENSG00000001460': 1,
#  'ENSG00000001461': 1,
#  'ENSG00000288982': 1,
#  'ENSG00000286061': 1,
#  'ENSG00000117602': 1,
#  'ENSG00000264443': 1,
#  'ENSG00000184454': 1,
#  'ENSG00000227312': 1,
#  'ENSG00000239106': 1,
#  'ENSG00000133226': 1,
#  'ENSG00000284699': 1,
#  'ENSG00000169504': 1,
#  'ENSG00000238482': 1,
#  'ENSG00000020633': 1,
#  'ENSG00000278034': 1,
#  'ENSG00000229162': 1,
#  'ENSG00000261025': 1,
#  'ENSG00000264371': 1,
#  'ENSG00000285823': 1,
#  'ENSG00000233755': 1,
#  'ENSG00000233419': 1,
#  'ENSG00000231953': 1,
#  'ENSG00000117614': 1,
#  'ENSG00000284602': 1,
#  'ENSG00000284657': 1,
#  'ENSG00000117616': 1,
#  'ENSG00000272432': 1,
#  'ENSG00000261349': 1,
#  'ENSG00000187010': 1,
#  'ENSG00000224183': 1,
#  'ENSG00000259984': 1,
#  'ENSG00000183726': 1,
#  'ENSG00000188672': 1,
#  'ENSG00000238084': 1,
#  'ENSG00000204178': 1,
#  'ENSG00000157978': 1,
#  'ENSG00000225643': 1,
#  'ENSG00000117643': 1,
#  'ENSG00000233478': 1,
#  'ENSG00000162430': 1,
#  'ENSG00000255054': 1,
#  'ENSG00000228172': 1,
#  'ENSG00000117640': 1,
#  'ENSG00000272478': 1,
#  'ENSG00000127423': 1,
#  'ENSG00000236528': 1,
#  'ENSG00000182749': 1,
#  'ENSG00000207302': 1,
#  'ENSG00000117632': 1,
#  'ENSG00000229786': 1,
#  'ENSG00000223624': 1,
#  'ENSG00000283938': 1,
#  'ENSG00000158006': 1,
#  'ENSG00000207237': 1,
#  'ENSG00000252190': 1,
#  'ENSG00000252691': 1,
#  'ENSG00000158008': 1,
#  'ENSG00000158014': 1,
#  'ENSG00000284309': 1,
#  'ENSG00000158022': 1,
#  'ENSG00000175087': 1,
#  'ENSG00000197245': 1,
#  'ENSG00000282872': 1,
#  'ENSG00000236782': 1,
#  'ENSG00000142684': 1,
#  'ENSG00000142675': 1,
#  'ENSG00000188782': 1,
#  'ENSG00000236155': 1,
#  'ENSG00000278572': 1,
#  'ENSG00000130695': 1,
#  'ENSG00000270733': 1,
#  'ENSG00000142669': 1,
#  'ENSG00000158062': 1,
#  'ENSG00000169442': 1,
#  'ENSG00000176092': 1,
#  'ENSG00000225854': 1,
#  'ENSG00000176083': 1,
#  'ENSG00000131914': 1,
#  'ENSG00000117682': 1,
#  'ENSG00000223583': 1,
#  'ENSG00000225891': 1,
#  'ENSG00000198830': 1,
#  'ENSG00000224129': 1,
#  'ENSG00000117676': 1,
#  'ENSG00000238705': 1,
#  'ENSG00000243905': 1,
#  'ENSG00000252802': 1,
#  'ENSG00000252429': 1,
#  ...}

# %%
len(genedict)
# Out:
# 119799

# %%
#Filter out the genes which are not in the approved genes file.

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]
var_to_keep_araw = [x for x in araw.var_names if (x in genedict)]

# %%
len(var_to_keep_adata)
# Out:
# 21760

# %%
len(var_to_keep_araw)
# Out:
# 36390

# %%
adata.var
# Out:
#                         gene_ids    feature_types  n_cells  \
# gene_ids
# ENSG00000243485  ENSG00000243485  Gene Expression        9
# ENSG00000238009  ENSG00000238009  Gene Expression       18
# ENSG00000241860  ENSG00000241860  Gene Expression      141
# ENSG00000286448  ENSG00000286448  Gene Expression        7
# ENSG00000237491  ENSG00000237491  Gene Expression     1097
# ...                          ...              ...      ...
# ENSG00000278384  ENSG00000278384  Gene Expression      318
# ENSG00000273748  ENSG00000273748  Gene Expression      182
# ENSG00000271254  ENSG00000271254  Gene Expression      607
# ENSG00000278817  ENSG00000278817  Gene Expression      224
# ENSG00000277196  ENSG00000277196  Gene Expression     3214
#
#                  highly_variablefirst  highly_variable_n
# gene_ids
# ENSG00000243485                 False                  0
# ENSG00000238009                 False                  0
# ENSG00000241860                  True                  1
# ENSG00000286448                 False                  0
# ENSG00000237491                 False                  0
# ...                               ...                ...
# ENSG00000278384                 False                  0
# ENSG00000273748                 False                  0
# ENSG00000271254                 False                  0
# ENSG00000278817                 False                  0
# ENSG00000277196                 False                  0
#
# [21868 rows x 5 columns]

# %%
araw.var
# Out:
#                         gene_ids    feature_types
# gene_ids
# ENSG00000243485  ENSG00000243485  Gene Expression
# ENSG00000237613  ENSG00000237613  Gene Expression
# ENSG00000186092  ENSG00000186092  Gene Expression
# ENSG00000238009  ENSG00000238009  Gene Expression
# ENSG00000239945  ENSG00000239945  Gene Expression
# ...                          ...              ...
# ENSG00000277836  ENSG00000277836  Gene Expression
# ENSG00000278633  ENSG00000278633  Gene Expression
# ENSG00000276017  ENSG00000276017  Gene Expression
# ENSG00000278817  ENSG00000278817  Gene Expression
# ENSG00000277196  ENSG00000277196  Gene Expression
#
# [36601 rows x 2 columns]

# %%
# Modify the anndata object by filtering out the filtered genes.

# %%
adata = adata[:, adata.var.index.isin(var_to_keep_adata)]
araw = araw[:, araw.var.index.isin(var_to_keep_araw)]

# %%
def add_zero():
	global adata
	global araw
	if araw.shape[1] > adata.shape[1]:
		genes_add = [x for x in araw.var.index.to_list() if x not in adata.var.index.to_list()]
		new_matrix = sparse.csr_matrix((adata.X.data, adata.X.indices, adata.X.indptr), shape = araw.shape)
		all_genes = adata.var.index.to_list()
		all_genes.extend(genes_add)
		new_var = pd.DataFrame(index=all_genes)
		new_var = pd.merge(new_var, araw.var, left_index=True, right_index=True, how='left')
		new_var['feature_is_filtered'] = False
		new_var.loc[genes_add, 'feature_is_filtered'] = True
		new_adata = ad.AnnData(X=new_matrix, obs=adata.obs, var=new_var, uns=adata.uns, obsm=adata.obsm)
		if adata.layers:
			for layer in adata.layers:
				new_layer = sparse.csr_matrix((adata.layers[layer].data, adata.layers[layer].indices, adata.layers[layer].indptr), shape = araw.shape)
				new_adata.layers[layer] = new_layer
		new_adata = new_adata[:,araw.var.index.to_list()]
		new_adata.var = new_adata.var.merge(adata.var, left_index=True, right_index=True, how='left')
		adata = new_adata
	else:
		adata.var['feature_is_filtered'] = False

# %%
add_zero()

# %%
adata.var
# Out:
#                       gene_ids_x  feature_types_x  feature_is_filtered  \
# ENSG00000243485  ENSG00000243485  Gene Expression                False
# ENSG00000237613  ENSG00000237613  Gene Expression                 True
# ENSG00000186092  ENSG00000186092  Gene Expression                 True
# ENSG00000238009  ENSG00000238009  Gene Expression                False
# ENSG00000239945  ENSG00000239945  Gene Expression                 True
# ...                          ...              ...                  ...
# ENSG00000277836  ENSG00000277836  Gene Expression                 True
# ENSG00000278633  ENSG00000278633  Gene Expression                 True
# ENSG00000276017  ENSG00000276017  Gene Expression                 True
# ENSG00000278817  ENSG00000278817  Gene Expression                False
# ENSG00000277196  ENSG00000277196  Gene Expression                False
#
#                       gene_ids_y  feature_types_y  n_cells  \
# ENSG00000243485  ENSG00000243485  Gene Expression      9.0
# ENSG00000237613              NaN              NaN      NaN
# ENSG00000186092              NaN              NaN      NaN
# ENSG00000238009  ENSG00000238009  Gene Expression     18.0
# ENSG00000239945              NaN              NaN      NaN
# ...                          ...              ...      ...
# ENSG00000277836              NaN              NaN      NaN
# ENSG00000278633              NaN              NaN      NaN
# ENSG00000276017              NaN              NaN      NaN
# ENSG00000278817  ENSG00000278817  Gene Expression    224.0
# ENSG00000277196  ENSG00000277196  Gene Expression   3214.0
#
#                 highly_variablefirst  highly_variable_n
# ENSG00000243485                False                0.0
# ENSG00000237613                  NaN                NaN
# ENSG00000186092                  NaN                NaN
# ENSG00000238009                False                0.0
# ENSG00000239945                  NaN                NaN
# ...                              ...                ...
# ENSG00000277836                  NaN                NaN
# ENSG00000278633                  NaN                NaN
# ENSG00000276017                  NaN                NaN
# ENSG00000278817                False                0.0
# ENSG00000277196                False                0.0
#
# [36390 rows x 8 columns]

# %%
# View var

# %%
adata.var
# Out:
#                       gene_ids_x  feature_types_x  feature_is_filtered  \
# ENSG00000243485  ENSG00000243485  Gene Expression                False
# ENSG00000237613  ENSG00000237613  Gene Expression                 True
# ENSG00000186092  ENSG00000186092  Gene Expression                 True
# ENSG00000238009  ENSG00000238009  Gene Expression                False
# ENSG00000239945  ENSG00000239945  Gene Expression                 True
# ...                          ...              ...                  ...
# ENSG00000277836  ENSG00000277836  Gene Expression                 True
# ENSG00000278633  ENSG00000278633  Gene Expression                 True
# ENSG00000276017  ENSG00000276017  Gene Expression                 True
# ENSG00000278817  ENSG00000278817  Gene Expression                False
# ENSG00000277196  ENSG00000277196  Gene Expression                False
#
#                       gene_ids_y  feature_types_y  n_cells  \
# ENSG00000243485  ENSG00000243485  Gene Expression      9.0
# ENSG00000237613              NaN              NaN      NaN
# ENSG00000186092              NaN              NaN      NaN
# ENSG00000238009  ENSG00000238009  Gene Expression     18.0
# ENSG00000239945              NaN              NaN      NaN
# ...                          ...              ...      ...
# ENSG00000277836              NaN              NaN      NaN
# ENSG00000278633              NaN              NaN      NaN
# ENSG00000276017              NaN              NaN      NaN
# ENSG00000278817  ENSG00000278817  Gene Expression    224.0
# ENSG00000277196  ENSG00000277196  Gene Expression   3214.0
#
#                 highly_variablefirst  highly_variable_n
# ENSG00000243485                False                0.0
# ENSG00000237613                  NaN                NaN
# ENSG00000186092                  NaN                NaN
# ENSG00000238009                False                0.0
# ENSG00000239945                  NaN                NaN
# ...                              ...                ...
# ENSG00000277836                  NaN                NaN
# ENSG00000278633                  NaN                NaN
# ENSG00000276017                  NaN                NaN
# ENSG00000278817                False                0.0
# ENSG00000277196                False                0.0
#
# [36390 rows x 8 columns]

# %%
araw.var
# Out:
#                         gene_ids    feature_types
# gene_ids
# ENSG00000243485  ENSG00000243485  Gene Expression
# ENSG00000237613  ENSG00000237613  Gene Expression
# ENSG00000186092  ENSG00000186092  Gene Expression
# ENSG00000238009  ENSG00000238009  Gene Expression
# ENSG00000239945  ENSG00000239945  Gene Expression
# ...                          ...              ...
# ENSG00000277836  ENSG00000277836  Gene Expression
# ENSG00000278633  ENSG00000278633  Gene Expression
# ENSG00000276017  ENSG00000276017  Gene Expression
# ENSG00000278817  ENSG00000278817  Gene Expression
# ENSG00000277196  ENSG00000277196  Gene Expression
#
# [36390 rows x 2 columns]

# %% [markdown]
# feature is filtered

# %%
list(adata.var['feature_is_filtered'].unique())
# Out:
# [False, True]

# %%
false_count = (adata.var['feature_is_filtered']== False).sum()

# %%
false_count
# Out:
# 21760

# %%
adata.var
# Out:
#                       gene_ids_x  feature_types_x  feature_is_filtered  \
# ENSG00000243485  ENSG00000243485  Gene Expression                False
# ENSG00000237613  ENSG00000237613  Gene Expression                 True
# ENSG00000186092  ENSG00000186092  Gene Expression                 True
# ENSG00000238009  ENSG00000238009  Gene Expression                False
# ENSG00000239945  ENSG00000239945  Gene Expression                 True
# ...                          ...              ...                  ...
# ENSG00000277836  ENSG00000277836  Gene Expression                 True
# ENSG00000278633  ENSG00000278633  Gene Expression                 True
# ENSG00000276017  ENSG00000276017  Gene Expression                 True
# ENSG00000278817  ENSG00000278817  Gene Expression                False
# ENSG00000277196  ENSG00000277196  Gene Expression                False
#
#                       gene_ids_y  feature_types_y  n_cells  \
# ENSG00000243485  ENSG00000243485  Gene Expression      9.0
# ENSG00000237613              NaN              NaN      NaN
# ENSG00000186092              NaN              NaN      NaN
# ENSG00000238009  ENSG00000238009  Gene Expression     18.0
# ENSG00000239945              NaN              NaN      NaN
# ...                          ...              ...      ...
# ENSG00000277836              NaN              NaN      NaN
# ENSG00000278633              NaN              NaN      NaN
# ENSG00000276017              NaN              NaN      NaN
# ENSG00000278817  ENSG00000278817  Gene Expression    224.0
# ENSG00000277196  ENSG00000277196  Gene Expression   3214.0
#
#                 highly_variablefirst  highly_variable_n
# ENSG00000243485                False                0.0
# ENSG00000237613                  NaN                NaN
# ENSG00000186092                  NaN                NaN
# ENSG00000238009                False                0.0
# ENSG00000239945                  NaN                NaN
# ...                              ...                ...
# ENSG00000277836                  NaN                NaN
# ENSG00000278633                  NaN                NaN
# ENSG00000276017                  NaN                NaN
# ENSG00000278817                False                0.0
# ENSG00000277196                False                0.0
#
# [36390 rows x 8 columns]

# %%
araw.var
# Out:
#                         gene_ids    feature_types
# gene_ids
# ENSG00000243485  ENSG00000243485  Gene Expression
# ENSG00000237613  ENSG00000237613  Gene Expression
# ENSG00000186092  ENSG00000186092  Gene Expression
# ENSG00000238009  ENSG00000238009  Gene Expression
# ENSG00000239945  ENSG00000239945  Gene Expression
# ...                          ...              ...
# ENSG00000277836  ENSG00000277836  Gene Expression
# ENSG00000278633  ENSG00000278633  Gene Expression
# ENSG00000276017  ENSG00000276017  Gene Expression
# ENSG00000278817  ENSG00000278817  Gene Expression
# ENSG00000277196  ENSG00000277196  Gene Expression
#
# [36390 rows x 2 columns]

# %%
del adata.var['gene_ids_x']
del araw.var['gene_ids']

# %% [markdown]
# #### **obs (Cell metadata)**

# %%
#view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score phase leiden          predicted_labels  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028    G1      4  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267    G1      7  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150    G1      0                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696    G1      0                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853    G1      7                  Late tip
# ...                    ...        ...   ...    ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153   G2M      5                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186    G1      6                  Late tip
# TTTGTCATCGCCTGAG  0.478485   0.114177     S      5                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052     S      3                  Late tip
# TTTGTCATCTCGTATT -0.011147  -0.161577    G1      8                  Late tip
#
#                  over_clustering           majority_voting  conf_score  \
# AAACCTGAGCAGCGTA              19  Pulmonary neuroendocrine    0.670715
# AAACCTGAGTACGTAA              46  Pulmonary neuroendocrine    0.755056
# AAACCTGCACCATGTA              53                  Late tip    0.979895
# AAACCTGCACCTATCC              83                  Late tip    0.642230
# AAACCTGCACTTAACG              20                  Late tip    0.863851
# ...                          ...                       ...         ...
# TTTGTCATCCACGAAT              36                  Late tip    0.235389
# TTTGTCATCGAGAGCA              85                 Mid fibro    0.735850
# TTTGTCATCGCCTGAG              31                  Late tip    0.998556
# TTTGTCATCTATCGCC              18                 Mid fibro    0.996191
# TTTGTCATCTCGTATT              89                 Mid fibro    0.999624
#
#                  leiden_R                      celltype      donor
# AAACCTGAGCAGCGTA        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG        7    Differentiating basal-like  HDBR16392
# ...                   ...                           ...        ...
# TTTGTCATCCACGAAT        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT      8,0                      AT2-like  HDBR15934
#
# [9619 rows x 19 columns]

# %%
# view the column names in obs

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor'],
#       dtype='object')

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score phase leiden          predicted_labels  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028    G1      4  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267    G1      7  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150    G1      0                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696    G1      0                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853    G1      7                  Late tip
# ...                    ...        ...   ...    ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153   G2M      5                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186    G1      6                  Late tip
# TTTGTCATCGCCTGAG  0.478485   0.114177     S      5                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052     S      3                  Late tip
# TTTGTCATCTCGTATT -0.011147  -0.161577    G1      8                  Late tip
#
#                  over_clustering           majority_voting  conf_score  \
# AAACCTGAGCAGCGTA              19  Pulmonary neuroendocrine    0.670715
# AAACCTGAGTACGTAA              46  Pulmonary neuroendocrine    0.755056
# AAACCTGCACCATGTA              53                  Late tip    0.979895
# AAACCTGCACCTATCC              83                  Late tip    0.642230
# AAACCTGCACTTAACG              20                  Late tip    0.863851
# ...                          ...                       ...         ...
# TTTGTCATCCACGAAT              36                  Late tip    0.235389
# TTTGTCATCGAGAGCA              85                 Mid fibro    0.735850
# TTTGTCATCGCCTGAG              31                  Late tip    0.998556
# TTTGTCATCTATCGCC              18                 Mid fibro    0.996191
# TTTGTCATCTCGTATT              89                 Mid fibro    0.999624
#
#                  leiden_R                      celltype      donor
# AAACCTGAGCAGCGTA        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG        7    Differentiating basal-like  HDBR16392
# ...                   ...                           ...        ...
# TTTGTCATCCACGAAT        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT      8,0                      AT2-like  HDBR15934
#
# [9619 rows x 19 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['barcodes'] = adata.obs_names

# %%
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
assay_info = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Megagut/Suppl_info/barcode_assay_summary.csv')

# %%
mapping = dict(zip(assay_info['barcode'], assay_info['assay_summary']))

# %%
adata.obs['assay'] = adata.obs['barcodes'].map(mapping)

# %%
list(adata.obs['assay'].unique())
# Out:
# ['3pv2_5pv1_5pv2', '3pv2_5pv1_5pv2,3pv3', '3pv2_5pv1_5pv2,multiome']

# %%
mapping= {'3pv2_5pv1_5pv2':'EFO:0030004', '3pv2_5pv1_5pv2,3pv3':'EFO:0009922', '3pv2_5pv1_5pv2,multiome':'EFO:0030004'}

# %%
# Convert 'assay' column values to strings
adata.obs['assay'] = adata.obs['assay'].astype(str)

# %%
adata.obs['assay_ontology_term_id'] = ['EFO:0011025']* len(adata.obs)

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...          predicted_labels  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                  Late tip
# ...                    ...        ...  ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                  Late tip
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                  Late tip
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                  Late tip
#
#                  over_clustering           majority_voting conf_score  \
# AAACCTGAGCAGCGTA              19  Pulmonary neuroendocrine   0.670715
# AAACCTGAGTACGTAA              46  Pulmonary neuroendocrine   0.755056
# AAACCTGCACCATGTA              53                  Late tip   0.979895
# AAACCTGCACCTATCC              83                  Late tip   0.642230
# AAACCTGCACTTAACG              20                  Late tip   0.863851
# ...                          ...                       ...        ...
# TTTGTCATCCACGAAT              36                  Late tip   0.235389
# TTTGTCATCGAGAGCA              85                 Mid fibro   0.735850
# TTTGTCATCGCCTGAG              31                  Late tip   0.998556
# TTTGTCATCTATCGCC              18                 Mid fibro   0.996191
# TTTGTCATCTCGTATT              89                 Mid fibro   0.999624
#
#                  leiden_R                      celltype      donor  \
# AAACCTGAGCAGCGTA        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG        7    Differentiating basal-like  HDBR16392
# ...                   ...                           ...        ...
# TTTGTCATCCACGAAT        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT      8,0                      AT2-like  HDBR15934
#
#                           barcodes           assay assay_ontology_term_id
# AAACCTGAGCAGCGTA  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGAGTACGTAA  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCATGTA  AAACCTGCACCATGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCTATCC  AAACCTGCACCTATCC  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACTTAACG  AAACCTGCACTTAACG  3pv2_5pv1_5pv2            EFO:0011025
# ...                            ...             ...                    ...
# TTTGTCATCCACGAAT  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGAGAGCA  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGCCTGAG  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTATCGCC  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTCGTATT  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2            EFO:0011025
#
# [9619 rows x 22 columns]

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
#identify the column in adata.obs related. to cell type annotation

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id'],
#       dtype='object')

# %%
list(adata.obs['celltype'].unique())
# Out:
# ['Intermediate',
#  'Differentiating basal-like',
#  'AT2-like',
#  'Cycling AT2',
#  'NE prog',
#  'Differentiating pulmonary NE',
#  'CXCL+ AT2-like',
#  'Ciliated-like']

# %%
# create a dictionary of cell type and ontology term

# %%
mapping= {'Intermediate':'CL:0002368',
'Differentiating basal-like':'CL:0000646',
'AT2-like':'CL:0002063',
'Cycling AT2':'CL:0002063',
'NE prog':'CL:1000223',
'Differentiating pulmonary NE':'CL:1000223',
'CXCL+ AT2-like':'CL:0002063',
'Ciliated-like':'CL:1000271'
}

# %%
# add the cell_type_ontology_term_id column

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['celltype'].map(mapping)

# %%
# change datatype of the column

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... over_clustering  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...              19
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...              46
# AAACCTGCACCATGTA -0.070328  -0.124150  ...              53
# AAACCTGCACCTATCC -0.082849  -0.208696  ...              83
# AAACCTGCACTTAACG -0.119884  -0.196853  ...              20
# ...                    ...        ...  ...             ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...              36
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...              85
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...              31
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...              18
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...              89
#
#                            majority_voting conf_score leiden_R  \
# AAACCTGAGCAGCGTA  Pulmonary neuroendocrine   0.670715        4
# AAACCTGAGTACGTAA  Pulmonary neuroendocrine   0.755056        7
# AAACCTGCACCATGTA                  Late tip   0.979895        0
# AAACCTGCACCTATCC                  Late tip   0.642230        0
# AAACCTGCACTTAACG                  Late tip   0.863851        7
# ...                                    ...        ...      ...
# TTTGTCATCCACGAAT                  Late tip   0.235389        5
# TTTGTCATCGAGAGCA                 Mid fibro   0.735850        6
# TTTGTCATCGCCTGAG                  Late tip   0.998556        5
# TTTGTCATCTATCGCC                 Mid fibro   0.996191      3,0
# TTTGTCATCTCGTATT                 Mid fibro   0.999624      8,0
#
#                                       celltype      donor          barcodes  \
# AAACCTGAGCAGCGTA                  Intermediate  HDBR16402  AAACCTGAGCAGCGTA
# AAACCTGAGTACGTAA    Differentiating basal-like  HDBR16402  AAACCTGAGTACGTAA
# AAACCTGCACCATGTA                      AT2-like  HDBR15934  AAACCTGCACCATGTA
# AAACCTGCACCTATCC                      AT2-like  HDBR15934  AAACCTGCACCTATCC
# AAACCTGCACTTAACG    Differentiating basal-like  HDBR16392  AAACCTGCACTTAACG
# ...                                        ...        ...               ...
# TTTGTCATCCACGAAT                   Cycling AT2  HDBR16392  TTTGTCATCCACGAAT
# TTTGTCATCGAGAGCA                      AT2-like  HDBR16392  TTTGTCATCGAGAGCA
# TTTGTCATCGCCTGAG                   Cycling AT2  HDBR16402  TTTGTCATCGCCTGAG
# TTTGTCATCTATCGCC  Differentiating pulmonary NE   doublets  TTTGTCATCTATCGCC
# TTTGTCATCTCGTATT                      AT2-like  HDBR15934  TTTGTCATCTCGTATT
#
#                            assay assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGAGTACGTAA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCATGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCTATCC  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACTTAACG  3pv2_5pv1_5pv2            EFO:0011025
# ...                          ...                    ...
# TTTGTCATCCACGAAT  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTATCGCC  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTCGTATT  3pv2_5pv1_5pv2            EFO:0011025
#
#                  cell_type_ontology_term_id
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
# [9619 rows x 23 columns]

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
# identify the column in adata which corresponds to age

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id'],
#       dtype='object')

# %%
mapping = {'12.0':'HsapDv:0000050', '20.0':'HsapDv:0000058', '9.0':'HsapDv:0000047', '8.0':'HsapDv:0000046', '18.0':'HsapDv:0000056', '22.0':'HsapDv:0000060', '15.0':'HsapDv:0000053', '6.86':'HsapDv:0000029', '5.0':'HsapDv:0000022', '11.0':'HsapDv:0000049', 'nan':'unknown'}

# %%
adata.obs['development_stage_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
# change datatype of the column

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
# view unique values of development_stage_ontology_term_id column

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['unknown']

# %%
# view adata.obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...           majority_voting  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  Pulmonary neuroendocrine
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  Pulmonary neuroendocrine
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                  Late tip
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                  Late tip
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                  Late tip
# ...                    ...        ...  ...                       ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                  Late tip
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                 Mid fibro
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                  Late tip
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                 Mid fibro
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                 Mid fibro
#
#                  conf_score leiden_R                      celltype      donor  \
# AAACCTGAGCAGCGTA   0.670715        4                  Intermediate  HDBR16402
# AAACCTGAGTACGTAA   0.755056        7    Differentiating basal-like  HDBR16402
# AAACCTGCACCATGTA   0.979895        0                      AT2-like  HDBR15934
# AAACCTGCACCTATCC   0.642230        0                      AT2-like  HDBR15934
# AAACCTGCACTTAACG   0.863851        7    Differentiating basal-like  HDBR16392
# ...                     ...      ...                           ...        ...
# TTTGTCATCCACGAAT   0.235389        5                   Cycling AT2  HDBR16392
# TTTGTCATCGAGAGCA   0.735850        6                      AT2-like  HDBR16392
# TTTGTCATCGCCTGAG   0.998556        5                   Cycling AT2  HDBR16402
# TTTGTCATCTATCGCC   0.996191      3,0  Differentiating pulmonary NE   doublets
# TTTGTCATCTCGTATT   0.999624      8,0                      AT2-like  HDBR15934
#
#                           barcodes           assay assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGAGTACGTAA  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCATGTA  AAACCTGCACCATGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCTATCC  AAACCTGCACCTATCC  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACTTAACG  AAACCTGCACTTAACG  3pv2_5pv1_5pv2            EFO:0011025
# ...                            ...             ...                    ...
# TTTGTCATCCACGAAT  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGAGAGCA  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGCCTGAG  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTATCGCC  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTCGTATT  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2            EFO:0011025
#
#                  cell_type_ontology_term_id development_stage_ontology_term_id
# AAACCTGAGCAGCGTA                 CL:0002368                            unknown
# AAACCTGAGTACGTAA                 CL:0000646                            unknown
# AAACCTGCACCATGTA                 CL:0002063                            unknown
# AAACCTGCACCTATCC                 CL:0002063                            unknown
# AAACCTGCACTTAACG                 CL:0000646                            unknown
# ...                                     ...                                ...
# TTTGTCATCCACGAAT                 CL:0002063                            unknown
# TTTGTCATCGAGAGCA                 CL:0002063                            unknown
# TTTGTCATCGCCTGAG                 CL:0002063                            unknown
# TTTGTCATCTATCGCC                 CL:1000223                            unknown
# TTTGTCATCTCGTATT                 CL:0002063                            unknown
#
# [9619 rows x 24 columns]

# %% [markdown]
# #### **donor_id**

# %%
#identify the column in adata.obs which provides donor information

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id'],
#       dtype='object')

# %%
# add the donor_id column

# %%
adata.obs['donor'] = adata.obs['donor'].astype(str)

# %%
adata.obs['donor'].fillna('pooled', inplace=True)
adata.obs['donor'].replace('', 'pooled', inplace=True)

# Replace 'doublets' with 'pooled'
adata.obs['donor'].replace('doublets', 'pooled', inplace=True)

# %%
adata.obs['donor_id'] = adata.obs['donor']

# %%
#adata.obs['donor_id'] = ['unknown'] * len(adata.obs['names'])

# %%
# change datatype of the column

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
# view unique values of donor_id column

# %%
list(adata.obs['donor_id'].unique())
# Out:
# ['HDBR16402', 'HDBR15934', 'HDBR16392', 'pooled', 'HDBR16011']

# %%
#view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... conf_score leiden_R  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...   0.670715        4
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...   0.755056        7
# AAACCTGCACCATGTA -0.070328  -0.124150  ...   0.979895        0
# AAACCTGCACCTATCC -0.082849  -0.208696  ...   0.642230        0
# AAACCTGCACTTAACG -0.119884  -0.196853  ...   0.863851        7
# ...                    ...        ...  ...        ...      ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...   0.235389        5
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...   0.735850        6
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...   0.998556        5
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...   0.996191      3,0
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...   0.999624      8,0
#
#                                       celltype      donor          barcodes  \
# AAACCTGAGCAGCGTA                  Intermediate  HDBR16402  AAACCTGAGCAGCGTA
# AAACCTGAGTACGTAA    Differentiating basal-like  HDBR16402  AAACCTGAGTACGTAA
# AAACCTGCACCATGTA                      AT2-like  HDBR15934  AAACCTGCACCATGTA
# AAACCTGCACCTATCC                      AT2-like  HDBR15934  AAACCTGCACCTATCC
# AAACCTGCACTTAACG    Differentiating basal-like  HDBR16392  AAACCTGCACTTAACG
# ...                                        ...        ...               ...
# TTTGTCATCCACGAAT                   Cycling AT2  HDBR16392  TTTGTCATCCACGAAT
# TTTGTCATCGAGAGCA                      AT2-like  HDBR16392  TTTGTCATCGAGAGCA
# TTTGTCATCGCCTGAG                   Cycling AT2  HDBR16402  TTTGTCATCGCCTGAG
# TTTGTCATCTATCGCC  Differentiating pulmonary NE     pooled  TTTGTCATCTATCGCC
# TTTGTCATCTCGTATT                      AT2-like  HDBR15934  TTTGTCATCTCGTATT
#
#                            assay assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGAGTACGTAA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCATGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCTATCC  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACTTAACG  3pv2_5pv1_5pv2            EFO:0011025
# ...                          ...                    ...
# TTTGTCATCCACGAAT  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTATCGCC  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTCGTATT  3pv2_5pv1_5pv2            EFO:0011025
#
#                  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
# [9619 rows x 25 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id'],
#       dtype='object')

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
adata.obs['disease_ontology_term_id']= ['PATO:0000461'] * len(adata.obs)

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... leiden_R  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...        4
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...        7
# AAACCTGCACCATGTA -0.070328  -0.124150  ...        0
# AAACCTGCACCTATCC -0.082849  -0.208696  ...        0
# AAACCTGCACTTAACG -0.119884  -0.196853  ...        7
# ...                    ...        ...  ...      ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...        5
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...        6
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...        5
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...      3,0
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...      8,0
#
#                                       celltype      donor          barcodes  \
# AAACCTGAGCAGCGTA                  Intermediate  HDBR16402  AAACCTGAGCAGCGTA
# AAACCTGAGTACGTAA    Differentiating basal-like  HDBR16402  AAACCTGAGTACGTAA
# AAACCTGCACCATGTA                      AT2-like  HDBR15934  AAACCTGCACCATGTA
# AAACCTGCACCTATCC                      AT2-like  HDBR15934  AAACCTGCACCTATCC
# AAACCTGCACTTAACG    Differentiating basal-like  HDBR16392  AAACCTGCACTTAACG
# ...                                        ...        ...               ...
# TTTGTCATCCACGAAT                   Cycling AT2  HDBR16392  TTTGTCATCCACGAAT
# TTTGTCATCGAGAGCA                      AT2-like  HDBR16392  TTTGTCATCGAGAGCA
# TTTGTCATCGCCTGAG                   Cycling AT2  HDBR16402  TTTGTCATCGCCTGAG
# TTTGTCATCTATCGCC  Differentiating pulmonary NE     pooled  TTTGTCATCTATCGCC
# TTTGTCATCTCGTATT                      AT2-like  HDBR15934  TTTGTCATCTCGTATT
#
#                            assay  assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGAGTACGTAA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACCATGTA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACCTATCC  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACTTAACG  3pv2_5pv1_5pv2             EFO:0011025
# ...                          ...                     ...
# TTTGTCATCCACGAAT  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCTATCGCC  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCTCGTATT  3pv2_5pv1_5pv2             EFO:0011025
#
#                  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id
# AAACCTGAGCAGCGTA             PATO:0000461
# AAACCTGAGTACGTAA             PATO:0000461
# AAACCTGCACCATGTA             PATO:0000461
# AAACCTGCACCTATCC             PATO:0000461
# AAACCTGCACTTAACG             PATO:0000461
# ...                                   ...
# TTTGTCATCCACGAAT             PATO:0000461
# TTTGTCATCGAGAGCA             PATO:0000461
# TTTGTCATCGCCTGAG             PATO:0000461
# TTTGTCATCTATCGCC             PATO:0000461
# TTTGTCATCTCGTATT             PATO:0000461
#
# [9619 rows x 26 columns]

# %%
# change datatype of the column

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... leiden_R  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...        4
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...        7
# AAACCTGCACCATGTA -0.070328  -0.124150  ...        0
# AAACCTGCACCTATCC -0.082849  -0.208696  ...        0
# AAACCTGCACTTAACG -0.119884  -0.196853  ...        7
# ...                    ...        ...  ...      ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...        5
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...        6
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...        5
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...      3,0
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...      8,0
#
#                                       celltype      donor          barcodes  \
# AAACCTGAGCAGCGTA                  Intermediate  HDBR16402  AAACCTGAGCAGCGTA
# AAACCTGAGTACGTAA    Differentiating basal-like  HDBR16402  AAACCTGAGTACGTAA
# AAACCTGCACCATGTA                      AT2-like  HDBR15934  AAACCTGCACCATGTA
# AAACCTGCACCTATCC                      AT2-like  HDBR15934  AAACCTGCACCTATCC
# AAACCTGCACTTAACG    Differentiating basal-like  HDBR16392  AAACCTGCACTTAACG
# ...                                        ...        ...               ...
# TTTGTCATCCACGAAT                   Cycling AT2  HDBR16392  TTTGTCATCCACGAAT
# TTTGTCATCGAGAGCA                      AT2-like  HDBR16392  TTTGTCATCGAGAGCA
# TTTGTCATCGCCTGAG                   Cycling AT2  HDBR16402  TTTGTCATCGCCTGAG
# TTTGTCATCTATCGCC  Differentiating pulmonary NE     pooled  TTTGTCATCTATCGCC
# TTTGTCATCTCGTATT                      AT2-like  HDBR15934  TTTGTCATCTCGTATT
#
#                            assay  assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGAGTACGTAA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACCATGTA  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACCTATCC  3pv2_5pv1_5pv2             EFO:0011025
# AAACCTGCACTTAACG  3pv2_5pv1_5pv2             EFO:0011025
# ...                          ...                     ...
# TTTGTCATCCACGAAT  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCTATCGCC  3pv2_5pv1_5pv2             EFO:0011025
# TTTGTCATCTCGTATT  3pv2_5pv1_5pv2             EFO:0011025
#
#                  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id
# AAACCTGAGCAGCGTA             PATO:0000461
# AAACCTGAGTACGTAA             PATO:0000461
# AAACCTGCACCATGTA             PATO:0000461
# AAACCTGCACCTATCC             PATO:0000461
# AAACCTGCACTTAACG             PATO:0000461
# ...                                   ...
# TTTGTCATCCACGAAT             PATO:0000461
# TTTGTCATCGAGAGCA             PATO:0000461
# TTTGTCATCGCCTGAG             PATO:0000461
# TTTGTCATCTATCGCC             PATO:0000461
# TTTGTCATCTCGTATT             PATO:0000461
#
# [9619 rows x 26 columns]

# %% [markdown]
# #### **is_primary_data**

# %%
import pandas as pd

# Assuming adata.obs is a pandas DataFrame
# Replace 'adata.obs' with the actual name of your DataFrame if different

# Set 'is_primary_data' to True for all entries initially
adata.obs['is_primary_data'] = True

# Set 'is_primary_data' to False for entries with 'batch' values starting with '5891' or 'WSSS'
adata.obs.loc[adata.obs['batch'].str.startswith(('5891', 'WSSS')), 'is_primary_data'] = False

# %%
list(adata.obs['is_primary_data'].unique())
# Out:
# [True]

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...                      celltype  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                  Intermediate
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...    Differentiating basal-like
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                      AT2-like
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                      AT2-like
# AAACCTGCACTTAACG -0.119884  -0.196853  ...    Differentiating basal-like
# ...                    ...        ...  ...                           ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                   Cycling AT2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                      AT2-like
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                   Cycling AT2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  Differentiating pulmonary NE
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                      AT2-like
#
#                       donor          barcodes           assay  \
# AAACCTGAGCAGCGTA  HDBR16402  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA  HDBR16402  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA  HDBR15934  AAACCTGCACCATGTA  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC  HDBR15934  AAACCTGCACCTATCC  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG  HDBR16392  AAACCTGCACTTAACG  3pv2_5pv1_5pv2
# ...                     ...               ...             ...
# TTTGTCATCCACGAAT  HDBR16392  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA  HDBR16392  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  HDBR16402  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC     pooled  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT  HDBR15934  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                  CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                  CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                  CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                  CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                  CL:0000646
# ...                                 ...                         ...
# TTTGTCATCCACGAAT            EFO:0011025                  CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                  CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                  CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                  CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                  CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id is_primary_data
# AAACCTGAGCAGCGTA             PATO:0000461            True
# AAACCTGAGTACGTAA             PATO:0000461            True
# AAACCTGCACCATGTA             PATO:0000461            True
# AAACCTGCACCTATCC             PATO:0000461            True
# AAACCTGCACTTAACG             PATO:0000461            True
# ...                                   ...             ...
# TTTGTCATCCACGAAT             PATO:0000461            True
# TTTGTCATCGAGAGCA             PATO:0000461            True
# TTTGTCATCGCCTGAG             PATO:0000461            True
# TTTGTCATCTATCGCC             PATO:0000461            True
# TTTGTCATCTCGTATT             PATO:0000461            True
#
# [9619 rows x 27 columns]

# %%
adata.obs['is_primary_data'] = [True] * len(adata.obs)

# %%
#change data type of column

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...                      celltype  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                  Intermediate
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...    Differentiating basal-like
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                      AT2-like
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                      AT2-like
# AAACCTGCACTTAACG -0.119884  -0.196853  ...    Differentiating basal-like
# ...                    ...        ...  ...                           ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                   Cycling AT2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                      AT2-like
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                   Cycling AT2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  Differentiating pulmonary NE
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                      AT2-like
#
#                       donor          barcodes           assay  \
# AAACCTGAGCAGCGTA  HDBR16402  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA  HDBR16402  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA  HDBR15934  AAACCTGCACCATGTA  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC  HDBR15934  AAACCTGCACCTATCC  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG  HDBR16392  AAACCTGCACTTAACG  3pv2_5pv1_5pv2
# ...                     ...               ...             ...
# TTTGTCATCCACGAAT  HDBR16392  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA  HDBR16392  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  HDBR16402  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC     pooled  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT  HDBR15934  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                  CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                  CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                  CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                  CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                  CL:0000646
# ...                                 ...                         ...
# TTTGTCATCCACGAAT            EFO:0011025                  CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                  CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                  CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                  CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                  CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id is_primary_data
# AAACCTGAGCAGCGTA             PATO:0000461            True
# AAACCTGAGTACGTAA             PATO:0000461            True
# AAACCTGCACCATGTA             PATO:0000461            True
# AAACCTGCACCTATCC             PATO:0000461            True
# AAACCTGCACTTAACG             PATO:0000461            True
# ...                                   ...             ...
# TTTGTCATCCACGAAT             PATO:0000461            True
# TTTGTCATCGAGAGCA             PATO:0000461            True
# TTTGTCATCGCCTGAG             PATO:0000461            True
# TTTGTCATCTATCGCC             PATO:0000461            True
# TTTGTCATCTCGTATT             PATO:0000461            True
#
# [9619 rows x 27 columns]

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
# assign organism id

# %%
adata.obs['organism_ontology_term_id'] = ['NCBITaxon:9606'] * len(adata.obs)

# %%
#change data type of column

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...      donor          barcodes  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  HDBR16402  AAACCTGAGCAGCGTA
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  HDBR16402  AAACCTGAGTACGTAA
# AAACCTGCACCATGTA -0.070328  -0.124150  ...  HDBR15934  AAACCTGCACCATGTA
# AAACCTGCACCTATCC -0.082849  -0.208696  ...  HDBR15934  AAACCTGCACCTATCC
# AAACCTGCACTTAACG -0.119884  -0.196853  ...  HDBR16392  AAACCTGCACTTAACG
# ...                    ...        ...  ...        ...               ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...  HDBR16392  TTTGTCATCCACGAAT
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...  HDBR16392  TTTGTCATCGAGAGCA
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...  HDBR16402  TTTGTCATCGCCTGAG
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...     pooled  TTTGTCATCTATCGCC
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...  HDBR15934  TTTGTCATCTCGTATT
#
#                            assay assay_ontology_term_id  \
# AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGAGTACGTAA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCATGTA  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACCTATCC  3pv2_5pv1_5pv2            EFO:0011025
# AAACCTGCACTTAACG  3pv2_5pv1_5pv2            EFO:0011025
# ...                          ...                    ...
# TTTGTCATCCACGAAT  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTATCGCC  3pv2_5pv1_5pv2            EFO:0011025
# TTTGTCATCTCGTATT  3pv2_5pv1_5pv2            EFO:0011025
#
#                  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
#                   development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                             unknown  HDBR16402
# AAACCTGAGTACGTAA                             unknown  HDBR16402
# AAACCTGCACCATGTA                             unknown  HDBR15934
# AAACCTGCACCTATCC                             unknown  HDBR15934
# AAACCTGCACTTAACG                             unknown  HDBR16392
# ...                                              ...        ...
# TTTGTCATCCACGAAT                             unknown  HDBR16392
# TTTGTCATCGAGAGCA                             unknown  HDBR16392
# TTTGTCATCGCCTGAG                             unknown  HDBR16402
# TTTGTCATCTATCGCC                             unknown     pooled
# TTTGTCATCTCGTATT                             unknown  HDBR15934
#
#                  disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA             PATO:0000461            True
# AAACCTGAGTACGTAA             PATO:0000461            True
# AAACCTGCACCATGTA             PATO:0000461            True
# AAACCTGCACCTATCC             PATO:0000461            True
# AAACCTGCACTTAACG             PATO:0000461            True
# ...                                   ...             ...
# TTTGTCATCCACGAAT             PATO:0000461            True
# TTTGTCATCGAGAGCA             PATO:0000461            True
# TTTGTCATCGCCTGAG             PATO:0000461            True
# TTTGTCATCTATCGCC             PATO:0000461            True
# TTTGTCATCTCGTATT             PATO:0000461            True
#
#                  organism_ontology_term_id
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
# [9619 rows x 28 columns]

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
# change data type

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...          barcodes           assay  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA -0.070328  -0.124150  ...  AAACCTGCACCATGTA  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC -0.082849  -0.208696  ...  AAACCTGCACCTATCC  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG -0.119884  -0.196853  ...  AAACCTGCACTTAACG  3pv2_5pv1_5pv2
# ...                    ...        ...  ...               ...             ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                 CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                 CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                 CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                 CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                 CL:0000646
# ...                                 ...                        ...
# TTTGTCATCCACGAAT            EFO:0011025                 CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                 CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                 CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                 CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA             PATO:0000461            True
# AAACCTGAGTACGTAA             PATO:0000461            True
# AAACCTGCACCATGTA             PATO:0000461            True
# AAACCTGCACCTATCC             PATO:0000461            True
# AAACCTGCACTTAACG             PATO:0000461            True
# ...                                   ...             ...
# TTTGTCATCCACGAAT             PATO:0000461            True
# TTTGTCATCGAGAGCA             PATO:0000461            True
# TTTGTCATCGCCTGAG             PATO:0000461            True
# TTTGTCATCTATCGCC             PATO:0000461            True
# TTTGTCATCTCGTATT             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                  self_reported_ethnicity_ontology_term_id
# AAACCTGAGCAGCGTA                                  unknown
# AAACCTGAGTACGTAA                                  unknown
# AAACCTGCACCATGTA                                  unknown
# AAACCTGCACCTATCC                                  unknown
# AAACCTGCACTTAACG                                  unknown
# ...                                                   ...
# TTTGTCATCCACGAAT                                  unknown
# TTTGTCATCGAGAGCA                                  unknown
# TTTGTCATCGCCTGAG                                  unknown
# TTTGTCATCTATCGCC                                  unknown
# TTTGTCATCTCGTATT                                  unknown
#
# [9619 rows x 29 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id'],
#       dtype='object')

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
# identify the column in adata.obs which corresponds to sex

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id'],
#       dtype='object')

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...          barcodes           assay  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  AAACCTGAGCAGCGTA  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  AAACCTGAGTACGTAA  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA -0.070328  -0.124150  ...  AAACCTGCACCATGTA  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC -0.082849  -0.208696  ...  AAACCTGCACCTATCC  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG -0.119884  -0.196853  ...  AAACCTGCACTTAACG  3pv2_5pv1_5pv2
# ...                    ...        ...  ...               ...             ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...  TTTGTCATCCACGAAT  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...  TTTGTCATCGAGAGCA  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...  TTTGTCATCGCCTGAG  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  TTTGTCATCTATCGCC  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...  TTTGTCATCTCGTATT  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                 CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                 CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                 CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                 CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                 CL:0000646
# ...                                 ...                        ...
# TTTGTCATCCACGAAT            EFO:0011025                 CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                 CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                 CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                 CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA             PATO:0000461            True
# AAACCTGAGTACGTAA             PATO:0000461            True
# AAACCTGCACCATGTA             PATO:0000461            True
# AAACCTGCACCTATCC             PATO:0000461            True
# AAACCTGCACTTAACG             PATO:0000461            True
# ...                                   ...             ...
# TTTGTCATCCACGAAT             PATO:0000461            True
# TTTGTCATCGAGAGCA             PATO:0000461            True
# TTTGTCATCGCCTGAG             PATO:0000461            True
# TTTGTCATCTATCGCC             PATO:0000461            True
# TTTGTCATCTCGTATT             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                  self_reported_ethnicity_ontology_term_id
# AAACCTGAGCAGCGTA                                  unknown
# AAACCTGAGTACGTAA                                  unknown
# AAACCTGCACCATGTA                                  unknown
# AAACCTGCACCTATCC                                  unknown
# AAACCTGCACTTAACG                                  unknown
# ...                                                   ...
# TTTGTCATCCACGAAT                                  unknown
# TTTGTCATCGAGAGCA                                  unknown
# TTTGTCATCGCCTGAG                                  unknown
# TTTGTCATCTATCGCC                                  unknown
# TTTGTCATCTCGTATT                                  unknown
#
# [9619 rows x 29 columns]

# %%
# list the unique values

# %%
# create a dictionary of sex and sex ontology term id

# %%
mapping= {'F': 'PATO:0000383', 'M': 'PATO:0000384', 'Unknown':'unknown'}

# %%
# add sex_ontology_term_id column

# %%
adata.obs['sex_ontology_term_id'] = ['unknown'] * len(adata.obs)

# %%
# change data type

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...           assay  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA -0.070328  -0.124150  ...  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC -0.082849  -0.208696  ...  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG -0.119884  -0.196853  ...  3pv2_5pv1_5pv2
# ...                    ...        ...  ...             ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                 CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                 CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                 CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                 CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                 CL:0000646
# ...                                 ...                        ...
# TTTGTCATCCACGAAT            EFO:0011025                 CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                 CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                 CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                 CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                   disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA              PATO:0000461            True
# AAACCTGAGTACGTAA              PATO:0000461            True
# AAACCTGCACCATGTA              PATO:0000461            True
# AAACCTGCACCTATCC              PATO:0000461            True
# AAACCTGCACTTAACG              PATO:0000461            True
# ...                                    ...             ...
# TTTGTCATCCACGAAT              PATO:0000461            True
# TTTGTCATCGAGAGCA              PATO:0000461            True
# TTTGTCATCGCCTGAG              PATO:0000461            True
# TTTGTCATCTATCGCC              PATO:0000461            True
# TTTGTCATCTCGTATT              PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                  self_reported_ethnicity_ontology_term_id sex_ontology_term_id
# AAACCTGAGCAGCGTA                                  unknown              unknown
# AAACCTGAGTACGTAA                                  unknown              unknown
# AAACCTGCACCATGTA                                  unknown              unknown
# AAACCTGCACCTATCC                                  unknown              unknown
# AAACCTGCACTTAACG                                  unknown              unknown
# ...                                                   ...                  ...
# TTTGTCATCCACGAAT                                  unknown              unknown
# TTTGTCATCGAGAGCA                                  unknown              unknown
# TTTGTCATCGCCTGAG                                  unknown              unknown
# TTTGTCATCTATCGCC                                  unknown              unknown
# TTTGTCATCTCGTATT                                  unknown              unknown
#
# [9619 rows x 30 columns]

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ...           assay  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...  3pv2_5pv1_5pv2
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...  3pv2_5pv1_5pv2
# AAACCTGCACCATGTA -0.070328  -0.124150  ...  3pv2_5pv1_5pv2
# AAACCTGCACCTATCC -0.082849  -0.208696  ...  3pv2_5pv1_5pv2
# AAACCTGCACTTAACG -0.119884  -0.196853  ...  3pv2_5pv1_5pv2
# ...                    ...        ...  ...             ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...  3pv2_5pv1_5pv2
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...  3pv2_5pv1_5pv2
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...  3pv2_5pv1_5pv2
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...  3pv2_5pv1_5pv2
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...  3pv2_5pv1_5pv2
#
#                  assay_ontology_term_id cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA            EFO:0011025                 CL:0002368
# AAACCTGAGTACGTAA            EFO:0011025                 CL:0000646
# AAACCTGCACCATGTA            EFO:0011025                 CL:0002063
# AAACCTGCACCTATCC            EFO:0011025                 CL:0002063
# AAACCTGCACTTAACG            EFO:0011025                 CL:0000646
# ...                                 ...                        ...
# TTTGTCATCCACGAAT            EFO:0011025                 CL:0002063
# TTTGTCATCGAGAGCA            EFO:0011025                 CL:0002063
# TTTGTCATCGCCTGAG            EFO:0011025                 CL:0002063
# TTTGTCATCTATCGCC            EFO:0011025                 CL:1000223
# TTTGTCATCTCGTATT            EFO:0011025                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                   disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA              PATO:0000461            True
# AAACCTGAGTACGTAA              PATO:0000461            True
# AAACCTGCACCATGTA              PATO:0000461            True
# AAACCTGCACCTATCC              PATO:0000461            True
# AAACCTGCACTTAACG              PATO:0000461            True
# ...                                    ...             ...
# TTTGTCATCCACGAAT              PATO:0000461            True
# TTTGTCATCGAGAGCA              PATO:0000461            True
# TTTGTCATCGCCTGAG              PATO:0000461            True
# TTTGTCATCTATCGCC              PATO:0000461            True
# TTTGTCATCTCGTATT              PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                  self_reported_ethnicity_ontology_term_id sex_ontology_term_id
# AAACCTGAGCAGCGTA                                  unknown              unknown
# AAACCTGAGTACGTAA                                  unknown              unknown
# AAACCTGCACCATGTA                                  unknown              unknown
# AAACCTGCACCTATCC                                  unknown              unknown
# AAACCTGCACTTAACG                                  unknown              unknown
# ...                                                   ...                  ...
# TTTGTCATCCACGAAT                                  unknown              unknown
# TTTGTCATCGAGAGCA                                  unknown              unknown
# TTTGTCATCGCCTGAG                                  unknown              unknown
# TTTGTCATCTATCGCC                                  unknown              unknown
# TTTGTCATCTCGTATT                                  unknown              unknown
#
# [9619 rows x 30 columns]

# %%
adata.obs['suspension_type'] = ['cell'] * len(adata.obs)

# %%
# change data type of column

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... assay_ontology_term_id  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...            EFO:0011025
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...            EFO:0011025
# AAACCTGCACCATGTA -0.070328  -0.124150  ...            EFO:0011025
# AAACCTGCACCTATCC -0.082849  -0.208696  ...            EFO:0011025
# AAACCTGCACTTAACG -0.119884  -0.196853  ...            EFO:0011025
# ...                    ...        ...  ...                    ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...            EFO:0011025
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...            EFO:0011025
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...            EFO:0011025
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...            EFO:0011025
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...            EFO:0011025
#
#                  cell_type_ontology_term_id  \
# AAACCTGAGCAGCGTA                 CL:0002368
# AAACCTGAGTACGTAA                 CL:0000646
# AAACCTGCACCATGTA                 CL:0002063
# AAACCTGCACCTATCC                 CL:0002063
# AAACCTGCACTTAACG                 CL:0000646
# ...                                     ...
# TTTGTCATCCACGAAT                 CL:0002063
# TTTGTCATCGAGAGCA                 CL:0002063
# TTTGTCATCGCCTGAG                 CL:0002063
# TTTGTCATCTATCGCC                 CL:1000223
# TTTGTCATCTCGTATT                 CL:0002063
#
#                  development_stage_ontology_term_id   donor_id  \
# AAACCTGAGCAGCGTA                            unknown  HDBR16402
# AAACCTGAGTACGTAA                            unknown  HDBR16402
# AAACCTGCACCATGTA                            unknown  HDBR15934
# AAACCTGCACCTATCC                            unknown  HDBR15934
# AAACCTGCACTTAACG                            unknown  HDBR16392
# ...                                             ...        ...
# TTTGTCATCCACGAAT                            unknown  HDBR16392
# TTTGTCATCGAGAGCA                            unknown  HDBR16392
# TTTGTCATCGCCTGAG                            unknown  HDBR16402
# TTTGTCATCTATCGCC                            unknown     pooled
# TTTGTCATCTCGTATT                            unknown  HDBR15934
#
#                  disease_ontology_term_id  is_primary_data  \
# AAACCTGAGCAGCGTA             PATO:0000461             True
# AAACCTGAGTACGTAA             PATO:0000461             True
# AAACCTGCACCATGTA             PATO:0000461             True
# AAACCTGCACCTATCC             PATO:0000461             True
# AAACCTGCACTTAACG             PATO:0000461             True
# ...                                   ...              ...
# TTTGTCATCCACGAAT             PATO:0000461             True
# TTTGTCATCGAGAGCA             PATO:0000461             True
# TTTGTCATCGCCTGAG             PATO:0000461             True
# TTTGTCATCTATCGCC             PATO:0000461             True
# TTTGTCATCTCGTATT             PATO:0000461             True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                  self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCAGCGTA                                  unknown
# AAACCTGAGTACGTAA                                  unknown
# AAACCTGCACCATGTA                                  unknown
# AAACCTGCACCTATCC                                  unknown
# AAACCTGCACTTAACG                                  unknown
# ...                                                   ...
# TTTGTCATCCACGAAT                                  unknown
# TTTGTCATCGAGAGCA                                  unknown
# TTTGTCATCGCCTGAG                                  unknown
# TTTGTCATCTATCGCC                                  unknown
# TTTGTCATCTCGTATT                                  unknown
#
#                  sex_ontology_term_id suspension_type
# AAACCTGAGCAGCGTA              unknown            cell
# AAACCTGAGTACGTAA              unknown            cell
# AAACCTGCACCATGTA              unknown            cell
# AAACCTGCACCTATCC              unknown            cell
# AAACCTGCACTTAACG              unknown            cell
# ...                               ...             ...
# TTTGTCATCCACGAAT              unknown            cell
# TTTGTCATCGAGAGCA              unknown            cell
# TTTGTCATCGCCTGAG              unknown            cell
# TTTGTCATCTATCGCC              unknown            cell
# TTTGTCATCTCGTATT              unknown            cell
#
# [9619 rows x 31 columns]

# %% [markdown]
# #### **tissue_type**

# %%
adata.obs['tissue_type'] = ['organoid'] * len(adata.obs)

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
# identify the column in adata.obs which corresponds to tissue

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type'],
#       dtype='object')

# %%
# add 'tissue_ontology_term_id' column

# %%
adata.obs['tissue_ontology_term_id'] = ['UBERON:0002048'] * len(adata.obs)

# %%
# change data type of column

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
#list the unique values in 'tissue_ontology_term_id' column

# %%
list(adata.obs['tissue_ontology_term_id'].unique())
# Out:
# ['UBERON:0002048']

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... development_stage_ontology_term_id  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                            unknown
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...                            unknown
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                            unknown
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                            unknown
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                            unknown
# ...                    ...        ...  ...                                ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                            unknown
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                            unknown
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                            unknown
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                            unknown
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                            unknown
#
#                    donor_id disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA  HDBR16402             PATO:0000461            True
# AAACCTGAGTACGTAA  HDBR16402             PATO:0000461            True
# AAACCTGCACCATGTA  HDBR15934             PATO:0000461            True
# AAACCTGCACCTATCC  HDBR15934             PATO:0000461            True
# AAACCTGCACTTAACG  HDBR16392             PATO:0000461            True
# ...                     ...                      ...             ...
# TTTGTCATCCACGAAT  HDBR16392             PATO:0000461            True
# TTTGTCATCGAGAGCA  HDBR16392             PATO:0000461            True
# TTTGTCATCGCCTGAG  HDBR16402             PATO:0000461            True
# TTTGTCATCTATCGCC     pooled             PATO:0000461            True
# TTTGTCATCTCGTATT  HDBR15934             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCAGCGTA                                   unknown
# AAACCTGAGTACGTAA                                   unknown
# AAACCTGCACCATGTA                                   unknown
# AAACCTGCACCTATCC                                   unknown
# AAACCTGCACTTAACG                                   unknown
# ...                                                    ...
# TTTGTCATCCACGAAT                                   unknown
# TTTGTCATCGAGAGCA                                   unknown
# TTTGTCATCGCCTGAG                                   unknown
# TTTGTCATCTATCGCC                                   unknown
# TTTGTCATCTCGTATT                                   unknown
#
#                  sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCAGCGTA              unknown            cell    organoid
# AAACCTGAGTACGTAA              unknown            cell    organoid
# AAACCTGCACCATGTA              unknown            cell    organoid
# AAACCTGCACCTATCC              unknown            cell    organoid
# AAACCTGCACTTAACG              unknown            cell    organoid
# ...                               ...             ...         ...
# TTTGTCATCCACGAAT              unknown            cell    organoid
# TTTGTCATCGAGAGCA              unknown            cell    organoid
# TTTGTCATCGCCTGAG              unknown            cell    organoid
# TTTGTCATCTATCGCC              unknown            cell    organoid
# TTTGTCATCTCGTATT              unknown            cell    organoid
#
#                  tissue_ontology_term_id
# AAACCTGAGCAGCGTA          UBERON:0002048
# AAACCTGAGTACGTAA          UBERON:0002048
# AAACCTGCACCATGTA          UBERON:0002048
# AAACCTGCACCTATCC          UBERON:0002048
# AAACCTGCACTTAACG          UBERON:0002048
# ...                                  ...
# TTTGTCATCCACGAAT          UBERON:0002048
# TTTGTCATCGAGAGCA          UBERON:0002048
# TTTGTCATCGCCTGAG          UBERON:0002048
# TTTGTCATCTATCGCC          UBERON:0002048
# TTTGTCATCTCGTATT          UBERON:0002048
#
# [9619 rows x 33 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
# view obsm

# %%
# check whether all columns are prefixed with X

# %%
adata.obsm
# Out:
# AxisArrays with keys: X_pca, X_umap

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
# View

# %%
adata.uns
# Out:
# OverloadedDict, wrapping:
# 	{'Souporcell4_assignment_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b'],
#       dtype=object), 'batch_colors': array(['#1f77b4'], dtype=object), 'celltype_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b',
#        '#e377c2', '#b5bd61'], dtype=object), 'leiden': {'params': {'n_iterations': -1, 'random_state': 0, 'resolution': 0.2}}, 'leiden_R_colors': array(['#023fa5', '#7d87b9', '#d6bcc0', '#bb7784', '#8e063b', '#4a6fe3',
#        '#8595e1', '#b5bbe3', '#e6afb9', '#e07b91', '#d33f6a', '#11c638',
#        '#8dd593', '#c6dec7', '#ead3c6', '#f0b98d', '#ef9708', '#0fcfc0',
#        '#9cded6', '#d5eae7'], dtype=object), 'log1p': {}, 'majority_voting_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728'], dtype=object), 'neighbors': {'connectivities_key': 'connectivities', 'distances_key': 'distances', 'params': {'method': 'umap', 'metric': 'euclidean', 'n_neighbors': 10, 'n_pcs': 50, 'random_state': 0}}, 'pca': {'params': {'use_highly_variable': True, 'zero_center': True}, 'variance': array([57.463844 , 23.517218 , 16.663454 , 15.480361 , 11.959532 ,
#        10.284296 ,  5.6541834,  5.053854 ,  4.8585577,  4.0674987,
#         3.7487388,  3.38524  ,  2.985367 ,  2.8512833,  2.6895208,
#         2.5131812,  2.33434  ,  2.2685542,  2.167773 ,  2.141382 ,
#         1.9672898,  1.8951718,  1.8358854,  1.8075143,  1.7850149,
#         1.7127323,  1.6801363,  1.6063175,  1.5655267,  1.5297124,
#         1.506897 ,  1.4799275,  1.458469 ,  1.4421917,  1.4299841,
#         1.4187607,  1.4166869,  1.3959285,  1.3782586,  1.3665804,
#         1.3515506,  1.3454438,  1.3390874,  1.3288107,  1.321395 ,
#         1.3155524,  1.3080636,  1.2997304,  1.2931117,  1.288459 ,
#         1.2787578,  1.2741314,  1.2676858,  1.2628244,  1.2555602,
#         1.2532943,  1.2466607,  1.2363584,  1.2296625,  1.2235112,
#         1.2228612,  1.2171007,  1.2129802,  1.2091513,  1.2061222,
#         1.2029963,  1.1994654,  1.195622 ,  1.19349  ,  1.1843213,
#         1.178479 ,  1.1716207,  1.1682224,  1.1645863,  1.1623244,
#         1.1536999,  1.153427 ,  1.1479969,  1.1457382,  1.137081 ,
#         1.1329066,  1.1311593,  1.1271335,  1.124211 ,  1.1207079,
#         1.1181786,  1.1156745,  1.1089408,  1.1082444,  1.1067727,
#         1.1021954,  1.0990988,  1.0963179,  1.0907716,  1.087389 ,
#         1.0860333,  1.0813593,  1.0774779,  1.0735043,  1.0684323],
#       dtype=float32), 'variance_ratio': array([0.09690361, 0.03965804, 0.02810026, 0.02610516, 0.02016784,
#        0.01734283, 0.00953488, 0.00852252, 0.00819318, 0.00685919,
#        0.00632165, 0.00570867, 0.00503435, 0.00480823, 0.00453545,
#        0.00423808, 0.00393649, 0.00382556, 0.0036556 , 0.0036111 ,
#        0.00331752, 0.00319591, 0.00309593, 0.00304808, 0.00301014,
#        0.00288825, 0.00283328, 0.0027088 , 0.00264001, 0.00257962,
#        0.00254114, 0.00249566, 0.00245948, 0.00243203, 0.00241144,
#        0.00239251, 0.00238902, 0.00235401, 0.00232421, 0.00230452,
#        0.00227917, 0.00226888, 0.00225816, 0.00224083, 0.00222832,
#        0.00221847, 0.00220584, 0.00219179, 0.00218063, 0.00217278,
#        0.00215642, 0.00214862, 0.00213775, 0.00212955, 0.0021173 ,
#        0.00211348, 0.00210229, 0.00208492, 0.00207363, 0.00206326,
#        0.00206216, 0.00205245, 0.0020455 , 0.00203904, 0.00203393,
#        0.00202866, 0.00202271, 0.00201623, 0.00201263, 0.00199717,
#        0.00198732, 0.00197575, 0.00197002, 0.00196389, 0.00196007,
#        0.00194553, 0.00194507, 0.00193591, 0.0019321 , 0.00191751,
#        0.00191047, 0.00190752, 0.00190073, 0.0018958 , 0.0018899 ,
#        0.00188563, 0.00188141, 0.00187005, 0.00186888, 0.0018664 ,
#        0.00185868, 0.00185345, 0.00184877, 0.00183941, 0.00183371,
#        0.00183142, 0.00182354, 0.00181699, 0.00181029, 0.00180174],
#       dtype=float32)}, 'predicted_labels_colors': array(['#ffff00', '#1ce6ff', '#ff34ff', '#ff4a46', '#008941', '#006fa6',
#        '#a30059', '#ffdbe5', '#7a4900', '#0000a6', '#004d43', '#997d87',
#        '#5a0007', '#809693', '#6a3a4c', '#1b4400', '#4fc601', '#4a3b53',
#        '#ff2f80', '#61615a', '#ba0900', '#6b7900', '#00c2a0', '#ffaa92',
#        '#ff90c9', '#b903aa', '#d16100', '#ddefff', '#000035', '#7b4f4b',
#        '#a1c299', '#300018', '#0aa6d8', '#013349', '#00846f', '#372101',
#        '#ffb500', '#c2ffed', '#a079bf', '#cc0744', '#c0b9b2', '#c2ff99',
#        '#001e09', '#00489c', '#6f0062', '#0cbd66'], dtype=object), 'umap': {'params': {'a': 0.583030019901822, 'b': 1.3341669931033755}}}
# With overloaded keys:
# 	['neighbors'].

# %%
adata.uns.keys
# Out:
# <bound method OverloadedDict.keys of OverloadedDict, wrapping:
# 	{'Souporcell4_assignment_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b'],
#       dtype=object), 'batch_colors': array(['#1f77b4'], dtype=object), 'celltype_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b',
#        '#e377c2', '#b5bd61'], dtype=object), 'leiden': {'params': {'n_iterations': -1, 'random_state': 0, 'resolution': 0.2}}, 'leiden_R_colors': array(['#023fa5', '#7d87b9', '#d6bcc0', '#bb7784', '#8e063b', '#4a6fe3',
#        '#8595e1', '#b5bbe3', '#e6afb9', '#e07b91', '#d33f6a', '#11c638',
#        '#8dd593', '#c6dec7', '#ead3c6', '#f0b98d', '#ef9708', '#0fcfc0',
#        '#9cded6', '#d5eae7'], dtype=object), 'log1p': {}, 'majority_voting_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728'], dtype=object), 'neighbors': {'connectivities_key': 'connectivities', 'distances_key': 'distances', 'params': {'method': 'umap', 'metric': 'euclidean', 'n_neighbors': 10, 'n_pcs': 50, 'random_state': 0}}, 'pca': {'params': {'use_highly_variable': True, 'zero_center': True}, 'variance': array([57.463844 , 23.517218 , 16.663454 , 15.480361 , 11.959532 ,
#        10.284296 ,  5.6541834,  5.053854 ,  4.8585577,  4.0674987,
#         3.7487388,  3.38524  ,  2.985367 ,  2.8512833,  2.6895208,
#         2.5131812,  2.33434  ,  2.2685542,  2.167773 ,  2.141382 ,
#         1.9672898,  1.8951718,  1.8358854,  1.8075143,  1.7850149,
#         1.7127323,  1.6801363,  1.6063175,  1.5655267,  1.5297124,
#         1.506897 ,  1.4799275,  1.458469 ,  1.4421917,  1.4299841,
#         1.4187607,  1.4166869,  1.3959285,  1.3782586,  1.3665804,
#         1.3515506,  1.3454438,  1.3390874,  1.3288107,  1.321395 ,
#         1.3155524,  1.3080636,  1.2997304,  1.2931117,  1.288459 ,
#         1.2787578,  1.2741314,  1.2676858,  1.2628244,  1.2555602,
#         1.2532943,  1.2466607,  1.2363584,  1.2296625,  1.2235112,
#         1.2228612,  1.2171007,  1.2129802,  1.2091513,  1.2061222,
#         1.2029963,  1.1994654,  1.195622 ,  1.19349  ,  1.1843213,
#         1.178479 ,  1.1716207,  1.1682224,  1.1645863,  1.1623244,
#         1.1536999,  1.153427 ,  1.1479969,  1.1457382,  1.137081 ,
#         1.1329066,  1.1311593,  1.1271335,  1.124211 ,  1.1207079,
#         1.1181786,  1.1156745,  1.1089408,  1.1082444,  1.1067727,
#         1.1021954,  1.0990988,  1.0963179,  1.0907716,  1.087389 ,
#         1.0860333,  1.0813593,  1.0774779,  1.0735043,  1.0684323],
#       dtype=float32), 'variance_ratio': array([0.09690361, 0.03965804, 0.02810026, 0.02610516, 0.02016784,
#        0.01734283, 0.00953488, 0.00852252, 0.00819318, 0.00685919,
#        0.00632165, 0.00570867, 0.00503435, 0.00480823, 0.00453545,
#        0.00423808, 0.00393649, 0.00382556, 0.0036556 , 0.0036111 ,
#        0.00331752, 0.00319591, 0.00309593, 0.00304808, 0.00301014,
#        0.00288825, 0.00283328, 0.0027088 , 0.00264001, 0.00257962,
#        0.00254114, 0.00249566, 0.00245948, 0.00243203, 0.00241144,
#        0.00239251, 0.00238902, 0.00235401, 0.00232421, 0.00230452,
#        0.00227917, 0.00226888, 0.00225816, 0.00224083, 0.00222832,
#        0.00221847, 0.00220584, 0.00219179, 0.00218063, 0.00217278,
#        0.00215642, 0.00214862, 0.00213775, 0.00212955, 0.0021173 ,
#        0.00211348, 0.00210229, 0.00208492, 0.00207363, 0.00206326,
#        0.00206216, 0.00205245, 0.0020455 , 0.00203904, 0.00203393,
#        0.00202866, 0.00202271, 0.00201623, 0.00201263, 0.00199717,
#        0.00198732, 0.00197575, 0.00197002, 0.00196389, 0.00196007,
#        0.00194553, 0.00194507, 0.00193591, 0.0019321 , 0.00191751,
#        0.00191047, 0.00190752, 0.00190073, 0.0018958 , 0.0018899 ,
#        0.00188563, 0.00188141, 0.00187005, 0.00186888, 0.0018664 ,
#        0.00185868, 0.00185345, 0.00184877, 0.00183941, 0.00183371,
#        0.00183142, 0.00182354, 0.00181699, 0.00181029, 0.00180174],
#       dtype=float32)}, 'predicted_labels_colors': array(['#ffff00', '#1ce6ff', '#ff34ff', '#ff4a46', '#008941', '#006fa6',
#        '#a30059', '#ffdbe5', '#7a4900', '#0000a6', '#004d43', '#997d87',
#        '#5a0007', '#809693', '#6a3a4c', '#1b4400', '#4fc601', '#4a3b53',
#        '#ff2f80', '#61615a', '#ba0900', '#6b7900', '#00c2a0', '#ffaa92',
#        '#ff90c9', '#b903aa', '#d16100', '#ddefff', '#000035', '#7b4f4b',
#        '#a1c299', '#300018', '#0aa6d8', '#013349', '#00846f', '#372101',
#        '#ffb500', '#c2ffed', '#a079bf', '#cc0744', '#c0b9b2', '#c2ff99',
#        '#001e09', '#00489c', '#6f0062', '#0cbd66'], dtype=object), 'umap': {'params': {'a': 0.583030019901822, 'b': 1.3341669931033755}}}
# With overloaded keys:
# 	['neighbors'].>

# %%
# Give a title for the dataset

# %%
adata.uns['title'] = 'organoid'

# %%
# Set the default embedding

# %%
adata.uns['default_embedding'] = 'X_umap'

# %% [markdown]
# ### **Final check**

# %%
# view anndata object

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 9619 × 36390
#     obs: 'Souporcell4_status', 'Souporcell4_assignment', 'percent_mito', 'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score', 'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering', 'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor', 'barcodes', 'assay', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'donor_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id', 'suspension_type', 'tissue_type', 'tissue_ontology_term_id'
#     var: 'feature_types_x', 'feature_is_filtered', 'gene_ids_y', 'feature_types_y', 'n_cells', 'highly_variablefirst', 'highly_variable_n'
#     uns: 'Souporcell4_assignment_colors', 'batch_colors', 'celltype_colors', 'leiden', 'leiden_R_colors', 'log1p', 'majority_voting_colors', 'neighbors', 'pca', 'predicted_labels_colors', 'umap', 'title', 'default_embedding'
#     obsm: 'X_pca', 'X_umap'

# %%
# view obs and var data types

# %%
adata.obs.dtypes
# Out:
# Souporcell4_status                          category
# Souporcell4_assignment                      category
# percent_mito                                 float32
# n_counts                                     float32
# n_genes                                        int64
# batch                                       category
# doublet_scores                               float64
# bh_pval                                      float64
# S_score                                      float64
# G2M_score                                    float64
# phase                                       category
# leiden                                      category
# predicted_labels                            category
# over_clustering                             category
# majority_voting                             category
# conf_score                                   float64
# leiden_R                                    category
# celltype                                    category
# donor                                         object
# barcodes                                      object
# assay                                         object
# assay_ontology_term_id                      category
# cell_type_ontology_term_id                  category
# development_stage_ontology_term_id          category
# donor_id                                    category
# disease_ontology_term_id                    category
# is_primary_data                                 bool
# organism_ontology_term_id                   category
# self_reported_ethnicity_ontology_term_id    category
# sex_ontology_term_id                        category
# suspension_type                             category
# tissue_type                                 category
# tissue_ontology_term_id                     category
# dtype: object

# %%
dty = pd.DataFrame(adata.var.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.var[c] = adata.var[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.var[c] = adata.var[c].astype('int32') 
    print(f"changed {c} from int64 to int32")
# Out:
# changed n_cells from float64 to float32
# changed highly_variable_n from float64 to float32

# %%
dty = pd.DataFrame(adata.obs.dtypes, columns = ['dtype'])
for c in dty[dty['dtype'] == 'float64'].index.values:
    adata.obs[c] = adata.obs[c].astype('float32')
    print(f"changed {c} from float64 to float32")
for c in dty[dty['dtype'] == 'int64'].index.values:
    adata.obs[c] = adata.obs[c].astype('int32') 
    print(f"changed {c} from int64 to int32")
for c in dty[dty['dtype'] == 'object'].index.values:
    adata.obs[c] = adata.obs[c].astype('category') 
    print(f"changed {c} from object to category")
# Out:
# changed doublet_scores from float64 to float32
# changed bh_pval from float64 to float32
# changed S_score from float64 to float32
# changed G2M_score from float64 to float32
# changed conf_score from float64 to float32
# changed n_genes from int64 to int32
# changed donor from object to category
# changed barcodes from object to category
# changed assay from object to category

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... development_stage_ontology_term_id  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                            unknown
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...                            unknown
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                            unknown
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                            unknown
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                            unknown
# ...                    ...        ...  ...                                ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                            unknown
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                            unknown
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                            unknown
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                            unknown
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                            unknown
#
#                    donor_id disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA  HDBR16402             PATO:0000461            True
# AAACCTGAGTACGTAA  HDBR16402             PATO:0000461            True
# AAACCTGCACCATGTA  HDBR15934             PATO:0000461            True
# AAACCTGCACCTATCC  HDBR15934             PATO:0000461            True
# AAACCTGCACTTAACG  HDBR16392             PATO:0000461            True
# ...                     ...                      ...             ...
# TTTGTCATCCACGAAT  HDBR16392             PATO:0000461            True
# TTTGTCATCGAGAGCA  HDBR16392             PATO:0000461            True
# TTTGTCATCGCCTGAG  HDBR16402             PATO:0000461            True
# TTTGTCATCTATCGCC     pooled             PATO:0000461            True
# TTTGTCATCTCGTATT  HDBR15934             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCAGCGTA                                   unknown
# AAACCTGAGTACGTAA                                   unknown
# AAACCTGCACCATGTA                                   unknown
# AAACCTGCACCTATCC                                   unknown
# AAACCTGCACTTAACG                                   unknown
# ...                                                    ...
# TTTGTCATCCACGAAT                                   unknown
# TTTGTCATCGAGAGCA                                   unknown
# TTTGTCATCGCCTGAG                                   unknown
# TTTGTCATCTATCGCC                                   unknown
# TTTGTCATCTCGTATT                                   unknown
#
#                  sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCAGCGTA              unknown            cell    organoid
# AAACCTGAGTACGTAA              unknown            cell    organoid
# AAACCTGCACCATGTA              unknown            cell    organoid
# AAACCTGCACCTATCC              unknown            cell    organoid
# AAACCTGCACTTAACG              unknown            cell    organoid
# ...                               ...             ...         ...
# TTTGTCATCCACGAAT              unknown            cell    organoid
# TTTGTCATCGAGAGCA              unknown            cell    organoid
# TTTGTCATCGCCTGAG              unknown            cell    organoid
# TTTGTCATCTATCGCC              unknown            cell    organoid
# TTTGTCATCTCGTATT              unknown            cell    organoid
#
#                  tissue_ontology_term_id
# AAACCTGAGCAGCGTA          UBERON:0002048
# AAACCTGAGTACGTAA          UBERON:0002048
# AAACCTGCACCATGTA          UBERON:0002048
# AAACCTGCACCTATCC          UBERON:0002048
# AAACCTGCACTTAACG          UBERON:0002048
# ...                                  ...
# TTTGTCATCCACGAAT          UBERON:0002048
# TTTGTCATCGAGAGCA          UBERON:0002048
# TTTGTCATCGCCTGAG          UBERON:0002048
# TTTGTCATCTATCGCC          UBERON:0002048
# TTTGTCATCTCGTATT          UBERON:0002048
#
# [9619 rows x 33 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype', 'donor',
#        'barcodes', 'assay', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'donor_id', 'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
# delete unwanted columns in obs

# %%
del adata.obs['barcodes']
del adata.obs['assay']
del adata.obs['donor']
del adata.uns['log1p']

# %%
# view obs

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... development_stage_ontology_term_id  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                            unknown
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...                            unknown
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                            unknown
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                            unknown
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                            unknown
# ...                    ...        ...  ...                                ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                            unknown
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                            unknown
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                            unknown
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                            unknown
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                            unknown
#
#                    donor_id disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA  HDBR16402             PATO:0000461            True
# AAACCTGAGTACGTAA  HDBR16402             PATO:0000461            True
# AAACCTGCACCATGTA  HDBR15934             PATO:0000461            True
# AAACCTGCACCTATCC  HDBR15934             PATO:0000461            True
# AAACCTGCACTTAACG  HDBR16392             PATO:0000461            True
# ...                     ...                      ...             ...
# TTTGTCATCCACGAAT  HDBR16392             PATO:0000461            True
# TTTGTCATCGAGAGCA  HDBR16392             PATO:0000461            True
# TTTGTCATCGCCTGAG  HDBR16402             PATO:0000461            True
# TTTGTCATCTATCGCC     pooled             PATO:0000461            True
# TTTGTCATCTCGTATT  HDBR15934             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCAGCGTA                                   unknown
# AAACCTGAGTACGTAA                                   unknown
# AAACCTGCACCATGTA                                   unknown
# AAACCTGCACCTATCC                                   unknown
# AAACCTGCACTTAACG                                   unknown
# ...                                                    ...
# TTTGTCATCCACGAAT                                   unknown
# TTTGTCATCGAGAGCA                                   unknown
# TTTGTCATCGCCTGAG                                   unknown
# TTTGTCATCTATCGCC                                   unknown
# TTTGTCATCTCGTATT                                   unknown
#
#                  sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCAGCGTA              unknown            cell    organoid
# AAACCTGAGTACGTAA              unknown            cell    organoid
# AAACCTGCACCATGTA              unknown            cell    organoid
# AAACCTGCACCTATCC              unknown            cell    organoid
# AAACCTGCACTTAACG              unknown            cell    organoid
# ...                               ...             ...         ...
# TTTGTCATCCACGAAT              unknown            cell    organoid
# TTTGTCATCGAGAGCA              unknown            cell    organoid
# TTTGTCATCGCCTGAG              unknown            cell    organoid
# TTTGTCATCTATCGCC              unknown            cell    organoid
# TTTGTCATCTCGTATT              unknown            cell    organoid
#
#                  tissue_ontology_term_id
# AAACCTGAGCAGCGTA          UBERON:0002048
# AAACCTGAGTACGTAA          UBERON:0002048
# AAACCTGCACCATGTA          UBERON:0002048
# AAACCTGCACCTATCC          UBERON:0002048
# AAACCTGCACTTAACG          UBERON:0002048
# ...                                  ...
# TTTGTCATCCACGAAT          UBERON:0002048
# TTTGTCATCGAGAGCA          UBERON:0002048
# TTTGTCATCGCCTGAG          UBERON:0002048
# TTTGTCATCTATCGCC          UBERON:0002048
# TTTGTCATCTCGTATT          UBERON:0002048
#
# [9619 rows x 30 columns]

# %%
# view var

# %%
adata.var
# Out:
#                  feature_types_x  feature_is_filtered       gene_ids_y  \
# ENSG00000243485  Gene Expression                False  ENSG00000243485
# ENSG00000237613  Gene Expression                 True              NaN
# ENSG00000186092  Gene Expression                 True              NaN
# ENSG00000238009  Gene Expression                False  ENSG00000238009
# ENSG00000239945  Gene Expression                 True              NaN
# ...                          ...                  ...              ...
# ENSG00000277836  Gene Expression                 True              NaN
# ENSG00000278633  Gene Expression                 True              NaN
# ENSG00000276017  Gene Expression                 True              NaN
# ENSG00000278817  Gene Expression                False  ENSG00000278817
# ENSG00000277196  Gene Expression                False  ENSG00000277196
#
#                  feature_types_y  n_cells highly_variablefirst  \
# ENSG00000243485  Gene Expression      9.0                False
# ENSG00000237613              NaN      NaN                  NaN
# ENSG00000186092              NaN      NaN                  NaN
# ENSG00000238009  Gene Expression     18.0                False
# ENSG00000239945              NaN      NaN                  NaN
# ...                          ...      ...                  ...
# ENSG00000277836              NaN      NaN                  NaN
# ENSG00000278633              NaN      NaN                  NaN
# ENSG00000276017              NaN      NaN                  NaN
# ENSG00000278817  Gene Expression    224.0                False
# ENSG00000277196  Gene Expression   3214.0                False
#
#                  highly_variable_n
# ENSG00000243485                0.0
# ENSG00000237613                NaN
# ENSG00000186092                NaN
# ENSG00000238009                0.0
# ENSG00000239945                NaN
# ...                            ...
# ENSG00000277836                NaN
# ENSG00000278633                NaN
# ENSG00000276017                NaN
# ENSG00000278817                0.0
# ENSG00000277196                0.0
#
# [36390 rows x 7 columns]

# %%
araw.var
# Out:
#                    feature_types
# gene_ids
# ENSG00000243485  Gene Expression
# ENSG00000237613  Gene Expression
# ENSG00000186092  Gene Expression
# ENSG00000238009  Gene Expression
# ENSG00000239945  Gene Expression
# ...                          ...
# ENSG00000277836  Gene Expression
# ENSG00000278633  Gene Expression
# ENSG00000276017  Gene Expression
# ENSG00000278817  Gene Expression
# ENSG00000277196  Gene Expression
#
# [36390 rows x 1 columns]

# %%
del araw.var['feature_types']
del adata.var['gene_ids_y']
del adata.var['feature_types_y']
del adata.var['n_cells']
del adata.var['highly_variablefirst']
del adata.var['highly_variable_n']
del adata.var['feature_types_x']

# %%
#view uns

# %%
adata.uns
# Out:
# OverloadedDict, wrapping:
# 	{'Souporcell4_assignment_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b'],
#       dtype=object), 'batch_colors': array(['#1f77b4'], dtype=object), 'celltype_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b',
#        '#e377c2', '#b5bd61'], dtype=object), 'leiden': {'params': {'n_iterations': -1, 'random_state': 0, 'resolution': 0.2}}, 'leiden_R_colors': array(['#023fa5', '#7d87b9', '#d6bcc0', '#bb7784', '#8e063b', '#4a6fe3',
#        '#8595e1', '#b5bbe3', '#e6afb9', '#e07b91', '#d33f6a', '#11c638',
#        '#8dd593', '#c6dec7', '#ead3c6', '#f0b98d', '#ef9708', '#0fcfc0',
#        '#9cded6', '#d5eae7'], dtype=object), 'majority_voting_colors': array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728'], dtype=object), 'neighbors': {'connectivities_key': 'connectivities', 'distances_key': 'distances', 'params': {'method': 'umap', 'metric': 'euclidean', 'n_neighbors': 10, 'n_pcs': 50, 'random_state': 0}}, 'pca': {'params': {'use_highly_variable': True, 'zero_center': True}, 'variance': array([57.463844 , 23.517218 , 16.663454 , 15.480361 , 11.959532 ,
#        10.284296 ,  5.6541834,  5.053854 ,  4.8585577,  4.0674987,
#         3.7487388,  3.38524  ,  2.985367 ,  2.8512833,  2.6895208,
#         2.5131812,  2.33434  ,  2.2685542,  2.167773 ,  2.141382 ,
#         1.9672898,  1.8951718,  1.8358854,  1.8075143,  1.7850149,
#         1.7127323,  1.6801363,  1.6063175,  1.5655267,  1.5297124,
#         1.506897 ,  1.4799275,  1.458469 ,  1.4421917,  1.4299841,
#         1.4187607,  1.4166869,  1.3959285,  1.3782586,  1.3665804,
#         1.3515506,  1.3454438,  1.3390874,  1.3288107,  1.321395 ,
#         1.3155524,  1.3080636,  1.2997304,  1.2931117,  1.288459 ,
#         1.2787578,  1.2741314,  1.2676858,  1.2628244,  1.2555602,
#         1.2532943,  1.2466607,  1.2363584,  1.2296625,  1.2235112,
#         1.2228612,  1.2171007,  1.2129802,  1.2091513,  1.2061222,
#         1.2029963,  1.1994654,  1.195622 ,  1.19349  ,  1.1843213,
#         1.178479 ,  1.1716207,  1.1682224,  1.1645863,  1.1623244,
#         1.1536999,  1.153427 ,  1.1479969,  1.1457382,  1.137081 ,
#         1.1329066,  1.1311593,  1.1271335,  1.124211 ,  1.1207079,
#         1.1181786,  1.1156745,  1.1089408,  1.1082444,  1.1067727,
#         1.1021954,  1.0990988,  1.0963179,  1.0907716,  1.087389 ,
#         1.0860333,  1.0813593,  1.0774779,  1.0735043,  1.0684323],
#       dtype=float32), 'variance_ratio': array([0.09690361, 0.03965804, 0.02810026, 0.02610516, 0.02016784,
#        0.01734283, 0.00953488, 0.00852252, 0.00819318, 0.00685919,
#        0.00632165, 0.00570867, 0.00503435, 0.00480823, 0.00453545,
#        0.00423808, 0.00393649, 0.00382556, 0.0036556 , 0.0036111 ,
#        0.00331752, 0.00319591, 0.00309593, 0.00304808, 0.00301014,
#        0.00288825, 0.00283328, 0.0027088 , 0.00264001, 0.00257962,
#        0.00254114, 0.00249566, 0.00245948, 0.00243203, 0.00241144,
#        0.00239251, 0.00238902, 0.00235401, 0.00232421, 0.00230452,
#        0.00227917, 0.00226888, 0.00225816, 0.00224083, 0.00222832,
#        0.00221847, 0.00220584, 0.00219179, 0.00218063, 0.00217278,
#        0.00215642, 0.00214862, 0.00213775, 0.00212955, 0.0021173 ,
#        0.00211348, 0.00210229, 0.00208492, 0.00207363, 0.00206326,
#        0.00206216, 0.00205245, 0.0020455 , 0.00203904, 0.00203393,
#        0.00202866, 0.00202271, 0.00201623, 0.00201263, 0.00199717,
#        0.00198732, 0.00197575, 0.00197002, 0.00196389, 0.00196007,
#        0.00194553, 0.00194507, 0.00193591, 0.0019321 , 0.00191751,
#        0.00191047, 0.00190752, 0.00190073, 0.0018958 , 0.0018899 ,
#        0.00188563, 0.00188141, 0.00187005, 0.00186888, 0.0018664 ,
#        0.00185868, 0.00185345, 0.00184877, 0.00183941, 0.00183371,
#        0.00183142, 0.00182354, 0.00181699, 0.00181029, 0.00180174],
#       dtype=float32)}, 'predicted_labels_colors': array(['#ffff00', '#1ce6ff', '#ff34ff', '#ff4a46', '#008941', '#006fa6',
#        '#a30059', '#ffdbe5', '#7a4900', '#0000a6', '#004d43', '#997d87',
#        '#5a0007', '#809693', '#6a3a4c', '#1b4400', '#4fc601', '#4a3b53',
#        '#ff2f80', '#61615a', '#ba0900', '#6b7900', '#00c2a0', '#ffaa92',
#        '#ff90c9', '#b903aa', '#d16100', '#ddefff', '#000035', '#7b4f4b',
#        '#a1c299', '#300018', '#0aa6d8', '#013349', '#00846f', '#372101',
#        '#ffb500', '#c2ffed', '#a079bf', '#cc0744', '#c0b9b2', '#c2ff99',
#        '#001e09', '#00489c', '#6f0062', '#0cbd66'], dtype=object), 'umap': {'params': {'a': 0.583030019901822, 'b': 1.3341669931033755}}, 'title': 'organoid', 'default_embedding': 'X_umap'}
# With overloaded keys:
# 	['neighbors'].

# %%
list(adata.uns.keys())
# Out:
# ['Souporcell4_assignment_colors',
#  'batch_colors',
#  'celltype_colors',
#  'leiden',
#  'leiden_R_colors',
#  'majority_voting_colors',
#  'neighbors',
#  'pca',
#  'predicted_labels_colors',
#  'umap',
#  'title',
#  'default_embedding']

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
# Remove unwanted columns in uns

# %%
#check the format of expression matrix

# %%
adata.X
# Out:
# <9619x36390 sparse matrix of type '<class 'numpy.float32'>'
# 	with 36956351 stored elements in Compressed Sparse Row format>

# %%
araw.X
# Out:
# <9619x36390 sparse matrix of type '<class 'numpy.float32'>'
# 	with 37083515 stored elements in Compressed Sparse Row format>

# %%
#Copy raw counts to adata.raw

# %%
adata.raw = araw

# %%
obs_dtype = adata.obs.dtypes

# %%
obs_dtype
# Out:
# Souporcell4_status                          category
# Souporcell4_assignment                      category
# percent_mito                                 float32
# n_counts                                     float32
# n_genes                                        int32
# batch                                       category
# doublet_scores                               float32
# bh_pval                                      float32
# S_score                                      float32
# G2M_score                                    float32
# phase                                       category
# leiden                                      category
# predicted_labels                            category
# over_clustering                             category
# majority_voting                             category
# conf_score                                   float32
# leiden_R                                    category
# celltype                                    category
# assay_ontology_term_id                      category
# cell_type_ontology_term_id                  category
# development_stage_ontology_term_id          category
# donor_id                                    category
# disease_ontology_term_id                    category
# is_primary_data                                 bool
# organism_ontology_term_id                   category
# self_reported_ethnicity_ontology_term_id    category
# sex_ontology_term_id                        category
# suspension_type                             category
# tissue_type                                 category
# tissue_ontology_term_id                     category
# dtype: object

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/lung_organoid_2024/Final_objects/lung_organoid.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                  Souporcell4_status Souporcell4_assignment  percent_mito  \
# AAACCTGAGCAGCGTA            singlet                      3      0.025313
# AAACCTGAGTACGTAA            singlet                      3      0.027868
# AAACCTGCACCATGTA            singlet                      0      0.005957
# AAACCTGCACCTATCC            singlet                      0      0.017658
# AAACCTGCACTTAACG            singlet                      2      0.038610
# ...                             ...                    ...           ...
# TTTGTCATCCACGAAT            singlet                      2      0.103709
# TTTGTCATCGAGAGCA            singlet                      2      0.016931
# TTTGTCATCGCCTGAG            singlet                      3      0.026760
# TTTGTCATCTATCGCC            doublet               doublets      0.015649
# TTTGTCATCTCGTATT            singlet                      0      0.001737
#
#                   n_counts  n_genes  batch  doublet_scores   bh_pval  \
# AAACCTGAGCAGCGTA   11667.0     3050  first        0.109792  0.792204
# AAACCTGAGTACGTAA   22709.0     4423  first        0.166667  0.792204
# AAACCTGCACCATGTA   16519.0     3771  first        0.334873  0.792204
# AAACCTGCACCTATCC   11905.0     3015  first        0.121951  0.792204
# AAACCTGCACTTAACG   13446.0     3568  first        0.125270  0.792204
# ...                    ...      ...    ...             ...       ...
# TTTGTCATCCACGAAT    2489.0     1326  first        0.083472  0.792204
# TTTGTCATCGAGAGCA   15851.0     3354  first        0.177285  0.792204
# TTTGTCATCGCCTGAG   15093.0     3791  first        0.195231  0.792204
# TTTGTCATCTATCGCC   49251.0     6942  first        0.232082  0.792204
# TTTGTCATCTCGTATT   26440.0     3970  first        0.115660  0.792204
#
#                    S_score  G2M_score  ... development_stage_ontology_term_id  \
# AAACCTGAGCAGCGTA -0.154529  -0.085028  ...                            unknown
# AAACCTGAGTACGTAA -0.097155  -0.174267  ...                            unknown
# AAACCTGCACCATGTA -0.070328  -0.124150  ...                            unknown
# AAACCTGCACCTATCC -0.082849  -0.208696  ...                            unknown
# AAACCTGCACTTAACG -0.119884  -0.196853  ...                            unknown
# ...                    ...        ...  ...                                ...
# TTTGTCATCCACGAAT  0.294187   0.429153  ...                            unknown
# TTTGTCATCGAGAGCA -0.127767  -0.152186  ...                            unknown
# TTTGTCATCGCCTGAG  0.478485   0.114177  ...                            unknown
# TTTGTCATCTATCGCC  0.037060  -0.000052  ...                            unknown
# TTTGTCATCTCGTATT -0.011147  -0.161577  ...                            unknown
#
#                    donor_id disease_ontology_term_id is_primary_data  \
# AAACCTGAGCAGCGTA  HDBR16402             PATO:0000461            True
# AAACCTGAGTACGTAA  HDBR16402             PATO:0000461            True
# AAACCTGCACCATGTA  HDBR15934             PATO:0000461            True
# AAACCTGCACCTATCC  HDBR15934             PATO:0000461            True
# AAACCTGCACTTAACG  HDBR16392             PATO:0000461            True
# ...                     ...                      ...             ...
# TTTGTCATCCACGAAT  HDBR16392             PATO:0000461            True
# TTTGTCATCGAGAGCA  HDBR16392             PATO:0000461            True
# TTTGTCATCGCCTGAG  HDBR16402             PATO:0000461            True
# TTTGTCATCTATCGCC     pooled             PATO:0000461            True
# TTTGTCATCTCGTATT  HDBR15934             PATO:0000461            True
#
#                  organism_ontology_term_id  \
# AAACCTGAGCAGCGTA            NCBITaxon:9606
# AAACCTGAGTACGTAA            NCBITaxon:9606
# AAACCTGCACCATGTA            NCBITaxon:9606
# AAACCTGCACCTATCC            NCBITaxon:9606
# AAACCTGCACTTAACG            NCBITaxon:9606
# ...                                    ...
# TTTGTCATCCACGAAT            NCBITaxon:9606
# TTTGTCATCGAGAGCA            NCBITaxon:9606
# TTTGTCATCGCCTGAG            NCBITaxon:9606
# TTTGTCATCTATCGCC            NCBITaxon:9606
# TTTGTCATCTCGTATT            NCBITaxon:9606
#
#                   self_reported_ethnicity_ontology_term_id  \
# AAACCTGAGCAGCGTA                                   unknown
# AAACCTGAGTACGTAA                                   unknown
# AAACCTGCACCATGTA                                   unknown
# AAACCTGCACCTATCC                                   unknown
# AAACCTGCACTTAACG                                   unknown
# ...                                                    ...
# TTTGTCATCCACGAAT                                   unknown
# TTTGTCATCGAGAGCA                                   unknown
# TTTGTCATCGCCTGAG                                   unknown
# TTTGTCATCTATCGCC                                   unknown
# TTTGTCATCTCGTATT                                   unknown
#
#                  sex_ontology_term_id suspension_type tissue_type  \
# AAACCTGAGCAGCGTA              unknown            cell    organoid
# AAACCTGAGTACGTAA              unknown            cell    organoid
# AAACCTGCACCATGTA              unknown            cell    organoid
# AAACCTGCACCTATCC              unknown            cell    organoid
# AAACCTGCACTTAACG              unknown            cell    organoid
# ...                               ...             ...         ...
# TTTGTCATCCACGAAT              unknown            cell    organoid
# TTTGTCATCGAGAGCA              unknown            cell    organoid
# TTTGTCATCGCCTGAG              unknown            cell    organoid
# TTTGTCATCTATCGCC              unknown            cell    organoid
# TTTGTCATCTCGTATT              unknown            cell    organoid
#
#                  tissue_ontology_term_id
# AAACCTGAGCAGCGTA          UBERON:0002048
# AAACCTGAGTACGTAA          UBERON:0002048
# AAACCTGCACCATGTA          UBERON:0002048
# AAACCTGCACCTATCC          UBERON:0002048
# AAACCTGCACTTAACG          UBERON:0002048
# ...                                  ...
# TTTGTCATCCACGAAT          UBERON:0002048
# TTTGTCATCGAGAGCA          UBERON:0002048
# TTTGTCATCGCCTGAG          UBERON:0002048
# TTTGTCATCTATCGCC          UBERON:0002048
# TTTGTCATCTCGTATT          UBERON:0002048
#
# [9619 rows x 30 columns]

# %%
adata.obs.columns
# Out:
# Index(['Souporcell4_status', 'Souporcell4_assignment', 'percent_mito',
#        'n_counts', 'n_genes', 'batch', 'doublet_scores', 'bh_pval', 'S_score',
#        'G2M_score', 'phase', 'leiden', 'predicted_labels', 'over_clustering',
#        'majority_voting', 'conf_score', 'leiden_R', 'celltype',
#        'assay_ontology_term_id', 'cell_type_ontology_term_id',
#        'development_stage_ontology_term_id', 'donor_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata.raw.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [ENSG00000243485, ENSG00000237613, ENSG00000186092, ENSG00000238009, ENSG00000239945, ENSG00000239906, ENSG00000241860, ENSG00000241599, ENSG00000286448, ENSG00000236601, ENSG00000284733, ENSG00000235146, ENSG00000284662, ENSG00000229905, ENSG00000237491, ENSG00000177757, ENSG00000228794, ENSG00000225880, ENSG00000230368, ENSG00000272438, ENSG00000230699, ENSG00000241180, ENSG00000223764, ENSG00000187634, ENSG00000188976, ENSG00000187961, ENSG00000187583, ENSG00000187642, ENSG00000272512, ENSG00000188290, ENSG00000187608, ENSG00000224969, ENSG00000188157, ENSG00000242590, ENSG00000273443, ENSG00000237330, ENSG00000131591, ENSG00000285812, ENSG00000223823, ENSG00000272141, ENSG00000205231, ENSG00000162571, ENSG00000186891, ENSG00000186827, ENSG00000078808, ENSG00000176022, ENSG00000184163, ENSG00000260179, ENSG00000160087, ENSG00000230415, ENSG00000162572, ENSG00000131584, ENSG00000169972, ENSG00000127054, ENSG00000240731, ENSG00000224051, ENSG00000169962, ENSG00000107404, ENSG00000162576, ENSG00000175756, ENSG00000221978, ENSG00000224870, ENSG00000242485, ENSG00000272455, ENSG00000235098, ENSG00000225905, ENSG00000205116, ENSG00000225285, ENSG00000179403, ENSG00000215915, ENSG00000160072, ENSG00000197785, ENSG00000205090, ENSG00000160075, ENSG00000215014, ENSG00000228594, ENSG00000286989, ENSG00000272106, ENSG00000197530, ENSG00000189409, ENSG00000248333, ENSG00000272004, ENSG00000189339, ENSG00000008128, ENSG00000215790, ENSG00000008130, ENSG00000078369, ENSG00000231050, ENSG00000169885, ENSG00000178821, ENSG00000142609, ENSG00000233542, ENSG00000187730, ENSG00000226969, ENSG00000067606, ENSG00000271806, ENSG00000182873, ENSG00000162585, ENSG00000234396, ENSG00000157933, ...]
#
# [36390 rows x 0 columns]

# %%
adata.var
# Out:
#                  feature_is_filtered
# ENSG00000243485                False
# ENSG00000237613                 True
# ENSG00000186092                 True
# ENSG00000238009                False
# ENSG00000239945                 True
# ...                              ...
# ENSG00000277836                 True
# ENSG00000278633                 True
# ENSG00000276017                 True
# ENSG00000278817                False
# ENSG00000277196                False
#
# [36390 rows x 1 columns]

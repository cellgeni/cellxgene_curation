# %% [markdown]
# ### **Curating visium_slide7.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9699525/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['AATAGTCGCGAGTCGG-1', 'CAGTAGCGAGGTAGTA-1', 'CCTAGGTAAAGGTAGC-1', 'GGTGATGAAGGAAGTG-1', 'GGTTGTGTAGCCTGGC-1', 'TGAGGTTGATCCCAAG-1', 'TGGGTTCCCGGACGGA-1']

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 14

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 6398240 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 4129)	1.0
#   (0, 5088)	1.0
#   (0, 7246)	1.0
#   (0, 7966)	1.0
#   (0, 10780)	1.0
#   (0, 13864)	1.0
#   (0, 17906)	1.0
#   (0, 30969)	1.0
#   (1, 8)	1.0
#   (1, 58)	1.0
#   (1, 97)	1.0
#   (1, 112)	1.0
#   (1, 125)	1.0
#   (1, 153)	11.0
#   (1, 194)	1.0
#   (1, 197)	2.0
#   (1, 264)	1.0
#   (1, 305)	1.0
#   (1, 385)	1.0
#   (1, 406)	1.0
#   (1, 442)	1.0
#   (1, 474)	1.0
#   (1, 482)	1.0
#   (1, 484)	15.0
#   (1, 495)	2.0
#   :	:
#   (4991, 32191)	2.0
#   (4991, 32338)	1.0
#   (4991, 32419)	1.0
#   (4991, 32681)	1.0
#   (4991, 32810)	1.0
#   (4991, 32858)	1.0
#   (4991, 32862)	1.0
#   (4991, 32888)	1.0
#   (4991, 32919)	3.0
#   (4991, 32925)	2.0
#   (4991, 32945)	1.0
#   (4991, 32979)	1.0
#   (4991, 33122)	1.0
#   (4991, 33144)	1.0
#   (4991, 33359)	1.0
#   (4991, 33431)	1.0
#   (4991, 33476)	1.0
#   (4991, 33621)	1.0
#   (4991, 33624)	1.0
#   (4991, 33654)	2.0
#   (4991, 33655)	1.0
#   (4991, 33657)	1.0
#   (4991, 33658)	6.0
#   (4991, 33659)	1.0
#   (4991, 33661)	3.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16                8
# AAACAAGTATCTCCCA-1          0         50        102             1286
# AAACAATCTACTAGCA-1          0          3         43               43
# AAACACCAATAACTGC-1          0         59         19               24
# AAACAGAGCGACTCCT-1          1         14         94             3714
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42             2901
# TTGTTTCATTAGTCTA-1          0         60         30              356
# TTGTTTCCATACAACT-1          0         45         27              128
# TTGTTTGTATTACACG-1          1         73         41             2232
# TTGTTTGTGTAAATTC-1          0          7         51              597
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide7.h5ad')

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525          1           0.0        0.001751
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525          1           0.0        0.000477
# AAACATTTCCCGGATT-1_WSSS_THYst9699525          1           0.0        0.000242
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525          1           0.0        0.000575
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525          1           0.0        0.000731
# ...                                         ...           ...             ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525          1           0.0        0.000785
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525          1           0.0        0.005870
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525          1           0.0        0.000127
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525          1           0.0        0.000108
# TTGTTTGTATTACACG-1_WSSS_THYst9699525          1           0.0        0.009071
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525        1.541157           0.004359
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525        0.001525           0.000017
# AAACATTTCCCGGATT-1_WSSS_THYst9699525        0.001744           0.000060
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525        0.000530           0.000050
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525        0.000610           0.000220
# ...                                              ...                ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525        0.000700           0.000632
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525        0.013089           0.009438
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525        0.003779           0.084643
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525        1.207687           0.000048
# TTGTTTGTATTACACG-1_WSSS_THYst9699525        0.001948           0.000315
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525       0.002649  0.001065    1.483553
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525       0.000268  0.000138    0.000376
# AAACATTTCCCGGATT-1_WSSS_THYst9699525       0.002066  0.010673    0.000945
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525       0.009610  0.016221    0.000696
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525       0.010200  0.021439    0.000825
# ...                                             ...       ...         ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525       0.013754  0.028640    0.000680
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525       0.001672  0.002985    0.006463
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525       0.000215  0.005103    0.001651
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525       0.000305  0.003516    0.290963
# TTGTTTGTATTACACG-1_WSSS_THYst9699525       0.007052  0.003754    0.001031
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525      0.002090          0.009983  ...
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525      0.000137          0.001281  ...
# AAACATTTCCCGGATT-1_WSSS_THYst9699525      0.000676          0.454696  ...
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525      0.001457          0.027216  ...
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525      0.002353          0.013453  ...
# ...                                            ...               ...  ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525      0.001986          0.044713  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525      0.001550          0.009358  ...
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525      0.000281          0.001404  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525      0.000717          0.001661  ...
# TTGTTTGTATTACACG-1_WSSS_THYst9699525      0.001231          0.016033  ...
#
#                                        stage  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525  PCW6.2
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525  PCW6.2
# AAACATTTCCCGGATT-1_WSSS_THYst9699525  PCW6.2
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525  PCW6.2
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525  PCW6.2
# ...                                      ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525  PCW6.2
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525  PCW6.2
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525  PCW6.2
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525  PCW6.2
# TTGTTTGTATTACACG-1_WSSS_THYst9699525  PCW6.2
#
#                                       development_stage_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACATTTCCCGGATT-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525                      HsapDv:0000024
# ...                                                                  ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTTGTATTACACG-1_WSSS_THYst9699525                      HsapDv:0000024
#
#                                       disease_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525              PATO:0000461
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525              PATO:0000461
# AAACATTTCCCGGATT-1_WSSS_THYst9699525              PATO:0000461
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525              PATO:0000461
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525              PATO:0000461
# ...                                                        ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525              PATO:0000461
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525              PATO:0000461
# TTGTTTGTATTACACG-1_WSSS_THYst9699525              PATO:0000461
#
#                                       is_primary_data  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525             True
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525             True
# AAACATTTCCCGGATT-1_WSSS_THYst9699525             True
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525             True
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525             True
# ...                                               ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525             True
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525             True
# TTGTTTGTATTACACG-1_WSSS_THYst9699525             True
#
#                                       organism_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACATTTCCCGGATT-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525             NCBITaxon:9606
# ...                                                         ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTTGTATTACACG-1_WSSS_THYst9699525             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525                                   unknown
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525                                   unknown
# AAACATTTCCCGGATT-1_WSSS_THYst9699525                                   unknown
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525                                   unknown
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525                                   unknown
# ...                                                                        ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525                                   unknown
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525                                   unknown
# TTGTTTGTATTACACG-1_WSSS_THYst9699525                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525          PATO:0000384               na
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525          PATO:0000384               na
# AAACATTTCCCGGATT-1_WSSS_THYst9699525          PATO:0000384               na
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525          PATO:0000384               na
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTTGTATTACACG-1_WSSS_THYst9699525          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACATTTCCCGGATT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTTGTATTACACG-1_WSSS_THYst9699525       tissue           UBERON:0000978
#
# [1381 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525          1           0.0        0.001751
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525          1           0.0        0.000477
# AAACATTTCCCGGATT-1_WSSS_THYst9699525          1           0.0        0.000242
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525          1           0.0        0.000575
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525          1           0.0        0.000731
# ...                                         ...           ...             ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525          1           0.0        0.000785
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525          1           0.0        0.005870
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525          1           0.0        0.000127
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525          1           0.0        0.000108
# TTGTTTGTATTACACG-1_WSSS_THYst9699525          1           0.0        0.009071
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525        1.541157           0.004359
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525        0.001525           0.000017
# AAACATTTCCCGGATT-1_WSSS_THYst9699525        0.001744           0.000060
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525        0.000530           0.000050
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525        0.000610           0.000220
# ...                                              ...                ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525        0.000700           0.000632
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525        0.013089           0.009438
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525        0.003779           0.084643
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525        1.207687           0.000048
# TTGTTTGTATTACACG-1_WSSS_THYst9699525        0.001948           0.000315
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525       0.002649  0.001065    1.483553
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525       0.000268  0.000138    0.000376
# AAACATTTCCCGGATT-1_WSSS_THYst9699525       0.002066  0.010673    0.000945
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525       0.009610  0.016221    0.000696
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525       0.010200  0.021439    0.000825
# ...                                             ...       ...         ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525       0.013754  0.028640    0.000680
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525       0.001672  0.002985    0.006463
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525       0.000215  0.005103    0.001651
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525       0.000305  0.003516    0.290963
# TTGTTTGTATTACACG-1_WSSS_THYst9699525       0.007052  0.003754    0.001031
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525      0.002090          0.009983  ...
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525      0.000137          0.001281  ...
# AAACATTTCCCGGATT-1_WSSS_THYst9699525      0.000676          0.454696  ...
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525      0.001457          0.027216  ...
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525      0.002353          0.013453  ...
# ...                                            ...               ...  ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525      0.001986          0.044713  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525      0.001550          0.009358  ...
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525      0.000281          0.001404  ...
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525      0.000717          0.001661  ...
# TTGTTTGTATTACACG-1_WSSS_THYst9699525      0.001231          0.016033  ...
#
#                                       development_stage_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACATTTCCCGGATT-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525                      HsapDv:0000024
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525                      HsapDv:0000024
# ...                                                                  ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525                      HsapDv:0000024
# TTGTTTGTATTACACG-1_WSSS_THYst9699525                      HsapDv:0000024
#
#                                       disease_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525              PATO:0000461
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525              PATO:0000461
# AAACATTTCCCGGATT-1_WSSS_THYst9699525              PATO:0000461
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525              PATO:0000461
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525              PATO:0000461
# ...                                                        ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525              PATO:0000461
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525              PATO:0000461
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525              PATO:0000461
# TTGTTTGTATTACACG-1_WSSS_THYst9699525              PATO:0000461
#
#                                       is_primary_data  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525             True
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525             True
# AAACATTTCCCGGATT-1_WSSS_THYst9699525             True
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525             True
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525             True
# ...                                               ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525             True
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525             True
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525             True
# TTGTTTGTATTACACG-1_WSSS_THYst9699525             True
#
#                                       organism_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACATTTCCCGGATT-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525             NCBITaxon:9606
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525             NCBITaxon:9606
# ...                                                         ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525             NCBITaxon:9606
# TTGTTTGTATTACACG-1_WSSS_THYst9699525             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525                                   unknown
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525                                   unknown
# AAACATTTCCCGGATT-1_WSSS_THYst9699525                                   unknown
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525                                   unknown
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525                                   unknown
# ...                                                                        ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525                                   unknown
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525                                   unknown
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525                                   unknown
# TTGTTTGTATTACACG-1_WSSS_THYst9699525                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525          PATO:0000384               na
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525          PATO:0000384               na
# AAACATTTCCCGGATT-1_WSSS_THYst9699525          PATO:0000384               na
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525          PATO:0000384               na
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525          PATO:0000384               na
# TTGTTTGTATTACACG-1_WSSS_THYst9699525          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACATTTCCCGGATT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525       tissue           UBERON:0000978
# TTGTTTGTATTACACG-1_WSSS_THYst9699525       tissue           UBERON:0000978
#
#                                               barcodes
# AAACAGAGCGACTCCT-1_WSSS_THYst9699525  AAACAGAGCGACTCCT
# AAACAGTGTTCCTGGG-1_WSSS_THYst9699525  AAACAGTGTTCCTGGG
# AAACATTTCCCGGATT-1_WSSS_THYst9699525  AAACATTTCCCGGATT
# AAACCTAAGCAGCCGG-1_WSSS_THYst9699525  AAACCTAAGCAGCCGG
# AAACGGGCGTACGGGT-1_WSSS_THYst9699525  AAACGGGCGTACGGGT
# ...                                                ...
# TTGTGGTGGTACTAAG-1_WSSS_THYst9699525  TTGTGGTGGTACTAAG
# TTGTGTATGCCACCAA-1_WSSS_THYst9699525  TTGTGTATGCCACCAA
# TTGTTCAGTGTGCTAC-1_WSSS_THYst9699525  TTGTTCAGTGTGCTAC
# TTGTTGTGTGTCAAGA-1_WSSS_THYst9699525  TTGTTGTGTGTCAAGA
# TTGTTTGTATTACACG-1_WSSS_THYst9699525  TTGTTTGTATTACACG
#
# [1381 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAGAGCGACTCCT': 'CL:0002551',
#  'AAACAGTGTTCCTGGG': 'CL:0008019',
#  'AAACATTTCCCGGATT': 'CL:0008019',
#  'AAACCTAAGCAGCCGG': 'CL:0000138',
#  'AAACGGGCGTACGGGT': 'CL:0000138',
#  'AAACGGTTGCGAACTG': 'CL:0008019',
#  'AAACGTGTTCGCCCTA': 'CL:0008019',
#  'AAACTAACGTGGCGAC': 'CL:0002551',
#  'AAACTCGGTTCGCAAT': 'CL:0000187',
#  'AAACTCGTGATATAAG': 'CL:0002551',
#  'AAAGGCTACGGACCAT': 'CL:0000187',
#  'AAAGGCTCTCGCGCCG': 'CL:0002551',
#  'AAAGGGATGTAGCAAG': 'CL:0008019',
#  'AAAGGTAAGCTGTACC': 'CL:0002551',
#  'AAATCCGATACACGCC': 'CL:0008019',
#  'AAATCTAGCCCTGCTA': 'CL:0008019',
#  'AAATGATTCGATCAGC': 'CL:0000187',
#  'AAATTACCTATCGATG': 'CL:0000138',
#  'AAATTGGTGAGAAGCA': 'CL:0008019',
#  'AACAATACATTGTCGA': 'CL:0002551',
#  'AACACACGCTCGCCGC': 'CL:0008019',
#  'AACAGGAAATCGAATA': 'CL:0008019',
#  'AACATATCAACTGGTG': 'CL:0002551',
#  'AACATCGATACGTCTA': 'CL:0008019',
#  'AACATTGTGACTCGAG': 'CL:0000187',
#  'AACCCGACAACCCGTG': 'CL:0008019',
#  'AACCCGCTGTATTCCA': 'CL:0002551',
#  'AACCGAGCTTGGTCAT': 'CL:0000138',
#  'AACCGTTGTGTTTGCT': 'CL:0008019',
#  'AACCTCGCTTTAGCCC': 'CL:0000138',
#  'AACCTTTACGACGTCT': 'CL:0002551',
#  'AACGATATGTCAACTG': 'CL:0000138',
#  'AACGCATGATCTGGGT': 'CL:0000138',
#  'AACGCGACCTTGGGCG': 'CL:0000515',
#  'AACGCGGTCTCCAGCC': 'CL:0008019',
#  'AACGCTGTTGCTGAAA': 'CL:0000138',
#  'AACTAGGCTTGGGTGT': 'CL:0002551',
#  'AACTCCAGAGCGTGTT': 'CL:0000138',
#  'AACTGAGGTCAGCGTC': 'CL:0000515',
#  'AACTGATATTAGGCCT': 'CL:0000138',
#  'AACTGGGTCCCGACGT': 'CL:0000138',
#  'AAGAAATCACCAGATT': 'CL:0002551',
#  'AAGACCCAACTGAACA': 'CL:0000388',
#  'AAGAGGCCCTTTGGAA': 'CL:0008019',
#  'AAGATTGGCGGAACGT': 'CL:0000138',
#  'AAGCACCCTGCGTATC': 'CL:0000138',
#  'AAGCCGCTTTACCTTG': 'CL:0002551',
#  'AAGCGCAGGGCTTTGA': 'CL:0008019',
#  'AAGCGGAGTGCGCGCA': 'CL:0008019',
#  'AAGCTCTTTCATGGTG': 'CL:0008019',
#  'AAGGATGAGGGACCTC': 'CL:0000138',
#  'AAGGGACAGATTCTGT': 'CL:0000138',
#  'AAGGTATCCTAATATA': 'CL:0000138',
#  'AAGTCTAGTAGCTGCC': 'CL:0002551',
#  'AAGTGAGTCGGGTTTA': 'CL:0000187',
#  'AAGTGCTTCTCTATTG': 'CL:0000138',
#  'AAGTTCACTCCAAGCT': 'CL:0000138',
#  'AAGTTCAGTCTGCGTA': 'CL:0008019',
#  'AAGTTGTGATGTTATA': 'CL:0008019',
#  'AAGTTTATGGGCCCAA': 'CL:0008019',
#  'AATACCGGAGGGCTGT': 'CL:0008019',
#  'AATAGCAAGCCTCCTG': 'CL:0008019',
#  'AATAGCTACCGCGTGC': 'CL:0000187',
#  'AATAGTCCGTCCCGAC': 'CL:0000138',
#  'AATATCGAGGGTTCTC': 'CL:0002551',
#  'AATCAGGTTTCATTTA': 'CL:0008019',
#  'AATCATGTAAAGACTC': 'CL:0000138',
#  'AATCCCGCTCAGAGCC': 'CL:0002551',
#  'AATCGTGAGCCGAGCA': 'CL:0008019',
#  'AATCTATGCCGGAGCC': 'CL:0002551',
#  'AATGATGATACGCTAT': 'CL:0008019',
#  'AATGATGCGACTCCTG': 'CL:0008019',
#  'AATGCAACCGGGTACC': 'CL:0008019',
#  'AATGCACCAAGCAATG': 'CL:0008019',
#  'AATGTGCTAATCTGAG': 'CL:0000138',
#  'AATTAACGGATTTCCA': 'CL:0000138',
#  'AATTCATAAGGGATCT': 'CL:0000138',
#  'AATTCCAAGCATGTAC': 'CL:0008019',
#  'AATTCGATTCGAGGAT': 'CL:0008019',
#  'AATTGCAGCAATCGAC': 'CL:0008019',
#  'ACAAACTCCATCAGAG': 'CL:0008019',
#  'ACAAAGCATGACCTAG': 'CL:0000138',
#  'ACAAATTCAGATCTGA': 'CL:0002551',
#  'ACAACAGCATGAGCTA': 'CL:0008019',
#  'ACAAGGATGCTTTAGG': 'CL:0000138',
#  'ACAATGATTCTTCTAC': 'CL:0008019',
#  'ACAATTGTGTCTCTTT': 'CL:0008019',
#  'ACAATTTGAGCAGTGG': 'CL:0008019',
#  'ACACAAAGACGGGTGG': 'CL:0000646',
#  'ACACAAATATTCCTAG': 'CL:0008019',
#  'ACACACTTTCTACACG': 'CL:0008019',
#  'ACACGAGACTCCTTCT': 'CL:0008019',
#  'ACACGGGAACTTAGGG': 'CL:0000138',
#  'ACACGTAGGCCACAAG': 'CL:0008019',
#  'ACAGCGACATTCTCAT': 'CL:0000138',
#  'ACAGGCACGGATCCTT': 'CL:0000138',
#  'ACAGGCTTGCCCGACT': 'CL:0008019',
#  'ACAGTATACCGTGGGA': 'CL:0002551',
#  'ACATAATAAGGCGGTG': 'CL:0008019',
#  'ACATCCCGGCCATACG': 'CL:0002551',
#  'ACCAAACACCCAGCGA': 'CL:0000187',
#  'ACCAACACCACACACT': 'CL:0000187',
#  'ACCAACCGCACTCCAC': 'CL:0000138',
#  'ACCAATATGCAAGTTA': 'CL:0008019',
#  'ACCAGTGCCCGGTCAA': 'CL:0002551',
#  'ACCCATTTGTCCCTCT': 'CL:0008019',
#  'ACCCGATTGGTTCCGA': 'CL:0000138',
#  'ACCCGGAAACTCCCAG': 'CL:0008019',
#  'ACCCGTGTCATCAGTA': 'CL:0002551',
#  'ACCCTCCCGTCAGGGC': 'CL:0008019',
#  'ACCCTGGTAACGCCCT': 'CL:0002551',
#  'ACCCTTCATCTGCGAA': 'CL:0008019',
#  'ACCCTTGCCTGGGTCG': 'CL:0008019',
#  'ACCGACACATCTCCCA': 'CL:0000138',
#  'ACCGACTGAGTCCCAC': 'CL:0008019',
#  'ACCGTGACCACGTGGG': 'CL:0002551',
#  'ACCTACTATAAATCTA': 'CL:0000515',
#  'ACCTCCGCCCTCGCTG': 'CL:0008019',
#  'ACGACTCTAGGGCCGA': 'CL:0008019',
#  'ACGACTGGTCATACTC': 'CL:0008019',
#  'ACGAGTACGGATGCCC': 'CL:0002551',
#  'ACGATACATAGAACTA': 'CL:0008019',
#  'ACGATCATACATAGAG': 'CL:0008019',
#  'ACGCAAACTAATAGAT': 'CL:0000187',
#  'ACGCAATCACTACAGC': 'CL:0002551',
#  'ACGCATACGTTTACTA': 'CL:0008019',
#  'ACGCCAGATGATTTCT': 'CL:0008019',
#  'ACGCTAGTGATACACT': 'CL:0002551',
#  'ACGGACTCTCAAAGCG': 'CL:0000138',
#  'ACGGAGCGCAAATTAC': 'CL:0000187',
#  'ACGGATGGTGCGGATA': 'CL:0008019',
#  'ACGGGCGTATGCGACA': 'CL:0002551',
#  'ACGGTACAGTTCAATG': 'CL:0008019',
#  'ACGTACTTTGGCACGG': 'CL:0008019',
#  'ACGTAGATTGCTGATG': 'CL:0008019',
#  'ACGTGCGCCTCGTGCA': 'CL:0008019',
#  'ACGTTCACTATGCCGC': 'CL:0008019',
#  'ACGTTCGTTCAGGAAA': 'CL:0002551',
#  'ACGTTCTGTACAAGTC': 'CL:0000138',
#  'ACGTTTAGTTGTGATC': 'CL:0008019',
#  'ACTACAAAGAGAGGTG': 'CL:0008019',
#  'ACTACGCGTTAGAATT': 'CL:0008019',
#  'ACTATATGCTGTGTTC': 'CL:0000187',
#  'ACTATTTCCGGGCCCA': 'CL:0000646',
#  'ACTCAAGTGCAAGGCT': 'CL:0000138',
#  'ACTCAATAAAGGCACG': 'CL:0000138',
#  'ACTCCCGTAGACTAGG': 'CL:0002551',
#  'ACTCCCTAATGCTAAA': 'CL:0008019',
#  'ACTCCGGCCGACCACT': 'CL:0008019',
#  'ACTCTGACCTAATAGA': 'CL:0000138',
#  'ACTGAAACGCCGTTAG': 'CL:0000138',
#  'ACTGCCCGCCATTCTC': 'CL:0002551',
#  'ACTGCCGTCGTAACTC': 'CL:0008019',
#  'ACTGGGATGCCAGTGC': 'CL:0000515',
#  'ACTGTACGATACACAT': 'CL:0008019',
#  'ACTGTCTTCTTTAGAA': 'CL:0008019',
#  'ACTTACGCATCCACGC': 'CL:0000138',
#  'ACTTCCATGCGGGACA': 'CL:0000138',
#  'ACTTCGCCATACGCAC': 'CL:0000138',
#  'ACTTGTTACCGGATCA': 'CL:0002551',
#  'ACTTTCCTATAGCTTC': 'CL:0008019',
#  'AGAACGTGGTACATTC': 'CL:0000138',
#  'AGAAGGTTGTAGGTCG': 'CL:0008019',
#  'AGAATGCGGGTTCGGA': 'CL:0000515',
#  'AGACCCGCCCTCCTCG': 'CL:0008019',
#  'AGACGGGCCGATTTAA': 'CL:0002551',
#  'AGACTGTTACCGGGTC': 'CL:0002551',
#  'AGAGAAACACCAGAAA': 'CL:0008019',
#  'AGAGAACCGTCTAGGA': 'CL:0000138',
#  'AGAGCGCTTGTAACGG': 'CL:0002551',
#  'AGAGCGGGCTAATCAT': 'CL:0000138',
#  'AGAGTTGCAGGCCTCC': 'CL:0000138',
#  'AGATACCAGCACTTCA': 'CL:0008019',
#  'AGATATAATACGACTA': 'CL:0008019',
#  'AGATCGTGCATAAGAT': 'CL:0000138',
#  'AGATCTCAGGTGTGAT': 'CL:0008019',
#  'AGATGAGGGTTGCGAT': 'CL:0002551',
#  'AGCAAAGGCCGCTAGT': 'CL:0000138',
#  'AGCACCAGTACTCACG': 'CL:0008019',
#  'AGCAGAAGGAGAAAGA': 'CL:0008019',
#  'AGCAGCCAGATGAATA': 'CL:0002551',
#  'AGCATATCAATATGCT': 'CL:0008019',
#  'AGCATTACGAGGCAAG': 'CL:0008019',
#  'AGCCAAGCTTTGTGTC': 'CL:0000058',
#  'AGCCACAGGTTACCCG': 'CL:0000138',
#  'AGCCACTCCCGTGCTT': 'CL:0008019',
#  'AGCCCGCAACAAGCAG': 'CL:0000187',
#  'AGCCCGGTAGCCTGTA': 'CL:0000187',
#  'AGCCCTAAGCGAAGTT': 'CL:0000138',
#  'AGCCCTCCCTGGTGGC': 'CL:0002551',
#  'AGCCCTTCTAATCCGA': 'CL:0008019',
#  'AGCGACATCCCATTCA': 'CL:0008019',
#  'AGCGACCAACGATATT': 'CL:0000646',
#  'AGCGACTTTGAAGACA': 'CL:0008019',
#  'AGCGATGCGCCTAATA': 'CL:0008019',
#  'AGCGCATAATGAATCG': 'CL:0002551',
#  'AGCGCGGGTGCCAATG': 'CL:0000138',
#  'AGCGGACACTTCGTAG': 'CL:0000138',
#  'AGCGGGTCTGACACTC': 'CL:0008019',
#  'AGCGGTTGCCGCTCTG': 'CL:0000187',
#  'AGCTAACAAGCAATGT': 'CL:0002551',
#  'AGCTAAGTACGCAGGC': 'CL:0000138',
#  'AGCTAGAAGCAGAAGT': 'CL:0000138',
#  'AGCTATTTAATCCAAC': 'CL:0008019',
#  'AGCTCCATATATGTTC': 'CL:0008019',
#  'AGCTCGTTGATGGAAA': 'CL:0008019',
#  'AGCTCTTCCCAGTGCA': 'CL:0002551',
#  'AGCTGAAGTAAACCAA': 'CL:0000138',
#  'AGCTTCTTCTCGAGCA': 'CL:0008019',
#  'AGGAAGCTGTCCGCCG': 'CL:0008019',
#  'AGGACGCTCGATGTTG': 'CL:0008019',
#  'AGGAGGCCTTCGCGCG': 'CL:0008019',
#  'AGGATATCCGACTGCA': 'CL:0008019',
#  'AGGCAGATGCGTAAAC': 'CL:0000138',
#  'AGGCAGGGAGCGTACT': 'CL:0002551',
#  'AGGCCTATCATACCAA': 'CL:0008019',
#  'AGGCCTGAGAATCTCG': 'CL:0000138',
#  'AGGCGTCTATGGACGG': 'CL:0000515',
#  'AGGGACTCTACGCGAC': 'CL:0002551',
#  'AGGGTCAGAGCACTCG': 'CL:0008019',
#  'AGGGTCAGTAACCCTA': 'CL:0008019',
#  'AGGGTGCCGTTCTTTA': 'CL:0008019',
#  'AGGGTTCAGACGGTCC': 'CL:0008019',
#  'AGGTAGATCGAGATAT': 'CL:0002355',
#  'AGGTCGCGGAGTTACT': 'CL:0000138',
#  'AGGTGGTGACCTTCGC': 'CL:0008019',
#  'AGGTTGAGGCACGCTT': 'CL:0000138',
#  'AGTAATGTCTTGCCGC': 'CL:0008019',
#  'AGTACCTTCGAGTGCT': 'CL:0002551',
#  'AGTACGGGCACCTGGC': 'CL:0000138',
#  'AGTACTCTTATGCCCA': 'CL:0000138',
#  'AGTAGAAGGCGCCTCA': 'CL:0002551',
#  'AGTAGGAAGGAAGTTG': 'CL:0000187',
#  'AGTATACACAGCGACA': 'CL:0000187',
#  'AGTATTTGGCACGACC': 'CL:0002551',
#  'AGTCAAATGATGTGAT': 'CL:0008019',
#  'AGTCACTAGCTCTCGA': 'CL:0000138',
#  'AGTCCCGCCTTTAATT': 'CL:0002551',
#  'AGTCGTATAAAGCAGA': 'CL:0000138',
#  'AGTCGTCGACCACCAA': 'CL:0000138',
#  'AGTCTTCTCCTCAAAT': 'CL:0000138',
#  'AGTCTTTAAAGTGTCC': 'CL:0008019',
#  'AGTGAAGATGGTGTCC': 'CL:0002551',
#  'AGTGAGCCTCGCCGCC': 'CL:0000646',
#  'AGTGATAACCTGCGCG': 'CL:0000138',
#  'AGTGCACGCTTAAGAA': 'CL:0008019',
#  'AGTGCTAAACACAGCA': 'CL:0000138',
#  'AGTGGCGGCAATTTGA': 'CL:0000138',
#  'AGTGGCGTCTGAAGGT': 'CL:0000138',
#  'AGTGTATTGCGCATTG': 'CL:0002551',
#  'AGTTAAGCGGTCCCGG': 'CL:0008019',
#  'AGTTACTCTATCGTGG': 'CL:0000646',
#  'AGTTGACGGTCCTTGC': 'CL:0008019',
#  'AGTTGGCAAGGCTAGA': 'CL:0008019',
#  'AGTTTCGCAGGTCGGA': 'CL:0008019',
#  'AGTTTGCACCTGCCTC': 'CL:0000138',
#  'ATAAACGTTGCACCAC': 'CL:0008019',
#  'ATAACGGAGTCCAACG': 'CL:0000138',
#  'ATAACGTTACCTCCAC': 'CL:0008019',
#  'ATAAGTACCCGATTGT': 'CL:0008019',
#  'ATAAGTAGGATTCAGA': 'CL:0002551',
#  'ATAATCTTGGAGAACC': 'CL:0000138',
#  'ATAATTAGCTAAGTAG': 'CL:0000138',
#  'ATACAGGCCCTCCAAT': 'CL:0002551',
#  'ATACCGTCATCCATAA': 'CL:0008019',
#  'ATACCTAACCAAGAAA': 'CL:0008019',
#  'ATACGAGGTTTGTAAG': 'CL:0008019',
#  'ATACGGGTTTCGATTG': 'CL:0008019',
#  'ATACGTACTTAGCCAC': 'CL:0008019',
#  'ATACGTTATGCACGGA': 'CL:0000138',
#  'ATACTACCCGTACCAC': 'CL:0000138',
#  'ATACTAGCATGACCCT': 'CL:0008019',
#  'ATACTGCCTTACACCG': 'CL:0000138',
#  'ATAGACAACGGGACCT': 'CL:0002551',
#  'ATAGAGTTATCAACTT': 'CL:0008019',
#  'ATAGCAACTAGGGAAG': 'CL:0000138',
#  'ATAGGCTAGCTTCGCA': 'CL:0000138',
#  'ATAGGGATATCCTTGA': 'CL:0000138',
#  'ATAGGTTGGGCAGATG': 'CL:0008019',
#  'ATATAAAGCGCTCGTG': 'CL:0000138',
#  'ATATAACACGGGCGCA': 'CL:0000138',
#  'ATATACGCTCGTGACG': 'CL:0008019',
#  'ATATCGTTCCTCGAAC': 'CL:0000138',
#  'ATATCTCCCTCGTTAA': 'CL:0008019',
#  'ATATGGGATAGCAACT': 'CL:0000515',
#  'ATATGTGCACAAACCA': 'CL:0008019',
#  'ATCAAGATCCCAGGAC': 'CL:0000187',
#  'ATCACATTAGAATATC': 'CL:0000138',
#  'ATCACTTCATCCTCGC': 'CL:0000138',
#  'ATCAGCCTCATGCTGC': 'CL:0000138',
#  'ATCAGTAGGCAGGGAT': 'CL:0000138',
#  'ATCATAGATCGACGAG': 'CL:0008019',
#  'ATCATAGCCCTATGTA': 'CL:0008019',
#  'ATCCACATCGACAGAA': 'CL:0000138',
#  'ATCCACTTTCAGACTA': 'CL:0008019',
#  'ATCCCATTTCCGTGGG': 'CL:0000187',
#  'ATCGACTCTTTCCGTT': 'CL:0008019',
#  'ATCGCACGCCGGGAGA': 'CL:0008019',
#  'ATCGCTGCGTGCAGCA': 'CL:0002551',
#  'ATCGGCAAGCAGTCCA': 'CL:0008019',
#  'ATCGTTAGCTAGCGGA': 'CL:0000138',
#  'ATCTAATATCCTACGG': 'CL:0002551',
#  'ATCTACCATCTGCTCC': 'CL:0008019',
#  'ATCTAGCTTGTGAGGG': 'CL:0008019',
#  'ATCTCCCACGGAATAT': 'CL:0008019',
#  'ATCTCCCTGCAATCTA': 'CL:0008019',
#  'ATCTGACATGGAAGGA': 'CL:0002551',
#  'ATCTGCTGTTATCGCC': 'CL:0008019',
#  'ATCTGGGCTGTTCTTG': 'CL:0000138',
#  'ATCTGGTTAAGACTGT': 'CL:0000138',
#  'ATCTTATCGCACACCC': 'CL:0008019',
#  'ATGACGCCGGCTCTAA': 'CL:0008019',
#  'ATGACTATCAGCTGTG': 'CL:0002551',
#  'ATGCATGATCCAGGAT': 'CL:0008019',
#  'ATGCCAATCGCTCTGC': 'CL:0000187',
#  'ATGCCGGTCTTGCATA': 'CL:0008019',
#  'ATGCCGGTTGATGGGA': 'CL:0008019',
#  'ATGCGACAATTGGTCC': 'CL:0000187',
#  'ATGCTCTGGCGCGGTA': 'CL:0000138',
#  'ATGGACTGCTTAGTTG': 'CL:0000138',
#  'ATGGATCCGGCGTCCG': 'CL:0000138',
#  'ATGGATTGACCAAACG': 'CL:0008019',
#  'ATGGTATTGGGAACCG': 'CL:0002551',
#  'ATGTACGATGACGTCG': 'CL:0000138',
#  'ATGTAGCGCGCGTAGG': 'CL:0008019',
#  'ATGTCTTGTTTGACTC': 'CL:0000138',
#  'ATGTGCATCCGACGCA': 'CL:0008019',
#  'ATGTTGATTAGAGACT': 'CL:0008019',
#  'ATGTTGTAGTCTGTTT': 'CL:0000187',
#  'ATTAATACTACGCGGG': 'CL:0000138',
#  'ATTAATGAACCAGTCG': 'CL:0000138',
#  'ATTAATTCGGTCACTC': 'CL:0008019',
#  'ATTACGACTCCACAGT': 'CL:0002551',
#  'ATTACTTACTGGGCAT': 'CL:0000138',
#  'ATTAGATTCCTCAGCA': 'CL:0008019',
#  'ATTATACTTTGCTCGT': 'CL:0008019',
#  'ATTATCGGAATGTACG': 'CL:0000187',
#  'ATTATTCAGAGTCACT': 'CL:0008019',
#  'ATTCAACCATTTAAGG': 'CL:0000138',
#  'ATTCACTGATGTTGGA': 'CL:0002551',
#  'ATTCAGGACCTATTTC': 'CL:0000138',
#  'ATTCATCGTTGAGGCA': 'CL:0000138',
#  'ATTCCTAAGACGTGGA': 'CL:0000187',
#  'ATTCGCAGAGGACACT': 'CL:0008019',
#  'ATTCGCGCCTTGAGAG': 'CL:0008019',
#  'ATTGACCGGCGATGAC': 'CL:0000187',
#  'ATTGCCTTTATGTTTG': 'CL:0000138',
#  'ATTGCGATCAGTAACT': 'CL:0000646',
#  'ATTGGATTACAGCGTA': 'CL:0008019',
#  'ATTGGGAGTTCTGTAA': 'CL:0008019',
#  'ATTGTCTGTTTCATGT': 'CL:0000515',
#  'ATTGTGACTTCGCTGC': 'CL:0000515',
#  'ATTTCATTATTTCGCG': 'CL:0000138',
#  'ATTTGTTCCAGGGCTC': 'CL:0008019',
#  'CAAATTGGATTATGCC': 'CL:0002551',
#  'CAAATTGTCAGCAAGC': 'CL:0008019',
#  'CAACCTACCGAGCAGT': 'CL:0008019',
#  'CAACGCGATGAGCCAA': 'CL:0000138',
#  'CAACTATATCGAATGC': 'CL:0000138',
#  'CAACTCCGTAACTTGC': 'CL:0008019',
#  'CAACTGAGGGTATGAC': 'CL:0008019',
#  'CAACTGCTCATCCGAT': 'CL:0008019',
#  'CAAGAAACCCTAAACT': 'CL:0008019',
#  'CAAGCACCAAATGCCT': 'CL:0008019',
#  'CAAGCGGCACATAATT': 'CL:0000646',
#  'CAAGGCCAGTGGTGCA': 'CL:0000138',
#  'CAAGTAAGTGATAGAC': 'CL:0000187',
#  'CAAGTCGTTGAAATCT': 'CL:0008019',
#  'CAATAAACCTTGGCCC': 'CL:0000138',
#  'CAATGACCCTTAATTT': 'CL:0000515',
#  'CAATGCGAGAAGTATC': 'CL:0008019',
#  'CAATGGATCTCTACCA': 'CL:0008019',
#  'CAATTAAGGGTGATGA': 'CL:0008019',
#  'CACAAGAAAGATATTA': 'CL:0000187',
#  'CACACACGCTAACGAG': 'CL:0008019',
#  'CACACTTGTATTGCGA': 'CL:0008019',
#  'CACAGCTAGGGAGTGA': 'CL:0008019',
#  'CACAGGGCCATATAGT': 'CL:0000138',
#  'CACAGGGCCGTTGTCA': 'CL:0000138',
#  'CACATCGTGCACGCGC': 'CL:0002551',
#  'CACATCTCACCGACGA': 'CL:0000138',
#  'CACATTCTTTCGATGG': 'CL:0002551',
#  'CACCATCGGAGGAGAC': 'CL:0008019',
#  'CACCATGATCGCAAAG': 'CL:0000187',
#  'CACCCACGAGGCAATT': 'CL:0008019',
#  'CACCCTAACAAGATCT': 'CL:0008019',
#  'CACCGCCAGAAGGTTT': 'CL:0008019',
#  'CACCGCGTCCACTCTA': 'CL:0008019',
#  'CACCGGGCATCACAAG': 'CL:0000646',
#  'CACCTAATCAGTTTAC': 'CL:0000138',
#  'CACCTCGATGGTGGAC': 'CL:0000138',
#  'CACCTTGCGAAACTCG': 'CL:0000138',
#  'CACGCACAGCGCAGCT': 'CL:0000138',
#  'CACGGCGCGCCAAAGG': 'CL:0002551',
#  'CACGTTTCGTACACAC': 'CL:0000138',
#  'CACTACGGGAGCTGCC': 'CL:0008019',
#  'CACTCCTCTCGGTCGG': 'CL:0000138',
#  'CACTCTCAAGCATCGA': 'CL:0000515',
#  'CACTCTTCTGCTAGCC': 'CL:0000138',
#  'CACTGACGATTGTGGA': 'CL:0000187',
#  'CAGAACTTAGCCCTCT': 'CL:0008019',
#  'CAGAGCATGAGCTTGC': 'CL:0000138',
#  'CAGATAATGGGCGGGT': 'CL:0000138',
#  'CAGATCATTTAAAGTC': 'CL:0000388',
#  'CAGCAGCCCGTTCCTT': 'CL:0000138',
#  'CAGCAGTCTGTGCTGC': 'CL:0008019',
#  'CAGCCTCCTGCAGAGG': 'CL:0000138',
#  'CAGCCTCTCCTCAAGA': 'CL:0002551',
#  'CAGCTCGACAAGTTAA': 'CL:0008019',
#  'CAGCTCTGGGCTCACT': 'CL:0008019',
#  'CAGGCAGTCTTACCAG': 'CL:0000138',
#  'CAGGTTTAGTACTACA': 'CL:0008019',
#  'CAGTAACTATTTATTG': 'CL:0008019',
#  'CAGTACATTCTCTAAA': 'CL:0000138',
#  'CAGTAGCCCACGCGGT': 'CL:0000138',
#  'CAGTCCAACGCCTTCT': 'CL:0002355',
#  'CAGTCGAGGATGCAAT': 'CL:0008019',
#  'CAGTGAATAAATGACT': 'CL:0008019',
#  'CAGTGTCGGCTGGCCC': 'CL:0008019',
#  'CAGTTCGAGGACCCGA': 'CL:0000515',
#  'CATAAGAAGCTTGGCT': 'CL:0000138',
#  'CATACACGGTTCCCAC': 'CL:0008019',
#  'CATACGAACTAGCTGG': 'CL:0002551',
#  'CATACTTCTTTCTCCG': 'CL:0008019',
#  'CATAGAGGAGATACTA': 'CL:0008019',
#  'CATAGTACATTGAGAG': 'CL:0000138',
#  'CATAGTCAAATACATA': 'CL:0000138',
#  'CATATACTACTGATAA': 'CL:0008019',
#  'CATCAAACTGGCGCCC': 'CL:0000187',
#  'CATCATTACCCTGAGG': 'CL:0008019',
#  'CATCCTCTCAAAGATC': 'CL:0008019',
#  'CATCTACCCGAGAACG': 'CL:0008019',
#  'CATCTATCCCGTGTCT': 'CL:0008019',
#  'CATGAGATGCACTCTC': 'CL:0008019',
#  'CATGATGCACAATTCT': 'CL:0008019',
#  'CATGCGACCAGTTTAA': 'CL:0008019',
#  'CATGCGTTAGACAGAA': 'CL:0008019',
#  'CATGCGTTGAGAGGAG': 'CL:0008019',
#  'CATGCTGGCTCCAATT': 'CL:0008019',
#  'CATGGATTGTCTTCCG': 'CL:0008019',
#  'CATGGCAGGAAGATCG': 'CL:0008019',
#  'CATGGGTATGCCTTAT': 'CL:0000138',
#  'CATGGGTCGGGTGTGG': 'CL:0008019',
#  'CATGGTCTAGATACCG': 'CL:0008019',
#  'CATGGTTTATTAATCA': 'CL:0008019',
#  'CATGTAAGAGACATTT': 'CL:0008019',
#  'CATGTAGGAGCGCCAA': 'CL:0000187',
#  'CATTACGCAGGAAGGG': 'CL:0000646',
#  'CATTACGTCGGCCCGT': 'CL:0000138',
#  'CATTATCCCATTAACG': 'CL:0000138',
#  'CATTGATGAACACGCC': 'CL:0002551',
#  'CATTGCGGGTCAATTC': 'CL:0002551',
#  'CATTTAGCGGACCATG': 'CL:0000138',
#  'CCAACCTTATGTAACT': 'CL:0008019',
#  'CCAACGCTTGCCAGGG': 'CL:0002551',
#  'CCAAGACTTCTGCGAA': 'CL:0008019',
#  'CCAATTACGGGTCGAG': 'CL:0008019',
#  'CCACGAGAAGAGAATC': 'CL:0008019',
#  'CCACGGCAGGTGTAGG': 'CL:0008019',
#  'CCACTGTTTGGATTAA': 'CL:0000138',
#  'CCAGATAGTTGAGTGA': 'CL:0008019',
#  'CCAGATGTAAATGGGT': 'CL:0002551',
#  'CCAGCTCGAACGCATT': 'CL:0000138',
#  'CCAGTAGTCTGATCCA': 'CL:0002551',
#  'CCAGTCTAGACGGCGC': 'CL:0000138',
#  'CCAGTCTTGTCATAGA': 'CL:0008019',
#  'CCATAGGTTGGCGTGG': 'CL:0008019',
#  'CCATATGGAAACTATA': 'CL:0008019',
#  'CCATGCCCTAGATTTC': 'CL:0008019',
#  'CCATGGCAAACGCTCA': 'CL:0008019',
#  'CCATTTCTACCTATTA': 'CL:0008019',
#  'CCCAAGTCATTACACT': 'CL:0000138',
#  'CCCAATGAGATTTGCA': 'CL:0002551',
#  'CCCAGAGGAGGGCGTA': 'CL:0000138',
#  'CCCGACCATAGTCCGC': 'CL:0008019',
#  'CCCGCAAATAATCATC': 'CL:0002551',
#  'CCCGGGTCGTTCAGGG': 'CL:0008019',
#  'CCCTAGCTCTAAGGTC': 'CL:0008019',
#  'CCCTCGATAATACACA': 'CL:0002551',
#  'CCCTTTAATGGAGTTC': 'CL:0008019',
#  'CCGACAATAGGCCGCC': 'CL:0008019',
#  'CCGAGCTGTGCTTGTC': 'CL:0000187',
#  'CCGATCTTAAGAGGCT': 'CL:0008019',
#  'CCGCATGTGGTACGAT': 'CL:0002551',
#  'CCGCCTGCGAATTGGT': 'CL:0002551',
#  'CCGCTCTTCCGAACTA': 'CL:0008019',
#  'CCGGAGCGTACTTTCT': 'CL:0008019',
#  'CCGGAGGTCTTATGGT': 'CL:0000187',
#  'CCGTAGGAAATCCCTG': 'CL:0000138',
#  'CCGTAGGGTTGTTTAC': 'CL:0008019',
#  'CCGTATTAGCGCAGTT': 'CL:0008019',
#  'CCGTGGAACGATCCAA': 'CL:0000138',
#  'CCGTTACGTTAGAACA': 'CL:0008019',
#  'CCGTTTCCTTTCCGTG': 'CL:0008019',
#  'CCTAACTAAGGCTCTA': 'CL:0008019',
#  'CCTACAAGTCCGGAAT': 'CL:0002551',
#  'CCTATAATGAGTGCCC': 'CL:0008019',
#  'CCTATATTTGTCCTGG': 'CL:0000187',
#  'CCTATCTATATCGGAA': 'CL:0000138',
#  'CCTATGGGTTACCGTC': 'CL:0008019',
#  'CCTATGGTCAAAGCTG': 'CL:0008019',
#  'CCTATGTCCACTCCAC': 'CL:0000138',
#  'CCTCACCTGAGGGAGC': 'CL:0002551',
#  'CCTCACCTTAGCATCG': 'CL:0002551',
#  'CCTCCTGTTGTGTCGT': 'CL:0000138',
#  'CCTCGAAGTGGACGGG': 'CL:0008019',
#  'CCTCGCCAGCAAATTA': 'CL:0008019',
#  'CCTCGCGCGATATAGG': 'CL:0008019',
#  'CCTCGCGCTGTGCGAT': 'CL:0008019',
#  'CCTCGGTTTCCTTGCC': 'CL:0000138',
#  'CCTCTAATCTGCCAAG': 'CL:0000138',
#  'CCTCTACAAGGATTGG': 'CL:0002551',
#  'CCTCTGGCCTAGACGG': 'CL:0008019',
#  'CCTGAATATTTACATA': 'CL:0000138',
#  'CCTGAGAATAAATGCA': 'CL:0000138',
#  'CCTGGTCGAATGTGGG': 'CL:0000138',
#  'CCTGTCACCCGGGCTC': 'CL:0008019',
#  'CCTGTTCAACCTCGGG': 'CL:0008019',
#  'CCTGTTTGAAGACACG': 'CL:0000138',
#  'CCTTCAGTTAAAGTGA': 'CL:0002551',
#  'CCTTCGTATAGAATCC': 'CL:0002551',
#  'CCTTCTTGATCCAGTG': 'CL:0000138',
#  'CCTTGACCACTTTATT': 'CL:0008019',
#  'CCTTGTGAACGTGGTT': 'CL:0002355',
#  'CCTTTAAGGGAGCACT': 'CL:0002551',
#  'CCTTTCAATGAAGAAA': 'CL:0000138',
#  'CGAACAGTATGGGCGT': 'CL:0000646',
#  'CGAACATAGTCAGAAA': 'CL:0008019',
#  'CGAACGCCCAGTGCCG': 'CL:0008019',
#  'CGAAGCTATAAATTCA': 'CL:0008019',
#  'CGAATGACGCATAATG': 'CL:0008019',
#  'CGACACCGCTTAAGGA': 'CL:0008019',
#  'CGACTCAGGATGTTAT': 'CL:0000138',
#  'CGACTCGGTACACGGT': 'CL:0008019',
#  'CGAGACTACTGCTGCT': 'CL:0000646',
#  'CGAGAGATGTGAACCT': 'CL:0000138',
#  'CGAGAGCTTTCACTAC': 'CL:0000138',
#  'CGAGAGGGTAGCCGCG': 'CL:0008019',
#  'CGAGCTGGGCTTTAGG': 'CL:0000138',
#  'CGAGGAGCTTCCATAT': 'CL:0002551',
#  'CGAGGCTAAATATGGC': 'CL:0000138',
#  'CGAGGGTATCCAGGTG': 'CL:0000138',
#  'CGAGTTCTGTCCCACC': 'CL:0008019',
#  'CGATAGTCGTACTGCA': 'CL:0008019',
#  'CGATCATTAGAGGCAC': 'CL:0008019',
#  'CGATCCACCATTGTTG': 'CL:0000515',
#  'CGATCCTCGCAACATA': 'CL:0008019',
#  'CGATGGACCCTACGCC': 'CL:0008019',
#  'CGATTAAATATCTCCT': 'CL:0002551',
#  'CGATTCGCCTGGCTGC': 'CL:0000138',
#  'CGCACGTCTGTTTATG': 'CL:0008019',
#  'CGCAGATCTTCACCCG': 'CL:0002551',
#  'CGCATGCCGAATGCGT': 'CL:0008019',
#  'CGCATTAGCTAATAGG': 'CL:0008019',
#  'CGCCATCCGATTATGA': 'CL:0000138',
#  'CGCCCAGCACGCCTAG': 'CL:0002551',
#  'CGCCCAGCGTTTCACG': 'CL:0000138',
#  'CGCCCGCTTCCGTACA': 'CL:0008019',
#  'CGCCGCGTTCTGAACG': 'CL:0008019',
#  'CGCCGTTCAGCATAGT': 'CL:0000138',
#  'CGCGAAGTGGCATACT': 'CL:0008019',
#  'CGCGACCGCGACAGAT': 'CL:0000138',
#  'CGCGAGAGGGACTTGT': 'CL:0000515',
#  'CGCGCCCGACTTAATA': 'CL:0000138',
#  'CGCGGGAATTAGGCAG': 'CL:0000138',
#  'CGCGGTCACAAACCAA': 'CL:0000187',
#  'CGCTGTGTGGATGTTG': 'CL:0002551',
#  'CGCTTAGTATTGATAC': 'CL:0000187',
#  'CGCTTCGGTCTAAGAC': 'CL:0008019',
#  'CGGAAAGAATCAAACG': 'CL:0002551',
#  'CGGACCTCTGTAGTTA': 'CL:0008019',
#  'CGGATCCTCAAGGACT': 'CL:0000138',
#  'CGGCCAGAGCGACCAT': 'CL:0008019',
#  'CGGCGCCATCAATCCC': 'CL:0000138',
#  'CGGGATCAATGTAAGA': 'CL:0008019',
#  'CGGTAGAGGTGCAGGT': 'CL:0000138',
#  'CGGTATAGGTATTAGC': 'CL:0002551',
#  'CGGTCAAGTGGGAACC': 'CL:0000138',
#  'CGGTCCATGAGACTCC': 'CL:0002551',
#  'CGGTCCGTCGCAAGCC': 'CL:0000187',
#  'CGGTCTATCAACCCGT': 'CL:0008019',
#  'CGGTGGGCTCCAGCCT': 'CL:0002551',
#  'CGGTTCAAGTAGGTGT': 'CL:0008019',
#  'CGGTTGAGTATCCTTC': 'CL:0002551',
#  'CGGTTTATGAAGGAAC': 'CL:0002551',
#  'CGTAAATAACAAAGGG': 'CL:0008019',
#  'CGTAACTTCGACACTT': 'CL:0008019',
#  'CGTACCTGATAGGCCT': 'CL:0000138',
#  'CGTAGAGAGTAATTAT': 'CL:0008019',
#  'CGTCAAATGGTCGCAG': 'CL:0002551',
#  'CGTCGCATGTGAGCCA': 'CL:0008019',
#  'CGTCGTCCTTCGCGAA': 'CL:0008019',
#  'CGTCTGGAAGGGCCCG': 'CL:0008019',
#  'CGTGACATTGGGTCGT': 'CL:0000138',
#  'CGTGACCAGTCCTCTG': 'CL:0000187',
#  'CGTGGTACCCAAAGGC': 'CL:0008019',
#  'CGTGTCTCGTTACGAC': 'CL:0002551',
#  'CGTTAATGTCCCGACG': 'CL:0000138',
#  'CGTTAGCTCACAACTG': 'CL:0008019',
#  'CGTTCAAGGAAACGGA': 'CL:0008019',
#  'CGTTCAGACCCGCGAA': 'CL:0008019',
#  'CGTTCTTCGCACACCT': 'CL:0000187',
#  'CGTTGAATACCGCGCT': 'CL:0000138',
#  'CGTTGAGTAATTGCGT': 'CL:0002551',
#  'CGTTGCCCGCGTGGGA': 'CL:0000187',
#  'CGTTGTAAGATTGATT': 'CL:0002551',
#  'CGTTGTCGGCAATTGA': 'CL:0008019',
#  'CGTTTAAGCGGAGCAC': 'CL:0008019',
#  'CGTTTACAAGGCAGCT': 'CL:0002551',
#  'CGTTTCACTTCGGGCG': 'CL:0008019',
#  'CTAAATCCGGTGTACA': 'CL:0002551',
#  'CTAAATCCTATTCCGG': 'CL:0008019',
#  'CTAACTGATAATCGCC': 'CL:0008019',
#  'CTAATTATGAAGCGTA': 'CL:0008019',
#  'CTAATTCTCAGATATT': 'CL:0002551',
#  'CTACACTCGCAGATGG': 'CL:0008019',
#  'CTACTCAAGGTATAGT': 'CL:0002551',
#  'CTACTGCCACCTGACC': 'CL:0008019',
#  'CTAGACATATATGTAG': 'CL:0002551',
#  'CTAGCCGATGTTATGA': 'CL:0008019',
#  'CTAGGCGCCCTATCAG': 'CL:0008019',
#  'CTAGGGATAGGGACAA': 'CL:0008019',
#  'CTAGGTTCGGACGTGA': 'CL:0000138',
#  'CTAGTAGAAAGGGATT': 'CL:0000138',
#  'CTAGTATTCGGAATTA': 'CL:0000138',
#  'CTAGTTGGGCCCGGTA': 'CL:0008019',
#  'CTATAAGAGCCAATCG': 'CL:0008019',
#  'CTATAGGCGTTGATGT': 'CL:0002355',
#  'CTATATCCAGCCTGGC': 'CL:0000138',
#  'CTATCGACGAAATACA': 'CL:0008019',
#  'CTATGCCCGAATGCAA': 'CL:0000138',
#  'CTATGGGAAGCGGAAT': 'CL:0008019',
#  'CTATGTCACTAGCCCA': 'CL:0008019',
#  'CTATTGTGTTTGGTCA': 'CL:0002551',
#  'CTATTTGCTTGGAGGA': 'CL:0002551',
#  'CTCAAACCACTGCCCG': 'CL:0002551',
#  'CTCAACTAACCCGGAT': 'CL:0000138',
#  'CTCAAGACATTAGCGC': 'CL:0002551',
#  'CTCACACGCAAGCCTA': 'CL:0002551',
#  'CTCACATTTACTAAAT': 'CL:0008019',
#  'CTCACCGATCCAAACT': 'CL:0008019',
#  'CTCACTGTGATACTTA': 'CL:0000138',
#  'CTCAGAGCTAATGTCG': 'CL:0002551',
#  'CTCAGTCACGACAAAT': 'CL:0000138',
#  'CTCATGGCTCACAATC': 'CL:0008019',
#  'CTCATTGCTCTAACAA': 'CL:0000138',
#  'CTCATTTGATGGGCGG': 'CL:0008019',
#  'CTCCGGCCTAATATGC': 'CL:0008019',
#  'CTCCTCCAGCTCACAC': 'CL:0000187',
#  'CTCCTTTACGCAAGTC': 'CL:0008019',
#  'CTCGAGGCAAGTTTCA': 'CL:0008019',
#  'CTCGAGGTCGAACAGT': 'CL:0008019',
#  'CTCGATATTTGCGAGC': 'CL:0008019',
#  'CTCGCACCTATATAGT': 'CL:0000138',
#  'CTCGCCGAATGTAGGG': 'CL:0008019',
#  'CTCGCTAGGTAAGCGA': 'CL:0000646',
#  'CTCGTTACGGCTACCA': 'CL:0000138',
#  'CTCGTTTCTAATGTTT': 'CL:0008019',
#  'CTCTAATGCATTGATC': 'CL:0002551',
#  'CTCTAGCCCTCGGAAA': 'CL:0000138',
#  'CTCTCACAATCGATGA': 'CL:0008019',
#  'CTCTGTTTGAGGATTC': 'CL:0008019',
#  'CTCTTCTGGAAGTTAG': 'CL:0002551',
#  'CTCTTGTCCCGCTTGG': 'CL:0002551',
#  'CTGAAAGAGATCCGAC': 'CL:0000138',
#  'CTGAATTTATTGCCAG': 'CL:0008019',
#  'CTGATCCCTTTATGCA': 'CL:0000138',
#  'CTGCAGAGAATCAGAG': 'CL:0008019',
#  'CTGCCAAGGTTGGAAG': 'CL:0000138',
#  'CTGCCTTTCTAGTAAA': 'CL:0000138',
#  'CTGCGATTTCGAGATT': 'CL:0002551',
#  'CTGCGTTACGATATAA': 'CL:0008019',
#  'CTGCTTTATGTCCGCG': 'CL:0000187',
#  'CTGGCGACATAAGTCC': 'CL:0008019',
#  'CTGGTAAAGACTTACA': 'CL:0008019',
#  'CTGTAGTGAGGATCGA': 'CL:0008019',
#  'CTGTCAAATGGCTCGG': 'CL:0008019',
#  'CTGTGGTCGGGAGATA': 'CL:0000138',
#  'CTGTTCACTGCCTGTG': 'CL:0000646',
#  'CTTAACTTCGAAGTAC': 'CL:0008019',
#  'CTTAGCCTTCCACATG': 'CL:0000138',
#  'CTTAGTGTAGTAGCAT': 'CL:0000138',
#  'CTTAGTTGAGGAATCG': 'CL:0008019',
#  'CTTCAACTCCACTTGG': 'CL:0008019',
#  'CTTCCGCTCCGTGAAG': 'CL:0002551',
#  'CTTCGATTGCGCAAGC': 'CL:0008019',
#  'CTTCTGGGCGTACCTA': 'CL:0008019',
#  'CTTCTTACGTCGTATA': 'CL:0008019',
#  'CTTGATGACCATCCAG': 'CL:0008019',
#  'CTTGCCCACCCACGCA': 'CL:0008019',
#  'CTTGGCCAAGCTGGGA': 'CL:0008019',
#  'CTTGTGCTCACCGATT': 'CL:0008019',
#  'CTTTAACTTTCAAAGG': 'CL:0000138',
#  'CTTTGCATCGCTCTTG': 'CL:0000138',
#  'CTTTGGGATTGTTGCA': 'CL:0002551',
#  'GAAACAGCCATGCAGT': 'CL:0008019',
#  'GAAACCATGGTGCGCT': 'CL:0002551',
#  'GAAACCTATACAAATG': 'CL:0000187',
#  'GAAAGCAGTGCACTTT': 'CL:0002551',
#  'GAAATATGCTTGAATG': 'CL:0008019',
#  'GAAATCGCGCGCAACT': 'CL:0000138',
#  'GAAATTAGCACGGATA': 'CL:0002573',
#  'GAACAACTGGGATGAA': 'CL:0008019',
#  'GAACAGATTACTAAAT': 'CL:0000138',
#  'GAACATTAGTATGTTA': 'CL:0000138',
#  'GAACCCTCTGTGTTCT': 'CL:0000138',
#  'GAACCTTTAACGATCC': 'CL:0008019',
#  'GAACGACCGAATGATA': 'CL:0000138',
#  'GAACTGTGGAGAGACA': 'CL:0008019',
#  'GAACTTGTGCACGGGA': 'CL:0002551',
#  'GAAGCCACTGATTATG': 'CL:0000138',
#  'GAAGCCTGCACATTCC': 'CL:0000138',
#  'GAAGGAGTCGAGTGCG': 'CL:0008019',
#  'GAAGGCTACCATTGTT': 'CL:0000646',
#  'GAAGTGCTGGATAGCT': 'CL:0008019',
#  'GAATAGCCCTGCGGTC': 'CL:0000187',
#  'GAATAGTGCTCGATTA': 'CL:0002551',
#  'GAATGAAGGTCTTCAG': 'CL:0000187',
#  'GAATGCGAATCGGTTC': 'CL:0008019',
#  'GAATGTATGGCAGGTC': 'CL:0002551',
#  'GAATGTTGGGTAATCT': 'CL:0000138',
#  'GACAACGACCATTGAA': 'CL:0000138',
#  'GACACAAGGGAAGAAA': 'CL:0008019',
#  'GACACCCAAAGACGCG': 'CL:0008019',
#  'GACACTTCCAATTACC': 'CL:0008019',
#  'GACATCCGTCGAACTG': 'CL:0008019',
#  'GACCAAACGTTGACTG': 'CL:0008019',
#  'GACCTTCCACGTCTAC': 'CL:0008019',
#  'GACGAGGCTAATAAAC': 'CL:0008019',
#  'GACGATATCACTGGGT': 'CL:0000138',
#  'GACGGGTTGGCCCGTA': 'CL:0000187',
#  'GACGTTCGTAAATACA': 'CL:0002551',
#  'GACGTTGCTCGGCGGC': 'CL:0000138',
#  'GACTAGGCCGTTAGGT': 'CL:0000138',
#  'GACTCCCAGAATAAGG': 'CL:0002551',
#  'GACTCGGTCGGCGGAT': 'CL:0002551',
#  'GACTCTAGAGTTCCAA': 'CL:0000187',
#  'GACTGATTGGTCACAA': 'CL:0002551',
#  'GACTGCAAATCGAGCT': 'CL:0000138',
#  'GACTGCTGGTGAGAAA': 'CL:0008019',
#  'GAGAACGGTTCTGACT': 'CL:0000138',
#  'GAGACCCTGCAACGCC': 'CL:0008019',
#  'GAGACTGATGGGTAGA': 'CL:0008019',
#  'GAGAGTCTCGGGAGAG': 'CL:0000138',
#  'GAGATCTGTCACTCCG': 'CL:0008019',
#  'GAGCACCTGTGTCCAG': 'CL:0008019',
#  'GAGCATCAACAACTTG': 'CL:0002551',
#  'GAGCCAGCTACCTGTG': 'CL:0008019',
#  'GAGCCGAGCGTTTATT': 'CL:0000187',
#  'GAGCGGAATGCGGTGT': 'CL:0000515',
#  'GAGCTAAGGGCATATC': 'CL:0008019',
#  'GAGCTGTCGTCTCGGA': 'CL:0000187',
#  'GAGGAATATCTCTTTG': 'CL:0008019',
#  'GAGGCATTTGCAGCAG': 'CL:0002551',
#  'GAGGCCTGTTGATACA': 'CL:0008019',
#  'GAGGGAGTCAGATCGC': 'CL:0002551',
#  'GAGGGCCATAATATTA': 'CL:0002551',
#  'GAGGGCGCAGCTCTGC': 'CL:0000138',
#  'GAGGGTAGTAACAAAG': 'CL:0002551',
#  'GAGGTACGCGTGTCCC': 'CL:0008019',
#  'GAGTAGATACTAGTTG': 'CL:0008019',
#  'GAGTATGCGCGTGCAT': 'CL:0008019',
#  'GAGTCAGACCAGAATC': 'CL:0000646',
#  'GAGTGCACGGACAACA': 'CL:0002551',
#  'GAGTGTCAACCAGAAA': 'CL:0000138',
#  'GATAGAACCCGCTAGG': 'CL:0000187',
#  'GATAGTGCGAGTAAGT': 'CL:0008019',
#  'GATATGCGGTAGCCAA': 'CL:0000138',
#  'GATATTTCCTACATGG': 'CL:0000138',
#  'GATCAACATAAAGGGA': 'CL:0002551',
#  'GATCATTCCAAACATT': 'CL:0000646',
#  'GATCCCTTTATACTGC': 'CL:0008019',
#  'GATCCTAAATCGGGAC': 'CL:0002551',
#  'GATCGGTGGCCATAAC': 'CL:0008019',
#  'GATCTGCTATCTAAGG': 'CL:0008019',
#  'GATCTTTGCTCAAAGA': 'CL:0008019',
#  'GATGACGATGATCGCG': 'CL:0000187',
#  'GATGAGGAACCTTCGG': 'CL:0008019',
#  'GATGCTACCTTCGATG': 'CL:0000187',
#  'GATGGTGAAATAACCC': 'CL:0002551',
#  'GATTAACCGAAAGCCC': 'CL:0000138',
#  'GATTAGAAACAAGCGT': 'CL:0008019',
#  'GATTCCCTTGTCGCAG': 'CL:0008019',
#  'GATTCCGCGTTTCCGT': 'CL:0008019',
#  'GATTCTGTTAATGAGT': 'CL:0002551',
#  'GATTGGGAAAGGTTGT': 'CL:0000138',
#  'GATTTAGTGCGTACTG': 'CL:0008019',
#  'GATTTGCGCTAACACC': 'CL:0008019',
#  'GCAAACCTTGGCCATA': 'CL:0002551',
#  'GCAACCACCAGACCGG': 'CL:0002551',
#  'GCAAGATGTGTTCGCG': 'CL:0002551',
#  'GCAAGTGTAAAGCATG': 'CL:0000187',
#  'GCACACACTGGTAGCC': 'CL:0000138',
#  'GCACAGCACGGGCCGA': 'CL:0000138',
#  'GCACGTGGTTTACTTA': 'CL:0008019',
#  'GCACTGCCTACCTTTA': 'CL:0000187',
#  'GCAGAAACGTAATCCA': 'CL:0008019',
#  'GCAGCTATGGACAGGT': 'CL:0000187',
#  'GCAGGTAGAGTATGGT': 'CL:0008019',
#  'GCAGTGTGGCTATAGG': 'CL:0000138',
#  'GCATGCTAATAACGAT': 'CL:0008019',
#  'GCATTCAAGGCAACGC': 'CL:0002551',
#  'GCCAACCATTTCCGGA': 'CL:0002551',
#  'GCCAATAGGGCATCTC': 'CL:0008019',
#  'GCCACTCAGAGCGCGA': 'CL:0000138',
#  'GCCAGGAAAGAACACT': 'CL:0000138',
#  'GCCAGGAGTAACCGAT': 'CL:0000138',
#  'GCCATATTGCACACAG': 'CL:0000138',
#  'GCCCGTAATACCTTCT': 'CL:0000138',
#  'GCCCTGAGGATGGGCT': 'CL:0002551',
#  'GCCGACCCACGACTGC': 'CL:0002551',
#  'GCCGGTCGTATCTCTC': 'CL:0000515',
#  'GCCGTCGGTTTCGGGC': 'CL:0000138',
#  'GCCTACGTTCTGTGCA': 'CL:0008019',
#  'GCCTATGCTGGGCCTT': 'CL:0000187',
#  'GCCTCCGACAATTCAC': 'CL:0000138',
#  'GCCTCTATACATAGCA': 'CL:0008019',
#  'GCCTGCTACACTGAGA': 'CL:0002551',
#  'GCCTGTCCCGGTGCAT': 'CL:0002551',
#  'GCGAAACGATCGGGAG': 'CL:0008019',
#  'GCGAAGAATCTGACGG': 'CL:0000138',
#  'GCGAAGCCATACCCGT': 'CL:0000646',
#  'GCGAGAGGCCATGTAA': 'CL:0000187',
#  'GCGCGGTCTAGTAACT': 'CL:0000187',
#  'GCGCGTCATTGGTACA': 'CL:0000138',
#  'GCGCTGATCCAGACTC': 'CL:0008019',
#  'GCGCTGGCGGAAAGTC': 'CL:0000138',
#  'GCGCTTAAATAATTGG': 'CL:0000138',
#  'GCGGGCGAGCCTTACC': 'CL:0000646',
#  'GCGGTCCCGGTGAAGG': 'CL:0008019',
#  'GCGGTGAACTGCGCTC': 'CL:0008019',
#  'GCGTCCCTAAGACATA': 'CL:0002551',
#  'GCGTCGAAATGTCGGT': 'CL:0000138',
#  'GCGTTCGGAGACCGGG': 'CL:0008019',
#  'GCTAACTGAAGTCTGA': 'CL:0000138',
#  'GCTACAATCGAGGATA': 'CL:0008019',
#  'GCTAGAGTAGAGATGT': 'CL:0000138',
#  'GCTAGCAGGGAGTGGG': 'CL:0002551',
#  'GCTAGGCACCACGGAG': 'CL:0008019',
#  'GCTATACGTCTCGGAC': 'CL:0008019',
#  'GCTCAATGTAATACCG': 'CL:0008019',
#  'GCTCATTGATCATATC': 'CL:0008019',
#  'GCTCCATGCAAAGCAA': 'CL:0000187',
#  'GCTCGGAATTTAAAGC': 'CL:0000138',
#  'GCTCTAAACCCTGACG': 'CL:0008019',
#  'GCTCTCGGGTACCGAA': 'CL:0008019',
#  'GCTCTTTCCGCTAGTG': 'CL:0000187',
#  'GCTGCGAAGAATTATT': 'CL:0002551',
#  'GCTGCTAAGTAGTCGA': 'CL:0002551',
#  'GCTGGACCCAAAGTGG': 'CL:0000187',
#  'GCTGGGAGCGCGTCAA': 'CL:0008019',
#  'GCTGGTGACTCGTAGT': 'CL:0008019',
#  'GCTTAGGGAAGCGGTA': 'CL:0008019',
#  'GCTTCAGTGGGATTAC': 'CL:0008019',
#  'GCTTCCGTCCCTAGAC': 'CL:0008019',
#  'GCTTGCAGCACAATTG': 'CL:0002551',
#  'GGAAACCTTGTTGAAT': 'CL:0000187',
#  'GGAAACTAAATGGGCC': 'CL:0008019',
#  'GGAAAGTCTTGATTGT': 'CL:0008019',
#  'GGAAAGTGCCCATGCC': 'CL:0008019',
#  'GGAACTCGTGAATACG': 'CL:0008019',
#  'GGAACTTTGGCGATTA': 'CL:0008019',
#  'GGAATGCGCTAGCGTG': 'CL:0008019',
#  'GGACAACCATGAAGCC': 'CL:0008019',
#  'GGACCTACGGTAACGT': 'CL:0000187',
#  'GGACGTCCATAGTTGG': 'CL:0000138',
#  'GGACTCGACAGCGCAT': 'CL:0000515',
#  'GGACTCGTGAGTGGTC': 'CL:0002551',
#  'GGAGACCAATGTGCTT': 'CL:0002551',
#  'GGAGCAACATTTCAAG': 'CL:0008019',
#  'GGAGCACCAAGAACTA': 'CL:0008019',
#  'GGAGCGAGGCCTACTT': 'CL:0000187',
#  'GGAGGGCTTGGTTGGC': 'CL:0008019',
#  'GGATCATCCCGTACGC': 'CL:0008019',
#  'GGATCTTACTGCCCTT': 'CL:0008019',
#  'GGATGGCTTGAAGTAT': 'CL:0008019',
#  'GGATTCCGCTATACCC': 'CL:0000138',
#  'GGATTGCTGTGACTCC': 'CL:0000138',
#  'GGATTTCACTTCTATA': 'CL:0008019',
#  'GGCAAGCCAGGGATAG': 'CL:0002551',
#  'GGCAAGCCCATAGTGG': 'CL:0000187',
#  'GGCAATAGTCAATGAG': 'CL:0008019',
#  'GGCAGCGGTAATCCTA': 'CL:0002551',
#  'GGCATATCGGTTCTGC': 'CL:0000138',
#  'GGCATTGAACATCTCA': 'CL:0002551',
#  'GGCCCAATCTAGAGGG': 'CL:0000138',
#  'GGCCCAGTTATCAGCA': 'CL:0008019',
#  'GGCCGAGACTCTGGTG': 'CL:0002355',
#  'GGCCGGCGTCTGCTAT': 'CL:0000138',
#  'GGCCGTTTGGGTTTCA': 'CL:0002551',
#  'GGCCTGCTCTGATGTT': 'CL:0002551',
#  'GGCGAACCGTTCTGAT': 'CL:0002551',
#  'GGCGCGGAGATCTTTC': 'CL:0000138',
#  'GGCGCTTCATTCCCTG': 'CL:0000187',
#  'GGCGGTAGGATCATTG': 'CL:0008019',
#  'GGCGTAGGGAAAGCTG': 'CL:0000138',
#  'GGCTAAAGGGCGGGTC': 'CL:0008019',
#  'GGCTAATGATTGAAAT': 'CL:0000187',
#  'GGCTACTATACACTCC': 'CL:0002551',
#  'GGCTCCTCCACCTGTT': 'CL:0002551',
#  'GGCTCTGCTCCAACGC': 'CL:0000138',
#  'GGCTGTCCTACTGCGG': 'CL:0000138',
#  'GGCTTTCAATAAGGGT': 'CL:0008019',
#  'GGGAACGGTTTCAGAT': 'CL:0008019',
#  'GGGAAGACGGTCTGTC': 'CL:0008019',
#  'GGGAAGGGCTTTCTCA': 'CL:0000138',
#  'GGGAATGAGCCCTCAC': 'CL:0000187',
#  'GGGACCCGTATATCTT': 'CL:0002551',
#  'GGGAGCGACCGTAGTG': 'CL:0008019',
#  'GGGATCCCAATACAAA': 'CL:0002551',
#  'GGGCACGTAGTACTGT': 'CL:0000515',
#  'GGGCAGAGCAATCGTT': 'CL:0008019',
#  'GGGCATGCATGTCGAG': 'CL:0008019',
#  'GGGCCTATTTAAGTAT': 'CL:0008019',
#  'GGGCGATATGTGTGAA': 'CL:0008019',
#  'GGGCGTCCACTGGCTC': 'CL:0000138',
#  'GGGCGTGGTTTCCCAG': 'CL:0000138',
#  'GGGCTATGATCGATGG': 'CL:0002551',
#  'GGGCTCATCGAACCCA': 'CL:0000138',
#  'GGGCTGCCTAGGGCGA': 'CL:0000646',
#  'GGGTCAGGAGCTAGAT': 'CL:0000187',
#  'GGGTCGTGGCAAGTGT': 'CL:0002551',
#  'GGGTGTTTCAGCTATG': 'CL:0008019',
#  'GGTACCATTAAGACGG': 'CL:0000646',
#  'GGTAGGCCAATATCAC': 'CL:0008019',
#  'GGTCATTGTAGTCATA': 'CL:0008019',
#  'GGTCGGATAAACGGCG': 'CL:0008019',
#  'GGTCGGCCAGGAGCTT': 'CL:0002551',
#  'GGTCGGTCGTCCACAG': 'CL:0002551',
#  'GGTCTCCGTCCAGGTT': 'CL:0000138',
#  'GGTCTGAGAATCTGGA': 'CL:0008019',
#  'GGTCTTGAGCGCTCTT': 'CL:0008019',
#  'GGTGCAGAGCCTATCG': 'CL:0002551',
#  'GGTGCATAAATGATTA': 'CL:0000515',
#  'GGTGGACTGCTCTGGC': 'CL:0008019',
#  'GGTGTAAATCGATTGT': 'CL:0002551',
#  'GGTGTAGGTAAGTAAA': 'CL:0000515',
#  'GGTTACCGCTCCCTAC': 'CL:0000138',
#  'GGTTCCGTACGACTAA': 'CL:0000138',
#  'GGTTTAATTACCATCG': 'CL:0002551',
#  'GGTTTACAATCTCAAT': 'CL:0000138',
#  'GGTTTGACAAGAAGCT': 'CL:0000187',
#  'GGTTTGCGAACACGTA': 'CL:0008019',
#  'GGTTTGTGACCTGAGG': 'CL:0008019',
#  'GTAACAACTGACCTTG': 'CL:0008019',
#  'GTAACAGGTTAACGGC': 'CL:0002551',
#  'GTAACATCTAAGATAA': 'CL:0008019',
#  'GTAACTGCCCAAGGAG': 'CL:0000187',
#  'GTAAGCGGGCAGTCAG': 'CL:0008019',
#  'GTACGAGATTGCGACA': 'CL:0008019',
#  'GTACGTCACGTATTAA': 'CL:0000515',
#  'GTACTAAGATTTGGAG': 'CL:0008019',
#  'GTACTCCTGGGTATGC': 'CL:0008019',
#  'GTACTGGAGTTAGACC': 'CL:0008019',
#  'GTAGACACGCCTGACT': 'CL:0008019',
#  'GTAGCTCCGGGAGGCT': 'CL:0008019',
#  'GTAGGTGATCCGTGTA': 'CL:0008019',
#  'GTAGTCTACGATATTG': 'CL:0008019',
#  'GTAGTTCGAAGGCGAA': 'CL:0002551',
#  'GTATAGGACTCAGTAG': 'CL:0008019',
#  'GTATCAAACGTTAGCT': 'CL:0008019',
#  'GTATCCTTTGGTAACC': 'CL:0000138',
#  'GTATTAGGGTTCGCGT': 'CL:0008019',
#  'GTCAACCAGGCCTATA': 'CL:0008019',
#  'GTCAATGCTATAATTT': 'CL:0002551',
#  'GTCATGCACCTCCGTT': 'CL:0008019',
#  'GTCATGCGCGAGGGCT': 'CL:0008019',
#  'GTCATGGACATGACTA': 'CL:0008019',
#  'GTCCAATATTTAGCCT': 'CL:0000187',
#  'GTCCAGGCACGTGTGC': 'CL:0008019',
#  'GTCCCGCGACGTTATG': 'CL:0000138',
#  'GTCCGGACCTGAAATT': 'CL:0008019',
#  'GTCCGGGTTCACATTA': 'CL:0002551',
#  'GTCCTACGAATAGTCT': 'CL:0008019',
#  'GTCCTTTAATGACTTC': 'CL:0002551',
#  'GTCGGAAGGATACCAG': 'CL:0000187',
#  'GTCGGATGTAGCGCGC': 'CL:0008019',
#  'GTCGGGAAGCAGAAAC': 'CL:0000138',
#  'GTCGTATTGGCGTACA': 'CL:0000138',
#  'GTCGTGTCTGGTCATC': 'CL:0000646',
#  'GTCTAGTGAGCCGCTT': 'CL:0000138',
#  'GTCTATACACGCATGG': 'CL:0008019',
#  'GTCTATTGCATGCTCG': 'CL:0008019',
#  'GTCTCAAGGCCCGGCT': 'CL:0000138',
#  'GTCTCCGCCTCAATAC': 'CL:0002551',
#  'GTCTCGACTAAGTTTG': 'CL:0002551',
#  'GTCTCGATCTGCTTTC': 'CL:0000138',
#  'GTCTGTAGGTTGAACA': 'CL:0008019',
#  'GTGAAACGGCGCCACC': 'CL:0000138',
#  'GTGAAGATTTCAAGTG': 'CL:0000138',
#  'GTGAAGCCGTATAGTC': 'CL:0000515',
#  'GTGACAGCTTCCCACT': 'CL:0008019',
#  'GTGACGCAGGTTTCAT': 'CL:0008019',
#  'GTGAGATAACCTTATA': 'CL:0008019',
#  'GTGATCCTTGTCATGA': 'CL:0000138',
#  'GTGCAACAAATGTGGC': 'CL:0008019',
#  'GTGCACCAGCTTCAAC': 'CL:0000187',
#  'GTGCACGAAAGTGACT': 'CL:0008019',
#  'GTGCCTGAGACCAAAC': 'CL:0008019',
#  'GTGCGGGTCTCCAAAT': 'CL:0000646',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16                8
# AAACAAGTATCTCCCA-1          0         50        102             1286
# AAACAATCTACTAGCA-1          0          3         43               43
# AAACACCAATAACTGC-1          0         59         19               24
# AAACAGAGCGACTCCT-1          1         14         94             3714
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42             2901
# TTGTTTCATTAGTCTA-1          0         60         30              356
# TTGTTTCCATACAACT-1          0         45         27              128
# TTGTTTGTATTACACG-1          1         73         41             2232
# TTGTTTGTGTAAATTC-1          0          7         51              597
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                        NaN
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                        NaN
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                        NaN
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                        NaN
# TTGTTTGTATTACACG-1                 CL:0000138
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 3611

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_31959/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16                8
# AAACAAGTATCTCCCA-1          0         50        102             1286
# AAACAATCTACTAGCA-1          0          3         43               43
# AAACACCAATAACTGC-1          0         59         19               24
# AAACAGAGCGACTCCT-1          1         14         94             3714
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42             2901
# TTGTTTCATTAGTCTA-1          0         60         30              356
# TTGTTTCCATACAACT-1          0         45         27              128
# TTGTTTGTATTACACG-1          1         73         41             2232
# TTGTTTGTGTAAATTC-1          0          7         51              597
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                    unknown
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                    unknown
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                    unknown
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                    unknown
# TTGTTTGTATTACACG-1                 CL:0000138
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0002551',
#  'CL:0008019',
#  'CL:0000138',
#  'CL:0000187',
#  'CL:0000515',
#  'CL:0000388',
#  'CL:0000646',
#  'CL:0000058',
#  'CL:0002355',
#  'CL:0002573']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000024']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000024
# AAACAAGTATCTCCCA-1    HsapDv:0000024
# AAACAATCTACTAGCA-1    HsapDv:0000024
# AAACACCAATAACTGC-1    HsapDv:0000024
# AAACAGAGCGACTCCT-1    HsapDv:0000024
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000024
# TTGTTTCATTAGTCTA-1    HsapDv:0000024
# TTGTTTCCATACAACT-1    HsapDv:0000024
# TTGTTTGTATTACACG-1    HsapDv:0000024
# TTGTTTGTGTAAATTC-1    HsapDv:0000024
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000024']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16                8
# AAACAAGTATCTCCCA-1          0         50        102             1286
# AAACAATCTACTAGCA-1          0          3         43               43
# AAACACCAATAACTGC-1          0         59         19               24
# AAACAGAGCGACTCCT-1          1         14         94             3714
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42             2901
# TTGTTTCATTAGTCTA-1          0         60         30              356
# TTGTTTCCATACAACT-1          0         45         27              128
# TTGTTTGTATTACACG-1          1         73         41             2232
# TTGTTTGTGTAAATTC-1          0          7         51              597
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699525
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9699525
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699525
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699525
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9699525
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                    unknown  WSSS_THYst9699525
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9699525
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699525
# TTGTTTGTATTACACG-1                 CL:0000138  WSSS_THYst9699525
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699525
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000024
# AAACAAGTATCTCCCA-1                     HsapDv:0000024
# AAACAATCTACTAGCA-1                     HsapDv:0000024
# AAACACCAATAACTGC-1                     HsapDv:0000024
# AAACAGAGCGACTCCT-1                     HsapDv:0000024
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000024
# TTGTTTCATTAGTCTA-1                     HsapDv:0000024
# TTGTTTCCATACAACT-1                     HsapDv:0000024
# TTGTTTGTATTACACG-1                     HsapDv:0000024
# TTGTTTGTGTAAATTC-1                     HsapDv:0000024
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699525': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         ...,
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]]], dtype=uint8),
#                  'lowres': array([[[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         ...,
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.60387877999607,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 168.97549649076288,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9699525.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)
adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16                8
# AAACAAGTATCTCCCA-1          0         50        102             1286
# AAACAATCTACTAGCA-1          0          3         43               43
# AAACACCAATAACTGC-1          0         59         19               24
# AAACAGAGCGACTCCT-1          1         14         94             3714
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          0         58         42             2901
# TTGTTTCATTAGTCTA-1          0         60         30              356
# TTGTTTCCATACAACT-1          0         45         27              128
# TTGTTTGTATTACACG-1          1         73         41             2232
# TTGTTTGTGTAAATTC-1          0          7         51              597
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699525
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9699525
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699525
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699525
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9699525
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                    unknown  WSSS_THYst9699525
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9699525
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699525
# TTGTTTGTATTACACG-1                 CL:0000138  WSSS_THYst9699525
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699525
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000024
# AAACAAGTATCTCCCA-1                     HsapDv:0000024
# AAACAATCTACTAGCA-1                     HsapDv:0000024
# AAACACCAATAACTGC-1                     HsapDv:0000024
# AAACAGAGCGACTCCT-1                     HsapDv:0000024
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000024
# TTGTTTCATTAGTCTA-1                     HsapDv:0000024
# TTGTTTCCATACAACT-1                     HsapDv:0000024
# TTGTTTGTATTACACG-1                     HsapDv:0000024
# TTGTTTGTGTAAATTC-1                     HsapDv:0000024
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699525': {'images': {'hires': array([[[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         ...,
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]]], dtype=uint8),
#                  'fullres': array([[[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         ...,
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]],
#
#                         [[237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          ...,
#                          [237, 235, 239],
#                          [237, 235, 239],
#                          [237, 235, 239]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 104.60387877999607,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9699525'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide7.h5ad', compression = 'gzip')

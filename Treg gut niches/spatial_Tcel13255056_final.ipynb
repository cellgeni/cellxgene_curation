# %% [markdown]
# ### **Curating Tcel13255056**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255056_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# []

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 13590294 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 231)	1.0
#   (0, 716)	1.0
#   (0, 1754)	1.0
#   (0, 2196)	1.0
#   (0, 3298)	2.0
#   (0, 3422)	1.0
#   (0, 3655)	1.0
#   (0, 4092)	1.0
#   (0, 4272)	2.0
#   (0, 4815)	1.0
#   (0, 4875)	1.0
#   (0, 5104)	1.0
#   (0, 5288)	1.0
#   (0, 5753)	4.0
#   (0, 5762)	1.0
#   (0, 6023)	1.0
#   (0, 6060)	1.0
#   (0, 6096)	1.0
#   (0, 6465)	1.0
#   (0, 6575)	1.0
#   (0, 6788)	1.0
#   (0, 7365)	1.0
#   (0, 7382)	1.0
#   (0, 7676)	1.0
#   (0, 7820)	1.0
#   :	:
#   (4991, 25795)	1.0
#   (4991, 25967)	1.0
#   (4991, 26092)	1.0
#   (4991, 26203)	1.0
#   (4991, 26577)	1.0
#   (4991, 26936)	1.0
#   (4991, 27047)	1.0
#   (4991, 27172)	1.0
#   (4991, 27744)	1.0
#   (4991, 28217)	1.0
#   (4991, 28540)	1.0
#   (4991, 28745)	1.0
#   (4991, 29088)	1.0
#   (4991, 29116)	1.0
#   (4991, 29299)	1.0
#   (4991, 29455)	1.0
#   (4991, 29675)	1.0
#   (4991, 29721)	1.0
#   (4991, 29902)	1.0
#   (4991, 30266)	1.0
#   (4991, 30616)	1.0
#   (4991, 31025)	1.0
#   (4991, 31246)	1.0
#   (4991, 32200)	1.0
#   (4991, 32202)	1.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              127
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             2035
# AAACAATCTACTAGCA-1        1.0        3.0        3.0              247
# AAACACCAATAACTGC-1        1.0       59.0       59.0             2624
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3390
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              192
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             2537
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              946
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0              151
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13255056_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATTTCCCGGATT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACCCGAACGAAATC-1        1.0  2B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTCCATACAACT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTGTATTACACG-1        1.0  2B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1               3723
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1               4547
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1               3890
# Mus_Tcel13255056_AAACATTTCCCGGATT-1               6181
# Mus_Tcel13255056_AAACCCGAACGAAATC-1               9764
# ...                                                ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1               4466
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                581
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                500
# Mus_Tcel13255056_TTGTTTCCATACAACT-1               2537
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                946
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                 8.222553        9548.0
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                 8.422442       13999.0
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                 8.266421       12371.0
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                 8.729397       25231.0
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                 9.186560       72639.0
# ...                                                      ...           ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                 8.404472       12135.0
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                 6.366470         760.0
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                 6.216606         635.0
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                 7.839132        5006.0
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                 6.853299        1331.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1            9.164192
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1            9.546813
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1            9.423191
# Mus_Tcel13255056_AAACATTTCCCGGATT-1           10.135868
# Mus_Tcel13255056_AAACCCGAACGAAATC-1           11.193271
# ...                                                 ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1            9.403932
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1            6.634634
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1            6.455199
# Mus_Tcel13255056_TTGTTTCCATACAACT-1            8.518592
# Mus_Tcel13255056_TTGTTTGTATTACACG-1            7.194437
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                   19.868034
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                   22.687334
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                   24.977770
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                   20.423288
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                   18.922342
# ...                                                         ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                   17.791512
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                   23.815790
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                   25.354330
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                   19.816221
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                   21.562735
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    27.094679
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    29.816416
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    32.560020
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    28.786016
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    26.984127
# ...                                                          ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    25.463535
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    36.710526
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                    37.007874
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    27.007591
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    30.353119
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    36.866360
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    39.152798
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    41.613449
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    39.328602
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    37.057228
# ...                                                          ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    35.352287
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    49.868420
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                    52.755905
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    36.316422
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    43.951916
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    52.241306  ...
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    53.710979  ...
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    56.850700  ...
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    53.505608  ...
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    50.317322  ...
# ...                                                          ...  ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    50.004120  ...
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    89.342102  ...
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                   100.000000  ...
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    53.276070  ...
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    66.491364  ...
#
#                                              donor_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATTTCCCGGATT-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACCCGAACGAAATC-1  2B_Hh.anti_IL10r
# ...                                               ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTCCATACAACT-1  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTGTATTACACG-1  2B_Hh.anti_IL10r
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                     MmusDv:0000061
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                     MmusDv:0000061
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                     MmusDv:0000061
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                     MmusDv:0000061
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                     MmusDv:0000061
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                     MmusDv:0000061
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                     MmusDv:0000061
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1             PATO:0000461            True
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1             PATO:0000461            True
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1             PATO:0000461            True
# Mus_Tcel13255056_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13255056_AAACCCGAACGAAATC-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTTGTATTACACG-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACCCGAACGAAATC-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTTGTATTACACG-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                                       na
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                                       na
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                                       na
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                                       na
# ...                                                                      ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1              unknown               na
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1              unknown               na
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1              unknown               na
# Mus_Tcel13255056_AAACATTTCCCGGATT-1              unknown               na
# Mus_Tcel13255056_AAACCCGAACGAAATC-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1              unknown               na
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1              unknown               na
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13255056_TTGTTTCCATACAACT-1              unknown               na
# Mus_Tcel13255056_TTGTTTGTATTACACG-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
#
# [2674 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACATTTCCCGGATT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_AAACCCGAACGAAATC-1        1.0  2B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTCCATACAACT-1        1.0  2B_Hh.anti_IL10r
# Mus_Tcel13255056_TTGTTTGTATTACACG-1        1.0  2B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1               3723
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1               4547
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1               3890
# Mus_Tcel13255056_AAACATTTCCCGGATT-1               6181
# Mus_Tcel13255056_AAACCCGAACGAAATC-1               9764
# ...                                                ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1               4466
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                581
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                500
# Mus_Tcel13255056_TTGTTTCCATACAACT-1               2537
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                946
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                 8.222553        9548.0
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                 8.422442       13999.0
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                 8.266421       12371.0
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                 8.729397       25231.0
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                 9.186560       72639.0
# ...                                                      ...           ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                 8.404472       12135.0
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                 6.366470         760.0
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                 6.216606         635.0
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                 7.839132        5006.0
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                 6.853299        1331.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1            9.164192
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1            9.546813
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1            9.423191
# Mus_Tcel13255056_AAACATTTCCCGGATT-1           10.135868
# Mus_Tcel13255056_AAACCCGAACGAAATC-1           11.193271
# ...                                                 ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1            9.403932
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1            6.634634
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1            6.455199
# Mus_Tcel13255056_TTGTTTCCATACAACT-1            8.518592
# Mus_Tcel13255056_TTGTTTGTATTACACG-1            7.194437
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                   19.868034
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                   22.687334
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                   24.977770
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                   20.423288
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                   18.922342
# ...                                                         ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                   17.791512
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                   23.815790
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                   25.354330
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                   19.816221
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                   21.562735
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    27.094679
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    29.816416
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    32.560020
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    28.786016
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    26.984127
# ...                                                          ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    25.463535
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    36.710526
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                    37.007874
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    27.007591
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    30.353119
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    36.866360
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    39.152798
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    41.613449
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    39.328602
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    37.057228
# ...                                                          ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    35.352287
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    49.868420
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                    52.755905
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    36.316422
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    43.951916
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                    52.241306  ...
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                    53.710979  ...
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                    56.850700  ...
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                    53.505608  ...
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                    50.317322  ...
# ...                                                          ...  ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                    50.004120  ...
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                    89.342102  ...
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                   100.000000  ...
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                    53.276070  ...
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                    66.491364  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                      MmusDv:0000061
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                      MmusDv:0000061
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                      MmusDv:0000061
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                      MmusDv:0000061
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                      MmusDv:0000061
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                      MmusDv:0000061
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                      MmusDv:0000061
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1             PATO:0000461            True
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1             PATO:0000461            True
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1             PATO:0000461            True
# Mus_Tcel13255056_AAACATTTCCCGGATT-1             PATO:0000461            True
# Mus_Tcel13255056_AAACCCGAACGAAATC-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTTCCATACAACT-1             PATO:0000461            True
# Mus_Tcel13255056_TTGTTTGTATTACACG-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACATTTCCCGGATT-1           NCBITaxon:10090
# Mus_Tcel13255056_AAACCCGAACGAAATC-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTTCCATACAACT-1           NCBITaxon:10090
# Mus_Tcel13255056_TTGTTTGTATTACACG-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1                                       na
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1                                       na
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1                                       na
# Mus_Tcel13255056_AAACATTTCCCGGATT-1                                       na
# Mus_Tcel13255056_AAACCCGAACGAAATC-1                                       na
# ...                                                                      ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1                                       na
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255056_TTGTTTCCATACAACT-1                                       na
# Mus_Tcel13255056_TTGTTTGTATTACACG-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1              unknown              na
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1              unknown              na
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1              unknown              na
# Mus_Tcel13255056_AAACATTTCCCGGATT-1              unknown              na
# Mus_Tcel13255056_AAACCCGAACGAAATC-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1              unknown              na
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1              unknown              na
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13255056_TTGTTTCCATACAACT-1              unknown              na
# Mus_Tcel13255056_TTGTTTGTATTACACG-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACATTTCCCGGATT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_AAACCCGAACGAAATC-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTTCCATACAACT-1       tissue           UBERON:0001155
# Mus_Tcel13255056_TTGTTTGTATTACACG-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13255056_AAACAGGGTCTATATT-1  AAACAGGGTCTATATT
# Mus_Tcel13255056_AAACAGTGTTCCTGGG-1  AAACAGTGTTCCTGGG
# Mus_Tcel13255056_AAACATGGTGAGAGGA-1  AAACATGGTGAGAGGA
# Mus_Tcel13255056_AAACATTTCCCGGATT-1  AAACATTTCCCGGATT
# Mus_Tcel13255056_AAACCCGAACGAAATC-1  AAACCCGAACGAAATC
# ...                                               ...
# Mus_Tcel13255056_TTGTTCAGTGTGCTAC-1  TTGTTCAGTGTGCTAC
# Mus_Tcel13255056_TTGTTCTAGATACGCT-1  TTGTTCTAGATACGCT
# Mus_Tcel13255056_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13255056_TTGTTTCCATACAACT-1  TTGTTTCCATACAACT
# Mus_Tcel13255056_TTGTTTGTATTACACG-1  TTGTTTGTATTACACG
#
# [2674 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAGGGTCTATATT': 'CL:0000844',
#  'AAACAGTGTTCCTGGG': 'CL:0000844',
#  'AAACATGGTGAGAGGA': 'CL:0000584',
#  'AAACATTTCCCGGATT': 'CL:0000844',
#  'AAACCCGAACGAAATC': 'CL:0000186',
#  'AAACCGTTCGTCCAGG': 'CL:0000584',
#  'AAACCTAAGCAGCCGG': 'CL:0000584',
#  'AAACCTCATGAAGTTG': 'CL:0000584',
#  'AAACGAAGATGGAGTA': 'CL:0000844',
#  'AAACGAGACGGTTGAT': 'CL:0000844',
#  'AAACGCTGGGCACGAC': 'CL:0000584',
#  'AAACGGGCGTACGGGT': 'CL:0000584',
#  'AAACGGTTGCGAACTG': 'CL:0000844',
#  'AAACTCGGTTCGCAAT': 'CL:0000844',
#  'AAACTGCTGGCTCCAA': 'CL:0000186',
#  'AAACTTAATTGCACGC': 'CL:0000584',
#  'AAACTTGCAAACGTAT': 'CL:0000844',
#  'AAAGAATGACCTTAGA': 'CL:0000584',
#  'AAAGAATGTGGACTAA': 'CL:0000584',
#  'AAAGACCCAAGTCGCG': 'CL:0000584',
#  'AAAGCTTGCCTACATA': 'CL:0000584',
#  'AAAGGCTACGGACCAT': 'CL:0000844',
#  'AAAGGCTCTCGCGCCG': 'CL:0000844',
#  'AAAGGGATGTAGCAAG': 'CL:0000844',
#  'AAAGGGCAGCTTGAAT': 'CL:0000844',
#  'AAAGTCACTGATGTAA': 'CL:0000584',
#  'AAAGTCGACCCTCAGT': 'CL:0000844',
#  'AAAGTGCCATCAATTA': 'CL:0000844',
#  'AAAGTTGACTCCCGTA': 'CL:0000844',
#  'AAATAGGGTGCTATTG': 'CL:0000584',
#  'AAATCCGATACACGCC': 'CL:0000584',
#  'AAATCGCGGAAGGAGT': 'CL:0000844',
#  'AAATCGTGTACCACAA': 'CL:0000584',
#  'AAATCTGCCCGCGTCC': 'CL:0000844',
#  'AAATGACTGATCAAAC': 'CL:0000844',
#  'AAATGCTCGTTACGTT': 'CL:0000584',
#  'AAATGGCATGTCTTGT': 'CL:0000584',
#  'AAATGGCCCGTGCCCT': 'CL:0000844',
#  'AAATTAACGGGTAGCT': 'CL:0000584',
#  'AAATTGATAGTCCTTT': 'CL:0000584',
#  'AAATTTGCGGGTGTGG': 'CL:0000844',
#  'AACAATTACTCTACGC': 'CL:0000844',
#  'AACACACGCTCGCCGC': 'CL:0000186',
#  'AACACGAGACGCGGCC': 'CL:0000844',
#  'AACAGCTGTGTGGCAA': 'CL:0000844',
#  'AACAGGAAATCGAATA': 'CL:0000844',
#  'AACAGGATGGGCCGCG': 'CL:0000584',
#  'AACAGGTAGTATGGAT': 'CL:0000844',
#  'AACATAGCGTGTATCG': 'CL:0000584',
#  'AACATATCAACTGGTG': 'CL:0000844',
#  'AACCATAGGGTTGAAC': 'CL:0000584',
#  'AACCATGGGATCGCTA': 'CL:0000844',
#  'AACCCAGAGACGGAGA': 'CL:0000844',
#  'AACCCATCCCATGATC': 'CL:0000584',
#  'AACCCGAGCAGAATCG': 'CL:0009010',
#  'AACCCGCTGTATTCCA': 'CL:0000584',
#  'AACCGCTAAGGGATGC': 'CL:0000584',
#  'AACCGTTGTGTTTGCT': 'CL:0000844',
#  'AACCTCGCTTTAGCCC': 'CL:0000844',
#  'AACCTTTAAATACGGT': 'CL:0000844',
#  'AACGAAAGTCGTCCCA': 'CL:0000584',
#  'AACGACCTCCTAGCCG': 'CL:0000844',
#  'AACGATAATGCCGTAG': 'CL:0000584',
#  'AACGATAGAAGGGCCG': 'CL:0000584',
#  'AACGATATGTCAACTG': 'CL:0000584',
#  'AACGCGACCTTGGGCG': 'CL:0000844',
#  'AACGCGGTCTCCAGCC': 'CL:0000844',
#  'AACGCTGTTGCTGAAA': 'CL:0000844',
#  'AACGGACGTACGTATA': 'CL:0000186',
#  'AACGGCCATCTCCGGT': 'CL:0000584',
#  'AACGTACTGTGGGTAC': 'CL:0000584',
#  'AACGTCAGACTAGTGG': 'CL:0000584',
#  'AACGTCGCTGCACTTC': 'CL:0000584',
#  'AACGTTATCAGCACCT': 'CL:0000584',
#  'AACGTTCTACCATTGT': 'CL:0000584',
#  'AACTACCCGTTTGTCA': 'CL:0000844',
#  'AACTAGGCTTGGGTGT': 'CL:0000844',
#  'AACTCAAGTTAATTGC': 'CL:0000844',
#  'AACTCCAGAGCGTGTT': 'CL:0000186',
#  'AACTCGATGGCGCAGT': 'CL:0000186',
#  'AACTCTCAGTGTGCTC': 'CL:0000844',
#  'AACTGATATTAGGCCT': 'CL:0000844',
#  'AACTGGGTCCCGACGT': 'CL:0000186',
#  'AACTTGCCCGTATGCA': 'CL:0000844',
#  'AAGAAAGTTTGATGGG': 'CL:0000844',
#  'AAGACCAAATAACTCA': 'CL:0000584',
#  'AAGACTGCAAGCTACT': 'CL:0000186',
#  'AAGAGATGAATCGGTA': 'CL:0000584',
#  'AAGAGCTCTTTATCGG': 'CL:0000844',
#  'AAGAGGCATGGATCGC': 'CL:0000844',
#  'AAGATGGCACCGGACC': 'CL:0000584',
#  'AAGCATACTCTCCTGA': 'CL:0000844',
#  'AAGCCGAAGCGGTTTA': 'CL:0000844',
#  'AAGCCGGAGAGCAGGA': 'CL:0000844',
#  'AAGCGTCCCTCATCGA': 'CL:0000186',
#  'AAGCTAGATCGAGTAA': 'CL:0000844',
#  'AAGCTATGGATTGACC': 'CL:0000844',
#  'AAGCTCTTTCATGGTG': 'CL:0000186',
#  'AAGGAGCGGTTGGTGC': 'CL:0000584',
#  'AAGGATCGATCGCTTG': 'CL:0000844',
#  'AAGGCGCGTAAAGCTT': 'CL:0000584',
#  'AAGGCTGTGCTCATCG': 'CL:0000584',
#  'AAGGGACTATGCATTC': 'CL:0000844',
#  'AAGGGTTTGATTTCAG': 'CL:0000844',
#  'AAGGTATCCTAATATA': 'CL:0000186',
#  'AAGGTGATAAACCAGC': 'CL:0000844',
#  'AAGTAGAAGACCGGGT': 'CL:0000844',
#  'AAGTAGTGACGCGAGG': 'CL:0000844',
#  'AAGTCAATTGTCGTCA': 'CL:0000584',
#  'AAGTGACGACCGAATT': 'CL:0000844',
#  'AAGTGCCTTGACTGTA': 'CL:0000844',
#  'AAGTGCTTCTCTATTG': 'CL:0000584',
#  'AAGTGTTTGGAGACGG': 'CL:0000186',
#  'AAGTTCACTCCAAGCT': 'CL:0000186',
#  'AAGTTCGGCCAACAGG': 'CL:0000584',
#  'AAGTTGTGATGTTATA': 'CL:0000844',
#  'AATAACACTAGAACAA': 'CL:0000844',
#  'AATAACGTCGCGCCCA': 'CL:0009010',
#  'AATACAATGTTTCAGG': 'CL:0000844',
#  'AATACCTGATGTGAAC': 'CL:0009010',
#  'AATAGAACAGAGTGGC': 'CL:0000186',
#  'AATAGAATCTGTTTCA': 'CL:0000186',
#  'AATAGTCCGTCCCGAC': 'CL:0009010',
#  'AATAGTCGCGAGTCGG': 'CL:0000186',
#  'AATATCGAATCAATGC': 'CL:0000844',
#  'AATATCGAGGGTTCTC': 'CL:0000844',
#  'AATCAGGTTTCATTTA': 'CL:0000584',
#  'AATCATGTAAAGACTC': 'CL:0000186',
#  'AATCCAAGGGCCTGAG': 'CL:0000844',
#  'AATCCCGCTCAGAGCC': 'CL:0000844',
#  'AATCGAGGTCTCAAGG': 'CL:0000584',
#  'AATCGCCTCAGCGCCA': 'CL:0000844',
#  'AATCGCGCAGAGGACT': 'CL:0000186',
#  'AATCGGTATAGCCCTC': 'CL:0000584',
#  'AATCGTGAGCCGAGCA': 'CL:0000584',
#  'AATCTAGGTTTACTTG': 'CL:0000584',
#  'AATCTATGCCGGAGCC': 'CL:0000584',
#  'AATCTGCGTTGGGACG': 'CL:0000584',
#  'AATCTGGCTTTCTAGT': 'CL:0000584',
#  'AATGACAGCAATGTCT': 'CL:0000844',
#  'AATGACGTAGGATGTC': 'CL:0000186',
#  'AATGACTGTCAGCCGG': 'CL:0000844',
#  'AATGATGATACGCTAT': 'CL:0000584',
#  'AATGATGCGACTCCTG': 'CL:0000844',
#  'AATGCAACCGGGTACC': 'CL:0000844',
#  'AATGCACCAAGCAATG': 'CL:0000584',
#  'AATGGTTCTCACAAGC': 'CL:0000584',
#  'AATGTATGGCACTGTA': 'CL:0000584',
#  'AATGTGCCCGAGGTGT': 'CL:0000844',
#  'AATGTGCTAATCTGAG': 'CL:0000844',
#  'AATGTTAAGACCCTGA': 'CL:0000584',
#  'AATGTTGTCGTGAGAC': 'CL:0000584',
#  'AATTAAAGGTCGGCGT': 'CL:0000844',
#  'AATTAACGGATTTCCA': 'CL:0000584',
#  'AATTACGAGACCCATC': 'CL:0000584',
#  'AATTAGCGCTGCAGCG': 'CL:0000844',
#  'AATTATACCCAGCAAG': 'CL:0000584',
#  'AATTCATAAGGGATCT': 'CL:0000584',
#  'AATTCATTGTCATGCA': 'CL:0000844',
#  'AATTCCAAGCATGTAC': 'CL:0000844',
#  'AATTCTAGAGTTAGGC': 'CL:0000844',
#  'AATTGAACGCTCTGGT': 'CL:0000844',
#  'AATTGCGTGGATTACA': 'CL:0000844',
#  'AATTGTGGTTGCCAAA': 'CL:0000844',
#  'AATTTGGTTCCAAAGA': 'CL:0000844',
#  'ACAAACTCCATCAGAG': 'CL:0000844',
#  'ACAAATCGCACCGAAT': 'CL:0000844',
#  'ACAAATGGTAGTGTTT': 'CL:0000844',
#  'ACAACGGTCCCTGCGA': 'CL:0000584',
#  'ACAAGCAGTGCCTAGC': 'CL:0000844',
#  'ACAAGGAAATCCGCCC': 'CL:0000186',
#  'ACAAGGATGCTTTAGG': 'CL:0000844',
#  'ACAAGGGCAGGCTCTG': 'CL:0000186',
#  'ACAATAGTCGTACGTT': 'CL:0000844',
#  'ACAATGAATACGGAGA': 'CL:0000844',
#  'ACAATTGTGTCTCTTT': 'CL:0000186',
#  'ACAATTTGGCCATATT': 'CL:0000584',
#  'ACACACCAGGACCAGT': 'CL:0000844',
#  'ACACACTTTCTACACG': 'CL:0000584',
#  'ACACATTTCCGTAGAC': 'CL:0000186',
#  'ACACCCAGCATGCAGC': 'CL:0000844',
#  'ACACCCGAGAAATCCG': 'CL:0000584',
#  'ACACCTTAAGTAGGGC': 'CL:0000844',
#  'ACACCTTACTACTTGC': 'CL:0000844',
#  'ACACTCCAATGTCACT': 'CL:0000584',
#  'ACACTGATCAAGGTGT': 'CL:0000584',
#  'ACACTGGGACAGTCGT': 'CL:0000584',
#  'ACAGCATAGAGCCAGT': 'CL:0000584',
#  'ACAGGCACGGATCCTT': 'CL:0000844',
#  'ACAGGTGGAGGTGAGG': 'CL:0000186',
#  'ACAGTAATACAACTTG': 'CL:0000584',
#  'ACATAAGTCGTGGTGA': 'CL:0000584',
#  'ACATAATAAGGCGGTG': 'CL:0000584',
#  'ACATACAATCAAGCGG': 'CL:0009010',
#  'ACATCCCGGCCATACG': 'CL:0000844',
#  'ACATCCTGGTAACTGT': 'CL:0000844',
#  'ACATCGATCGTTTACC': 'CL:0000186',
#  'ACATCGCAATATTCGG': 'CL:0000844',
#  'ACATCGGTCAGCCGCG': 'CL:0000844',
#  'ACATCGTATGCAATGG': 'CL:0000844',
#  'ACATGGCGCCAAAGTA': 'CL:0000186',
#  'ACATTCGCGCGGAATA': 'CL:0000844',
#  'ACATTTGAAACCTAAC': 'CL:0009010',
#  'ACCAACCGCACTCCAC': 'CL:0000844',
#  'ACCAAGAACGCGTGTC': 'CL:0000844',
#  'ACCAAGTCATCGGCAG': 'CL:0000584',
#  'ACCACACGGTTGATGG': 'CL:0000584',
#  'ACCACCAATGTAACAA': 'CL:0000844',
#  'ACCACGTGCAGCTATA': 'CL:0000186',
#  'ACCATATCCGCAATAA': 'CL:0000186',
#  'ACCATCCGCCAACTAG': 'CL:0000844',
#  'ACCATCGTATATGGTA': 'CL:0000844',
#  'ACCCACCTACATGCTC': 'CL:0000844',
#  'ACCCGATTGGTTCCGA': 'CL:0000584',
#  'ACCCGGAAACTCCCAG': 'CL:0000584',
#  'ACCCGGAGCACCACAA': 'CL:0000844',
#  'ACCCGGATGACGCATC': 'CL:0000186',
#  'ACCCGGTTACACTTCC': 'CL:0000844',
#  'ACCCGTAGTCTAGTTG': 'CL:0000584',
#  'ACCCGTGTCATCAGTA': 'CL:0000844',
#  'ACCCTATGCCATATCG': 'CL:0000844',
#  'ACCCTCCCGTCAGGGC': 'CL:0000844',
#  'ACCCTCCCTTGCTATT': 'CL:0000186',
#  'ACCCTTCATCTGCGAA': 'CL:0000844',
#  'ACCGAAAGGGCCCTGC': 'CL:0000584',
#  'ACCGACACATCTCCCA': 'CL:0000844',
#  'ACCGACTGAGTCCCAC': 'CL:0000844',
#  'ACCGAGTCTCCTTATT': 'CL:0000584',
#  'ACCGATAGGCATAACC': 'CL:0000844',
#  'ACCGCAATAACTGCCT': 'CL:0000034',
#  'ACCGCGGTGGAAGTCG': 'CL:0000844',
#  'ACCGGGCCTTTGTTGA': 'CL:0000584',
#  'ACCGTCCACTGGGCCC': 'CL:0000584',
#  'ACCTAAGTACCTTTCA': 'CL:0000186',
#  'ACCTAATCGACTTCCT': 'CL:0000584',
#  'ACCTACTATAAATCTA': 'CL:0000844',
#  'ACCTCAGCGAGGCGCA': 'CL:0000844',
#  'ACCTCCGCCCTCGCTG': 'CL:0000844',
#  'ACCTGCGTGTCATGTT': 'CL:0000584',
#  'ACGACCCATGAGTTGC': 'CL:0000844',
#  'ACGACTCTAGGGCCGA': 'CL:0000844',
#  'ACGAGGATACCACTCT': 'CL:0000844',
#  'ACGAGTACGGATGCCC': 'CL:0000844',
#  'ACGATACATAGAACTA': 'CL:0000186',
#  'ACGATCATACATAGAG': 'CL:0000844',
#  'ACGATGCATATGTTAT': 'CL:0000584',
#  'ACGCAATCACTACAGC': 'CL:0000844',
#  'ACGCATTCGTGAGTAC': 'CL:0000844',
#  'ACGCCACTCGAAACAG': 'CL:0000584',
#  'ACGCCAGATGATTTCT': 'CL:0000584',
#  'ACGCCAGTGCGTTTGC': 'CL:0000584',
#  'ACGCCGCTAGACGACC': 'CL:0000844',
#  'ACGCGAAGTCAGACGA': 'CL:0000584',
#  'ACGCTAGTGATACACT': 'CL:0000844',
#  'ACGCTGTGAGGCGTAG': 'CL:0000584',
#  'ACGGAACACGAGTGCC': 'CL:0009010',
#  'ACGGACGCAGCGACAA': 'CL:0000844',
#  'ACGGCACTTGCTTGGG': 'CL:0000844',
#  'ACGGCCAACATGGACT': 'CL:0000844',
#  'ACGGCGACGATGGGAA': 'CL:0000186',
#  'ACGGGCGTATGCGACA': 'CL:0000844',
#  'ACGGGTTGTGACCTGT': 'CL:0000844',
#  'ACGGTACAGTTCAATG': 'CL:0000584',
#  'ACGTACTTTGGCACGG': 'CL:0000844',
#  'ACGTAGATTGCTGATG': 'CL:0000186',
#  'ACGTATTACTCCGATC': 'CL:0000844',
#  'ACGTCGGGCAACTCGG': 'CL:0000844',
#  'ACGTGCGCCTCGTGCA': 'CL:0000584',
#  'ACGTTAATGTCGAAGA': 'CL:0000186',
#  'ACGTTATTGGTCACTC': 'CL:0000584',
#  'ACGTTCACTATGCCGC': 'CL:0000844',
#  'ACGTTCGTTCAGGAAA': 'CL:0000584',
#  'ACGTTTAGTTGTGATC': 'CL:0000844',
#  'ACGTTTCGGTGCACTT': 'CL:0000584',
#  'ACTACAAAGAGAGGTG': 'CL:0009010',
#  'ACTACGCGTTAGAATT': 'CL:0000844',
#  'ACTAGTTGCGATCGTC': 'CL:0000844',
#  'ACTATCCAGGGCATGG': 'CL:0000186',
#  'ACTATCTGCCCGCGTA': 'CL:0000844',
#  'ACTATTTCCGGGCCCA': 'CL:0000584',
#  'ACTCAAGTGCAAGGCT': 'CL:0000844',
#  'ACTCATGGCAGCCTTC': 'CL:0000584',
#  'ACTCCAATATCATCAT': 'CL:0000844',
#  'ACTCCCATTCCTAAAG': 'CL:0000844',
#  'ACTCCCTAATGCTAAA': 'CL:0000844',
#  'ACTCCCTAGAATAGTA': 'CL:0000584',
#  'ACTCGCGATCTGACGC': 'CL:0000584',
#  'ACTCGTAACCCGTCCT': 'CL:0000584',
#  'ACTCGTCAGTAATCCC': 'CL:0000844',
#  'ACTCTCTGACTTAGGT': 'CL:0000584',
#  'ACTCTGACCTAATAGA': 'CL:0000844',
#  'ACTCTTGTATAGTAAC': 'CL:0000584',
#  'ACTGAAACGCCGTTAG': 'CL:0000186',
#  'ACTGAATGGCGAAAGT': 'CL:0000844',
#  'ACTGCCCGCCATTCTC': 'CL:0000584',
#  'ACTGTACGATACACAT': 'CL:0000844',
#  'ACTGTATACGCGAGCA': 'CL:0000844',
#  'ACTGTCTTCTTTAGAA': 'CL:0000844',
#  'ACTGTGCTAGTAGATC': 'CL:0000844',
#  'ACTTAGTACGACAAGA': 'CL:0000844',
#  'ACTTATTAGGATCGGT': 'CL:0000844',
#  'ACTTATTTATGTGCCA': 'CL:0009010',
#  'ACTTCAGGCTGATCCC': 'CL:0000034',
#  'ACTTCCAGTGGAAGCT': 'CL:0000844',
#  'ACTTCCATGCGGGACA': 'CL:0000186',
#  'ACTTCGCCATACGCAC': 'CL:0000844',
#  'ACTTGACTCCCTCTTT': 'CL:0000584',
#  'ACTTGCTCTATCTACC': 'CL:0000844',
#  'ACTTGGGACCCGGTGG': 'CL:0000844',
#  'ACTTGGGCTTTCGCCA': 'CL:0000844',
#  'ACTTGTGGATGGAACG': 'CL:0000844',
#  'ACTTGTTACCGGATCA': 'CL:0000584',
#  'ACTTTATACACCACTT': 'CL:0000584',
#  'ACTTTCCTATAGCTTC': 'CL:0000584',
#  'AGAAATTATGACTCGC': 'CL:0000186',
#  'AGAACACGGCGATGGT': 'CL:0000844',
#  'AGAACCCTCAATTGGG': 'CL:0000584',
#  'AGAACGTGGTACATTC': 'CL:0000844',
#  'AGAACTGTACTTTGTA': 'CL:0000844',
#  'AGAAGGTACACTTCAC': 'CL:0000584',
#  'AGAAGGTTGCCGAATT': 'CL:0000844',
#  'AGAAGTGATTCGTGAT': 'CL:0000844',
#  'AGAATACAGGCTATCC': 'CL:0009010',
#  'AGAATTATGGATTCGA': 'CL:0000844',
#  'AGACCATGGGATACAA': 'CL:0000844',
#  'AGACCCACCGCTGATC': 'CL:0000844',
#  'AGACCGCTCCGCGGTT': 'CL:0000844',
#  'AGACCGGGAAACCCTG': 'CL:0000584',
#  'AGACGAAGTGCCGGTC': 'CL:0000584',
#  'AGACGACGATGCCGCT': 'CL:0000844',
#  'AGACGCCCACTTCGCC': 'CL:0000844',
#  'AGACTAGCCTTCCAGA': 'CL:0000844',
#  'AGAGAAACACCAGAAA': 'CL:0000584',
#  'AGAGAAGGAGTACAAT': 'CL:0000186',
#  'AGAGATCTCTAAAGCG': 'CL:0000584',
#  'AGAGCGGGCTAATCAT': 'CL:0000844',
#  'AGAGCGTACAAGCTCG': 'CL:0000844',
#  'AGAGTAAACTTCACTA': 'CL:0000844',
#  'AGAGTCTTAATGAAAG': 'CL:0000584',
#  'AGATAACTTCAGGGCC': 'CL:0000844',
#  'AGATAATCACACCTAT': 'CL:0000844',
#  'AGATACCAATAGAACC': 'CL:0000584',
#  'AGATACGACTTCATAT': 'CL:0000844',
#  'AGATACTCAAGATCGA': 'CL:0000584',
#  'AGATATAATACGACTA': 'CL:0000844',
#  'AGATCGTGCATAAGAT': 'CL:0000844',
#  'AGATCTCAGGTGTGAT': 'CL:0000844',
#  'AGATCTGGAGAGGATA': 'CL:0000844',
#  'AGATGACTCGCCCACG': 'CL:0000186',
#  'AGATGCAAGACGTGCA': 'CL:0000584',
#  'AGATTCACAACCGATA': 'CL:0000844',
#  'AGCAAAGGCCGCTAGT': 'CL:0000584',
#  'AGCAACCGAAAGTAAT': 'CL:0000186',
#  'AGCACACGTTTAGACT': 'CL:0000584',
#  'AGCACCAGTACTCACG': 'CL:0000844',
#  'AGCACTACCTCACCAG': 'CL:0000186',
#  'AGCAGAAGGAGAAAGA': 'CL:0000844',
#  'AGCAGCCAGATGAATA': 'CL:0000844',
#  'AGCAGTCGAAGCATGC': 'CL:0000584',
#  'AGCATATCAATATGCT': 'CL:0000186',
#  'AGCATCATTTCGAAAG': 'CL:0000584',
#  'AGCATCGTCGATAATT': 'CL:0000186',
#  'AGCATTACGAGGCAAG': 'CL:0000844',
#  'AGCCAAGCTTTGTGTC': 'CL:0000844',
#  'AGCCACAGGTTACCCG': 'CL:0000584',
#  'AGCCACTCCCGTGCTT': 'CL:0000057',
#  'AGCCCATACATGTAAG': 'CL:0000844',
#  'AGCCCGCAACAAGCAG': 'CL:0009010',
#  'AGCCCGCACTACAATG': 'CL:0000584',
#  'AGCCCGGCATTAGAGG': 'CL:0000584',
#  'AGCCCTAAGCGAAGTT': 'CL:0000844',
#  'AGCCCTCCCTGGTGGC': 'CL:0000844',
#  'AGCCGTGGCTAAATGT': 'CL:0000844',
#  'AGCCTAATACCCACGT': 'CL:0000584',
#  'AGCCTTAAAGCGGAAG': 'CL:0000186',
#  'AGCCTTGTCACTGATA': 'CL:0000844',
#  'AGCGACAGGAACGGTC': 'CL:0000186',
#  'AGCGACATCCCATTCA': 'CL:0000584',
#  'AGCGACTTTGAAGACA': 'CL:0000844',
#  'AGCGATGCGCCTAATA': 'CL:0000584',
#  'AGCGCATAATGAATCG': 'CL:0009010',
#  'AGCGCGGGTGCCAATG': 'CL:0000584',
#  'AGCGGACACTTCGTAG': 'CL:0000844',
#  'AGCGGCGGTTAGCGGT': 'CL:0000844',
#  'AGCGGGAAGGGTCCAT': 'CL:0000186',
#  'AGCGGGTCTGACACTC': 'CL:0000844',
#  'AGCGTGGTATTCTACT': 'CL:0007011',
#  'AGCTAACAAGCAATGT': 'CL:0000844',
#  'AGCTAAGTACGCAGGC': 'CL:0000186',
#  'AGCTACGAATGGTGGT': 'CL:0000844',
#  'AGCTAGAAGCAGAAGT': 'CL:0000584',
#  'AGCTCCTTCGCACATC': 'CL:0000186',
#  'AGCTCTAGACGTTCCA': 'CL:0000844',
#  'AGCTCTTCCCAGTGCA': 'CL:0000584',
#  'AGCTCTTCGTAACCTT': 'CL:0000186',
#  'AGCTCTTTACTCAGTT': 'CL:0000584',
#  'AGCTGAAGTAAACCAA': 'CL:0000584',
#  'AGCTGTAACCTCAATC': 'CL:0000584',
#  'AGCTTCTTCTCGAGCA': 'CL:0000844',
#  'AGCTTGATCTTAACTT': 'CL:0000844',
#  'AGGAACGAACGACTTC': 'CL:0000844',
#  'AGGAAGCTGTCCGCCG': 'CL:0000844',
#  'AGGACAGTCGAATCCC': 'CL:0000844',
#  'AGGACATCGGCACACT': 'CL:0000844',
#  'AGGACGACCCATTAGA': 'CL:0000844',
#  'AGGAGACATCCACAGT': 'CL:0000584',
#  'AGGAGGCCTTCGCGCG': 'CL:0000186',
#  'AGGATAAAGTCGGGAT': 'CL:0000844',
#  'AGGATATAGGGATTTA': 'CL:0000584',
#  'AGGATATCCGACTGCA': 'CL:0000844',
#  'AGGATCACGCGATCTG': 'CL:0000844',
#  'AGGCACGTGACTGTCC': 'CL:0009010',
#  'AGGCCCATTGTACAGG': 'CL:0000844',
#  'AGGCCCTAGAACGCCA': 'CL:0000584',
#  'AGGCCTGAGAATCTCG': 'CL:0000844',
#  'AGGCGATAACTGGCGT': 'CL:0000584',
#  'AGGCTTCCCGAAGAAG': 'CL:0000844',
#  'AGGCTTGCTAGACACC': 'CL:0000844',
#  'AGGGACCGGCTGCGTT': 'CL:0000186',
#  'AGGGACTCTACGCGAC': 'CL:0000844',
#  'AGGGCGAGCAGCTGAT': 'CL:0000844',
#  'AGGGCGTGATCGGCTA': 'CL:0000844',
#  'AGGGCTGCAGTTACAG': 'CL:0000186',
#  'AGGGTCTGGACGCAGT': 'CL:0000844',
#  'AGGGTGCCGTTCTTTA': 'CL:0000844',
#  'AGGGTTCAGACGGTCC': 'CL:0000844',
#  'AGGGTTTAGTTCGGGA': 'CL:0000844',
#  'AGGTAACCTCCTATTC': 'CL:0000844',
#  'AGGTAGATCGAGATAT': 'CL:0000844',
#  'AGGTCAGGTGAGAGTG': 'CL:0000844',
#  'AGGTCGCCTCCCAACA': 'CL:0000844',
#  'AGGTCGCGGAGTTACT': 'CL:0000844',
#  'AGGTGCACGTCCACAT': 'CL:0000584',
#  'AGGTGGTGACCTTCGC': 'CL:0000844',
#  'AGGTGTATCGCCATGA': 'CL:0000844',
#  'AGGTTACACCATGCCG': 'CL:0000186',
#  'AGGTTCTCCTTTCCGG': 'CL:0000584',
#  'AGGTTGAGGCACGCTT': 'CL:0000584',
#  'AGGTTTCACACACCTT': 'CL:0000186',
#  'AGTAACTATAGCAGCC': 'CL:0000844',
#  'AGTAATCTAAGGGTGG': 'CL:0000584',
#  'AGTAATGTCTTGCCGC': 'CL:0000844',
#  'AGTAATTTGCAAGCGT': 'CL:0000844',
#  'AGTACATCATTTATCA': 'CL:0000844',
#  'AGTACGGGCACCTGGC': 'CL:0000186',
#  'AGTACTCTTATGCCCA': 'CL:0000186',
#  'AGTAGAAGGCGCCTCA': 'CL:0000186',
#  'AGTAGGTAACATACAT': 'CL:0000844',
#  'AGTCAACACCACCATC': 'CL:0000584',
#  'AGTCAAGATGACACTT': 'CL:0009010',
#  'AGTCACTAGCTCTCGA': 'CL:0000186',
#  'AGTCAGCCACCGCCTG': 'CL:0000584',
#  'AGTCCATTGGCTGATG': 'CL:0000844',
#  'AGTCGAAACGATTCAG': 'CL:0000844',
#  'AGTCGAATTAGCGTAA': 'CL:0000844',
#  'AGTCGGCCCAAACGAC': 'CL:0000584',
#  'AGTCGGCTCAACTTTA': 'CL:0000844',
#  'AGTCGTCGACCACCAA': 'CL:0000186',
#  'AGTCGTGGGCATTACG': 'CL:0000844',
#  'AGTCTCACAAGACTAC': 'CL:0000844',
#  'AGTCTTCTCCTCAAAT': 'CL:0000186',
#  'AGTCTTTAAAGTGTCC': 'CL:0000844',
#  'AGTGAACAAACTTCTC': 'CL:0000844',
#  'AGTGACCTACTTTACG': 'CL:0000844',
#  'AGTGACTGTGACACAA': 'CL:0000844',
#  'AGTGAGCCTCGCCGCC': 'CL:0000844',
#  'AGTGAGTCGAATTAAC': 'CL:0000584',
#  'AGTGATAACCTGCGCG': 'CL:0000186',
#  'AGTGATATGAGTAGTT': 'CL:0000584',
#  'AGTGCACGCTTAAGAA': 'CL:0000186',
#  'AGTGCGTAGCTCGTAA': 'CL:0000584',
#  'AGTGCTAAACACAGCA': 'CL:0000844',
#  'AGTGCTTGCACGAATA': 'CL:0000844',
#  'AGTGGCCCGCAAATGG': 'CL:0000584',
#  'AGTGGCGGCAATTTGA': 'CL:0000584',
#  'AGTGGCGTCTGAAGGT': 'CL:0000186',
#  'AGTGTGGTCTATTGTG': 'CL:0000186',
#  'AGTTAAACACTTGCGA': 'CL:0000844',
#  'AGTTAAGCGGTCCCGG': 'CL:0000844',
#  'AGTTACCCTTAAGACT': 'CL:0000186',
#  'AGTTACCGCACATGGT': 'CL:0000584',
#  'AGTTCACCGGTTGGAC': 'CL:0000584',
#  'AGTTCCTACAGAATTA': 'CL:0000844',
#  'AGTTCCTATTTATGTT': 'CL:0000186',
#  'AGTTGACATCGGCTGG': 'CL:0000186',
#  'AGTTGACGGTCCTTGC': 'CL:0000844',
#  'AGTTGGCAAGGCTAGA': 'CL:0000186',
#  'AGTTTATGTAAAGACA': 'CL:0000584',
#  'AGTTTCGCAGGTCGGA': 'CL:0000584',
#  'AGTTTGGCCAGACCTA': 'CL:0000584',
#  'ATAAACGGACCCGTAA': 'CL:0000186',
#  'ATAAATATTAGCAGCT': 'CL:0000584',
#  'ATAACGCCGGAGGGTC': 'CL:0000844',
#  'ATAACGGAGTCCAACG': 'CL:0000844',
#  'ATAAGGTGGAGAACAT': 'CL:0000584',
#  'ATAAGTACCCGATTGT': 'CL:0000844',
#  'ATAAGTAGGATTCAGA': 'CL:0000844',
#  'ATAAGTAGGGCGACTC': 'CL:0009010',
#  'ATAAGTTACCGCGACG': 'CL:0000844',
#  'ATAATACCGTTAGCCG': 'CL:0000844',
#  'ATAATAGCTGTTGAAT': 'CL:0000584',
#  'ATAATAGTGTAGGGAC': 'CL:0000186',
#  'ATAATTAGCTAAGTAG': 'CL:0000844',
#  'ATACAGCGTCCACTGA': 'CL:0000844',
#  'ATACAGGCCCTCCAAT': 'CL:0000844',
#  'ATACCCTCCCGGCCAA': 'CL:0000844',
#  'ATACCTAACCAAGAAA': 'CL:0000584',
#  'ATACGAGGTTTGTAAG': 'CL:0000844',
#  'ATACGCCGGCGAAACC': 'CL:0000844',
#  'ATACGGAACGTCGTTT': 'CL:0000186',
#  'ATACGGGTTTCGATTG': 'CL:0000186',
#  'ATACGTCCACTCCTGT': 'CL:0000584',
#  'ATACGTTATGCACGGA': 'CL:0000584',
#  'ATACTAGCATGACCCT': 'CL:0000844',
#  'ATACTGCCTTACACCG': 'CL:0000186',
#  'ATAGACGAAGAGAAAG': 'CL:0000844',
#  'ATAGAGTACTGGGACA': 'CL:0000584',
#  'ATAGCAACTAGGGAAG': 'CL:0000844',
#  'ATAGCCATAACAGTCA': 'CL:0000584',
#  'ATAGCCTCAGTACCCA': 'CL:0000584',
#  'ATAGGCGGCTATAGAA': 'CL:0000584',
#  'ATAGGCTAGCTTCGCA': 'CL:0000844',
#  'ATAGGGATATCCTTGA': 'CL:0000584',
#  'ATAGGTTGGGCAGATG': 'CL:0000844',
#  'ATAGTGAAGCGTTCTC': 'CL:0000584',
#  'ATAGTTCCACCCACTC': 'CL:0000186',
#  'ATATAAAGCGCTCGTG': 'CL:0000844',
#  'ATATAACACGGGCGCA': 'CL:0000844',
#  'ATATCAACCTACAGAG': 'CL:0000844',
#  'ATATCGGTAGGGAGAT': 'CL:0000186',
#  'ATATCGTTCCTCGAAC': 'CL:0000186',
#  'ATATCTCCCTCGTTAA': 'CL:0000584',
#  'ATATCTTAGGGCCTTC': 'CL:0000844',
#  'ATATGTCTAGAGCGTG': 'CL:0000844',
#  'ATATTCAGTTAAACCT': 'CL:0000584',
#  'ATATTCCACATAGTGA': 'CL:0000584',
#  'ATATTCCCACAGGTCA': 'CL:0000844',
#  'ATATTGCTGTCAAAGT': 'CL:0000844',
#  'ATATTGGAGAGGCCTT': 'CL:0000844',
#  'ATCAAACACTGTTCCA': 'CL:0000844',
#  'ATCAAACGAAGGTTTG': 'CL:0000844',
#  'ATCAAAGAGCCGTGGT': 'CL:0000844',
#  'ATCAATCTGGGCTGCA': 'CL:0000186',
#  'ATCACATTAGAATATC': 'CL:0000844',
#  'ATCACGTGCTAATTAA': 'CL:0000584',
#  'ATCACTTCATCCTCGC': 'CL:0000584',
#  'ATCAGAAGCTGGTTGC': 'CL:0000844',
#  'ATCAGACGGCACGCCG': 'CL:0000844',
#  'ATCAGCCTCATGCTGC': 'CL:0000186',
#  'ATCAGCTCGTCCACTA': 'CL:0000844',
#  'ATCAGGTAGCTGACAG': 'CL:0000584',
#  'ATCAGTAGGCAGGGAT': 'CL:0000844',
#  'ATCATAGATCGACGAG': 'CL:0000584',
#  'ATCATCCAATATTTGT': 'CL:0000844',
#  'ATCATGGACTACCGAC': 'CL:0000584',
#  'ATCATTGTACCGCATT': 'CL:0000584',
#  'ATCCAATGGAGGGTCC': 'CL:0000844',
#  'ATCCACATCGACAGAA': 'CL:0000844',
#  'ATCCAGGATTCGTGAA': 'CL:0000584',
#  'ATCCGGACCAGCCTGA': 'CL:0000844',
#  'ATCCTACCTAAGCTCT': 'CL:0000844',
#  'ATCCTGAATCGCTGCG': 'CL:0000584',
#  'ATCCTGCGTGGAATGG': 'CL:0000584',
#  'ATCGACCCAATACAGA': 'CL:0000844',
#  'ATCGACTCTTTCCGTT': 'CL:0000186',
#  'ATCGCCAGTCAACATT': 'CL:0000844',
#  'ATCGCCGTGGTTCATG': 'CL:0000584',
#  'ATCGGCAAGCAGTCCA': 'CL:0000844',
#  'ATCGTTAGCTAGCGGA': 'CL:0000186',
#  'ATCTAATATCCTACGG': 'CL:0000844',
#  'ATCTAGCTTGTGAGGG': 'CL:0000584',
#  'ATCTCGTGAGCGAAAC': 'CL:0000186',
#  'ATCTGACATGGAAGGA': 'CL:0000844',
#  'ATCTGCACCTCTGCGA': 'CL:0000844',
#  'ATCTGCTGTTATCGCC': 'CL:0000844',
#  'ATCTGGGCTGTTCTTG': 'CL:0000844',
#  'ATCTGGTTAAGACTGT': 'CL:0000584',
#  'ATCTGTAATTGTACCC': 'CL:0000844',
#  'ATCTTGACCTGCAACG': 'CL:0000844',
#  'ATCTTGACTTGTCCAA': 'CL:0000034',
#  'ATCTTTCGTATAACCA': 'CL:0000844',
#  'ATGAAGCCAAGGAGCC': 'CL:0000844',
#  'ATGACGCCGGCTCTAA': 'CL:0000584',
#  'ATGACGCGTTCTATCC': 'CL:0000844',
#  'ATGACTATCAGCTGTG': 'CL:0000844',
#  'ATGACTATGCGACATT': 'CL:0000844',
#  'ATGATCGGGAATAGAC': 'CL:0000844',
#  'ATGATGCAATGGTACA': 'CL:0000844',
#  'ATGCACCTTCCTTAAT': 'CL:0000844',
#  'ATGCACTACCGCATTG': 'CL:0000844',
#  'ATGCATGATCCAGGAT': 'CL:0000844',
#  'ATGCCATTTGCGACCA': 'CL:0000844',
#  'ATGCCGGTCTTGCATA': 'CL:0000844',
#  'ATGCCGGTTGATGGGA': 'CL:0000584',
#  'ATGCGAGTCCCACCAC': 'CL:0000844',
#  'ATGCTCAGTGTTGCAT': 'CL:0000844',
#  'ATGGACTGCTTAGTTG': 'CL:0000844',
#  'ATGGAGCAGGCCGTGA': 'CL:0000186',
#  'ATGGATCCGGCGTCCG': 'CL:0000844',
#  'ATGGATTGACCAAACG': 'CL:0000844',
#  'ATGGCCCGAAAGGTTA': 'CL:0000584',
#  'ATGGGACCTGCTGAAC': 'CL:0000844',
#  'ATGGGCCTCGGCCTCT': 'CL:0000844',
#  'ATGGTATTGGGAACCG': 'CL:0000584',
#  'ATGGTCGCGTGGTTTC': 'CL:0009010',
#  'ATGTACATGCGGTGAG': 'CL:0000584',
#  'ATGTACGATGACGTCG': 'CL:0000844',
#  'ATGTCATTTCCCATTG': 'CL:0000584',
#  'ATGTCTTGTTTGACTC': 'CL:0000844',
#  'ATGTGAAAGCCTAATG': 'CL:0000844',
#  'ATGTGGACATCTTGAT': 'CL:0000584',
#  'ATGTTACGAGCAATAC': 'CL:0000584',
#  'ATGTTGTAGTCTGTTT': 'CL:0000844',
#  'ATTAAACATGCGGACC': 'CL:0000584',
#  'ATTAACACCTGAGATA': 'CL:0000584',
#  'ATTAATACTACGCGGG': 'CL:0000584',
#  'ATTAATGAACCAGTCG': 'CL:0000186',
#  'ATTAATTCGGTCACTC': 'CL:0000844',
#  'ATTACATGTCAGTCTT': 'CL:0000844',
#  'ATTACGGGCTACGGTT': 'CL:0000844',
#  'ATTACTAGCCTCTTGC': 'CL:0000584',
#  'ATTACTTACTGGGCAT': 'CL:0000584',
#  'ATTAGATTCCTCAGCA': 'CL:0000844',
#  'ATTAGATTGATAGCGG': 'CL:0000584',
#  'ATTAGGCGATGCTTTC': 'CL:0000584',
#  'ATTATACTTTGCTCGT': 'CL:0000584',
#  'ATTATGAGACCCAATT': 'CL:0000844',
#  'ATTATGCCATAGGGAG': 'CL:0000186',
#  'ATTATTATGTCCGTCA': 'CL:0000844',
#  'ATTATTCAGAGTCACT': 'CL:0000844',
#  'ATTCACTGATGTTGGA': 'CL:0000844',
#  'ATTCAGGACCTATTTC': 'CL:0000584',
#  'ATTCAGTAGCAGGGTC': 'CL:0000584',
#  'ATTCATATACTGTCCA': 'CL:0000186',
#  'ATTCATCGTTGAGGCA': 'CL:0000186',
#  'ATTCCCACATAAACAA': 'CL:0000584',
#  'ATTCCCGAAGGTACAG': 'CL:0000584',
#  'ATTCCTCCGCCAGTGC': 'CL:0000844',
#  'ATTCCTTCCAGGCGGT': 'CL:0000844',
#  'ATTCGCGCCTTGAGAG': 'CL:0000844',
#  'ATTCGTCCCGAGGTTA': 'CL:0000584',
#  'ATTCGTGTACCCATTC': 'CL:0000844',
#  'ATTCGTTTATCGTATT': 'CL:0009010',
#  'ATTCTCGTCTCTTTAG': 'CL:0000186',
#  'ATTGAAGATCTTAGTG': 'CL:0000844',
#  'ATTGAATTCCCTGTAG': 'CL:0000584',
#  'ATTGATAGCAACGAGA': 'CL:0009010',
#  'ATTGCCTTTATGTTTG': 'CL:0000844',
#  'ATTGCGATCAGTAACT': 'CL:0000186',
#  'ATTGGGAATATCTTGG': 'CL:0000844',
#  'ATTGGTTGTGCATTAC': 'CL:0000844',
#  'ATTGTCTGTTTCATGT': 'CL:0009010',
#  'ATTTAACTCGTATTAC': 'CL:0000844',
#  'ATTTATACTGGTAAAG': 'CL:0000584',
#  'ATTTCATTATTTCGCG': 'CL:0000584',
#  'ATTTCCGGGTTCTGCG': 'CL:0000844',
#  'ATTTGCGCGAGTAGCT': 'CL:0000186',
#  'ATTTGGAGATTGCGGT': 'CL:0000584',
#  'ATTTGTCTTGGGAGCT': 'CL:0000844',
#  'ATTTGTTCCAGGGCTC': 'CL:0000584',
#  'CAAACCATAAGCGTAT': 'CL:0000844',
#  'CAAACTCGCGACGCCG': 'CL:0000844',
#  'CAAAGATTATTGGGCC': 'CL:0000844',
#  'CAAATCTCTCACAAGG': 'CL:0000844',
#  'CAAATGTCCTTCCGTG': 'CL:0000844',
#  'CAAATTGTCAGCAAGC': 'CL:0000844',
#  'CAACCAGTGGCCTACC': 'CL:0000584',
#  'CAACCTGAACCTGCCA': 'CL:0000584',
#  'CAACGACCCGTTTACA': 'CL:0000844',
#  'CAACGAGCTTATTATG': 'CL:0000844',
#  'CAACGATCGATCCAAT': 'CL:0000584',
#  'CAACGCGATGAGCCAA': 'CL:0000844',
#  'CAACGGTTCTTGATAC': 'CL:0000844',
#  'CAACGTGGTGGAGTCT': 'CL:0000844',
#  'CAACTATATCGAATGC': 'CL:0000844',
#  'CAACTCCTTGATCCCG': 'CL:0000844',
#  'CAACTGCTCATCCGAT': 'CL:0000844',
#  'CAACTTGTAGTGGGCA': 'CL:0000844',
#  'CAAGAGGGCGGAGTAC': 'CL:0000057',
#  'CAAGATATTATAACGT': 'CL:0000844',
#  'CAAGCACCAAATGCCT': 'CL:0000584',
#  'CAAGCGGCACATAATT': 'CL:0000844',
#  'CAAGGATCGCATGTTC': 'CL:0000186',
#  'CAAGTAAGTGATAGAC': 'CL:0009010',
#  'CAATAAACCTTGGCCC': 'CL:0000844',
#  'CAATATTCTTGACCTA': 'CL:0000844',
#  'CAATGCGAGAAGTATC': 'CL:0000186',
#  'CAATTAAGGGTGATGA': 'CL:0000844',
#  'CAATTGGGCCGCACTC': 'CL:0000584',
#  'CAATTTCGTATAAGGG': 'CL:0000186',
#  'CACAAACCGCAGAACT': 'CL:0000584',
#  'CACAAGCTAAGAAAGG': 'CL:0000844',
#  'CACAATGAGCTGCTAT': 'CL:0000584',
#  'CACACACGCTAACGAG': 'CL:0000844',
#  'CACACAGCTTGCGCTC': 'CL:0000844',
#  'CACACAGGGATAGATT': 'CL:0000584',
#  'CACAGCACCCACGGCA': 'CL:0000844',
#  'CACAGCTAGGGAGTGA': 'CL:0000186',
#  'CACAGGGCCATATAGT': 'CL:0000186',
#  'CACAGGGCCGTTGTCA': 'CL:0000844',
#  'CACAGTTCGCTTCCCA': 'CL:0000844',
#  'CACATATTAGCAGGAT': 'CL:0000186',
#  'CACATGATTCAGCAAC': 'CL:0000186',
#  'CACATTCTTTCGATGG': 'CL:0000584',
#  'CACATTTCTTGTCAGA': 'CL:0000584',
#  'CACCATCGGAGGAGAC': 'CL:0000844',
#  'CACCCACACGTCACCC': 'CL:0000844',
#  'CACCCACGAGGCAATT': 'CL:0000584',
#  'CACCCGCGTTTGACAC': 'CL:0000584',
#  'CACCCTAACAAGATCT': 'CL:0000584',
#  'CACCCTTGGTGAGACC': 'CL:0000584',
#  'CACCGATGATGGGTAC': 'CL:0000844',
#  'CACCGGGCATCACAAG': 'CL:0000584',
#  'CACCGGTAGAGACATT': 'CL:0000584',
#  'CACCGTATCCCATCCG': 'CL:0000844',
#  'CACCGTTAGGGATCAC': 'CL:0000844',
#  'CACCGTTGCGCGATAT': 'CL:0000844',
#  'CACCTAATAGAGTCGT': 'CL:0000584',
#  'CACCTAATCAGTTTAC': 'CL:0000584',
#  'CACCTCGATGGTGGAC': 'CL:0000584',
#  'CACCTTGCGAAACTCG': 'CL:0000057',
#  'CACCTTGGCGCCTTTG': 'CL:0000844',
#  'CACGAGCAAACCAGAC': 'CL:0000844',
#  'CACGCACAGCGCAGCT': 'CL:0000844',
#  'CACGCGGAACTGTTGC': 'CL:0000844',
#  'CACGTCAATCAATGGA': 'CL:0000844',
#  'CACGTCGGCAACCTCT': 'CL:0000844',
#  'CACGTTCGTGCTCTAG': 'CL:0000844',
#  'CACGTTTCGTACACAC': 'CL:0000186',
#  'CACTCAAGAGCTATGG': 'CL:0000844',
#  'CACTCCTATGTAAGAT': 'CL:0000186',
#  'CACTCGAGCTGAACAA': 'CL:0000186',
#  'CACTCTCAAGCATCGA': 'CL:0000844',
#  'CACTGTCCAAGTGAGA': 'CL:0000844',
#  'CACTTAATCAGACGGA': 'CL:0000844',
#  'CACTTCGCCACAGGCT': 'CL:0000844',
#  'CACTTCGTCTTATCTC': 'CL:0000584',
#  'CAGAACTTAGCCCTCT': 'CL:0000186',
#  'CAGACCTGTAAGTGTT': 'CL:0000844',
#  'CAGACGAACCTGATAC': 'CL:0000186',
#  'CAGAGACGGTCACCCA': 'CL:0000844',
#  'CAGAGCGATGGATGCT': 'CL:0000584',
#  'CAGATACTAACATAGT': 'CL:0000844',
#  'CAGATATGAAGATGAC': 'CL:0000584',
#  'CAGATCCTGGTTTGAA': 'CL:0000844',
#  'CAGCAGCCCGTTCCTT': 'CL:0000584',
#  'CAGCCTCCTGCAGAGG': 'CL:0000186',
#  'CAGCCTCGATAGCGGT': 'CL:0000844',
#  'CAGCGATTCCCTTCAA': 'CL:0000584',
#  'CAGCTCACTGAGACAT': 'CL:0000844',
#  'CAGCTCGTGCTTGTGT': 'CL:0000844',
#  'CAGCTCTGGGCTCACT': 'CL:0000844',
#  'CAGCTGGCGTAACCGT': 'CL:0000584',
#  'CAGCTTAGTAGGTAGC': 'CL:0000844',
#  'CAGGATATATCGTTGT': 'CL:0000844',
#  'CAGGCAGTCTTACCAG': 'CL:0000584',
#  'CAGGCCAGTACCACCT': 'CL:0000844',
#  'CAGGCGCACGGTGGTC': 'CL:0000584',
#  'CAGGGAGATAGGCCAG': 'CL:0000844',
#  'CAGTAAGGGACGTCTC': 'CL:0000584',
#  'CAGTAATCCCTCCCAG': 'CL:0000186',
#  'CAGTACCAGTTTACGT': 'CL:0000844',
#  'CAGTCGAGGATGCAAT': 'CL:0000844',
#  'CAGTCTGTATACTGGG': 'CL:0000186',
#  'CAGTGGTTGCACATGA': 'CL:0000584',
#  'CAGTGTCCGCAGAATG': 'CL:0000844',
#  'CAGTGTCGGCTGGCCC': 'CL:0000186',
#  'CAGTGTTAATCTCTCA': 'CL:0000844',
#  'CAGTTCAAATTGACAC': 'CL:0000844',
#  'CAGTTCCGCGGGTCGA': 'CL:0000584',
#  'CAGTTCGAGGACCCGA': 'CL:0000844',
#  'CATAAGAAGCTTGGCT': 'CL:0000844',
#  'CATACAAAGCCGAACC': 'CL:0000584',
#  'CATACACAAAGTCAGC': 'CL:0000584',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACGGCGTCTGGGC': 'CL:0000186',
#  'CATACTTAGGCAATAC': 'CL:0000186',
#  'CATACTTCTTTCTCCG': 'CL:0000844',
#  'CATAGCCGCCCGGGAT': 'CL:0000584',
#  'CATAGCGTTGCCCACC': 'CL:0000844',
#  'CATAGGGACACTTGTG': 'CL:0000844',
#  'CATAGTACATTGAGAG': 'CL:0000844',
#  'CATAGTAGCATAGTAG': 'CL:0000844',
#  'CATAGTCCACAAGAAC': 'CL:0000584',
#  'CATAGTGGGCACGCCT': 'CL:0000584',
#  'CATATAGGTACAGTCA': 'CL:0000844',
#  'CATCAAACTGGCGCCC': 'CL:0000584',
#  'CATCATCTACCCGGAC': 'CL:0000584',
#  'CATCATTACCCTGAGG': 'CL:0000844',
#  'CATCCGCAGGCCCGAA': 'CL:0000844',
#  'CATCCTCTCAAAGATC': 'CL:0000186',
#  'CATCGCCCGCGGCCAA': 'CL:0000584',
#  'CATCGGACGGGTTAAT': 'CL:0000844',
#  'CATGAACCGACATTTG': 'CL:0000844',
#  'CATGACTTCGCTGAAT': 'CL:0000844',
#  'CATGAGTCCATCACGG': 'CL:0000844',
#  'CATGATACGGTGAAAC': 'CL:0000584',
#  'CATGATCGCTTTGAGA': 'CL:0000584',
#  'CATGATGCACAATTCT': 'CL:0000584',
#  'CATGATGGAAGTTAGC': 'CL:0000844',
#  'CATGCACATGAGAGGC': 'CL:0000844',
#  'CATGCCAACTCGCAAA': 'CL:0000844',
#  'CATGCGACCAGTTTAA': 'CL:0000844',
#  'CATGCGTTAGACAGAA': 'CL:0000844',
#  'CATGCGTTGAGAGGAG': 'CL:0000584',
#  'CATGCTGGCTCCAATT': 'CL:0000584',
#  'CATGGCAGGAAGATCG': 'CL:0000584',
#  'CATGGCTCCCTATGTC': 'CL:0000844',
#  'CATGGGTATGCCTTAT': 'CL:0000186',
#  'CATGGGTCGGGTGTGG': 'CL:0000844',
#  'CATGGTAAGTAGCGTT': 'CL:0000186',
#  'CATGGTATTAGTTTGT': 'CL:0000584',
#  'CATGGTCTAGATACCG': 'CL:0000844',
#  'CATGGTTTATTAATCA': 'CL:0000186',
#  'CATGTAAGAGACATTT': 'CL:0000186',
#  'CATGTCTCATTTATGG': 'CL:0000186',
#  'CATGTGGGCTCATCAC': 'CL:0000844',
#  'CATTACATAGATTGTG': 'CL:0009010',
#  'CATTACGCAGGAAGGG': 'CL:0000584',
#  'CATTACGTCGGCCCGT': 'CL:0000844',
#  'CATTATCCCATTAACG': 'CL:0000844',
#  'CATTATGCTTGTTGTG': 'CL:0000844',
#  'CATTGCGGGTCAATTC': 'CL:0000844',
#  'CATTGTGTGCTAGATC': 'CL:0000844',
#  'CATTTAGCGGACCATG': 'CL:0000844',
#  'CATTTCTAGCAGACTA': 'CL:0000584',
#  'CATTTGAGTGGTACGT': 'CL:0000186',
#  'CCAAACAGAACCCTCG': 'CL:0000844',
#  'CCAAATAACAAGATTC': 'CL:0000844',
#  'CCAAATCAAAGGGCAA': 'CL:0000844',
#  'CCAAGACTTCTGCGAA': 'CL:0000186',
#  'CCAAGGAACAGAGAGG': 'CL:0000844',
#  'CCAATGTCACAGCAAG': 'CL:0000584',
#  'CCAATTACGGGTCGAG': 'CL:0000844',
#  'CCAATTGAATGTTAAT': 'CL:0000584',
#  'CCACAGTACCCATCCT': 'CL:0009010',
#  'CCACCCAAGGAAAGTG': 'CL:0000584',
#  'CCACGGAGCCATAAGA': 'CL:0000844',
#  'CCACGGCAGGTGTAGG': 'CL:0000844',
#  'CCACTCAGATCCGCAA': 'CL:0000844',
#  'CCACTGGTGGCTGGTT': 'CL:0000584',
#  'CCAGAAAGCAACTCAT': 'CL:0000584',
#  'CCAGAGACAAAGCCGG': 'CL:0000844',
#  'CCAGCCTGGACCAATA': 'CL:0000186',
#  'CCAGCTACGCCTCATA': 'CL:0000186',
#  'CCAGCTCGAACGCATT': 'CL:0000844',
#  'CCAGCTTCCGCCCGCA': 'CL:0000844',
#  'CCAGTCCATTATTCGA': 'CL:0000186',
#  'CCAGTCTAGACGGCGC': 'CL:0000186',
#  'CCAGTCTTGTCATAGA': 'CL:0000844',
#  'CCAGTGTACAGACCGA': 'CL:0000844',
#  'CCAGTTCGGTAACTCA': 'CL:0000186',
#  'CCATAAACAACCCGAC': 'CL:0000584',
#  'CCATACCTTTACTTGT': 'CL:0000844',
#  'CCATAGAGGCTGCCAG': 'CL:0000584',
#  'CCATAGGTTGGCGTGG': 'CL:0000584',
#  'CCATATGGAAACTATA': 'CL:0000844',
#  'CCATCCATACCAAGTC': 'CL:0000844',
#  'CCATCGCAGTTAAACT': 'CL:0000844',
#  'CCATCTCACCAGTGAA': 'CL:0000186',
#  'CCATGCCCTAGATTTC': 'CL:0000186',
#  'CCATGCTCTGCAGGAA': 'CL:0000844',
#  'CCATGTTCATCTATAT': 'CL:0000584',
#  'CCATTTCTACCTATTA': 'CL:0000844',
#  'CCCAACATACGTCGCG': 'CL:0000584',
#  'CCCAAGTCATTACACT': 'CL:0000844',
#  'CCCAATGAGATTTGCA': 'CL:0000584',
#  'CCCAGGAAGAATTCGA': 'CL:0000584',
#  'CCCAGGTCTGAAGGCT': 'CL:0000844',
#  'CCCAGTAAACTTGGGA': 'CL:0000844',
#  'CCCAGTTAAGGCGCCG': 'CL:0000844',
#  'CCCATATAGGTCGATT': 'CL:0000844',
#  'CCCATTATTGTATCCT': 'CL:0000584',
#  'CCCGAAGTTTCGCGAA': 'CL:0000844',
#  'CCCGACCATAGTCCGC': 'CL:0000844',
#  'CCCGAGTTTCTCCGTA': 'CL:0000844',
#  'CCCGATAGCCTCGCCT': 'CL:0000584',
#  'CCCGCAGCGCGAACTA': 'CL:0000844',
#  'CCCGCCATGCTCCCGT': 'CL:0000844',
#  'CCCGCGCAATGCACCC': 'CL:0000186',
#  'CCCGGCACGTGTCAGG': 'CL:0000844',
#  'CCCGGGTCGTTCAGGG': 'CL:0009010',
#  'CCCGGTGGAAGAACCT': 'CL:0000584',
#  'CCCGGTGTATCGGAAT': 'CL:0000584',
#  'CCCGTAAGTCTAGGCC': 'CL:0000584',
#  'CCCGTAGCTGGGAAGA': 'CL:0000844',
#  'CCCGTCAGCGTCTGAC': 'CL:0000844',
#  'CCCGTTTCGCAGATGT': 'CL:0000844',
#  'CCCTACCCACACCCAG': 'CL:0000584',
#  'CCCTCAAGCTCTTAGT': 'CL:0000844',
#  'CCCTCAGATCGAGAAC': 'CL:0000844',
#  'CCCTCATTCTGGAATT': 'CL:0000844',
#  'CCCTCCTCGCTCGTAT': 'CL:0000844',
#  'CCCTCGATAATACACA': 'CL:0000844',
#  'CCCTGATGTAACTCGT': 'CL:0000844',
#  'CCCTGCCCAATCCGCT': 'CL:0000584',
#  'CCCTGGGAGGGATCCT': 'CL:0000844',
#  'CCCTTTGACAGGTCTT': 'CL:0000584',
#  'CCGAAACACGACCTCT': 'CL:0000844',
#  'CCGAAAGTGGTGAGCA': 'CL:0000584',
#  'CCGAACCTTCCCGGCC': 'CL:0000584',
#  'CCGAAGCATTGACCAA': 'CL:0000584',
#  'CCGAAGTATATTGTTC': 'CL:0000186',
#  'CCGACAAACACATGAG': 'CL:0000844',
#  'CCGAGAAGTCGCATAA': 'CL:0000844',
#  'CCGATATGACGTAAGG': 'CL:0000844',
#  'CCGATCTCAACCTTAT': 'CL:0000186',
#  'CCGATTCGAGGGACCC': 'CL:0000584',
#  'CCGCACAAAGACCAAC': 'CL:0000844',
#  'CCGCACGTGACCTCGG': 'CL:0000584',
#  'CCGCACTTGCAATGAC': 'CL:0000584',
#  'CCGCATGTGGTACGAT': 'CL:0000584',
#  'CCGCCGGAACTTCTCG': 'CL:0000584',
#  'CCGCCGGTCAACACAC': 'CL:0000844',
#  'CCGCGCAAGATACCCA': 'CL:0000584',
#  'CCGCGGAATGCGTCAC': 'CL:0000186',
#  'CCGCGTAGGTAAGGGC': 'CL:0000844',
#  'CCGCTATCAGCACCAG': 'CL:0000186',
#  'CCGCTCCGGATAAGCT': 'CL:0009010',
#  'CCGCTTACCTCACTCT': 'CL:0000584',
#  'CCGCTTGCTGACATGG': 'CL:0000584',
#  'CCGGAAGTGCAATATG': 'CL:0000844',
#  'CCGGAATGGTTTCAGT': 'CL:0000584',
#  'CCGGAGCGTACTTTCT': 'CL:0000844',
#  'CCGGCCGCGAGCATAT': 'CL:0000844',
#  'CCGGCGCATATTGGAT': 'CL:0000584',
#  'CCGGCGTGAGACTCTG': 'CL:0000584',
#  'CCGGGACCCGCAGAGA': 'CL:0000844',
#  'CCGGGCGGTCTCGTCA': 'CL:0000844',
#  'CCGGGCTAAGAATTTC': 'CL:0000584',
#  'CCGGTATCTGGCGACT': 'CL:0000584',
#  'CCGGTTTGTAATTGTG': 'CL:0000584',
#  'CCGTAAGTTGGTCCCA': 'CL:0000844',
#  'CCGTACCCAAGCGCCA': 'CL:0000844',
#  'CCGTAGGAAATCCCTG': 'CL:0000844',
#  'CCGTCAACCTCTGGCG': 'CL:0009010',
#  'CCGTGCCCATGACGGC': 'CL:0000844',
#  'CCGTGGAACGATCCAA': 'CL:0000844',
#  'CCGTGTTAAATTCCAT': 'CL:0000844',
#  'CCGTTACGTTAGAACA': 'CL:0000584',
#  'CCGTTCCGAATCTCGG': 'CL:0000844',
#  'CCTAAATTAACGGTTC': 'CL:0000186',
#  'CCTAAATTGTATCCTA': 'CL:0000844',
#  'CCTAACCCAAACAAGT': 'CL:0000186',
#  'CCTAACTAAGGCTCTA': 'CL:0000844',
#  'CCTACAGTTGAGGGAG': 'CL:0000844',
#  'CCTACATTCACAGACG': 'CL:0000584',
#  'CCTACGGCTCAGTCGA': 'CL:0000844',
#  'CCTACTCAACACGATT': 'CL:0000844',
#  'CCTACTGCTTACACTT': 'CL:0000584',
#  'CCTAGTTAGTCGCATG': 'CL:0000584',
#  'CCTATAATGAGTGCCC': 'CL:0000186',
#  'CCTATACCGTCCTGTC': 'CL:0000844',
#  'CCTATATCGTGTCACG': 'CL:0000584',
#  'CCTATCTATATCGGAA': 'CL:0000844',
#  'CCTATGAAGTGGTGCC': 'CL:0000186',
#  'CCTATGGGTTACCGTC': 'CL:0000584',
#  'CCTATGTCCACTCCAC': 'CL:0000584',
#  'CCTATTATTCCGGCCG': 'CL:0000584',
#  'CCTCACCTGAGGGAGC': 'CL:0000844',
#  'CCTCACCTTAGCATCG': 'CL:0000584',
#  'CCTCACGTCAGCTAAT': 'CL:0000844',
#  'CCTCATGCAGCTACGA': 'CL:0000186',
#  'CCTCCTAGCTAGAGTC': 'CL:0000844',
#  'CCTCCTGTTGTGTCGT': 'CL:0000844',
#  'CCTCGCCAGCAAATTA': 'CL:0000584',
#  'CCTCGCGCGATATAGG': 'CL:0000844',
#  'CCTCGCGCTGTGCGAT': 'CL:0000844',
#  'CCTCGGACCGGGATAG': 'CL:0000844',
#  'CCTCGGTTTCCTTGCC': 'CL:0000584',
#  'CCTCTAATCTGCCAAG': 'CL:0000844',
#  'CCTCTACAAGGATTGG': 'CL:0000584',
#  'CCTCTGTACTATTCTA': 'CL:0000844',
#  'CCTGACAAACTCGCGC': 'CL:0000584',
#  'CCTGACCACCGATGGT': 'CL:0000844',
#  'CCTGAGAATAAATGCA': 'CL:0000844',
#  'CCTGATTCGCGAAGAA': 'CL:0000844',
#  'CCTGCTACAACCATAC': 'CL:0000844',
#  'CCTGCTATTTGAGAAG': 'CL:0000584',
#  'CCTGGTCGAATGTGGG': 'CL:0000844',
#  'CCTGTACTCACGCCCA': 'CL:0000584',
#  'CCTGTCACCCGGGCTC': 'CL:0000186',
#  'CCTGTCGCCCGTAAAT': 'CL:0000844',
#  'CCTGTTCAACCTCGGG': 'CL:0009010',
#  'CCTGTTTGAAGACACG': 'CL:0000186',
#  'CCTTAAGTACGCAATT': 'CL:0009010',
#  'CCTTCCGCAACGCTGC': 'CL:0000584',
#  'CCTTCGTATAGAATCC': 'CL:0000844',
#  'CCTTCTTGATCCAGTG': 'CL:0000584',
#  'CCTTGACCACTTTATT': 'CL:0000844',
#  'CCTTGTGAACGTGGTT': 'CL:0000584',
#  'CCTTTCAATGAAGAAA': 'CL:0000584',
#  'CCTTTGAATTATGGCT': 'CL:0000844',
#  'CGAACAGTATGGGCGT': 'CL:0000186',
#  'CGAACCCGCATGCGTC': 'CL:0000844',
#  'CGAACCTCTTTCCTAG': 'CL:0000844',
#  'CGAACGGCCGGACAAC': 'CL:0000844',
#  'CGAAGATCAGTTTCAT': 'CL:0000584',
#  'CGAAGGGTTTCAGATT': 'CL:0000844',
#  'CGAATGACGCATAATG': 'CL:0009010',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              127
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             2035
# AAACAATCTACTAGCA-1        1.0        3.0        3.0              247
# AAACACCAATAACTGC-1        1.0       59.0       59.0             2624
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3390
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              192
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             2537
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              946
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0              151
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                        NaN
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                        NaN
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                        NaN
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                 CL:0000844
# TTGTTTGTATTACACG-1                 CL:0000844
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 2318

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_49030/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              127
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             2035
# AAACAATCTACTAGCA-1        1.0        3.0        3.0              247
# AAACACCAATAACTGC-1        1.0       59.0       59.0             2624
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3390
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              192
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             2537
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              946
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0              151
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                    unknown
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                    unknown
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                    unknown
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                 CL:0000844
# TTGTTTGTATTACACG-1                 CL:0000844
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000844',
#  'CL:0000584',
#  'CL:0000186',
#  'CL:0009010',
#  'CL:0000034',
#  'CL:0000057',
#  'CL:0007011',
#  'CL:0000775',
#  'CL:0000066']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    2B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1    2B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1    2B_Hh.anti_IL10r
# AAACACCAATAACTGC-1    2B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1    2B_Hh.anti_IL10r
#                             ...
# TTGTTTCACATCCAGG-1    2B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1    2B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1    2B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1    2B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1    2B_Hh.anti_IL10r
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['2B_Hh.anti_IL10r']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              127
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             2035
# AAACAATCTACTAGCA-1        1.0        3.0        3.0              247
# AAACACCAATAACTGC-1        1.0       59.0       59.0             2624
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3390
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              192
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             2537
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              946
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0              151
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  2B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                    unknown  2B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                    unknown  2B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                    unknown  2B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  2B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                    unknown  2B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                    unknown  2B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000844  2B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                 CL:0000844  2B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                    unknown  2B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255056_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'lowres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'tissue_lowres_scalef': 0.019862289,
#                  'fiducial_diameter_fullres': 240.3325285639895,
#                  'spot_diameter_fullres': 148.7772795872316}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255056_mm10-2020-A/V12Y31-030_D1.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '2B_Hh.anti_IL10r'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255056_mm10-2020-A': {'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'fullres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 148.7772795872316}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '2B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0              127
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             2035
# AAACAATCTACTAGCA-1        1.0        3.0        3.0              247
# AAACACCAATAACTGC-1        1.0       59.0       59.0             2624
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0             3390
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              192
# TTGTTTCCATACAACT-1        1.0       45.0       45.0             2537
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              946
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0              151
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  2B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                    unknown  2B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                    unknown  2B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                    unknown  2B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  2B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                    unknown  2B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                    unknown  2B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                 CL:0000844  2B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                 CL:0000844  2B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                    unknown  2B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255056_mm10-2020-A': {'images': {'hires': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8),
#                  'fullres': array([[[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         ...,
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]],
#
#                         [[227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          ...,
#                          [227, 224, 225],
#                          [227, 224, 225],
#                          [227, 224, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 148.7772795872316}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '2B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_49030/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13255056.h5ad', compression = 'gzip')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0          0              127
# AAACAAGTATCTCCCA-1          1         50         50             2035
# AAACAATCTACTAGCA-1          1          3          3              247
# AAACACCAATAACTGC-1          1         59         59             2624
# AAACAGAGCGACTCCT-1          1         14         14              191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         58             3390
# TTGTTTCATTAGTCTA-1          1         60         60              192
# TTGTTTCCATACAACT-1          1         45         45             2537
# TTGTTTGTATTACACG-1          1         73         73              946
# TTGTTTGTGTAAATTC-1          1          7          7              151
#
#                    assay_ontology_term_id cell_type_ontology_term_id  \
# AAACAACGAATAGTTC-1            EFO:0010961                    unknown
# AAACAAGTATCTCCCA-1            EFO:0010961                    unknown
# AAACAATCTACTAGCA-1            EFO:0010961                    unknown
# AAACACCAATAACTGC-1            EFO:0010961                    unknown
# AAACAGAGCGACTCCT-1            EFO:0010961                    unknown
# ...                                   ...                        ...
# TTGTTTCACATCCAGG-1            EFO:0010961                    unknown
# TTGTTTCATTAGTCTA-1            EFO:0010961                    unknown
# TTGTTTCCATACAACT-1            EFO:0010961                 CL:0000844
# TTGTTTGTATTACACG-1            EFO:0010961                 CL:0000844
# TTGTTTGTGTAAATTC-1            EFO:0010961                    unknown
#
#                             donor_id development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAAGTATCTCCCA-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAATCTACTAGCA-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# AAACACCAATAACTGC-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# AAACAGAGCGACTCCT-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# ...                              ...                                ...
# TTGTTTCACATCCAGG-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTCCATACAACT-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTATTACACG-1  2B_Hh.anti_IL10r                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1  2B_Hh.anti_IL10r                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 16 columns]

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)
# Out:
# Missing columns: []

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
# Out:
# Data Types:
# array_col    int64
# array_row    int64
# in_tissue    int64
# dtype: object
#
# Missing Values:
# array_col    0
# array_row    0
# in_tissue    0
# dtype: int64

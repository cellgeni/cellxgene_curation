# %% [markdown]
# ### **Curating visium_slide5.h5ad**

# %% [markdown]
# Article:   A human embryonic limb cell atlas resolved in space and time

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-023-06806-x

# %% [markdown]
# Data Source : https://developmental.cellatlas.io/embryonic-limb

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/nfs/team205/ph12/190308Hongbohindlimb/210124LizVisium/WSSS_THYst9699523/outs'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['ACCTACAGTATGTGGT-1', 'AGAAGAGCGCCGTTCC-1']

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'in_tissue']

print("Value of 'in_tissue' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'in_tissue' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
cell_name = 'AGAAGAGCGCCGTTCC-1'

# Check the value of 'in_tissue' for the specified cell
in_tissue_value = adata.obs.loc[cell_name, 'non_zero_counts']

print("Value of 'non_zero_counts' for cell '{}': {}".format(cell_name, in_tissue_value))
# Out:
# Value of 'non_zero_counts' for cell 'AGAAGAGCGCCGTTCC-1': 0

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + '/spatial/tissue_positions_list.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 33694
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x33694 sparse matrix of type '<class 'numpy.float32'>'
# 	with 6908330 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 26)	1.0
#   (0, 52)	1.0
#   (0, 474)	1.0
#   (0, 640)	1.0
#   (0, 674)	1.0
#   (0, 694)	1.0
#   (0, 741)	1.0
#   (0, 771)	1.0
#   (0, 808)	1.0
#   (0, 942)	1.0
#   (0, 1114)	1.0
#   (0, 1289)	1.0
#   (0, 1476)	1.0
#   (0, 1493)	1.0
#   (0, 1549)	1.0
#   (0, 1688)	1.0
#   (0, 1784)	1.0
#   (0, 1790)	1.0
#   (0, 1915)	1.0
#   (0, 1933)	2.0
#   (0, 1959)	1.0
#   (0, 2042)	1.0
#   (0, 2176)	1.0
#   (0, 2219)	1.0
#   (0, 2288)	1.0
#   :	:
#   (4991, 33433)	2.0
#   (4991, 33440)	1.0
#   (4991, 33465)	2.0
#   (4991, 33475)	1.0
#   (4991, 33480)	7.0
#   (4991, 33550)	1.0
#   (4991, 33556)	1.0
#   (4991, 33568)	1.0
#   (4991, 33598)	1.0
#   (4991, 33600)	1.0
#   (4991, 33601)	1.0
#   (4991, 33621)	1.0
#   (4991, 33630)	2.0
#   (4991, 33635)	1.0
#   (4991, 33651)	1.0
#   (4991, 33652)	1.0
#   (4991, 33653)	2.0
#   (4991, 33654)	13.0
#   (4991, 33655)	8.0
#   (4991, 33657)	7.0
#   (4991, 33658)	18.0
#   (4991, 33659)	2.0
#   (4991, 33661)	5.0
#   (4991, 33662)	2.0
#   (4991, 33664)	6.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                      gene_ids    feature_types  genome
# RP11-34P13.3  ENSG00000243485  Gene Expression  GRCh38
# FAM138A       ENSG00000237613  Gene Expression  GRCh38
# OR4F5         ENSG00000186092  Gene Expression  GRCh38
# RP11-34P13.7  ENSG00000238009  Gene Expression  GRCh38
# RP11-34P13.8  ENSG00000239945  Gene Expression  GRCh38
# ...                       ...              ...     ...
# AC233755.2    ENSG00000277856  Gene Expression  GRCh38
# AC233755.1    ENSG00000275063  Gene Expression  GRCh38
# AC240274.1    ENSG00000271254  Gene Expression  GRCh38
# AC213203.1    ENSG00000277475  Gene Expression  GRCh38
# FAM231B       ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                    feature_types  genome
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38
# ENSG00000237613  Gene Expression  GRCh38
# ENSG00000186092  Gene Expression  GRCh38
# ENSG00000238009  Gene Expression  GRCh38
# ENSG00000239945  Gene Expression  GRCh38
# ...                          ...     ...
# ENSG00000277856  Gene Expression  GRCh38
# ENSG00000275063  Gene Expression  GRCh38
# ENSG00000271254  Gene Expression  GRCh38
# ENSG00000277475  Gene Expression  GRCh38
# ENSG00000268674  Gene Expression  GRCh38
#
# [33694 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                    feature_types  genome  feature_is_filtered
# gene_ids
# ENSG00000243485  Gene Expression  GRCh38                False
# ENSG00000237613  Gene Expression  GRCh38                False
# ENSG00000186092  Gene Expression  GRCh38                False
# ENSG00000238009  Gene Expression  GRCh38                False
# ENSG00000239945  Gene Expression  GRCh38                False
# ...                          ...     ...                  ...
# ENSG00000277856  Gene Expression  GRCh38                False
# ENSG00000275063  Gene Expression  GRCh38                False
# ENSG00000271254  Gene Expression  GRCh38                False
# ENSG00000277475  Gene Expression  GRCh38                False
# ENSG00000268674  Gene Expression  GRCh38                False
#
# [32831 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1          0          0         16              316
# AAACAAGTATCTCCCA-1          0         50        102             2714
# AAACAATCTACTAGCA-1          0          3         43             2126
# AAACACCAATAACTGC-1          0         59         19              807
# AAACAGAGCGACTCCT-1          1         14         94             5191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4909
# TTGTTTCATTAGTCTA-1          0         60         30             2546
# TTGTTTCCATACAACT-1          0         45         27              152
# TTGTTTGTATTACACG-1          0         73         41               79
# TTGTTTGTGTAAATTC-1          0          7         51             2242
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/spatial_h5ad_final_objects/visium_slide5.h5ad')

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523          1           0.0        0.011579
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523          1           0.0        0.000202
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523          1           0.0        0.005411
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523          1           0.0        0.000038
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523          1           0.0        0.044575
# ...                                         ...           ...             ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523          1           0.0        0.000437
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523          1           0.0        0.000806
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523          1           0.0        0.000133
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523          1           0.0        0.004647
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523          1           0.0        0.000050
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523        0.004852           0.938012
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523        0.000515           0.000048
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523        0.008158           0.002846
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523        3.154694           0.000008
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523        0.002330           0.000089
# ...                                              ...                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523        0.001112           0.000048
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523        0.000870           0.017527
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523        0.000352           0.000125
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523        0.002732           0.110262
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523        0.005145           0.041950
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523       0.037083  0.002034    0.002604
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523       0.023470  0.033397    0.001511
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523       0.006513  0.003317    0.005920
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523       0.000253  0.000445    0.700221
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523       0.000199  0.002312    0.001294
# ...                                             ...       ...         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523       0.330041  0.099735    0.001560
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523       0.060876  0.079082    0.000976
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523       0.044493  0.016182    0.000381
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523       0.007000  0.048923    0.001592
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523       0.000452  0.026231    0.001187
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523      0.001818          0.005950  ...
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523      0.000989          0.724933  ...
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523      0.013023          0.338732  ...
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523      0.000158          0.000481  ...
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523      0.000417          0.001239  ...
# ...                                            ...               ...  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523      0.004697          2.005553  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523      0.002340          1.811632  ...
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523      0.001765          5.573963  ...
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523      0.034065          0.013572  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523      0.000173          0.000517  ...
#
#                                        stage  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523  PCW7.0
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523  PCW7.0
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523  PCW7.0
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523  PCW7.0
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523  PCW7.0
# ...                                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523  PCW7.0
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523  PCW7.0
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523  PCW7.0
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523  PCW7.0
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523  PCW7.0
#
#                                       development_stage_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523                      HsapDv:0000026
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523                      HsapDv:0000026
# ...                                                                  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523                      HsapDv:0000026
#
#                                       disease_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523              PATO:0000461
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523              PATO:0000461
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523              PATO:0000461
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523              PATO:0000461
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523              PATO:0000461
# ...                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523              PATO:0000461
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523              PATO:0000461
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523              PATO:0000461
#
#                                       is_primary_data  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523             True
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523             True
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523             True
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523             True
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523             True
# ...                                               ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523             True
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523             True
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523             True
#
#                                       organism_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523             NCBITaxon:9606
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523             NCBITaxon:9606
# ...                                                         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523                                   unknown
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523                                   unknown
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523                                   unknown
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523                                   unknown
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523                                   unknown
# ...                                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523                                   unknown
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523                                   unknown
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523          PATO:0000384               na
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523       tissue           UBERON:0000978
#
# [996 rows x 82 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'percent_mito', 'C2L: ADH+Fibro', 'C2L: AER-Basal',
#        'C2L: ArterialEndo', 'C2L: ArtiChon', 'C2L: B', 'C2L: Basal',
#        'C2L: CMP/GMP', 'C2L: ChondroProg', 'C2L: DC2', 'C2L: DefErythro',
#        'C2L: DefReticulo', 'C2L: DermFibro', 'C2L: DistalMes',
#        'C2L: F10+DermFibroProg', 'C2L: HOXC5+DermFibroProg', 'C2L: HyperChon',
#        'C2L: ISL1+Mes', 'C2L: InterMusFibro', 'C2L: InterZone',
#        'C2L: LMPP/ELP', 'C2L: LymphEndo', 'C2L: MFAP5+Fibro', 'C2L: MYH3+MyoC',
#        'C2L: MYL3+MyoC', 'C2L: Macro', 'C2L: Mast', 'C2L: Megakaryo',
#        'C2L: Melano', 'C2L: Mes1', 'C2L: Mes2', 'C2L: Mes3', 'C2L: Mes4',
#        'C2L: MesCond', 'C2L: Monocyte', 'C2L: Myelocyte', 'C2L: MyoB1',
#        'C2L: MyoB2', 'C2L: MyoC1', 'C2L: MyoC2', 'C2L: NK', 'C2L: NeuralFibro',
#        'C2L: Neuronal', 'C2L: OCP', 'C2L: OsteoB', 'C2L: PAX3+MyoProg',
#        'C2L: PAX7+MyoProg', 'C2L: Perichon', 'C2L: Pericyte', 'C2L: Periderm',
#        'C2L: Perimysium', 'C2L: PrehyperChon', 'C2L: PrimErythro1',
#        'C2L: PrimErythro2', 'C2L: ProlifChon', 'C2L: ProxMes',
#        'C2L: RDH10+DistalMes', 'C2L: RestingChon', 'C2L: SMC', 'C2L: SMProg',
#        'C2L: STMN2+Fibro', 'C2L: Schwann', 'C2L: SchwannProg',
#        'C2L: SynapSchwann', 'C2L: Teno', 'C2L: TenoProg', 'C2L: TransMes',
#        'C2L: VenousEndo', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'donor_id', 'stage',
#        'development_stage_ontology_term_id', 'disease_ontology_term_id',
#        'is_primary_data', 'organism_ontology_term_id',
#        'self_reported_ethnicity_ontology_term_id', 'sex_ontology_term_id',
#        'suspension_type', 'tissue_type', 'tissue_ontology_term_id'],
#       dtype='object')

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                       in_tissue  percent_mito  C2L: ADH+Fibro  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523          1           0.0        0.011579
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523          1           0.0        0.000202
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523          1           0.0        0.005411
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523          1           0.0        0.000038
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523          1           0.0        0.044575
# ...                                         ...           ...             ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523          1           0.0        0.000437
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523          1           0.0        0.000806
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523          1           0.0        0.000133
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523          1           0.0        0.004647
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523          1           0.0        0.000050
#
#                                       C2L: AER-Basal  C2L: ArterialEndo  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523        0.004852           0.938012
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523        0.000515           0.000048
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523        0.008158           0.002846
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523        3.154694           0.000008
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523        0.002330           0.000089
# ...                                              ...                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523        0.001112           0.000048
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523        0.000870           0.017527
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523        0.000352           0.000125
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523        0.002732           0.110262
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523        0.005145           0.041950
#
#                                       C2L: ArtiChon    C2L: B  C2L: Basal  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523       0.037083  0.002034    0.002604
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523       0.023470  0.033397    0.001511
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523       0.006513  0.003317    0.005920
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523       0.000253  0.000445    0.700221
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523       0.000199  0.002312    0.001294
# ...                                             ...       ...         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523       0.330041  0.099735    0.001560
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523       0.060876  0.079082    0.000976
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523       0.044493  0.016182    0.000381
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523       0.007000  0.048923    0.001592
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523       0.000452  0.026231    0.001187
#
#                                       C2L: CMP/GMP  C2L: ChondroProg  ...  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523      0.001818          0.005950  ...
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523      0.000989          0.724933  ...
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523      0.013023          0.338732  ...
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523      0.000158          0.000481  ...
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523      0.000417          0.001239  ...
# ...                                            ...               ...  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523      0.004697          2.005553  ...
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523      0.002340          1.811632  ...
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523      0.001765          5.573963  ...
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523      0.034065          0.013572  ...
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523      0.000173          0.000517  ...
#
#                                       development_stage_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523                      HsapDv:0000026
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523                      HsapDv:0000026
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523                      HsapDv:0000026
# ...                                                                  ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523                      HsapDv:0000026
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523                      HsapDv:0000026
#
#                                       disease_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523              PATO:0000461
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523              PATO:0000461
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523              PATO:0000461
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523              PATO:0000461
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523              PATO:0000461
# ...                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523              PATO:0000461
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523              PATO:0000461
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523              PATO:0000461
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523              PATO:0000461
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523              PATO:0000461
#
#                                       is_primary_data  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523             True
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523             True
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523             True
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523             True
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523             True
# ...                                               ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523             True
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523             True
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523             True
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523             True
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523             True
#
#                                       organism_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523             NCBITaxon:9606
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523             NCBITaxon:9606
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523             NCBITaxon:9606
# ...                                                         ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523             NCBITaxon:9606
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523             NCBITaxon:9606
#
#                                       self_reported_ethnicity_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523                                   unknown
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523                                   unknown
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523                                   unknown
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523                                   unknown
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523                                   unknown
# ...                                                                        ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523                                   unknown
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523                                   unknown
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523                                   unknown
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523                                   unknown
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523                                   unknown
#
#                                       sex_ontology_term_id  suspension_type  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523          PATO:0000384               na
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523          PATO:0000384               na
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523          PATO:0000384               na
# ...                                                    ...              ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523          PATO:0000384               na
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523          PATO:0000384               na
#
#                                       tissue_type  tissue_ontology_term_id  \
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# ...                                           ...                      ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523       tissue           UBERON:0000978
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523       tissue           UBERON:0000978
#
#                                               barcodes
# AAACAGAGCGACTCCT-1_WSSS_THYst9699523  AAACAGAGCGACTCCT
# AAACCGTTCGTCCAGG-1_WSSS_THYst9699523  AAACCGTTCGTCCAGG
# AAAGACCCAAGTCGCG-1_WSSS_THYst9699523  AAAGACCCAAGTCGCG
# AAAGGCTACGGACCAT-1_WSSS_THYst9699523  AAAGGCTACGGACCAT
# AAAGGCTCTCGCGCCG-1_WSSS_THYst9699523  AAAGGCTCTCGCGCCG
# ...                                                ...
# TTGTGGCCCTGACAGT-1_WSSS_THYst9699523  TTGTGGCCCTGACAGT
# TTGTGTATGCCACCAA-1_WSSS_THYst9699523  TTGTGTATGCCACCAA
# TTGTGTTTCCCGAAAG-1_WSSS_THYst9699523  TTGTGTTTCCCGAAAG
# TTGTTAGCAAATTCGA-1_WSSS_THYst9699523  TTGTTAGCAAATTCGA
# TTGTTTCACATCCAGG-1_WSSS_THYst9699523  TTGTTTCACATCCAGG
#
# [996 rows x 83 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAGAGCGACTCCT': 'CL:0002551',
#  'AAACCGTTCGTCCAGG': 'CL:0008019',
#  'AAAGACCCAAGTCGCG': 'CL:0002551',
#  'AAAGGCTACGGACCAT': 'CL:0008019',
#  'AAAGGCTCTCGCGCCG': 'CL:0000515',
#  'AAAGGGCAGCTTGAAT': 'CL:0000138',
#  'AAAGTCACTGATGTAA': 'CL:0002551',
#  'AAATAACCATACGGGA': 'CL:0008019',
#  'AAATACCTATAAGCAT': 'CL:0008019',
#  'AAATAGGGTGCTATTG': 'CL:0008019',
#  'AAATCTAGCCCTGCTA': 'CL:0000138',
#  'AAATGGCATGTCTTGT': 'CL:0000058',
#  'AAATTACACGACTCTG': 'CL:0008019',
#  'AACAACTGGTAGTTGC': 'CL:0008019',
#  'AACACACGCTCGCCGC': 'CL:0008019',
#  'AACACGACTGTACTGA': 'CL:0002551',
#  'AACAGGAAATCGAATA': 'CL:0000138',
#  'AACAGGATGGGCCGCG': 'CL:0000646',
#  'AACCCAGAGACGGAGA': 'CL:0000138',
#  'AACCCGAGCAGAATCG': 'CL:0000138',
#  'AACCCTGGTGGAACCA': 'CL:0000187',
#  'AACCGTTGTGTTTGCT': 'CL:0008019',
#  'AACCTTTAAATACGGT': 'CL:0000138',
#  'AACCTTTACGACGTCT': 'CL:0000057',
#  'AACGATAATGCCGTAG': 'CL:0000138',
#  'AACGATAGAAGGGCCG': 'CL:0008019',
#  'AACGCTGTTGCTGAAA': 'CL:0000138',
#  'AACGGACGTACGTATA': 'CL:0002573',
#  'AACGTCAGACTAGTGG': 'CL:0008019',
#  'AACGTGATGAAGGACA': 'CL:0000138',
#  'AACTAGGCTTGGGTGT': 'CL:0000138',
#  'AACTCCTAATCCCATG': 'CL:0000138',
#  'AACTCTCAGTGTGCTC': 'CL:0008019',
#  'AACTGATATTAGGCCT': 'CL:0000138',
#  'AACTGGGTCCCGACGT': 'CL:0002355',
#  'AAGACCCAACTGAACA': 'CL:0008019',
#  'AAGAGATGAATCGGTA': 'CL:0008019',
#  'AAGAGGCCCTTTGGAA': 'CL:0000138',
#  'AAGCATACTCTCCTGA': 'CL:0000138',
#  'AAGCGTCCCTCATCGA': 'CL:0008019',
#  'AAGCTAGATCGAGTAA': 'CL:0008019',
#  'AAGCTCTTTCATGGTG': 'CL:0002551',
#  'AAGGAGCGGTTGGTGC': 'CL:0008019',
#  'AAGGCGCGTAAAGCTT': 'CL:0000138',
#  'AAGTAGAAGACCGGGT': 'CL:0000138',
#  'AAGTGTTTGGAGACGG': 'CL:0008019',
#  'AAGTTCACTCCAAGCT': 'CL:0002551',
#  'AATAACACTAGAACAA': 'CL:0008019',
#  'AATAGAACAGAGTGGC': 'CL:0000138',
#  'AATAGAATCTGTTTCA': 'CL:0000187',
#  'AATAGTCCGTCCCGAC': 'CL:0008019',
#  'AATCATGTAAAGACTC': 'CL:0000138',
#  'AATCCAAGGGCCTGAG': 'CL:0000187',
#  'AATCGGGACACTACGA': 'CL:0002551',
#  'AATGACTGTCAGCCGG': 'CL:0008019',
#  'AATGGTTCTCACAAGC': 'CL:0000138',
#  'AATTAACGGATTTCCA': 'CL:0000138',
#  'AATTAGCGCTGCAGCG': 'CL:0000138',
#  'AATTCTAGAGTTAGGC': 'CL:0000138',
#  'AATTTGGGACATAGTA': 'CL:0000138',
#  'AATTTGGTTCCAAAGA': 'CL:0000187',
#  'ACAAATCGCACCGAAT': 'CL:0000138',
#  'ACAACGGTCCCTGCGA': 'CL:0008019',
#  'ACAAGGAAATCCGCCC': 'CL:0008019',
#  'ACAATTGTGTCTCTTT': 'CL:0000138',
#  'ACACACTTTCTACACG': 'CL:0008019',
#  'ACACCCAGCATGCAGC': 'CL:0008019',
#  'ACACCCGAGAAATCCG': 'CL:0000138',
#  'ACACCTTAAGTAGGGC': 'CL:0000138',
#  'ACACGGCACTATGCAT': 'CL:0002551',
#  'ACACGTAGGCCACAAG': 'CL:0000138',
#  'ACACTGATCAAGGTGT': 'CL:0000138',
#  'ACAGCATAGAGCCAGT': 'CL:0008019',
#  'ACAGCGACATTCTCAT': 'CL:0002551',
#  'ACAGCGCACCCGCAGC': 'CL:0000138',
#  'ACAGGCTTGCCCGACT': 'CL:0000058',
#  'ACAGGTGGAGGTGAGG': 'CL:0008019',
#  'ACATAATAAGGCGGTG': 'CL:0002355',
#  'ACATCCCGGCCATACG': 'CL:0000138',
#  'ACATCGTTAACCTAGT': 'CL:0008019',
#  'ACATTAGTTTATATCC': 'CL:0000138',
#  'ACCAACGCTTATTTAT': 'CL:0000138',
#  'ACCAAGAACGCGTGTC': 'CL:0000138',
#  'ACCAATATGCAAGTTA': 'CL:0000138',
#  'ACCCACCTACATGCTC': 'CL:0000138',
#  'ACCCGGAAACTCCCAG': 'CL:0000138',
#  'ACCCGTGTCATCAGTA': 'CL:0008019',
#  'ACCCTATGCCATATCG': 'CL:0008019',
#  'ACCCTCCCTTGCTATT': 'CL:0008019',
#  'ACCCTTCATCTGCGAA': 'CL:0008019',
#  'ACCGAAAGGGCCCTGC': 'CL:0002551',
#  'ACCGCAATAACTGCCT': 'CL:0008019',
#  'ACCTCCGCCCTCGCTG': 'CL:0008019',
#  'ACGAGATATTTGCTTA': 'CL:0008019',
#  'ACGATGGATCCGATGC': 'CL:0000187',
#  'ACGCATACGTTTACTA': 'CL:0000138',
#  'ACGCCAGATGATTTCT': 'CL:0008019',
#  'ACGCGAAGTCAGACGA': 'CL:0000138',
#  'ACGGATGGTGCGGATA': 'CL:0002551',
#  'ACGGCACTTGCTTGGG': 'CL:0000138',
#  'ACGGCCAACATGGACT': 'CL:0000138',
#  'ACGGCGACGATGGGAA': 'CL:0008019',
#  'ACGTACAGATTTCTCT': 'CL:0000187',
#  'ACGTGCGCCTCGTGCA': 'CL:0000138',
#  'ACGTTTAGTTGTGATC': 'CL:0000058',
#  'ACTACCAGCTCTCTGG': 'CL:0008019',
#  'ACTACGCGTTAGAATT': 'CL:0008019',
#  'ACTATCTGCCCGCGTA': 'CL:0002551',
#  'ACTATTCGTCCGTGGT': 'CL:0000138',
#  'ACTCCCTAATGCTAAA': 'CL:0000138',
#  'ACTCCCTAGAATAGTA': 'CL:0008019',
#  'ACTGAAACGCCGTTAG': 'CL:0002551',
#  'ACTGAATGGCGAAAGT': 'CL:0002551',
#  'ACTGCCGTCGTAACTC': 'CL:0000138',
#  'ACTGTAGCACTTTGGA': 'CL:0008019',
#  'ACTTACCGGGCGCGCA': 'CL:0002551',
#  'ACTTAGTACGACAAGA': 'CL:0002551',
#  'ACTTCAGGCTGATCCC': 'CL:0008019',
#  'ACTTGTGGATGGAACG': 'CL:0000138',
#  'AGAAATTATGACTCGC': 'CL:0002551',
#  'AGACCATGGGATACAA': 'CL:0008019',
#  'AGACCCACCGCTGATC': 'CL:0000138',
#  'AGACGAAGTGCCGGTC': 'CL:0000388',
#  'AGACGACGATGCCGCT': 'CL:0008019',
#  'AGACTAGCCTTCCAGA': 'CL:0008019',
#  'AGAGCCGCCGAGATTT': 'CL:0002551',
#  'AGAGCGGGCTAATCAT': 'CL:0000138',
#  'AGAGCGTACAAGCTCG': 'CL:0000138',
#  'AGAGGCTTCGGAAACC': 'CL:0000138',
#  'AGATACGACTTCATAT': 'CL:0008019',
#  'AGATGACTCGCCCACG': 'CL:0000138',
#  'AGATGAGGGTTGCGAT': 'CL:0002551',
#  'AGCACTACCTCACCAG': 'CL:0008019',
#  'AGCAGCCAGATGAATA': 'CL:0000138',
#  'AGCATATCAATATGCT': 'CL:0000138',
#  'AGCATCGTCGATAATT': 'CL:0008019',
#  'AGCCCTAAGCGAAGTT': 'CL:0000138',
#  'AGCGACAGGAACGGTC': 'CL:0008019',
#  'AGCGACATCCCATTCA': 'CL:0008019',
#  'AGCGCATAATGAATCG': 'CL:0000138',
#  'AGCGGGAAGGGTCCAT': 'CL:0008019',
#  'AGCTATTTAATCCAAC': 'CL:0000058',
#  'AGCTCCATATATGTTC': 'CL:0008019',
#  'AGCTCCTTCGCACATC': 'CL:0008019',
#  'AGCTCTTCCCAGTGCA': 'CL:0002551',
#  'AGGACATCGCACGTCG': 'CL:0000138',
#  'AGGAGGCCTTCGCGCG': 'CL:0000138',
#  'AGGATAAAGTCGGGAT': 'CL:0000138',
#  'AGGCACGTGACTGTCC': 'CL:0002551',
#  'AGGCAGGGAGCGTACT': 'CL:0008019',
#  'AGGCCACCCGTTATGA': 'CL:0008019',
#  'AGGCCCATTGTACAGG': 'CL:0008019',
#  'AGGCTATGGTTAGCTT': 'CL:0008019',
#  'AGGCTTCCCGAAGAAG': 'CL:0008019',
#  'AGGGAAACGAGGTACT': 'CL:0000138',
#  'AGGGACTCTACGCGAC': 'CL:0008019',
#  'AGGGCAGCGGCGTGGT': 'CL:0000187',
#  'AGGGCGTGATCGGCTA': 'CL:0008019',
#  'AGGTAACCTCCTATTC': 'CL:0008019',
#  'AGGTACGATATTGCCA': 'CL:0000138',
#  'AGTAATGTCTTGCCGC': 'CL:0008019',
#  'AGTACTCTTATGCCCA': 'CL:0000058',
#  'AGTAGGAAGGAAGTTG': 'CL:0002551',
#  'AGTAGGTAACATACAT': 'CL:0000187',
#  'AGTATAATACTAGGCA': 'CL:0008019',
#  'AGTATTTGGCACGACC': 'CL:0008019',
#  'AGTCAAGATGACACTT': 'CL:0008019',
#  'AGTCACTAGCTCTCGA': 'CL:0000138',
#  'AGTCCCGCCTTTAATT': 'CL:0002551',
#  'AGTCGGCCCAAACGAC': 'CL:0000138',
#  'AGTCGTCGACCACCAA': 'CL:0002355',
#  'AGTGCACGCTTAAGAA': 'CL:0000138',
#  'AGTGTATTGCGCATTG': 'CL:0002551',
#  'AGTTAAGCGGTCCCGG': 'CL:0002551',
#  'AGTTACTCTATCGTGG': 'CL:0000138',
#  'AGTTTCGCAGGTCGGA': 'CL:0008019',
#  'AGTTTGCACCTGCCTC': 'CL:0002551',
#  'ATAAACGGACCCGTAA': 'CL:0000187',
#  'ATAAACGTTGCACCAC': 'CL:0008019',
#  'ATAAGGTGGAGAACAT': 'CL:0008019',
#  'ATAAGTTACCGCGACG': 'CL:0002551',
#  'ATAATAGCTGTTGAAT': 'CL:0000187',
#  'ATAATAGTGTAGGGAC': 'CL:0008019',
#  'ATACAGGCCCTCCAAT': 'CL:0000138',
#  'ATACCAGGCTAATAGA': 'CL:0002551',
#  'ATACCTAACCAAGAAA': 'CL:0000138',
#  'ATACGTACTTAGCCAC': 'CL:0008019',
#  'ATACTACCCGTACCAC': 'CL:0008019',
#  'ATACTAGCATGACCCT': 'CL:0002551',
#  'ATAGAGTACTGGGACA': 'CL:0008019',
#  'ATAGGGATATCCTTGA': 'CL:0002355',
#  'ATATAAAGCGCTCGTG': 'CL:0000138',
#  'ATATAAATGTAGCTGC': 'CL:0000138',
#  'ATATACGCTCGTGACG': 'CL:0002551',
#  'ATATTCCACATAGTGA': 'CL:0008019',
#  'ATATTCCCACAGGTCA': 'CL:0008019',
#  'ATATTGCTGTCAAAGT': 'CL:0008019',
#  'ATCACTTCATCCTCGC': 'CL:0002355',
#  'ATCAGCCTCATGCTGC': 'CL:0002551',
#  'ATCCAACGCAGTCATA': 'CL:0008019',
#  'ATCCAGAGCAACAACC': 'CL:0000138',
#  'ATCGGAGACAGACGGC': 'CL:0000138',
#  'ATCGTTAGCTAGCGGA': 'CL:0002551',
#  'ATCGTTCACTTTCGCC': 'CL:0002551',
#  'ATCTAATATCCTACGG': 'CL:0000138',
#  'ATCTCCCACGGAATAT': 'CL:0002551',
#  'ATCTCCCTGCAATCTA': 'CL:0000058',
#  'ATCTGTAATTGTACCC': 'CL:0000138',
#  'ATCTTGACCTGCAACG': 'CL:0008019',
#  'ATGAAGCCAAGGAGCC': 'CL:0000138',
#  'ATGACGCCGGCTCTAA': 'CL:0000138',
#  'ATGACTATGCGACATT': 'CL:0008019',
#  'ATGAGGAGTGTTAATC': 'CL:0008019',
#  'ATGATCGGGAATAGAC': 'CL:0008019',
#  'ATGCACTACCGCATTG': 'CL:0008019',
#  'ATGCTCAGTGTTGCAT': 'CL:0008019',
#  'ATGCTTAGGAGTTGAT': 'CL:0000138',
#  'ATGTGGACATCTTGAT': 'CL:0008019',
#  'ATTAATTCGGTCACTC': 'CL:0000058',
#  'ATTACAACTACCGGCC': 'CL:0000388',
#  'ATTACTAGCCTCTTGC': 'CL:0000138',
#  'ATTAGATTGATAGCGG': 'CL:0000138',
#  'ATTATGCCATAGGGAG': 'CL:0000138',
#  'ATTCAACCATTTAAGG': 'CL:0008019',
#  'ATTCACTGATGTTGGA': 'CL:0000138',
#  'ATTCAGTAGCAGGGTC': 'CL:0008019',
#  'ATTCATATACTGTCCA': 'CL:0008019',
#  'ATTCCCACATAAACAA': 'CL:0008019',
#  'ATTCCTCCGCCAGTGC': 'CL:0000138',
#  'ATTCTCGTCTCTTTAG': 'CL:0008019',
#  'ATTCTTCGTACTTATG': 'CL:0002551',
#  'ATTGACGTAACTCGGT': 'CL:0000187',
#  'ATTGCGATCAGTAACT': 'CL:0000138',
#  'ATTGGATTACAGCGTA': 'CL:0000138',
#  'ATTGGGAATATCTTGG': 'CL:0008019',
#  'ATTGTCGCAATACCTT': 'CL:0008019',
#  'ATTTAACTCGTATTAC': 'CL:0000138',
#  'ATTTCATTATTTCGCG': 'CL:0000058',
#  'ATTTCCGGGTTCTGCG': 'CL:0008019',
#  'ATTTGTTCCAGGGCTC': 'CL:0002355',
#  'CAAACTACGATAGAGA': 'CL:0008019',
#  'CAAACTATTGAGCTTC': 'CL:0000388',
#  'CAAATTGTCAGCAAGC': 'CL:0008019',
#  'CAACGACCCGTTTACA': 'CL:0008019',
#  'CAACGGTTCTTGATAC': 'CL:0000138',
#  'CAACGTGGTGGAGTCT': 'CL:0000138',
#  'CAACTATATCGAATGC': 'CL:0000058',
#  'CAACTCCTTGATCCCG': 'CL:0000138',
#  'CAACTGCTCATCCGAT': 'CL:0008019',
#  'CAAGAGGGCGGAGTAC': 'CL:0002551',
#  'CAAGCACCAAATGCCT': 'CL:0000138',
#  'CAAGCGGCACATAATT': 'CL:0000138',
#  'CAATATTCTTGACCTA': 'CL:0008019',
#  'CAATCCCTATACCAGC': 'CL:0008019',
#  'CAATGCGAGAAGTATC': 'CL:0000138',
#  'CAATGGAATCTACATA': 'CL:0002551',
#  'CACACACGCTAACGAG': 'CL:0008019',
#  'CACACAGGGATAGATT': 'CL:0008019',
#  'CACAGCTAGGGAGTGA': 'CL:0008019',
#  'CACAGGGCCATATAGT': 'CL:0008019',
#  'CACAGTCCCGCTTCGC': 'CL:0002551',
#  'CACAGTTCGCTTCCCA': 'CL:0002551',
#  'CACATCTCACCGACGA': 'CL:0000138',
#  'CACATTCTTTCGATGG': 'CL:0002551',
#  'CACCATCGGAGGAGAC': 'CL:0008019',
#  'CACCCACACGTCACCC': 'CL:0000138',
#  'CACCCGGTTTGTGACT': 'CL:0008019',
#  'CACCCTAACAAGATCT': 'CL:0008019',
#  'CACCGATACACCGAGC': 'CL:0008019',
#  'CACCGCCGACCAGCGA': 'CL:0008019',
#  'CACCGTATCCCATCCG': 'CL:0008019',
#  'CACCGTTAGGGATCAC': 'CL:0008019',
#  'CACCTAATCAGTTTAC': 'CL:0002551',
#  'CACCTCGATGGTGGAC': 'CL:0008019',
#  'CACGTTTCGTACACAC': 'CL:0000058',
#  'CACTACGGGAGCTGCC': 'CL:0000138',
#  'CACTCAGCTCTTGAGG': 'CL:0008019',
#  'CACTCCTATGTAAGAT': 'CL:0008019',
#  'CACTCCTCTCGGTCGG': 'CL:0008019',
#  'CACTCGAGCTGAACAA': 'CL:0008019',
#  'CACTCTTCTGCTAGCC': 'CL:0002551',
#  'CACTGTCCAAGTGAGA': 'CL:0000138',
#  'CACTTCGCCACAGGCT': 'CL:0008019',
#  'CAGAACTTAGCCCTCT': 'CL:0000058',
#  'CAGAATAACACACGGA': 'CL:0000138',
#  'CAGACACCGATCGCTG': 'CL:0000138',
#  'CAGACGAACCTGATAC': 'CL:0008019',
#  'CAGAGACGGTCACCCA': 'CL:0008019',
#  'CAGAGGCGATGCATGA': 'CL:0008019',
#  'CAGAGTGATTTAACGT': 'CL:0000187',
#  'CAGATACTAACATAGT': 'CL:0008019',
#  'CAGCAGTCCAGACTAT': 'CL:0000138',
#  'CAGCCGGGCCCTCTAT': 'CL:0008019',
#  'CAGCCTCTCCTCAAGA': 'CL:0002551',
#  'CAGCGATTCCCTTCAA': 'CL:0000138',
#  'CAGCTCGTGCTTGTGT': 'CL:0000138',
#  'CAGGAAGACTTTATAT': 'CL:0008019',
#  'CAGGCGCCATGCTAGG': 'CL:0000138',
#  'CAGTGTCCGCAGAATG': 'CL:0008019',
#  'CAGTGTCGGCTGGCCC': 'CL:0000058',
#  'CAGTTCCGCGGGTCGA': 'CL:0008019',
#  'CATAAGAAGCTTGGCT': 'CL:0008019',
#  'CATACAAAGCCGAACC': 'CL:0002551',
#  'CATACACGGTTCCCAC': 'CL:0008019',
#  'CATAGCCGCCCGGGAT': 'CL:0008019',
#  'CATAGCGTTGCCCACC': 'CL:0008019',
#  'CATAGTACATTGAGAG': 'CL:0000058',
#  'CATAGTAGCATAGTAG': 'CL:0000138',
#  'CATATTATTTGCCCTA': 'CL:0008019',
#  'CATCATCTACCCGGAC': 'CL:0000187',
#  'CATCATTACCCTGAGG': 'CL:0000058',
#  'CATCCTCTCAAAGATC': 'CL:0000138',
#  'CATCGCCCGCGGCCAA': 'CL:0000138',
#  'CATGAACCGACATTTG': 'CL:0008019',
#  'CATGATGCACAATTCT': 'CL:0002551',
#  'CATGCGTTAGACAGAA': 'CL:0000138',
#  'CATGCTGGCTCCAATT': 'CL:0008019',
#  'CATGGATTGTCTTCCG': 'CL:0000138',
#  'CATGGCAGGAAGATCG': 'CL:0000138',
#  'CATGGGTATGCCTTAT': 'CL:0008019',
#  'CATGTAAGAGACATTT': 'CL:0000138',
#  'CATGTCTCATTTATGG': 'CL:0000058',
#  'CATTACGTCGGCCCGT': 'CL:0000138',
#  'CATTTGAGTGGTACGT': 'CL:0008019',
#  'CCAAACAGAACCCTCG': 'CL:0008019',
#  'CCAAGAAAGTGGGCGA': 'CL:0000138',
#  'CCAAGACTTCTGCGAA': 'CL:0000138',
#  'CCAAGGAACAGAGAGG': 'CL:0000138',
#  'CCAATCGGTAGATCGA': 'CL:0008019',
#  'CCAATTGAATGTTAAT': 'CL:0000138',
#  'CCACAGTACCCATCCT': 'CL:0008019',
#  'CCACCAACTTTACTGT': 'CL:0008019',
#  'CCACGAGAAGAGAATC': 'CL:0002551',
#  'CCACTGTTTGGATTAA': 'CL:0008019',
#  'CCAGAAAGCAACTCAT': 'CL:0008019',
#  'CCAGAGACAAAGCCGG': 'CL:0000646',
#  'CCAGTCTTGTCATAGA': 'CL:0008019',
#  'CCATAAACAACCCGAC': 'CL:0000138',
#  'CCATAGGTTGGCGTGG': 'CL:0000138',
#  'CCATATGGAAACTATA': 'CL:0000138',
#  'CCATCCATACCAAGTC': 'CL:0008019',
#  'CCATCGCAGTTAAACT': 'CL:0000138',
#  'CCATGCCCTAGATTTC': 'CL:0000138',
#  'CCATGCTCTGCAGGAA': 'CL:0000138',
#  'CCATTTCTACCTATTA': 'CL:0000138',
#  'CCCAACCACACTAACA': 'CL:0002551',
#  'CCCAGGTCTGAAGGCT': 'CL:0000138',
#  'CCCGCAGCGCGAACTA': 'CL:0000138',
#  'CCCGCAGGGCCCAAAG': 'CL:0000138',
#  'CCCGCCATGCTCCCGT': 'CL:0000138',
#  'CCCGGTGGAAGAACCT': 'CL:0008019',
#  'CCCGTAGCTGGGAAGA': 'CL:0008019',
#  'CCCGTCAGCGTCTGAC': 'CL:0008019',
#  'CCCGTTTCGCAGATGT': 'CL:0008019',
#  'CCCTCATTCTGGAATT': 'CL:0000138',
#  'CCCTGAAATGAGTTGA': 'CL:0000187',
#  'CCCTTTGACAGGTCTT': 'CL:0000138',
#  'CCGAACCTTCCCGGCC': 'CL:0000388',
#  'CCGACAATAGGCCGCC': 'CL:0000138',
#  'CCGACGTAAACACAAC': 'CL:0002551',
#  'CCGCATGTGGTACGAT': 'CL:0000138',
#  'CCGCCGGTCAACACAC': 'CL:0000138',
#  'CCGCCTGCGAATTGGT': 'CL:0002551',
#  'CCGCGGAATGCGTCAC': 'CL:0008019',
#  'CCGCTATCAGCACCAG': 'CL:0002551',
#  'CCGGAATGGTTTCAGT': 'CL:0008019',
#  'CCGGAGCGTACTTTCT': 'CL:0008019',
#  'CCGGCGCATATTGGAT': 'CL:0008019',
#  'CCGGGACCCGCAGAGA': 'CL:0000138',
#  'CCGGTTTGTAATTGTG': 'CL:0008019',
#  'CCGTAGGGTTGTTTAC': 'CL:0002551',
#  'CCGTGCCCATGACGGC': 'CL:0000187',
#  'CCTAAAGGCTGACGCT': 'CL:0000058',
#  'CCTAACCCAAACAAGT': 'CL:0000388',
#  'CCTACGGCTCAGTCGA': 'CL:0002551',
#  'CCTACTGCTTACACTT': 'CL:0008019',
#  'CCTAGTTAGTCGCATG': 'CL:0000058',
#  'CCTATAATGAGTGCCC': 'CL:0000138',
#  'CCTATACCGTCCTGTC': 'CL:0008019',
#  'CCTATATTTGTCCTGG': 'CL:0000646',
#  'CCTATGTCCACTCCAC': 'CL:0000138',
#  'CCTCACCAATCTTGAC': 'CL:0008019',
#  'CCTCCCGACAATCCCT': 'CL:0002551',
#  'CCTCGAAGTGGACGGG': 'CL:0000138',
#  'CCTCGCCAGCAAATTA': 'CL:0002551',
#  'CCTCGCGCTGTGCGAT': 'CL:0000138',
#  'CCTCTGGCCTAGACGG': 'CL:0000058',
#  'CCTCTGTACTATTCTA': 'CL:0000138',
#  'CCTGACCACCGATGGT': 'CL:0002551',
#  'CCTGCTATTTGAGAAG': 'CL:0008019',
#  'CCTGGTCGAATGTGGG': 'CL:0002551',
#  'CCTGTTTGAAGACACG': 'CL:0002551',
#  'CCTTGACCACTTTATT': 'CL:0008019',
#  'CCTTTAAGGGAGCACT': 'CL:0008019',
#  'CGAAACATAGATGGCA': 'CL:0000058',
#  'CGAACAGTATGGGCGT': 'CL:0000388',
#  'CGAACGCCCAGTGCCG': 'CL:0000138',
#  'CGACATGCGATCTTCT': 'CL:0002551',
#  'CGAGAGGGTAGCCGCG': 'CL:0008019',
#  'CGAGCACTTCAAGTTT': 'CL:0008019',
#  'CGAGCGTTGATCAGCC': 'CL:0000187',
#  'CGAGCTGGGCTTTAGG': 'CL:0000138',
#  'CGATTAAATATCTCCT': 'CL:0000138',
#  'CGATTCGCCTGGCTGC': 'CL:0000138',
#  'CGCAAACACGAGTTAC': 'CL:0008019',
#  'CGCAATTACTTTCGGT': 'CL:0000138',
#  'CGCAATTAGGGTAATA': 'CL:0008019',
#  'CGCAATTCTACAATAA': 'CL:0008019',
#  'CGCAGAAACATTTGCG': 'CL:0002551',
#  'CGCAGGCGATCCAAAC': 'CL:0000138',
#  'CGCATCATGGCTTCAG': 'CL:0002551',
#  'CGCCCAGCACGCCTAG': 'CL:0008019',
#  'CGCCCTTGAAGGCTGA': 'CL:0008019',
#  'CGCCGTTCAGCATAGT': 'CL:0008019',
#  'CGCGCATGTTTGATTG': 'CL:0000138',
#  'CGCTATACCGCCCACT': 'CL:0008019',
#  'CGCTATTCAATGTATG': 'CL:0008019',
#  'CGCTCGACATAATGAT': 'CL:0008019',
#  'CGCTGTGACGCCGCAC': 'CL:0008019',
#  'CGCTTCCACTGAAATC': 'CL:0008019',
#  'CGCTTTCATACCGGTG': 'CL:0000138',
#  'CGGAAAGAATCAAACG': 'CL:0008019',
#  'CGGAGCAATTTAATCG': 'CL:0008019',
#  'CGGAGCTTATAACACC': 'CL:0000388',
#  'CGGCAAACATCGTGCG': 'CL:0000138',
#  'CGGCAATAAGATCGCC': 'CL:0008019',
#  'CGGCACCGTTAGCGCC': 'CL:0000388',
#  'CGGGAATTTATGTAAA': 'CL:0002551',
#  'CGGGAGCTTCAGTGTA': 'CL:0008019',
#  'CGGGTTTGTTAGGGCT': 'CL:0002551',
#  'CGGTGTACTTGATCCC': 'CL:0008019',
#  'CGTAGCGAATTGTCAG': 'CL:0000058',
#  'CGTATTGTTTGGCGCC': 'CL:0000138',
#  'CGTCACGTCCATTGGT': 'CL:0008019',
#  'CGTCAGTGCGCACAAG': 'CL:0008019',
#  'CGTCGTCCTTCGCGAA': 'CL:0000138',
#  'CGTCTGGAAGGGCCCG': 'CL:0000138',
#  'CGTGACATTGGGTCGT': 'CL:0008019',
#  'CGTGTCCCATTCGCGA': 'CL:0008019',
#  'CGTTAGCTCACAACTG': 'CL:0000138',
#  'CGTTGAATACCGCGCT': 'CL:0000138',
#  'CGTTTAAGCGGAGCAC': 'CL:0008019',
#  'CGTTTCACTTCGGGCG': 'CL:0002551',
#  'CGTTTGTGTAGAGGGT': 'CL:0008019',
#  'CTAACTGATAATCGCC': 'CL:0008019',
#  'CTAATTTCAACAACAC': 'CL:0008019',
#  'CTACAAGAAATAACCC': 'CL:0008019',
#  'CTACACTCGCAGATGG': 'CL:0000138',
#  'CTACGCCATTTCCGAT': 'CL:0000138',
#  'CTAGGCGCCCTATCAG': 'CL:0008019',
#  'CTAGGTTCGGACGTGA': 'CL:0008019',
#  'CTAGTATTCGGAATTA': 'CL:0000058',
#  'CTAGTTACAACCCGGT': 'CL:0000138',
#  'CTATGGGAAGCGGAAT': 'CL:0008019',
#  'CTATGTCTATTGAAAC': 'CL:0008019',
#  'CTATTCATGTGTCCCA': 'CL:0000138',
#  'CTCAGGACTCACCTGT': 'CL:0000646',
#  'CTCATGGCTCACAATC': 'CL:0000138',
#  'CTCATTTGATGGGCGG': 'CL:0008019',
#  'CTCCGGCCTAATATGC': 'CL:0008019',
#  'CTCCTGTTCAAGGCAG': 'CL:0002551',
#  'CTCGCCGAATGTAGGG': 'CL:0008019',
#  'CTCGGTCCGTAGCCTG': 'CL:0000138',
#  'CTCTATTTGGCTGCAG': 'CL:0000187',
#  'CTCTGCGAAGCAAGCA': 'CL:0008019',
#  'CTCTGTTTGAGGATTC': 'CL:0000138',
#  'CTCTTGTCCCGCTTGG': 'CL:0008019',
#  'CTGAAAGAGATCCGAC': 'CL:0002355',
#  'CTGAATCCGAGACCTC': 'CL:0008019',
#  'CTGCAAGCACGTTCCG': 'CL:0008019',
#  'CTGCACAACTACATAT': 'CL:0008019',
#  'CTGCACCTGGAACCGC': 'CL:0000138',
#  'CTGCACTCCAGTACAG': 'CL:0008019',
#  'CTGCCTAGCCACCAAG': 'CL:0000138',
#  'CTGCGGTAGTCACGTG': 'CL:0002551',
#  'CTGCGTTACGATATAA': 'CL:0000138',
#  'CTGCTTGGCGATAGCT': 'CL:0000138',
#  'CTGGAAGACACGGTGG': 'CL:0000058',
#  'CTGGATTTACACTTGA': 'CL:0000138',
#  'CTGGCTGGTTGTCAGT': 'CL:0000138',
#  'CTGGTTTCGAGCAAGA': 'CL:0002551',
#  'CTGTAGCCATCTCACT': 'CL:0008019',
#  'CTGTATGGTGTAGAAA': 'CL:0008019',
#  'CTGTGGTCGGGAGATA': 'CL:0000058',
#  'CTGTTACCCAATCTAG': 'CL:0008019',
#  'CTGTTCACTGCCTGTG': 'CL:0008019',
#  'CTGTTCATCTCACGGG': 'CL:0000138',
#  'CTTAACTTCGAAGTAC': 'CL:0008019',
#  'CTTACACTGGGAAATA': 'CL:0000138',
#  'CTTCATAGCTCAAGAA': 'CL:0000138',
#  'CTTCCGCTCCGTGAAG': 'CL:0008019',
#  'CTTCTATTAATGCTAG': 'CL:0000138',
#  'CTTCTTACGTCGTATA': 'CL:0000138',
#  'CTTGACCCGAAAGATA': 'CL:0002551',
#  'CTTGGCCAAGCTGGGA': 'CL:0008019',
#  'CTTGTACTTGTTGACT': 'CL:0000138',
#  'CTTGTCAACATTCGAG': 'CL:0008019',
#  'CTTGTTTATGTAGCCA': 'CL:0002551',
#  'CTTTAATATTGGTCGA': 'CL:0008019',
#  'CTTTACCGAATAGTAG': 'CL:0000138',
#  'CTTTCTGTGCGGGCTT': 'CL:0000138',
#  'GAAACAGCCATGCAGT': 'CL:0008019',
#  'GAAACCTATACAAATG': 'CL:0008019',
#  'GAAACTCTAATGAAGG': 'CL:0000138',
#  'GAAAGCAGTGCACTTT': 'CL:0008019',
#  'GAAAGTGACTAACTGC': 'CL:0008019',
#  'GAAATCGCGCGCAACT': 'CL:0000058',
#  'GAAATTCACATCGCTG': 'CL:0000187',
#  'GAACACACATCAACCA': 'CL:0000138',
#  'GAACAGATTACTAAAT': 'CL:0000138',
#  'GAACCCTCTGTGTTCT': 'CL:0008019',
#  'GAACGACCGAATGATA': 'CL:0000138',
#  'GAAGAACGGTGCAGGT': 'CL:0008019',
#  'GAAGCCTGCACATTCC': 'CL:0008019',
#  'GAAGTCAGTTGCACTA': 'CL:0000138',
#  'GAAGTGCTGGATAGCT': 'CL:0008019',
#  'GAATATTCGGAGTCCC': 'CL:0008019',
#  'GAATCGACATGGTCAC': 'CL:0000138',
#  'GAATCGCCGGACACGG': 'CL:0002551',
#  'GAATGTATGGCAGGTC': 'CL:0000138',
#  'GAATTCACCCGGGTGT': 'CL:0008019',
#  'GACAACGCAGCTTACG': 'CL:0000138',
#  'GACAAGAGATGAGATT': 'CL:0002551',
#  'GACACTGGAACCCGAT': 'CL:0000388',
#  'GACATCGATTTATAAC': 'CL:0000138',
#  'GACCAAACGTTGACTG': 'CL:0008019',
#  'GACCCGTCGCCGGCTA': 'CL:0002551',
#  'GACCGTCAGGTCGTGA': 'CL:0000058',
#  'GACGACGATCCGCGTT': 'CL:0000138',
#  'GACGAGGCTAATAAAC': 'CL:0000138',
#  'GACGCCGTAAAGGCTA': 'CL:0008019',
#  'GACGGGTTGGCCCGTA': 'CL:0008019',
#  'GACTAAGATCATGCAC': 'CL:0008019',
#  'GACTAAGTAGGCTCAC': 'CL:0008019',
#  'GACTACAATTGCTCGT': 'CL:0002551',
#  'GAGACTTCGCGACCGA': 'CL:0008019',
#  'GAGATGGGAGTCGACA': 'CL:0000138',
#  'GAGCATCATCCCTGGG': 'CL:0002551',
#  'GAGCCAGCTACCTGTG': 'CL:0000058',
#  'GAGCGAGGGAGTACCG': 'CL:0000138',
#  'GAGCGCAAATACTCCG': 'CL:0000138',
#  'GAGCGCGCACGAGTAG': 'CL:0000187',
#  'GAGCTCTCGGACCTAA': 'CL:0002551',
#  'GAGGAATGGAGAGGTT': 'CL:0008019',
#  'GAGGTACATCCATCTT': 'CL:0008019',
#  'GAGTACGGGTATACAA': 'CL:0000138',
#  'GAGTCAGACCAGAATC': 'CL:0000138',
#  'GAGTCCGCTTACCGGA': 'CL:0008019',
#  'GATAAATCGGTGGATG': 'CL:0008019',
#  'GATATCTCATGCAATA': 'CL:0000138',
#  'GATATGCGGTAGCCAA': 'CL:0002551',
#  'GATATTTCCTACATGG': 'CL:0002551',
#  'GATCGACACTATCTGA': 'CL:0008019',
#  'GATCGCTACCCGATTT': 'CL:0008019',
#  'GATCTGCTATCTAAGG': 'CL:0008019',
#  'GATGACAAGTAGGGCA': 'CL:0008019',
#  'GATGCTACAAGCGCCT': 'CL:0000138',
#  'GATGGCGCACACATTA': 'CL:0008019',
#  'GATGGTGCCCTAGGCA': 'CL:0008019',
#  'GATGTCGGTCAACTGC': 'CL:0000187',
#  'GATGTTTGTGCGAGAT': 'CL:0008019',
#  'GATTAACCGAAAGCCC': 'CL:0000058',
#  'GATTCCGCGTTTCCGT': 'CL:0000058',
#  'GATTCCTATACGGCGC': 'CL:0008019',
#  'GCAAACCCTACATTAT': 'CL:0008019',
#  'GCAAACCTTGGCCATA': 'CL:0000138',
#  'GCAACCACCAGACCGG': 'CL:0000138',
#  'GCAAGTGCACAGAGAA': 'CL:0000138',
#  'GCACAAGTGTCGGAAG': 'CL:0008019',
#  'GCACACACTGGTAGCC': 'CL:0000388',
#  'GCACGCCTACTTAGAT': 'CL:0008019',
#  'GCACTAGTCGCGCTAT': 'CL:0000187',
#  'GCAGATCCATAAGACT': 'CL:0008019',
#  'GCAGGTAGAGTATGGT': 'CL:0002551',
#  'GCATCCCTAACTTTGA': 'CL:0008019',
#  'GCCAGGCGTTCGCATG': 'CL:0002551',
#  'GCCATCGAGCTGCGTG': 'CL:0000138',
#  'GCCCACCAAGGCTGTC': 'CL:0002551',
#  'GCCCAGTTGGTATGCC': 'CL:0000138',
#  'GCCCGATCTGTGGTCG': 'CL:0000138',
#  'GCCCGCGCGTTTGACA': 'CL:0000138',
#  'GCCTAGCGATCTGACC': 'CL:0000138',
#  'GCCTATTCCGATATAG': 'CL:0008019',
#  'GCCTCTATACATAGCA': 'CL:0008019',
#  'GCCTTCAGCCCTACCG': 'CL:0000138',
#  'GCGAAACGATCGGGAG': 'CL:0000138',
#  'GCGACGATAGTTGTAC': 'CL:0008019',
#  'GCGATTCTGGAAGCAG': 'CL:0008019',
#  'GCGCGTCATTGGTACA': 'CL:0002355',
#  'GCGCTGATCCAGACTC': 'CL:0002551',
#  'GCGCTTAAATAATTGG': 'CL:0002355',
#  'GCGGACCGCGTTGTGG': 'CL:0008019',
#  'GCGGAGAAACTTCGCA': 'CL:0000646',
#  'GCGGGAACCAGGCCCT': 'CL:0000138',
#  'GCGGGCGAGCCTTACC': 'CL:0008019',
#  'GCGGTCCCTAGACGCA': 'CL:0000187',
#  'GCGGTTCCCTATCATG': 'CL:0002551',
#  'GCGTCGAAATGTCGGT': 'CL:0000138',
#  'GCGTCGCCAGGGTGAT': 'CL:0000138',
#  'GCTAAACCTGAGGTGA': 'CL:0008019',
#  'GCTAATACCGAATGCC': 'CL:0008019',
#  'GCTACAATCGAGGATA': 'CL:0002551',
#  'GCTACTATAGTAGAGT': 'CL:0008019',
#  'GCTAGAGTAGAGATGT': 'CL:0000058',
#  'GCTAGCTTGAATAGCT': 'CL:0000138',
#  'GCTAGGCACCACGGAG': 'CL:0000058',
#  'GCTAGTTTCATTGAGG': 'CL:0008019',
#  'GCTATACGTCTCGGAC': 'CL:0000058',
#  'GCTATCATACTCATGG': 'CL:0008019',
#  'GCTCAATCCGTTTATT': 'CL:0008019',
#  'GCTCAATGTAATACCG': 'CL:0000646',
#  'GCTCATTACTGCATGT': 'CL:0008019',
#  'GCTCTATGTTACGTGC': 'CL:0008019',
#  'GCTGCTAAGTAGTCGA': 'CL:0000138',
#  'GCTGCTACTGCGTAGC': 'CL:0000138',
#  'GCTGGCGGCGCATGCT': 'CL:0000138',
#  'GCTTGATGATAATCAG': 'CL:0000138',
#  'GGAAACTAAATGGGCC': 'CL:0002551',
#  'GGAACTTTGGCGATTA': 'CL:0002551',
#  'GGAAGCTCGCTTACAG': 'CL:0008019',
#  'GGACCAACAGGATAAC': 'CL:0000138',
#  'GGAGAAGTCATTGGCA': 'CL:0008019',
#  'GGAGCAACATTTCAAG': 'CL:0008019',
#  'GGAGGATTGAAAGGAG': 'CL:0002551',
#  'GGAGTGCCGCCCTGGA': 'CL:0000138',
#  'GGATTCAGTACGGTGG': 'CL:0008019',
#  'GGCAAAGGCGCCAATA': 'CL:0008019',
#  'GGCAGCAAACCTATGC': 'CL:0008019',
#  'GGCATATCGGTTCTGC': 'CL:0002551',
#  'GGCCTGCTTCTCCCGA': 'CL:0002551',
#  'GGCGCGTTCGAGTTTA': 'CL:0008019',
#  'GGCTCGTGCCACCAGC': 'CL:0000138',
#  'GGCTGAAATAGCAAAG': 'CL:0000138',
#  'GGCTTTCAATAAGGGT': 'CL:0008019',
#  'GGGACCCGTATATCTT': 'CL:0008019',
#  'GGGAGTAATGGCTGGC': 'CL:0002551',
#  'GGGCAGAGCAATCGTT': 'CL:0008019',
#  'GGGCGGCAAATGAATT': 'CL:0008019',
#  'GGGCGTCCACTGGCTC': 'CL:0008019',
#  'GGGCTATGATCGATGG': 'CL:0008019',
#  'GGGTGACACCTTAACT': 'CL:0008019',
#  'GGGTGGTCCAGCCTGT': 'CL:0002551',
#  'GGGTGTTTCAGCTATG': 'CL:0000138',
#  'GGGTTAACATTTGAGT': 'CL:0008019',
#  'GGTAAATGTGCGTTAC': 'CL:0000058',
#  'GGTAACTATGTATCTG': 'CL:0000187',
#  'GGTAGAAGACCGCCTG': 'CL:0000138',
#  'GGTAGACCGTTGGGCG': 'CL:0008019',
#  'GGTCAAGACTACTTCG': 'CL:0008019',
#  'GGTCAGTGGGTCCCAC': 'CL:0000138',
#  'GGTCGGTAATTAGACA': 'CL:0002551',
#  'GGTCGGTCGTCCACAG': 'CL:0008019',
#  'GGTCTCTGAATGGACT': 'CL:0008019',
#  'GGTGAGATGCAGATAA': 'CL:0008019',
#  'GGTGCGGATAAGTGGC': 'CL:0000138',
#  'GGTGCTGATCACAAAG': 'CL:0008019',
#  'GGTGGACTGCTCTGGC': 'CL:0000058',
#  'GGTTAGCTATATGTCT': 'CL:0002551',
#  'GGTTAGGCTTGGAGAA': 'CL:0008019',
#  'GGTTAGTTACGGCGCC': 'CL:0008019',
#  'GGTTTGAGTGCTGGAA': 'CL:0008019',
#  'GTAACATCTAAGATAA': 'CL:0000138',
#  'GTAAGGATTTGTCGGA': 'CL:0000187',
#  'GTAAGTAGGGTATACC': 'CL:0008019',
#  'GTAATCTGATTCTTCG': 'CL:0008019',
#  'GTACGAGATTGCGACA': 'CL:0002551',
#  'GTACGCTTCATTGCAC': 'CL:0002551',
#  'GTACTGAGGTCGTAAC': 'CL:0002551',
#  'GTACTGCATGAAGCGT': 'CL:0002551',
#  'GTACTTGGGCACTTCT': 'CL:0008019',
#  'GTAGACGTCGTTACAT': 'CL:0008019',
#  'GTAGCCAAACATGGGA': 'CL:0000138',
#  'GTAGTCGCGGGAATCA': 'CL:0000138',
#  'GTATAGGACTCAGTAG': 'CL:0000138',
#  'GTATCAAACGTTAGCT': 'CL:0000138',
#  'GTATCAGCTTGGGTTC': 'CL:0008019',
#  'GTATCTTTCATAACCA': 'CL:0008019',
#  'GTATTAAGGCGTCTAA': 'CL:0000646',
#  'GTCACAAAGTTTCCAA': 'CL:0002551',
#  'GTCACTCTCCAAATCT': 'CL:0008019',
#  'GTCAGTTGTGCTCGTT': 'CL:0000187',
#  'GTCCGGACCTGAAATT': 'CL:0000138',
#  'GTCCTACGAATAGTCT': 'CL:0000138',
#  'GTCCTTCTAGTGGGTT': 'CL:0008019',
#  'GTCGCCGTTGTGTGTT': 'CL:0008019',
#  'GTCGGATGTAGCGCGC': 'CL:0002551',
#  'GTCGGGAAGCAGAAAC': 'CL:0008019',
#  'GTCGTACCATCTCGGG': 'CL:0008019',
#  'GTCGTCAATTATAAGG': 'CL:0002551',
#  'GTCTATTGGTTCCGGT': 'CL:0000388',
#  'GTCTCAAGGCCCGGCT': 'CL:0008019',
#  'GTCTTAGTACAGCCGG': 'CL:0000138',
#  'GTGAGGAGCGGTTGAG': 'CL:0008019',
#  'GTGAGTGGTACAACGC': 'CL:0000138',
#  'GTGATCATAGATCTGC': 'CL:0002551',
#  'GTGATGCACAACATCT': 'CL:0002551',
#  'GTGCAACAAATGTGGC': 'CL:0000138',
#  'GTGCACGAAAGTGACT': 'CL:0000058',
#  'GTGCCTCAGTGTACGG': 'CL:0002551',
#  'GTGCGGGTCTCCAAAT': 'CL:0000138',
#  'GTGGAACCTACATGCG': 'CL:0000058',
#  'GTGGACGCATTTGTCC': 'CL:0000138',
#  'GTGGACGTGCTGAGAC': 'CL:0000138',
#  'GTGGAGTCGGCGGTTG': 'CL:0008019',
#  'GTGGTATAGTCTGCCG': 'CL:0008019',
#  'GTGTATATCAGCGGGC': 'CL:0002551',
#  'GTGTCGTATAGCGTTC': 'CL:0000138',
#  'GTTAACATCACTTAAA': 'CL:0008019',
#  'GTTACCTACAACTTGC': 'CL:0000187',
#  'GTTAGAGTGTGCCGCT': 'CL:0002551',
#  'GTTATAATACGGTGAA': 'CL:0000138',
#  'GTTATATTATCTCCCT': 'CL:0008019',
#  'GTTCCAGTCTGACCAT': 'CL:0008019',
#  'GTTCGCTGAGACGTCT': 'CL:0000388',
#  'GTTCTTCCCTCGATGT': 'CL:0000138',
#  'GTTGAGTCCCGCCGGT': 'CL:0000138',
#  'GTTGCACGGAGTTTCG': 'CL:0008019',
#  'GTTGGATTCAGTGGCT': 'CL:0002551',
#  'GTTGGTCATGCTATCC': 'CL:0000138',
#  'GTTGTCGTGTTAGTTG': 'CL:0008019',
#  'GTTTACGTTCCATCTG': 'CL:0000138',
#  'GTTTCAAACGAGTTGT': 'CL:0002551',
#  'GTTTCCTGGAGGGTGA': 'CL:0008019',
#  'GTTTGGGCTTGTGAGC': 'CL:0008019',
#  'GTTTGGTAGGGTCAAC': 'CL:0008019',
#  'TAAACCCAGGAGGGCA': 'CL:0008019',
#  'TAAAGAGCCCGAAACC': 'CL:0002551',
#  'TAAAGCTGCAATAGGG': 'CL:0002551',
#  'TAAATGAATCCGTTTC': 'CL:0008019',
#  'TAACAAAGGGAGAAGC': 'CL:0000138',
#  'TAACCGCCCGCAGTGC': 'CL:0002551',
#  'TAACCTAGGGAGTCCA': 'CL:0002551',
#  'TAACGCTTTGAGAGCG': 'CL:0008019',
#  'TAACTATCGAAGGTCC': 'CL:0008019',
#  'TAACTCCATGGAGGCT': 'CL:0008019',
#  'TAAGGAACTTGTGGGA': 'CL:0008019',
#  'TAAGGCATAACATCAA': 'CL:0008019',
#  'TAAGGGCCTGTCCGAT': 'CL:0008019',
#  'TAAGTTGCGACGTAGG': 'CL:0000138',
#  'TAATAAACAAGGAGAT': 'CL:0002551',
#  'TAATACACAGTAGTAT': 'CL:0000138',
#  'TAATATTGAAATTCGC': 'CL:0000138',
#  'TACCAAATAGCCCAGA': 'CL:0008019',
#  'TACCAATAAAGTACCA': 'CL:0000058',
#  'TACCAGCTAGGTTTAA': 'CL:0008019',
#  'TACCGGCTCACTGCCC': 'CL:0000187',
#  'TACCGTAGGTTAACTA': 'CL:0008019',
#  'TACCGTGCCTCGGACC': 'CL:0000138',
#  'TACCTACTCCCAGTAT': 'CL:0000138',
#  'TACCTCACGCTTGTAC': 'CL:0000138',
#  'TACCTCAGTTGTCTGT': 'CL:0002551',
#  'TACGACGCTTGCTGCG': 'CL:0002551',
#  'TACGCCGAGGGTACCC': 'CL:0008019',
#  'TACGCCTCCATTCCGA': 'CL:0000138',
#  'TACGTGCACTATGCTG': 'CL:0000138',
#  'TACTATGGTTCCTCAG': 'CL:0008019',
#  'TACTCTTACTTTACTG': 'CL:0002551',
#  'TACTCTTTCGTCTTCA': 'CL:0008019',
#  'TACTGAACAGATTTAG': 'CL:0008019',
#  'TAGAATTAAGGGCAAC': 'CL:0000388',
#  'TAGAGCTACGAAGAAC': 'CL:0000187',
#  'TAGAGGTTCTACTTGT': 'CL:0000138',
#  'TAGATATGGACTGGAA': 'CL:0000138',
#  'TAGATCCGAAGTCGCA': 'CL:0002573',
#  'TAGCAACCTGTCACAA': 'CL:0008019',
#  'TAGCGTCCGGTGTGGT': 'CL:0000138',
#  'TAGCTAGAAGGCATGA': 'CL:0000138',
#  'TAGCTCGCCTGATAAC': 'CL:0008019',
#  'TAGGGTGTTTCAAGAG': 'CL:0008019',
#  'TAGGTGTTCCACAGAT': 'CL:0008019',
#  'TAGTTAAGATAGGATA': 'CL:0000058',
#  'TAGTTTATTCTTGCTT': 'CL:0008019',
#  'TATAAATCCACAAGCT': 'CL:0000138',
#  'TATAAGTGAGGATAGC': 'CL:0000138',
#  'TATACACAGACGCCTT': 'CL:0000138',
#  'TATACACGCAAAGTAT': 'CL:0008019',
#  'TATACGCGTCATCACT': 'CL:0008019',
#  'TATATTCGCGTCGATA': 'CL:0002551',
#  'TATCCAATTGGTTATC': 'CL:0000138',
#  'TATCCATATCATGCGA': 'CL:0000138',
#  'TATCCGCACCGTCGGG': 'CL:0008019',
#  'TATCCTGCATGGGAAT': 'CL:0000138',
#  'TATCGATGATTAAACG': 'CL:0008019',
#  'TATTAACCTGACCGCG': 'CL:0000138',
#  'TATTCCACTCAGCTCG': 'CL:0000138',
#  'TATTCCGAGCTGTTAT': 'CL:0000138',
#  'TATTTAGTCTAGATCG': 'CL:0000138',
#  'TATTTATACCGAGTAG': 'CL:0000058',
#  'TATTTGTTACCCTTTA': 'CL:0008019',
#  'TCAACATAGCGCCCTA': 'CL:0008019',
#  'TCAACCATGTTCGGGC': 'CL:0008019',
#  'TCAACTGCAGAGTCAG': 'CL:0008019',
#  'TCAAGCGCGGACGGTA': 'CL:0002551',
#  'TCACAGCAAACTCGAA': 'CL:0000138',
#  'TCACAGGAGAATAAGA': 'CL:0000138',
#  'TCACAGGGAATCGCAA': 'CL:0002551',
#  'TCACCCTCTTAAGATT': 'CL:0002551',
#  'TCACGGTCATCGCACA': 'CL:0000138',
#  'TCACTACGACCAATGC': 'CL:0002551',
#  'TCACTCGTGCAACGGC': 'CL:0000057',
#  'TCAGACGCTATAGAAG': 'CL:0008019',
#  'TCAGTACTGACCCGCG': 'CL:0008019',
#  'TCAGTGTATACGTCAT': 'CL:0008019',
#  'TCATACTTACAGATCC': 'CL:0008019',
#  'TCATCACTCGAGCTCG': 'CL:0002551',
#  'TCATCCCAGAGGGTGG': 'CL:0008019',
#  'TCATTTAGAAGTGTGA': 'CL:0000138',
#  'TCCACCTCTAGCCTTT': 'CL:0008019',
#  'TCCAGGGTATATACGA': 'CL:0008019',
#  'TCCATTGTGACCTCGT': 'CL:0000187',
#  'TCCCTTAGATTACTCG': 'CL:0002551',
#  'TCCGATAATTGCCATA': 'CL:0000138',
#  'TCCGCCTGTCTACAAG': 'CL:0008019',
#  'TCCGCGGCCCAATGAA': 'CL:0000138',
#  'TCCGCTGTCATCCCGG': 'CL:0002551',
#  'TCCGCTTATCCCATTA': 'CL:0008019',
#  'TCCGGTTCGTCCGGTC': 'CL:0000138',
#  'TCCGTTAAGCTAATAT': 'CL:0000138',
#  'TCCTAAATTGGGAAGC': 'CL:0000138',
#  'TCCTCTACGAGATGGC': 'CL:0008019',
#  'TCCTCTGGCCCATTAG': 'CL:0000388',
#  'TCCTGCCAACTGGAGA': 'CL:0000388',
#  'TCCTTACGACGGTCCG': 'CL:0008019',
#  'TCCTTCAGTGGTCGAA': 'CL:0000138',
#  'TCCTTTAAATCCGCTT': 'CL:0008019',
#  'TCGAGCCAGGCAGGCC': 'CL:0008019',
#  'TCGCAAAGATGCATTT': 'CL:0008019',
#  'TCGCACCAGGAGGCAG': 'CL:0000138',
#  'TCGCCGGTCGATCCGT': 'CL:0000138',
#  'TCGCGTAGCAGTGTCC': 'CL:0000138',
#  'TCGCTAAACCGCTATC': 'CL:0002551',
#  'TCGCTGTGCGTAAATC': 'CL:0000138',
#  'TCGGCTTGTATCGACG': 'CL:0002551',
#  'TCGGGTGAAACTGCTA': 'CL:0008019',
#  'TCGGTCCCTGACTCCA': 'CL:0002551',
#  'TCGTATAGTGCAATTA': 'CL:0008019',
#  'TCGTCAAGTACGCGCA': 'CL:0008019',
#  'TCGTCACACTGTTAGC': 'CL:0008019',
#  'TCGTCCGCTGGCGTCT': 'CL:0000138',
#  'TCGTCTTAGGCGTTAA': 'CL:0000058',
#  'TCGTGTACTATGGATG': 'CL:0002551',
#  'TCGTGTATTGGTCACG': 'CL:0002551',
#  'TCGTGTTCGACCACAA': 'CL:0008019',
#  'TCGTTAGGAGTCCCTA': 'CL:0000138',
#  'TCGTTCGTTATTATGT': 'CL:0008019',
#  'TCGTTGCTATCCGGTC': 'CL:0000138',
#  'TCTACCCAATAGAGAG': 'CL:0008019',
#  'TCTAGCATCTTCGATG': 'CL:0000138',
#  'TCTAGCATGCCCAGAA': 'CL:0000138',
#  'TCTATCATGCAGTTAC': 'CL:0000138',
#  'TCTATCGGTCGCAACA': 'CL:0002551',
#  'TCTATTACGCTGGCGA': 'CL:0002551',
#  'TCTCATGAGATAGGGT': 'CL:0000058',
#  'TCTCCCTGGGCAGCGT': 'CL:0000138',
#  'TCTCGAACGAGGTCAC': 'CL:0002551',
#  'TCTCTAATAGCTGGTA': 'CL:0000138',
#  'TCTCTCGCCGCACATA': 'CL:0002551',
#  'TCTGAACCGGTCGGCT': 'CL:0000138',
#  'TCTGAAGCACGTGGTC': 'CL:0008019',
#  'TCTGAGCAATTGACTG': 'CL:0000138',
#  'TCTGATGTATTCTGTC': 'CL:0000138',
#  'TCTGTCATACAAGAGC': 'CL:0002551',
#  'TCTGTTACCCAGCATA': 'CL:0000646',
#  'TCTTACAGAGGTACCG': 'CL:0000138',
#  'TCTTACGGCATCCGAC': 'CL:0008019',
#  'TCTTGGTAACACCAAA': 'CL:0008019',
#  'TGAAACTTATGCAAGC': 'CL:0000388',
#  'TGACTATAATCCTTTC': 'CL:0008019',
#  'TGAGAATGCTTTACCG': 'CL:0008019',
#  'TGAGATTAGGCCCTAA': 'CL:0002551',
#  'TGAGCGGAAAGTGTTC': 'CL:0000138',
#  'TGAGGAGTGCCAGCTT': 'CL:0008019',
#  'TGAGTAAATTAGCGTA': 'CL:0008019',
#  'TGATACATTTAGCCGT': 'CL:0008019',
#  'TGATGTCAATTAAGTG': 'CL:0000138',
#  'TGATTTCCTCCTGACG': 'CL:0008019',
#  'TGCATGGATCGGATCT': 'CL:0008019',
#  'TGCCAATGGGTACTCT': 'CL:0000138',
#  'TGCCAGTACGTGGAGA': 'CL:0000138',
#  'TGCCGTGGATCGTCCT': 'CL:0000138',
#  'TGCCTAATTGAAGATT': 'CL:0008019',
#  'TGCCTGATCAAACGAT': 'CL:0002355',
#  'TGCCTTGGCCAGGCAA': 'CL:0000138',
#  'TGCGAGAATATTACCC': 'CL:0008019',
#  'TGCGCGATTAACGGAG': 'CL:0008019',
#  'TGCGGAGTAAAGGTGC': 'CL:0002551',
#  'TGCGGCATAGTTCAAC': 'CL:0008019',
#  'TGCGGTGAAATTTCAT': 'CL:0008019',
#  'TGCTAAGTGTCTATTT': 'CL:0000058',
#  'TGCTCGGCGAAACCCA': 'CL:0008019',
#  'TGCTGGTTGGACAATT': 'CL:0000138',
#  'TGGAAGACGAACACCA': 'CL:0000138',
#  'TGGAAGGATAAAGATG': 'CL:0002355',
#  'TGGAATTAGACGCTTT': 'CL:0008019',
#  'TGGCAAACTAAATTAC': 'CL:0008019',
#  'TGGCAATGGGACGGCG': 'CL:0008019',
#  'TGGCCGTATATTGACC': 'CL:0008019',
#  'TGGCGACTGCTCCAAA': 'CL:0008019',
#  'TGGCGATCAAGTTATG': 'CL:0000138',
#  'TGGCTTTGGGTAGACA': 'CL:0000138',
#  'TGGGAAATGCCTTTCC': 'CL:0008019',
#  'TGGGATGCACTCATTC': 'CL:0002551',
#  'TGGGCACGTTCTATGG': 'CL:0000138',
#  'TGGGCAGGCCACCGCA': 'CL:0002551',
#  'TGGGCCACAAGAGCGC': 'CL:0002355',
#  'TGGGCCCATACTAATT': 'CL:0002551',
#  'TGGGTAAGGTTCCCGC': 'CL:0000138',
#  'TGGTATCGCATCCCAA': 'CL:0002551',
#  'TGGTCCCACGCTACGG': 'CL:0000138',
#  'TGGTTCAACGGGTAAT': 'CL:0008019',
#  'TGGTTGGAGGATCCTG': 'CL:0000388',
#  'TGTATCCTTATTCCAT': 'CL:0002551',
#  'TGTCCCGACATAGCAC': 'CL:0008019',
#  'TGTCTACAGTTTCTGT': 'CL:0008019',
#  'TGTGAGACTAGCCCAA': 'CL:0008019',
#  'TGTGCCGGTGCCGGAA': 'CL:0000138',
#  'TGTGTAGTAGCACGTG': 'CL:0002551',
#  'TGTGTCGCGAGTTGCA': 'CL:0008019',
#  'TGTTCGTATTGCGGTG': 'CL:0000138',
#  'TGTTTAATACTTCATC': 'CL:0000388',
#  'TGTTTCGGTACTTCTC': 'CL:0008019',
#  'TTAACACCTCGAACAT': 'CL:0008019',
#  'TTAACCAACCCTCCCT': 'CL:0000138',
#  'TTAACGTCGCAAGACC': 'CL:0008019',
#  'TTAAGCCGACAACTTC': 'CL:0000138',
#  'TTAATTTCAGACGCGG': 'CL:0000058',
#  'TTACAACTACGCATCC': 'CL:0008019',
#  'TTACATCGTGGCCTGG': 'CL:0000138',
#  'TTACCCATTGCCGGGT': 'CL:0002551',
#  'TTACCCTAACAGTCCT': 'CL:0008019',
#  'TTACCCTAGGGATTGG': 'CL:0008019',
#  'TTAGAAGAACATGACT': 'CL:0000138',
#  'TTAGACACGATCGTTG': 'CL:0008019',
#  'TTAGACGAGTCACCTC': 'CL:0000138',
#  'TTAGCAACATGGATGT': 'CL:0008019',
#  'TTAGGTCATAACCGAC': 'CL:0008019',
#  'TTAGTTATTCGTGGCA': 'CL:0002551',
#  'TTATCCGGGATCTATA': 'CL:0008019',
#  'TTATGACAAACTGGAT': 'CL:0008019',
#  'TTATGTTTGCGATAGA': 'CL:0008019',
#  'TTATTAGAGCGTGTTC': 'CL:0008019',
#  'TTATTAGGGAAGCATC': 'CL:0000138',
#  'TTCAACGACCCGACCG': 'CL:0000138',
#  'TTCAAGCCGAGCTGAG': 'CL:0000138',
#  'TTCAATTAGCCATAAT': 'CL:0002551',
#  'TTCACTCGAGCACCTA': 'CL:0000138',
#  'TTCAGCCCTGGTCCAC': 'CL:0002551',
#  'TTCAGCTGGCGTGCCC': 'CL:0000058',
#  'TTCCACACAGATTTGA': 'CL:0008019',
#  'TTCCATCGACAGCGTG': 'CL:0002551',
#  'TTCCGCGTGAGGCGAT': 'CL:0002551',
#  'TTCCGGCCTTGAGGCT': 'CL:0008019',
#  'TTCCTCGAGGGTGTCT': 'CL:0008019',
#  'TTCCTCGGACTAACCA': 'CL:0000058',
#  'TTCGACAGAGCCCGTG': 'CL:0000138',
#  'TTCGACGGGAAGGGCG': 'CL:0000138',
#  'TTCGCACTCGCGTGCT': 'CL:0008019',
#  'TTCGCACTGTACGACA': 'CL:0008019',
#  'TTCGGACTGGGCATGG': 'CL:0008019',
#  'TTCGGCAACCCGCTGA': 'CL:0000138',
#  'TTCGGGCGCTAGTCTT': 'CL:0008019',
#  'TTCGTAATCCCAGCGG': 'CL:0008019',
#  'TTCGTACTCCAGAACG': 'CL:0000646',
#  'TTCTACTTGCGAGGGC': 'CL:0000138',
#  'TTCTAGGCCAATTGTG': 'CL:0008019',
#  'TTCTGACCGGGCTCAA': 'CL:0000138',
#  'TTCTGCCGCGCCTAGA': 'CL:0000138',
#  'TTCTTAGTGAACGGTG': 'CL:0008019',
#  'TTCTTAGTGGCTCAGA': 'CL:0008019',
#  'TTCTTGTAACCTAATG': 'CL:0008019',
#  'TTGACGATTCAGCACG': 'CL:0002551',
#  'TTGAGAAGTTTAGCAT': 'CL:0000058',
#  'TTGATTATGCAGATGA': 'CL:0008019',
#  'TTGCACGGAGCAGCAC': 'CL:0002551',
#  'TTGCCGGTGATCCCTC': 'CL:0002551',
#  'TTGCGGCATCAGAAAG': 'CL:0000138',
#  'TTGCGTAGTTTGAGGA': 'CL:0008019',
#  'TTGCGTCGGCCAACCG': 'CL:0008019',
#  'TTGCGTGAACGCTTAG': 'CL:0002551',
#  'TTGCTGAAGGAACCAC': 'CL:0000138',
#  'TTGCTGGCCGGGCTTC': 'CL:0008019',
#  'TTGGACCATCTGGCAA': 'CL:0008019',
#  'TTGGACCTATAACAGT': 'CL:0008019',
#  'TTGGATCGACTTCTGG': 'CL:0008019',
#  'TTGGATTGGGTACCAC': 'CL:0000138',
#  'TTGGCCTAGAATTTCG': 'CL:0002551',
#  'TTGGCTCGCATGAGAC': 'CL:0008019',
#  'TTGGTCACACTCGTAA': 'CL:0002551',
#  'TTGTATCACACAGAAT': 'CL:0000058',
#  'TTGTCGTTCAGTTACC': 'CL:0002551',
#  'TTGTGAACCTAATCCG': 'CL:0008019',
#  'TTGTGGCCCTGACAGT': 'CL:0008019',
#  'TTGTGTATGCCACCAA': 'CL:0008019',
#  'TTGTGTTTCCCGAAAG': 'CL:0008019',
#  'TTGTTAGCAAATTCGA': 'CL:0000138',
#  'TTGTTTCACATCCAGG': 'CL:0008019'}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              316
# AAACAAGTATCTCCCA-1          0         50        102             2714
# AAACAATCTACTAGCA-1          0          3         43             2126
# AAACACCAATAACTGC-1          0         59         19              807
# AAACAGAGCGACTCCT-1          1         14         94             5191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4909
# TTGTTTCATTAGTCTA-1          0         60         30             2546
# TTGTTTCCATACAACT-1          0         45         27              152
# TTGTTTGTATTACACG-1          0         73         41               79
# TTGTTTGTGTAAATTC-1          0          7         51             2242
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                        NaN
# AAACAATCTACTAGCA-1                        NaN
# AAACACCAATAACTGC-1                        NaN
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0008019
# TTGTTTCATTAGTCTA-1                        NaN
# TTGTTTCCATACAACT-1                        NaN
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                        NaN
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 3996

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_31817/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              316
# AAACAAGTATCTCCCA-1          0         50        102             2714
# AAACAATCTACTAGCA-1          0          3         43             2126
# AAACACCAATAACTGC-1          0         59         19              807
# AAACAGAGCGACTCCT-1          1         14         94             5191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4909
# TTGTTTCATTAGTCTA-1          0         60         30             2546
# TTGTTTCCATACAACT-1          0         45         27              152
# TTGTTTGTATTACACG-1          0         73         41               79
# TTGTTTGTGTAAATTC-1          0          7         51             2242
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                    unknown
# AAACAATCTACTAGCA-1                    unknown
# AAACACCAATAACTGC-1                    unknown
# AAACAGAGCGACTCCT-1                 CL:0002551
# ...                                       ...
# TTGTTTCACATCCAGG-1                 CL:0008019
# TTGTTTCATTAGTCTA-1                    unknown
# TTGTTTCCATACAACT-1                    unknown
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                    unknown
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0002551',
#  'CL:0008019',
#  'CL:0000515',
#  'CL:0000138',
#  'CL:0000058',
#  'CL:0000646',
#  'CL:0000187',
#  'CL:0000057',
#  'CL:0002573',
#  'CL:0002355',
#  'CL:0000388']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['HsapDv:0000026']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    HsapDv:0000026
# AAACAAGTATCTCCCA-1    HsapDv:0000026
# AAACAATCTACTAGCA-1    HsapDv:0000026
# AAACACCAATAACTGC-1    HsapDv:0000026
# AAACAGAGCGACTCCT-1    HsapDv:0000026
#                            ...
# TTGTTTCACATCCAGG-1    HsapDv:0000026
# TTGTTTCATTAGTCTA-1    HsapDv:0000026
# TTGTTTCCATACAACT-1    HsapDv:0000026
# TTGTTTGTATTACACG-1    HsapDv:0000026
# TTGTTTGTGTAAATTC-1    HsapDv:0000026
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['HsapDv:0000026']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:9606
# AAACAAGTATCTCCCA-1    NCBITaxon:9606
# AAACAATCTACTAGCA-1    NCBITaxon:9606
# AAACACCAATAACTGC-1    NCBITaxon:9606
# AAACAGAGCGACTCCT-1    NCBITaxon:9606
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:9606
# TTGTTTCATTAGTCTA-1    NCBITaxon:9606
# TTGTTTCCATACAACT-1    NCBITaxon:9606
# TTGTTTGTATTACACG-1    NCBITaxon:9606
# TTGTTTGTGTAAATTC-1    NCBITaxon:9606
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:9606']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000384
# AAACAAGTATCTCCCA-1    PATO:0000384
# AAACAATCTACTAGCA-1    PATO:0000384
# AAACACCAATAACTGC-1    PATO:0000384
# AAACAGAGCGACTCCT-1    PATO:0000384
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000384
# TTGTTTCATTAGTCTA-1    PATO:0000384
# TTGTTTCCATACAACT-1    PATO:0000384
# TTGTTTGTATTACACG-1    PATO:0000384
# TTGTTTGTGTAAATTC-1    PATO:0000384
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000384']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = "UBERON:0002103"

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              316
# AAACAAGTATCTCCCA-1          0         50        102             2714
# AAACAATCTACTAGCA-1          0          3         43             2126
# AAACACCAATAACTGC-1          0         59         19              807
# AAACAGAGCGACTCCT-1          1         14         94             5191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4909
# TTGTTTCATTAGTCTA-1          0         60         30             2546
# TTGTTTCCATACAACT-1          0         45         27              152
# TTGTTTGTATTACACG-1          0         73         41               79
# TTGTTTGTGTAAATTC-1          0          7         51             2242
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699523
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9699523
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699523
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699523
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9699523
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0008019  WSSS_THYst9699523
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9699523
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699523
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9699523
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699523
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000026
# AAACAAGTATCTCCCA-1                     HsapDv:0000026
# AAACAATCTACTAGCA-1                     HsapDv:0000026
# AAACACCAATAACTGC-1                     HsapDv:0000026
# AAACAGAGCGACTCCT-1                     HsapDv:0000026
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000026
# TTGTTTCATTAGTCTA-1                     HsapDv:0000026
# TTGTTTCCATACAACT-1                     HsapDv:0000026
# TTGTTTGTATTACACG-1                     HsapDv:0000026
# TTGTTTGTGTAAATTC-1                     HsapDv:0000026
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#adata.obsm['X_spatial'] = adata.obsm['spatial']

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699523': {'metadata': {'chemistry_description': "Spatial 3' v1",
#                  'software_version': '4.0'},
#                 'images': {'hires': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8),
#                  'lowres': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 116.21939514763997,
#                  'tissue_hires_scalef': 0.07496252,
#                  'fiducial_diameter_fullres': 187.73902293080303,
#                  'tissue_lowres_scalef': 0.022488756}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Data/Full_res_image/WSSS_THYst9699523.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
adata.uns['title'] = library_id

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1          0          0         16              316
# AAACAAGTATCTCCCA-1          0         50        102             2714
# AAACAATCTACTAGCA-1          0          3         43             2126
# AAACACCAATAACTGC-1          0         59         19              807
# AAACAGAGCGACTCCT-1          1         14         94             5191
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1          1         58         42             4909
# TTGTTTCATTAGTCTA-1          0         60         30             2546
# TTGTTTCCATACAACT-1          0         45         27              152
# TTGTTTGTATTACACG-1          0         73         41               79
# TTGTTTGTGTAAATTC-1          0          7         51             2242
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id           donor_id  \
# AAACAACGAATAGTTC-1                    unknown  WSSS_THYst9699523
# AAACAAGTATCTCCCA-1                    unknown  WSSS_THYst9699523
# AAACAATCTACTAGCA-1                    unknown  WSSS_THYst9699523
# AAACACCAATAACTGC-1                    unknown  WSSS_THYst9699523
# AAACAGAGCGACTCCT-1                 CL:0002551  WSSS_THYst9699523
# ...                                       ...                ...
# TTGTTTCACATCCAGG-1                 CL:0008019  WSSS_THYst9699523
# TTGTTTCATTAGTCTA-1                    unknown  WSSS_THYst9699523
# TTGTTTCCATACAACT-1                    unknown  WSSS_THYst9699523
# TTGTTTGTATTACACG-1                    unknown  WSSS_THYst9699523
# TTGTTTGTGTAAATTC-1                    unknown  WSSS_THYst9699523
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     HsapDv:0000026
# AAACAAGTATCTCCCA-1                     HsapDv:0000026
# AAACAATCTACTAGCA-1                     HsapDv:0000026
# AAACACCAATAACTGC-1                     HsapDv:0000026
# AAACAGAGCGACTCCT-1                     HsapDv:0000026
# ...                                               ...
# TTGTTTCACATCCAGG-1                     HsapDv:0000026
# TTGTTTCATTAGTCTA-1                     HsapDv:0000026
# TTGTTTCCATACAACT-1                     HsapDv:0000026
# TTGTTTGTATTACACG-1                     HsapDv:0000026
# TTGTTTGTGTAAATTC-1                     HsapDv:0000026
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1            NCBITaxon:9606
# AAACAAGTATCTCCCA-1            NCBITaxon:9606
# AAACAATCTACTAGCA-1            NCBITaxon:9606
# AAACACCAATAACTGC-1            NCBITaxon:9606
# AAACAGAGCGACTCCT-1            NCBITaxon:9606
# ...                                      ...
# TTGTTTCACATCCAGG-1            NCBITaxon:9606
# TTGTTTCATTAGTCTA-1            NCBITaxon:9606
# TTGTTTCCATACAACT-1            NCBITaxon:9606
# TTGTTTGTATTACACG-1            NCBITaxon:9606
# TTGTTTGTGTAAATTC-1            NCBITaxon:9606
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                  unknown
# AAACAAGTATCTCCCA-1                                  unknown
# AAACAATCTACTAGCA-1                                  unknown
# AAACACCAATAACTGC-1                                  unknown
# AAACAGAGCGACTCCT-1                                  unknown
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                  unknown
# TTGTTTCATTAGTCTA-1                                  unknown
# TTGTTTCCATACAACT-1                                  unknown
# TTGTTTGTATTACACG-1                                  unknown
# TTGTTTGTGTAAATTC-1                                  unknown
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1         PATO:0000384              na      tissue
# AAACAAGTATCTCCCA-1         PATO:0000384              na      tissue
# AAACAATCTACTAGCA-1         PATO:0000384              na      tissue
# AAACACCAATAACTGC-1         PATO:0000384              na      tissue
# AAACAGAGCGACTCCT-1         PATO:0000384              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1         PATO:0000384              na      tissue
# TTGTTTCATTAGTCTA-1         PATO:0000384              na      tissue
# TTGTTTCCATACAACT-1         PATO:0000384              na      tissue
# TTGTTTGTATTACACG-1         PATO:0000384              na      tissue
# TTGTTTGTGTAAATTC-1         PATO:0000384              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0002103
# AAACAAGTATCTCCCA-1          UBERON:0002103
# AAACAATCTACTAGCA-1          UBERON:0002103
# AAACACCAATAACTGC-1          UBERON:0002103
# AAACAGAGCGACTCCT-1          UBERON:0002103
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0002103
# TTGTTTCATTAGTCTA-1          UBERON:0002103
# TTGTTTCCATACAACT-1          UBERON:0002103
# TTGTTTGTATTACACG-1          UBERON:0002103
# TTGTTTGTGTAAATTC-1          UBERON:0002103
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                  feature_is_filtered
# gene_ids
# ENSG00000243485                False
# ENSG00000237613                False
# ENSG00000186092                False
# ENSG00000238009                False
# ENSG00000239945                False
# ...                              ...
# ENSG00000277856                False
# ENSG00000275063                False
# ENSG00000271254                False
# ENSG00000277475                False
# ENSG00000268674                False
#
# [32831 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'WSSS_THYst9699523': {'images': {'hires': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8),
#                  'fullres': array([[[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         ...,
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]],
#
#                         [[237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          ...,
#                          [237, 237, 240],
#                          [237, 237, 240],
#                          [237, 237, 240]]], dtype=uint8)},
#                 'scalefactors': {'spot_diameter_fullres': 116.21939514763997,
#                  'tissue_hires_scalef': 0.07496252}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of whole embryonic limb samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', 'WSSS_THYst9699523'),
#              ('spatial_metadata',
#               {'chemistry_description': "Spatial 3' v1",
#                'software_version': '4.0'})])

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/limb_cell_atlas/Final_objects/to_upload/visium_slide5.h5ad', compression = 'gzip')

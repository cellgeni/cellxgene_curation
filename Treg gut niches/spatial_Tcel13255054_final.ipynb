# %% [markdown]
# ### **Curating Tcel13255054**

# %% [markdown]
# Article:   Immune microniches shape intestinal Treg function

# %% [markdown]
# DOI: https://doi.org/10.1038/s41586-024-07251-0

# %% [markdown]
# Data Source :  https://treg-gut-niches.cellgeni.sanger.ac.uk/

# %% [markdown]
# ##### **Packages required for curation**

# %%
#Import all packages required for curation

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import scipy
from tqdm import tqdm
from scipy import sparse
from scipy.sparse import csr_matrix
import anndata as ad
import os
import subprocess
import math
import squidpy as sq
from PIL import Image
from pyometiff import OMETIFFReader

# %% [markdown]
# ### **Curation Schema**

# %% [markdown]
# ##### **X (Matrix Layers)**

# %% [markdown]
# ##### **AnnData object**

# %%
# Load the AnnData object

# %%
folder = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255054_mm10-2020-A/'

#REQUIRED to include background spots, so specify raw_feature_bc_matrix.h5
adata = sq.read.visium(folder, counts_file='raw_feature_bc_matrix.h5')
# Out:
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /nfs/users/nfs_s/sa32/anaconda/envs/shibla_env/lib/python3.11/site-packages/anndata/_core/anndata.py:1820: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
# Check if adata.X is a sparse matrix
if scipy.sparse.issparse(adata.X):
    # For sparse matrices, use the count_nonzero method of sparse matrices
    non_zero_counts = adata.X.getnnz(axis=1)
else:
    # For dense matrices, use np.count_nonzero
    non_zero_counts = np.count_nonzero(adata.X, axis=1)

# Filter observations based on the condition 'in_tissue' == 1
non_zero_counts_in_tissue = non_zero_counts[adata.obs['in_tissue'] == 1]

# Add this information to adata.obs
adata.obs['non_zero_counts'] = non_zero_counts

# Check for any zero values
any_zero_values = (non_zero_counts_in_tissue == 0).any()

if any_zero_values:
    print("There are zero values in 'non_zero_counts' for observations in tissue.")
else:
    print("There are no zero values in 'non_zero_counts' for observations in tissue.")

# Count the number of zero values
num_zero_values = (non_zero_counts_in_tissue == 0).sum()
num_zero_values
# Out:
# There are no zero values in 'non_zero_counts' for observations in tissue.
# 0

# %%
all_zero_rows = np.asarray(adata.X.sum(axis=1)).flatten() == 0
all_zero_cells_indices = np.where(all_zero_rows)[0]
all_zero_cells = adata[all_zero_cells_indices]
in_tissue_all_zero_cells = all_zero_cells[all_zero_cells.obs['in_tissue'] == 1]
print("Cell names of identified all-zero cells:")
print(all_zero_cells.obs.index.tolist())
# Out:
# Cell names of identified all-zero cells:
# ['AGTGGGAGTATACACG-1']

# %%
import pandas as pd

# Ensure the 'array_col' column exists in adata.obs
if 'array_row' in adata.obs:
    # Find the indices where the values in 'array_col' are NaN
    nan_indices = adata.obs[pd.isna(adata.obs['array_row'])].index
    print("Indices with NaN values in 'array_row':", nan_indices.tolist())
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# Indices with NaN values in 'array_row': ['ACGCCTGACACGCGCT-1']

# %%
if 'array_col' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_col'].fillna(0)
    print("NaN values in 'array_col' have been replaced with 0.")
else:
    print("The 'array_col' column does not exist in adata.obs")
# Out:
# NaN values in 'array_col' have been replaced with 0.

# %%
if 'array_row' in adata.obs:
    adata.obs['array_col'] = adata.obs['array_row'].fillna(0)
    print("NaN values in 'array_row have been replaced with 0.")
else:
    print("The 'array_row' column does not exist in adata.obs")
# Out:
# NaN values in 'array_row have been replaced with 0.

# %%
if 'in_tissue' in adata.obs:
    adata.obs['in_tissue'] = adata.obs['in_tissue'].fillna(0)
    print("NaN values in 'in_tissue have been replaced with 0.")
else:
    print("The 'in_tissue' column does not exist in adata.obs")
# Out:
# NaN values in 'in_tissue have been replaced with 0.

# %%
#SpaceRanger will not output spots that have zero reads mapped, so fill those in with 0s, if needed
if adata.obs.shape[0] < 4992:
    all_barcodes = pd.read_csv(folder + 'spatial/tissue_positions.csv', header=None)
    missing_barcodes = all_barcodes[all_barcodes[0].isin(list(adata.obs.index)) == False]
    missing_barcodes.set_index(0, inplace=True)
    missing_barcodes.rename(columns={1: 'in_tissue', 2:'array_row', 3:'array_col'}, inplace=True)
    empty_matrix = sparse.csr_matrix((missing_barcodes.shape[0], adata.var.shape[0]))
    missing_adata = ad.AnnData(empty_matrix, var=adata.var, obs=missing_barcodes[['in_tissue','array_row','array_col']])
    comb_adata = ad.concat([adata, missing_adata], uns_merge='first', merge='first')
    comb_adata.obsm['spatial'] = np.concatenate((adata.obsm['spatial'],missing_barcodes[[5,4]].values))
    adata = comb_adata

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4992 × 32285
#     obs: 'in_tissue', 'array_row', 'array_col', 'non_zero_counts'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %% [markdown]
# ##### **X- expression matrix**

# %%
adata.X
# Out:
# <4992x32285 sparse matrix of type '<class 'numpy.float32'>'
# 	with 10118250 stored elements in Compressed Sparse Row format>

# %%
print(adata.X)
# Out:
#   (0, 8)	1.0
#   (0, 10)	2.0
#   (0, 24)	1.0
#   (0, 30)	1.0
#   (0, 34)	1.0
#   (0, 38)	1.0
#   (0, 40)	2.0
#   (0, 63)	15.0
#   (0, 69)	1.0
#   (0, 115)	1.0
#   (0, 119)	1.0
#   (0, 123)	1.0
#   (0, 156)	4.0
#   (0, 167)	1.0
#   (0, 168)	2.0
#   (0, 175)	1.0
#   (0, 178)	2.0
#   (0, 179)	1.0
#   (0, 185)	5.0
#   (0, 188)	1.0
#   (0, 193)	6.0
#   (0, 194)	1.0
#   (0, 198)	1.0
#   (0, 213)	2.0
#   (0, 218)	1.0
#   :	:
#   (4991, 31040)	1.0
#   (4991, 31043)	1.0
#   (4991, 31080)	4.0
#   (4991, 31102)	1.0
#   (4991, 31173)	1.0
#   (4991, 31193)	1.0
#   (4991, 31236)	1.0
#   (4991, 31258)	1.0
#   (4991, 31276)	1.0
#   (4991, 31323)	1.0
#   (4991, 31324)	1.0
#   (4991, 31339)	2.0
#   (4991, 31343)	1.0
#   (4991, 31414)	1.0
#   (4991, 31439)	1.0
#   (4991, 31450)	15.0
#   (4991, 31480)	1.0
#   (4991, 32195)	2.0
#   (4991, 32196)	2.0
#   (4991, 32197)	14.0
#   (4991, 32198)	2.0
#   (4991, 32200)	7.0
#   (4991, 32201)	16.0
#   (4991, 32204)	4.0
#   (4991, 32207)	3.0

# %% [markdown]
# ##### **Variables(var)**

# %%
adata.var
# Out:
#                       gene_ids    feature_types genome
# Xkr4        ENSMUSG00000051951  Gene Expression   mm10
# Gm1992      ENSMUSG00000089699  Gene Expression   mm10
# Gm19938     ENSMUSG00000102331  Gene Expression   mm10
# Gm37381     ENSMUSG00000102343  Gene Expression   mm10
# Rp1         ENSMUSG00000025900  Gene Expression   mm10
# ...                        ...              ...    ...
# AC124606.1  ENSMUSG00000095523  Gene Expression   mm10
# AC133095.2  ENSMUSG00000095475  Gene Expression   mm10
# AC133095.1  ENSMUSG00000094855  Gene Expression   mm10
# AC234645.1  ENSMUSG00000095019  Gene Expression   mm10
# AC149090.1  ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 3 columns]

# %%
adata.var.set_index('gene_ids', inplace=True)

# %%
adata.var
# Out:
#                       feature_types genome
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10
# ENSMUSG00000089699  Gene Expression   mm10
# ENSMUSG00000102331  Gene Expression   mm10
# ENSMUSG00000102343  Gene Expression   mm10
# ENSMUSG00000025900  Gene Expression   mm10
# ...                             ...    ...
# ENSMUSG00000095523  Gene Expression   mm10
# ENSMUSG00000095475  Gene Expression   mm10
# ENSMUSG00000094855  Gene Expression   mm10
# ENSMUSG00000095019  Gene Expression   mm10
# ENSMUSG00000095041  Gene Expression   mm10
#
# [32285 rows x 2 columns]

# %%
approved_genes = pd.read_csv('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Endometrium_reference_integrated_atlas/genes_approved.csv')

# %%
genedict = {key: 1 for key in list(approved_genes.feature_id)}

# %%
var_to_keep_adata = [x for x in adata.var_names if (x in genedict)]

# %%
adata = adata[:, var_to_keep_adata].copy()

# %%
adata.var['feature_is_filtered'] = [False] * len(adata.var)

# %%
adata.var
# Out:
#                       feature_types genome  feature_is_filtered
# gene_ids
# ENSMUSG00000051951  Gene Expression   mm10                False
# ENSMUSG00000089699  Gene Expression   mm10                False
# ENSMUSG00000102331  Gene Expression   mm10                False
# ENSMUSG00000102343  Gene Expression   mm10                False
# ENSMUSG00000025900  Gene Expression   mm10                False
# ...                             ...    ...                  ...
# ENSMUSG00000095523  Gene Expression   mm10                False
# ENSMUSG00000095475  Gene Expression   mm10                False
# ENSMUSG00000094855  Gene Expression   mm10                False
# ENSMUSG00000095019  Gene Expression   mm10                False
# ENSMUSG00000095041  Gene Expression   mm10                False
#
# [32101 rows x 3 columns]

# %%
del adata.var['feature_types']
del adata.var['genome']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %% [markdown]
# #### **Observations(obs) (Cell metadata)**

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             4282
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             4633
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             2856
# AAACACCAATAACTGC-1        1.0       59.0       59.0              593
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             4783
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0              250
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              618
# TTGTTTCCATACAACT-1        1.0       45.0       45.0              316
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              154
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2472
#
# [4992 rows x 4 columns]

# %% [markdown]
# #### **assay_ontology_term_id**

# %%
adata.obs['assay_ontology_term_id'] = 'EFO:0010961'

# %%
adata.obs['assay_ontology_term_id'] = adata.obs['assay_ontology_term_id'].astype('category')

# %% [markdown]
# #### **cell_type_ontology_term_id**

# %%
adata1 = sc.read_h5ad('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/Tcel13255054_download.h5ad')

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACACCAATAACTGC-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGGGTCTATATT-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1        1.0  1B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1        1.0  1B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1               2856
# Mus_Tcel13255054_AAACACCAATAACTGC-1                593
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1               5478
# Mus_Tcel13255054_AAACAGGGTCTATATT-1               1205
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1               1052
# ...                                                ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1               3557
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1               5176
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                586
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                618
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1               2472
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                 7.957528        6380.0
# Mus_Tcel13255054_AAACACCAATAACTGC-1                 6.386879         742.0
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                 8.608678       17597.0
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                 7.095064        1733.0
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                 6.959399        1571.0
# ...                                                      ...           ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                 8.176954        7941.0
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                 8.551981       15544.0
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                 6.375025         687.0
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                 6.428105         831.0
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                 7.813187        5233.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1            8.761080
# Mus_Tcel13255054_AAACACCAATAACTGC-1            6.610696
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1            9.775540
# Mus_Tcel13255054_AAACAGGGTCTATATT-1            7.458186
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1            7.360104
# ...                                                 ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1            8.979920
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1            9.651494
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1            6.533789
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1            6.723833
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1            8.562931
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                   21.347963
# Mus_Tcel13255054_AAACACCAATAACTGC-1                   21.563343
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                   20.668295
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                   18.522793
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                   20.305538
# ...                                                         ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                   15.338119
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                   15.742409
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                   20.232897
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                   26.835138
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                   21.612841
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    28.479624
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    33.557953
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    27.595613
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    27.178303
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    30.108212
# ...                                                          ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    23.485706
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    23.359495
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    29.257643
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    37.665462
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    29.161093
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    37.727272
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    47.035042
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    36.653976
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    38.834393
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    43.093571
# ...                                                          ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    33.622971
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    33.118889
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    43.813683
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    49.699158
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    38.715843
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    53.949844  ...
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    87.466309  ...
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    50.656361  ...
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    59.319099  ...
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    64.863144  ...
# ...                                                          ...  ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    49.427025  ...
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    47.941326  ...
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    87.481804  ...
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    85.800240  ...
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    55.685074  ...
#
#                                              donor_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACACCAATAACTGC-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGGGTCTATATT-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1  1B_Hh.anti_IL10r
# ...                                               ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1  1B_Hh.anti_IL10r
#
#                                     development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                     MmusDv:0000061
# Mus_Tcel13255054_AAACACCAATAACTGC-1                     MmusDv:0000061
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                     MmusDv:0000061
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                     MmusDv:0000061
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                     MmusDv:0000061
# ...                                                                ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                     MmusDv:0000061
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                     MmusDv:0000061
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                     MmusDv:0000061
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1             PATO:0000461            True
# Mus_Tcel13255054_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13255054_AAACAGGGTCTATATT-1             PATO:0000461            True
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACAGGGTCTATATT-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                                       na
# Mus_Tcel13255054_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                                       na
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                                       na
# ...                                                                      ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                                       na
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id  suspension_type  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1              unknown               na
# Mus_Tcel13255054_AAACACCAATAACTGC-1              unknown               na
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1              unknown               na
# Mus_Tcel13255054_AAACAGGGTCTATATT-1              unknown               na
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1              unknown               na
# ...                                                  ...              ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1              unknown               na
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1              unknown               na
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1              unknown               na
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1              unknown               na
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1              unknown               na
#
#                                      tissue_type  tissue_ontology_term_id
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
# [2613 rows x 101 columns]

# %%
adata1.obs.columns
# Out:
# Index(['in_tissue', 'sample', 'n_genes_by_counts', 'log1p_n_genes_by_counts',
#        'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes',
#        'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes',
#        'pct_counts_in_top_500_genes',
#        ...
#        'donor_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'is_primary_data',
#        'organism_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'suspension_type', 'tissue_type',
#        'tissue_ontology_term_id'],
#       dtype='object', length=101)

# %%
adata1.obs['barcodes'] = adata1.obs_names
adata1.obs['barcodes'] = adata1.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata1.obs
# Out:
#                                      in_tissue            sample  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACACCAATAACTGC-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACAGGGTCTATATT-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1        1.0  1B_Hh.anti_IL10r
# ...                                        ...               ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1        1.0  1B_Hh.anti_IL10r
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1        1.0  1B_Hh.anti_IL10r
#
#                                      n_genes_by_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1               2856
# Mus_Tcel13255054_AAACACCAATAACTGC-1                593
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1               5478
# Mus_Tcel13255054_AAACAGGGTCTATATT-1               1205
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1               1052
# ...                                                ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1               3557
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1               5176
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                586
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                618
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1               2472
#
#                                      log1p_n_genes_by_counts  total_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                 7.957528        6380.0
# Mus_Tcel13255054_AAACACCAATAACTGC-1                 6.386879         742.0
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                 8.608678       17597.0
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                 7.095064        1733.0
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                 6.959399        1571.0
# ...                                                      ...           ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                 8.176954        7941.0
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                 8.551981       15544.0
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                 6.375025         687.0
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                 6.428105         831.0
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                 7.813187        5233.0
#
#                                      log1p_total_counts  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1            8.761080
# Mus_Tcel13255054_AAACACCAATAACTGC-1            6.610696
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1            9.775540
# Mus_Tcel13255054_AAACAGGGTCTATATT-1            7.458186
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1            7.360104
# ...                                                 ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1            8.979920
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1            9.651494
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1            6.533789
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1            6.723833
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1            8.562931
#
#                                      pct_counts_in_top_50_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                   21.347963
# Mus_Tcel13255054_AAACACCAATAACTGC-1                   21.563343
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                   20.668295
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                   18.522793
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                   20.305538
# ...                                                         ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                   15.338119
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                   15.742409
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                   20.232897
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                   26.835138
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                   21.612841
#
#                                      pct_counts_in_top_100_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    28.479624
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    33.557953
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    27.595613
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    27.178303
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    30.108212
# ...                                                          ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    23.485706
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    23.359495
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    29.257643
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    37.665462
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    29.161093
#
#                                      pct_counts_in_top_200_genes  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    37.727272
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    47.035042
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    36.653976
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    38.834393
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    43.093571
# ...                                                          ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    33.622971
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    33.118889
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    43.813683
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    49.699158
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    38.715843
#
#                                      pct_counts_in_top_500_genes  ...  \
# spot_id                                                           ...
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                    53.949844  ...
# Mus_Tcel13255054_AAACACCAATAACTGC-1                    87.466309  ...
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                    50.656361  ...
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                    59.319099  ...
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                    64.863144  ...
# ...                                                          ...  ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                    49.427025  ...
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                    47.941326  ...
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                    87.481804  ...
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                    85.800240  ...
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                    55.685074  ...
#
#                                      development_stage_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                      MmusDv:0000061
# Mus_Tcel13255054_AAACACCAATAACTGC-1                      MmusDv:0000061
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                      MmusDv:0000061
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                      MmusDv:0000061
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                      MmusDv:0000061
# ...                                                                 ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                      MmusDv:0000061
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                      MmusDv:0000061
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                      MmusDv:0000061
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                      MmusDv:0000061
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                      MmusDv:0000061
#
#                                     disease_ontology_term_id is_primary_data  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1             PATO:0000461            True
# Mus_Tcel13255054_AAACACCAATAACTGC-1             PATO:0000461            True
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1             PATO:0000461            True
# Mus_Tcel13255054_AAACAGGGTCTATATT-1             PATO:0000461            True
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1             PATO:0000461            True
# ...                                                      ...             ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1             PATO:0000461            True
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1             PATO:0000461            True
#
#                                     organism_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACACCAATAACTGC-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACAGGGTCTATATT-1           NCBITaxon:10090
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1           NCBITaxon:10090
# ...                                                       ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                                     self_reported_ethnicity_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1                                       na
# Mus_Tcel13255054_AAACACCAATAACTGC-1                                       na
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1                                       na
# Mus_Tcel13255054_AAACAGGGTCTATATT-1                                       na
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1                                       na
# ...                                                                      ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1                                       na
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1                                       na
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1                                       na
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1                                       na
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1                                       na
#
#                                     sex_ontology_term_id suspension_type  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1              unknown              na
# Mus_Tcel13255054_AAACACCAATAACTGC-1              unknown              na
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1              unknown              na
# Mus_Tcel13255054_AAACAGGGTCTATATT-1              unknown              na
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1              unknown              na
# ...                                                  ...             ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1              unknown              na
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1              unknown              na
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1              unknown              na
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1              unknown              na
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1              unknown              na
#
#                                      tissue_type  tissue_ontology_term_id  \
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACACCAATAACTGC-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACAGGGTCTATATT-1       tissue           UBERON:0001155
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1       tissue           UBERON:0001155
# ...                                          ...                      ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1       tissue           UBERON:0001155
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1       tissue           UBERON:0001155
#
#                                              barcodes
# spot_id
# Mus_Tcel13255054_AAACAATCTACTAGCA-1  AAACAATCTACTAGCA
# Mus_Tcel13255054_AAACACCAATAACTGC-1  AAACACCAATAACTGC
# Mus_Tcel13255054_AAACAGCTTTCAGAAG-1  AAACAGCTTTCAGAAG
# Mus_Tcel13255054_AAACAGGGTCTATATT-1  AAACAGGGTCTATATT
# Mus_Tcel13255054_AAACATGGTGAGAGGA-1  AAACATGGTGAGAGGA
# ...                                               ...
# Mus_Tcel13255054_TTGTTAGCAAATTCGA-1  TTGTTAGCAAATTCGA
# Mus_Tcel13255054_TTGTTCAGTGTGCTAC-1  TTGTTCAGTGTGCTAC
# Mus_Tcel13255054_TTGTTGTGTGTCAAGA-1  TTGTTGTGTGTCAAGA
# Mus_Tcel13255054_TTGTTTCATTAGTCTA-1  TTGTTTCATTAGTCTA
# Mus_Tcel13255054_TTGTTTGTGTAAATTC-1  TTGTTTGTGTAAATTC
#
# [2613 rows x 102 columns]

# %%
# Ensure 'barcode' and 'cell_type_ontology_term_id' are columns in adata.obs
if 'barcodes' in adata1.obs.columns and 'cell_type_ontology_term_id' in adata1.obs.columns:
    # Create the dictionary
    mapping = dict(zip(adata1.obs['barcodes'], adata1.obs['cell_type_ontology_term_id']))
else:
    raise KeyError("Columns 'barcode' and/or 'cell_type_ontology_term_id' not found in adata1.obs")

# %%
mapping
# Out:
# {'AAACAATCTACTAGCA': 'CL:0000584',
#  'AAACACCAATAACTGC': 'CL:0000844',
#  'AAACAGCTTTCAGAAG': 'CL:0000186',
#  'AAACAGGGTCTATATT': 'CL:0000844',
#  'AAACATGGTGAGAGGA': 'CL:0000844',
#  'AAACATTTCCCGGATT': 'CL:0000844',
#  'AAACCGGGTAGGTACC': 'CL:0000844',
#  'AAACCTCATGAAGTTG': 'CL:0000844',
#  'AAACGAAGAACATACC': 'CL:0000584',
#  'AAACGAAGATGGAGTA': 'CL:0000186',
#  'AAACGAGACGGTTGAT': 'CL:0000186',
#  'AAACGGGCGTACGGGT': 'CL:0000844',
#  'AAACGGTTGCGAACTG': 'CL:0000844',
#  'AAACTCGGTTCGCAAT': 'CL:0000844',
#  'AAACTGCTGGCTCCAA': 'CL:0000844',
#  'AAACTTAATTGCACGC': 'CL:0000844',
#  'AAACTTGCAAACGTAT': 'CL:0000844',
#  'AAAGAATGACCTTAGA': 'CL:0000844',
#  'AAAGAATGTGGACTAA': 'CL:0000844',
#  'AAAGACCCAAGTCGCG': 'CL:0000844',
#  'AAAGGCCCTATAATAC': 'CL:0000844',
#  'AAAGGCTCTCGCGCCG': 'CL:0000844',
#  'AAAGGGATGTAGCAAG': 'CL:0000186',
#  'AAAGGGCAGCTTGAAT': 'CL:0000844',
#  'AAAGTAGCATTGCTCA': 'CL:0000844',
#  'AAAGTCACTGATGTAA': 'CL:0000844',
#  'AAAGTCGACCCTCAGT': 'CL:0000844',
#  'AAAGTGTGATTTATCT': 'CL:0000844',
#  'AAAGTTGACTCCCGTA': 'CL:0000844',
#  'AAATAACCATACGGGA': 'CL:0000844',
#  'AAATACCTATAAGCAT': 'CL:0000844',
#  'AAATAGCTTAGACTTT': 'CL:0000844',
#  'AAATCCGATACACGCC': 'CL:0000844',
#  'AAATCGCGGAAGGAGT': 'CL:0000844',
#  'AAATCGTGTACCACAA': 'CL:0000844',
#  'AAATCTAGCCCTGCTA': 'CL:0000844',
#  'AAATGACTGATCAAAC': 'CL:0000584',
#  'AAATGCTCGTTACGTT': 'CL:0000844',
#  'AAATGGCATGTCTTGT': 'CL:0000844',
#  'AAATGGCCCGTGCCCT': 'CL:0000844',
#  'AAATGGTCAATGTGCC': 'CL:0000584',
#  'AAATTAATAAGCGCGA': 'CL:0000844',
#  'AAATTACACGACTCTG': 'CL:0000844',
#  'AAATTACCTATCGATG': 'CL:0000844',
#  'AAATTGATAGTCCTTT': 'CL:0000844',
#  'AACAACTGGTAGTTGC': 'CL:0000844',
#  'AACAATACATTGTCGA': 'CL:0000844',
#  'AACAATTACTCTACGC': 'CL:0000844',
#  'AACACACGCTCGCCGC': 'CL:0000844',
#  'AACACGAGACGCGGCC': 'CL:0000844',
#  'AACACGCGGCCGCGAA': 'CL:0000844',
#  'AACAGCTGTGTGGCAA': 'CL:0000584',
#  'AACAGGAAATCGAATA': 'CL:0000844',
#  'AACATAGCGTGTATCG': 'CL:0000844',
#  'AACATATCAACTGGTG': 'CL:0000844',
#  'AACATTGTGACTCGAG': 'CL:0000844',
#  'AACCAAGACTTCTCTG': 'CL:0000844',
#  'AACCATAGGGTTGAAC': 'CL:0000844',
#  'AACCCATCCCATGATC': 'CL:0000844',
#  'AACCCGACAACCCGTG': 'CL:0000584',
#  'AACCCGCTGTATTCCA': 'CL:0000584',
#  'AACCCTACTGTCAATA': 'CL:0000844',
#  'AACCGAGCTTGGTCAT': 'CL:0000584',
#  'AACCGCTAAGGGATGC': 'CL:0000844',
#  'AACCGTTGTGTTTGCT': 'CL:0000584',
#  'AACCTCGCTTTAGCCC': 'CL:0000584',
#  'AACCTTTAAATACGGT': 'CL:0000844',
#  'AACGAAAGTCGTCCCA': 'CL:0000844',
#  'AACGATAATGCCGTAG': 'CL:0000844',
#  'AACGATATGTCAACTG': 'CL:0000576',
#  'AACGCGGTCTCCAGCC': 'CL:0000186',
#  'AACGCTGTTGCTGAAA': 'CL:0000844',
#  'AACGGACGTACGTATA': 'CL:0000584',
#  'AACGTACTGTGGGTAC': 'CL:0000584',
#  'AACGTCAGACTAGTGG': 'CL:0009010',
#  'AACGTGATGAAGGACA': 'CL:0000844',
#  'AACGTGCGAAAGTCTC': 'CL:0000844',
#  'AACTACCCGTTTGTCA': 'CL:0000186',
#  'AACTAGCGTATCGCAC': 'CL:0000584',
#  'AACTAGGCTTGGGTGT': 'CL:0000844',
#  'AACTCAAGTTAATTGC': 'CL:0000844',
#  'AACTCCAGAGCGTGTT': 'CL:0000584',
#  'AACTCCTAATCCCATG': 'CL:0000844',
#  'AACTCGATGGCGCAGT': 'CL:0000844',
#  'AACTCTCAATAGAGCG': 'CL:0000844',
#  'AACTGGGTCCCGACGT': 'CL:0007011',
#  'AACTGGTGTGGGCCTT': 'CL:0000584',
#  'AACTTGCGTTCTCGCG': 'CL:0000844',
#  'AACTTTACGGGAGCTT': 'CL:0000844',
#  'AACTTTAGCTGCTGAG': 'CL:0000584',
#  'AAGAAGGATCAGTTAG': 'CL:0000844',
#  'AAGACCAAATAACTCA': 'CL:0000844',
#  'AAGACCCAACTGAACA': 'CL:0000844',
#  'AAGACTAACCCGTTGT': 'CL:0000844',
#  'AAGACTGCAAGCTACT': 'CL:0000844',
#  'AAGAGATGAATCGGTA': 'CL:0000844',
#  'AAGAGCTCTTTATCGG': 'CL:0000186',
#  'AAGAGGATGTACGCGA': 'CL:0000186',
#  'AAGAGGCATGGATCGC': 'CL:0000186',
#  'AAGATGGCACCGGACC': 'CL:0000844',
#  'AAGATTGGCGGAACGT': 'CL:0000186',
#  'AAGCACCCTGCGTATC': 'CL:0000844',
#  'AAGCATACTCTCCTGA': 'CL:0000844',
#  'AAGCCACTTGCAGGTA': 'CL:0000844',
#  'AAGCCGAAGCGGTTTA': 'CL:0000584',
#  'AAGCGCAGGGCTTTGA': 'CL:0000584',
#  'AAGCGTCCCTCATCGA': 'CL:0000844',
#  'AAGCTCGTGCCAAGTC': 'CL:0000844',
#  'AAGCTCTTTCATGGTG': 'CL:0000844',
#  'AAGGAGAACTTATAAG': 'CL:0000844',
#  'AAGGATCGATCGCTTG': 'CL:0000844',
#  'AAGGATGAGGGACCTC': 'CL:0000186',
#  'AAGGCGCGTAAAGCTT': 'CL:0009010',
#  'AAGGGACAGATTCTGT': 'CL:0000844',
#  'AAGGGACTATGCATTC': 'CL:0000844',
#  'AAGGGTTTGATTTCAG': 'CL:0000844',
#  'AAGGTATCCTAATATA': 'CL:0000186',
#  'AAGGTGATAAACCAGC': 'CL:0000844',
#  'AAGTAGTGACGCGAGG': 'CL:0000584',
#  'AAGTCAATTGTCGTCA': 'CL:0000844',
#  'AAGTCTTCTGTGGCCT': 'CL:0000584',
#  'AAGTGACGACCGAATT': 'CL:0000186',
#  'AAGTGAGTCGGGTTTA': 'CL:0000584',
#  'AAGTGCAAAGGTAGAC': 'CL:0000844',
#  'AAGTGCCTTGACTGTA': 'CL:0000844',
#  'AAGTGCTTCTCTATTG': 'CL:0000844',
#  'AAGTTCACTCCAAGCT': 'CL:0000844',
#  'AAGTTCGGCCAACAGG': 'CL:0000844',
#  'AAGTTTACTAATGGCA': 'CL:0000584',
#  'AATAACAACGCTCGGC': 'CL:0000584',
#  'AATAAGTCCTCGAGAC': 'CL:0000844',
#  'AATACAATGTTTCAGG': 'CL:0000844',
#  'AATACCGGAGGGCTGT': 'CL:0000844',
#  'AATACCTGATGTGAAC': 'CL:0000844',
#  'AATAGAATCTGTTTCA': 'CL:0000844',
#  'AATAGTCCGTCCCGAC': 'CL:0000844',
#  'AATATCAAGGTCGGAT': 'CL:0000844',
#  'AATATCCTAGCAAACT': 'CL:0000844',
#  'AATATCGAATCAATGC': 'CL:0000844',
#  'AATATCGAGGGTTCTC': 'CL:0000844',
#  'AATATTGGAGTATTGA': 'CL:0000844',
#  'AATCATGTAAAGACTC': 'CL:0000844',
#  'AATCCATGCAAGGGTG': 'CL:0000844',
#  'AATCGAGGTCTCAAGG': 'CL:0000186',
#  'AATCGCCTCAGCGCCA': 'CL:0000584',
#  'AATCGTGAGCCGAGCA': 'CL:0000844',
#  'AATCTCTACTGTGGTT': 'CL:0000584',
#  'AATCTGCGTTGGGACG': 'CL:0000844',
#  'AATGACAGCAATGTCT': 'CL:0000844',
#  'AATGACGTAGGATGTC': 'CL:0000844',
#  'AATGACTGTCAGCCGG': 'CL:0000844',
#  'AATGAGTTCGCATATG': 'CL:0000844',
#  'AATGATGATACGCTAT': 'CL:0000186',
#  'AATGCAACCGGGTACC': 'CL:0000844',
#  'AATGCACCAAGCAATG': 'CL:0009010',
#  'AATGGTCCACCGTTCA': 'CL:0000844',
#  'AATGTATGGCACTGTA': 'CL:0000844',
#  'AATGTGCTAATCTGAG': 'CL:0000844',
#  'AATGTTAAGACCCTGA': 'CL:0000844',
#  'AATTAAAGGTCGGCGT': 'CL:0000844',
#  'AATTAACGGATTTCCA': 'CL:0000844',
#  'AATTACGAGACCCATC': 'CL:0000186',
#  'AATTATACCCAGCAAG': 'CL:0000844',
#  'AATTCATAAGGGATCT': 'CL:0000186',
#  'AATTCATTGTCATGCA': 'CL:0000584',
#  'AATTCCAAGCATGTAC': 'CL:0000844',
#  'AATTCTAGAGTTAGGC': 'CL:0000844',
#  'AATTGAACGCTCTGGT': 'CL:0000584',
#  'AATTGCAGCAATCGAC': 'CL:0000844',
#  'ACAAACCATGCGTCCT': 'CL:0000186',
#  'ACAAAGAAGGTAGGCC': 'CL:0000844',
#  'ACAAAGCATGACCTAG': 'CL:0000844',
#  'ACAAATGGTAGTGTTT': 'CL:0000584',
#  'ACAACAGCATGAGCTA': 'CL:0000844',
#  'ACAACGGTCCCTGCGA': 'CL:0000844',
#  'ACAAGCTATATGGAAG': 'CL:0000584',
#  'ACAAGGAAATCCGCCC': 'CL:0000844',
#  'ACAAGGACAAGAGGTT': 'CL:0000844',
#  'ACAAGGATGCTTTAGG': 'CL:0000844',
#  'ACAAGGGCAGGCTCTG': 'CL:0000844',
#  'ACAATAGTCGTACGTT': 'CL:0000186',
#  'ACAATCCATTTAAACC': 'CL:0000584',
#  'ACAATGAATACGGAGA': 'CL:0000844',
#  'ACAATTGTGTCTCTTT': 'CL:0000844',
#  'ACAATTTAGGAGGCTC': 'CL:0000844',
#  'ACAATTTGAGCAGTGG': 'CL:0000844',
#  'ACACAAAGACGGGTGG': 'CL:0000186',
#  'ACACACCAGGACCAGT': 'CL:0000844',
#  'ACACACTTTCTACACG': 'CL:0000844',
#  'ACACATGATCAAATCT': 'CL:0000844',
#  'ACACATTTCCGTAGAC': 'CL:0000844',
#  'ACACCCAGCATGCAGC': 'CL:0000844',
#  'ACACCGGTCTGACCGC': 'CL:0000186',
#  'ACACCTTAAGTAGGGC': 'CL:0000844',
#  'ACACCTTACTACTTGC': 'CL:0000844',
#  'ACACGGGAACTTAGGG': 'CL:0000844',
#  'ACAGAACTGAGAACAA': 'CL:0000844',
#  'ACAGCATAGAGCCAGT': 'CL:0000584',
#  'ACAGCGACATTCTCAT': 'CL:0000844',
#  'ACAGCGCACCCGCAGC': 'CL:0000844',
#  'ACAGGCACGGATCCTT': 'CL:0000844',
#  'ACAGTAATACAACTTG': 'CL:0000844',
#  'ACATAAGTCGTGGTGA': 'CL:0000844',
#  'ACATAATAAGGCGGTG': 'CL:0007011',
#  'ACATACAATCAAGCGG': 'CL:0000186',
#  'ACATCAGCTGGGACGC': 'CL:0000844',
#  'ACATCCTGGTAACTGT': 'CL:0000844',
#  'ACATCGATCGTTTACC': 'CL:0000584',
#  'ACATCGCAATATTCGG': 'CL:0009010',
#  'ACATCGTATGCAATGG': 'CL:0000844',
#  'ACATCGTTAACCTAGT': 'CL:0000844',
#  'ACATCTCAACGCGTAA': 'CL:0000844',
#  'ACATGGCGCCAAAGTA': 'CL:0000584',
#  'ACATTAGTTTATATCC': 'CL:0000844',
#  'ACATTCGCGCGGAATA': 'CL:0000844',
#  'ACCAAACTAGAAATCC': 'CL:0000844',
#  'ACCAACCGCACTCCAC': 'CL:0000844',
#  'ACCAATATGCAAGTTA': 'CL:0000844',
#  'ACCACACGGTTGATGG': 'CL:0000844',
#  'ACCACCAATGTAACAA': 'CL:0000584',
#  'ACCACGTGCAGCTATA': 'CL:0000844',
#  'ACCAGACCATAACAAC': 'CL:0000844',
#  'ACCAGCCCGGTCTTTG': 'CL:0000844',
#  'ACCAGGAGTGTGATCT': 'CL:0000584',
#  'ACCAGTGCGGGAGACG': 'CL:0000844',
#  'ACCATATCCGCAATAA': 'CL:0000844',
#  'ACCATCCGCCAACTAG': 'CL:0000186',
#  'ACCATCGTATATGGTA': 'CL:0000844',
#  'ACCCAACGCCCGTGGC': 'CL:0000844',
#  'ACCCACCTACATGCTC': 'CL:0000844',
#  'ACCCATCTTGAGGGTA': 'CL:0000186',
#  'ACCCATTTGTCCCTCT': 'CL:0000844',
#  'ACCCGAGCGAAATTAC': 'CL:0000844',
#  'ACCCGGAAACTCCCAG': 'CL:0000844',
#  'ACCCGGATGACGCATC': 'CL:0000844',
#  'ACCCGGTTACACTTCC': 'CL:0000844',
#  'ACCCTATAGGACTGAG': 'CL:0000844',
#  'ACCCTATGCCATATCG': 'CL:0000844',
#  'ACCCTCCCTTGCTATT': 'CL:0000844',
#  'ACCCTTCATCTGCGAA': 'CL:0000844',
#  'ACCGAAAGGGCCCTGC': 'CL:0000844',
#  'ACCGAAGAGTCTGGTT': 'CL:0000844',
#  'ACCGACACATCTCCCA': 'CL:0000844',
#  'ACCGACTGAGTCCCAC': 'CL:0000844',
#  'ACCGATGGTAGCATCG': 'CL:0000844',
#  'ACCGCGGTGGAAGTCG': 'CL:0000844',
#  'ACCGGGCCTTTGTTGA': 'CL:0000844',
#  'ACCGGTCAGGTACACC': 'CL:0000844',
#  'ACCGTCCACTGGGCCC': 'CL:0000844',
#  'ACCGTGACCACGTGGG': 'CL:0000844',
#  'ACCGTTCCCGCTCTGA': 'CL:0000844',
#  'ACCTAATCGACTTCCT': 'CL:0000584',
#  'ACCTACAGTATGTGGT': 'CL:0000844',
#  'ACCTACTATAAATCTA': 'CL:0000844',
#  'ACCTCAGCGAGGCGCA': 'CL:0000584',
#  'ACCTCCGCCCTCGCTG': 'CL:0000844',
#  'ACCTCGAACTTATGCT': 'CL:0000186',
#  'ACGAGAACCCATCACG': 'CL:0000844',
#  'ACGAGATATTTGCTTA': 'CL:0000584',
#  'ACGAGGATACCACTCT': 'CL:0000844',
#  'ACGAGGTTTACAACGT': 'CL:0000844',
#  'ACGAGTACGGATGCCC': 'CL:0000844',
#  'ACGATACATAGAACTA': 'CL:0000844',
#  'ACGATCATACATAGAG': 'CL:0000844',
#  'ACGATCATCTTGTAAA': 'CL:0000844',
#  'ACGATGCATATGTTAT': 'CL:0000844',
#  'ACGATGGATCCGATGC': 'CL:0000844',
#  'ACGCAAACTAATAGAT': 'CL:0000584',
#  'ACGCATACGTTTACTA': 'CL:0000844',
#  'ACGCCACTCGAAACAG': 'CL:0000844',
#  'ACGCCAGATGATTTCT': 'CL:0000186',
#  'ACGCCCAGCTGTCGAT': 'CL:0000844',
#  'ACGCCGCTAGACGACC': 'CL:0000844',
#  'ACGCGAAGTCAGACGA': 'CL:0000584',
#  'ACGCGCTACACAGGGT': 'CL:0000844',
#  'ACGCGGGCCAAGGACA': 'CL:0000584',
#  'ACGCGTTTCTTAAGAG': 'CL:0000844',
#  'ACGCTAGTGATACACT': 'CL:0000844',
#  'ACGCTGTGAGGCGTAG': 'CL:0000844',
#  'ACGGAATTTAGCAAAT': 'CL:0000844',
#  'ACGGACTCTCAAAGCG': 'CL:0000844',
#  'ACGGATGGTGCGGATA': 'CL:0000844',
#  'ACGGCCAACATGGACT': 'CL:0000584',
#  'ACGGCGACGATGGGAA': 'CL:0000844',
#  'ACGGCGGGTTGCCCTG': 'CL:0000844',
#  'ACGGCTGGATGTAGAA': 'CL:0000186',
#  'ACGGTACAGTTCAATG': 'CL:0000844',
#  'ACGTAGGAGAGTCGCT': 'CL:0000584',
#  'ACGTATTACTCCGATC': 'CL:0000844',
#  'ACGTCTCGTTCCGGGA': 'CL:0000844',
#  'ACGTGACAAAGTAAGT': 'CL:0000844',
#  'ACGTTAATGTCGAAGA': 'CL:0000844',
#  'ACGTTCCGCGCTCCGT': 'CL:0000844',
#  'ACGTTCTGTACAAGTC': 'CL:0000844',
#  'ACGTTGTCGTTGAAAG': 'CL:0000844',
#  'ACGTTTAGTTGTGATC': 'CL:0000844',
#  'ACTACAAAGAGAGGTG': 'CL:0000844',
#  'ACTACATCCCGACAAG': 'CL:0000844',
#  'ACTACCAGCTCTCTGG': 'CL:0000844',
#  'ACTACCATCCGAGGGC': 'CL:0000844',
#  'ACTACGCGTTAGAATT': 'CL:0000844',
#  'ACTATTCGTCCGTGGT': 'CL:0000844',
#  'ACTCAACGAATGTATT': 'CL:0000844',
#  'ACTCAAGTGCAAGGCT': 'CL:0000844',
#  'ACTCAATAAAGGCACG': 'CL:0000844',
#  'ACTCAGACCTGCTTCT': 'CL:0000844',
#  'ACTCATGGCAGCCTTC': 'CL:0000844',
#  'ACTCCAATATCATCAT': 'CL:0000844',
#  'ACTCCCATTCCTAAAG': 'CL:0000844',
#  'ACTCCCGAATTCGTTT': 'CL:0000844',
#  'ACTCCCTAATGCTAAA': 'CL:0000844',
#  'ACTCCCTAGAATAGTA': 'CL:0000844',
#  'ACTCGTCAGTAATCCC': 'CL:0000844',
#  'ACTCTCTGACTTAGGT': 'CL:0000584',
#  'ACTCTGACCTAATAGA': 'CL:0000844',
#  'ACTCTTGTATAGTAAC': 'CL:0000584',
#  'ACTGAAACGCCGTTAG': 'CL:0000844',
#  'ACTGCCCGCCATTCTC': 'CL:0000584',
#  'ACTGCTCGGAAGGATG': 'CL:0000844',
#  'ACTGGGATGCCAGTGC': 'CL:0000844',
#  'ACTGTATACGCGAGCA': 'CL:0000844',
#  'ACTGTGCTAGTAGATC': 'CL:0000844',
#  'ACTGTTTAGTGTAGGC': 'CL:0000844',
#  'ACTTACGCATCCACGC': 'CL:0000844',
#  'ACTTATACTTACCCGG': 'CL:0000584',
#  'ACTTATTAGGATCGGT': 'CL:0000844',
#  'ACTTATTTATGTGCCA': 'CL:0000844',
#  'ACTTCCAGTGGAAGCT': 'CL:0000186',
#  'ACTTCCATGCGGGACA': 'CL:0000844',
#  'ACTTCGCCATACGCAC': 'CL:0000186',
#  'ACTTGACTCCCTCTTT': 'CL:0000844',
#  'ACTTGCCATATTGTAC': 'CL:0000844',
#  'ACTTGGGCTTTCGCCA': 'CL:0000584',
#  'ACTTGTAGTCCCTTCA': 'CL:0000186',
#  'ACTTGTGGATGGAACG': 'CL:0000584',
#  'ACTTGTTACCGGATCA': 'CL:0000844',
#  'ACTTTACCCTCATGAA': 'CL:0000844',
#  'ACTTTCCTATAGCTTC': 'CL:0000844',
#  'ACTTTGACTGCATCCT': 'CL:0000584',
#  'ACTTTGGTCGTGCTCC': 'CL:0000186',
#  'AGAACCCTCAATTGGG': 'CL:0000186',
#  'AGAACGTGGTACATTC': 'CL:0009010',
#  'AGAACTGTACTTTGTA': 'CL:0000844',
#  'AGAAGAGCGCCGTTCC': 'CL:0000775',
#  'AGAAGGTTGTAGGTCG': 'CL:0000584',
#  'AGAAGTGATTCGTGAT': 'CL:0000844',
#  'AGAATAAATCTTCAGG': 'CL:0000844',
#  'AGAATACAGGCTATCC': 'CL:0000844',
#  'AGAATTATGGATTCGA': 'CL:0000844',
#  'AGAATTGTTTGACATA': 'CL:0000844',
#  'AGACATAGATCCTTCC': 'CL:0000844',
#  'AGACCAAACCACACCT': 'CL:0000584',
#  'AGACCATGGGATACAA': 'CL:0000584',
#  'AGACCCGCCCTCCTCG': 'CL:0000844',
#  'AGACCGCTCCGCGGTT': 'CL:0000584',
#  'AGACCGGGAAACCCTG': 'CL:0000844',
#  'AGACGAAGTGCCGGTC': 'CL:0000844',
#  'AGACGACGATGCCGCT': 'CL:0000844',
#  'AGACTAGCCTTCCAGA': 'CL:0000844',
#  'AGACTGTTACCGGGTC': 'CL:0000584',
#  'AGAGAAACACCAGAAA': 'CL:0000844',
#  'AGAGAACCGTCTAGGA': 'CL:0000186',
#  'AGAGAAGGAGTACAAT': 'CL:0000844',
#  'AGAGATCTCTAAAGCG': 'CL:0000844',
#  'AGAGCAGTTATGAGAC': 'CL:0000844',
#  'AGAGCGTACAAGCTCG': 'CL:0000844',
#  'AGAGGCTTCGGAAACC': 'CL:0000844',
#  'AGAGTAAACTTCACTA': 'CL:0000844',
#  'AGATAACTTCAGGGCC': 'CL:0000844',
#  'AGATATAATACGACTA': 'CL:0000844',
#  'AGATCGTGCATAAGAT': 'CL:0000186',
#  'AGATCTCAGGTGTGAT': 'CL:0000844',
#  'AGATGATGGAGTCTGG': 'CL:0000584',
#  'AGATGCAAGACGTGCA': 'CL:0000844',
#  'AGATGCATCCTGTGTC': 'CL:0000844',
#  'AGATTATAGGACGTTT': 'CL:0000186',
#  'AGCAAAGGCCGCTAGT': 'CL:0000844',
#  'AGCAACATATCTTATT': 'CL:0000844',
#  'AGCAACCGAAAGTAAT': 'CL:0000844',
#  'AGCACTTAAGGACGCC': 'CL:0000844',
#  'AGCAGAAGGAGAAAGA': 'CL:0000844',
#  'AGCAGCCAGATGAATA': 'CL:0000844',
#  'AGCATATCAATATGCT': 'CL:0000844',
#  'AGCATCATTTCGAAAG': 'CL:0000844',
#  'AGCATCGTCGATAATT': 'CL:0000186',
#  'AGCATTACGAGGCAAG': 'CL:0000844',
#  'AGCCACAGGTTACCCG': 'CL:0000844',
#  'AGCCACTCCCGTGCTT': 'CL:0000844',
#  'AGCCATATAGTATGTG': 'CL:0000844',
#  'AGCCCATACATGTAAG': 'CL:0000844',
#  'AGCCCGCAACAAGCAG': 'CL:0000844',
#  'AGCCCGGTAGCCTGTA': 'CL:0000584',
#  'AGCCCTAAGCGAAGTT': 'CL:0000844',
#  'AGCCGCAAATTCAAAT': 'CL:0000584',
#  'AGCGACCAACGATATT': 'CL:0000844',
#  'AGCGAGACGTGAAGGC': 'CL:0000844',
#  'AGCGATGCGCCTAATA': 'CL:0000844',
#  'AGCGCATAATGAATCG': 'CL:0000844',
#  'AGCGCGGGTGCCAATG': 'CL:0000057',
#  'AGCGGGAAGGGTCCAT': 'CL:0000844',
#  'AGCGGGTCTGACACTC': 'CL:0000584',
#  'AGCGTCTGAACCCGCA': 'CL:0000844',
#  'AGCGTGGTATTCTACT': 'CL:0000844',
#  'AGCTAACAAGCAATGT': 'CL:0000584',
#  'AGCTAAGTACGCAGGC': 'CL:0000844',
#  'AGCTAGAAGCAGAAGT': 'CL:0000186',
#  'AGCTCCATATATGTTC': 'CL:0000584',
#  'AGCTCTAGACGTTCCA': 'CL:0000844',
#  'AGCTCTTCCCAGTGCA': 'CL:0000844',
#  'AGCTCTTCGTAACCTT': 'CL:0000844',
#  'AGCTGTAACCTCAATC': 'CL:0000844',
#  'AGCTTATAGAGACCTG': 'CL:0000584',
#  'AGCTTGATCTTAACTT': 'CL:0000186',
#  'AGGACAGTCGAATCCC': 'CL:0000844',
#  'AGGACGACCCATTAGA': 'CL:0000844',
#  'AGGACGCTCGATGTTG': 'CL:0000844',
#  'AGGAGGCCTTCGCGCG': 'CL:0000844',
#  'AGGATAAAGTCGGGAT': 'CL:0000844',
#  'AGGATATAGGGATTTA': 'CL:0000844',
#  'AGGATATCCGACTGCA': 'CL:0000844',
#  'AGGATCACGCGATCTG': 'CL:0000844',
#  'AGGCAGATGCGTAAAC': 'CL:0000186',
#  'AGGCAGGGAGCGTACT': 'CL:0000186',
#  'AGGCATTGTCGTAGGG': 'CL:0000844',
#  'AGGCCCAGTGACTGGT': 'CL:0000844',
#  'AGGCCCATTGTACAGG': 'CL:0000844',
#  'AGGCCTATCATACCAA': 'CL:0000844',
#  'AGGCCTGAGAATCTCG': 'CL:0000844',
#  'AGGCTATGGTTAGCTT': 'CL:0000844',
#  'AGGCTTGCTAGACACC': 'CL:0000844',
#  'AGGGACAGCACGGCGG': 'CL:0000584',
#  'AGGGACCGGCTGCGTT': 'CL:0000844',
#  'AGGGACTCTACGCGAC': 'CL:0000844',
#  'AGGGCAGCGGCGTGGT': 'CL:0000584',
#  'AGGGCGAGCAGCTGAT': 'CL:0009010',
#  'AGGGCGTGATCGGCTA': 'CL:0000844',
#  'AGGGCTGCAGTTACAG': 'CL:0000844',
#  'AGGGTCGATGCGAACT': 'CL:0000844',
#  'AGGGTGCCGTTCTTTA': 'CL:0000844',
#  'AGGGTGCTCTCGAGGG': 'CL:0000844',
#  'AGGGTGGATAGTGCAT': 'CL:0000844',
#  'AGGGTTCCCTTTGGTT': 'CL:0000844',
#  'AGGTAACCTCCTATTC': 'CL:0000844',
#  'AGGTACGATATTGCCA': 'CL:0000844',
#  'AGGTAGATCGAGATAT': 'CL:0000584',
#  'AGGTAGGTACAAAGCT': 'CL:0000584',
#  'AGGTATAATTGATAGT': 'CL:0000844',
#  'AGGTCAGGTGAGAGTG': 'CL:0000844',
#  'AGGTCGCGGAGTTACT': 'CL:0000844',
#  'AGGTGTATCGCCATGA': 'CL:0000844',
#  'AGGTTGAGGCACGCTT': 'CL:0000844',
#  'AGGTTTCACACACCTT': 'CL:0000844',
#  'AGTAATGTCTTGCCGC': 'CL:0000844',
#  'AGTACAGAAGCTTATA': 'CL:0000844',
#  'AGTACGGGCACCTGGC': 'CL:0000186',
#  'AGTACTCTTATGCCCA': 'CL:0000844',
#  'AGTAGGTAACATACAT': 'CL:0000844',
#  'AGTATAATACTAGGCA': 'CL:0009010',
#  'AGTATACACAGCGACA': 'CL:0000844',
#  'AGTATGCTGGAGACCA': 'CL:0000844',
#  'AGTATTTGGCACGACC': 'CL:0000844',
#  'AGTCAAATGATGTGAT': 'CL:0000844',
#  'AGTCAAGATGACACTT': 'CL:0000844',
#  'AGTCACTAGCTCTCGA': 'CL:0000844',
#  'AGTCACTCCGCCTCAT': 'CL:0000844',
#  'AGTCAGCCACCGCCTG': 'CL:0000844',
#  'AGTCCATTGGCTGATG': 'CL:0000844',
#  'AGTCCCGCCTTTAATT': 'CL:0000844',
#  'AGTCGACGGTCTCAAG': 'CL:0000186',
#  'AGTCGGCTCAACTTTA': 'CL:0000844',
#  'AGTCGGTTGCGTGAGA': 'CL:0000844',
#  'AGTCGTATAAAGCAGA': 'CL:0000844',
#  'AGTCGTCGACCACCAA': 'CL:0000844',
#  'AGTCGTGGGCATTACG': 'CL:0000844',
#  'AGTCTCACAAGACTAC': 'CL:0000844',
#  'AGTCTGGACATCCTTG': 'CL:0000584',
#  'AGTCTTCTCCTCAAAT': 'CL:0000844',
#  'AGTGAACAAACTTCTC': 'CL:0000844',
#  'AGTGACCTACTTTACG': 'CL:0000584',
#  'AGTGAGACTTCCAGTA': 'CL:0000584',
#  'AGTGAGCCTCGCCGCC': 'CL:0000844',
#  'AGTGATAACCTGCGCG': 'CL:0000844',
#  'AGTGATATGAGTAGTT': 'CL:0000584',
#  'AGTGATTCAAGCAGGA': 'CL:0000844',
#  'AGTGCACGCTTAAGAA': 'CL:0000844',
#  'AGTGCGTAGCTCGTAA': 'CL:0000584',
#  'AGTGCTAAACACAGCA': 'CL:0000584',
#  'AGTGCTTGCACGAATA': 'CL:0000844',
#  'AGTGGCCCGCAAATGG': 'CL:0000844',
#  'AGTGGCGGCAATTTGA': 'CL:0000186',
#  'AGTGGCGTCTGAAGGT': 'CL:0000584',
#  'AGTGGCTCCGTCGGCC': 'CL:0000584',
#  'AGTGGTGTTACCCGTG': 'CL:0000844',
#  'AGTGTATTGCGCATTG': 'CL:0009010',
#  'AGTGTGGTCTATTGTG': 'CL:0000584',
#  'AGTTAAACACTTGCGA': 'CL:0000844',
#  'AGTTAAGTCAACCGCT': 'CL:0000584',
#  'AGTTACCGCACATGGT': 'CL:0000844',
#  'AGTTCCTATTTATGTT': 'CL:0000844',
#  'AGTTCTGCGTTGTATC': 'CL:0000844',
#  'AGTTGACATCGGCTGG': 'CL:0000844',
#  'AGTTGACGGTCCTTGC': 'CL:0000844',
#  'AGTTGCTGACTGATAT': 'CL:0000584',
#  'AGTTGGCAAGGCTAGA': 'CL:0000844',
#  'AGTTTCGCAGGTCGGA': 'CL:0000844',
#  'AGTTTGGCACGGGTTG': 'CL:0000844',
#  'AGTTTGGCCAGACCTA': 'CL:0000844',
#  'ATAAACGGACCCGTAA': 'CL:0000186',
#  'ATAAACGTTGCACCAC': 'CL:0000844',
#  'ATAAAGGCTCGGTCGT': 'CL:0000186',
#  'ATAAATATTAGCAGCT': 'CL:0000584',
#  'ATAACGCCGGAGGGTC': 'CL:0000186',
#  'ATAACGGAGTCCAACG': 'CL:0000186',
#  'ATAAGGTGGAGAACAT': 'CL:0000844',
#  'ATAAGTAGGATTCAGA': 'CL:0000844',
#  'ATAAGTAGGGCGACTC': 'CL:0000844',
#  'ATAAGTTACCGCGACG': 'CL:0000584',
#  'ATAATACCGTTAGCCG': 'CL:0000584',
#  'ATAATAGCTGTTGAAT': 'CL:0000844',
#  'ATAATAGTGTAGGGAC': 'CL:0000844',
#  'ATAATCTTGGAGAACC': 'CL:0000844',
#  'ATAATTAGCTAAGTAG': 'CL:0000844',
#  'ATACCACGGGCAACTT': 'CL:0000584',
#  'ATACCAGCAAATTGCT': 'CL:0000844',
#  'ATACCAGGCTAATAGA': 'CL:0000584',
#  'ATACCTAACCAAGAAA': 'CL:0000584',
#  'ATACGAGGTTTGTAAG': 'CL:0000844',
#  'ATACGCCGGCGAAACC': 'CL:0000584',
#  'ATACGGAACGTCGTTT': 'CL:0000844',
#  'ATACGGGTTTCGATTG': 'CL:0000844',
#  'ATACGGTGAAGATGCA': 'CL:0000844',
#  'ATACGTCCACTCCTGT': 'CL:0000844',
#  'ATACGTTATGCACGGA': 'CL:0000844',
#  'ATACTAGCATGACCCT': 'CL:0000186',
#  'ATACTGCCTTACACCG': 'CL:0000584',
#  'ATACTTGTTCTCGAGC': 'CL:0000844',
#  'ATAGACAACGGGACCT': 'CL:0000844',
#  'ATAGACGAAGAGAAAG': 'CL:0000584',
#  'ATAGAGTACTGGGACA': 'CL:0000844',
#  'ATAGAGTTATCAACTT': 'CL:0000844',
#  'ATAGCAACTAGGGAAG': 'CL:0000844',
#  'ATAGGCGGCTATAGAA': 'CL:0000844',
#  'ATAGGGATATCCTTGA': 'CL:0000844',
#  'ATAGGTTGGGCAGATG': 'CL:0000844',
#  'ATAGTGAAGCGTTCTC': 'CL:0000844',
#  'ATAGTTCCACCCACTC': 'CL:0000844',
#  'ATATAAAGCGCTCGTG': 'CL:0000844',
#  'ATATAAATGTAGCTGC': 'CL:0000844',
#  'ATATAACACGGGCGCA': 'CL:0000844',
#  'ATATACATGTATGGTA': 'CL:0000844',
#  'ATATACGCTCGTGACG': 'CL:0000844',
#  'ATATAGAGTATTGGTC': 'CL:0000186',
#  'ATATCGGTAGGGAGAT': 'CL:0000844',
#  'ATATCGTTCCTCGAAC': 'CL:0000844',
#  'ATATCTTAGGGCCTTC': 'CL:0000186',
#  'ATATGGGATAGCAACT': 'CL:0000844',
#  'ATATGTCTCCCTAGCC': 'CL:0000844',
#  'ATATTCAGTTAAACCT': 'CL:0000844',
#  'ATATTCCCACAGGTCA': 'CL:0000584',
#  'ATATTTAACCCTCAAG': 'CL:0000584',
#  'ATCAAACACTGTTCCA': 'CL:0000844',
#  'ATCAAGATCCCAGGAC': 'CL:0000844',
#  'ATCACGTGCTAATTAA': 'CL:0000844',
#  'ATCACTTCATCCTCGC': 'CL:0000186',
#  'ATCAGAAGCTGGTTGC': 'CL:0009010',
#  'ATCAGCCTCATGCTGC': 'CL:0000844',
#  'ATCAGTAGGCAGGGAT': 'CL:0000844',
#  'ATCATAGCCCTATGTA': 'CL:0000844',
#  'ATCATCCAATATTTGT': 'CL:0000844',
#  'ATCATTGTACCGCATT': 'CL:0000844',
#  'ATCCAATGGTACCGAA': 'CL:0000584',
#  'ATCCACATCGACAGAA': 'CL:0000844',
#  'ATCCAGAGCAACAACC': 'CL:0000584',
#  'ATCCCATCCACAGCGC': 'CL:0000186',
#  'ATCCCATTTCCGTGGG': 'CL:0000844',
#  'ATCCTACCTAAGCTCT': 'CL:0000844',
#  'ATCCTGAATCGCTGCG': 'CL:0000844',
#  'ATCCTGCGTGGAATGG': 'CL:0000584',
#  'ATCCTGCTGCAGATAG': 'CL:0000584',
#  'ATCGACCCAATACAGA': 'CL:0000844',
#  'ATCGACTCTTTCCGTT': 'CL:0000775',
#  'ATCGCACGCCGGGAGA': 'CL:0000844',
#  'ATCGCCAGTCAACATT': 'CL:0000844',
#  'ATCGGAGACAGACGGC': 'CL:0000844',
#  'ATCGGCAAGCAGTCCA': 'CL:0009010',
#  'ATCGTATTCCGAGAAC': 'CL:0000844',
#  'ATCGTTAGCTAGCGGA': 'CL:0000844',
#  'ATCTAATATCCTACGG': 'CL:0000844',
#  'ATCTAGCTTGTGAGGG': 'CL:0000844',
#  'ATCTCCCACGGAATAT': 'CL:0000844',
#  'ATCTGACATGGAAGGA': 'CL:0000584',
#  'ATCTGCACCTCTGCGA': 'CL:0000844',
#  'ATCTGCTGTTATCGCC': 'CL:0000844',
#  'ATCTGGGCTGTTCTTG': 'CL:0000844',
#  'ATCTGGTTAAGACTGT': 'CL:0000186',
#  'ATCTGTAATTGTACCC': 'CL:0000844',
#  'ATCTTATCGCACACCC': 'CL:0000844',
#  'ATCTTGACCTGCAACG': 'CL:0000844',
#  'ATCTTGACTTGTCCAA': 'CL:0000844',
#  'ATGAAGCCAAGGAGCC': 'CL:0000844',
#  'ATGAAGTGGACCCAGC': 'CL:0000844',
#  'ATGACGCCGGCTCTAA': 'CL:0000844',
#  'ATGACGCGTTCTATCC': 'CL:0000844',
#  'ATGACTATCAGCTGTG': 'CL:0000844',
#  'ATGACTATGCGACATT': 'CL:0000844',
#  'ATGAGGAGTGTTAATC': 'CL:0009010',
#  'ATGATGCAATGGTACA': 'CL:0000584',
#  'ATGCACGCGCTGTTCA': 'CL:0000844',
#  'ATGCACTACCGCATTG': 'CL:0000844',
#  'ATGCATGATCCAGGAT': 'CL:0000584',
#  'ATGCATTCCGTGATGG': 'CL:0000584',
#  'ATGCCATTTGCGACCA': 'CL:0000844',
#  'ATGCCGGTCTTGCATA': 'CL:0000844',
#  'ATGCGACAGTCCCATT': 'CL:0000844',
#  'ATGCGAGTCCCACCAC': 'CL:0000584',
#  'ATGCTCAGTGTTGCAT': 'CL:0000584',
#  'ATGCTCTGGCGCGGTA': 'CL:0000844',
#  'ATGGAAATTTAAGGAG': 'CL:0000584',
#  'ATGGAGCAGGCCGTGA': 'CL:0000584',
#  'ATGGATCCGGCGTCCG': 'CL:0000844',
#  'ATGGATTGACCAAACG': 'CL:0000844',
#  'ATGGCAGCATTACGAT': 'CL:0000844',
#  'ATGGCAGCCGAGAAAC': 'CL:0000844',
#  'ATGGGCCTCGGCCTCT': 'CL:0000844',
#  'ATGGGTGTATACCTCC': 'CL:0000844',
#  'ATGGTATTGGGAACCG': 'CL:0000844',
#  'ATGGTCGCGTGGTTTC': 'CL:0000844',
#  'ATGTACGATGACGTCG': 'CL:0000844',
#  'ATGTAGCGCGCGTAGG': 'CL:0000844',
#  'ATGTGAAAGCCTAATG': 'CL:0000844',
#  'ATGTGCATCCGACGCA': 'CL:0000775',
#  'ATGTGGACATCTTGAT': 'CL:0000186',
#  'ATGTGTAGTTTAGTCA': 'CL:0000584',
#  'ATGTTACGAGCAATAC': 'CL:0000844',
#  'ATGTTGTAGTCTGTTT': 'CL:0000844',
#  'ATTAAACATGCGGACC': 'CL:0000844',
#  'ATTAATACTACGCGGG': 'CL:0000844',
#  'ATTAATGAACCAGTCG': 'CL:0000576',
#  'ATTAATTCGGTCACTC': 'CL:0000844',
#  'ATTACAACTACCGGCC': 'CL:0000844',
#  'ATTACATGTCAGTCTT': 'CL:0000584',
#  'ATTACGCGCTGGCAGG': 'CL:0000844',
#  'ATTACTAGCCTCTTGC': 'CL:0000844',
#  'ATTACTTACTGGGCAT': 'CL:0000186',
#  'ATTAGGCGATGCTTTC': 'CL:0000844',
#  'ATTATACTTTGCTCGT': 'CL:0000186',
#  'ATTATGAGACCCAATT': 'CL:0000844',
#  'ATTATTATGTCCGTCA': 'CL:0000844',
#  'ATTATTCAGAGTCACT': 'CL:0000844',
#  'ATTCAACCATTTAAGG': 'CL:0000844',
#  'ATTCACTGATGTTGGA': 'CL:0000844',
#  'ATTCAGGACCTATTTC': 'CL:0000844',
#  'ATTCATATACTGTCCA': 'CL:0000584',
#  'ATTCATCGTTGAGGCA': 'CL:0000844',
#  'ATTCCCACATAAACAA': 'CL:0000844',
#  'ATTCCCGAAGGTACAG': 'CL:0000844',
#  'ATTCCTCCGCCAGTGC': 'CL:0009010',
#  'ATTCCTTCCAGGCGGT': 'CL:0000844',
#  'ATTCGACGCCGGGCCT': 'CL:0000584',
#  'ATTCGCGCCTTGAGAG': 'CL:0000844',
#  'ATTCGTGCTATCTCTT': 'CL:0000584',
#  'ATTCGTGTACCCATTC': 'CL:0000584',
#  'ATTGAAGATCTTAGTG': 'CL:0000844',
#  'ATTGATAGCAACGAGA': 'CL:0000844',
#  'ATTGATCACCACATTT': 'CL:0000584',
#  'ATTGATGAGTCCTAAC': 'CL:0000844',
#  'ATTGCCTTTATGTTTG': 'CL:0000844',
#  'ATTGCGATCAGTAACT': 'CL:0000844',
#  'ATTGCTGCTCCTCCAT': 'CL:0000186',
#  'ATTGGATTACAGCGTA': 'CL:0000844',
#  'ATTGGGAATATCTTGG': 'CL:0000844',
#  'ATTGTACAACTCGGCT': 'CL:0000844',
#  'ATTGTCTGTTTCATGT': 'CL:0000844',
#  'ATTTAACTCGTATTAC': 'CL:0000844',
#  'ATTTACAGTTTACTGG': 'CL:0000844',
#  'ATTTATACTGGTAAAG': 'CL:0000844',
#  'ATTTCCGGGTTCTGCG': 'CL:0000844',
#  'ATTTGCGCGAGTAGCT': 'CL:0000844',
#  'ATTTGGAGATTGCGGT': 'CL:0007011',
#  'ATTTGTCTTGGGAGCT': 'CL:0000844',
#  'ATTTGTTCCAGGGCTC': 'CL:0000186',
#  'CAAACCATAAGCGTAT': 'CL:0000186',
#  'CAAACTACGATAGAGA': 'CL:0000844',
#  'CAAACTATTGAGCTTC': 'CL:0000844',
#  'CAAACTCGCGACGCCG': 'CL:0000186',
#  'CAAAGATTATTGGGCC': 'CL:0000844',
#  'CAAATCTCTCACAAGG': 'CL:0000844',
#  'CAAATGTCCTTCCGTG': 'CL:0000584',
#  'CAAATTGTCAGCAAGC': 'CL:0000844',
#  'CAACGGTTCTTGATAC': 'CL:0000844',
#  'CAACTCCTTGATCCCG': 'CL:0000844',
#  'CAACTGCTCATCCGAT': 'CL:0000844',
#  'CAAGAGGGCGGAGTAC': 'CL:0000584',
#  'CAAGATATTATAACGT': 'CL:0000844',
#  'CAAGCAACGTCGGAGT': 'CL:0000584',
#  'CAAGCACCAAATGCCT': 'CL:0000186',
#  'CAAGGATCGCATGTTC': 'CL:0000844',
#  'CAAGGCCAGTGGTGCA': 'CL:0000844',
#  'CAAGGTCCTATAGGCT': 'CL:0000844',
#  'CAAGTAAGTGATAGAC': 'CL:0000844',
#  'CAAGTCGTTGAAATCT': 'CL:0000844',
#  'CAAGTGAACTTTGGTT': 'CL:0000584',
#  'CAAGTGTGGTTGCAAA': 'CL:0000844',
#  'CAATAAACCTTGGCCC': 'CL:0000186',
#  'CAATACGCTCTGAGGC': 'CL:0000584',
#  'CAATATTCTTGACCTA': 'CL:0000844',
#  'CAATATTGGACTAGTG': 'CL:0000844',
#  'CAATCCCTATACCAGC': 'CL:0000844',
#  'CAATCCTGCCGTGGAG': 'CL:0000844',
#  'CAATGACCCTTAATTT': 'CL:0000584',
#  'CAATGCGAGAAGTATC': 'CL:0000844',
#  'CAATGGATCTCTACCA': 'CL:0000844',
#  'CAATGGTCGGCCTGGG': 'CL:0000584',
#  'CAATTAAGGGTGATGA': 'CL:0009010',
#  'CAATTGGGCCGCACTC': 'CL:0000844',
#  'CAATTTCGTATAAGGG': 'CL:0000844',
#  'CACAAGCTAAGAAAGG': 'CL:0000844',
#  'CACACACGCTAACGAG': 'CL:0000844',
#  'CACACAGGGATAGATT': 'CL:0000844',
#  'CACACGCGCTGTCTTA': 'CL:0000844',
#  'CACAGCTAGGGAGTGA': 'CL:0000186',
#  'CACAGGGCCATATAGT': 'CL:0000844',
#  'CACAGGGCCGTTGTCA': 'CL:0000844',
#  'CACATATTAGCAGGAT': 'CL:0000186',
#  'CACATCTCACCGACGA': 'CL:0000844',
#  'CACATGATTCAGCAAC': 'CL:0000844',
#  'CACATTCTTTCGATGG': 'CL:0000186',
#  'CACATTTCTTGTCAGA': 'CL:0000844',
#  'CACCAATCATCCGTCT': 'CL:0000844',
#  'CACCACGCCACACAGA': 'CL:0000584',
#  'CACCAGTCAGCATGCA': 'CL:0000844',
#  'CACCCAAATCTTATGT': 'CL:0000844',
#  'CACCCTAACAAGATCT': 'CL:0000844',
#  'CACCGATACACCGAGC': 'CL:0000844',
#  'CACCGCCAGAAGGTTT': 'CL:0000844',
#  'CACCGGGCATCACAAG': 'CL:0000844',
#  'CACCGGTAGAGACATT': 'CL:0000844',
#  'CACCGTATCCCATCCG': 'CL:0000844',
#  'CACCGTTAGGGATCAC': 'CL:0000584',
#  'CACCGTTGCGCGATAT': 'CL:0000844',
#  'CACCTAATAGAGTCGT': 'CL:0000844',
#  'CACCTCGATGGTGGAC': 'CL:0000186',
#  'CACCTTGCGAAACTCG': 'CL:0000057',
#  'CACCTTGGCGCCTTTG': 'CL:0000844',
#  'CACGAAAGTTAGTCCC': 'CL:0000584',
#  'CACGAGCAAACCAGAC': 'CL:0000844',
#  'CACGCACAGCGCAGCT': 'CL:0000844',
#  'CACGCGGAACTGTTGC': 'CL:0000844',
#  'CACGGGATTGAGGGTT': 'CL:0000844',
#  'CACGTCGGCAACCTCT': 'CL:0000584',
#  'CACGTTCGTGCTCTAG': 'CL:0000844',
#  'CACGTTTCGTACACAC': 'CL:0000844',
#  'CACTAAAGTTGCCTAT': 'CL:0000186',
#  'CACTACGGGAGCTGCC': 'CL:0000844',
#  'CACTACTCAGTTCTGT': 'CL:0000844',
#  'CACTCAAGAGCTATGG': 'CL:0000844',
#  'CACTCAGCTCTTGAGG': 'CL:0000844',
#  'CACTCCTATGTAAGAT': 'CL:0000844',
#  'CACTCGAGCTGAACAA': 'CL:0000844',
#  'CACTCTCAAGCATCGA': 'CL:0000844',
#  'CACTCTTCTGCTAGCC': 'CL:0000844',
#  'CACTGACGATTGTGGA': 'CL:0000844',
#  'CACTTAATCAGACGGA': 'CL:0000584',
#  'CACTTCGCCACAGGCT': 'CL:0000844',
#  'CAGACCTGTAAGTGTT': 'CL:0000844',
#  'CAGAGCATGAGCTTGC': 'CL:0000844',
#  'CAGAGGCGATGCATGA': 'CL:0000584',
#  'CAGATACTAACATAGT': 'CL:0000844',
#  'CAGATATGAAGATGAC': 'CL:0000186',
#  'CAGATGTTTGTCCCAA': 'CL:0000844',
#  'CAGCAGCCCGTTCCTT': 'CL:0000186',
#  'CAGCAGTCTGTGCTGC': 'CL:0000844',
#  'CAGCCGGGCCCTCTAT': 'CL:0000844',
#  'CAGCCTCCTGCAGAGG': 'CL:0000844',
#  'CAGCGCCAACACGATA': 'CL:0000584',
#  'CAGCTCGACAAGTTAA': 'CL:0000844',
#  'CAGCTCGTGCTTGTGT': 'CL:0000844',
#  'CAGCTTAGTAGGTAGC': 'CL:0000844',
#  'CAGGAAGACTTTATAT': 'CL:0000844',
#  'CAGGATATATCGTTGT': 'CL:0000844',
#  'CAGGCAGTCTTACCAG': 'CL:0000844',
#  'CAGGCCGTTTGGGTGT': 'CL:0000844',
#  'CAGGCGCACGGTGGTC': 'CL:0000844',
#  'CAGGCGCCATGCTAGG': 'CL:0000844',
#  'CAGTAATCCCTCCCAG': 'CL:0000584',
#  'CAGTACCAGTTTACGT': 'CL:0000844',
#  'CAGTAGCCCACGCGGT': 'CL:0000186',
#  'CAGTAGCGAGGTAGTA': 'CL:0000844',
#  'CAGTCTCTCGGCTAAT': 'CL:0000844',
#  'CAGTGAATAAATGACT': 'CL:0000186',
#  'CAGTGGTTGCACATGA': 'CL:0000844',
#  'CAGTTCCGCGGGTCGA': 'CL:0000844',
#  'CAGTTCGAGGACCCGA': 'CL:0000584',
#  'CATAACGGACAGTCGT': 'CL:0000844',
#  'CATAAGAAGCTTGGCT': 'CL:0000844',
#  'CATAAGCTCTCCGTCT': 'CL:0000584',
#  'CATAATGAGCGGGCGA': 'CL:0000584',
#  'CATACACGGTTCCCAC': 'CL:0000584',
#  'CATACCCGTACCCAGT': 'CL:0000584',
#  'CATACGAACTAGCTGG': 'CL:0000844',
#  'CATACGGCGTCTGGGC': 'CL:0000844',
#  'CATACTATGTAATTGT': 'CL:0000844',
#  'CATACTTCTTTCTCCG': 'CL:0000844',
#  'CATAGAGGAGATACTA': 'CL:0000844',
#  'CATAGCCGCCCGGGAT': 'CL:0000844',
#  'CATAGTAGCATAGTAG': 'CL:0000844',
#  'CATAGTCAAATACATA': 'CL:0000844',
#  'CATAGTCCACAAGAAC': 'CL:0000844',
#  'CATATAGGTACAGTCA': 'CL:0000844',
#  'CATATTATTTGCCCTA': 'CL:0000844',
#  'CATCATCTACCCGGAC': 'CL:0000844',
#  'CATCATTACCCTGAGG': 'CL:0000844',
#  'CATCCAATATAGTTTG': 'CL:0000186',
#  'CATCCGCAGGCCCGAA': 'CL:0000584',
#  'CATCCTCTCAAAGATC': 'CL:0000844',
#  'CATCGGACGGGTTAAT': 'CL:0000844',
#  'CATCTGCAGGATCATT': 'CL:0000844',
#  'CATCTTACACCACCTC': 'CL:0000844',
#  'CATGAACCGACATTTG': 'CL:0000844',
#  'CATGAACCTCTTATCA': 'CL:0000844',
#  'CATGACTTCGCTGAAT': 'CL:0000584',
#  'CATGAGATGCACTCTC': 'CL:0000844',
#  'CATGATACGGTGAAAC': 'CL:0000844',
#  'CATGATGCACAATTCT': 'CL:0000186',
#  'CATGATGGAAGTTAGC': 'CL:0000844',
#  'CATGCACATGAGAGGC': 'CL:0000844',
#  'CATGCATGGAGACCCT': 'CL:0000844',
#  'CATGCCAACTCGCAAA': 'CL:0000186',
#  'CATGCGTTAGACAGAA': 'CL:0000844',
#  'CATGCTGGCTCCAATT': 'CL:0000584',
#  'CATGGATTGTCTTCCG': 'CL:0000844',
#  'CATGGGTATGCCTTAT': 'CL:0000844',
#  'CATGGGTCGGGTGTGG': 'CL:0000186',
#  'CATGGTAAGTAGCGTT': 'CL:0000584',
#  'CATGGTATTAGTTTGT': 'CL:0000186',
#  'CATGGTCTAGATACCG': 'CL:0000584',
#  'CATGGTTTATTAATCA': 'CL:0000844',
#  'CATGTAAGAGACATTT': 'CL:0000844',
#  'CATGTCTCATTTATGG': 'CL:0000844',
#  'CATGTGGGCTCATCAC': 'CL:0000844',
#  'CATTACGTCGGCCCGT': 'CL:0000186',
#  'CATTATGCTTGTTGTG': 'CL:0000844',
#  'CATTCACTGACAGCTA': 'CL:0000844',
#  'CATTGTGTGCTAGATC': 'CL:0000844',
#  'CATTTAGCGGACCATG': 'CL:0000186',
#  'CATTTATCGTTCAAGA': 'CL:0000844',
#  'CCAAACAGAACCCTCG': 'CL:0000844',
#  'CCAAAGTCCCGCTAAC': 'CL:0000844',
#  'CCAAATCAAAGGGCAA': 'CL:0000844',
#  'CCAACCTTATGTAACT': 'CL:0000844',
#  'CCAACGATGCACTGAT': 'CL:0000844',
#  'CCAAGAAAGTGGGCGA': 'CL:0000844',
#  'CCAAGACTTCTGCGAA': 'CL:0000186',
#  'CCAATAGTGCCGTCGA': 'CL:0000584',
#  'CCAATGTCACAGCAAG': 'CL:0000844',
#  'CCACAATGTACGTCTT': 'CL:0000844',
#  'CCACACTGAGATATTA': 'CL:0000844',
#  'CCACAGCTGAAATCAT': 'CL:0000844',
#  'CCACAGTACCCATCCT': 'CL:0000844',
#  'CCACATGGCTCTTTAT': 'CL:0000844',
#  'CCACCCAAGGAAAGTG': 'CL:0000844',
#  'CCACGAATTTAACCTC': 'CL:0000584',
#  'CCACGGTGCCCGGTAG': 'CL:0000844',
#  'CCACTCAGATCCGCAA': 'CL:0000844',
#  'CCACTGGTGGCTGGTT': 'CL:0000844',
#  'CCACTGTTTGGATTAA': 'CL:0000844',
#  'CCAGAGACAAAGCCGG': 'CL:0000844',
#  'CCAGCCTGGACCAATA': 'CL:0000584',
#  'CCAGCTACGCCTCATA': 'CL:0000844',
#  'CCAGCTCGAACGCATT': 'CL:0000844',
#  'CCAGGGACGTGGCCTC': 'CL:0000844',
#  'CCAGTAGTCTGATCCA': 'CL:0000186',
#  'CCAGTCAAATCTCTTA': 'CL:0000186',
#  'CCAGTCTAGACGGCGC': 'CL:0002138',
#  'CCAGTCTTGTCATAGA': 'CL:0000844',
#  'CCATACCTTTACTTGT': 'CL:0000844',
#  'CCATAGAGGCTGCCAG': 'CL:0000844',
#  'CCATAGTCAGTAACCC': 'CL:0000584',
#  'CCATATGGAAACTATA': 'CL:0000844',
#  'CCATATTGGATCATGA': 'CL:0000844',
#  'CCATCGCAGTTAAACT': 'CL:0000844',
#  'CCATCTCACCAGTGAA': 'CL:0000584',
#  'CCATCTTGTTCACAAT': 'CL:0000844',
#  'CCATGCCCTAGATTTC': 'CL:0000844',
#  'CCATGCCTGTTTAGTA': 'CL:0000186',
#  'CCATGCTCTGCAGGAA': 'CL:0000844',
#  'CCATGTTCATCTATAT': 'CL:0000844',
#  'CCATTAGCGATAATCC': 'CL:0000844',
#  'CCATTCCCTGCCCACA': 'CL:0000584',
#  'CCCAAACATGCTGCTC': 'CL:0000844',
#  'CCCAAGACAGAGTATG': 'CL:0000844',
#  'CCCAATTTCACAACTT': 'CL:0000844',
#  'CCCACTCCACGGTATC': 'CL:0000844',
#  'CCCAGGAAGAATTCGA': 'CL:0000844',
#  'CCCAGGTCTGAAGGCT': 'CL:0000584',
#  'CCCGAAGTTTCGCGAA': 'CL:0000844',
#  'CCCGCAGGGCCCAAAG': 'CL:0000844',
#  'CCCGCGCAATGCACCC': 'CL:0000584',
#  'CCCGGGTCGTTCAGGG': 'CL:0000844',
#  'CCCGGTGGAAGAACCT': 'CL:0000844',
#  'CCCGTAAGTCTAGGCC': 'CL:0000186',
#  'CCCGTAGCTGGGAAGA': 'CL:0000844',
#  'CCCGTCAGCGTCTGAC': 'CL:0000844',
#  'CCCGTGACAGTGCCTT': 'CL:0000186',
#  'CCCGTTTCGCAGATGT': 'CL:0000844',
#  'CCCTACTTGAACAATG': 'CL:0000844',
#  'CCCTAGGCAACAAGAG': 'CL:0000844',
#  'CCCTATGTAGAGCAGA': 'CL:0000844',
#  'CCCTCAGATCGAGAAC': 'CL:0000844',
#  'CCCTCATCACAGAGTA': 'CL:0000844',
#  'CCCTCGATAATACACA': 'CL:0000584',
#  'CCCTGAAATGAGTTGA': 'CL:0000844',
#  'CCCTGACTAACAAATT': 'CL:0000844',
#  'CCCTGATGTAACTCGT': 'CL:0000844',
#  'CCCTGCCCAATCCGCT': 'CL:0000186',
#  'CCCTGGCTGTTCCTTC': 'CL:0000844',
#  'CCCTGGGAGGGATCCT': 'CL:0000584',
#  'CCCTGGTATGGGCGGC': 'CL:0000844',
#  'CCCTTCTCGTACGCGA': 'CL:0000844',
#  'CCCTTTGACAGGTCTT': 'CL:0000844',
#  'CCGAAAGTGGTGAGCA': 'CL:0000844',
#  'CCGAACACTGGGCCTC': 'CL:0000186',
#  'CCGAACCTTCCCGGCC': 'CL:0000844',
#  'CCGAAGCATTGACCAA': 'CL:0000844',
#  'CCGACGGGCATGAGGT': 'CL:0000844',
#  'CCGACTCGCATAGTCT': 'CL:0000844',
#  'CCGAGAAGTCGCATAA': 'CL:0000186',
#  'CCGAGGGATGTTAGGC': 'CL:0000584',
#  'CCGATCTCAACCTTAT': 'CL:0000844',
#  'CCGATTCGAGGGACCC': 'CL:0000844',
#  'CCGCACAAAGACCAAC': 'CL:0000844',
#  'CCGCACGTGACCTCGG': 'CL:0000844',
#  'CCGCACTTGCAATGAC': 'CL:0000844',
#  'CCGCATGTGGTACGAT': 'CL:0000844',
#  'CCGCCACCACAATCCA': 'CL:0000844',
#  'CCGCCGGTCAACACAC': 'CL:0000844',
#  'CCGCCTGCGAATTGGT': 'CL:0000844',
#  'CCGCCTTGCGATGTCG': 'CL:0000186',
#  'CCGCGATTTGGTAGGT': 'CL:0000844',
#  'CCGCGCAAGATACCCA': 'CL:0000844',
#  'CCGCGGGTACGAAGAA': 'CL:0000844',
#  'CCGCTATCAGCACCAG': 'CL:0000584',
#  'CCGCTCTTCCGAACTA': 'CL:0000844',
#  'CCGCTGGTGCCATTCA': 'CL:0000844',
#  'CCGCTTACCTCACTCT': 'CL:0000844',
#  'CCGCTTCGCGGTTAAC': 'CL:0000844',
#  'CCGGAATGGTTTCAGT': 'CL:0000844',
#  'CCGGAGCGTACTTTCT': 'CL:0000844',
#  'CCGGCACGACCGTTTC': 'CL:0000844',
#  'CCGGCCGCGAGCATAT': 'CL:0000186',
#  'CCGGCGCATATTGGAT': 'CL:0000844',
#  'CCGGCGTGAGACTCTG': 'CL:0000844',
#  'CCGGGCGGTCTCGTCA': 'CL:0000844',
#  'CCGGGCTAAGAATTTC': 'CL:0000844',
#  'CCGGGCTGCTCCATAC': 'CL:0000584',
#  'CCGGGTTCGAGGTTAC': 'CL:0000186',
#  'CCGGTATCTGGCGACT': 'CL:0000844',
#  'CCGGTTTGTAATTGTG': 'CL:0000844',
#  'CCGTAAGTTGGTCCCA': 'CL:0000844',
#  'CCGTACCCAAGCGCCA': 'CL:0000844',
#  'CCGTAGGAAATCCCTG': 'CL:0000844',
#  'CCGTATCTCGTCGTAG': 'CL:0000844',
#  'CCGTGCCCATGACGGC': 'CL:0000844',
#  'CCGTGGAACGATCCAA': 'CL:0000186',
#  'CCGTGTTAAATTCCAT': 'CL:0000584',
#  'CCGTTCCGAATCTCGG': 'CL:0000844',
#  'CCTAAATTAACGGTTC': 'CL:0000844',
#  'CCTAACCCAAACAAGT': 'CL:0000844',
#  'CCTACAGTTGAGGGAG': 'CL:0000844',
#  'CCTACATTCACAGACG': 'CL:0000584',
#  'CCTACGGCTCAGTCGA': 'CL:0000844',
#  'CCTAGGCGTAGCGATC': 'CL:0000584',
#  'CCTAGGTAAAGGTAGC': 'CL:0000844',
#  'CCTAGTTAGTCGCATG': 'CL:0000844',
#  'CCTATAATGAGTGCCC': 'CL:0000844',
#  'CCTATACCGTCCTGTC': 'CL:0000844',
#  'CCTATATCGTGTCACG': 'CL:0000186',
#  'CCTATATTTGTCCTGG': 'CL:0000844',
#  'CCTATCTATATCGGAA': 'CL:0000186',
#  'CCTATGAAGTGGTGCC': 'CL:0000844',
#  'CCTATGGTCAAAGCTG': 'CL:0000844',
#  'CCTATGTCCACTCCAC': 'CL:0000584',
#  'CCTCACCTGAGGGAGC': 'CL:0000844',
#  'CCTCACCTTAGCATCG': 'CL:0000844',
#  'CCTCATGCAGCTACGA': 'CL:0000775',
#  'CCTCCGACAATTCAAG': 'CL:0000584',
#  'CCTCCTGAGCCCACAT': 'CL:0000584',
#  'CCTCCTGTTGTGTCGT': 'CL:0000844',
#  'CCTCGACCCACTGCCT': 'CL:0000844',
#  'CCTCGCCAGCAAATTA': 'CL:0000186',
#  'CCTCGCGCGATATAGG': 'CL:0000186',
#  'CCTCGCGCTGTGCGAT': 'CL:0000844',
#  'CCTCGGACCGGGATAG': 'CL:0000844',
#  'CCTCGGATGCTACCTG': 'CL:0000844',
#  'CCTCTAATCTGCCAAG': 'CL:0000844',
#  'CCTCTATCGATTAGCA': 'CL:0000584',
#  'CCTCTCTCCCATCTAG': 'CL:0000584',
#  'CCTCTGTACTATTCTA': 'CL:0000844',
#  'CCTGAACGATATATTC': 'CL:0000186',
#  'CCTGAATATTTACATA': 'CL:0000844',
#  ...}

# %%
adata.obs['barcodes'] = adata.obs_names
adata.obs['barcodes'] = adata.obs['barcodes'].str.extract(r'([ATGC]{10,16})', expand=False)

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['barcodes'].map(mapping)

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             4282
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             4633
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             2856
# AAACACCAATAACTGC-1        1.0       59.0       59.0              593
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             4783
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0              250
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              618
# TTGTTTCCATACAACT-1        1.0       45.0       45.0              316
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              154
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2472
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                        NaN
# AAACAAGTATCTCCCA-1                        NaN
# AAACAATCTACTAGCA-1                 CL:0000584
# AAACACCAATAACTGC-1                 CL:0000844
# AAACAGAGCGACTCCT-1                        NaN
# ...                                       ...
# TTGTTTCACATCCAGG-1                        NaN
# TTGTTTCATTAGTCTA-1                 CL:0000844
# TTGTTTCCATACAACT-1                        NaN
# TTGTTTGTATTACACG-1                        NaN
# TTGTTTGTGTAAATTC-1                 CL:0000584
#
# [4992 rows x 7 columns]

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 2379

# %%
adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)
# Out:
# /tmp/ipykernel_48296/2352945792.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['cell_type_ontology_term_id'].fillna('unknown', inplace=True)

# %%
num_nans = adata.obs['cell_type_ontology_term_id'].isna().sum()
num_nans
# Out:
# 0

# %%
adata.obs['cell_type_ontology_term_id'] = adata.obs['cell_type_ontology_term_id'].astype('category')

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             4282
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             4633
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             2856
# AAACACCAATAACTGC-1        1.0       59.0       59.0              593
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             4783
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0              250
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              618
# TTGTTTCCATACAACT-1        1.0       45.0       45.0              316
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              154
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2472
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id
# AAACAACGAATAGTTC-1                    unknown
# AAACAAGTATCTCCCA-1                    unknown
# AAACAATCTACTAGCA-1                 CL:0000584
# AAACACCAATAACTGC-1                 CL:0000844
# AAACAGAGCGACTCCT-1                    unknown
# ...                                       ...
# TTGTTTCACATCCAGG-1                    unknown
# TTGTTTCATTAGTCTA-1                 CL:0000844
# TTGTTTCCATACAACT-1                    unknown
# TTGTTTGTATTACACG-1                    unknown
# TTGTTTGTGTAAATTC-1                 CL:0000584
#
# [4992 rows x 7 columns]

# %%
list(adata.obs['cell_type_ontology_term_id'].unique())
# Out:
# ['unknown',
#  'CL:0000584',
#  'CL:0000844',
#  'CL:0000186',
#  'CL:0000576',
#  'CL:0009010',
#  'CL:0007011',
#  'CL:0000775',
#  'CL:0000057',
#  'CL:0002138',
#  'CL:0000034']

# %% [markdown]
# #### **donor_id**

# %%
unique_value = adata1.obs['donor_id'].unique()[0]
unique_value 
adata.obs['donor_id'] = unique_value

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].str.replace('.only', '')

# %%
adata.obs['donor_id'] = adata.obs['donor_id'].astype('category')

# %%
adata.obs['donor_id']
# Out:
# AAACAACGAATAGTTC-1    1B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1    1B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1    1B_Hh.anti_IL10r
# AAACACCAATAACTGC-1    1B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1    1B_Hh.anti_IL10r
#                             ...
# TTGTTTCACATCCAGG-1    1B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1    1B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1    1B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1    1B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1    1B_Hh.anti_IL10r
# Name: donor_id, Length: 4992, dtype: category
# Categories (1, object): ['1B_Hh.anti_IL10r']

# %% [markdown]
# #### **development_stage_ontology_term_id**

# %%
unique_value = adata1.obs['development_stage_ontology_term_id'].unique()[0]
unique_value 
adata.obs['development_stage_ontology_term_id'] = unique_value

# %%
list(adata.obs['development_stage_ontology_term_id'].unique())
# Out:
# ['MmusDv:0000061']

# %%
adata.obs['development_stage_ontology_term_id'] = adata.obs['development_stage_ontology_term_id'].astype('category')

# %%
adata.obs['development_stage_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    MmusDv:0000061
# AAACAAGTATCTCCCA-1    MmusDv:0000061
# AAACAATCTACTAGCA-1    MmusDv:0000061
# AAACACCAATAACTGC-1    MmusDv:0000061
# AAACAGAGCGACTCCT-1    MmusDv:0000061
#                            ...
# TTGTTTCACATCCAGG-1    MmusDv:0000061
# TTGTTTCATTAGTCTA-1    MmusDv:0000061
# TTGTTTCCATACAACT-1    MmusDv:0000061
# TTGTTTGTATTACACG-1    MmusDv:0000061
# TTGTTTGTGTAAATTC-1    MmusDv:0000061
# Name: development_stage_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['MmusDv:0000061']

# %% [markdown]
# #### **disease_ontology_term_id**

# %%
unique_value = adata1.obs['disease_ontology_term_id'].unique()[0]
unique_value 
adata.obs['disease_ontology_term_id'] = unique_value

# %%
adata.obs['disease_ontology_term_id'] = adata.obs['disease_ontology_term_id'].astype('category')

# %%
adata.obs['disease_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    PATO:0000461
# AAACAAGTATCTCCCA-1    PATO:0000461
# AAACAATCTACTAGCA-1    PATO:0000461
# AAACACCAATAACTGC-1    PATO:0000461
# AAACAGAGCGACTCCT-1    PATO:0000461
#                           ...
# TTGTTTCACATCCAGG-1    PATO:0000461
# TTGTTTCATTAGTCTA-1    PATO:0000461
# TTGTTTCCATACAACT-1    PATO:0000461
# TTGTTTGTATTACACG-1    PATO:0000461
# TTGTTTGTGTAAATTC-1    PATO:0000461
# Name: disease_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['PATO:0000461']

# %% [markdown]
# #### **is_primary_data**

# %%
unique_value = adata1.obs['is_primary_data'].unique()[0]
unique_value 
adata.obs['is_primary_data'] = unique_value

# %%
adata.obs['is_primary_data'] = adata.obs['is_primary_data'].astype('bool')

# %%
adata.obs['is_primary_data']
# Out:
# AAACAACGAATAGTTC-1    True
# AAACAAGTATCTCCCA-1    True
# AAACAATCTACTAGCA-1    True
# AAACACCAATAACTGC-1    True
# AAACAGAGCGACTCCT-1    True
#                       ...
# TTGTTTCACATCCAGG-1    True
# TTGTTTCATTAGTCTA-1    True
# TTGTTTCCATACAACT-1    True
# TTGTTTGTATTACACG-1    True
# TTGTTTGTGTAAATTC-1    True
# Name: is_primary_data, Length: 4992, dtype: bool

# %% [markdown]
# #### **organism_ontology_term_id**

# %%
unique_value = adata1.obs['organism_ontology_term_id'].unique()[0]
unique_value 
adata.obs['organism_ontology_term_id'] = unique_value

# %%
adata.obs['organism_ontology_term_id'] = adata.obs['organism_ontology_term_id'].astype('category')

# %%
adata.obs['organism_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    NCBITaxon:10090
# AAACAAGTATCTCCCA-1    NCBITaxon:10090
# AAACAATCTACTAGCA-1    NCBITaxon:10090
# AAACACCAATAACTGC-1    NCBITaxon:10090
# AAACAGAGCGACTCCT-1    NCBITaxon:10090
#                            ...
# TTGTTTCACATCCAGG-1    NCBITaxon:10090
# TTGTTTCATTAGTCTA-1    NCBITaxon:10090
# TTGTTTCCATACAACT-1    NCBITaxon:10090
# TTGTTTGTATTACACG-1    NCBITaxon:10090
# TTGTTTGTGTAAATTC-1    NCBITaxon:10090
# Name: organism_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['NCBITaxon:10090']

# %% [markdown]
# #### **self_reported_ethnicity_ontology_term_id**

# %%
unique_value = adata1.obs['self_reported_ethnicity_ontology_term_id'].unique()[0]
unique_value 
adata.obs['self_reported_ethnicity_ontology_term_id'] = unique_value

# %%
adata.obs['self_reported_ethnicity_ontology_term_id'] = adata.obs['self_reported_ethnicity_ontology_term_id'].astype('category')

# %%
adata.obs['self_reported_ethnicity_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    na
# AAACAAGTATCTCCCA-1    na
# AAACAATCTACTAGCA-1    na
# AAACACCAATAACTGC-1    na
# AAACAGAGCGACTCCT-1    na
#                       ..
# TTGTTTCACATCCAGG-1    na
# TTGTTTCATTAGTCTA-1    na
# TTGTTTCCATACAACT-1    na
# TTGTTTGTATTACACG-1    na
# TTGTTTGTGTAAATTC-1    na
# Name: self_reported_ethnicity_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['na']

# %% [markdown]
# #### **sex_ontology_term_id**

# %%
unique_value = adata1.obs['sex_ontology_term_id'].unique()[0]
unique_value 
adata.obs['sex_ontology_term_id'] = unique_value

# %%
adata.obs['sex_ontology_term_id'] = adata.obs['sex_ontology_term_id'].astype('category')

# %%
adata.obs['sex_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    unknown
# AAACAAGTATCTCCCA-1    unknown
# AAACAATCTACTAGCA-1    unknown
# AAACACCAATAACTGC-1    unknown
# AAACAGAGCGACTCCT-1    unknown
#                        ...
# TTGTTTCACATCCAGG-1    unknown
# TTGTTTCATTAGTCTA-1    unknown
# TTGTTTCCATACAACT-1    unknown
# TTGTTTGTATTACACG-1    unknown
# TTGTTTGTGTAAATTC-1    unknown
# Name: sex_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['unknown']

# %% [markdown]
# #### **suspension_type**

# %%
adata.obs['suspension_type'] = 'na'

# %%
adata.obs['suspension_type'] = adata.obs['suspension_type'].astype('category')

# %% [markdown]
# #### **tissue_type**

# %%
unique_value = adata1.obs['tissue_type'].unique()[0]
unique_value 
adata.obs['tissue_type'] = unique_value

# %%
adata.obs['tissue_type']
# Out:
# AAACAACGAATAGTTC-1    tissue
# AAACAAGTATCTCCCA-1    tissue
# AAACAATCTACTAGCA-1    tissue
# AAACACCAATAACTGC-1    tissue
# AAACAGAGCGACTCCT-1    tissue
#                        ...
# TTGTTTCACATCCAGG-1    tissue
# TTGTTTCATTAGTCTA-1    tissue
# TTGTTTCCATACAACT-1    tissue
# TTGTTTGTATTACACG-1    tissue
# TTGTTTGTGTAAATTC-1    tissue
# Name: tissue_type, Length: 4992, dtype: object

# %%
adata.obs['tissue_type'] = adata.obs['tissue_type'].astype('category')

# %% [markdown]
# #### **tissue_ontology_term_id**

# %%
unique_value = adata1.obs['tissue_ontology_term_id'].unique()[0]
unique_value 
adata.obs['tissue_ontology_term_id'] = unique_value

# %%
adata.obs['tissue_ontology_term_id'] = adata.obs['tissue_ontology_term_id'].astype('category')

# %%
adata.obs['tissue_ontology_term_id']
# Out:
# AAACAACGAATAGTTC-1    UBERON:0001155
# AAACAAGTATCTCCCA-1    UBERON:0001155
# AAACAATCTACTAGCA-1    UBERON:0001155
# AAACACCAATAACTGC-1    UBERON:0001155
# AAACAGAGCGACTCCT-1    UBERON:0001155
#                            ...
# TTGTTTCACATCCAGG-1    UBERON:0001155
# TTGTTTCATTAGTCTA-1    UBERON:0001155
# TTGTTTCCATACAACT-1    UBERON:0001155
# TTGTTTGTATTACACG-1    UBERON:0001155
# TTGTTTGTGTAAATTC-1    UBERON:0001155
# Name: tissue_ontology_term_id, Length: 4992, dtype: category
# Categories (1, object): ['UBERON:0001155']

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             4282
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             4633
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             2856
# AAACACCAATAACTGC-1        1.0       59.0       59.0              593
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             4783
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0              250
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              618
# TTGTTTCCATACAACT-1        1.0       45.0       45.0              316
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              154
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2472
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  1B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                    unknown  1B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                 CL:0000584  1B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000844  1B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  1B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                 CL:0000844  1B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                 CL:0000584  1B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %% [markdown]
# #### **obsm (Embeddings)**

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %% [markdown]
# #### **uns (Dataset Metadata)**

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255054_mm10-2020-A': {'metadata': {'chemistry_description': 'Visium V1 Slide',
#                  'software_version': 'spaceranger-2.0.0'},
#                 'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'lowres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'tissue_lowres_scalef': 0.019862289,
#                  'fiducial_diameter_fullres': 231.82710298294393,
#                  'spot_diameter_fullres': 143.5120161322986}}})])

# %%
adata.uns['image_caption'] = 'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'

# %%
adata.uns['default_embedding'] = 'spatial'

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# %%
#REQUIRED to distinguish single section data from integrated data
adata.uns['spatial']['is_single'] = True

# %%
#PREFERRED to include fullres image
#this is a SpaceRanger input, not an output
fullres_path = '/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Data/spaceranger200_count_46322_Mus_Tcel13255054_mm10-2020-A/V12Y31-030_B1.tif'

#some of the fullres images require expanding the limit
Image.MAX_IMAGE_PIXELS = 699408640

#.ome.tif examples - https://www.heartcellatlas.org/
if fullres_path.endswith('.ome.tif'):
    reader = OMETIFFReader(fpath=fullres_path)
    fullres_np, metadata, xml_metadata = reader.read()

    #may need to transpose the image if its an invalid shape
    fullres_np = np.transpose(fullres_np, (1,2,0))

    sr_adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

    #optional to store image metadata in the dataset
    sr_adata.uns['fullres_xml_metadata'] = xml_metadata
elif fullres_path.split('.')[-1] in ['tif','tiff','jpg']:
    fullres_np = np.asarray(Image.open(fullres_path))

#may need to rotate the image to align with embeddings
#k is the number of times to rotate the image 90 degrees counter-clockwise
fullres_np  = np.rot90(fullres_np, k=3)
fullres_np  = np.rot90(fullres_np, k=1)

adata.uns['spatial'][library_id]['images']['fullres'] = fullres_np

# %%
unique_donor_id = adata.obs['donor_id'].unique()

# Since there is only one unique value, assign it directly to 'adata.uns['title']'
adata.uns['title'] = unique_donor_id[0]

# %%
#adata.uns['title'] = adata.obs['donor_id']

# %%
adata.uns['title']
# Out:
# '1B_Hh.anti_IL10r'

# %%
#OPTIONAL to move metadata before deleting it
adata.uns['spatial_metadata'] = adata.uns['spatial'][library_id]['metadata']

#MUST NOT SUBMIT metadata or lowres or fiducial_diameter_fullres in uns.spatial
del adata.uns['spatial'][library_id]['metadata']
del adata.uns['spatial'][library_id]['images']['lowres']
del adata.uns['spatial'][library_id]['scalefactors']['tissue_lowres_scalef']
del adata.uns['spatial'][library_id]['scalefactors']['fiducial_diameter_fullres']

# %%
#QA by plotting with the hires image
sq.pl.spatial_scatter(
    adata,
    library_id=library_id,
    color='in_tissue'
)

#same plot with fullres image, if present
if 'fullres' in adata.uns['spatial'][library_id]['images']:
    sq.pl.spatial_scatter(
        adata,
        library_id=library_id,
        color='in_tissue',
        img_res_key='fullres',
        scale_factor=1.0
        )

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255054_mm10-2020-A': {'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'fullres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 143.5120161322986}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '1B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
adata.obs
# Out:
#                     in_tissue  array_row  array_col  non_zero_counts  \
# AAACAACGAATAGTTC-1        0.0        0.0        0.0             4282
# AAACAAGTATCTCCCA-1        1.0       50.0       50.0             4633
# AAACAATCTACTAGCA-1        1.0        3.0        3.0             2856
# AAACACCAATAACTGC-1        1.0       59.0       59.0              593
# AAACAGAGCGACTCCT-1        1.0       14.0       14.0             4783
# ...                       ...        ...        ...              ...
# TTGTTTCACATCCAGG-1        1.0       58.0       58.0              250
# TTGTTTCATTAGTCTA-1        1.0       60.0       60.0              618
# TTGTTTCCATACAACT-1        1.0       45.0       45.0              316
# TTGTTTGTATTACACG-1        1.0       73.0       73.0              154
# TTGTTTGTGTAAATTC-1        1.0        7.0        7.0             2472
#
#                    assay_ontology_term_id          barcodes  \
# AAACAACGAATAGTTC-1            EFO:0010961  AAACAACGAATAGTTC
# AAACAAGTATCTCCCA-1            EFO:0010961  AAACAAGTATCTCCCA
# AAACAATCTACTAGCA-1            EFO:0010961  AAACAATCTACTAGCA
# AAACACCAATAACTGC-1            EFO:0010961  AAACACCAATAACTGC
# AAACAGAGCGACTCCT-1            EFO:0010961  AAACAGAGCGACTCCT
# ...                                   ...               ...
# TTGTTTCACATCCAGG-1            EFO:0010961  TTGTTTCACATCCAGG
# TTGTTTCATTAGTCTA-1            EFO:0010961  TTGTTTCATTAGTCTA
# TTGTTTCCATACAACT-1            EFO:0010961  TTGTTTCCATACAACT
# TTGTTTGTATTACACG-1            EFO:0010961  TTGTTTGTATTACACG
# TTGTTTGTGTAAATTC-1            EFO:0010961  TTGTTTGTGTAAATTC
#
#                    cell_type_ontology_term_id          donor_id  \
# AAACAACGAATAGTTC-1                    unknown  1B_Hh.anti_IL10r
# AAACAAGTATCTCCCA-1                    unknown  1B_Hh.anti_IL10r
# AAACAATCTACTAGCA-1                 CL:0000584  1B_Hh.anti_IL10r
# AAACACCAATAACTGC-1                 CL:0000844  1B_Hh.anti_IL10r
# AAACAGAGCGACTCCT-1                    unknown  1B_Hh.anti_IL10r
# ...                                       ...               ...
# TTGTTTCACATCCAGG-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTCATTAGTCTA-1                 CL:0000844  1B_Hh.anti_IL10r
# TTGTTTCCATACAACT-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTGTATTACACG-1                    unknown  1B_Hh.anti_IL10r
# TTGTTTGTGTAAATTC-1                 CL:0000584  1B_Hh.anti_IL10r
#
#                    development_stage_ontology_term_id  \
# AAACAACGAATAGTTC-1                     MmusDv:0000061
# AAACAAGTATCTCCCA-1                     MmusDv:0000061
# AAACAATCTACTAGCA-1                     MmusDv:0000061
# AAACACCAATAACTGC-1                     MmusDv:0000061
# AAACAGAGCGACTCCT-1                     MmusDv:0000061
# ...                                               ...
# TTGTTTCACATCCAGG-1                     MmusDv:0000061
# TTGTTTCATTAGTCTA-1                     MmusDv:0000061
# TTGTTTCCATACAACT-1                     MmusDv:0000061
# TTGTTTGTATTACACG-1                     MmusDv:0000061
# TTGTTTGTGTAAATTC-1                     MmusDv:0000061
#
#                    disease_ontology_term_id  is_primary_data  \
# AAACAACGAATAGTTC-1             PATO:0000461             True
# AAACAAGTATCTCCCA-1             PATO:0000461             True
# AAACAATCTACTAGCA-1             PATO:0000461             True
# AAACACCAATAACTGC-1             PATO:0000461             True
# AAACAGAGCGACTCCT-1             PATO:0000461             True
# ...                                     ...              ...
# TTGTTTCACATCCAGG-1             PATO:0000461             True
# TTGTTTCATTAGTCTA-1             PATO:0000461             True
# TTGTTTCCATACAACT-1             PATO:0000461             True
# TTGTTTGTATTACACG-1             PATO:0000461             True
# TTGTTTGTGTAAATTC-1             PATO:0000461             True
#
#                    organism_ontology_term_id  \
# AAACAACGAATAGTTC-1           NCBITaxon:10090
# AAACAAGTATCTCCCA-1           NCBITaxon:10090
# AAACAATCTACTAGCA-1           NCBITaxon:10090
# AAACACCAATAACTGC-1           NCBITaxon:10090
# AAACAGAGCGACTCCT-1           NCBITaxon:10090
# ...                                      ...
# TTGTTTCACATCCAGG-1           NCBITaxon:10090
# TTGTTTCATTAGTCTA-1           NCBITaxon:10090
# TTGTTTCCATACAACT-1           NCBITaxon:10090
# TTGTTTGTATTACACG-1           NCBITaxon:10090
# TTGTTTGTGTAAATTC-1           NCBITaxon:10090
#
#                    self_reported_ethnicity_ontology_term_id  \
# AAACAACGAATAGTTC-1                                       na
# AAACAAGTATCTCCCA-1                                       na
# AAACAATCTACTAGCA-1                                       na
# AAACACCAATAACTGC-1                                       na
# AAACAGAGCGACTCCT-1                                       na
# ...                                                     ...
# TTGTTTCACATCCAGG-1                                       na
# TTGTTTCATTAGTCTA-1                                       na
# TTGTTTCCATACAACT-1                                       na
# TTGTTTGTATTACACG-1                                       na
# TTGTTTGTGTAAATTC-1                                       na
#
#                    sex_ontology_term_id suspension_type tissue_type  \
# AAACAACGAATAGTTC-1              unknown              na      tissue
# AAACAAGTATCTCCCA-1              unknown              na      tissue
# AAACAATCTACTAGCA-1              unknown              na      tissue
# AAACACCAATAACTGC-1              unknown              na      tissue
# AAACAGAGCGACTCCT-1              unknown              na      tissue
# ...                                 ...             ...         ...
# TTGTTTCACATCCAGG-1              unknown              na      tissue
# TTGTTTCATTAGTCTA-1              unknown              na      tissue
# TTGTTTCCATACAACT-1              unknown              na      tissue
# TTGTTTGTATTACACG-1              unknown              na      tissue
# TTGTTTGTGTAAATTC-1              unknown              na      tissue
#
#                    tissue_ontology_term_id
# AAACAACGAATAGTTC-1          UBERON:0001155
# AAACAAGTATCTCCCA-1          UBERON:0001155
# AAACAATCTACTAGCA-1          UBERON:0001155
# AAACACCAATAACTGC-1          UBERON:0001155
# AAACAGAGCGACTCCT-1          UBERON:0001155
# ...                                    ...
# TTGTTTCACATCCAGG-1          UBERON:0001155
# TTGTTTCATTAGTCTA-1          UBERON:0001155
# TTGTTTCCATACAACT-1          UBERON:0001155
# TTGTTTGTATTACACG-1          UBERON:0001155
# TTGTTTGTGTAAATTC-1          UBERON:0001155
#
# [4992 rows x 17 columns]

# %%
del adata.obs['barcodes']

# %%
adata.obsm
# Out:
# AxisArrays with keys: spatial

# %%
#del adata.obsm['X_spatial']

# %%
adata.var
# Out:
#                     feature_is_filtered
# gene_ids
# ENSMUSG00000051951                False
# ENSMUSG00000089699                False
# ENSMUSG00000102331                False
# ENSMUSG00000102343                False
# ENSMUSG00000025900                False
# ...                                 ...
# ENSMUSG00000095523                False
# ENSMUSG00000095475                False
# ENSMUSG00000094855                False
# ENSMUSG00000095019                False
# ENSMUSG00000095041                False
#
# [32101 rows x 1 columns]

# %%
adata.uns
# Out:
# OrderedDict([('spatial',
#               {'spaceranger200_count_46322_Mus_Tcel13255054_mm10-2020-A': {'images': {'hires': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8),
#                  'fullres': array([[[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         ...,
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]],
#
#                         [[229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          ...,
#                          [229, 225, 225],
#                          [229, 225, 225],
#                          [229, 225, 225]]], dtype=uint8)},
#                 'scalefactors': {'tissue_hires_scalef': 0.066207625,
#                  'spot_diameter_fullres': 143.5120161322986}},
#                'is_single': True}),
#              ('image_caption',
#               'Shown here is an image of ten micron thick cryosections of colon tissue samples stained with H&E'),
#              ('default_embedding', 'spatial'),
#              ('title', '1B_Hh.anti_IL10r'),
#              ('spatial_metadata',
#               {'chemistry_description': 'Visium V1 Slide',
#                'software_version': 'spaceranger-2.0.0'})])

# %%
# Check for non-finite values
invalid_values = adata.obs['array_row'].isna() | ~np.isfinite(adata.obs['array_row'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_row'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_row'] = adata.obs['array_row'].astype(int)
# Out:
# /tmp/ipykernel_48296/2085027531.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   adata.obs['array_row'].fillna(0, inplace=True)

# %%
# Check for non-finite values
invalid_values = adata.obs['array_col'].isna() | ~np.isfinite(adata.obs['array_col'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
    adata.obs['array_col'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['array_col'] = adata.obs['array_col'].astype(int)

# %%
# Check for non-finite values
invalid_values = adata.obs['in_tissue'].isna() | ~np.isfinite(adata.obs['in_tissue'])

# If there are any non-finite values, handle them
if invalid_values.any():
    # Option 1: Drop rows with non-finite values
    #adata = adata[~invalid_values]
    
    # Option 2: Fill missing values with a default (e.g., 0)
     adata.obs['in_tissue'].fillna(0, inplace=True)
    
# Convert to integer
adata.obs['in_tissue'] = adata.obs['in_tissue'].astype(int)

# %%
adata.write('/lustre/scratch127/cellgen/cellgeni/cxgportal_sets/Treg_Gut_Niches/Final_objects/spatial_Tcel13255054.h5ad', compression = 'gzip')

# %%
adata.obs

# %%
required_columns = ['array_col', 'array_row', 'in_tissue']
missing_columns = [col for col in required_columns if col not in adata.obs.columns]

print("Missing columns:", missing_columns)

# %%
print("Data Types:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].dtypes)

print("\nMissing Values:")
print(adata.obs[['array_col', 'array_row', 'in_tissue']].isna().sum())
